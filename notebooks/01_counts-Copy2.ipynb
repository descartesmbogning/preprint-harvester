# %% [markdown]
# # A) Server-by-server “thin view”

# %% [markdown]
# ## 1) Setup (paths + safe view)

# %%
import duckdb
from pathlib import Path

con = duckdb.connect()

# Low-memory settings
con.execute("PRAGMA threads=1;")
con.execute("PRAGMA preserve_insertion_order=false;")
con.execute("PRAGMA enable_object_cache=false;")
con.execute("PRAGMA memory_limit='2GB';")           # try 1GB if still unstable
con.execute("PRAGMA temp_directory='data/tmp_duckdb';")

# 2) Build paths robustly from the notebook folder
ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

BASE = ROOT / "data" / "by_server"

# IMPORTANT: your files are hive-partitioned like:
# data/all_backends/all_crossref/backend=crossref/data_0.parquet
all_backends = (BASE / "*" / "*.parquet").as_posix()
# datacite_glob = (BASE / "all_datacite" / "*" / "*.parquet").as_posix()
# openalex_glob = (BASE / "all_openalex" / "*" / "*.parquet").as_posix()

con.execute(f"""
CREATE OR REPLACE VIEW all_backends AS
SELECT * FROM read_parquet('{all_backends}', hive_partitioning=true, union_by_name=true);
""")
# con.execute(f"""
# CREATE OR REPLACE VIEW datacite AS
# SELECT * FROM read_parquet('{datacite_glob}', hive_partitioning=true, union_by_name=true);
# """)
# con.execute(f"""
# CREATE OR REPLACE VIEW openalex AS
# SELECT * FROM read_parquet('{openalex_glob}', hive_partitioning=true, union_by_name=true);
# """)

# A unified "all_rows" view
con.execute("""
CREATE OR REPLACE VIEW all_rows AS
SELECT * FROM all_backends
""")

print(con.execute("SHOW TABLES").fetchall())

# %%
con.execute("""
SELECT backend, COUNT(*) AS total, COUNT(record_id) AS with_record_id
FROM (
    SELECT backend, record_id FROM all_backends
)
GROUP BY backend
""").df()

# %%
import duckdb
from pathlib import Path

con = duckdb.connect()

# Low-memory settings
con.execute("PRAGMA threads=1;")
con.execute("PRAGMA preserve_insertion_order=false;")
con.execute("PRAGMA enable_object_cache=false;")
con.execute("PRAGMA memory_limit='2GB';")           # try 1GB if still unstable
con.execute("PRAGMA temp_directory='data/tmp_duckdb';")

# 2) Build paths robustly from the notebook folder
ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

BASE = ROOT / "data" / "all_backends"

# IMPORTANT: your files are hive-partitioned like:
# data/all_backends/all_crossref/backend=crossref/data_0.parquet
crossref_glob = (BASE / "all_crossref" / "*" / "*.parquet").as_posix()
datacite_glob = (BASE / "all_datacite" / "*" / "*.parquet").as_posix()
openalex_glob = (BASE / "all_openalex" / "*" / "*.parquet").as_posix()

con.execute(f"""
CREATE OR REPLACE VIEW crossref AS
SELECT * FROM read_parquet('{crossref_glob}', hive_partitioning=true, union_by_name=true);
""")
con.execute(f"""
CREATE OR REPLACE VIEW datacite AS
SELECT * FROM read_parquet('{datacite_glob}', hive_partitioning=true, union_by_name=true);
""")
con.execute(f"""
CREATE OR REPLACE VIEW openalex AS
SELECT * FROM read_parquet('{openalex_glob}', hive_partitioning=true, union_by_name=true);
""")

# A unified "all_rows" view
con.execute("""
CREATE OR REPLACE VIEW all_rows AS
SELECT * FROM crossref
UNION ALL
SELECT * FROM datacite
UNION ALL
SELECT * FROM openalex;
""")

print(con.execute("SHOW TABLES").fetchall())
# Out:
# [('all_rows',), ('crossref',), ('datacite',), ('openalex',)]

# %% [markdown]
# ### Quick helper: list servers so you can copy/paste names

# %%
server_name_df = con.execute("""
SELECT server_name, COUNT(*) AS n
FROM all_rows
GROUP BY 1
ORDER BY n DESC
LIMIT 200;
""").df()

# %%
server_name_df.head(60)
# Out:
#                                           server_name        n
# 0                                               arXiv  2920797
# 1                                                 HAL  1320107
# 2                                                SSRN  1258958
# 3                                     Research Square   870976
# 4                 RePEc: Research Papers in Economics   702078
# 5                                             bioRxiv   306948
# 6                                               eLife   247558
# 7                                       AgEcon Search   189671
# 8                                        ResearchGate   181231
# 9                                               Qeios   172316
# 10                                             Zenodo   166786
# 11                             Open Science Framework   135543
# 12                                      Preprints.org   115815
# 13                                 EconStor Preprints   113013
# 14                      Munich Personal RePEc Archive    99237
# 15                                            medRxiv    75743
# 16                                      Authorea Inc.    65450
# 17                                          EGUsphere    60396
# 18                                           PsyArXiv    56866
# 19                                           ChemRxiv    46475
# 20                                     JMIR Preprints    37631
# 21                            Humanities Commons CORE    30665
# 22                                           TechRxiv    29418
# 23              Social Science Open Access Repository    27201
# 24                                              viXra    25570
# 25               Earth and Space Science Open Archive    22932
# 26                                           SocArXiv    21541
# 27                                           INA-Rxiv    17837
# 28                                      F1000Research    16873
# 29                                    Organic Eprints    13983
# 30                                         DSpace@MIT    12661
# 31                     IACR Cryptology ePrint Archive    11904
# 32                                            ART-Dok     9841
# 33  Digital Access to Scholarship at Harvard (DASH...     9703
# 34                                   E-LIS Repository     9128
# 35                                            engrXiv     7001
# 36                                      PropylaeumDok     6822
# 37                                         EarthArXiv     6537
# 38                                    PeerJ Preprints     6446
# 39                                  Nature Precedings     5210
# 40                              ScienceOpen Preprints     5087
# 41                             Wellcome Open Research     4727
# 42                                            Advance     4401
# 43                                   SciELO Preprints     4141
# 44                                     Thesis Commons     3959
# 45                               UCL Open Environment     3474
# 46                              Cambridge Open Engage     3090
# 47                                         EcoEvoRxiv     2886
# 48                                           CrimRxiv     2838
# 49                                            EdArXiv     2547
# 50                                    PhilSci-Archive     2362
# 51                               Open Research Europe     1877
# 52               National Bureau of Economic Research     1856
# 53                                        Law Archive     1808
# 54                                        ResearchHub     1636
# 55                                          CogPrints     1537
# 56                                     APSA Preprints     1470
# 57                                       PREPRINTS.RU     1415
# 58                        Keldysh Institute Preprints     1258
# 59                                  HRB Open Research     1012

# %%
server_name_df.tail(52)
# Out:
#                                     server_name    n
# 60                         CERN document server  976
# 61                              ARPHA Preprints  890
# 62                                    MetaArXiv  880
# 63                                    SportRxiv  878
# 64                          Gates Open Research  863
# 65                                     AgriRxiv  818
# 66                           Beilstein Archives  697
# 67                           Covid-19 Preprints  647
# 68                           EasyChair preprint  620
# 69                                       MarXiv  508
# 70                                      VeriXiv  504
# 71                                     Arabixiv  502
# 72                                   AfricArXiv  501
# 73                         CrossAsia-Repository  500
# 74                      LIS Scholarship Archive  397
# 75                                     MindRxiv  335
# 76                                     ECSarXiv  314
# 77                                    MediArXiv  309
# 78                         Open Research Africa  288
# 79                                    PaleorXiv  287
# 80           Electron Colloquium Comput Complex  227
# 81                                    prepare@u  227
# 82                                    EnerarXiv  204
# 83                                      Frenxiv  179
# 84                                 Encyclopedia  166
# 85                                    BodoArXiv  165
# 86                               AIJR Preprints  143
# 87                                    IndiaRxiv  142
# 88                                  BioHackrXiv  139
# 89                                    UnisaRxiv  126
# 90                                     LatArXiv  125
# 91   LSE Research Online Documents on Economics  119
# 92                                 SAE Mobilus®  105
# 93                         Oroboros Instruments  100
# 94                          Sciencepaper Online   99
# 95                                     NutriXiv   94
# 96                                FocUS Archive   83
# 97                                     PoolText   79
# 98                   HANS Publication PrePrints   75
# 99                      WikiJournal of Medicine   63
# 100                      WikiJournal of Science   45
# 101               ELPUB (Universitat Wuppertal)   41
# 102                          AMRC Open Research   39
# 103                                         CoP   30
# 104                           MNI Open Research   20
# 105                   WikiJournal of Humanities   10
# 106                                       EmeRI    8
# 107                Prepublicaciones OpenCiencia    8
# 108                                   Therapoid    7
# 109                              NewAddictionsX    7
# 110                    Bepress Legal Repository    6
# 111                                  searchRxiv    2

# %% [markdown]
# ## 2) Choose the server you want to explore

# %%
SERVER = "arXiv"   # <-- change me (exact spelling must match server_name values)
BACKEND = None     # set to "crossref" or "datacite" or "openalex" if you want only one backend

# %% [markdown]
# ## 3) Create a thin server view (casts to VARCHAR to avoid schema drift)
#
# This avoids the COALESCE VARCHAR/BOOLEAN error and drops heavy JSON columns.

# %%
def make_server_view(server_name: str, backend: str | None = None):
    backend_filter = ""
    if backend:
        backend_filter = f"AND backend = '{backend}'"

    con.execute(f"""
    CREATE OR REPLACE VIEW server_thin AS
    SELECT
      CAST(record_id AS VARCHAR)           AS record_id,
      CAST(server_name AS VARCHAR)         AS server_name,
      CAST(backend AS VARCHAR)             AS backend,

      CAST(doi AS VARCHAR)                 AS doi,
      CAST(doi_url AS VARCHAR)             AS doi_url,
      CAST(landing_page_url AS VARCHAR)    AS landing_page_url,

      CAST(version_label AS VARCHAR)       AS version_label,

      -- Relationships (keep these for true version links)
      CAST(relations_json AS VARCHAR)       AS relations_json,
      CAST(raw_relationships_json AS VARCHAR)       AS raw_relationships_json,
      CAST(is_version_of AS VARCHAR)       AS is_version_of,      -- keep as text; we’ll interpret later
      CAST(version_of_ids_json AS VARCHAR) AS version_of_ids_json,
      CAST(is_preprint_of AS VARCHAR)      AS is_preprint_of,
      CAST(published_version_ids_json AS VARCHAR) AS published_version_ids_json,

      -- Dates (helpful for temporal patterns)
      CAST(date_posted AS VARCHAR)         AS date_posted,
      CAST(date_published AS VARCHAR)      AS date_published,
      CAST(date_published_online AS VARCHAR)      AS date_published_online,
      CAST(date_issued AS VARCHAR)         AS date_issued,
      CAST(date_deposited AS VARCHAR)      AS date_deposited,
      CAST(date_indexed AS VARCHAR)        AS date_indexed,
      CAST(date_created AS VARCHAR)        AS date_created,
      CAST(date_registered AS VARCHAR)     AS date_registered,
      CAST(date_updated AS VARCHAR)        AS date_updated,
      CAST(publication_year AS VARCHAR)    AS publication_year
    FROM all_rows
    WHERE server_name = '{server_name}'
    {backend_filter};
    """)

make_server_view(SERVER, BACKEND)
con.execute("SELECT COUNT(*) AS n FROM server_thin").df()
# Out:
#          n
# 0  2920797

# %%
data = con.execute("SELECT * FROM server_thin").df()
data.head()
# Out:
#                              record_id server_name   backend  \
# 0  datacite::10.48550/arxiv.2201.00002       arXiv  datacite
# 1  datacite::10.48550/arxiv.2201.00005       arXiv  datacite
# 2  datacite::10.48550/arxiv.2201.00006       arXiv  datacite
# 3  datacite::10.48550/arxiv.2201.00018       arXiv  datacite
# 4  datacite::10.48550/arxiv.2201.00019       arXiv  datacite
#
#                          doi                                    doi_url  \
# 0  10.48550/arxiv.2201.00002  https://doi.org/10.48550/arxiv.2201.00002
# 1  10.48550/arxiv.2201.00005  https://doi.org/10.48550/arxiv.2201.00005
# 2  10.48550/arxiv.2201.00006  https://doi.org/10.48550/arxiv.2201.00006
# 3  10.48550/arxiv.2201.00018  https://doi.org/10.48550/arxiv.2201.00018
# 4  10.48550/arxiv.2201.00019  https://doi.org/10.48550/arxiv.2201.00019
#
#                    landing_page_url version_label  \
# 0  https://arxiv.org/abs/2201.00002             1
# 1  https://arxiv.org/abs/2201.00005             1
# 2  https://arxiv.org/abs/2201.00006             3
# 3  https://arxiv.org/abs/2201.00018             1
# 4  https://arxiv.org/abs/2201.00019             2
#
#                                       relations_json  \
# 0  [{"relatedIdentifier": "10.1088/1361-6544/ac48...
# 1                                                 []
# 2                                                 []
# 3  [{"relatedIdentifier": "10.21468/scipostphys.1...
# 4  [{"relatedIdentifier": "10.1007/jhep06(2022)11...
#
#                               raw_relationships_json is_version_of  ...  \
# 0  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 1  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 2  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 3  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 4  {"client": {"data": {"id": "arxiv.content", "t...                ...
#
#   date_posted date_published date_published_online date_issued date_deposited  \
# 0        None           None                  None        None           None
# 1        None           None                  None        None           None
# 2        None           None                  None        None           None
# 3        None           None                  None        None           None
# 4        None           None                  None        None           None
#
#   date_indexed date_created date_registered date_updated publication_year
# 0         None   2022-01-04      2022-01-04   2025-05-28             2022
# 1         None   2022-01-04      2022-01-04   2022-01-12             2022
# 2         None   2022-01-04      2022-01-04   2024-05-03             2022
# 3         None   2022-01-04      2022-01-04   2022-11-03             2022
# 4         None   2022-01-04      2022-01-04   2022-07-07             2022
#
# [5 rows x 23 columns]

# %%
data.head(60)
# Out:
#                               record_id server_name   backend  \
# 0   datacite::10.48550/arxiv.2201.00002       arXiv  datacite
# 1   datacite::10.48550/arxiv.2201.00005       arXiv  datacite
# 2   datacite::10.48550/arxiv.2201.00006       arXiv  datacite
# 3   datacite::10.48550/arxiv.2201.00018       arXiv  datacite
# 4   datacite::10.48550/arxiv.2201.00019       arXiv  datacite
# 5   datacite::10.48550/arxiv.2201.00020       arXiv  datacite
# 6   datacite::10.48550/arxiv.2201.00021       arXiv  datacite
# 7   datacite::10.48550/arxiv.2201.00022       arXiv  datacite
# 8   datacite::10.48550/arxiv.2201.00023       arXiv  datacite
# 9   datacite::10.48550/arxiv.2201.00030       arXiv  datacite
# 10  datacite::10.48550/arxiv.2201.00032       arXiv  datacite
# 11  datacite::10.48550/arxiv.2201.00034       arXiv  datacite
# 12  datacite::10.48550/arxiv.2201.00035       arXiv  datacite
# 13  datacite::10.48550/arxiv.2201.00037       arXiv  datacite
# 14  datacite::10.48550/arxiv.2201.00039       arXiv  datacite
# 15  datacite::10.48550/arxiv.2201.00040       arXiv  datacite
# 16  datacite::10.48550/arxiv.2201.00041       arXiv  datacite
# 17  datacite::10.48550/arxiv.2201.00042       arXiv  datacite
# 18  datacite::10.48550/arxiv.2201.00046       arXiv  datacite
# 19  datacite::10.48550/arxiv.2201.00047       arXiv  datacite
# 20  datacite::10.48550/arxiv.2201.00048       arXiv  datacite
# 21  datacite::10.48550/arxiv.2201.00049       arXiv  datacite
# 22  datacite::10.48550/arxiv.2201.00051       arXiv  datacite
# 23  datacite::10.48550/arxiv.2201.00052       arXiv  datacite
# 24  datacite::10.48550/arxiv.2201.00055       arXiv  datacite
# 25  datacite::10.48550/arxiv.2201.00056       arXiv  datacite
# 26  datacite::10.48550/arxiv.2201.00058       arXiv  datacite
# 27  datacite::10.48550/arxiv.2201.00066       arXiv  datacite
# 28  datacite::10.48550/arxiv.2201.00067       arXiv  datacite
# 29  datacite::10.48550/arxiv.2201.00069       arXiv  datacite
# 30  datacite::10.48550/arxiv.2201.00070       arXiv  datacite
# 31  datacite::10.48550/arxiv.2201.00073       arXiv  datacite
# 32  datacite::10.48550/arxiv.2201.00076       arXiv  datacite
# 33  datacite::10.48550/arxiv.2201.00079       arXiv  datacite
# 34  datacite::10.48550/arxiv.2201.00085       arXiv  datacite
# 35  datacite::10.48550/arxiv.2201.00091       arXiv  datacite
# 36  datacite::10.48550/arxiv.2201.00093       arXiv  datacite
# 37  datacite::10.48550/arxiv.2201.00099       arXiv  datacite
# 38  datacite::10.48550/arxiv.2201.00100       arXiv  datacite
# 39  datacite::10.48550/arxiv.2201.00101       arXiv  datacite
# 40  datacite::10.48550/arxiv.2201.00105       arXiv  datacite
# 41  datacite::10.48550/arxiv.2201.00111       arXiv  datacite
# 42  datacite::10.48550/arxiv.2201.00113       arXiv  datacite
# 43  datacite::10.48550/arxiv.2201.00115       arXiv  datacite
# 44  datacite::10.48550/arxiv.2201.00117       arXiv  datacite
# 45  datacite::10.48550/arxiv.2201.00121       arXiv  datacite
# 58  10.48550/arxiv.2201.00150  https://doi.org/10.48550/arxiv.2201.00150
# 59  10.48550/arxiv.2201.00151  https://doi.org/10.48550/arxiv.2201.00151
#
#                     landing_page_url version_label  \
# 0   https://arxiv.org/abs/2201.00002             1
# 1   https://arxiv.org/abs/2201.00005             1
# 2   https://arxiv.org/abs/2201.00006             3
# 3   https://arxiv.org/abs/2201.00018             1
# 4   https://arxiv.org/abs/2201.00019             2
# 5   https://arxiv.org/abs/2201.00020             3
# 6   https://arxiv.org/abs/2201.00021             3
# 7   https://arxiv.org/abs/2201.00022             2
# 8   https://arxiv.org/abs/2201.00023             1
# 9   https://arxiv.org/abs/2201.00030             2
# 10  https://arxiv.org/abs/2201.00032             2
# 11  https://arxiv.org/abs/2201.00034             1
# 12  https://arxiv.org/abs/2201.00035             2
# 13  https://arxiv.org/abs/2201.00037             1
# 14  https://arxiv.org/abs/2201.00039             1
# 15  https://arxiv.org/abs/2201.00040             5
# 16  https://arxiv.org/abs/2201.00041             2
# 17  https://arxiv.org/abs/2201.00042             2
# 18  https://arxiv.org/abs/2201.00046             1
# 19  https://arxiv.org/abs/2201.00047             2
# 20  https://arxiv.org/abs/2201.00048             2
# 21  https://arxiv.org/abs/2201.00049             3
# 22  https://arxiv.org/abs/2201.00051             1
# 23  https://arxiv.org/abs/2201.00052             1
# 24  https://arxiv.org/abs/2201.00055             1
# 25  https://arxiv.org/abs/2201.00056             2
# 26  https://arxiv.org/abs/2201.00058             2
# 27  https://arxiv.org/abs/2201.00066             2
# 28  https://arxiv.org/abs/2201.00067             1
# 29  https://arxiv.org/abs/2201.00069             1
# 30  https://arxiv.org/abs/2201.00070             2
# 31  https://arxiv.org/abs/2201.00073             3
# 32  https://arxiv.org/abs/2201.00076             2
# 33  https://arxiv.org/abs/2201.00079             2
# 34  https://arxiv.org/abs/2201.00085             1
# 35  https://arxiv.org/abs/2201.00091             3
# 36  https://arxiv.org/abs/2201.00093             1
# 37  https://arxiv.org/abs/2201.00099             1
# 38  https://arxiv.org/abs/2201.00100             1
# 39  https://arxiv.org/abs/2201.00101             1
# 40  https://arxiv.org/abs/2201.00105             2
# 41  https://arxiv.org/abs/2201.00111             1
# 42  https://arxiv.org/abs/2201.00113             1
# 43  https://arxiv.org/abs/2201.00115             1
# 44  https://arxiv.org/abs/2201.00117             1
# 45  https://arxiv.org/abs/2201.00121             1
# 46  https://arxiv.org/abs/2201.00123             1
# 47  https://arxiv.org/abs/2201.00128             4
# 48  https://arxiv.org/abs/2201.00129             2
# 49  https://arxiv.org/abs/2201.00130             1
# 50  https://arxiv.org/abs/2201.00131             1
# 51  https://arxiv.org/abs/2201.00132             1
# 52  https://arxiv.org/abs/2201.00133             1
# 53  https://arxiv.org/abs/2201.00134             1
# 54  https://arxiv.org/abs/2201.00140             1
# 55  https://arxiv.org/abs/2201.00141             1
# 56  https://arxiv.org/abs/2201.00146             1
# 57  https://arxiv.org/abs/2201.00149             2
# 58  https://arxiv.org/abs/2201.00150             6
# 59  https://arxiv.org/abs/2201.00151             1
#
#                                        relations_json  \
# 0   [{"relatedIdentifier": "10.1088/1361-6544/ac48...
# 1                                                  []
# 2                                                  []
# 3   [{"relatedIdentifier": "10.21468/scipostphys.1...
# 4   [{"relatedIdentifier": "10.1007/jhep06(2022)11...
# 5   [{"relatedIdentifier": "10.1038/s41467-023-380...
# 6   [{"relatedIdentifier": "10.1051/0004-6361/2021...
# 7   [{"relatedIdentifier": "10.3847/2041-8213/ac64...
# 8   [{"relatedIdentifier": "10.1103/physrevd.105.1...
# 9   [{"relatedIdentifier": "10.1103/physrevd.105.1...
# 10  [{"relatedIdentifier": "10.1063/5.0084219", "r...
# 11  [{"relatedIdentifier": "10.1017/jfm.2022.785",...
# 12  [{"relatedIdentifier": "10.1103/physrevd.105.0...
# 13  [{"relatedIdentifier": "10.1029/2020je006621",...
# 14                                                 []
# 15                                                 []
# 16  [{"relatedIdentifier": "10.1051/cocv/2023046",...
# 17  [{"relatedIdentifier": "10.3389/fnbot.2022.846...
# 18  [{"relatedIdentifier": "10.1103/physrevapplied...
# 19  [{"relatedIdentifier": "10.1103/physrevd.108.0...
# 20  [{"relatedIdentifier": "10.3103/s0027134922020...
# 21  [{"relatedIdentifier": "10.1038/s41467-023-384...
# 22  [{"relatedIdentifier": "10.1016/j.ecresq.2020....
# 23                                                 []
# 24  [{"relatedIdentifier": "10.1109/taes.2021.3139...
# 25  [{"relatedIdentifier": "10.1103/physrevb.105.0...
# 26                                                 []
# 27  [{"relatedIdentifier": "10.1142/s0219887823502...
# 28                                                 []
# 29  [{"relatedIdentifier": "10.1093/mnras/stac1601...
# 30  [{"relatedIdentifier": "10.1103/physrevd.106.0...
# 31  [{"relatedIdentifier": "10.1093/biomet/asac049...
# 32                                                 []
# 33  [{"relatedIdentifier": "10.3847/1538-4357/ac48...
# 34  [{"relatedIdentifier": "10.1088/1751-8121/ac3b...
# 35  [{"relatedIdentifier": "10.1103/physrevresearc...
# 36  [{"relatedIdentifier": "10.1109/ssci47803.2020...
# 37  [{"relatedIdentifier": "10.1109/etecte55893.20...
# 38  [{"relatedIdentifier": "10.1109/tip.2021.31392...
# 39  [{"relatedIdentifier": "10.1016/j.actaastro.20...
# 40  [{"relatedIdentifier": "10.1088/1361-6382/ac6c...
# 41  [{"relatedIdentifier": "10.1109/jiot.2021.3139...
# 42  [{"relatedIdentifier": "10.1016/j.ssc.2022.114...
# 43                                                 []
# 44                                                 []
# 45  [{"relatedIdentifier": "10.1016/j.physb.2021.4...
# 46  [{"relatedIdentifier": "10.1103/physrevd.105.1...
# 47  [{"relatedIdentifier": "10.3842/sigma.2022.058...
# 48  [{"relatedIdentifier": "10.1016/j.ins.2022.10....
# 49  [{"relatedIdentifier": "10.1021/acs.jpcc.1c109...
# 50                                                 []
# 51  [{"relatedIdentifier": "10.1109/icmla51294.202...
# 52  [{"relatedIdentifier": "10.1073/pnas.212231311...
# 53  [{"relatedIdentifier": "10.1063/5.0086067", "r...
# 54  [{"relatedIdentifier": "10.1145/3488560.349848...
# 55                                                 []
# 56                                                 []
# 57  [{"relatedIdentifier": "10.1088/1742-5468/ac5d...
# 58  [{"relatedIdentifier": "10.1145/3510003.351012...
# 59  [{"relatedIdentifier": "10.1051/0004-6361/2021...
#
#                                raw_relationships_json is_version_of  ...  \
# 0   {"client": {"data": {"id": "arxiv.content", "t...                ...
# 1   {"client": {"data": {"id": "arxiv.content", "t...                ...
# 2   {"client": {"data": {"id": "arxiv.content", "t...                ...
# 3   {"client": {"data": {"id": "arxiv.content", "t...                ...
# 4   {"client": {"data": {"id": "arxiv.content", "t...                ...
# 5   {"client": {"data": {"id": "arxiv.content", "t...                ...
# 6   {"client": {"data": {"id": "arxiv.content", "t...                ...
# 7   {"client": {"data": {"id": "arxiv.content", "t...                ...
# 8   {"client": {"data": {"id": "arxiv.content", "t...                ...
# 9   {"client": {"data": {"id": "arxiv.content", "t...                ...
# 10  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 11  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 12  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 13  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 14  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 15  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 16  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 17  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 18  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 19  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 20  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 21  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 22  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 23  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 24  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 25  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 26  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 27  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 28  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 29  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 30  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 31  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 32  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 33  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 34  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 35  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 36  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 37  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 38  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 39  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 40  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 41  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 42  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 43  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 44  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 45  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 46  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 47  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 48  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 49  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 50  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 51  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 52  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 53  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 54  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 55  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 56  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 57  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 58  {"client": {"data": {"id": "arxiv.content", "t...                ...
# 59  {"client": {"data": {"id": "arxiv.content", "t...                ...
#
#    date_posted date_published date_published_online date_issued  \
# 0         None           None                  None        None
# 1         None           None                  None        None
# 2         None           None                  None        None
# 3         None           None                  None        None
# 4         None           None                  None        None
# 5         None           None                  None        None
# 6         None           None                  None        None
# 7         None           None                  None        None
# 8         None           None                  None        None
# 9         None           None                  None        None
# 10        None           None                  None        None
# 11        None           None                  None        None
# 12        None           None                  None        None
# 13        None           None                  None        None
# 14        None           None                  None        None
# 15        None           None                  None        None
# 16        None           None                  None        None
# 17        None           None                  None        None
# 18        None           None                  None        None
# 19        None           None                  None        None
# 20        None           None                  None        None
# 21        None           None                  None        None
# 22        None           None                  None        None
# 23        None           None                  None        None
# 24        None           None                  None        None
# 25        None           None                  None        None
# 26        None           None                  None        None
# 27        None           None                  None        None
# 28        None           None                  None        None
# 29        None           None                  None        None
# 30        None           None                  None        None
# 31        None           None                  None        None
# 32        None           None                  None        None
# 33        None           None                  None        None
# 34        None           None                  None        None
# 35        None           None                  None        None
# 36        None           None                  None        None
# 37        None           None                  None        None
# 38        None           None                  None        None
# 39        None           None                  None        None
# 40        None           None                  None        None
# 41        None           None                  None        None
# 42        None           None                  None        None
# 43        None           None                  None        None
# 44        None           None                  None        None
# 45        None           None                  None        None
# 46        None           None                  None        None
# 47        None           None                  None        None
# 48        None           None                  None        None
# 49        None           None                  None        None
# 50        None           None                  None        None
# 51        None           None                  None        None
# 52        None           None                  None        None
# 53        None           None                  None        None
# 54        None           None                  None        None
# 55        None           None                  None        None
# 56        None           None                  None        None
# 57        None           None                  None        None
# 58        None           None                  None        None
# 59        None           None                  None        None
#
#    date_deposited date_indexed date_created date_registered date_updated  \
# 0            None         None   2022-01-04      2022-01-04   2025-05-28
# 1            None         None   2022-01-04      2022-01-04   2022-01-12
# 2            None         None   2022-01-04      2022-01-04   2024-05-03
# 55           None         None   2022-01-04      2022-01-04   2022-01-14
# 56           None         None   2022-01-04      2022-01-04   2025-05-28
# 57           None         None   2022-01-04      2022-01-04   2022-04-21
# 58           None         None   2022-01-04      2022-01-04   2024-03-22
# 59           None         None   2022-01-04      2022-01-04   2022-03-17
#
#    publication_year
# 0              2022
# 1              2022
# 2              2022
# 3              2022
# 4              2022
# 5              2022
# 6              2022
# 7              2022
# 8              2022
# 9              2022
# 10             2022
# 11             2022
# 12             2022
# 13             2022
# 14             2022
# 15             2022
# 16             2022
# 17             2022
# 18             2022
# 19             2022
# 20             2022
# 21             2022
# 22             2022
# 23             2022
# 24             2022
# 25             2022
# 26             2022
# 27             2022
# 28             2022
# 29             2022
# 30             2022
# 31             2022
# 32             2022
# 33             2022
# 34             2022
# 35             2022
# 36             2022
# 37             2022
# 38             2022
# 39             2022
# 40             2022
# 41             2022
# 42             2022
# 43             2022
# 44             2022
# 45             2022
# 46             2022
# 47             2022
# 48             2022
# 49             2022
# 50             2022
# 51             2022
# 52             2022
# 53             2022
# 54             2022
# 55             2022
# 56             2022
# 57             2022
# 58             2022
# 59             2022
#
# [60 rows x 23 columns]

# %%
data.count()
# Out:
# record_id                     2920797
# server_name                   2920797
# backend                       2920797
# doi                           2920797
# doi_url                       2920797
# landing_page_url              2920797
# version_label                 2920797
# relations_json                2920797
# raw_relationships_json        2920797
# is_version_of                 2920797
# version_of_ids_json                 0
# is_preprint_of                2920797
# published_version_ids_json          0
# date_posted                         0
# date_published                      0
# date_published_online               0
# date_issued                         0
# date_deposited                      0
# date_indexed                        0
# date_created                  2920797
# date_registered               2920797
# date_updated                  2920797
# publication_year              2920797
# dtype: int64

# %%
data[['doi','relations_json']]
# Out:
#                                doi  \
# 0        10.48550/arxiv.2201.00002
# 1        10.48550/arxiv.2201.00005
# 2        10.48550/arxiv.2201.00006
# 3        10.48550/arxiv.2201.00018
# 4        10.48550/arxiv.2201.00019
# ...                            ...
# 2920792  10.48550/arxiv.2501.10584
# 2920793  10.48550/arxiv.2501.10585
# 2920794  10.48550/arxiv.2501.10586
# 2920795  10.48550/arxiv.2501.10587
# 2920796  10.48550/arxiv.2501.10588
#
#                                             relations_json
# 0        [{"relatedIdentifier": "10.1088/1361-6544/ac48...
# 1                                                       []
# 2                                                       []
# 3        [{"relatedIdentifier": "10.21468/scipostphys.1...
# 4        [{"relatedIdentifier": "10.1007/jhep06(2022)11...
# ...                                                    ...
# 2920792                                                 []
# 2920793                                                 []
# 2920794                                                 []
# 2920795  [{"relatedIdentifier": "10.1088/1475-7516/2025...
# 2920796                                                 []
#
# [2920797 rows x 2 columns]

# %%
data['relations_json'][1044404]
# Out:
# '[]'

# %% [markdown]
# ####

# %%
vvv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 vvv
#
# NameError: name 'vvv' is not defined

# %% [markdown]
# # B) Explore versioning signals for ONLY that server

# %% [markdown]
# ## 1) Build a clean version detection table for that server
#
# This outputs: record_id -> version_signal_reasons (pipe-separated reasons).

# %%
con.execute(r"""
CREATE OR REPLACE TABLE server_version_signals AS
WITH base AS (
  SELECT
    record_id,
    server_name,
    backend,

    lower(coalesce(doi, '')) AS doi_l,
    lower(coalesce(landing_page_url, '')) AS landing_l,
    lower(coalesce(version_label, '')) AS vlabel_l,

    -- interpret is_version_of safely from text
    CASE
      WHEN lower(coalesce(is_version_of,'')) IN ('true','t','1','yes') THEN TRUE
      ELSE FALSE
    END AS is_version_of_bool
  FROM server_thin
),
flags AS (
  SELECT
    *,
    regexp_matches(doi_l, '[-._]v[0-9]{1,3}([^0-9]|$)') AS doi_sep_vN,
    regexp_matches(doi_l, '[-._][0-9]{1,3}([^0-9]|$)')  AS doi_sep_N,

    regexp_matches(landing_l, '([?&](version|ver|v)=([0-9]{1,3}))') AS landing_param_version,
    regexp_matches(landing_l, '(/v[0-9]{1,3})(/|$)')                AS landing_path_vN,

    (vlabel_l <> '' AND vlabel_l <> 'null') AS version_label_present,

    (is_version_of_bool) AS metadata_is_version_of
  FROM base
),
reasons AS (
  SELECT
    record_id,
    server_name,
    backend,

    -- Build a pipe-separated reason string
    trim(both '|' from
      (CASE WHEN doi_sep_vN THEN '|doi_sep_vN' ELSE '' END) ||
      (CASE WHEN doi_sep_N THEN '|doi_sep_N' ELSE '' END) ||
      (CASE WHEN landing_param_version THEN '|landing_param_version' ELSE '' END) ||
      (CASE WHEN landing_path_vN THEN '|landing_path_vN' ELSE '' END) ||
      (CASE WHEN version_label_present THEN '|metadata_version_label' ELSE '' END) ||
      (CASE WHEN metadata_is_version_of THEN '|metadata_is_version_of' ELSE '' END)
    ) AS version_signal_reasons
  FROM flags
)
SELECT
  record_id, server_name, backend,
  CASE
    WHEN version_signal_reasons = '' THEN 'no_signal'
    ELSE version_signal_reasons
  END AS version_signal_reasons
FROM reasons;
""")

con.execute("""
SELECT version_signal_reasons, COUNT(*) AS n
FROM server_version_signals
GROUP BY 1
ORDER BY n DESC;
""").df()

# %% [markdown]
# ## 2) Inspect records with any signal (sample)

# %%
con.execute("""
SELECT *
FROM server_version_signals
WHERE version_signal_reasons <> 'no_signal'
LIMIT 200;
""").df()

# %% [markdown]
# # C) Export only THIS server (safe, chunked)
#
# If you want to move one server to Colab or work offline.

# %%
import math
from pathlib import Path

OUT = Path(f"data/all_backends/server_exports/{SERVER}")
OUT.mkdir(parents=True, exist_ok=True)

ROWS_PER_PART = 200_000

total = con.execute("SELECT COUNT(*) FROM server_thin").fetchone()[0]
n_parts = math.ceil(total / ROWS_PER_PART)
print("rows:", total, "parts:", n_parts)

for i in range(n_parts):
    offset = i * ROWS_PER_PART
    out_path = OUT / f"server_thin_part_{i:06d}.parquet"
    con.execute(f"""
        COPY (
            SELECT * FROM server_thin
            LIMIT {ROWS_PER_PART} OFFSET {offset}
        )
        TO '{out_path.as_posix()}'
        (FORMAT PARQUET);
    """)
print("done ->", OUT)
