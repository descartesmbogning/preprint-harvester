# %%
import pandas as pd
# Set option to display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# # A) Counts

# %% [markdown]
# ## import data

# %%
import duckdb
from pathlib import Path

con = duckdb.connect()

# Low-memory settings
con.execute("PRAGMA threads=1;")
con.execute("PRAGMA preserve_insertion_order=false;")
con.execute("PRAGMA enable_object_cache=false;")
con.execute("PRAGMA memory_limit='2GB';")           # try 1GB if still unstable
con.execute("PRAGMA temp_directory='data/tmp_duckdb';")

# 2) Build paths robustly from the notebook folder
ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

BASE = ROOT / "data" / "by_server"

# IMPORTANT: your files are hive-partitioned like:
all_backends = (BASE / "*" / "*.parquet").as_posix()

con.execute(f"""
CREATE OR REPLACE VIEW all_backends AS
SELECT * FROM read_parquet('{all_backends}', hive_partitioning=true, union_by_name=true);
""")

# A unified "all_rows" view
con.execute("""
CREATE OR REPLACE VIEW all_rows AS
SELECT * FROM all_backends
""")

print(con.execute("SHOW TABLES").fetchall())
# Out:
# [('all_backends',), ('all_rows',)]

# %%
con.execute("""
SELECT backend, COUNT(*) AS total, COUNT(record_id) AS with_record_id
FROM (
    SELECT backend, record_id FROM all_backends
)
GROUP BY backend
""").df()
# Out:
#     backend    total  with_record_id
# 0  crossref  3612833         3612833
# 1  datacite  3523368         3523368
# 2  openalex  2350692         2350692

# %% [markdown]
# ## total count

# %%
con.execute("""
SELECT COUNT(DISTINCT record_id) AS total_dedup_records
FROM (
    SELECT record_id FROM all_backends
)
""").df()
# Out:
#    total_dedup_records
# 0              8410094

# %% [markdown]
# ## count per backend

# %%
con.execute("""
SELECT
    backend,
    COUNT(DISTINCT record_id) AS dedup_records
FROM (
    SELECT backend, record_id FROM all_backends
)
GROUP BY backend
ORDER BY dedup_records DESC
""").df()
# Out:
#     backend  dedup_records
# 0  datacite        3520391
# 1  crossref        3187171
# 2  openalex        1702532

# %% [markdown]
# ## count per server

# %%
con.execute("""
SELECT
    backend,
    server_name,
    COUNT(DISTINCT record_id) AS dedup_records
FROM (
    SELECT backend, server_name, record_id FROM all_backends
)
GROUP BY backend, server_name
ORDER BY dedup_records DESC
""").df()
# Out:
#       backend                          server_name  dedup_records
# 0    datacite                                arXiv        2920797
# 1    crossref                                 SSRN        1258958
# 2    openalex                                  HAL        1056424
# 3    crossref                      Research Square         450818
# 4    openalex  RePEc: Research Papers in Economics         389398
# ..        ...                                  ...            ...
# 108  crossref         Prepublicaciones OpenCiencia              8
# 109  crossref                            Therapoid              7
# 110  crossref                       NewAddictionsX              7
# 111  openalex             Bepress Legal Repository              6
# 112  crossref                           searchRxiv              2
#
# [113 rows x 3 columns]

# %%
server_name_df = con.execute("""
SELECT server_name, COUNT(DISTINCT record_id) AS n
FROM all_backends
GROUP BY 1
ORDER BY n DESC
LIMIT 200;
""").df()

# %%
server_name_df.head(60)
# Out:
#                                           server_name        n
# 0                                               arXiv  2920797
# 1                                                SSRN  1258958
# 2                                                 HAL  1056424
# 3                                     Research Square   450818
# 4                 RePEc: Research Papers in Economics   389398
# 5                                             bioRxiv   306948
# 6                                               eLife   247558
# 7                                       AgEcon Search   188173
# 8                                        ResearchGate   181231
# 9                                               Qeios   172316
# 10                                             Zenodo   166786
# 11                             Open Science Framework   119481
# 12                                      Preprints.org   115815
# 13                                            medRxiv    75743
# 14                                 EconStor Preprints    71761
# 15                      Munich Personal RePEc Archive    68692
# 16                                      Authorea Inc.    65450
# 17                                          EGUsphere    60396
# 18                                           PsyArXiv    56866
# 19                                           ChemRxiv    46475
# 20                                     JMIR Preprints    37631
# 21                            Humanities Commons CORE    29584
# 22                                           TechRxiv    29418
# 23              Social Science Open Access Repository    27201
# 24                                              viXra    25570
# 25               Earth and Space Science Open Archive    22932
# 26                                           SocArXiv    21541
# 27                                           INA-Rxiv    17837
# 28                                      F1000Research    16873
# 29                                    Organic Eprints    13983
# 30                                         DSpace@MIT    12661
# 31                     IACR Cryptology ePrint Archive    11904
# 32  Digital Access to Scholarship at Harvard (DASH...     9703
# 33                                            ART-Dok     9653
# 34                                   E-LIS Repository     9128
# 35                                      PropylaeumDok     6750
# 36                                         EarthArXiv     6537
# 37                                    PeerJ Preprints     6446
# 38                                  Nature Precedings     5210
# 39                              ScienceOpen Preprints     5087
# 40                                            engrXiv     4929
# 41                             Wellcome Open Research     4727
# 42                                            Advance     4401
# 43                                   SciELO Preprints     4141
# 44                                     Thesis Commons     3959
# 45                               UCL Open Environment     3474
# 46                              Cambridge Open Engage     3090
# 47                                         EcoEvoRxiv     2886
# 48                                           CrimRxiv     2838
# 49                                            EdArXiv     2547
# 50                                    PhilSci-Archive     2362
# 51                               Open Research Europe     1877
# 52               National Bureau of Economic Research     1856
# 53                                        Law Archive     1808
# 54                                        ResearchHub     1636
# 55                                          CogPrints     1537
# 56                                     APSA Preprints     1470
# 57                                       PREPRINTS.RU     1415
# 58                        Keldysh Institute Preprints     1258
# 59                                  HRB Open Research     1012

# %%
server_name_df.tail(52)
# Out:
#                                     server_name    n
# 60                         CERN document server  973
# 61                              ARPHA Preprints  890
# 62                                    MetaArXiv  880
# 63                                    SportRxiv  878
# 64                          Gates Open Research  863
# 65                                     AgriRxiv  818
# 66                           Beilstein Archives  697
# 67                           Covid-19 Preprints  647
# 68                           EasyChair preprint  620
# 69                                       MarXiv  508
# 70                                      VeriXiv  504
# 71                                     Arabixiv  502
# 72                                   AfricArXiv  501
# 73                         CrossAsia-Repository  479
# 74                      LIS Scholarship Archive  397
# 75                                     MindRxiv  335
# 76                                     ECSarXiv  314
# 77                                    MediArXiv  309
# 78                         Open Research Africa  288
# 79                                    PaleorXiv  287
# 80           Electron Colloquium Comput Complex  227
# 81                                    prepare@u  227
# 82                                    EnerarXiv  204
# 83                                      Frenxiv  179
# 84                                 Encyclopedia  166
# 85                                    BodoArXiv  165
# 86                               AIJR Preprints  143
# 87                                    IndiaRxiv  142
# 88                                  BioHackrXiv  139
# 89                                    UnisaRxiv  126
# 90                                     LatArXiv  125
# 91   LSE Research Online Documents on Economics  119
# 92                                 SAE Mobilus®  105
# 93                          Sciencepaper Online   99
# 94                         Oroboros Instruments   95
# 95                                     NutriXiv   94
# 96                                FocUS Archive   83
# 97                                     PoolText   79
# 98                   HANS Publication PrePrints   75
# 99                      WikiJournal of Medicine   63
# 100                      WikiJournal of Science   45
# 101               ELPUB (Universitat Wuppertal)   41
# 102                          AMRC Open Research   39
# 103                                         CoP   30
# 104                           MNI Open Research   20
# 105                   WikiJournal of Humanities   10
# 106                Prepublicaciones OpenCiencia    8
# 107                                       EmeRI    8
# 108                              NewAddictionsX    7
# 109                                   Therapoid    7
# 110                    Bepress Legal Repository    6
# 111                                  searchRxiv    2

# %% [markdown]
# # B) Explorations

# %%
# con.execute(f"""
# CREATE OR REPLACE VIEW server_thin AS
# SELECT
#   CAST(record_id AS VARCHAR)           AS record_id,
#   CAST(server_name AS VARCHAR)         AS server_name,
#   CAST(backend AS VARCHAR)             AS backend,

#   CAST(doi AS VARCHAR)                 AS doi,
#   CAST(doi_url AS VARCHAR)             AS doi_url,
#   CAST(landing_page_url AS VARCHAR)    AS landing_page_url,

#   CAST(version_label AS VARCHAR)       AS version_label,

#   -- Relationships (keep these for true version links)
#   CAST(relations_json AS VARCHAR)       AS relations_json,
#   CAST(raw_relationships_json AS VARCHAR)       AS raw_relationships_json,
#   CAST(is_version_of AS VARCHAR)       AS is_version_of,      -- keep as text; we’ll interpret later
#   CAST(version_of_ids_json AS VARCHAR) AS version_of_ids_json,
#   CAST(is_preprint_of AS VARCHAR)      AS is_preprint_of,
#   CAST(published_version_ids_json AS VARCHAR) AS published_version_ids_json,

#   -- Dates (helpful for temporal patterns)
#   CAST(date_posted AS VARCHAR)         AS date_posted,
#   CAST(date_published AS VARCHAR)      AS date_published,
#   CAST(date_published_online AS VARCHAR)      AS date_published_online,
#   CAST(date_issued AS VARCHAR)         AS date_issued,
#   CAST(date_deposited AS VARCHAR)      AS date_deposited,
#   CAST(date_indexed AS VARCHAR)        AS date_indexed,
#   CAST(date_created AS VARCHAR)        AS date_created,
#   CAST(date_registered AS VARCHAR)     AS date_registered,
#   CAST(date_updated AS VARCHAR)        AS date_updated,
#   CAST(publication_year AS VARCHAR)    AS publication_year
# FROM all_backends
# """)

# con.execute("SELECT COUNT(*) AS n FROM server_thin").df()

# %%
con.execute(f"""
CREATE OR REPLACE VIEW server_thin AS
SELECT
  CAST(record_id AS VARCHAR)           AS record_id,
  CAST(server_name AS VARCHAR)         AS server_name,
  CAST(backend AS VARCHAR)             AS backend,

  CAST(doi AS VARCHAR)                 AS doi,
  CAST(doi_url AS VARCHAR)             AS doi_url,
  CAST(landing_page_url AS VARCHAR)    AS landing_page_url,

  CAST(title AS VARCHAR) AS title,
  -- CAST(abstract_text AS VARCHAR)      AS abstract_text,
  CAST(authors_flat AS VARCHAR)      AS authors_flat,
  
  -- Dates (helpful for temporal patterns)
  CAST(publication_year AS VARCHAR)    AS publication_year,
  CAST(date_created AS VARCHAR)        AS date_created,
  -- CAST(date_posted AS VARCHAR)         AS date_posted,
  -- CAST(date_deposited AS VARCHAR)      AS date_deposited,

  -- Relationships (keep these for true version links)
  CAST(relations_json AS VARCHAR)       AS relations_json,
  CAST(version_label AS VARCHAR)       AS version_label,
  CAST(is_version_of AS VARCHAR)       AS is_version_of,      -- keep as text; we’ll interpret later
  CAST(is_preprint_of AS VARCHAR)      AS is_preprint_of,
  CAST(has_preprint AS VARCHAR)      AS has_preprint,
  CAST(has_review AS VARCHAR)      AS has_review,
  CAST(has_published_version AS VARCHAR)      AS has_published_version,
  CAST(published_version_ids_json AS VARCHAR) AS published_version_ids_json,
  CAST(version_of_ids_json AS VARCHAR) AS version_of_ids_json,
  CAST(update_to_json AS VARCHAR)      AS update_to_json,
  CAST(raw_relationships_json AS VARCHAR)       AS raw_relationships_json,
FROM all_backends
""")

con.execute("SELECT COUNT(*) AS n FROM server_thin").df()
# Out:
#          n
# 0  9486893

# %% [markdown]
# ## Global Exploration

# %% [markdown]
# ### Duplicates

# %%
data = con.execute("SELECT * FROM server_thin").df()
# data.drop_duplicates(subset=['record_id'], keep='first', inplace=False)

data = data.drop_duplicates()
data
# Out:
#                                record_id     server_name   backend  \
# 0        crossref::10.21467/preprints.48  AIJR Preprints  crossref
# 1        crossref::10.21467/preprints.43  AIJR Preprints  crossref
# 2        crossref::10.21467/preprints.39  AIJR Preprints  crossref
# 3        crossref::10.21467/preprints.38  AIJR Preprints  crossref
# 4        crossref::10.21467/preprints.36  AIJR Preprints  crossref
# ...                                  ...             ...       ...
# 9486888             openalex::W999325625           viXra  openalex
# 9486889             openalex::W999460032           viXra  openalex
# 9486890              openalex::W99967155           viXra  openalex
# 9486891             openalex::W999790414           viXra  openalex
# 9486892             openalex::W999805801           viXra  openalex
#
#                            doi                                doi_url  \
# 0        10.21467/preprints.48  https://doi.org/10.21467/preprints.48
# 1        10.21467/preprints.43  https://doi.org/10.21467/preprints.43
# 2        10.21467/preprints.39  https://doi.org/10.21467/preprints.39
# 3        10.21467/preprints.38  https://doi.org/10.21467/preprints.38
# 4        10.21467/preprints.36  https://doi.org/10.21467/preprints.36
# ...                        ...                                    ...
# 9486888                   None                                   None
# 9486889                   None                                   None
# 9486890                   None                                   None
# 9486891                   None                                   None
# 9486892                   None                                   None
#
#                                           landing_page_url  \
# 0        https://preprints.aijr.org/index.php/ap/prepri...
# 1        https://preprints.aijr.org/index.php/ap/prepri...
# 2        https://preprints.aijr.org/index.php/ap/prepri...
# 3        https://preprints.aijr.org/index.php/ap/prepri...
# 4        https://preprints.aijr.org/index.php/ap/prepri...
# ...                                                    ...
# 9486888              https://vixra.org/pdf/1409.0090v1.pdf
# 9486889                    https://vixra.org/abs/1112.0094
# 9486890              https://vixra.org/pdf/1406.0019v1.pdf
# 9486891              https://vixra.org/pdf/1306.0105v3.pdf
# 9486892              https://vixra.org/pdf/1412.0197v3.pdf
#
#                                                      title  \
# 0        Bird’s Eye View on the Diagnosis, Treatment, &...
# 1        Doxycycline and Minocycline Drugs as a Treatme...
# 2        A Genetic Perspective of 2019-nCoV in Relation...
# 3        Marine Algae as a Natural Source for Antiviral...
# 4        Possible Prevention of COVID 19 by Using Linol...
# ...                                                    ...
# 9486888                 Three Objections to Modern Physics
# 9486889                               Particle Mass Ratios
# 9486890  Quantum FFF Theory Proposals for Some Unsolved...
# 9486891  Investigation of the Formalism of Particle Dyn...
# 9486892  Electromagnetic Energy and Electromagnetic For...
#
#                                               authors_flat publication_year  \
# 0                              Panchalingala, Sai Bhargavi           2020.0
# 1                                         Mostafa, Mohamed           2020.0
# 2                                        Dasgupta, Rimjhim           2020.0
# 3        Musale, Amar S; G., Raja Krishna Kumar; Sapre,...           2020.0
# 4        Subhash, Venkata; G, Raja Krishna Kumar; Sapre...           2020.0
# ...                                                    ...              ...
# 9486888                                      Lubomir Vlcek           2014.0
# 9486889                                         DT Froedge           2011.0
# 9486890                                           Leo Vuyk           2014.0
# 9486891                                        Chi-Yi Chen           2013.0
# 9486892                                    Yu.A. Spirichev           2014.0
#
#                 date_created relations_json version_label is_version_of  \
# 0                 2020-09-15           None          None
# 1                 2020-09-15           None          None
# 2                 2020-09-15           None          None
# 3                 2020-09-17           None          None
# 4                 2020-09-17           None          None
# ...                      ...            ...           ...           ...
# 9486888  2025-10-10T00:00:00           None          None          None
# 9486889  2025-10-10T00:00:00           None          None          None
# 9486890  2025-10-10T00:00:00           None          None          None
# 9486891  2025-10-10T00:00:00           None          None          None
# 9486892  2025-10-10T00:00:00           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 0                                                              false
# 1                                                              false
# 2                                                              false
# 3                                                              false
# 4                                                              false
# ...                ...          ...        ...                   ...
# 9486888           None         None       None                  None
# 9486889           None         None       None                  None
# 9486890           None         None       None                  None
# 9486891           None         None       None                  None
# 9486892           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 0                             None                None           None
# 1                             None                None           None
# 2                             None                None           None
# 3                             None                None           None
# 4                             None                None           None
# ...                            ...                 ...            ...
# 9486888                       None                None           None
# 9486889                       None                None           None
# 9486890                       None                None           None
# 9486891                       None                None           None
# 9486892                       None                None           None
#
#         raw_relationships_json
# 0                         None
# 1                         None
# 2                         None
# 3                         None
# 4                         None
# ...                        ...
# 9486888                   None
# 9486889                   None
# 9486890                   None
# 9486891                   None
# 9486892                   None
#
# [8413526 rows x 21 columns]

# %%
dupes = data[data.duplicated(subset=['record_id'], keep=False)]
dupes
# Out:
#                                                record_id  \
# 15570             crossref::10.31124/advance.24454624.v1
# 16016   crossref::10.31124/advance.170921771.12975902/v1
# 232722    crossref::10.22541/essoar.167016857.73309909.1
# 232752   crossref::10.22541/essoar.167024940.09387576/v1
# 232822   crossref::10.22541/essoar.167045090.02735580/v1
# ...                                                  ...
# 446146   crossref::10.22541/essoar.170365313.34695479/v1
# 446148   crossref::10.22541/essoar.170680200.06135599/v2
# 446149   crossref::10.22541/essoar.170923255.57545328/v1
# 446341   crossref::10.22541/essoar.170612447.73077522/v1
# 446342   crossref::10.22541/essoar.170612447.73077522/v2
#
#                                  server_name   backend  \
# 15570                                Advance  crossref
# 16016                                Advance  crossref
# 232722                         Authorea Inc.  crossref
# 232752                         Authorea Inc.  crossref
# 232822                         Authorea Inc.  crossref
# ...                                      ...       ...
# 446146  Earth and Space Science Open Archive  crossref
# 446341  Alharthi, Abdullah; Tokatli, Ozan; Lopez, Erwi...           2024.0
# 446342                                 Alharthi, Abdullah           2024.0
#
#        date_created                                     relations_json  \
# 15570    2024-02-05                                               None
# 16016    2024-02-29                                               None
# 232722   2022-12-04                                               None
# 232752   2022-12-05                                               None
# 232822   2022-12-07                                               None
# ...             ...                                                ...
# 446146   2023-12-27                                               None
# 446148   2024-02-29  {"is-version-of": [{"asserted-by": "subject", ...
# 446149   2024-02-29                                               None
# 446341   2024-01-24                                               None
# 446342   2024-02-02  {"is-version-of": [{"asserted-by": "subject", ...
#
#        version_label                          is_version_of is_preprint_of  \
# 15570           None
# 16016           None
# 232722          None
# 232752          None
# 232822          None
# ...              ...                                    ...            ...
# 446146          None
# 446148          None  10.22541/essoar.170680200.06135599/v1
# 446149          None
# 446341          None
# 446342          None  10.22541/essoar.170612447.73077522/v1
#
#        has_preprint has_review has_published_version  \
# 15570                                          false
# 16016                                          false
# 232722                                         false
# 232752                                         false
# 232822                                         false
# ...             ...        ...                   ...
# 446146                                         false
# 446148                                         false
# 446149                                         false
# 446341                                         false
# 446342                                         false
#
#        published_version_ids_json version_of_ids_json update_to_json  \
# 15570                        None                None           None
# 16016                        None                None           None
# 232722                       None                None           None
# 232752                       None                None           None
# 232822                       None                None           None
# ...                           ...                 ...            ...
# 446146                       None                None           None
# 446148                       None                None           None
# 446149                       None                None           None
# 446341                       None                None           None
# 446342                       None                None           None
#
#        raw_relationships_json
# 15570                    None
# 16016                    None
# 232722                   None
# 232752                   None
# 232822                   None
# ...                       ...
# 446146                   None
# 446148                   None
# 446149                   None
# 446341                   None
# 446342                   None
#
# [6864 rows x 21 columns]

# %%
dupes['server_name'].value_counts()
# Out:
# server_name
# Authorea Inc.                           3432
# Earth and Space Science Open Archive    3430
# Advance                                    2
# Name: count, dtype: int64

# %%
data[data['record_id']=='crossref::10.31124/advance.24454624.v1']
# Out:
#                                      record_id    server_name   backend  \
# 15570   crossref::10.31124/advance.24454624.v1        Advance  crossref
# 273723  crossref::10.31124/advance.24454624.v1  Authorea Inc.  crossref
#
#                                  doi  \
# 15570   10.31124/advance.24454624.v1
# 273723  10.31124/advance.24454624.v1
#
#                                              doi_url  \
# 15570   https://doi.org/10.31124/advance.24454624.v1
# 273723  https://doi.org/10.31124/advance.24454624.v1
#
#                                          landing_page_url  \
# 15570   https://advance.sagepub.com/doi/full/10.31124/...
# 273723  https://advance.sagepub.com/doi/full/10.31124/...
#
#                                                     title       authors_flat  \
# 15570   Ancient Social Motive Simulation Hypothesis of...  Thomas, Frederick
# 273723  Ancient Social Motive Simulation Hypothesis of...  Thomas, Frederick
#
#        publication_year date_created relations_json version_label  \
# 15570            2024.0   2024-02-05           None          None
# 273723           2024.0   2024-02-05           None          None
#
#        is_version_of is_preprint_of has_preprint has_review  \
# 15570
# 273723
#
#        has_published_version published_version_ids_json version_of_ids_json  \
# 15570                  false                       None                None
# 273723                 false                       None                None
#
#        update_to_json raw_relationships_json
# 15570            None                   None
# 273723           None                   None

# %%
data[data['record_id']=='crossref::10.22541/essoar.170923255.57545328/v1']
# Out:
#                                               record_id  \
# 250777  crossref::10.22541/essoar.170923255.57545328/v1
# 446149  crossref::10.22541/essoar.170923255.57545328/v1
#
#                                  server_name   backend  \
# 250777                         Authorea Inc.  crossref
# 446149  Earth and Space Science Open Archive  crossref
#
#                                           doi  \
# 250777  10.22541/essoar.170923255.57545328/v1
# 446149  10.22541/essoar.170923255.57545328/v1
#
#                                                   doi_url  \
# 250777  https://doi.org/10.22541/essoar.170923255.5754...
# 446149  https://doi.org/10.22541/essoar.170923255.5754...
#
#                                          landing_page_url  \
# 250777  https://essopenarchive.org/users/528524/articl...
# 446149  https://essopenarchive.org/users/528524/articl...
#
#                                                     title  \
# 250777  Data Drought in the Humid Tropics: How to Over...
# 446149  Data Drought in the Humid Tropics: How to Over...
#
#                                              authors_flat publication_year  \
# 250777  Frankenberg, Christian; Bar-On, Yinon Moise; Y...           2024.0
# 446149  Frankenberg, Christian; Bar-On, Yinon Moise; Y...           2024.0
#
#        date_created relations_json version_label is_version_of is_preprint_of  \
# 250777   2024-02-29           None          None
# 446149   2024-02-29           None          None
#
#        has_preprint has_review has_published_version  \
# 250777                                         false
# 446149                                         false
#
#        published_version_ids_json version_of_ids_json update_to_json  \
# 250777                       None                None           None
# 446149                       None                None           None
#
#        raw_relationships_json
# 250777                   None
# 446149                   None

# %% [raw]
# Authorea was harverst using prefix/institution_name as rule, Advance using prefix and Earth and Space Science Open Archive using prefix/doi_prefix_first_token. It seems like data from Advance, specificaly these 2 records (10.31124/advance.24454624.v1, and 10.31124/advance.170921771.12975902/v1), has "Authorea, Inc." in institution_name fieds so we got theses duplicates. The same for  Earth and Space Science Open Archive sever.
# We decide to delect those from Authorea that cause the duplicates issues.,
# Then update the rule file, instead of harverster Authorea metadata using prefix/institution_name, we will use prefix/doi_prefix_first_token, and choose the doi_prefix_first_token specific to Authorea

# %% [markdown]
# #### Resolution

# %%
import pandas as pd

# ----------------------------------
# 1) Define server priority
#    Lower value = higher priority (kept first)
# ----------------------------------
server_priority = {
    "Earth and Space Science Open Archive": 1,
    "Advance": 2,
    "Authorea Inc.": 3
}

# Work on a copy to avoid side effects
data = data.copy()

# ----------------------------------
# 2) Add priority column
#    Unknown servers get lowest priority
# ----------------------------------
data['server_priority'] = (
    data['server_name']
    .map(server_priority)
    .fillna(99)
    .astype(int)
)

# ----------------------------------
# 3) Deduplicate STRICTLY on record_id
#    - Sort so preferred server comes first
#    - Keep only the best row per record_id
# ----------------------------------
data_clean = (
    data
    .sort_values(by=['record_id', 'server_priority'])
    .drop_duplicates(subset=['record_id'], keep='first')
    .drop(columns=['server_priority'])
)

# ----------------------------------
# 4) (Optional but recommended) Inspect removals
# ----------------------------------
removed = data.loc[~data.index.isin(data_clean.index)]

print("Removed rows by server_name:")
print(removed['server_name'].value_counts(dropna=False))

print("\nRows before:", len(data))
print("Rows after :", len(data_clean))
print("Rows removed:", len(removed))

# ----------------------------------
# data_clean is the final deduplicated dataframe
# ----------------------------------
# Out:
# Removed rows by server_name:
# server_name
# Authorea Inc.    3432
# Name: count, dtype: int64
#
# Rows before: 8413526
# Rows after : 8410094
# Rows removed: 3432

# %%
removed
# Out:
#                                                record_id    server_name  \
# 232722    crossref::10.22541/essoar.167016857.73309909.1  Authorea Inc.
# 232752   crossref::10.22541/essoar.167024940.09387576/v1  Authorea Inc.
# 232822   crossref::10.22541/essoar.167045090.02735580/v1  Authorea Inc.
# 232890   crossref::10.22541/essoar.167065826.69236575/v1  Authorea Inc.
# 232903   crossref::10.22541/essoar.167079456.68733298/v1  Authorea Inc.
# ...                                                  ...            ...
# 273720               crossref::10.1002/essoar.10510558.3  Authorea Inc.
# 273721               crossref::10.1002/essoar.10505617.2  Authorea Inc.
# 273722               crossref::10.1002/essoar.10505617.3  Authorea Inc.
# 273723            crossref::10.31124/advance.24454624.v1  Authorea Inc.
# 273724  crossref::10.31124/advance.170921771.12975902/v1  Authorea Inc.
#
#          backend                                     doi  \
# 232722  crossref    10.22541/essoar.167016857.73309909.1
# 232752  crossref   10.22541/essoar.167024940.09387576/v1
# 232822  crossref   10.22541/essoar.167045090.02735580/v1
# 232890  crossref   10.22541/essoar.167065826.69236575/v1
# 232903  crossref   10.22541/essoar.167079456.68733298/v1
# ...          ...                                     ...
# 273720  crossref               10.1002/essoar.10510558.3
# 273721  crossref               10.1002/essoar.10505617.2
# 273722  crossref               10.1002/essoar.10505617.3
# 273723  crossref            10.31124/advance.24454624.v1
# 273724  crossref  10.31124/advance.170921771.12975902/v1
#
#                                                   doi_url  \
# 232722  https://doi.org/10.22541/essoar.167016857.7330...
# 232752  https://doi.org/10.22541/essoar.167024940.0938...
# 232822  https://doi.org/10.22541/essoar.167045090.0273...
# 232890  https://doi.org/10.22541/essoar.167065826.6923...
# 232903  https://doi.org/10.22541/essoar.167079456.6873...
# ...                                                   ...
# 273720          https://doi.org/10.1002/essoar.10510558.3
# 273721          https://doi.org/10.1002/essoar.10505617.2
# 273722          https://doi.org/10.1002/essoar.10505617.3
# 273723       https://doi.org/10.31124/advance.24454624.v1
# 273724  https://doi.org/10.31124/advance.170921771.129...
#
#                                          landing_page_url  \
# 232722  https://www.authorea.com/users/525275/articles...
# 232752  https://www.authorea.com/users/525275/articles...
# 232822  https://www.authorea.com/users/563627/articles...
# 232890  https://www.authorea.com/users/565295/articles...
# 232903  https://www.authorea.com/users/525475/articles...
# ...                                                   ...
# 273720  https://essopenarchive.org/users/968711/articl...
# 273721  https://essopenarchive.org/users/545576/articl...
# 273722  https://essopenarchive.org/users/545576/articl...
# 273723  https://advance.sagepub.com/doi/full/10.31124/...
# 273724  https://advance.sagepub.com/users/748375/artic...
#
#                                                     title  \
# 232722  Non-native hosts of an invasive seaweed holobi...
# 232752  (test) IL-36γ in Enthesitis related Juvenile I...
# 232822  LROCNet: Detecting Impact Ejecta and Older Cra...
# 232890  A simulation study for future geodetic satelli...
# 232903                                      Test Document
# ...                                                   ...
# 273720  Eddy covariance data reveal that a small fresh...
# 273721  COVID-19 and Social Vulnerabilities in Virgini...
# 273722  COVID-19 and Social Vulnerabilities in Virgini...
# 273723  Ancient Social Motive Simulation Hypothesis of...
# 273724  ScholarOne - The Colonial Origin of Population...
#
#                                              authors_flat publication_year  \
# 232722                                     Author, Albert           2022.0
# 232752                                     Author, Albert           2022.0
# 232822  Dunkel, Emily; Lu, Steven; Grimes, Kevin; McAu...           2022.0
# 232890  Najder, Joanna Marta; Sośnica, Krzysztof Jakub...           2022.0
# 232903                                  Hanson, R. Brooks           2022.0
# ...                                                   ...              ...
# 273720  Hounshell, Alexandria G; D'Acunha, Brenda M; B...           2022.0
# 273721                     Patel, Parthay; Patel, Bhaumik           2025.0
# 273722                     Patel, Parthay; Patel, Bhaumik           2025.0
# 273723                                  Thomas, Frederick           2024.0
# 273724          Saijo, Harunobu; Xu, Crystal; Zhang, Anna           2024.0
#
#        date_created                                     relations_json  \
# 232722   2022-12-04                                               None
# 232752   2022-12-05                                               None
# 232822   2022-12-07                                               None
# 232890   2022-12-10                                               None
# 232903   2022-12-11                                               None
# ...             ...                                                ...
# 273720   2022-12-13  {"is-version-of": [{"asserted-by": "subject", ...
# 273721   2025-10-23  {"is-version-of": [{"asserted-by": "subject", ...
# 273722   2025-11-13  {"is-version-of": [{"asserted-by": "subject", ...
# 273723   2024-02-05                                               None
# 273724   2024-02-29                                               None
#
#        version_label              is_version_of is_preprint_of has_preprint  \
# 232722          None
# 232752          None
# 232822          None
# 232890          None
# 232903          None
# ...              ...                        ...            ...          ...
# 273720          None  10.1002/essoar.10510558.1
# 273721          None  10.1002/essoar.10505617.1
# 273722          None  10.1002/essoar.10505617.1
# 273723          None
# 273724          None
#
#        has_review has_published_version published_version_ids_json  \
# 232722                            false                       None
# 232752                            false                       None
# 232822                            false                       None
# 232890                            false                       None
# 232903                            false                       None
# ...           ...                   ...                        ...
# 273720                            false                       None
# 273721                            false                       None
# 273722                            false                       None
# 273723                            false                       None
# 273724                            false                       None
#
#        version_of_ids_json update_to_json raw_relationships_json  \
# 232722                None           None                   None
# 232752                None           None                   None
# 232822                None           None                   None
# 232890                None           None                   None
# 232903                None           None                   None
# ...                    ...            ...                    ...
# 273720                None           None                   None
# 273721                None           None                   None
# 273722                None           None                   None
# 273723                None           None                   None
# 273724                None           None                   None
#
#         server_priority
# 232722                3
# 232752                3
# 232822                3
# 232890                3
# 232903                3
# ...                 ...
# 273720                3
# 273721                3
# 273722                3
# 273723                3
# 273724                3
#
# [3432 rows x 22 columns]

# %%
removed['server_name'].value_counts()
# Out:
# server_name
# Authorea Inc.    3432
# Name: count, dtype: int64

# %%
data_clean.count()
# Out:
# record_id                     8410094
# server_name                   8410094
# backend                       8410094
# doi                           6784859
# doi_url                       6784859
# landing_page_url              8330648
# title                         8410069
# authors_flat                  8194686
# publication_year              8264048
# date_created                  8410094
# relations_json                4253292
# version_label                 2974496
# is_version_of                 6707562
# is_preprint_of                6707562
# has_preprint                  6707562
# has_review                    6707562
# has_published_version         6707562
# published_version_ids_json          0
# version_of_ids_json                 0
# update_to_json                   8899
# raw_relationships_json        3520391
# dtype: int64

# %% [markdown]
# ### Clean columns

# %%
data_clean["title"] = (
    data_clean["title"]
    .astype(str)
    .str.strip()
    .replace({"": pd.NA, "None": pd.NA, "null": pd.NA, "nan": pd.NA,
              "N/A": pd.NA, "[]": pd.NA, "{}": pd.NA})
)

# %%
data_clean["doi"] = (
    data_clean["doi"]
    .astype(str)
    .str.strip()
    .replace({"": pd.NA, "None": pd.NA, "null": pd.NA, "nan": pd.NA,
              "N/A": pd.NA, "[]": pd.NA, "{}": pd.NA})
)

# %%
data_clean["authors_flat"] = (
    data_clean["authors_flat"]
    .astype(str)
    .str.strip()
    .replace({"": pd.NA, "None": pd.NA, "null": pd.NA, "nan": pd.NA,
              "N/A": pd.NA, "[]": pd.NA, "{}": pd.NA})
)

# %%
data_clean["landing_page_url"] = (
    data_clean["landing_page_url"]
    .astype(str)
    .str.strip()
    .replace({"": pd.NA, "None": pd.NA, "null": pd.NA, "nan": pd.NA,
              "N/A": pd.NA, "[]": pd.NA, "{}": pd.NA})
)

# %%
data_clean.shape
# Out:
# (8410094, 21)

# %%
data_clean.count()
# Out:
# record_id                     8410094
# server_name                   8410094
# backend                       8410094
# doi                           6784859
# doi_url                       6784859
# landing_page_url              8330648
# title                         8408457
# authors_flat                  8194673
# publication_year              8264048
# date_created                  8410094
# relations_json                4253292
# version_label                 2974496
# is_version_of                 6707562
# is_preprint_of                6707562
# has_preprint                  6707562
# has_review                    6707562
# has_published_version         6707562
# published_version_ids_json          0
# version_of_ids_json                 0
# update_to_json                   8899
# raw_relationships_json        3520391
# dtype: int64

# %% [markdown]
# ### Summary

# %%
import pandas as pd
import numpy as np

data = data_clean.copy()

# -------------------------------------------------
# Configuration
# -------------------------------------------------
GROUP_COL = 'server_name'

MISSINGNESS_COLUMNS = [
    'doi',
    'landing_page_url'
]

COMPLETENESS_COLUMNS = [
    'version_label',
    'relations_json',
    'is_version_of',
    'is_preprint_of',
    'has_review',
    'has_preprint',
    'has_published_version',
    'version_of_ids_json',
    'update_to_json',
    'published_version_ids_json',
    'raw_relationships_json'
]

# -------------------------------------------------
# Helper functions
# -------------------------------------------------
def is_missing(series):
    """Strict missingness (NaN / None)"""
    return series.isna()

def is_incomplete(series):
    """
    Missing OR empty content:
    - NaN
    - empty string
    - empty list
    - empty dict
    """
    return (
        series.isna()
        | (series.astype(str).str.strip() == '')
        | (series.astype(str).isin(['[]', '{}']))
    )

# -------------------------------------------------
# Base counts per server
# -------------------------------------------------
base = (
    data
    .groupby(GROUP_COL, dropna=False)
    .size()
    .rename('total_records')
    .to_frame()
)

# -------------------------------------------------
# Missingness metrics
# -------------------------------------------------
for col in MISSINGNESS_COLUMNS:
    missing_count = (
        data.loc[is_missing(data[col])]
        .groupby(GROUP_COL, dropna=False)
        .size()
        .rename(f'{col}_missing_count')
    )

    base = base.join(missing_count, how='left').fillna(0)
    base[f'{col}_missing_count'] = base[f'{col}_missing_count'].astype(int)
    base[f'{col}_missing_percent'] = (
        base[f'{col}_missing_count'] / base['total_records'] * 100
    ).round(2)

# -------------------------------------------------
# Completeness metrics
# -------------------------------------------------
for col in COMPLETENESS_COLUMNS:
    incomplete_count = (
        data.loc[is_incomplete(data[col])]
        .groupby(GROUP_COL, dropna=False)
        .size()
        .rename(f'{col}_incomplete_count')
    )

    base = base.join(incomplete_count, how='left').fillna(0)
    base[f'{col}_incomplete_count'] = base[f'{col}_incomplete_count'].astype(int)
    base[f'{col}_incomplete_percent'] = (
        base[f'{col}_incomplete_count'] / base['total_records'] * 100
    ).round(2)

# -------------------------------------------------
# Final table
# -------------------------------------------------
summary = base.sort_values('total_records', ascending=False)

# summary

# %%
summary.head(60)
# Out:
#                                                     total_records  \
# server_name
# arXiv                                                     2920797
# SSRN                                                      1258958
# HAL                                                       1056424
# Research Square                                            450818
# RePEc: Research Papers in Economics                        389398
# bioRxiv                                                    306948
# eLife                                                      247558
# AgEcon Search                                              188173
# ResearchGate                                               181231
# Qeios                                                      172316
# Zenodo                                                     166786
# Open Science Framework                                     119481
# Preprints.org                                              115815
# medRxiv                                                     75743
# EconStor Preprints                                          71761
# Munich Personal RePEc Archive                               68692
# Authorea Inc.                                               62018
# EGUsphere                                                   60396
# PsyArXiv                                                    56866
# ChemRxiv                                                    46475
# JMIR Preprints                                              37631
# Humanities Commons CORE                                     29584
# TechRxiv                                                    29418
# Social Science Open Access Repository                       27201
# viXra                                                       25570
# Earth and Space Science Open Archive                        22932
# SocArXiv                                                    21541
# INA-Rxiv                                                    17837
# F1000Research                                               16873
# Organic Eprints                                             13983
# DSpace@MIT                                                  12661
# IACR Cryptology ePrint Archive                              11904
# Digital Access to Scholarship at Harvard (DASH)...           9703
# ART-Dok                                                      9653
# E-LIS Repository                                             9128
# PropylaeumDok                                                6750
# EarthArXiv                                                   6537
# PeerJ Preprints                                              6446
# Nature Precedings                                            5210
# ScienceOpen Preprints                                        5087
# engrXiv                                                      4929
# Wellcome Open Research                                       4727
# Advance                                                      4401
# SciELO Preprints                                             4141
# Thesis Commons                                               3959
# UCL Open Environment                                         3474
# Cambridge Open Engage                                        3090
# EcoEvoRxiv                                                   2886
# CrimRxiv                                                     2838
# EdArXiv                                                      2547
# PhilSci-Archive                                              2362
# Open Research Europe                                         1877
# National Bureau of Economic Research                         1856
# Law Archive                                                  1808
# ResearchHub                                                  1636
# CogPrints                                                    1537
# APSA Preprints                                               1470
# PREPRINTS.RU                                                 1415
# Keldysh Institute Preprints                                  1258
# HRB Open Research                                            1012
#
#                                                     doi_missing_count  \
# server_name
# arXiv                                                               0
# SSRN                                                                0
# HAL                                                           1024809
# Research Square                                                     0
# RePEc: Research Papers in Economics                            364045
# bioRxiv                                                             0
# eLife                                                               0
# AgEcon Search                                                       0
# ResearchGate                                                        0
# Qeios                                                               0
# Zenodo                                                              0
# Open Science Framework                                              0
# Preprints.org                                                       0
# medRxiv                                                             0
# EconStor Preprints                                              64676
# Munich Personal RePEc Archive                                   67263
# Authorea Inc.                                                       0
# EGUsphere                                                           0
# PsyArXiv                                                            0
# ChemRxiv                                                            0
# JMIR Preprints                                                      0
# Humanities Commons CORE                                             0
# TechRxiv                                                            0
# Social Science Open Access Repository                           20522
# RePEc: Research Papers in Economics                                           100.00
# bioRxiv                                                                       100.00
# eLife                                                                          99.85
# AgEcon Search                                                                 100.00
# ResearchGate                                                                   96.53
# Qeios                                                                         100.00
# Zenodo                                                                         77.14
# Open Science Framework                                                        100.00
# Preprints.org                                                                 100.00
# medRxiv                                                                        99.97
# EconStor Preprints                                                            100.00
# Munich Personal RePEc Archive                                                 100.00
# Authorea Inc.                                                                 100.00
# EGUsphere                                                                     100.00
# PsyArXiv                                                                      100.00
# ChemRxiv                                                                      100.00
# JMIR Preprints                                                                100.00
# Humanities Commons CORE                                                        99.03
# TechRxiv                                                                      100.00
# Social Science Open Access Repository                                         100.00
# viXra                                                                         100.00
# Earth and Space Science Open Archive                                          100.00
# SocArXiv                                                                      100.00
# INA-Rxiv                                                                      100.00
# F1000Research                                                                  66.41
# Organic Eprints                                                               100.00
# DSpace@MIT                                                                    100.00
# IACR Cryptology ePrint Archive                                                100.00
# Digital Access to Scholarship at Harvard (DASH)...                            100.00
# ART-Dok                                                                       100.00
# E-LIS Repository                                                              100.00
# PropylaeumDok                                                                 100.00
# EarthArXiv                                                                    100.00
# PeerJ Preprints                                                               100.00
# Nature Precedings                                                             100.00
# ScienceOpen Preprints                                                         100.00
# engrXiv                                                                       100.00
# Wellcome Open Research                                                         72.52
# Advance                                                                       100.00
# SciELO Preprints                                                              100.00
# Thesis Commons                                                                100.00
# UCL Open Environment                                                          100.00
# Cambridge Open Engage                                                         100.00
# EcoEvoRxiv                                                                    100.00
# CrimRxiv                                                                      100.00
# EdArXiv                                                                       100.00
# PhilSci-Archive                                                               100.00
# Open Research Europe                                                           62.81
# National Bureau of Economic Research                                          100.00
# Law Archive                                                                   100.00
# ResearchHub                                                                   100.00
# CogPrints                                                                     100.00
# APSA Preprints                                                                100.00
# PREPRINTS.RU                                                                  100.00
# Keldysh Institute Preprints                                                   100.00
# HRB Open Research                                                              64.33
#
#                                                     relations_json_incomplete_count  \
# server_name
# arXiv                                                                       1638047
# SSRN                                                                        1258703
# HAL                                                                         1056424
# Research Square                                                              283964
# RePEc: Research Papers in Economics                                          389398
# bioRxiv                                                                      196496
# eLife                                                                        151705
# AgEcon Search                                                                188173
# ResearchGate                                                                 174741
# Qeios                                                                        111907
# Zenodo                                                                          179
# Open Science Framework                                                       105712
# Preprints.org                                                                 41242
# medRxiv                                                                       42266
# EconStor Preprints                                                            71761
# Munich Personal RePEc Archive                                                 68692
# Authorea Inc.                                                                 60087
# EGUsphere                                                                       459
# PsyArXiv                                                                      43289
# ChemRxiv                                                                      20531
# JMIR Preprints                                                                12632
# Humanities Commons CORE                                                        9063
# TechRxiv                                                                      23098
# Social Science Open Access Repository                                         27201
# viXra                                                                         25570
# Earth and Space Science Open Archive                                          19052
# SocArXiv                                                                      15096
# INA-Rxiv                                                                      16225
# F1000Research                                                                  2116
# Organic Eprints                                                               13983
# DSpace@MIT                                                                    12661
# IACR Cryptology ePrint Archive                                                11904
# Digital Access to Scholarship at Harvard (DASH)...                             9703
# ART-Dok                                                                        9653
# Research Square                                                             435544
# RePEc: Research Papers in Economics                                         389398
# bioRxiv                                                                     306947
# eLife                                                                       233206
# AgEcon Search                                                               188173
# ResearchGate                                                                174741
# Qeios                                                                       167745
# Zenodo                                                                      163848
# Open Science Framework                                                      117193
# Preprints.org                                                               102557
# medRxiv                                                                      75743
# EconStor Preprints                                                           71761
# Munich Personal RePEc Archive                                                68692
# Authorea Inc.                                                                60087
# EGUsphere                                                                    60372
# PsyArXiv                                                                     51340
# ChemRxiv                                                                     33548
# JMIR Preprints                                                               37631
# ...
# ChemRxiv                                                                                    100.0
# JMIR Preprints                                                                              100.0
# Humanities Commons CORE                                                                     100.0
# TechRxiv                                                                                    100.0
# Social Science Open Access Repository                                                       100.0
# viXra                                                                                       100.0
# Earth and Space Science Open Archive                                                        100.0
# SocArXiv                                                                                    100.0
# INA-Rxiv                                                                                    100.0
# F1000Research                                                                               100.0
# Organic Eprints                                                                             100.0
# DSpace@MIT                                                                                  100.0
# IACR Cryptology ePrint Archive                                                              100.0
# Digital Access to Scholarship at Harvard (DASH)...                                          100.0
# ART-Dok                                                                                     100.0
# E-LIS Repository                                                                            100.0
# PropylaeumDok                                                                               100.0
# EarthArXiv                                                                                  100.0
# PeerJ Preprints                                                                             100.0
# Nature Precedings                                                                           100.0
# ScienceOpen Preprints                                                                       100.0
# engrXiv                                                                                     100.0
# Wellcome Open Research                                                                      100.0
# Advance                                                                                     100.0
# SciELO Preprints                                                                            100.0
# Thesis Commons                                                                              100.0
# UCL Open Environment                                                                        100.0
# Cambridge Open Engage                                                                       100.0
# EcoEvoRxiv                                                                                  100.0
# CrimRxiv                                                                                    100.0
# EdArXiv                                                                                     100.0
# PhilSci-Archive                                                                             100.0
# Open Research Europe                                                                        100.0
# National Bureau of Economic Research                                                        100.0
# Law Archive                                                                                 100.0
# ResearchHub                                                                                 100.0
# CogPrints                                                                                   100.0
# APSA Preprints                                                                              100.0
# PREPRINTS.RU                                                                                100.0
# Keldysh Institute Preprints                                                                 100.0
# HRB Open Research                                                                           100.0
#
#                                                     raw_relationships_json_incomplete_count  \
# server_name
# arXiv                                                                                     0
# SSRN                                                                                1258958
# HAL                                                                                 1056424
# Research Square                                                                      450818
# RePEc: Research Papers in Economics                                                  389398
# bioRxiv                                                                              306948
# eLife                                                                                247558
# AgEcon Search                                                                             0
# ResearchGate                                                                              0
# Qeios                                                                                172316
# Zenodo                                                                                    0
# Open Science Framework                                                               103652
# Preprints.org                                                                        115815
# medRxiv                                                                               75743
# EconStor Preprints                                                                    71761
# Munich Personal RePEc Archive                                                         68692
# Authorea Inc.                                                                         62018
# EGUsphere                                                                             60396
# PsyArXiv                                                                              56866
# ChemRxiv                                                                              46475
# JMIR Preprints                                                                        37631
# Humanities Commons CORE                                                                   0
# TechRxiv                                                                              29418
# Social Science Open Access Repository                                                 27201
# viXra                                                                                 25570
# Earth and Space Science Open Archive                                                  22932
# SocArXiv                                                                              21541
# INA-Rxiv                                                                              17837
# F1000Research                                                                         16873
# Organic Eprints                                                                       13983
# APSA Preprints                                                                         100.00
# PREPRINTS.RU                                                                           100.00
# Keldysh Institute Preprints                                                            100.00
# HRB Open Research                                                                      100.00

# %%
summary.tail(52)
# Out:
#                                             total_records  doi_missing_count  \
# server_name
# CERN document server                                  973                  0
# ARPHA Preprints                                       890                  0
# MetaArXiv                                             880                  0
# SportRxiv                                             878                  0
# Gates Open Research                                   863                  0
# AgriRxiv                                              818                  0
# Beilstein Archives                                    697                  0
# Covid-19 Preprints                                    647                  0
# EasyChair preprint                                    620                  0
# MarXiv                                                508                  0
# VeriXiv                                               504                  0
# Arabixiv                                              502                  0
# AfricArXiv                                            501                  0
# CrossAsia-Repository                                  479                  0
# LIS Scholarship Archive                               397                  0
# MindRxiv                                              335                  0
# ECSarXiv                                              314                  0
# MediArXiv                                             309                  0
# Open Research Africa                                  288                  0
# PaleorXiv                                             287                  0
# prepare@u                                             227                  0
# Electron Colloquium Comput Complex                    227                227
# EnerarXiv                                             204                  0
# Frenxiv                                               179                  0
# Encyclopedia                                          166                  0
# BodoArXiv                                             165                  0
# AIJR Preprints                                        143                  0
# IndiaRxiv                                             142                  0
# BioHackrXiv                                           139                  0
# UnisaRxiv                                             126                  0
# LatArXiv                                              125                  0
# LSE Research Online Documents on Economics            119                107
# SAE Mobilus®                                          105                  0
# Sciencepaper Online                                    99                  0
# Oroboros Instruments                                   95                  0
# NutriXiv                                               94                  0
# FocUS Archive                                          83                  0
# PoolText                                               79                  0
# HANS Publication PrePrints                             75                  0
# WikiJournal of Medicine                                63                  0
# WikiJournal of Science                                 45                  0
# ELPUB (Universitat Wuppertal)                          41                  0
# AMRC Open Research                                     39                  0
# CoP                                                    30                  0
# MNI Open Research                                      20                  0
# WikiJournal of Humanities                              10                  0
# Prepublicaciones OpenCiencia                            8                  0
# EmeRI                                                   8                  0
# Therapoid                                               7                  0
# NewAddictionsX                                          7                  0
# Bepress Legal Repository                                6                  3
# searchRxiv                                              2                  0
#
#                                             doi_missing_percent  \
# server_name
# CERN document server                                       0.00
# ARPHA Preprints                                            0.00
# MetaArXiv                                                  0.00
# SportRxiv                                                  0.00
# Gates Open Research                                        0.00
# AgriRxiv                                                   0.00
# Beilstein Archives                                         0.00
# Covid-19 Preprints                                         0.00
# EasyChair preprint                                         0.00
# MarXiv                                                     0.00
# VeriXiv                                                    0.00
# Arabixiv                                                   0.00
# AfricArXiv                                                 0.00
# CrossAsia-Repository                                       0.00
# LIS Scholarship Archive                                    0.00
# MindRxiv                                                   0.00
# ECSarXiv                                                   0.00
# MediArXiv                                                  0.00
# Open Research Africa                                       0.00
# PaleorXiv                                                  0.00
# prepare@u                                                  0.00
# Electron Colloquium Comput Complex                       100.00
# EnerarXiv                                                  0.00
# Frenxiv                                                    0.00
# Encyclopedia                                               0.00
# BodoArXiv                                                  0.00
# AIJR Preprints                                             0.00
# IndiaRxiv                                                  0.00
# BioHackrXiv                                                0.00
# UnisaRxiv                                                  0.00
# LatArXiv                                                   0.00
# LSE Research Online Documents on Economics                89.92
# SAE Mobilus®                                               0.00
# Sciencepaper Online                                        0.00
# Oroboros Instruments                                       0.00
# NutriXiv                                                   0.00
# FocUS Archive                                              0.00
# PoolText                                                   0.00
# HANS Publication PrePrints                                 0.00
# WikiJournal of Medicine                                    0.00
# WikiJournal of Science                                     0.00
# ELPUB (Universitat Wuppertal)                              0.00
# AMRC Open Research                                         0.00
# CoP                                                        0.00
# MNI Open Research                                          0.00
# WikiJournal of Humanities                                  0.00
# Prepublicaciones OpenCiencia                               0.00
# EmeRI                                                      0.00
# Therapoid                                                  0.00
# NewAddictionsX                                             0.00
# Bepress Legal Repository                                  50.00
# searchRxiv                                                 0.00
#
#                                             landing_page_url_missing_count  \
# server_name
# CERN document server                                                     0
# ARPHA Preprints                                                          0
# MetaArXiv                                                                0
# SportRxiv                                                                0
# Gates Open Research                                                      0
# AgriRxiv                                                                 0
# Beilstein Archives                                                       0
# Covid-19 Preprints                                                       0
# EasyChair preprint                                                       0
# MarXiv                                                                   0
# VeriXiv                                                                  0
# Arabixiv                                                                 0
# AfricArXiv                                                               0
# CrossAsia-Repository                                                     0
# LIS Scholarship Archive                                                  0
# MindRxiv                                                                 0
# ECSarXiv                                                                 0
# MediArXiv                                                                0
# Open Research Africa                                                     0
# PaleorXiv                                                                0
# prepare@u                                                                0
# Electron Colloquium Comput Complex                                       0
# EnerarXiv                                                                0
# Frenxiv                                                                  0
# Encyclopedia                                                             0
# BodoArXiv                                                                0
# AIJR Preprints                                                           0
# IndiaRxiv                                                                0
# BioHackrXiv                                                              0
# UnisaRxiv                                                                0
# LatArXiv                                                                 0
# LSE Research Online Documents on Economics                               0
# SAE Mobilus®                                                             0
# Sciencepaper Online                                                      0
# Oroboros Instruments                                                     0
# NutriXiv                                                                 0
# FocUS Archive                                                            0
# PoolText                                                                 0
# HANS Publication PrePrints                                               0
# WikiJournal of Medicine                                                  0
# WikiJournal of Science                                                   0
# ELPUB (Universitat Wuppertal)                                            0
# AMRC Open Research                                                       0
# CoP                                                                      0
# MNI Open Research                                                        0
# WikiJournal of Humanities                                                0
# Prepublicaciones OpenCiencia                                             0
# EmeRI                                                                    0
# Therapoid                                                                0
# NewAddictionsX                                                           0
# Bepress Legal Repository                                                 0
# searchRxiv                                                               0
#
#                                             landing_page_url_missing_percent  \
# server_name
# CERN document server                                                     0.0
# ARPHA Preprints                                                          0.0
# MetaArXiv                                                                0.0
# SportRxiv                                                                0.0
# Gates Open Research                                                      0.0
# AgriRxiv                                                                 0.0
# Beilstein Archives                                                       0.0
# Covid-19 Preprints                                                       0.0
# EasyChair preprint                                                       0.0
# MarXiv                                                                   0.0
# VeriXiv                                                                  0.0
# Arabixiv                                                                 0.0
# AfricArXiv                                                               0.0
# CrossAsia-Repository                                                     0.0
# LIS Scholarship Archive                                                  0.0
# MindRxiv                                                                 0.0
# ECSarXiv                                                                 0.0
# MediArXiv                                                                0.0
# Open Research Africa                                                     0.0
# PaleorXiv                                                                0.0
# prepare@u                                                                0.0
# Electron Colloquium Comput Complex                                       0.0
# EnerarXiv                                                                0.0
# Frenxiv                                                                  0.0
# Encyclopedia                                                             0.0
# BodoArXiv                                                                0.0
# AIJR Preprints                                                           0.0
# IndiaRxiv                                                                0.0
# BioHackrXiv                                                              0.0
# UnisaRxiv                                                                0.0
# LatArXiv                                                                 0.0
# LSE Research Online Documents on Economics                               0.0
# SAE Mobilus®                                                             0.0
# Sciencepaper Online                                                      0.0
# Oroboros Instruments                                                     0.0
# NutriXiv                                                                 0.0
# FocUS Archive                                                            0.0
# PoolText                                                                 0.0
# HANS Publication PrePrints                                               0.0
# WikiJournal of Medicine                                                  0.0
# WikiJournal of Science                                                   0.0
# ELPUB (Universitat Wuppertal)                                            0.0
# AMRC Open Research                                                       0.0
# CoP                                                                      0.0
# MNI Open Research                                                        0.0
# WikiJournal of Humanities                                                0.0
# Prepublicaciones OpenCiencia                                             0.0
# EmeRI                                                                    0.0
# Therapoid                                                                0.0
# NewAddictionsX                                                           0.0
# Bepress Legal Repository                                                 0.0
# searchRxiv                                                               0.0
#
#                                             version_label_incomplete_count  \
# server_name
# CERN document server                                                   933
# ARPHA Preprints                                                        890
# MetaArXiv                                                              880
# SportRxiv                                                              878
# Gates Open Research                                                    539
# AgriRxiv                                                               818
# Beilstein Archives                                                     697
# Covid-19 Preprints                                                     647
# EasyChair preprint                                                     620
# MarXiv                                                                 508
# VeriXiv                                                                502
# Arabixiv                                                               502
# AfricArXiv                                                             501
# CrossAsia-Repository                                                   479
# LIS Scholarship Archive                                                397
# MindRxiv                                                               335
# ECSarXiv                                                               314
# MediArXiv                                                              309
# Open Research Africa                                                   188
# PaleorXiv                                                              287
# prepare@u                                                              227
# Electron Colloquium Comput Complex                                     227
# EnerarXiv                                                              204
# Frenxiv                                                                179
# Encyclopedia                                                           166
# BodoArXiv                                                              165
# AIJR Preprints                                                         143
# IndiaRxiv                                                              142
# BioHackrXiv                                                            139
# UnisaRxiv                                                              126
# LatArXiv                                                               125
# LSE Research Online Documents on Economics                             119
# SAE Mobilus®                                                           105
# Sciencepaper Online                                                     99
# Oroboros Instruments                                                    76
# NutriXiv                                                                94
# FocUS Archive                                                           83
# PoolText                                                                79
# HANS Publication PrePrints                                              75
# WikiJournal of Medicine                                                 60
# WikiJournal of Science                                                  45
# ELPUB (Universitat Wuppertal)                                           41
# AMRC Open Research                                                      28
# CoP                                                                     30
# MNI Open Research                                                       14
# WikiJournal of Humanities                                               10
# Prepublicaciones OpenCiencia                                             8
# EmeRI                                                                    8
# Therapoid                                                                7
# NewAddictionsX                                                           7
# Bepress Legal Repository                                                 6
# searchRxiv                                                               2
#
#                                             version_label_incomplete_percent  \
# server_name
# CERN document server                                                   95.89
# ARPHA Preprints                                                       100.00
# MetaArXiv                                                             100.00
# SportRxiv                                                             100.00
# Gates Open Research                                                    62.46
# AgriRxiv                                                              100.00
# Beilstein Archives                                                    100.00
# Covid-19 Preprints                                                    100.00
# EasyChair preprint                                                    100.00
# MarXiv                                                                100.00
# VeriXiv                                                                99.60
# Arabixiv                                                              100.00
# AfricArXiv                                                            100.00
# CrossAsia-Repository                                                  100.00
# LIS Scholarship Archive                                               100.00
# MindRxiv                                                              100.00
# ECSarXiv                                                              100.00
# MediArXiv                                                             100.00
# Open Research Africa                                                   65.28
# PaleorXiv                                                             100.00
# prepare@u                                                             100.00
# Electron Colloquium Comput Complex                                    100.00
# EnerarXiv                                                             100.00
# Frenxiv                                                               100.00
# Encyclopedia                                                          100.00
# BodoArXiv                                                             100.00
# AIJR Preprints                                                        100.00
# IndiaRxiv                                                             100.00
# BioHackrXiv                                                           100.00
# UnisaRxiv                                                             100.00
# LatArXiv                                                              100.00
# LSE Research Online Documents on Economics                            100.00
# SAE Mobilus®                                                          100.00
# Sciencepaper Online                                                   100.00
# Oroboros Instruments                                                   80.00
# NutriXiv                                                              100.00
# FocUS Archive                                                         100.00
# PoolText                                                              100.00
# HANS Publication PrePrints                                            100.00
# WikiJournal of Medicine                                                95.24
# WikiJournal of Science                                                100.00
# ELPUB (Universitat Wuppertal)                                         100.00
# AMRC Open Research                                                     71.79
# CoP                                                                   100.00
# MNI Open Research                                                      70.00
# WikiJournal of Humanities                                             100.00
# Prepublicaciones OpenCiencia                                          100.00
# EmeRI                                                                 100.00
# Therapoid                                                             100.00
# NewAddictionsX                                                        100.00
# Bepress Legal Repository                                              100.00
# searchRxiv                                                            100.00
#
#                                             relations_json_incomplete_count  \
# server_name
# CERN document server                                                     46
# ARPHA Preprints                                                         578
# MetaArXiv                                                               681
# SportRxiv                                                               794
# Gates Open Research                                                      83
# AgriRxiv                                                                805
# Beilstein Archives                                                      236
# Covid-19 Preprints                                                      647
# EasyChair preprint                                                      620
# MarXiv                                                                  249
# VeriXiv                                                                 361
# Arabixiv                                                                280
# AfricArXiv                                                              451
# CrossAsia-Repository                                                      0
# LIS Scholarship Archive                                                 316
# MindRxiv                                                                219
# ECSarXiv                                                                287
# MediArXiv                                                               217
# Open Research Africa                                                     26
# PaleorXiv                                                               154
# prepare@u                                                               227
# Electron Colloquium Comput Complex                                      227
# EnerarXiv                                                               204
# Frenxiv                                                                 123
# Encyclopedia                                                            155
# BodoArXiv                                                               118
# AIJR Preprints                                                          143
# IndiaRxiv                                                               130
# BioHackrXiv                                                             136
# UnisaRxiv                                                               126
# LatArXiv                                                                120
# LSE Research Online Documents on Economics                              119
# SAE Mobilus®                                                             89
# Sciencepaper Online                                                      99
# Oroboros Instruments                                                     94
# NutriXiv                                                                 77
# FocUS Archive                                                            80
# PoolText                                                                 65
# HANS Publication PrePrints                                               75
# WikiJournal of Medicine                                                  63
# WikiJournal of Science                                                   45
# ELPUB (Universitat Wuppertal)                                            40
# AMRC Open Research                                                        2
# CoP                                                                      24
# MNI Open Research                                                         5
# WikiJournal of Humanities                                                10
# Prepublicaciones OpenCiencia                                              7
# EmeRI                                                                     8
# Therapoid                                                                 7
# NewAddictionsX                                                            4
# Bepress Legal Repository                                                  6
# searchRxiv                                                                2
#
#                                             relations_json_incomplete_percent  \
# server_name
# CERN document server                                                     4.73
# ARPHA Preprints                                                         64.94
# MetaArXiv                                                               77.39
# SportRxiv                                                               90.43
# Gates Open Research                                                      9.62
# AgriRxiv                                                                98.41
# Beilstein Archives                                                      33.86
# Covid-19 Preprints                                                     100.00
# EasyChair preprint                                                     100.00
# MarXiv                                                                  49.02
# VeriXiv                                                                 71.63
# Arabixiv                                                                55.78
# AfricArXiv                                                              90.02
# CrossAsia-Repository                                                     0.00
# LIS Scholarship Archive                                                 79.60
# MindRxiv                                                                65.37
# ECSarXiv                                                                91.40
# MediArXiv                                                               70.23
# Open Research Africa                                                     9.03
# PaleorXiv                                                               53.66
# prepare@u                                                              100.00
# Electron Colloquium Comput Complex                                     100.00
# EnerarXiv                                                              100.00
# Frenxiv                                                                 68.72
# Encyclopedia                                                            93.37
# BodoArXiv                                                               71.52
# AIJR Preprints                                                         100.00
# IndiaRxiv                                                               91.55
# BioHackrXiv                                                             97.84
# UnisaRxiv                                                              100.00
# LatArXiv                                                                96.00
# LSE Research Online Documents on Economics                             100.00
# SAE Mobilus®                                                            84.76
# Sciencepaper Online                                                    100.00
# Oroboros Instruments                                                    98.95
# NutriXiv                                                                81.91
# FocUS Archive                                                           96.39
# PoolText                                                                82.28
# HANS Publication PrePrints                                             100.00
# WikiJournal of Medicine                                                100.00
# WikiJournal of Science                                                 100.00
# ELPUB (Universitat Wuppertal)                                           97.56
# AMRC Open Research                                                       5.13
# CoP                                                                     80.00
# MNI Open Research                                                       25.00
# WikiJournal of Humanities                                              100.00
# Prepublicaciones OpenCiencia                                            87.50
# EmeRI                                                                  100.00
# Therapoid                                                              100.00
# NewAddictionsX                                                          57.14
# Bepress Legal Repository                                               100.00
# searchRxiv                                                             100.00
#
#                                             is_version_of_incomplete_count  \
# server_name
# CERN document server                                                   973
# ARPHA Preprints                                                        890
# MetaArXiv                                                              813
# SportRxiv                                                              877
# Gates Open Research                                                    799
# AgriRxiv                                                               818
# Beilstein Archives                                                     697
# Covid-19 Preprints                                                     647
# EasyChair preprint                                                     620
# MarXiv                                                                 506
# VeriXiv                                                                451
# Arabixiv                                                               502
# AfricArXiv                                                             501
# CrossAsia-Repository                                                   479
# LIS Scholarship Archive                                                387
# MindRxiv                                                               335
# ECSarXiv                                                               311
# MediArXiv                                                              302
# Open Research Africa                                                   266
# PaleorXiv                                                              270
# prepare@u                                                              227
# Electron Colloquium Comput Complex                                     227
# EnerarXiv                                                              204
# Frenxiv                                                                179
# Encyclopedia                                                           155
# BodoArXiv                                                              163
# AIJR Preprints                                                         143
# IndiaRxiv                                                              142
# BioHackrXiv                                                            136
# UnisaRxiv                                                              126
# LatArXiv                                                               124
# LSE Research Online Documents on Economics                             119
# SAE Mobilus®                                                           105
# Sciencepaper Online                                                     99
# Oroboros Instruments                                                    94
# NutriXiv                                                                94
# FocUS Archive                                                           83
# PoolText                                                                79
# HANS Publication PrePrints                                              75
# WikiJournal of Medicine                                                 63
# WikiJournal of Science                                                  45
# ELPUB (Universitat Wuppertal)                                           41
# AMRC Open Research                                                      39
# CoP                                                                     29
# MNI Open Research                                                       20
# WikiJournal of Humanities                                               10
# Prepublicaciones OpenCiencia                                             7
# EmeRI                                                                    8
# Therapoid                                                                7
# NewAddictionsX                                                           4
# Bepress Legal Repository                                                 6
# searchRxiv                                                               2
#
#                                             is_version_of_incomplete_percent  \
# server_name
# CERN document server                                                  100.00
# ARPHA Preprints                                                       100.00
# MetaArXiv                                                              92.39
# SportRxiv                                                              99.89
# Gates Open Research                                                    92.58
# AgriRxiv                                                              100.00
# Beilstein Archives                                                    100.00
# Covid-19 Preprints                                                    100.00
# EasyChair preprint                                                    100.00
# MarXiv                                                                 99.61
# VeriXiv                                                                89.48
# Arabixiv                                                              100.00
# AfricArXiv                                                            100.00
# CrossAsia-Repository                                                  100.00
# LIS Scholarship Archive                                                97.48
# MindRxiv                                                              100.00
# ECSarXiv                                                               99.04
# MediArXiv                                                              97.73
# Open Research Africa                                                   92.36
# PaleorXiv                                                              94.08
# prepare@u                                                             100.00
# Electron Colloquium Comput Complex                                    100.00
# EnerarXiv                                                             100.00
# Frenxiv                                                               100.00
# Encyclopedia                                                           93.37
# BodoArXiv                                                              98.79
# AIJR Preprints                                                        100.00
# IndiaRxiv                                                             100.00
# BioHackrXiv                                                            97.84
# UnisaRxiv                                                             100.00
# LatArXiv                                                               99.20
# LSE Research Online Documents on Economics                            100.00
# SAE Mobilus®                                                          100.00
# Sciencepaper Online                                                   100.00
# Oroboros Instruments                                                   98.95
# NutriXiv                                                              100.00
# FocUS Archive                                                         100.00
# PoolText                                                              100.00
# HANS Publication PrePrints                                            100.00
# WikiJournal of Medicine                                               100.00
# WikiJournal of Science                                                100.00
# ELPUB (Universitat Wuppertal)                                         100.00
# AMRC Open Research                                                    100.00
# CoP                                                                    96.67
# MNI Open Research                                                     100.00
# WikiJournal of Humanities                                             100.00
# Prepublicaciones OpenCiencia                                           87.50
# EmeRI                                                                 100.00
# Therapoid                                                             100.00
# NewAddictionsX                                                         57.14
# Bepress Legal Repository                                              100.00
# searchRxiv                                                            100.00
#
#                                             is_preprint_of_incomplete_count  \
# server_name
# CERN document server                                                    443
# ARPHA Preprints                                                         578
# MetaArXiv                                                               742
# SportRxiv                                                               795
# Gates Open Research                                                     863
# AgriRxiv                                                                805
# Beilstein Archives                                                      236
# Covid-19 Preprints                                                      647
# EasyChair preprint                                                      620
# MarXiv                                                                  251
# VeriXiv                                                                 461
# Arabixiv                                                                280
# AfricArXiv                                                              451
# CrossAsia-Repository                                                    479
# LIS Scholarship Archive                                                 326
# MindRxiv                                                                219
# ECSarXiv                                                                290
# MediArXiv                                                               223
# Open Research Africa                                                    288
# PaleorXiv                                                               171
# prepare@u                                                               227
# Electron Colloquium Comput Complex                                      227
# EnerarXiv                                                               204
# Frenxiv                                                                 123
# Encyclopedia                                                            166
# BodoArXiv                                                               120
# AIJR Preprints                                                          143
# IndiaRxiv                                                               130
# BioHackrXiv                                                             139
# UnisaRxiv                                                               126
# LatArXiv                                                                122
# LSE Research Online Documents on Economics                              119
# SAE Mobilus®                                                             89
# Sciencepaper Online                                                      99
# Oroboros Instruments                                                     95
# NutriXiv                                                                 77
# FocUS Archive                                                            80
# PoolText                                                                 65
# HANS Publication PrePrints                                               75
# WikiJournal of Medicine                                                  63
# WikiJournal of Science                                                   45
# ELPUB (Universitat Wuppertal)                                            40
# AMRC Open Research                                                       39
# CoP                                                                      25
# MNI Open Research                                                        20
# WikiJournal of Humanities                                                10
# Prepublicaciones OpenCiencia                                              8
# EmeRI                                                                     8
# Therapoid                                                                 7
# NewAddictionsX                                                            7
# Bepress Legal Repository                                                  6
# searchRxiv                                                                2
#
#                                             is_preprint_of_incomplete_percent  \
# server_name
# CERN document server                                                    45.53
# ARPHA Preprints                                                         64.94
# MetaArXiv                                                               84.32
# SportRxiv                                                               90.55
# Gates Open Research                                                    100.00
# AgriRxiv                                                                98.41
# Beilstein Archives                                                      33.86
# Covid-19 Preprints                                                     100.00
# EasyChair preprint                                                     100.00
# MarXiv                                                                  49.41
# VeriXiv                                                                 91.47
# Arabixiv                                                                55.78
# AfricArXiv                                                              90.02
# CrossAsia-Repository                                                   100.00
# LIS Scholarship Archive                                                 82.12
# MindRxiv                                                                65.37
# ECSarXiv                                                                92.36
# ...
# FocUS Archive                                                                        83
# PoolText                                                                             79
# HANS Publication PrePrints                                                           75
# WikiJournal of Medicine                                                              63
# WikiJournal of Science                                                               45
# ELPUB (Universitat Wuppertal)                                                        41
# AMRC Open Research                                                                   39
# CoP                                                                                  30
# MNI Open Research                                                                    20
# WikiJournal of Humanities                                                            10
# Prepublicaciones OpenCiencia                                                          8
# EmeRI                                                                                 8
# Therapoid                                                                             7
# NewAddictionsX                                                                        7
# Bepress Legal Repository                                                              6
# searchRxiv                                                                            2
#
#                                             published_version_ids_json_incomplete_percent  \
# server_name
# CERN document server                                                                100.0
# ARPHA Preprints                                                                     100.0
# MetaArXiv                                                                           100.0
# SportRxiv                                                                           100.0
# Gates Open Research                                                                 100.0
# AgriRxiv                                                                            100.0
# Beilstein Archives                                                                  100.0
# Covid-19 Preprints                                                                  100.0
# EasyChair preprint                                                                  100.0
# MarXiv                                                                              100.0
# VeriXiv                                                                             100.0
# Arabixiv                                                                            100.0
# AfricArXiv                                                                          100.0
# CrossAsia-Repository                                                                100.0
# LIS Scholarship Archive                                                             100.0
# MindRxiv                                                                            100.0
# ECSarXiv                                                                            100.0
# MediArXiv                                                                           100.0
# Open Research Africa                                                                100.0
# PaleorXiv                                                                           100.0
# prepare@u                                                                           100.0
# Electron Colloquium Comput Complex                                                  100.0
# EnerarXiv                                                                           100.0
# Frenxiv                                                                             100.0
# Encyclopedia                                                                        100.0
# BodoArXiv                                                                           100.0
# AIJR Preprints                                                                      100.0
# IndiaRxiv                                                                           100.0
# BioHackrXiv                                                                         100.0
# UnisaRxiv                                                                           100.0
# LatArXiv                                                                            100.0
# LSE Research Online Documents on Economics                                          100.0
# SAE Mobilus®                                                                        100.0
# Sciencepaper Online                                                                 100.0
# Oroboros Instruments                                                                100.0
# NutriXiv                                                                            100.0
# FocUS Archive                                                                       100.0
# PoolText                                                                            100.0
# HANS Publication PrePrints                                                          100.0
# WikiJournal of Medicine                                                             100.0
# WikiJournal of Science                                                              100.0
# ELPUB (Universitat Wuppertal)                                                       100.0
# AMRC Open Research                                                                  100.0
# CoP                                                                                 100.0
# MNI Open Research                                                                   100.0
# WikiJournal of Humanities                                                           100.0
# Prepublicaciones OpenCiencia                                                        100.0
# EmeRI                                                                               100.0
# Therapoid                                                                           100.0
# NewAddictionsX                                                                      100.0
# Bepress Legal Repository                                                            100.0
# searchRxiv                                                                          100.0
#
#                                             raw_relationships_json_incomplete_count  \
# server_name
# CERN document server                                                              0
# ARPHA Preprints                                                                 890
# MetaArXiv                                                                       880
# SportRxiv                                                                       878
# Gates Open Research                                                             863
# AgriRxiv                                                                        818
# Beilstein Archives                                                              697
# Covid-19 Preprints                                                              647
# EasyChair preprint                                                              620
# MarXiv                                                                          508
# VeriXiv                                                                         504
# Arabixiv                                                                        502
# AfricArXiv                                                                      501
# CrossAsia-Repository                                                              0
# LIS Scholarship Archive                                                         397
# MindRxiv                                                                        335
# ECSarXiv                                                                        314
# MediArXiv                                                                       309
# Open Research Africa                                                            288
# PaleorXiv                                                                       287
# prepare@u                                                                       227
# Electron Colloquium Comput Complex                                              227
# EnerarXiv                                                                       204
# Frenxiv                                                                         179
# Encyclopedia                                                                    166
# BodoArXiv                                                                       165
# AIJR Preprints                                                                  143
# IndiaRxiv                                                                       142
# BioHackrXiv                                                                     139
# UnisaRxiv                                                                       126
# LatArXiv                                                                        125
# LSE Research Online Documents on Economics                                      119
# SAE Mobilus®                                                                    105
# Sciencepaper Online                                                              99
# Oroboros Instruments                                                              0
# NutriXiv                                                                         94
# FocUS Archive                                                                    83
# PoolText                                                                         79
# HANS Publication PrePrints                                                       75
# WikiJournal of Medicine                                                          63
# WikiJournal of Science                                                           45
# ELPUB (Universitat Wuppertal)                                                     0
# AMRC Open Research                                                               39
# CoP                                                                              30
# MNI Open Research                                                                20
# WikiJournal of Humanities                                                        10
# Prepublicaciones OpenCiencia                                                      8
# EmeRI                                                                             8
# Therapoid                                                                         7
# NewAddictionsX                                                                    7
# Bepress Legal Repository                                                          6
# searchRxiv                                                                        2
#
#                                             raw_relationships_json_incomplete_percent
# server_name
# CERN document server                                                              0.0
# ARPHA Preprints                                                                 100.0
# MetaArXiv                                                                       100.0
# SportRxiv                                                                       100.0
# Gates Open Research                                                             100.0
# AgriRxiv                                                                        100.0
# Beilstein Archives                                                              100.0
# Covid-19 Preprints                                                              100.0
# EasyChair preprint                                                              100.0
# MarXiv                                                                          100.0
# VeriXiv                                                                         100.0
# Arabixiv                                                                        100.0
# AfricArXiv                                                                      100.0
# CrossAsia-Repository                                                              0.0
# LIS Scholarship Archive                                                         100.0
# MindRxiv                                                                        100.0
# ECSarXiv                                                                        100.0
# MediArXiv                                                                       100.0
# Open Research Africa                                                            100.0
# PaleorXiv                                                                       100.0
# prepare@u                                                                       100.0
# Electron Colloquium Comput Complex                                              100.0
# EnerarXiv                                                                       100.0
# Frenxiv                                                                         100.0
# Encyclopedia                                                                    100.0
# BodoArXiv                                                                       100.0
# AIJR Preprints                                                                  100.0
# IndiaRxiv                                                                       100.0
# BioHackrXiv                                                                     100.0
# UnisaRxiv                                                                       100.0
# LatArXiv                                                                        100.0
# LSE Research Online Documents on Economics                                      100.0
# SAE Mobilus®                                                                    100.0
# Sciencepaper Online                                                             100.0
# Oroboros Instruments                                                              0.0
# NutriXiv                                                                        100.0
# FocUS Archive                                                                   100.0
# PoolText                                                                        100.0
# HANS Publication PrePrints                                                      100.0
# WikiJournal of Medicine                                                         100.0
# WikiJournal of Science                                                          100.0
# ELPUB (Universitat Wuppertal)                                                     0.0
# AMRC Open Research                                                              100.0
# CoP                                                                             100.0
# MNI Open Research                                                               100.0
# WikiJournal of Humanities                                                       100.0
# Prepublicaciones OpenCiencia                                                    100.0
# EmeRI                                                                           100.0
# Therapoid                                                                       100.0
# NewAddictionsX                                                                  100.0
# Bepress Legal Repository                                                        100.0
# searchRxiv                                                                      100.0

# %%
data_clean
# Out:
#                                    record_id  \
# 429739   crossref::10.1002/essoar.10500000.1
# 429742   crossref::10.1002/essoar.10500002.1
# 429740   crossref::10.1002/essoar.10500004.1
# 429741   crossref::10.1002/essoar.10500007.1
# 429746   crossref::10.1002/essoar.10500009.1
# ...                                      ...
# 2806404                 openalex::W999921877
# 1016201                 openalex::W999947037
# 2713111                 openalex::W999974616
# 1015101                 openalex::W999989114
# 2893587                 openalex::W999989584
#
#                                   server_name   backend  \
# 429739   Earth and Space Science Open Archive  crossref
# 429742   Earth and Space Science Open Archive  crossref
# 429740   Earth and Space Science Open Archive  crossref
# 429741   Earth and Space Science Open Archive  crossref
# 429746   Earth and Space Science Open Archive  crossref
# ...                                       ...       ...
# 2806404   RePEc: Research Papers in Economics  openalex
# 1016201                                   HAL  openalex
# 2713111   RePEc: Research Papers in Economics  openalex
# 1015101                                   HAL  openalex
# 2893587   RePEc: Research Papers in Economics  openalex
#
#                                doi                                    doi_url  \
# 429739   10.1002/essoar.10500000.1  https://doi.org/10.1002/essoar.10500000.1
# 429742   10.1002/essoar.10500002.1  https://doi.org/10.1002/essoar.10500002.1
# 429740   10.1002/essoar.10500004.1  https://doi.org/10.1002/essoar.10500004.1
# 429741   10.1002/essoar.10500007.1  https://doi.org/10.1002/essoar.10500007.1
# 429746   10.1002/essoar.10500009.1  https://doi.org/10.1002/essoar.10500009.1
# ...                            ...                                        ...
# 2806404                       <NA>                                       None
# 1016201                       <NA>                                       None
# 2713111                       <NA>                                       None
# 1015101                       <NA>                                       None
# 2893587                       <NA>                                       None
#
#                                           landing_page_url  \
# 429739   https://essopenarchive.org/doi/full/10.1002/es...
# 429742   https://essopenarchive.org/doi/full/10.1002/es...
# 429740   https://essopenarchive.org/doi/full/10.1002/es...
# 429741   https://essopenarchive.org/doi/full/10.1002/es...
# 429746   https://essopenarchive.org/doi/full/10.1002/es...
# ...                                                    ...
# 2806404  https://steconomice.uoradea.ro/anale/volume/20...
# 1016201                   https://hal.science/hal-01922484
# 2713111   https://EconPapers.repec.org/RePEc:cde:cdewps:19
# 1015101                   https://hal.science/hal-01268467
# 2893587  http://thred.devecon.org/papers/2014/2014-018_...
#
#                                                      title  \
# 429739   Long-term monitoring of land surface phenologi...
# 429742   Impact of spatial scale for phenological indic...
# 429740   Observations of Low Latitude Red Aurora in Mex...
# 429741   Pipeline oil fire detection with MODIS active ...
# 429746   Land Product Validation of MODIS Derived FPAR ...
# ...                                                    ...
# 2806404  IDE sous l'influence du degré de l'intégration...
# 1016201  Building realistic potential patients queries ...
# 2713111  Debt Financing with Limited Liability and Quan...
# 1015101  Sustainable orchards' redesign: at the crossro...
# 2893587  When warm glow burns: Motivational (mis)alloca...
#
#                                               authors_flat publication_year  \
# 429739                                Tsutsumida, Narumasa           2018.0
# 429742                   Tsutsumida, Narumasa; Kaduk, Jörg           2018.0
# 429740   Gonzalez-Esparza, J. Americo; Cuevas-Cardona, ...           2018.0
# 429741   Ogungbuyi, Michael Gbenga; Martinez, Peter; Ec...           2018.0
# 429746   Sharp, Iain; Sanchez-Azofeifa, Arturo; Musilek...           2018.0
# ...                                                    ...              ...
# 2806404                        Simona-Gabriela Serbu Masca           2008.0
# 1016201  Lorraine Goeuriot; Wendy W. Chapman; Gareth Jf...           2014.0
# 2713111                          Krishnendu Ghosh Dastidar           1994.0
# 1015101  Servane Penvern; Sylvaine Simon; Stéphane Bell...           2012.0
# 2893587  Gani Aldashev; Esteban Jaimovich; Thierry Verdier           2015.0
#
#                 date_created  \
# 429739            2019-11-13
# 429742            2019-11-13
# 429740            2019-11-13
# 429741            2019-11-13
# 429746            2019-12-03
# ...                      ...
# 2806404  2025-10-10T00:00:00
# 1016201  2025-10-10T00:00:00
# 2713111  2025-10-10T00:00:00
# 1015101  2025-10-10T00:00:00
# 2893587  2025-10-10T00:00:00
#
#                                             relations_json version_label  \
# 429739                                                None          None
# 429742                                                None          None
# 429740   {"is-preprint-of": [{"asserted-by": "subject",...          None
# 429741                                                None          None
# 429746                                                None          None
# ...                                                    ...           ...
# 2806404                                               None          None
# 1016201                                               None          None
# 2713111                                               None          None
# 1015101                                               None          None
# 2893587                                               None          None
#
#         is_version_of                             is_preprint_of has_preprint  \
# 429739
# 429742
# 429740                 10.1029/2017sw001789;10.1029/2018sw001995
# 429741
# 429746
# ...               ...                                        ...          ...
# 2806404          None                                       None         None
# 1016201          None                                       None         None
# 2713111          None                                       None         None
# 1015101          None                                       None         None
# 2893587          None                                       None         None
#
#         has_review has_published_version published_version_ids_json  \
# 429739                             false                       None
# 429742                             false                       None
# 429740                              true                       None
# 429741                             false                       None
# 429746                             false                       None
# ...            ...                   ...                        ...
# 2806404       None                  None                       None
# 1016201       None                  None                       None
# 2713111       None                  None                       None
# 1015101       None                  None                       None
# 2893587       None                  None                       None
#
#         version_of_ids_json update_to_json raw_relationships_json
# 429739                 None           None                   None
# 429742                 None           None                   None
# 429740                 None           None                   None
# 429741                 None           None                   None
# 429746                 None           None                   None
# ...                     ...            ...                    ...
# 2806404                None           None                   None
# 1016201                None           None                   None
# 2713111                None           None                   None
# 1015101                None           None                   None
# 2893587                None           None                   None
#
# [8410094 rows x 21 columns]

# %% [markdown]
# ## Manage hierarchy

# %% [markdown]
# ### check those who have are version

# %%
pattern = "ew version"

mask = data_clean['version_label'].str.contains(pattern, regex=False, na=False)
result = data_clean[mask]
result
# Out:
#                                       record_id           server_name  \
# 2121749   crossref::10.12688/aasopenres.12825.2  Open Research Africa
# 2121794   crossref::10.12688/aasopenres.12832.2  Open Research Africa
# 2121813   crossref::10.12688/aasopenres.12837.2  Open Research Africa
# 2121910   crossref::10.12688/aasopenres.12841.2  Open Research Africa
# 2121901   crossref::10.12688/aasopenres.12844.2  Open Research Africa
# ...                                         ...                   ...
# 572348   crossref::10.3410/f1000research.1-6.v2         F1000Research
# 5805088       datacite::10.5281/zenodo.16753537                Zenodo
# 5840882       datacite::10.5281/zenodo.17434801                Zenodo
# 5883185       datacite::10.5281/zenodo.17980589                Zenodo
# 5883184       datacite::10.5281/zenodo.17980590                Zenodo
#
#           backend                           doi  \
# 2121749  crossref   10.12688/aasopenres.12825.2
# 2121794  crossref   10.12688/aasopenres.12832.2
# 2121813  crossref   10.12688/aasopenres.12837.2
# 2121910  crossref   10.12688/aasopenres.12841.2
# 2121901  crossref   10.12688/aasopenres.12844.2
# ...           ...                           ...
# 572348   crossref  10.3410/f1000research.1-6.v2
# 5805088  datacite       10.5281/zenodo.16753537
# 5840882  datacite       10.5281/zenodo.17434801
# 5883185  datacite       10.5281/zenodo.17980589
# 5883184  datacite       10.5281/zenodo.17980590
#
#                                               doi_url  \
# 2121749   https://doi.org/10.12688/aasopenres.12825.2
# 2121794   https://doi.org/10.12688/aasopenres.12832.2
# 2121813   https://doi.org/10.12688/aasopenres.12837.2
# 2121910   https://doi.org/10.12688/aasopenres.12841.2
# 2121901   https://doi.org/10.12688/aasopenres.12844.2
# ...                                               ...
# 572348   https://doi.org/10.3410/f1000research.1-6.v2
# 5805088       https://doi.org/10.5281/zenodo.16753537
# 5840882       https://doi.org/10.5281/zenodo.17434801
# 5883185       https://doi.org/10.5281/zenodo.17980589
# 5883184       https://doi.org/10.5281/zenodo.17980590
#
#                                        landing_page_url  \
# 2121749     https://aasopenresearch.org/articles/1-1/v2
# 2121794     https://aasopenresearch.org/articles/1-3/v2
# 2121813    https://aasopenresearch.org/articles/1-12/v2
# 2121910     https://aasopenresearch.org/articles/1-2/v2
# 2121901    https://aasopenresearch.org/articles/1-13/v2
# ...                                                 ...
# 572348         http://f1000research.com/articles/1-6/v2
# 5805088  https://zenodo.org/doi/10.5281/zenodo.16753537
# 5840882  https://zenodo.org/doi/10.5281/zenodo.17434801
# 5883185  https://zenodo.org/doi/10.5281/zenodo.17980589
# 5883184  https://zenodo.org/doi/10.5281/zenodo.17980590
#
#                                                      title  \
# 2121749  Prevalence of chloroquine and antifolate drug ...
# 2121794  The Collaborative African Genomics Network (CA...
# 2121813  Microbiological assessment of sachet water “pu...
# 2121910  Ethical and scientific considerations on the e...
# 2121901  Model framework for governance of genomic rese...
# ...                                                    ...
# 572348   Sirenomelia in a Cameroonian woman: a case rep...
# 5805088  Temperature-driven tunability of a vanadium di...
# 5840882  Temperature-driven tunability of a vanadium di...
# 5883185  Singularity-Free Planck-Scale Dual-Unified Ene...
# 5883184  Singularity-Free Planck-Scale Dual-Unified Ene...
#
#                                               authors_flat publication_year  \
# 2121749  Abugri, James; Ansah, Felix; Asante, Kwaku P.;...           2018.0
# 2121794  Mboowa, Gerald; Mwesigwa, Savannah; Katagirya,...           2018.0
# 2121813  Mosi, Lydia; Adadey, Samuel Mawuli; Sowah, San...           2019.0
# 2121910  Elliott, Alison M.; Roestenberg, Meta; Wajja, ...           2018.0
# 2121901  Yakubu, Aminu; Tindana, Paulina; Matimba, Alic...           2018.0
# ...                                                    ...              ...
# 572348                Morfaw, Frederick LI; Nana, Philip N           2012.0
# 5805088                             Francesco, Scotognella           2025.0
# 5840882                             Francesco, Scotognella           2025.0
# 5883185                                       Nand, Gokula           2025.0
# 5883184                                       Nand, Gokula           2025.0
#
#         date_created                                     relations_json  \
# 2121749   2018-12-03  {"has-review": [{"asserted-by": "subject", "id...
# 2121794   2018-06-21  {"has-review": [{"asserted-by": "subject", "id...
# 2121813   2019-01-24  {"has-review": [{"asserted-by": "subject", "id...
# 2121910   2018-08-06  {"has-review": [{"asserted-by": "subject", "id...
# 2121901   2018-12-12                                               None
# ...              ...                                                ...
# 572348    2015-06-25                                               None
# 5805088   2025-08-06  [{"relatedIdentifier": "10.5281/zenodo.1743480...
# 5840882   2025-10-24  [{"relatedIdentifier": "10.5281/zenodo.1675353...
# 5883185   2025-12-18  [{"relatedIdentifier": "10.5281/zenodo.1800041...
# 5883184   2025-12-18  [{"relatedIdentifier": "10.5281/zenodo.1798058...
#
#                                              version_label is_version_of  \
# 2121749                                        New version
# 2121794                                        New version
# 2121813                                        New version
# 2121910                                        New version
# 2121901                                        New version
# ...                                                    ...           ...
# 572348                                         New version
# 5805088  2 [New version of the manuscript uploaded on A...
# 5840882  2 [New version of the manuscript uploaded on A...
# 5883185                                        new version
# 5883184                                        new version
#
#                   is_preprint_of has_preprint  \
# 2121749
# 2121794
# 2121813
# 2121910
# 2121901
# ...                          ...          ...
# 572348
# 5805088
# 5840882  10.5281/zenodo.16753537
# 5883185
# 5883184  10.5281/zenodo.17980589
#
#                                                 has_review  \
# 2121749                   10.21956/aasopenres.13998.r26676
# 2121794                   10.21956/aasopenres.13951.r26487
# 2121813  10.21956/aasopenres.14017.r26741;10.21956/aaso...
# 2121910                   10.21956/aasopenres.13967.r26567
# 2121901
# ...                                                    ...
# 572348
# 5805088
# 5840882
# 5883185
# 5883184
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 2121749                 false                       None                None
# 2121794                 false                       None                None
# 2121813                 false                       None                None
# 2121910                 false                       None                None
# 2121901                 false                       None                None
# ...                       ...                        ...                 ...
# 572348                  false                       None                None
# 5805088                 false                       None                None
# 5840882                  true                       None                None
# 5883185                 false                       None                None
# 5883184                  true                       None                None
#
#                                             update_to_json  \
# 2121749  [{"DOI": "10.12688/aasopenres.12825.1", "label...
# 2121794  [{"DOI": "10.12688/aasopenres.12832.1", "label...
# 2121813  [{"DOI": "10.12688/aasopenres.12837.1", "label...
# 2121910  [{"DOI": "10.12688/aasopenres.12841.1", "label...
# 2121901  [{"DOI": "10.12688/aasopenres.12844.1", "label...
# ...                                                    ...
# 572348   [{"DOI": "10.3410/f1000research.1-6.v1", "labe...
# 5805088                                               None
# 5840882                                               None
# 5883185                                               None
# 5883184                                               None
#
#                                     raw_relationships_json
# 2121749                                               None
# 2121794                                               None
# 2121813                                               None
# 2121910                                               None
# 2121901                                               None
# ...                                                    ...
# 572348                                                None
# 5805088  {"client": {"data": {"id": "cern.zenodo", "typ...
# 5840882  {"client": {"data": {"id": "cern.zenodo", "typ...
# 5883185  {"client": {"data": {"id": "cern.zenodo", "typ...
# 5883184  {"client": {"data": {"id": "cern.zenodo", "typ...
#
# [8456 rows x 21 columns]

# %%
result['server_name'].value_counts()
# Out:
# server_name
# F1000Research             5651
# Wellcome Open Research    1299
# Open Research Europe       698
# HRB Open Research          361
# Gates Open Research        324
# Open Research Africa       100
# AMRC Open Research          11
# MNI Open Research            6
# Zenodo                       4
# VeriXiv                      2
# Name: count, dtype: int64

# %%
df_version = data_clean.copy()

# Normalize version_label once
vl = df_version["version_label"].astype(str).str.strip().str.lower()

# CHILD rules
child_mask = (
    # mask_remain &
    vl.isin(["new version", 'new version; retraction'])
)
df_version.loc[child_mask, "records_hierarchy"] = "version"

# correction rules
correction_mask = (
    # mask_remain &
    vl.isin(["correction"])
)
df_version.loc[correction_mask, "records_hierarchy"] = "correction"

print(df_version["records_hierarchy"].value_counts(dropna=False))
# Out:
# records_hierarchy
# NaN           8401285
# version          8454
# correction        355
# Name: count, dtype: int64

# %%
df_label = df_version[df_version['records_hierarchy'].notna()]
df_label['server_name'].value_counts()
# Out:
# server_name
# F1000Research              5651
# Wellcome Open Research     1299
# Open Research Europe        698
# HRB Open Research           361
# eLife                       354
# Gates Open Research         324
# Open Research Africa        100
# AMRC Open Research           11
# MNI Open Research             6
# VeriXiv                       2
# Zenodo                        2
# WikiJournal of Medicine       1
# Name: count, dtype: int64

# %%
pattern = "is-version-of"

mask = df_version['relations_json'].str.contains(pattern, regex=False, na=False)
result = df_version[mask]
result
# Out:
#                                    record_id  \
# 442472   crossref::10.1002/essoar.10503117.2
# 442443   crossref::10.1002/essoar.10503623.3
# 442692   crossref::10.1002/essoar.10503738.2
# 442249   crossref::10.1002/essoar.10505190.2
# 442462   crossref::10.1002/essoar.10505545.4
# ...                                      ...
# 9330883      crossref::10.7554/elife.99997.3
# 9370551        crossref::10.7554/elife.99999
# 9351901      crossref::10.7554/elife.99999.1
# 9366338      crossref::10.7554/elife.99999.2
# 9370550      crossref::10.7554/elife.99999.3
#
#                                   server_name   backend  \
# 442472   Earth and Space Science Open Archive  crossref
# 442443   Earth and Space Science Open Archive  crossref
# 442692   Earth and Space Science Open Archive  crossref
# 442249   Earth and Space Science Open Archive  crossref
# 442462   Earth and Space Science Open Archive  crossref
# ...                                       ...       ...
# 9330883                                 eLife  crossref
# 9370551                                 eLife  crossref
# 9351901                                 eLife  crossref
# 9366338                                 eLife  crossref
# 9370550                                 eLife  crossref
#
#                                doi                                    doi_url  \
# 442472   10.1002/essoar.10503117.2  https://doi.org/10.1002/essoar.10503117.2
# 442443   10.1002/essoar.10503623.3  https://doi.org/10.1002/essoar.10503623.3
# 442692   10.1002/essoar.10503738.2  https://doi.org/10.1002/essoar.10503738.2
# 442249   10.1002/essoar.10505190.2  https://doi.org/10.1002/essoar.10505190.2
# 442462   10.1002/essoar.10505545.4  https://doi.org/10.1002/essoar.10505545.4
# ...                            ...                                        ...
# 9330883      10.7554/elife.99997.3      https://doi.org/10.7554/elife.99997.3
# 9370551        10.7554/elife.99999        https://doi.org/10.7554/elife.99999
# 9351901      10.7554/elife.99999.1      https://doi.org/10.7554/elife.99999.1
# 9366338      10.7554/elife.99999.2      https://doi.org/10.7554/elife.99999.2
# 9370550      10.7554/elife.99999.3      https://doi.org/10.7554/elife.99999.3
#
#                                           landing_page_url  \
# 442472   https://essopenarchive.org/users/545221/articl...
# 442443   https://essopenarchive.org/users/574499/articl...
# 442692   https://essopenarchive.org/users/530351/articl...
# 442249   https://essopenarchive.org/users/544442/articl...
# 442462   https://essopenarchive.org/users/543175/articl...
# ...                                                    ...
# 9330883           https://elifesciences.org/articles/99997
# 9370551           https://elifesciences.org/articles/99999
# 9351901  https://elifesciences.org/reviewed-preprints/9...
# 9366338  https://elifesciences.org/reviewed-preprints/9...
# 9370550           https://elifesciences.org/articles/99999
#
#                                                      title  \
# 442472   Carbon Dioxide Removal Estimation Method to Re...
# 442443   A Bayesian model for quantifying errors in cit...
# 442692   Global oceanic iron distribution estimated by ...
# 442249   Soil profile stratigraphy detected by ground p...
# 442462   Internal vs Forced Variability Metrics for Geo...
# ...                                                    ...
# 9330883  Tripartite organization of brain state dynamic...
# 9370551  Glia-mediated gut–brain cytokine signaling cou...
# 9351901  Glia-mediated gut-brain cytokine signaling cou...
# 9366338  Glia-mediated gut-brain cytokine signaling cou...
# 9370550  Glia-mediated gut–brain cytokine signaling cou...
#
#                                               authors_flat publication_year  \
# 442472                                      Fiume, Shannon           2023.0
# 442443   Eisma, Jessica A; Schoups, Gerrit; Davids, Jef...           2023.0
# 442692   Doi, Toshimasa; Osafune, Satoshi; Masuda, Shuh...           2024.0
# 442249       Wang, Ping; Li, Xinju; Min, Xiangyu; Xu, Shuo           2023.0
# 442462     Sane, Aakash; Fox-Kemper, Baylor; Ullman, David           2023.0
# ...                                                    ...              ...
# 9330883  Liu, Lanfang; Jiang, Jiahao; Li, Hehui; Ding, ...           2025.0
# 9370551  Malita, Alina; Skakkebaek, Anne H; Kubrak, Olg...           2025.0
# 9351901  Malita, Alina; Kubrak, Olga; Chen, Xiaokang; K...           2024.0
# 9366338  Malita, Alina; Skakkebaek, Anne H; Kubrak, Olg...           2025.0
# 9370550  Malita, Alina; Skakkebaek, Anne H; Kubrak, Olg...           2025.0
#
#         date_created                                     relations_json  \
# 442472    2023-09-20  {"is-version-of": [{"asserted-by": "subject", ...
# 442443    2023-04-04  {"is-version-of": [{"asserted-by": "subject", ...
# 442692    2024-07-31  {"is-version-of": [{"asserted-by": "subject", ...
# 442249    2023-02-01  {"is-version-of": [{"asserted-by": "subject", ...
# 442462    2023-08-10  {"is-version-of": [{"asserted-by": "subject", ...
# ...              ...                                                ...
# 9330883   2025-01-21  {"has-preprint": [{"asserted-by": "subject", "...
# 9370551   2024-09-18  {"has-preprint": [{"asserted-by": "subject", "...
# 9351901   2024-09-18  {"is-version-of": [{"asserted-by": "subject", ...
# 9366338   2025-06-26  {"is-version-of": [{"asserted-by": "subject", ...
# 9370550   2025-09-09  {"has-preprint": [{"asserted-by": "subject", "...
#
#         version_label                                    is_version_of  \
# 442472           None                        10.1002/essoar.10503117.1
# 442443           None                        10.1002/essoar.10503623.1
# 442692           None                        10.1002/essoar.10503738.1
# 442249           None                        10.1002/essoar.10505190.1
# 442462           None                        10.1002/essoar.10505545.1
# ...               ...                                              ...
# 9330883          None      10.7554/elife.99997.1;10.7554/elife.99997.2
# 9370551          None      10.7554/elife.99999.1;10.7554/elife.99999.2
# 9351901          None                        10.1101/2024.06.25.600726
# 9366338          None  10.1101/2024.06.25.600726;10.7554/elife.99999.1
# 9370550          None      10.7554/elife.99999.1;10.7554/elife.99999.2
#
#         is_preprint_of               has_preprint has_review  \
# 442472
# 442443
# 442692
# 442249
# 442462
# ...                ...                        ...        ...
# 9330883                 10.1101/2024.06.13.598625
# 9370551                 10.1101/2024.06.25.600726
# 9351901
# 9366338
# 9370550                 10.1101/2024.06.25.600726
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 442472                  false                       None                None
# 442443                  false                       None                None
# 442692                  false                       None                None
# 442249                  false                       None                None
# 442462                  false                       None                None
# ...                       ...                        ...                 ...
# 9330883                 false                       None                None
# 9370551                 false                       None                None
# 9351901                 false                       None                None
# 9366338                 false                       None                None
# 9370550                 false                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy
# 442472            None                   None               NaN
# 442443            None                   None               NaN
# 442692            None                   None               NaN
# 442249            None                   None               NaN
# 442462            None                   None               NaN
# ...                ...                    ...               ...
# 9330883           None                   None               NaN
# 9370551           None                   None               NaN
# 9351901           None                   None               NaN
# 9366338           None                   None               NaN
# 9370550           None                   None               NaN
#
# [76713 rows x 22 columns]

# %%
result['server_name'].value_counts()
# Out:
# server_name
# Research Square                         15274
# eLife                                   14352
# Preprints.org                           13462
# ChemRxiv                                12927
# PsyArXiv                                 5525
# Qeios                                    4571
# Open Science Framework                   2288
# Authorea Inc.                            1931
# CrimRxiv                                 1516
# TechRxiv                                 1313
# SocArXiv                                 1021
# Cambridge Open Engage                     996
# Earth and Space Science Open Archive      809
# APSA Preprints                            367
# EdArXiv                                   131
# MetaArXiv                                  67
# Thesis Commons                             42
# Advance                                    42
# PaleorXiv                                  17
# EGUsphere                                  13
# Encyclopedia                               11
# LIS Scholarship Archive                    10
# MediArXiv                                   7
# ECSarXiv                                    3
# NewAddictionsX                              3
# Law Archive                                 3
# BioHackrXiv                                 3
# BodoArXiv                                   2
# MarXiv                                      2
# SciELO Preprints                            1
# CoP                                         1
# SportRxiv                                   1
# Prepublicaciones OpenCiencia                1
# LatArXiv                                    1
# Name: count, dtype: int64

# %%
df_version = df_version.copy()

# Normalize relations_json once
relations_norm = df_version["relations_json"].astype(str).str.lower()

# CHILD rules
child_mask = (
    # mask_remain &
    relations_norm.str.contains("is-version-of", na=False)
)
df_version.loc[child_mask, "records_hierarchy"] = "version"

print(df_version["records_hierarchy"].value_counts(dropna=False))
# Out:
# records_hierarchy
# NaN           8324572
# version         85167
# correction        355
# Name: count, dtype: int64

# %%
df_label = df_version[df_version['records_hierarchy'].notna()]
df_label['server_name'].value_counts()
# Out:
# server_name
# Research Square                         15274
# eLife                                   14706
# Preprints.org                           13462
# ChemRxiv                                12927
# F1000Research                            5651
# PsyArXiv                                 5525
# Qeios                                    4571
# Open Science Framework                   2288
# Authorea Inc.                            1931
# CrimRxiv                                 1516
# TechRxiv                                 1313
# Wellcome Open Research                   1299
# SocArXiv                                 1021
# Cambridge Open Engage                     996
# Earth and Space Science Open Archive      809
# Open Research Europe                      698
# APSA Preprints                            367
# HRB Open Research                         361
# Gates Open Research                       324
# EdArXiv                                   131
# Open Research Africa                      100
# MetaArXiv                                  67
# Advance                                    42
# Thesis Commons                             42
# PaleorXiv                                  17
# EGUsphere                                  13
# AMRC Open Research                         11
# Encyclopedia                               11
# LIS Scholarship Archive                    10
# MediArXiv                                   7
# MNI Open Research                           6
# Law Archive                                 3
# ECSarXiv                                    3
# BioHackrXiv                                 3
# NewAddictionsX                              3
# VeriXiv                                     2
# MarXiv                                      2
# Zenodo                                      2
# BodoArXiv                                   2
# SciELO Preprints                            1
# WikiJournal of Medicine                     1
# CoP                                         1
# SportRxiv                                   1
# Prepublicaciones OpenCiencia                1
# LatArXiv                                    1
# Name: count, dtype: int64

# %% [markdown]
# ### check those who are review

# %%
pattern = "is-review-of"

mask = df_version['relations_json'].str.contains(pattern, regex=False, na=False)
result = df_version[mask]
result
# Out:
#                                                  record_id  \
# 5643709  crossref::10.14293/p2199-8442.1.sop-geo.pnx1a0...
# 5640221  crossref::10.14293/p2199-8442.1.sop-life.pptzs...
# 5642452  crossref::10.14293/p2199-8442.1.sop-matsci.p6s...
# 5642292  crossref::10.14293/s2199-1006.1.sor-ag.a7cgne....
# 5640628  crossref::10.14293/s2199-1006.1.sor-ag.afqaon....
# ...                                                    ...
# 9366362                crossref::10.7554/elife.99999.2.sa1
# 9366367                crossref::10.7554/elife.99999.2.sa2
# 9370553                crossref::10.7554/elife.99999.3.sa0
# 9370552                crossref::10.7554/elife.99999.3.sa1
# 9370554                crossref::10.7554/elife.99999.3.sa2
#
#                    server_name   backend  \
# 5643709  ScienceOpen Preprints  crossref
# 5640221  ScienceOpen Preprints  crossref
# 5642452  ScienceOpen Preprints  crossref
# 5642292  ScienceOpen Preprints  crossref
# 5640628  ScienceOpen Preprints  crossref
# ...                        ...       ...
# 9366362                  eLife  crossref
# 9366367                  eLife  crossref
# 9370553                  eLife  crossref
# 9370552                  eLife  crossref
# 9370554                  eLife  crossref
#
# 9370554  Malita, Alina; Kubrak, Olga; Chen, Xiaokang; K...           2025.0
#
#         date_created                                     relations_json  \
# 5643709   2025-06-05  {"is-review-of": [{"asserted-by": "subject", "...
# 5640221   2021-08-10  {"is-review-of": [{"asserted-by": "subject", "...
# 5642452   2023-08-22  {"is-review-of": [{"asserted-by": "subject", "...
# 5642292   2023-06-06  {"is-review-of": [{"asserted-by": "subject", "...
# 5640628   2023-05-02  {"is-review-of": [{"asserted-by": "subject", "...
# ...              ...                                                ...
# 9366362   2025-06-26  {"is-review-of": [{"asserted-by": "subject", "...
# 9366367   2025-06-26  {"is-review-of": [{"asserted-by": "subject", "...
# 9370553   2025-09-09  {"is-review-of": [{"asserted-by": "subject", "...
# 9370552   2025-09-09  {"is-review-of": [{"asserted-by": "subject", "...
# 9370554   2025-09-09  {"is-review-of": [{"asserted-by": "subject", "...
#
#         version_label is_version_of is_preprint_of has_preprint has_review  \
# 5643709          None
# 5640221          None
# 5642452          None
# 5642292          None
# 5640628          None
# ...               ...           ...            ...          ...        ...
# 9366362          None
# 9366367          None
# 9370553          None
# 9370552          None
# 9370554          None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 5643709                 false                       None                None
# 5640221                 false                       None                None
# 5642452                 false                       None                None
# 5642292                 false                       None                None
# 5640628                 false                       None                None
# ...                       ...                        ...                 ...
# 9366362                 false                       None                None
# 9366367                 false                       None                None
# 9370553                 false                       None                None
# 9370552                 false                       None                None
# 9370554                 false                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy
# 5643709           None                   None               NaN
# 5640221           None                   None               NaN
# 5642452           None                   None               NaN
# 5642292           None                   None               NaN
# 5640628           None                   None               NaN
# ...                ...                    ...               ...
# 9366362           None                   None               NaN
# 9366367           None                   None               NaN
# 9370553           None                   None               NaN
# 9370552           None                   None               NaN
# 9370554           None                   None               NaN
#
# [175443 rows x 22 columns]

# %%
result['server_name'].value_counts()
# Out:
# server_name
# eLife                    73369
# Qeios                    55838
# EGUsphere                45433
# ScienceOpen Preprints      790
# UCL Open Environment         7
# CrimRxiv                     6
# Name: count, dtype: int64

# %%
df_version_review = df_version.copy()

# Normalize relations_json once
relations_norm = df_version_review["relations_json"].astype(str).str.lower()

# Review signals
review_mask = (
    # mask_remain &
    (
        # relations_norm.str.contains("has-review", na=False) |
        relations_norm.str.contains("is-review-of", na=False) 
    )
)

df_version_review.loc[review_mask, "records_hierarchy"] = "review"
print(df_version_review["records_hierarchy"].value_counts(dropna=False))
# Out:
# records_hierarchy
# NaN           8149129
# review         175443
# version         85167
# correction        355
# Name: count, dtype: int64

# %%
df_label = df_version_review[df_version_review['records_hierarchy'].notna()]
df_label['server_name'].value_counts()
# Out:
# server_name
# eLife                                   88075
# Qeios                                   60409
# EGUsphere                               45446
# Research Square                         15274
# Preprints.org                           13462
# ChemRxiv                                12927
# F1000Research                            5651
# PsyArXiv                                 5525
# Open Science Framework                   2288
# Authorea Inc.                            1931
# CrimRxiv                                 1522
# TechRxiv                                 1313
# Wellcome Open Research                   1299
# SocArXiv                                 1021
# Cambridge Open Engage                     996
# Earth and Space Science Open Archive      809
# ScienceOpen Preprints                     790
# Open Research Europe                      698
# APSA Preprints                            367
# HRB Open Research                         361
# Gates Open Research                       324
# EdArXiv                                   131
# Open Research Africa                      100
# MetaArXiv                                  67
# Advance                                    42
# Thesis Commons                             42
# PaleorXiv                                  17
# AMRC Open Research                         11
# Encyclopedia                               11
# LIS Scholarship Archive                    10
# UCL Open Environment                        7
# MediArXiv                                   7
# MNI Open Research                           6
# Law Archive                                 3
# ECSarXiv                                    3
# BioHackrXiv                                 3
# NewAddictionsX                              3
# VeriXiv                                     2
# MarXiv                                      2
# Zenodo                                      2
# BodoArXiv                                   2
# SciELO Preprints                            1
# WikiJournal of Medicine                     1
# CoP                                         1
# SportRxiv                                   1
# Prepublicaciones OpenCiencia                1
# LatArXiv                                    1
# Name: count, dtype: int64

# %% [markdown]
# ### use regular expression to extract version and others

# %%
import re
import numpy as np
import pandas as pd

df = df_version_review.copy()

# ------------------------------------------------------------
# 0) Ensure target column exists
# ------------------------------------------------------------

# normalize strings once (safe)
df["landing_norm"] = df.get("landing_page_url", "").astype(str).str.lower()
df["doi_norm"] = df.get("doi", "").astype(str).str.lower()

# ------------------------------------------------------------
# 1) Your regex (good: avoids /v284p and .v50i7)
# ------------------------------------------------------------
VERSION_RX = re.compile(
    r'(?P<token>('
    r'/v\d+(?![a-z0-9])|'       # /v1 but not /v284p
    r'\.v\d+(?![a-z0-9])|'      # .v1 but not .v50i7
    r'_v\d+(?![a-z0-9])|'       # _v1
    r'-v\d+(?![a-z0-9])|'       # -v2 but not -v8018x
    r'-rc\d+(?![a-z0-9])|'      # -rc1
    r'-cc\d+(?![a-z0-9])|'      # -cc1
    r'-supplement|'             # -supplement
    r'\.sa\d+(?![a-z0-9])'      # .sa10
    r'))',
    re.IGNORECASE
)

# helpers: classify token family + get numeric v
VNUM_RX = re.compile(r'(?:^|[._/\-])v(\d+)$', re.IGNORECASE)  # matches v1 at end of token
def extract_token(text: str):
    if not isinstance(text, str) or text.strip() == "" or text.lower() == "nan":
        return None
    m = VERSION_RX.search(text)
    return m.group("token") if m else None

def token_kind(token: str):
    if not isinstance(token, str):
        return None
    t = token.lower()
    if t.startswith(("/v", ".v", "_v", "-v")):
        return "explicit_version"
    if t.startswith("-rc"):
        return "rc"
    if t.startswith("-cc"):
        return "cc"
    if t == "-supplement":
        return "supplement"
    if t.startswith(".sa"):
        return "supplementary_asset"
    return "other"

def token_vnum(token: str):
    if not isinstance(token, str):
        return np.nan
    t = token.lower()
    # extract trailing v number for explicit version tokens only
    m = re.search(r'v(\d+)$', t)
    return float(m.group(1)) if m else np.nan

# ------------------------------------------------------------
# 2) Apply extraction: landing_page_url first, then doi
# ------------------------------------------------------------
remain = df["records_hierarchy"].fillna("other").eq("other")

# --- landing page tokens ---
df.loc[remain, "version_token_lp"] = df.loc[remain, "landing_norm"].map(extract_token)
df.loc[remain, "token_kind_lp"] = df.loc[remain, "version_token_lp"].map(token_kind)
df.loc[remain, "vnum_lp"] = df.loc[remain, "version_token_lp"].map(token_vnum)

# Label rules (landing_page_url)
# - Only use explicit vN tokens for parent/child
# - parent if v0 or v1, child if v>=2
lp_parent = remain & (df["token_kind_lp"] == "explicit_version") & (df["vnum_lp"].isin([0.0, 1.0]))
lp_child  = remain & (df["token_kind_lp"] == "explicit_version") & (df["vnum_lp"] >= 2)

df.loc[lp_parent, "records_hierarchy"] = "parent"
df.loc[lp_child,  "records_hierarchy"] = "version"

# Everything else from landing tokens (rc/cc/supplement/.sa) keep as other
# If you prefer to label them separately, do it here:
df.loc[remain & df["token_kind_lp"].isin(["rc","cc"]), "records_hierarchy"] = "comment"
df.loc[remain & df["token_kind_lp"].isin(["supplement","supplementary_asset"]), "records_hierarchy"] = "part_of"

# --- doi tokens (only for still-unlabeled) ---
remain2 = df["records_hierarchy"].fillna("other").eq("other")

df.loc[remain2, "version_token_doi"] = df.loc[remain2, "doi_norm"].map(extract_token)
df.loc[remain2, "token_kind_doi"] = df.loc[remain2, "version_token_doi"].map(token_kind)
df.loc[remain2, "vnum_doi"] = df.loc[remain2, "version_token_doi"].map(token_vnum)

doi_parent = remain2 & (df["token_kind_doi"] == "explicit_version") & (df["vnum_doi"].isin([0.0, 1.0]))
doi_child  = remain2 & (df["token_kind_doi"] == "explicit_version") & (df["vnum_doi"] >= 2)

df.loc[doi_parent, "records_hierarchy"] = "parent"
df.loc[doi_child,  "records_hierarchy"] = "version"

# ------------------------------------------------------------
# 3) Optional: quick diagnostics
# ------------------------------------------------------------
# How many got labeled via landing vs doi?
print(df["records_hierarchy"].value_counts(dropna=False))
# print(df.loc[df["records_hierarchy"].isin(["parent","child"]),
#              ["server_name","landing_page_url","doi","version_token_lp","version_token_doi","records_hierarchy"]].head(20))
# Out:
# records_hierarchy
# NaN           7324091
# parent         782740
# review         175443
# version        122862
# part_of          4583
# correction        355
# comment            20
# Name: count, dtype: int64

# %%
df_label = df[df['records_hierarchy'].notna()]
df_label['server_name'].value_counts()
# Out:
# server_name
# Research Square                                                         450818
# Preprints.org                                                           115815
# eLife                                                                    88075
# Open Science Framework                                                   80649
# Qeios                                                                    60414
#                                                                          ...
# WikiJournal of Medicine                                                      1
# CERN document server                                                         1
# Prepublicaciones OpenCiencia                                                 1
# Digital Access to Scholarship at Harvard (DASH) (Harvard University)         1
# National Bureau of Economic Research                                         1
# Name: count, Length: 79, dtype: int64

# %%
df = df.copy()

# Ensure column exists
# if "records_hierarchy" not in df.columns:
#     df["records_hierarchy"] = "other"

# Normalize relations_json once
relations_norm = df["landing_page_url"].astype(str).str.lower()

# Only touch rows not already parent/child
mask_remain = df["records_hierarchy"].isin(["other", None, np.nan])

# Part signals
part_mask = (
    mask_remain &
    (
        relations_norm.str.contains("#fig", na=False) |
        relations_norm.str.contains("#digest", na=False) |
        relations_norm.str.contains("#supp", na=False) |
        relations_norm.str.contains("#video", na=False) |
        relations_norm.str.contains("#media", na=False) |
        relations_norm.str.contains("#tbl", na=False) |
        relations_norm.str.contains("#table", na=False) |
        relations_norm.str.contains("#sd", na=False) |
        relations_norm.str.contains("#transrepform", na=False) |
        relations_norm.str.contains("/figures#", na=False) |
        relations_norm.str.contains("#box", na=False) |
        relations_norm.str.contains("#app", na=False) |
        relations_norm.str.contains("#resp", na=False) |
        relations_norm.str.contains("#a", na=False) |
        relations_norm.str.contains("#b", na=False) |
        relations_norm.str.contains("#c", na=False) |
        relations_norm.str.contains("#s", na=False) |
        relations_norm.str.contains("#atbl", na=False) |
        relations_norm.str.contains("#sa", na=False) |
        relations_norm.str.contains("#none", na=False) |
        relations_norm.str.contains("#desfig", na=False) |
        relations_norm.str.contains("#keyresource", na=False) |
        relations_norm.str.contains("#abstract", na=False) 
    )
)
df.loc[part_mask, "records_hierarchy"] = "part_of"
#
# Review signals
comment_mask = (
    mask_remain &
    (
        relations_norm.str.contains("#ac", na=False) |
        relations_norm.str.contains("#rc", na=False) |
        relations_norm.str.contains("#cc", na=False) |
        relations_norm.str.contains("#ec", na=False) |
        relations_norm.str.contains("/peer-reviews", na=False) |
        relations_norm.str.contains("#decision-letter", na=False) |
        relations_norm.str.contains("#cec", na=False) 
    )
)

df.loc[comment_mask, "records_hierarchy"] = "comment"


print(df["records_hierarchy"].value_counts(dropna=False))
# Out:
# records_hierarchy
# NaN           7178907
# parent         782740
# review         175443
# part_of        149462
# version        122862
# correction        355
# comment           325
# Name: count, dtype: int64

# %%
df_label = df[df['records_hierarchy'].notna()]
df_label['server_name'].value_counts()
# Out:
# server_name
# Research Square                                                         450818
# eLife                                                                   231745
# Preprints.org                                                           115815
# Open Science Framework                                                   80649
# Qeios                                                                    60414
#                                                                          ...
# WikiJournal of Science                                                       1
# CERN document server                                                         1
# Prepublicaciones OpenCiencia                                                 1
# Digital Access to Scholarship at Harvard (DASH) (Harvard University)         1
# National Bureau of Economic Research                                         1
# Name: count, Length: 81, dtype: int64

# %% [markdown]
# ### identify publish versions

# %%
pattern = "has-preprint"

mask = df['relations_json'].str.contains(pattern, regex=False, na=False)
result = df[mask]
result
# Out:
#                                    record_id  \
# 429693   crossref::10.1002/essoar.10502762.1
# 429702   crossref::10.1002/essoar.10503378.1
# 429703   crossref::10.1002/essoar.10503397.1
# 429708   crossref::10.1002/essoar.10503526.1
# 429713   crossref::10.1002/essoar.10503764.1
# ...                                      ...
# 9373415      crossref::10.7554/elife.99989.3
# 9330914        crossref::10.7554/elife.99997
# 9330883      crossref::10.7554/elife.99997.3
# 9370551        crossref::10.7554/elife.99999
# 9370550      crossref::10.7554/elife.99999.3
#
#                                   server_name   backend  \
# 429693   Earth and Space Science Open Archive  crossref
# 429702   Earth and Space Science Open Archive  crossref
# 429703   Earth and Space Science Open Archive  crossref
# 429708   Earth and Space Science Open Archive  crossref
# 429713   Earth and Space Science Open Archive  crossref
# ...                                       ...       ...
# 9373415                                 eLife  crossref
# 9330914                                 eLife  crossref
# 9330883                                 eLife  crossref
# 9370551                                 eLife  crossref
# 9370550                                 eLife  crossref
#
#                                doi                                    doi_url  \
# 429693   10.1002/essoar.10502762.1  https://doi.org/10.1002/essoar.10502762.1
# 429702   10.1002/essoar.10503378.1  https://doi.org/10.1002/essoar.10503378.1
# 429703   10.1002/essoar.10503397.1  https://doi.org/10.1002/essoar.10503397.1
# 429708   10.1002/essoar.10503526.1  https://doi.org/10.1002/essoar.10503526.1
# 429713   10.1002/essoar.10503764.1  https://doi.org/10.1002/essoar.10503764.1
# ...                            ...                                        ...
# 9373415      10.7554/elife.99989.3      https://doi.org/10.7554/elife.99989.3
# 9330914        10.7554/elife.99997        https://doi.org/10.7554/elife.99997
# 9330883      10.7554/elife.99997.3      https://doi.org/10.7554/elife.99997.3
# 9370551        10.7554/elife.99999        https://doi.org/10.7554/elife.99999
# 9370550      10.7554/elife.99999.3      https://doi.org/10.7554/elife.99999.3
#
#                                           landing_page_url  \
# 429693   https://essopenarchive.org/doi/full/10.1002/es...
# 429702   https://essopenarchive.org/doi/full/10.1002/es...
# 429703   https://essopenarchive.org/doi/full/10.1002/es...
# 429708   https://essopenarchive.org/doi/full/10.1002/es...
# 429713   https://essopenarchive.org/doi/full/10.1002/es...
# ...                                                    ...
# 9373415           https://elifesciences.org/articles/99989
# 9330914           https://elifesciences.org/articles/99997
# 9330883           https://elifesciences.org/articles/99997
# 9370551           https://elifesciences.org/articles/99999
# 9370550           https://elifesciences.org/articles/99999
#
#                                                      title  \
# 429693   Extant mat world analog microbes synchronize m...
# 429702   Adjoint Slip Inversion under a Constrained Opt...
# 429703   Restoring pre-industrial CO2 levels while achi...
# 429708   Determining the Isotopic Composition of Surfac...
# 429713   Observational evidence of interaction between ...
# ...                                                    ...
# 9373415  Tonotopy is not preserved in a descending stag...
# 9330914  Tripartite organization of brain state dynamic...
# 9330883  Tripartite organization of brain state dynamic...
# 9370551  Glia-mediated gut–brain cytokine signaling cou...
# 9370550  Glia-mediated gut–brain cytokine signaling cou...
#
#                                               authors_flat publication_year  \
# 429693              Biddanda, Bopaiah A; Weinke, Anthony D           2020.0
# 429702   Tago, Josué; Cruz-Atienza, Víctor M.; Villafue...           2020.0
# 429703   Capron, Mark E; Stewart, Jim R.; de Ramon N'Ye...           2020.0
# 429708   Hu, Yongbo; Xiao, Wei; Wei, Zhongwang; Welp, L...           2020.0
# 429713   Figueiredo, Cosme Alexandre O. B.; Wrasse, Cri...           2020.0
# ...                                                    ...              ...
# 9373415  Gu, Miaoqing; Liang, Shanshan; Zhu, Jiahui; Li...           2025.0
# 9330914  Liu, Lanfang; Jiang, Jiahao; Li, Hehui; Ding, ...           2025.0
# 9330883  Liu, Lanfang; Jiang, Jiahao; Li, Hehui; Ding, ...           2025.0
# 9370551  Malita, Alina; Skakkebaek, Anne H; Kubrak, Olg...           2025.0
# 9370550  Malita, Alina; Skakkebaek, Anne H; Kubrak, Olg...           2025.0
#
#         date_created                                     relations_json  \
# 429693    2020-04-28  {"has-preprint": [{"asserted-by": "subject", "...
# 429702    2020-06-18  {"has-preprint": [{"asserted-by": "subject", "...
# 429703    2020-06-18  {"has-preprint": [{"asserted-by": "subject", "...
# 429708    2020-07-05  {"has-preprint": [{"asserted-by": "subject", "...
# 429713    2020-07-30  {"has-preprint": [{"asserted-by": "subject", "...
# ...              ...                                                ...
# 9373415   2025-10-14  {"has-preprint": [{"asserted-by": "subject", "...
# 9330914   2024-10-08  {"has-preprint": [{"asserted-by": "subject", "...
# 9330883   2025-01-21  {"has-preprint": [{"asserted-by": "subject", "...
# 9370551   2024-09-18  {"has-preprint": [{"asserted-by": "subject", "...
# 9370550   2025-09-09  {"has-preprint": [{"asserted-by": "subject", "...
#
#         version_label                                is_version_of  \
# 429693           None
# 429702           None
# 429703           None
# 429708           None
# 429713           None
# ...               ...                                          ...
# 9373415          None  10.7554/elife.99989.1;10.7554/elife.99989.2
# 9330914          None  10.7554/elife.99997.1;10.7554/elife.99997.2
# 9330883          None  10.7554/elife.99997.1;10.7554/elife.99997.2
# 9370551          None  10.7554/elife.99999.1;10.7554/elife.99999.2
# 9370550          None  10.7554/elife.99999.1;10.7554/elife.99999.2
#
#                                          is_preprint_of  \
# 429693                        10.1002/essoar.10502762.1
# 429702    10.1002/essoar.10503378.1;10.1093/gji/ggab165
# 429703     10.1002/essoar.10503397.1;10.3390/en13184972
# 429708   10.1002/essoar.10503526.1;10.1029/2020ea001304
# 429713
# ...                                                 ...
# 9373415
# 9330914
# 9330883
# 9370551
# 9370550
#
#                       has_preprint has_review has_published_version  \
# 429693   10.1002/essoar.10502762.1                             true
# 429702   10.1002/essoar.10503378.1                             true
# 429703   10.1002/essoar.10503397.1                             true
# 429708   10.1002/essoar.10503526.1                             true
# 429713   10.1002/essoar.10503437.1                            false
# ...                            ...        ...                   ...
# 9373415  10.1101/2024.05.25.595883                            false
# 9330914  10.1101/2024.06.13.598625                            false
# 9330883  10.1101/2024.06.13.598625                            false
# 9370551  10.1101/2024.06.25.600726                            false
# 9370550  10.1101/2024.06.25.600726                            false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 429693                        None                None           None
# 429702                        None                None           None
# 429703                        None                None           None
# 429708                        None                None           None
# 429713                        None                None           None
# ...                            ...                 ...            ...
# 9373415                       None                None           None
# 9330914                       None                None           None
# 9330883                       None                None           None
# 9370551                       None                None           None
# 9370550                       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 429693                    None               NaN
# 429702                    None               NaN
# 429703                    None               NaN
# 429708                    None               NaN
# 429713                    None               NaN
# ...                        ...               ...
# 9373415                   None           version
# 9330914                   None           version
# 9330883                   None           version
# 9370551                   None           version
# 9370550                   None           version
#
#                                               landing_norm  \
# 429693   https://essopenarchive.org/doi/full/10.1002/es...
# 429702   https://essopenarchive.org/doi/full/10.1002/es...
# 429703   https://essopenarchive.org/doi/full/10.1002/es...
# 429708   https://essopenarchive.org/doi/full/10.1002/es...
# 429713   https://essopenarchive.org/doi/full/10.1002/es...
# ...                                                    ...
# 9373415           https://elifesciences.org/articles/99989
# 9330914           https://elifesciences.org/articles/99997
# 9330883           https://elifesciences.org/articles/99997
# 9370551           https://elifesciences.org/articles/99999
# 9370550           https://elifesciences.org/articles/99999
#
#                           doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 429693   10.1002/essoar.10502762.1             None          None      NaN
# 429702   10.1002/essoar.10503378.1             None          None      NaN
# 429703   10.1002/essoar.10503397.1             None          None      NaN
# 429708   10.1002/essoar.10503526.1             None          None      NaN
# 429713   10.1002/essoar.10503764.1             None          None      NaN
# ...                            ...              ...           ...      ...
# 9373415      10.7554/elife.99989.3              NaN           NaN      NaN
# 9330914        10.7554/elife.99997              NaN           NaN      NaN
# 9330883      10.7554/elife.99997.3              NaN           NaN      NaN
# 9370551        10.7554/elife.99999              NaN           NaN      NaN
# 9370550      10.7554/elife.99999.3              NaN           NaN      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 429693               None           None       NaN
# 429702               None           None       NaN
# 429703               None           None       NaN
# 429708               None           None       NaN
# 429713               None           None       NaN
# ...                   ...            ...       ...
# 9373415               NaN            NaN       NaN
# 9330914               NaN            NaN       NaN
# 9330883               NaN            NaN       NaN
# 9370551               NaN            NaN       NaN
# 9370550               NaN            NaN       NaN
#
# [9351 rows x 30 columns]

# %%
result['server_name'].value_counts()
# Out:
# server_name
# eLife                                   9294
# Earth and Space Science Open Archive      29
# Gates Open Research                       28
# Name: count, dtype: int64

# %%
df = df.copy()

# Normalize relations_json once
relations_norm = df["relations_json"].astype(str).str.lower()

# Review signals
review_mask = (
    (
        relations_norm.str.contains("has-preprint", na=False) 
    )
)

df.loc[review_mask, "records_hierarchy"] = "publish_version"
print(df["records_hierarchy"].value_counts(dropna=False))
# Out:
# records_hierarchy
# NaN                7175014
# parent              782712
# review              175443
# part_of             149462
# version             117432
# publish_version       9351
# correction             355
# comment                325
# Name: count, dtype: int64

# %%
df_label = df[df['records_hierarchy'].notna()]
df_label['server_name'].value_counts()
# Out:
# server_name
# Research Square                                                         450818
# eLife                                                                   235609
# Preprints.org                                                           115815
# Open Science Framework                                                   80649
# Qeios                                                                    60414
#                                                                          ...
# WikiJournal of Science                                                       1
# CERN document server                                                         1
# Prepublicaciones OpenCiencia                                                 1
# Digital Access to Scholarship at Harvard (DASH) (Harvard University)         1
# National Bureau of Economic Research                                         1
# Name: count, Length: 81, dtype: int64

# %% [markdown]
# #### remaining

# %%
df_remain = df[df['records_hierarchy'].isna()]
df_remain['server_name'].value_counts()
# Out:
# server_name
# arXiv                                  2920797
# SSRN                                   1258958
# HAL                                    1056216
# RePEc: Research Papers in Economics     388814
# bioRxiv                                 306948
#                                         ...
# searchRxiv                                   2
# Gates Open Research                          1
# MNI Open Research                            1
# Open Research Africa                         1
# AMRC Open Research                           1
# Name: count, Length: 103, dtype: int64

# %% [markdown]
# ### Label server who assingn unique doi for all version as parent

# %%
import pandas as pd
import numpy as np
import re

# ============================================================
# 1) Read the Google Sheet (rules tab) as CSV
#    - Works for public / shared-to-anyone sheets
# ============================================================

SHEET_ID = "10_7FdcpZjntqFsEHIii7bAM72uF__of_iUohSD5w8w4"
GID = "1230415212"  # the gid you shared for the 'rules' tab

rules_csv_url = f"https://docs.google.com/spreadsheets/d/{SHEET_ID}/export?format=csv&gid={GID}"
rules = pd.read_csv(rules_csv_url)

# Normalize column names (strip spaces/newlines)
rules.columns = (
    rules.columns.astype(str)
    .str.replace(r"\s+", " ", regex=True)  # collapse whitespace/newlines
    .str.strip()
)

# ============================================================
# 2) Extract servers where "versionning - doi" == "unique"
# ============================================================

# These are the column names seen in your screenshot:
SERVER_COL = "Field_server_name"
VERS_COL = "versionning - doi"  # after normalization it should match like this

# Safety: show close matches if something is off
if SERVER_COL not in rules.columns or VERS_COL not in rules.columns:
    print("Columns available:", rules.columns.tolist())
    raise KeyError(f"Expected columns not found. Need: {SERVER_COL!r} and {VERS_COL!r}")

# Build "unique versioning" server list
unique_servers = (
    rules.loc[
        rules[VERS_COL].astype(str).str.strip().str.lower().eq("unique"),
        SERVER_COL
    ]
    .dropna()
    .astype(str)
    .str.strip()
    .unique()
    .tolist()
)

print(f"Unique-versioning servers found: {len(unique_servers)}")
print(unique_servers[:30])  # preview

# ============================================================
# 3) Apply mapping to your dataframe df -> records_hierarchy = "parent"
# ============================================================

df = df.copy()

# Normalize server_name in df for matching
df["server_name_norm"] = df["server_name"].astype(str).str.strip()

# Normalize unique list too (strip)
unique_servers_norm = [s.strip() for s in unique_servers]

# Create / overwrite records_hierarchy
# Default: keep existing if present; else "other"
# df["records_hierarchy"] = df["records_hierarchy"] if "records_hierarchy" in df.columns else "other"

mask_unique = df["server_name_norm"].isin(unique_servers_norm)
# df.loc[mask_unique, "records_hierarchy"] = "parent"
# only fill missing values (uncomment instead of overwrite)
df.loc[mask_unique & df["records_hierarchy"].isna(), "records_hierarchy"] = "parent"

# Optional: drop helper col
df.drop(columns=["server_name_norm"], inplace=True)

# Quick check
print(df["records_hierarchy"].value_counts(dropna=False).head(10))
# print(df.loc[df["server_name"].isin(unique_servers_norm), ["server_name","records_hierarchy"]].drop_duplicates().head(20))
# Out:
# Unique-versioning servers found: 60
# ['arXiv', 'HAL', 'SSRN', 'RePEc: Research Papers in Economics', 'bioRxiv', 'Zenodo', 'medRxiv', 'Munich Personal RePEc Archive', 'JMIR Preprints', 'AgEcon Search', 'viXra', 'IACR Cryptology ePrint Archive', 'Qeios', 'Nature Precedings', 'SciELO Preprints', 'EcoEvoRxiv', 'National Bureau of Economic Research', 'PREPRINTS.RU', 'ARPHA Preprints', 'SportRxiv', 'Covid-19 Preprints', 'DSpace@MIT', 'Organic Eprints', 'Digital Access to Scholarship at Harvard (DASH) (Harvard University)', 'PhilSci-Archive', 'prepare@u', 'UCL Open Environment', 'EnerarXiv', 'AIJR Preprints', 'IndiaRxiv']
# records_hierarchy
# parent             7841901
# review              175443
# part_of             149462
# version             117432
# NaN                 115825
# publish_version       9351
# correction             355
# comment                325
# Name: count, dtype: int64

# %% [markdown]
# #### remaining

# %%
df_remain = df[df['records_hierarchy'].isna()]
df_remain['server_name'].value_counts()
# Out:
# server_name
# ChemRxiv                                26513
# Earth and Space Science Open Archive    13089
# eLife                                   11949
# EGUsphere                               10209
# TechRxiv                                 8320
# PsyArXiv                                 6632
# PeerJ Preprints                          6446
# EarthArXiv                               6425
# Authorea Inc.                            6092
# engrXiv                                  4925
# SocArXiv                                 3072
# INA-Rxiv                                 2830
# Cambridge Open Engage                    2089
# Advance                                  1717
# Thesis Commons                           1507
# APSA Preprints                           1101
# AgriRxiv                                  787
# EdArXiv                                   550
# Law Archive                               287
# Arabixiv                                  209
# MetaArXiv                                 196
# ScienceOpen Preprints                     151
# LIS Scholarship Archive                    85
# PoolText                                   79
# Oroboros Instruments                       70
# BioHackrXiv                                65
# MindRxiv                                   62
# MarXiv                                     54
# PaleorXiv                                  51
# AfricArXiv                                 41
# Frenxiv                                    39
# ECSarXiv                                   39
# MediArXiv                                  37
# BodoArXiv                                  34
# NutriXiv                                   28
# FocUS Archive                              16
# F1000Research                              14
# CoP                                         9
# NewAddictionsX                              2
# Gates Open Research                         1
# AMRC Open Research                          1
# MNI Open Research                           1
# Open Research Africa                        1
# Name: count, dtype: int64

# %% [markdown]
# ### manage server-by-server

# %% [markdown]
# #### eLife

# %%
df_remain[df_remain['server_name']=='eLife']
# Out:
#                              record_id server_name   backend  \
# 9130897        crossref::10.7554/elife       eLife  crossref
# 9274104  crossref::10.7554/elife.00003       eLife  crossref
# 9274103  crossref::10.7554/elife.00005       eLife  crossref
# 9274102  crossref::10.7554/elife.00007       eLife  crossref
# 9274105  crossref::10.7554/elife.00011       eLife  crossref
# ...                                ...         ...       ...
# 9324934  crossref::10.7554/elife.99560       eLife  crossref
# 9325271  crossref::10.7554/elife.99765       eLife  crossref
# 9327321  crossref::10.7554/elife.99770       eLife  crossref
# 9326155  crossref::10.7554/elife.99804       eLife  crossref
# 9325514  crossref::10.7554/elife.99991       eLife  crossref
#
#                          doi                              doi_url  \
# 9130897        10.7554/elife        https://doi.org/10.7554/elife
# 9274104  10.7554/elife.00003  https://doi.org/10.7554/elife.00003
# 9274103  10.7554/elife.00005  https://doi.org/10.7554/elife.00005
# 9274102  10.7554/elife.00007  https://doi.org/10.7554/elife.00007
# 9274105  10.7554/elife.00011  https://doi.org/10.7554/elife.00011
# ...                      ...                                  ...
# 9324934  10.7554/elife.99560  https://doi.org/10.7554/elife.99560
# 9325271  10.7554/elife.99765  https://doi.org/10.7554/elife.99765
# 9327321  10.7554/elife.99770  https://doi.org/10.7554/elife.99770
# 9326155  10.7554/elife.99804  https://doi.org/10.7554/elife.99804
# 9325514  10.7554/elife.99991  https://doi.org/10.7554/elife.99991
#
#                                  landing_page_url  \
# 9130897                https://elifesciences.org/
# 9274104  https://elifesciences.org/articles/00003
# 9274103  https://elifesciences.org/articles/00005
# 9274102  https://elifesciences.org/articles/00007
# 9274105  https://elifesciences.org/articles/00011
# ...                                           ...
# 9324934  https://elifesciences.org/articles/99560
# 9325271  https://elifesciences.org/articles/99765
# 9327321  https://elifesciences.org/articles/99770
# 9326155  https://elifesciences.org/articles/99804
# 9325514  https://elifesciences.org/articles/99991
#
#                                                      title  \
# 9130897                                              eLife
# 9274104  A novel role for lipid droplets in the organis...
# 9274103  Molecular architecture of human polycomb repre...
# 9274102  Herbivory-induced volatiles function as defens...
# 9274105  Nascent-Seq reveals novel features of mouse ci...
# ...                                                    ...
# 9324934                                   Paying attention
# 9325271                                Redox takes control
# 9327321  Exploring protein structural ensembles: Integr...
# 9326155                         Mapping the fly nerve cord
# 9325514                      How mutations affect function
#
#                                               authors_flat publication_year  \
# 9130897                                               <NA>             None
# 9274104  Anand, Preetha; Cermelli, Silvia; Li, Zhihuan;...           2012.0
# 9274103  Ciferri, Claudio; Lander, Gabriel C; Maiolica,...           2012.0
# 9274102  Schuman, Meredith C; Barthel, Kathleen; Baldwi...           2012.0
# 9274105  Menet, Jerome S; Rodriguez, Joseph; Abruzzi, K...           2012.0
# ...                                                    ...              ...
# 9324934                                  Poth, Christian H           2024.0
# 9325271                                Plaza-Menacho, Iván           2024.0
# 9327321                  Belyaeva, Julia; Elgeti, Matthias           2024.0
# 9326155                 Seggewisse, Anna; Winding, Michael           2024.0
# 9325514                                    Kuhlman, Thomas           2024.0
#
#         date_created                                     relations_json  \
# 9130897   2017-07-25                                               None
# 9274104   2012-11-13                                               None
# 9274103   2012-10-30                                               None
# 9274102   2012-10-15  {"is-supplemented-by": [{"asserted-by": "subje...
# 9274105   2012-11-13  {"is-supplemented-by": [{"asserted-by": "subje...
# ...              ...                                                ...
# 9324934   2024-06-10                                               None
# 9325271   2024-06-20                                               None
# 9327321   2024-09-16                                               None
# 9326155   2024-07-09                                               None
# 9325514   2024-06-28                                               None
#
#         version_label is_version_of is_preprint_of has_preprint has_review  \
# 9130897          None
# 9274104          None
# 9274103          None
# 9274102          None
# 9274105          None
# ...               ...           ...            ...          ...        ...
# 9324934          None
# 9325271          None
# 9327321          None
# 9326155          None
# 9325514          None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 9130897                 false                       None                None
# 9274104                 false                       None                None
# 9274103                 false                       None                None
# 9274102                 false                       None                None
# 9274105                 false                       None                None
# ...                       ...                        ...                 ...
# 9324934                 false                       None                None
# 9325271                 false                       None                None
# 9327321                 false                       None                None
# 9326155                 false                       None                None
# 9325514                 false                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 9130897           None                   None               NaN
# 9274104           None                   None               NaN
# 9274103           None                   None               NaN
# 9274102           None                   None               NaN
# 9274105           None                   None               NaN
# ...                ...                    ...               ...
# 9324934           None                   None               NaN
# 9325271           None                   None               NaN
# 9327321           None                   None               NaN
# 9326155           None                   None               NaN
# 9325514           None                   None               NaN
#
#                                      landing_norm             doi_norm  \
# 9130897                https://elifesciences.org/        10.7554/elife
# 9274104  https://elifesciences.org/articles/00003  10.7554/elife.00003
# 9274103  https://elifesciences.org/articles/00005  10.7554/elife.00005
# 9274102  https://elifesciences.org/articles/00007  10.7554/elife.00007
# 9274105  https://elifesciences.org/articles/00011  10.7554/elife.00011
# ...                                           ...                  ...
# 9324934  https://elifesciences.org/articles/99560  10.7554/elife.99560
# 9325271  https://elifesciences.org/articles/99765  10.7554/elife.99765
# 9327321  https://elifesciences.org/articles/99770  10.7554/elife.99770
# 9326155  https://elifesciences.org/articles/99804  10.7554/elife.99804
# 9325514  https://elifesciences.org/articles/99991  10.7554/elife.99991
#
#         version_token_lp token_kind_lp  vnum_lp version_token_doi  \
# 9130897             None          None      NaN              None
# 9274104             None          None      NaN              None
# 9274103             None          None      NaN              None
# 9274102             None          None      NaN              None
# 9274105             None          None      NaN              None
# ...                  ...           ...      ...               ...
# 9324934             None          None      NaN              None
# 9325271             None          None      NaN              None
# 9327321             None          None      NaN              None
# 9326155             None          None      NaN              None
# 9325514             None          None      NaN              None
#
#         token_kind_doi  vnum_doi
# 9130897           None       NaN
# 9274104           None       NaN
# 9274103           None       NaN
# 9274102           None       NaN
# 9274105           None       NaN
# ...                ...       ...
# 9324934           None       NaN
# 9325271           None       NaN
# 9327321           None       NaN
# 9326155           None       NaN
# 9325514           None       NaN
#
# [11949 rows x 30 columns]

# %%
pattern = "10.7554/elife.12523"

mask = df['doi'].str.contains(pattern, regex=False, na=False)
result = df[mask]
result
# Out:
#                                  record_id server_name   backend  \
# 9287585      crossref::10.7554/elife.12523       eLife  crossref
# 9130880  crossref::10.7554/elife.12523.001       eLife  crossref
#
#                              doi                                  doi_url  \
# 9287585      10.7554/elife.12523      https://doi.org/10.7554/elife.12523
# 9130880  10.7554/elife.12523.001  https://doi.org/10.7554/elife.12523.001
#
#                                           landing_page_url  \
# 9287585           https://elifesciences.org/articles/12523
# 9130880  http://elifesciences.org/lookup/doi/10.7554/eL...
#
#                                                      title  \
# 9287585                                  Hold your breath!
# 9130880  Figure 1. The reactive oxygen species (ROS) th...
#
#                                 authors_flat publication_year date_created  \
# 9287585  Lust, Katharina; Wittbrodt, Joachim           2015.0   2015-12-11
# 9130880                                 <NA>             None   2015-12-11
#
#         relations_json version_label is_version_of is_preprint_of  \
# 9287585           None          None
# 9130880           None          None
#
#         has_preprint has_review has_published_version  \
# 9287585                                         false
# 9130880                                         false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 9287585                       None                None           None
# 9130880                       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 9287585                   None               NaN
# 9130880                   None               NaN
#
#                                               landing_norm  \
# 9287585           https://elifesciences.org/articles/12523
# 9130880  http://elifesciences.org/lookup/doi/10.7554/el...
#
#                         doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 9287585      10.7554/elife.12523             None          None      NaN
# 9130880  10.7554/elife.12523.001             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 9287585              None           None       NaN
# 9130880              None           None       NaN

# %%
pattern = "10.7554/elife.100000"

mask = df['doi'].str.contains(pattern, regex=False, na=False)
result = df[mask]
result
# Out:
#                                     record_id server_name   backend  \
# 9366162        crossref::10.7554/elife.100000       eLife  crossref
# 9352818      crossref::10.7554/elife.100000.1       eLife  crossref
# 9353978  crossref::10.7554/elife.100000.1.sa0       eLife  crossref
# 9353967  crossref::10.7554/elife.100000.1.sa1       eLife  crossref
# 9353972  crossref::10.7554/elife.100000.1.sa2       eLife  crossref
# 9353963  crossref::10.7554/elife.100000.1.sa3       eLife  crossref
# 9360443      crossref::10.7554/elife.100000.2       eLife  crossref
# 9361880  crossref::10.7554/elife.100000.2.sa0       eLife  crossref
# 9361870  crossref::10.7554/elife.100000.2.sa1       eLife  crossref
# 9361866  crossref::10.7554/elife.100000.2.sa2       eLife  crossref
# 9364549      crossref::10.7554/elife.100000.3       eLife  crossref
# 9364573  crossref::10.7554/elife.100000.3.sa0       eLife  crossref
# 9364572  crossref::10.7554/elife.100000.3.sa1       eLife  crossref
# 9364571  crossref::10.7554/elife.100000.3.sa2       eLife  crossref
# 9366131      crossref::10.7554/elife.100000.4       eLife  crossref
# 9366187  crossref::10.7554/elife.100000.4.sa0       eLife  crossref
# 9366186  crossref::10.7554/elife.100000.4.sa1       eLife  crossref
# 9366188  crossref::10.7554/elife.100000.4.sa2       eLife  crossref
#
#                                 doi  \
# 9366162        10.7554/elife.100000
# 9352818      10.7554/elife.100000.1
# 9360443  Group identification drives brain integration ...
# 9361880  Author response: Group identification drives b...
# 9361870  Reviewer #1 (Public review): Group identificat...
# 9361866  eLife Assessment: Group identification drives ...
# 9364549  Group identification drives brain integration ...
# 9364573  Author response: Group identification drives b...
# 9364572  Reviewer #1 (Public review): Group identificat...
# 9364571  eLife Assessment: Group identification drives ...
# 9366131  Group identification drives brain integration ...
# 9366187  eLife Assessment: Group identification drives ...
# 9366186  Reviewer #1 (Public review): Group identificat...
# 9366188  Author response: Group identification drives b...
#
#                                              authors_flat publication_year  \
# 9366162  Xie, Enhui; Zha, Shuyi; Xu, Yiyang; Li, Xianchun           2025.0
# 9352818  Xie, Enhui; Zha, Shuyi; Xu, Yiyang; Li, Xianchun           2024.0
# 9353978  Xie, Enhui; Zha, Shuyi; Xu, Yiyang; Li, Xianchun           2024.0
# 9353967                                              <NA>           2024.0
# 9353972                                              <NA>           2024.0
# 9353963                                     Fornito, Alex           2024.0
# 9360443  Xie, Enhui; Zha, Shuyi; Xu, Yiyang; Li, Xianchun           2025.0
# 9361880  Xie, Enhui; Zha, Shuyi; Xu, Yiyang; Li, Xianchun           2025.0
# 9361870                                              <NA>           2025.0
# 9361866                                     Fornito, Alex           2025.0
# 9364549  Xie, Enhui; Zha, Shuyi; Xu, Yiyang; Li, Xianchun           2025.0
# 9364573  Xie, Enhui; Zha, Shuyi; Xu, Yiyang; Li, Xianchun           2025.0
# 9364572                                              <NA>           2025.0
# 9364571                                     Fornito, Alex           2025.0
# 9366131  Xie, Enhui; Zha, Shuyi; Xu, Yiyang; Li, Xianchun           2025.0
# 9366187                                     Fornito, Alex           2025.0
# 9366186                                              <NA>           2025.0
# 9366188  Xie, Enhui; Zha, Shuyi; Xu, Yiyang; Li, Xianchun           2025.0
#
#         date_created                                     relations_json  \
# 9366162   2024-10-14  {"has-preprint": [{"asserted-by": "subject", "...
# 9352818   2024-10-14  {"is-version-of": [{"asserted-by": "subject", ...
# 9353978   2024-10-14  {"is-review-of": [{"asserted-by": "subject", "...
# 9353967   2024-10-14  {"is-review-of": [{"asserted-by": "subject", "...
# 9353972   2024-10-14  {"is-review-of": [{"asserted-by": "subject", "...
# 9353963   2024-10-14  {"is-review-of": [{"asserted-by": "subject", "...
# 9360443   2025-04-01  {"is-version-of": [{"asserted-by": "subject", ...
# 9361880   2025-04-02  {"is-review-of": [{"asserted-by": "subject", "...
# 9361870   2025-04-02  {"is-review-of": [{"asserted-by": "subject", "...
# 9361866   2025-04-02  {"is-review-of": [{"asserted-by": "subject", "...
# 9364549   2025-06-04  {"is-version-of": [{"asserted-by": "subject", ...
# 9364573   2025-06-04  {"is-review-of": [{"asserted-by": "subject", "...
# 9364572   2025-06-04  {"is-review-of": [{"asserted-by": "subject", "...
# 9364571   2025-06-04  {"is-review-of": [{"asserted-by": "subject", "...
# 9366131   2025-06-24  {"has-preprint": [{"asserted-by": "subject", "...
# 9366187   2025-06-24  {"is-review-of": [{"asserted-by": "subject", "...
# 9366186   2025-06-24  {"is-review-of": [{"asserted-by": "subject", "...
# 9366188   2025-06-24  {"is-review-of": [{"asserted-by": "subject", "...
#
#         version_label                                      is_version_of  \
# 9366162          None  10.7554/elife.100000.1;10.7554/elife.100000.2;...
# 9352818          None                          10.1101/2024.06.03.597223
# 9353978          None
# 9353967          None
# 9353972          None
# 9353963          None
# 9360443          None   10.1101/2024.06.03.597223;10.7554/elife.100000.1
# 9361880          None
# 9361870          None
# 9361866          None
# 9364549          None  10.1101/2024.06.03.597223;10.7554/elife.100000...
# 9364573          None
# 9364572          None
# 9364571          None
# 9366131          None  10.7554/elife.100000.1;10.7554/elife.100000.2;...
# 9366187          None
# 9366186          None
# 9366188          None
#
#         is_preprint_of               has_preprint has_review  \
# 9366162                 10.1101/2024.06.03.597223
# 9352818
# 9353978
# 9353967
# 9353972
# 9353963
# 9360443
# 9361880
# 9361870
# 9361866
# 9364549
# 9364573
# 9364572
# 9364571
# 9366131                 10.1101/2024.06.03.597223
# 9366187
# 9366186
# 9366188
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 9366162                 false                       None                None
# 9352818                 false                       None                None
# 9353978                 false                       None                None
# 9353967                 false                       None                None
# 9353972                 false                       None                None
# 9353963                 false                       None                None
# 9360443                 false                       None                None
# 9361880                 false                       None                None
# 9361870                 false                       None                None
# 9361866                 false                       None                None
# 9364549                 false                       None                None
# 9364573                 false                       None                None
# 9364572                 false                       None                None
# 9364571                 false                       None                None
# 9366131                 false                       None                None
# 9366187                 false                       None                None
# 9366186                 false                       None                None
# 9366188                 false                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 9366162           None                   None   publish_version
# 9352818           None                   None           version
# 9353978           None                   None            review
# 9353967           None                   None            review
# 9353972           None                   None            review
# 9353963           None                   None            review
# 9360443           None                   None           version
# 9361880           None                   None            review
# 9361870           None                   None            review
# 9361866           None                   None            review
# 9364549           None                   None           version
# 9364573           None                   None            review
# 9364572           None                   None            review
# 9364571           None                   None            review
# 9366131           None                   None   publish_version
# 9366187           None                   None            review
# 9366186           None                   None            review
# 9366188           None                   None            review
#
#                                               landing_norm  \
# 9366162          https://elifesciences.org/articles/100000
# 9352818  https://elifesciences.org/reviewed-preprints/1...
# 9353978  https://elifesciences.org/reviewed-preprints/1...
# 9353967  https://elifesciences.org/reviewed-preprints/1...
# 9353972  https://elifesciences.org/reviewed-preprints/1...
# 9353963  https://elifesciences.org/reviewed-preprints/1...
# 9360443  https://elifesciences.org/reviewed-preprints/1...
# 9361880  https://elifesciences.org/reviewed-preprints/1...
# 9361870  https://elifesciences.org/reviewed-preprints/1...
# 9361866  https://elifesciences.org/reviewed-preprints/1...
# 9364549  https://elifesciences.org/reviewed-preprints/1...
# 9364573  https://elifesciences.org/reviewed-preprints/1...
# 9364572  https://elifesciences.org/reviewed-preprints/1...
# 9364571  https://elifesciences.org/reviewed-preprints/1...
# 9366131          https://elifesciences.org/articles/100000
# 9366187        https://elifesciences.org/articles/100000v1
# 9366186  https://elifesciences.org/articles/100000v1/pe...
# 9366188  https://elifesciences.org/articles/100000v1/pe...
#
#                            doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 9366162        10.7554/elife.100000              NaN           NaN      NaN
# 9352818      10.7554/elife.100000.1              NaN           NaN      NaN
# 9353978  10.7554/elife.100000.1.sa0              NaN           NaN      NaN
# 9353967  10.7554/elife.100000.1.sa1              NaN           NaN      NaN
# 9353972  10.7554/elife.100000.1.sa2              NaN           NaN      NaN
# 9353963  10.7554/elife.100000.1.sa3              NaN           NaN      NaN
# 9360443      10.7554/elife.100000.2              NaN           NaN      NaN
# 9361880  10.7554/elife.100000.2.sa0              NaN           NaN      NaN
# 9361870  10.7554/elife.100000.2.sa1              NaN           NaN      NaN
# 9361866  10.7554/elife.100000.2.sa2              NaN           NaN      NaN
# 9364549      10.7554/elife.100000.3              NaN           NaN      NaN
# 9364573  10.7554/elife.100000.3.sa0              NaN           NaN      NaN
# 9364572  10.7554/elife.100000.3.sa1              NaN           NaN      NaN
# 9364571  10.7554/elife.100000.3.sa2              NaN           NaN      NaN
# 9366131      10.7554/elife.100000.4              NaN           NaN      NaN
# 9366187  10.7554/elife.100000.4.sa0              NaN           NaN      NaN
# 9366186  10.7554/elife.100000.4.sa1              NaN           NaN      NaN
# 9366188  10.7554/elife.100000.4.sa2              NaN           NaN      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 9366162               NaN            NaN       NaN
# 9352818               NaN            NaN       NaN
# 9353978               NaN            NaN       NaN
# 9353967               NaN            NaN       NaN
# 9353972               NaN            NaN       NaN
# 9353963               NaN            NaN       NaN
# 9360443               NaN            NaN       NaN
# 9361880               NaN            NaN       NaN
# 9361870               NaN            NaN       NaN
# 9361866               NaN            NaN       NaN
# 9364549               NaN            NaN       NaN
# 9364573               NaN            NaN       NaN
# 9364572               NaN            NaN       NaN
# 9364571               NaN            NaN       NaN
# 9366131               NaN            NaN       NaN
# 9366187               NaN            NaN       NaN
# 9366186               NaN            NaN       NaN
# 9366188               NaN            NaN       NaN

# %%
pattern = ".1"

mask = df[df['server_name']=='eLife']['doi'].str.contains(pattern, regex=False, na=False)
result = df[df['server_name']=='eLife'][mask]
result
# Out:
#                                     record_id server_name   backend  \
# 9366162        crossref::10.7554/elife.100000       eLife  crossref
# 9352818      crossref::10.7554/elife.100000.1       eLife  crossref
# 9353978  crossref::10.7554/elife.100000.1.sa0       eLife  crossref
# 9353967  crossref::10.7554/elife.100000.1.sa1       eLife  crossref
# 9353972  crossref::10.7554/elife.100000.1.sa2       eLife  crossref
# ...                                       ...         ...       ...
# 9353740   crossref::10.7554/elife.99997.1.sa2       eLife  crossref
# 9353736   crossref::10.7554/elife.99997.1.sa3       eLife  crossref
# 9351901       crossref::10.7554/elife.99999.1       eLife  crossref
# 9352368   crossref::10.7554/elife.99999.1.sa0       eLife  crossref
# 9352357   crossref::10.7554/elife.99999.1.sa1       eLife  crossref
#
#                                 doi  \
# 9366162        10.7554/elife.100000
# 9352818      10.7554/elife.100000.1
# 9353978  10.7554/elife.100000.1.sa0
# 9353967  10.7554/elife.100000.1.sa1
# 9353972  10.7554/elife.100000.1.sa2
# ...                             ...
# 9353740   10.7554/elife.99997.1.sa2
# 9353736   10.7554/elife.99997.1.sa3
# 9351901       10.7554/elife.99999.1
# 9352368   10.7554/elife.99999.1.sa0
# 9352357   10.7554/elife.99999.1.sa1
#
#                                             doi_url  \
# 9366162        https://doi.org/10.7554/elife.100000
# 9352818      https://doi.org/10.7554/elife.100000.1
# 9353978  https://doi.org/10.7554/elife.100000.1.sa0
# 9353967  https://doi.org/10.7554/elife.100000.1.sa1
# 9353972  https://doi.org/10.7554/elife.100000.1.sa2
# ...                                             ...
# 9353740   https://doi.org/10.7554/elife.99997.1.sa2
# 9353736   https://doi.org/10.7554/elife.99997.1.sa3
# 9351901       https://doi.org/10.7554/elife.99999.1
# 9352368   https://doi.org/10.7554/elife.99999.1.sa0
# 9352357   https://doi.org/10.7554/elife.99999.1.sa1
#
#                                           landing_page_url  \
# 9366162          https://elifesciences.org/articles/100000
# 9352818  https://elifesciences.org/reviewed-preprints/1...
# 9353978  https://elifesciences.org/reviewed-preprints/1...
# 9353967  https://elifesciences.org/reviewed-preprints/1...
# 9353972  https://elifesciences.org/reviewed-preprints/1...
# ...                                                    ...
# 9353740  https://elifesciences.org/reviewed-preprints/9...
# 9353736  https://elifesciences.org/reviewed-preprints/9...
# 9351901  https://elifesciences.org/reviewed-preprints/9...
# 9352368  https://elifesciences.org/reviewed-preprints/9...
# 9352357  https://elifesciences.org/reviewed-preprints/9...
#
#                                                      title  \
# 9366162  Group identification drives brain integration ...
# 9352818  Group identification drives brain integration ...
# 9353978  Author response: Group identification drives b...
# 9353967  Reviewer #2 (Public review): Group identificat...
# 9353972  Reviewer #1 (Public review): Group identificat...
# ...                                                    ...
# 9353740  Reviewer #1 (Public review): Tripartite organi...
# 9353736  eLife Assessment: Tripartite organization of b...
# 9351901  Glia-mediated gut-brain cytokine signaling cou...
# 9352368  Joint Public Review: Glia-mediated gut-brain c...
# 9352357  eLife Assessment: Glia-mediated gut-brain cyto...
#
#                                               authors_flat publication_year  \
# 9366162   Xie, Enhui; Zha, Shuyi; Xu, Yiyang; Li, Xianchun           2025.0
# 9352818   Xie, Enhui; Zha, Shuyi; Xu, Yiyang; Li, Xianchun           2024.0
# 9353978   Xie, Enhui; Zha, Shuyi; Xu, Yiyang; Li, Xianchun           2024.0
# 9353967                                               <NA>           2024.0
# 9353972                                               <NA>           2024.0
# ...                                                    ...              ...
# 9353740                                               <NA>           2024.0
# 9353736                                   Martin, Andrea E           2024.0
# 9351901  Malita, Alina; Kubrak, Olga; Chen, Xiaokang; K...           2024.0
# 9352368                                               <NA>           2024.0
# 9352357                                         Ewer, John           2024.0
#
#         date_created                                     relations_json  \
# 9366162   2024-10-14  {"has-preprint": [{"asserted-by": "subject", "...
# 9352818   2024-10-14  {"is-version-of": [{"asserted-by": "subject", ...
# 9353978   2024-10-14  {"is-review-of": [{"asserted-by": "subject", "...
# 9353967   2024-10-14  {"is-review-of": [{"asserted-by": "subject", "...
# 9353972   2024-10-14  {"is-review-of": [{"asserted-by": "subject", "...
# ...              ...                                                ...
# 9353740   2024-10-08  {"is-review-of": [{"asserted-by": "subject", "...
# 9353736   2024-10-08  {"is-review-of": [{"asserted-by": "subject", "...
# 9351901   2024-09-18  {"is-version-of": [{"asserted-by": "subject", ...
# 9352368   2024-09-18  {"is-review-of": [{"asserted-by": "subject", "...
# 9352357   2024-09-18  {"is-review-of": [{"asserted-by": "subject", "...
#
#         version_label                                      is_version_of  \
# 9366162          None  10.7554/elife.100000.1;10.7554/elife.100000.2;...
# 9352818          None                          10.1101/2024.06.03.597223
# 9353978          None
# 9353967          None
# 9353972          None
# ...               ...                                                ...
# 9353740          None
# 9353736          None
# 9351901          None                          10.1101/2024.06.25.600726
# 9352368          None
# 9352357          None
#
#         is_preprint_of               has_preprint has_review  \
# 9366162                 10.1101/2024.06.03.597223
# 9352818
# 9353978
# 9353967
# 9353972
# ...                ...                        ...        ...
# 9353740
# 9353736
# 9351901
# 9352368
# 9352357
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 9366162                 false                       None                None
# 9352818                 false                       None                None
# 9353978                 false                       None                None
# 9353967                 false                       None                None
# 9353972                 false                       None                None
# ...                       ...                        ...                 ...
# 9353740                 false                       None                None
# 9353736                 false                       None                None
# 9351901                 false                       None                None
# 9352368                 false                       None                None
# 9352357                 false                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 9366162           None                   None   publish_version
# 9352818           None                   None           version
# 9353978           None                   None            review
# 9353967           None                   None            review
# 9353972           None                   None            review
# ...                ...                    ...               ...
# 9353740           None                   None            review
# 9353736           None                   None            review
# 9351901           None                   None           version
# 9352368           None                   None            review
# 9352357           None                   None            review
#
#                                               landing_norm  \
# 9366162          https://elifesciences.org/articles/100000
# 9352818  https://elifesciences.org/reviewed-preprints/1...
# 9353978  https://elifesciences.org/reviewed-preprints/1...
# 9353967  https://elifesciences.org/reviewed-preprints/1...
# 9353972  https://elifesciences.org/reviewed-preprints/1...
# ...                                                    ...
# 9353740  https://elifesciences.org/reviewed-preprints/9...
# 9353736  https://elifesciences.org/reviewed-preprints/9...
# 9351901  https://elifesciences.org/reviewed-preprints/9...
# 9352368  https://elifesciences.org/reviewed-preprints/9...
# 9352357  https://elifesciences.org/reviewed-preprints/9...
#
#                            doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 9366162        10.7554/elife.100000              NaN           NaN      NaN
# 9352818      10.7554/elife.100000.1              NaN           NaN      NaN
# 9353978  10.7554/elife.100000.1.sa0              NaN           NaN      NaN
# 9353967  10.7554/elife.100000.1.sa1              NaN           NaN      NaN
# 9353972  10.7554/elife.100000.1.sa2              NaN           NaN      NaN
# ...                             ...              ...           ...      ...
# 9353740   10.7554/elife.99997.1.sa2              NaN           NaN      NaN
# 9353736   10.7554/elife.99997.1.sa3              NaN           NaN      NaN
# 9351901       10.7554/elife.99999.1              NaN           NaN      NaN
# 9352368   10.7554/elife.99999.1.sa0              NaN           NaN      NaN
# 9352357   10.7554/elife.99999.1.sa1              NaN           NaN      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 9366162               NaN            NaN       NaN
# 9352818               NaN            NaN       NaN
# 9353978               NaN            NaN       NaN
# 9353967               NaN            NaN       NaN
# 9353972               NaN            NaN       NaN
# ...                   ...            ...       ...
# 9353740               NaN            NaN       NaN
# 9353736               NaN            NaN       NaN
# 9351901               NaN            NaN       NaN
# 9352368               NaN            NaN       NaN
# 9352357               NaN            NaN       NaN
#
# [58466 rows x 30 columns]

# %%
df[df['server_name']=='eLife']['doi']
# Out:
# 9130897                10.7554/elife
# 9274104          10.7554/elife.00003
# 9131097      10.7554/elife.00003.001
# 9131098      10.7554/elife.00003.002
# 9131100      10.7554/elife.00003.003
#                      ...
# 9366367    10.7554/elife.99999.2.sa2
# 9370550        10.7554/elife.99999.3
# 9370553    10.7554/elife.99999.3.sa0
# 9370552    10.7554/elife.99999.3.sa1
# 9370554    10.7554/elife.99999.3.sa2
# Name: doi, Length: 247558, dtype: object

# %%
import re
import numpy as np
import pandas as pd

df = df.copy()

# Ensure column exists
# if "records_hierarchy" not in df.columns:
#     df["records_hierarchy"] = np.nan

# Work ONLY on remaining rows
remaining = df["records_hierarchy"].isna()

is_elife = df["server_name"].astype(str).str.lower().eq("elife")
doi_l = df["doi"].astype(str).str.lower()

# ---------- Regex patterns ----------

# Base parent: 10.7554/elife.12523
RX_PARENT_BASE = re.compile(    r"^10\.7554/elife\.\d+$",    re.IGNORECASE)

# Explicit parent v1 (NO padding)
RX_PARENT_V1 = re.compile(    r"^10\.7554/elife\.\d+\.1$",    re.IGNORECASE)

# Any dotted numeric suffix (captures padding too)
RX_ANY_SUFFIX = re.compile(r"^10\.7554/elife\.\d+\.(\d+)$", re.IGNORECASE)

# ---------- Apply rules ----------

# Parent: base DOI
mask_parent_base = remaining & is_elife & doi_l.str.match(RX_PARENT_BASE, na=False)
df.loc[mask_parent_base, "records_hierarchy"] = "parent"

# Parent: explicit ".1" ONLY
mask_parent_v1 = remaining & is_elife & doi_l.str.match(RX_PARENT_V1, na=False)
df.loc[mask_parent_v1, "records_hierarchy"] = "parent_duplicate"

# Child: any numeric suffix EXCEPT exact ".1"
suffix = doi_l.str.extract(RX_ANY_SUFFIX)[0]

mask_child = (
    remaining
    & is_elife
    & suffix.notna()
    & (suffix != "1")   # excludes .1 but keeps .001, .002, .2, etc.
)

df.loc[mask_child, "records_hierarchy"] = "version"
print(df["records_hierarchy"].value_counts(dropna=False))
# Out:
# records_hierarchy
# parent              7853725
# review               175443
# part_of              149462
# version              117553
# NaN                  103877
# publish_version        9351
# correction              355
# comment                 325
# parent_duplicate          3
# Name: count, dtype: int64

# %%
df_remain = df[df['records_hierarchy'].isna()]
df_remain['server_name'].value_counts()
# Out:
# server_name
# ChemRxiv                                26513
# Earth and Space Science Open Archive    13089
# EGUsphere                               10209
# TechRxiv                                 8320
# PsyArXiv                                 6632
# PeerJ Preprints                          6446
# EarthArXiv                               6425
# Authorea Inc.                            6092
# engrXiv                                  4925
# SocArXiv                                 3072
# INA-Rxiv                                 2830
# Cambridge Open Engage                    2089
# Advance                                  1717
# Thesis Commons                           1507
# APSA Preprints                           1101
# AgriRxiv                                  787
# EdArXiv                                   550
# Law Archive                               287
# Arabixiv                                  209
# MetaArXiv                                 196
# ScienceOpen Preprints                     151
# LIS Scholarship Archive                    85
# PoolText                                   79
# Oroboros Instruments                       70
# BioHackrXiv                                65
# MindRxiv                                   62
# MarXiv                                     54
# PaleorXiv                                  51
# AfricArXiv                                 41
# Frenxiv                                    39
# ECSarXiv                                   39
# MediArXiv                                  37
# BodoArXiv                                  34
# NutriXiv                                   28
# FocUS Archive                              16
# F1000Research                              14
# CoP                                         9
# NewAddictionsX                              2
# Open Research Africa                        1
# Gates Open Research                         1
# AMRC Open Research                          1
# MNI Open Research                           1
# eLife                                       1
# Name: count, dtype: int64

# %%
df_remain[df_remain['server_name']=='eLife']
# Out:
#                        record_id server_name   backend            doi  \
# 9130897  crossref::10.7554/elife       eLife  crossref  10.7554/elife
#
#                                doi_url            landing_page_url  title  \
# 9130897  https://doi.org/10.7554/elife  https://elifesciences.org/  eLife
#
#         authors_flat publication_year date_created relations_json  \
# 9130897         <NA>             None   2017-07-25           None
#
#         version_label is_version_of is_preprint_of has_preprint has_review  \
# 9130897          None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 9130897                 false                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 9130897           None                   None               NaN
#
#                        landing_norm       doi_norm version_token_lp  \
# 9130897  https://elifesciences.org/  10.7554/elife             None
#
#         token_kind_lp  vnum_lp version_token_doi token_kind_doi  vnum_doi
# 9130897          None      NaN              None           None       NaN

# %%
# pattern = "10.7554/elife.99997"

# mask = df['doi'].str.contains(pattern, regex=False, na=False)
# result = df[mask]
# result

# df = df[df.records_hiearchy.isin(['publish_version', 'version'])]

# %% [markdown]
# #### ChemRxiv

# %%
df_remain[df_remain['server_name']=='ChemRxiv']
# Out:
#                                      record_id server_name   backend  \
# 286137  crossref::10.26434/chemrxiv-2021-00kkd    ChemRxiv  crossref
# 312423  crossref::10.26434/chemrxiv-2021-00rj4    ChemRxiv  crossref
# 312367  crossref::10.26434/chemrxiv-2021-012c7    ChemRxiv  crossref
# 286132  crossref::10.26434/chemrxiv-2021-01dfq    ChemRxiv  crossref
# 312472  crossref::10.26434/chemrxiv-2021-01hrg    ChemRxiv  crossref
# ...                                        ...         ...       ...
# 285987     crossref::10.26434/chemrxiv.5917351    ChemRxiv  crossref
# 287405     crossref::10.26434/chemrxiv.6483989    ChemRxiv  crossref
# 287403     crossref::10.26434/chemrxiv.8021102    ChemRxiv  crossref
# 287404     crossref::10.26434/chemrxiv.8378342    ChemRxiv  crossref
# 287402     crossref::10.26434/chemrxiv.9947129    ChemRxiv  crossref
#
#                                  doi  \
# 286137  10.26434/chemrxiv-2021-00kkd
# 312423  10.26434/chemrxiv-2021-00rj4
# 312367  10.26434/chemrxiv-2021-012c7
# 286132  10.26434/chemrxiv-2021-01dfq
# 312472  10.26434/chemrxiv-2021-01hrg
# ...                              ...
# 285987     10.26434/chemrxiv.5917351
# 287405     10.26434/chemrxiv.6483989
# 287403     10.26434/chemrxiv.8021102
# 287404     10.26434/chemrxiv.8378342
# 287402     10.26434/chemrxiv.9947129
#
#                                              doi_url  \
# 286137  https://doi.org/10.26434/chemrxiv-2021-00kkd
# 312423  https://doi.org/10.26434/chemrxiv-2021-00rj4
# 312367  https://doi.org/10.26434/chemrxiv-2021-012c7
# 286132  https://doi.org/10.26434/chemrxiv-2021-01dfq
# 312472  https://doi.org/10.26434/chemrxiv-2021-01hrg
# ...                                              ...
# 285987     https://doi.org/10.26434/chemrxiv.5917351
# 287405     https://doi.org/10.26434/chemrxiv.6483989
# 287403     https://doi.org/10.26434/chemrxiv.8021102
# 287404     https://doi.org/10.26434/chemrxiv.8378342
# 287402     https://doi.org/10.26434/chemrxiv.9947129
#
#                                          landing_page_url  \
# 286137  https://chemrxiv.org/engage/chemrxiv/article-d...
# 312423  https://chemrxiv.org/engage/chemrxiv/article-d...
# 312367  https://chemrxiv.org/engage/chemrxiv/article-d...
# 286132  https://chemrxiv.org/engage/chemrxiv/article-d...
# 312472  https://chemrxiv.org/engage/chemrxiv/article-d...
# ...                                                   ...
# 285987  https://chemrxiv.org/articles/CO2_Activation_o...
# 287405  https://chemrxiv.org/engage/chemrxiv/article-d...
# 287403  https://chemrxiv.org/engage/chemrxiv/article-d...
# 287404  https://chemrxiv.org/engage/chemrxiv/article-d...
# 287402  https://chemrxiv.org/engage/chemrxiv/article-d...
#
#                                                     title  \
# 286137  Understanding MOF nucleation from solution wit...
# 312423  Electrochemical Ozone Generation Using Compact...
# 312367  Surface modification of carbon dots with tetra...
# 286132  On the Role of Solvent in the Formation of Vac...
# 312472  Visible Light-driven Metal-free C–H Functional...
# ...                                                   ...
# 285987  CO2 Activation on Heterostructures of Bi2O3-Na...
# 287405  Highly sensitive gating in pH-responsive nanoc...
# 287403  Potassium Speciation and Distribution for the ...
# 287404  Outlier Modeling in Gear Bearing Using Autoenc...
# 287402  Negative Redox Potential Shift in Fire-Retarda...
#
#                                              authors_flat publication_year  \
# 286137  Kollias, Loukas; Rousseau, Roger; Glezakou, Va...           2021.0
# 312423  Wood, Georgia; Terrero Rodriguez, Irina; Tully...           2021.0
# 312367  Sviridova, Elizaveta; Barras, Alexandre; Plotn...           2021.0
# 286132  Marinova, Veselina; Wood, Geoffrey P. F.; Marz...           2021.0
# 312472  Kersting, Lena; Kuhn, Leah; Anokhin, Maksim; S...           2021.0
# ...                                                   ...              ...
# 285987                                     Nolan, Michael           2018.0
# 287405                    Lopez, Luis G.; Nap, Rikkert J.           2018.0
# 287403  Knutsson, Pavleta; Maric, Jelena; Knutsson, Je...           2019.0
# 287404           Singh, Sunny; Shiv, Praneet; Ahmed, Atif           2019.0
# 287402  Ernould, Bruno; Sieuw, Louis; Barozzino-Consig...           2019.0
#
#        date_created                                     relations_json  \
# 286137   2021-12-23                                               None
# 312423   2022-01-25  {"is-preprint-of": [{"asserted-by": "subject",...
# 312367   2022-01-25  {"is-preprint-of": [{"asserted-by": "subject",...
# 286132   2021-12-23                                               None
# 312472   2021-12-21  {"is-preprint-of": [{"asserted-by": "subject",...
# ...             ...                                                ...
# 285987   2018-02-23                                               None
# 287405   2018-06-12                                               None
# 287403   2019-04-23                                               None
# 287404   2019-07-01                                               None
# 287402   2019-10-11                                               None
#
#        version_label is_version_of              is_preprint_of has_preprint  \
# 286137          None
# 312423          None                  10.1149/1945-7111/ac3ff4
# 312367          None                10.1016/j.msec.2022.112697
# 286132          None
# 312472          None                    10.1002/cptc.202200109
# ...              ...           ...                         ...          ...
# 285987          None
# 287405          None
# 287403          None
# 287404          None
# 287402          None
#
#        has_review has_published_version published_version_ids_json  \
# 286137                            false                       None
# 312423                             true                       None
# 312367                             true                       None
# 286132                            false                       None
# 312472                             true                       None
# ...           ...                   ...                        ...
# 285987                            false                       None
# 287405                            false                       None
# 287403                            false                       None
# 287404                            false                       None
# 287402                            false                       None
#
#        version_of_ids_json update_to_json raw_relationships_json  \
# 286137                None           None                   None
# 312423                None           None                   None
# 312367                None           None                   None
# 286132                None           None                   None
# 312472                None           None                   None
# ...                    ...            ...                    ...
# 285987                None           None                   None
# 287405                None           None                   None
# 287403                None           None                   None
# 287404                None           None                   None
# 287402                None           None                   None
#
#        records_hierarchy                                       landing_norm  \
# 286137               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# 312423               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# 312367               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# 286132               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# 312472               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# ...                  ...                                                ...
# 285987               NaN  https://chemrxiv.org/articles/co2_activation_o...
# 287405               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# 287403               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# 287404               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# 287402               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
#
#                             doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 286137  10.26434/chemrxiv-2021-00kkd             None          None      NaN
# 312423  10.26434/chemrxiv-2021-00rj4             None          None      NaN
# 312367  10.26434/chemrxiv-2021-012c7             None          None      NaN
# 286132  10.26434/chemrxiv-2021-01dfq             None          None      NaN
# 312472  10.26434/chemrxiv-2021-01hrg             None          None      NaN
# ...                              ...              ...           ...      ...
# 285987     10.26434/chemrxiv.5917351             None          None      NaN
# 287405     10.26434/chemrxiv.6483989             None          None      NaN
# 287403     10.26434/chemrxiv.8021102             None          None      NaN
# 287404     10.26434/chemrxiv.8378342             None          None      NaN
# 287402     10.26434/chemrxiv.9947129             None          None      NaN
#
#        version_token_doi token_kind_doi  vnum_doi
# 286137              None           None       NaN
# 312423              None           None       NaN
# 312367              None           None       NaN
# 286132              None           None       NaN
# 312472              None           None       NaN
# ...                  ...            ...       ...
# 285987              None           None       NaN
# 287405              None           None       NaN
# 287403              None           None       NaN
# 287404              None           None       NaN
# 287402              None           None       NaN
#
# [26513 rows x 30 columns]

# %%
pattern = "v"

mask = df_remain[df_remain['server_name']=='ChemRxiv']['doi'].str.contains(pattern, regex=False, na=False)
result = df_remain[df_remain['server_name']=='ChemRxiv'][mask]
result
# Out:
#                                      record_id server_name   backend  \
# 286137  crossref::10.26434/chemrxiv-2021-00kkd    ChemRxiv  crossref
# 312423  crossref::10.26434/chemrxiv-2021-00rj4    ChemRxiv  crossref
# 312367  crossref::10.26434/chemrxiv-2021-012c7    ChemRxiv  crossref
# 286132  crossref::10.26434/chemrxiv-2021-01dfq    ChemRxiv  crossref
# 312472  crossref::10.26434/chemrxiv-2021-01hrg    ChemRxiv  crossref
# ...                                        ...         ...       ...
# 285987     crossref::10.26434/chemrxiv.5917351    ChemRxiv  crossref
# 287405     crossref::10.26434/chemrxiv.6483989    ChemRxiv  crossref
# 287403     crossref::10.26434/chemrxiv.8021102    ChemRxiv  crossref
# 287404     crossref::10.26434/chemrxiv.8378342    ChemRxiv  crossref
# 287402     crossref::10.26434/chemrxiv.9947129    ChemRxiv  crossref
#
#                                  doi  \
# 286137  10.26434/chemrxiv-2021-00kkd
# 312423  10.26434/chemrxiv-2021-00rj4
# 312367  10.26434/chemrxiv-2021-012c7
# 286132  10.26434/chemrxiv-2021-01dfq
# 312472  10.26434/chemrxiv-2021-01hrg
# ...                              ...
# 285987     10.26434/chemrxiv.5917351
# 287405     10.26434/chemrxiv.6483989
# 287403     10.26434/chemrxiv.8021102
# 287404     10.26434/chemrxiv.8378342
# 287402     10.26434/chemrxiv.9947129
#
#                                              doi_url  \
# 286137  https://doi.org/10.26434/chemrxiv-2021-00kkd
# 312423  https://doi.org/10.26434/chemrxiv-2021-00rj4
# 312367  https://doi.org/10.26434/chemrxiv-2021-012c7
# 286132  https://doi.org/10.26434/chemrxiv-2021-01dfq
# 312472  https://doi.org/10.26434/chemrxiv-2021-01hrg
# ...                                              ...
# 285987     https://doi.org/10.26434/chemrxiv.5917351
# 287405     https://doi.org/10.26434/chemrxiv.6483989
# 287403     https://doi.org/10.26434/chemrxiv.8021102
# 287404     https://doi.org/10.26434/chemrxiv.8378342
# 287402     https://doi.org/10.26434/chemrxiv.9947129
#
#                                          landing_page_url  \
# 286137  https://chemrxiv.org/engage/chemrxiv/article-d...
# 312423  https://chemrxiv.org/engage/chemrxiv/article-d...
# 312367  https://chemrxiv.org/engage/chemrxiv/article-d...
# 286132  https://chemrxiv.org/engage/chemrxiv/article-d...
# 312472  https://chemrxiv.org/engage/chemrxiv/article-d...
# ...                                                   ...
# 285987  https://chemrxiv.org/articles/CO2_Activation_o...
# 287405  https://chemrxiv.org/engage/chemrxiv/article-d...
# 287403  https://chemrxiv.org/engage/chemrxiv/article-d...
# 287404  https://chemrxiv.org/engage/chemrxiv/article-d...
# 287402  https://chemrxiv.org/engage/chemrxiv/article-d...
#
#                                                     title  \
# 286137  Understanding MOF nucleation from solution wit...
# 312423  Electrochemical Ozone Generation Using Compact...
# 312367  Surface modification of carbon dots with tetra...
# 286132  On the Role of Solvent in the Formation of Vac...
# 312472  Visible Light-driven Metal-free C–H Functional...
# ...                                                   ...
# 285987  CO2 Activation on Heterostructures of Bi2O3-Na...
# 287405  Highly sensitive gating in pH-responsive nanoc...
# 287403  Potassium Speciation and Distribution for the ...
# 287404  Outlier Modeling in Gear Bearing Using Autoenc...
# 287402  Negative Redox Potential Shift in Fire-Retarda...
#
#                                              authors_flat publication_year  \
# 286137  Kollias, Loukas; Rousseau, Roger; Glezakou, Va...           2021.0
# 312423  Wood, Georgia; Terrero Rodriguez, Irina; Tully...           2021.0
# 312367  Sviridova, Elizaveta; Barras, Alexandre; Plotn...           2021.0
# 286132  Marinova, Veselina; Wood, Geoffrey P. F.; Marz...           2021.0
# 312472  Kersting, Lena; Kuhn, Leah; Anokhin, Maksim; S...           2021.0
# ...                                                   ...              ...
# 285987                                     Nolan, Michael           2018.0
# 287405                    Lopez, Luis G.; Nap, Rikkert J.           2018.0
# 287403  Knutsson, Pavleta; Maric, Jelena; Knutsson, Je...           2019.0
# 287404           Singh, Sunny; Shiv, Praneet; Ahmed, Atif           2019.0
# 287402  Ernould, Bruno; Sieuw, Louis; Barozzino-Consig...           2019.0
#
#        date_created                                     relations_json  \
# 286137   2021-12-23                                               None
# 312423   2022-01-25  {"is-preprint-of": [{"asserted-by": "subject",...
# 312367   2022-01-25  {"is-preprint-of": [{"asserted-by": "subject",...
# 286132   2021-12-23                                               None
# 312472   2021-12-21  {"is-preprint-of": [{"asserted-by": "subject",...
# ...             ...                                                ...
# 285987   2018-02-23                                               None
# 287405   2018-06-12                                               None
# 287403   2019-04-23                                               None
# 287404   2019-07-01                                               None
# 287402   2019-10-11                                               None
#
#        version_label is_version_of              is_preprint_of has_preprint  \
# 286137          None
# 312423          None                  10.1149/1945-7111/ac3ff4
# 312367          None                10.1016/j.msec.2022.112697
# 286132          None
# 312472          None                    10.1002/cptc.202200109
# ...              ...           ...                         ...          ...
# 285987          None
# 287405          None
# 287403          None
# 287404          None
# 287402          None
#
#        has_review has_published_version published_version_ids_json  \
# 286137                            false                       None
# 312423                             true                       None
# 312367                             true                       None
# 286132                            false                       None
# 312472                             true                       None
# ...           ...                   ...                        ...
# 285987                            false                       None
# 287405                            false                       None
# 287403                            false                       None
# 287404                            false                       None
# 287402                            false                       None
#
#        version_of_ids_json update_to_json raw_relationships_json  \
# 286137                None           None                   None
# 312423                None           None                   None
# 312367                None           None                   None
# 286132                None           None                   None
# 312472                None           None                   None
# ...                    ...            ...                    ...
# 285987                None           None                   None
# 287405                None           None                   None
# 287403                None           None                   None
# 287404                None           None                   None
# 287402                None           None                   None
#
#        records_hierarchy                                       landing_norm  \
# 286137               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# 312423               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# 312367               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# 286132               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# 312472               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# ...                  ...                                                ...
# 285987               NaN  https://chemrxiv.org/articles/co2_activation_o...
# 287405               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# 287403               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# 287404               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
# 287402               NaN  https://chemrxiv.org/engage/chemrxiv/article-d...
#
#                             doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 286137  10.26434/chemrxiv-2021-00kkd             None          None      NaN
# 312423  10.26434/chemrxiv-2021-00rj4             None          None      NaN
# 312367  10.26434/chemrxiv-2021-012c7             None          None      NaN
# 286132  10.26434/chemrxiv-2021-01dfq             None          None      NaN
# 312472  10.26434/chemrxiv-2021-01hrg             None          None      NaN
# ...                              ...              ...           ...      ...
# 285987     10.26434/chemrxiv.5917351             None          None      NaN
# 287405     10.26434/chemrxiv.6483989             None          None      NaN
# 287403     10.26434/chemrxiv.8021102             None          None      NaN
# 287404     10.26434/chemrxiv.8378342             None          None      NaN
# 287402     10.26434/chemrxiv.9947129             None          None      NaN
#
#        version_token_doi token_kind_doi  vnum_doi
# 286137              None           None       NaN
# 312423              None           None       NaN
# 312367              None           None       NaN
# 286132              None           None       NaN
# 312472              None           None       NaN
# ...                  ...            ...       ...
# 285987              None           None       NaN
# 287405              None           None       NaN
# 287403              None           None       NaN
# 287404              None           None       NaN
# 287402              None           None       NaN
#
# [26513 rows x 30 columns]

# %%
df = df.copy()

# Work only on remaining (not already forced to parent)
mask_remain = df["records_hierarchy"] != "parent"

# Normalize version_label once
server_name = df["server_name"].astype(str).str.strip()#.str.lower()

# CHILD rules
child_mask = (
    mask_remain &
    server_name.isin(["ChemRxiv"])
)
df.loc[child_mask, "records_hierarchy"] = "parent"

print(df["records_hierarchy"].value_counts(dropna=False))
# Out:
# records_hierarchy
# parent              7893182
# review               175443
# part_of              149462
# version              104609
# NaN                   77364
# publish_version        9351
# correction              355
# comment                 325
# parent_duplicate          3
# Name: count, dtype: int64

# %%
df_remain = df[df['records_hierarchy'].isna()]
df_remain['server_name'].value_counts()
# Out:
# server_name
# Earth and Space Science Open Archive    13089
# EGUsphere                               10209
# TechRxiv                                 8320
# PsyArXiv                                 6632
# PeerJ Preprints                          6446
# EarthArXiv                               6425
# Authorea Inc.                            6092
# engrXiv                                  4925
# SocArXiv                                 3072
# INA-Rxiv                                 2830
# Cambridge Open Engage                    2089
# Advance                                  1717
# Thesis Commons                           1507
# APSA Preprints                           1101
# AgriRxiv                                  787
# EdArXiv                                   550
# Law Archive                               287
# Arabixiv                                  209
# MetaArXiv                                 196
# ScienceOpen Preprints                     151
# LIS Scholarship Archive                    85
# PoolText                                   79
# Oroboros Instruments                       70
# BioHackrXiv                                65
# MindRxiv                                   62
# MarXiv                                     54
# PaleorXiv                                  51
# AfricArXiv                                 41
# Frenxiv                                    39
# ECSarXiv                                   39
# MediArXiv                                  37
# BodoArXiv                                  34
# NutriXiv                                   28
# FocUS Archive                              16
# F1000Research                              14
# CoP                                         9
# NewAddictionsX                              2
# Gates Open Research                         1
# MNI Open Research                           1
# Open Research Africa                        1
# AMRC Open Research                          1
# eLife                                       1
# Name: count, dtype: int64

# %% [markdown]
# #### OSF-based servers

# %%
df_remain[df_remain['server_name']=='TechRxiv']
# Out:
#                                     record_id server_name   backend  \
# 5693929                                         Ding, Yuan           2019.0
# 5693935  Saborío-Romano, Oscar; Bidadfar, Ali; Sakamuri...           2019.0
# 5693930                            Santra, Subhendu Bikash           2019.0
# 5693933                      Ding, Yuan; Narbudowicz, Adam           2019.0
# 5693932  Alves, Erick; Noeland, Jonas; Marafioti, Gianc...           2019.0
# ...                                                    ...              ...
# 5702124                                 Alexander, Thomson           2023.0
# 5702125  Wang, Kai; Yu, Zichuan; Jin, Zhiyuan; Zhong, F...           2023.0
# 5702126  Farouk, Ahmed; AbuAli, Najah Abed; Mumtaz, Shahid           2023.0
# 5717544                        Kalhoro, Meer; Nadir, Masab           2025.0
# 5693928                      Arabian, Farah; Rice, Michael           2019.0
#
#         date_created relations_json version_label is_version_of  \
# 5693929   2019-10-18           None          None
# 5693935   2019-10-20           None          None
# 5693930   2019-10-20           None          None
# 5693933   2019-10-21           None          None
# 5693932   2019-10-21           None          None
# ...              ...            ...           ...           ...
# 5702124   2023-12-07           None          None
# 5702125   2023-12-07           None          None
# 5702126   2023-12-07           None          None
# 5717544   2025-02-17           None          None
# 5693928   2019-10-18           None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 5693929                                                        false
# 5693935                                                        false
# 5693930                                                        false
# 5693933                                                        false
# 5693932                                                        false
# ...                ...          ...        ...                   ...
# 5702124                                                        false
# 5702125                                                        false
# 5702126                                                        false
# 5717544                                                        false
# 5693928                                                        false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 5693929                       None                None           None
# 5693935                       None                None           None
# 5693930                       None                None           None
# 5693933                       None                None           None
# 5693932                       None                None           None
# ...                            ...                 ...            ...
# 5702124                       None                None           None
# 5702125                       None                None           None
# 5702126                       None                None           None
# 5717544                       None                None           None
# 5693928                       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 5693929                   None               NaN
# 5693935                   None               NaN
# 5693930                   None               NaN
# 5693933                   None               NaN
# 5693932                   None               NaN
# ...                        ...               ...
# 5702124                   None               NaN
# 5702125                   None               NaN
# 5702126                   None               NaN
# 5717544                   None               NaN
# 5693928                   None               NaN
#
#                                               landing_norm  \
# 5693929  https://www.techrxiv.org/articles/comment_on_c...
# 5693935  https://www.techrxiv.org/articles/novel_energi...
# 5693930  https://www.techrxiv.org/articles/modified_she...
# 5693933  https://www.techrxiv.org/articles/can_frequenc...
# 5693932  https://www.techrxiv.org/articles/online_param...
# ...                                                    ...
# 5702124  https://www.techrxiv.org/articles/preprint/opt...
# 5702125  https://www.techrxiv.org/articles/preprint/fre...
# 5702126  https://www.techrxiv.org/articles/preprint/qua...
# 5717544  https://techrxiv.figshare.com/articles/preprin...
# 5693928  https://www.techrxiv.org/articles/on_polarizat...
#
#                            doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 5693929  10.36227/techrxiv.10002041             None          None      NaN
# 5693935  10.36227/techrxiv.10002782             None          None      NaN
# 5693930  10.36227/techrxiv.10005770             None          None      NaN
# 5693933  10.36227/techrxiv.10007051             None          None      NaN
# 5693932  10.36227/techrxiv.10008968             None          None      NaN
# ...                             ...              ...           ...      ...
# 5702124  10.36227/techrxiv.24750039             None          None      NaN
# 5702125  10.36227/techrxiv.24751587             None          None      NaN
# 5702126  10.36227/techrxiv.24751989             None          None      NaN
# 5717544  10.36227/techrxiv.28424396             None          None      NaN
# 5693928   10.36227/techrxiv.9999659             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 5693929              None           None       NaN
# 5693935              None           None       NaN
# 5693930              None           None       NaN
# 5693933              None           None       NaN
# 5693932              None           None       NaN
# ...                   ...            ...       ...
# 5702124              None           None       NaN
# 5702125              None           None       NaN
# 5702126              None           None       NaN
# 5717544              None           None       NaN
# 5693928              None           None       NaN
#
# [8320 rows x 30 columns]

# %%
pattern = "10.31234/osf.io/zypk9"

mask = df['doi'].str.contains(pattern, regex=False, na=False)
result = df[mask]
result
# Out:
#                                   record_id server_name   backend  \
# 2391992     crossref::10.31234/osf.io/zypk9    PsyArXiv  crossref
# 2398751  crossref::10.31234/osf.io/zypk9_v1    PsyArXiv  crossref
#
#                               doi                                   doi_url  \
# 2391992     10.31234/osf.io/zypk9     https://doi.org/10.31234/osf.io/zypk9
# 2398751  10.31234/osf.io/zypk9_v1  https://doi.org/10.31234/osf.io/zypk9_v1
#
#                 landing_page_url  \
# 2391992     https://osf.io/zypk9
# 2398751  https://osf.io/zypk9_v1
#
#                                                      title  \
# 2391992  The Opposition of Surprisal and Semantic Simil...
# 2398751                                          WITHDRAWN
#
#                        authors_flat publication_year date_created  \
# 2391992  Sun, Kun; Nixon, Jessie S.           2020.0   2020-12-10
# 2398751                        <NA>           2020.0   2025-05-19
#
#         relations_json version_label is_version_of is_preprint_of  \
# 2391992           None          None
# 2398751           None          None
#
#         has_preprint has_review has_published_version  \
# 2391992                                         false
# 2398751                                         false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 2391992                       None                None           None
# 2398751                       None                None           None
#
#         raw_relationships_json records_hierarchy             landing_norm  \
# 2391992                   None               NaN     https://osf.io/zypk9
# 2398751                   None            parent  https://osf.io/zypk9_v1
#
#                          doi_norm version_token_lp     token_kind_lp  vnum_lp  \
# 2391992     10.31234/osf.io/zypk9             None              None      NaN
# 2398751  10.31234/osf.io/zypk9_v1              _v1  explicit_version      1.0
#
#         version_token_doi token_kind_doi  vnum_doi
# 2391992              None           None       NaN
# 2398751               NaN            NaN       NaN

# %%
pattern = "10.36227/techrxiv.24750039"

mask = df['doi'].str.contains(pattern, regex=False, na=False)
result = df[mask]
result
# Out:
#                                        record_id server_name   backend  \
# 5702124     crossref::10.36227/techrxiv.24750039    TechRxiv  crossref
# 5709343  crossref::10.36227/techrxiv.24750039.v1    TechRxiv  crossref
#
#                                    doi  \
# 5702124     10.36227/techrxiv.24750039
# 5709343  10.36227/techrxiv.24750039.v1
#
#                                                doi_url  \
# 5702124     https://doi.org/10.36227/techrxiv.24750039
# 5709343  https://doi.org/10.36227/techrxiv.24750039.v1
#
#                                           landing_page_url  \
# 5702124  https://www.techrxiv.org/articles/preprint/Opt...
# 5709343  https://www.techrxiv.org/doi/full/10.36227/tec...
#
#                                                      title  \
# 5702124  Optimizing Complex CPQ Software Systems for Qu...
# 5709343  Optimizing Complex CPQ Software Systems for Qu...
#
#                authors_flat publication_year date_created relations_json  \
# 5702124  Alexander, Thomson           2023.0   2023-12-07           None
# 5709343  Alexander, Thomson           2023.0   2023-12-07           None
#
#         version_label is_version_of is_preprint_of has_preprint has_review  \
# 5702124          None
# 5709343          None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 5702124                 false                       None                None
# 5709343                 false                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 5702124           None                   None               NaN
# 5709343           None                   None            parent
#
#                                               landing_norm  \
# 5702124  https://www.techrxiv.org/articles/preprint/opt...
# 5709343  https://www.techrxiv.org/doi/full/10.36227/tec...
#
#                               doi_norm version_token_lp     token_kind_lp  \
# 5702124     10.36227/techrxiv.24750039             None              None
# 5709343  10.36227/techrxiv.24750039.v1              .v1  explicit_version
#
#          vnum_lp version_token_doi token_kind_doi  vnum_doi
# 5702124      NaN              None           None       NaN
# 5709343      1.0               NaN            NaN       NaN

# %%
import re
import numpy as np

# Ensure column exists
if 'records_hierarchy' not in df.columns:
    df['records_hierarchy'] = pd.NA

# Work only on remaining (unlabeled)
remain = df['records_hierarchy'].isna()

# ----------------------------
# 1) OSF-based servers: parent if DOI is exactly osf.io/<5chars>
#    Examples:
#      10.31234/osf.io/zypk9  -> parent
#      10.31234/osf.io/zypk9_v1  -> NOT parent by this rule
# ----------------------------
OSF_SERVERS = {
    'PsyArXiv',
    'Thesis Commons',
    'SocArXiv',
    'OSF Preprints',
    'Open Science Framework',
    'MindRxiv',
    'MetaArXiv',
    'SportRxiv',
    'LawArXiv',
    'EarthArXiv',
    'EngrXiv',
    'MarXiv',
    'INA-Rxiv',
    'AfricArXiv',
    'AgriXiv',
    'Arabixiv',
    # add/remove servers you want to include
}

# matches "...osf.io/ABCDE" at end of DOI string
OSF_PARENT_RX = re.compile(r'osf\.io/[a-z0-9]{5}$', re.IGNORECASE)

mask_osf_parent = (
    remain
    # & df['server_name'].isin(OSF_SERVERS)
    & df['doi'].astype(str).str.lower().str.contains('osf.io/', na=False)
    & df['doi'].astype(str).str.match(r'.*osf\.io/[a-z0-9]{5}$', na=False)
)

df.loc[mask_osf_parent, 'records_hierarchy'] = 'parent'


# ----------------------------
# 2) TechRxiv: parent if DOI is exactly "techrxiv.<digits>"
#    Examples:
#      10.36227/techrxiv.24750039 -> parent
#      10.36227/techrxiv.24750039.v1 -> NOT parent by this rule
# ----------------------------
TECHRXIV_PARENT_RX = re.compile(r'techrxiv\.\d+$', re.IGNORECASE)

mask_techrxiv_parent = (
    df['records_hierarchy'].isna()
    & (df['server_name'] == 'TechRxiv')
    & df['doi'].astype(str).str.match(r'.*techrxiv\.\d+$', na=False)
)

df.loc[mask_techrxiv_parent, 'records_hierarchy'] = 'parent'


# ----------------------------
# Optional: if you want to label obvious "child" for OSF when suffix exists
# (only do this if you are confident the suffix means versioning)
# Example: osf.io/xxxxx_v2 or osf.io/xxxxx-v2 or osf.io/xxxxx.v2
# ----------------------------
OSF_CHILD_RX = re.compile(r'osf\.io/[a-z0-9]{5}([._-]?v\d+)$', re.IGNORECASE)

mask_osf_child = (
    df['records_hierarchy'].isna()
    & df['server_name'].isin(OSF_SERVERS)
    & df['doi'].astype(str).str.match(r'.*osf\.io/[a-z0-9]{5}([._-]?v\d+)$', na=False)
)

df.loc[mask_osf_child, 'records_hierarchy'] = 'version'


# ----------------------------
# Optional: TechRxiv child rule if you see explicit versioning later
# Example: techrxiv.24750039.v2 or techrxiv.24750039-v2
# ----------------------------
mask_techrxiv_child = (
    df['records_hierarchy'].isna()
    & (df['server_name'] == 'TechRxiv')
    & df['doi'].astype(str).str.match(r'.*techrxiv\.\d+([._-]?v\d+)$', na=False)
)

df.loc[mask_techrxiv_child, 'records_hierarchy'] = 'version'


# Quick check
print(df['records_hierarchy'].value_counts(dropna=False))
# Out:
# records_hierarchy
# parent              7921678
# review               175443
# part_of              149462
# version              104609
# NaN                   48868
# publish_version        9351
# correction              355
# comment                 325
# parent_duplicate          3
# Name: count, dtype: int64

# %%
df_remain = df[df['records_hierarchy'].isna()]
df_remain['server_name'].value_counts()
# Out:
# server_name
# Earth and Space Science Open Archive    13089
# EGUsphere                               10209
# PeerJ Preprints                          6446
# Authorea Inc.                            6092
# EarthArXiv                               4693
# engrXiv                                  2733
# Cambridge Open Engage                    2089
# Advance                                  1717
# APSA Preprints                           1101
# AgriRxiv                                  380
# ScienceOpen Preprints                     151
# PoolText                                   79
# Oroboros Instruments                       70
# F1000Research                              14
# Open Research Africa                        1
# AMRC Open Research                          1
# MNI Open Research                           1
# Gates Open Research                         1
# eLife                                       1
# Name: count, dtype: int64

# %%
pattern = "10.31234/osf.io/zypk9"

mask = df['doi'].str.contains(pattern, regex=False, na=False)
result = df[mask]
result
# Out:
#                                   record_id server_name   backend  \
# 2391992     crossref::10.31234/osf.io/zypk9    PsyArXiv  crossref
# 2398751  crossref::10.31234/osf.io/zypk9_v1    PsyArXiv  crossref
#
#                               doi                                   doi_url  \
# 2391992     10.31234/osf.io/zypk9     https://doi.org/10.31234/osf.io/zypk9
# 2398751  10.31234/osf.io/zypk9_v1  https://doi.org/10.31234/osf.io/zypk9_v1
#
#                 landing_page_url  \
# 2391992     https://osf.io/zypk9
# 2398751  https://osf.io/zypk9_v1
#
#                                                      title  \
# 2391992  The Opposition of Surprisal and Semantic Simil...
# 2398751                                          WITHDRAWN
#
#                        authors_flat publication_year date_created  \
# 2391992  Sun, Kun; Nixon, Jessie S.           2020.0   2020-12-10
# 2398751                        <NA>           2020.0   2025-05-19
#
#         relations_json version_label is_version_of is_preprint_of  \
# 2391992           None          None
# 2398751           None          None
#
#         has_preprint has_review has_published_version  \
# 2391992                                         false
# 2398751                                         false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 2391992                       None                None           None
# 2398751                       None                None           None
#
#         raw_relationships_json records_hierarchy             landing_norm  \
# 2391992                   None            parent     https://osf.io/zypk9
# 2398751                   None            parent  https://osf.io/zypk9_v1
#
#                          doi_norm version_token_lp     token_kind_lp  vnum_lp  \
# 2391992     10.31234/osf.io/zypk9             None              None      NaN
# 2398751  10.31234/osf.io/zypk9_v1              _v1  explicit_version      1.0
#
#         version_token_doi token_kind_doi  vnum_doi
# 2391992              None           None       NaN
# 2398751               NaN            NaN       NaN

# %%
pattern = "10.36227/techrxiv.24750039"

mask = df['doi'].str.contains(pattern, regex=False, na=False)
result = df[mask]
result
# Out:
#                                        record_id server_name   backend  \
# 5702124     crossref::10.36227/techrxiv.24750039    TechRxiv  crossref
# 5709343  crossref::10.36227/techrxiv.24750039.v1    TechRxiv  crossref
#
#                                    doi  \
# 5702124     10.36227/techrxiv.24750039
# 5709343  10.36227/techrxiv.24750039.v1
#
#                                                doi_url  \
# 5702124     https://doi.org/10.36227/techrxiv.24750039
# 5709343  https://doi.org/10.36227/techrxiv.24750039.v1
#
#                                           landing_page_url  \
# 5702124  https://www.techrxiv.org/articles/preprint/Opt...
# 5709343  https://www.techrxiv.org/doi/full/10.36227/tec...
#
#                                                      title  \
# 5702124  Optimizing Complex CPQ Software Systems for Qu...
# 5709343  Optimizing Complex CPQ Software Systems for Qu...
#
#                authors_flat publication_year date_created relations_json  \
# 5702124  Alexander, Thomson           2023.0   2023-12-07           None
# 5709343  Alexander, Thomson           2023.0   2023-12-07           None
#
#         version_label is_version_of is_preprint_of has_preprint has_review  \
# 5702124          None
# 5709343          None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 5702124                 false                       None                None
# 5709343                 false                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 5702124           None                   None            parent
# 5709343           None                   None            parent
#
#                                               landing_norm  \
# 5702124  https://www.techrxiv.org/articles/preprint/opt...
# 5709343  https://www.techrxiv.org/doi/full/10.36227/tec...
#
#                               doi_norm version_token_lp     token_kind_lp  \
# 5702124     10.36227/techrxiv.24750039             None              None
# 5709343  10.36227/techrxiv.24750039.v1              .v1  explicit_version
#
#          vnum_lp version_token_doi token_kind_doi  vnum_doi
# 5702124      NaN              None           None       NaN
# 5709343      1.0               NaN            NaN       NaN

# %% [markdown]
# #### EarthArXiv, Authorea Inc., Cambridge Open Engage

# %%
import re
import pandas as pd

# Ensure target column exists
# if 'records_hierarchy' not in df.columns:
#     df['records_hierarchy'] = pd.NA

remain = df['records_hierarchy'].isna()

doi_s = df['doi'].astype(str).str.strip().str.lower()

# -------------------------
# EarthArXiv: 10.15697/<token>
# Examples: 10.15697/fk20022, 10.15697/fk2v59g
# -------------------------
mask_eartharxiv_parent = (
    remain
    & (df['server_name'] == 'EarthArXiv')
    & doi_s.str.match(r'^10\.15697/[a-z0-9]+$', na=False)
)
df.loc[mask_eartharxiv_parent, 'records_hierarchy'] = 'parent'

# -------------------------
# Authorea: 10.22541/au.<digits>.<digits>
# Examples: 10.22541/au.148928287.78038962
# -------------------------
mask_authorea_parent = (
    df['records_hierarchy'].isna()
    & (df['server_name'] == 'Authorea Inc.')
    & doi_s.str.match(r'^10\.22541/au\.\d+\.\d+$', na=False)
)
df.loc[mask_authorea_parent, 'records_hierarchy'] = 'parent'

# -------------------------
# The Winnower: 10.15200/winn.<digits>.<digits>
# Examples: 10.15200/winn.143644.45920
# -------------------------
mask_winn_parent = (
    df['records_hierarchy'].isna()
    & doi_s.str.match(r'^10\.15200/winn\.\d+\.\d+$', na=False)
)
df.loc[mask_winn_parent, 'records_hierarchy'] = 'parent'

# -------------------------
# engrXiv: 10.31224/<digits>
# Examples: 10.31224/2109
# -------------------------
mask_engrxiv_parent = (
    df['records_hierarchy'].isna()
    & (df['server_name'] == 'engrXiv')
    & doi_s.str.match(r'^10\.31224/\d+$', na=False)
)
df.loc[mask_engrxiv_parent, 'records_hierarchy'] = 'parent'

# -------------------------
# Cambridge Open Engage: 10.33774/coe-<year or token>-<token>
# Examples: 10.33774/coe-2025-zz7tp, 10.33774/coe-2020-03prm, 10.33774/coe-xxxx-xxxxx
# -------------------------
mask_coe_parent = (
    df['records_hierarchy'].isna()
    & (df['server_name'] == 'Cambridge Open Engage')
    & doi_s.str.match(r'^10\.33774/coe-[a-z0-9]{4}-[a-z0-9]{4,}$', na=False)
)
df.loc[mask_coe_parent, 'records_hierarchy'] = 'parent'

# Optional quick check
print(df['records_hierarchy'].value_counts(dropna=False))
# Out:
# records_hierarchy
# parent              7932594
# review               175443
# part_of              149462
# version              104609
# NaN                   37952
# publish_version        9351
# correction              355
# comment                 325
# parent_duplicate          3
# Name: count, dtype: int64

# %% [markdown]
# #### Advance, APSA Preprints, AgriRxiv, EGUsphere

# %%
import pandas as pd

# Ensure column exists
# if 'records_hierarchy' not in df.columns:
#     df['records_hierarchy'] = pd.NA

remain = df['records_hierarchy'].isna()
doi_s = df['doi'].astype(str).str.strip().str.lower()

# -------------------------
# Advance: 10.31124/advance.<digits>
# Examples: 10.31124/advance.10005662, 10.31124/advance.9978302
# -------------------------
mask_advance_parent = (
    remain
    & (df['server_name'] == 'Advance')
    & doi_s.str.match(r'^10\.31124/advance\.\d+$', na=False)
)
df.loc[mask_advance_parent, 'records_hierarchy'] = 'parent'

# -------------------------
# APSA Preprints: 10.33774/apsa-<yyyy>-<token>
# Examples: 10.33774/apsa-2025-zqggn, 10.33774/apsa-2019-0b2dl
# -------------------------
mask_apsa_parent = (
    df['records_hierarchy'].isna()
    & (df['server_name'] == 'APSA Preprints')
    & doi_s.str.match(r'^10\.33774/apsa-\d{4}-[a-z0-9]+$', na=False)
)
df.loc[mask_apsa_parent, 'records_hierarchy'] = 'parent'

# -------------------------
# AgriRxiv: 10.31220/agrirxiv.<yyyy>.<5digits>
# Examples: 10.31220/agrirxiv.2020.00001, 10.31220/agrirxiv.2025.00384
# -------------------------
mask_agrirxiv_parent = (
    df['records_hierarchy'].isna()
    & (df['server_name'] == 'AgriRxiv')
    & doi_s.str.match(r'^10\.31220/agrirxiv\.\d{4}\.\d{5}$', na=False)
)
df.loc[mask_agrirxiv_parent, 'records_hierarchy'] = 'parent'

# -------------------------
# EGUsphere (and EGUsphere-style journal DOIs): 10.5194/<slug>-<yyyy>-<number>
# Examples:
#   10.5194/egusphere-2022-1
#   10.5194/egusphere-2022-1000
#   10.5194/amt-2022-295
#   10.5194/hess-2024-3989
# -------------------------
mask_egusphere_parent = (
    df['records_hierarchy'].isna()
    & (df['server_name'] == 'EGUsphere')
    & doi_s.str.match(r'^10\.5194/[a-z0-9]+-\d{4}-\d+$', na=False)
)
df.loc[mask_egusphere_parent, 'records_hierarchy'] = 'parent'

# Optional quick check
print(df['records_hierarchy'].value_counts(dropna=False))
# Out:
# records_hierarchy
# parent              7946001
# review               175443
# part_of              149462
# version              104609
# NaN                   24545
# publish_version        9351
# correction              355
# comment                 325
# parent_duplicate          3
# Name: count, dtype: int64

# %% [markdown]
# #### Oroboros Instruments, PoolText, ScienceOpen Preprints, EarthArXiv

# %%
import pandas as pd

# Ensure column exists
# if 'records_hierarchy' not in df.columns:
#     df['records_hierarchy'] = pd.NA

remain = df['records_hierarchy'].isna()
doi_s = df['doi'].astype(str).str.strip().str.lower()

# ------------------------------------------------------------
# Oroboros Instruments (examples)
# - 10.26124/bec.2024-0007
# - 10.26124/mitofit:ea19.mipschool.0005
# Parent if EXACT pattern with nothing after.
# ------------------------------------------------------------
mask_oroboros_parent = (
    remain
    & (df['server_name'] == 'Oroboros Instruments')
    & doi_s.str.match(
        r'^10\.26124/('
        r'bec\.\d{4}-\d{4}'                       # bec.2024-0007
        r'|mitofit:[a-z0-9]+\.[a-z0-9]+\.\d{4}'   # mitofit:ea19.mipschool.0005
        r')$',
        na=False
    )
)
df.loc[mask_oroboros_parent, 'records_hierarchy'] = 'parent'

# ------------------------------------------------------------
# Oroboros Instruments — Parent DOI patterns
# Examples (parents):
# - 10.26124/bec.2025-0005ar
# - 10.26124/bec.2025-0005it
# - 10.26124/bec:2024-0001
# - 10.26124/becprep.2025-0006.ed2
# - 10.26124/becprep.2025-0005
# - 10.26124/mitofit:190001
# - 10.26124/mitofit:2021-0005
# ------------------------------------------------------------
OROBOROS_PARENT_RX = r'^10\.26124/(' \
    r'bec[.:]\d{4}-\d{4}[a-z]{0,3}' \
    r'|' \
    r'becprep\.\d{4}-\d{4}(?:\.[a-z0-9]{1,6})?' \
    r'|' \
    r'mitofit:\d{6}' \
    r'|' \
    r'mitofit:\d{4}-\d{4}' \
    r')$'

mask_oroboros_parent = (
    remain
    & (df['server_name'] == 'Oroboros Instruments')
    & doi_s.str.match(OROBOROS_PARENT_RX, na=False)
)

df.loc[mask_oroboros_parent, 'records_hierarchy'] = 'parent'

# ------------------------------------------------------------
# PoolText (examples)
# - 10.31923/5547-4288-0095
# - 10.31923/pooltext-preprint-0067-3907-0053
# Parent if EXACT pattern with nothing after.
# ------------------------------------------------------------
mask_pooltext_parent = (
    df['records_hierarchy'].isna()
    & (df['server_name'] == 'PoolText')
    & doi_s.str.match(
        r'^10\.31923/('
        r'\d{4}-\d{4}-\d{4}'                                  # 5547-4288-0095
        r'|pooltext-preprint-\d{4}-\d{4}-\d{4}'               # pooltext-preprint-0067-3907-0053
        r')$',
        na=False
    )
)
df.loc[mask_pooltext_parent, 'records_hierarchy'] = 'parent'


# ------------------------------------------------------------
# ScienceOpen Preprints — Parent DOI patterns (STRICT / exact)
# Parent if EXACT pattern with nothing after.
# ------------------------------------------------------------

SCIENCEOPEN_PARENT_RX = (
    r'^10\.14293/('
    # 1) Old pattern like: s2199-1006.1.sor-.sdg.01
    r's2199-1006\.1\.sor-\.[a-z0-9]+\.\d{2}'
    r'|'
    # 2) New s2199-r2om patterns:
    #    - s2199-r2om-0001
    #    - s2199-r2om-abs-0003
    r's2199-r2om-(?:abs-)?\d{4}'
    r'|'
    # 3) New "rexpo" compact pattern:
    #    - s2199-rexpo22011v1
    r's2199-rexpo\d{5}v\d+'
    r'|'
    # 4) New ssp-am patterns:
    #    - s2199-ssp-am22-0001
    #    - s2199-ssp-am23-01001
    #    - s2199-ssp-am25-01015
    r's2199-ssp-am\d{2}-\d{4,5}'
    r'|'
    # 5) sblunisa patterns:
    #    - sblunisa.2023a024.mm (old)
    #    - sblunisa.2023a002.vnm (new)
    #    - sblunisa.2023a017.ojjt (new)
    r'sblunisa\.\d{4}a\d{3}\.[a-z0-9]{2,4}'
    r')$'
)

mask_scienceopen_parent = (
    df['records_hierarchy'].isna()
    & (df['server_name'] == 'ScienceOpen Preprints')
    & doi_s.str.match(SCIENCEOPEN_PARENT_RX, na=False)
)

df.loc[mask_scienceopen_parent, 'records_hierarchy'] = 'parent'


# ------------------------------------------------------------
# EarthArXiv
# Examples:
# - 10.31223/x50025  (5)
# - 10.31223/x5003j  (6)
# - 10.31223/x5zr0p  (6)
# Parent if EXACT pattern with nothing after.
# ------------------------------------------------------------
mask_eartharxiv_parent = (
    df['records_hierarchy'].isna()
    & (df['server_name'] == 'EarthArXiv')
    & doi_s.str.match(r'^10\.31223/[a-z0-9]{5,6}$', na=False)   # 5–6 chars after slash
)
df.loc[mask_eartharxiv_parent, 'records_hierarchy'] = 'parent'


# Optional quick check
print(df['records_hierarchy'].value_counts(dropna=False))
# Out:
# records_hierarchy
# parent              7950992
# review               175443
# part_of              149462
# version              104609
# NaN                   19554
# publish_version        9351
# correction              355
# comment                 325
# parent_duplicate          3
# Name: count, dtype: int64

# %% [markdown]
# #### PeerJ Preprints

# %%
import re

# ------------------------------------------------------------
# PeerJ Preprints
# Parent:
#  - no trailing vN: 10.7287/peerj.preprints.1001
#  - trailing v1:    10.7287/peerj.preprints.1001v1
# Child:
#  - trailing v2+:   10.7287/peerj.preprints.1001v2, v3, ...
# ------------------------------------------------------------

doi_s = df['doi'].astype(str).str.strip().str.lower()

mask_peerj = (
    df['records_hierarchy'].isna()
    & (df['server_name'] == 'PeerJ Preprints')
    & doi_s.str.startswith('10.7287/peerj.preprints.', na=False)
)

# Extract trailing version number if present (v1, v2, ...)
peerj_v_str = doi_s.where(mask_peerj).str.extract(r'v(?P<v>\d+)$')['v']

# Convert safely to numeric (NaN stays NaN)
peerj_v_num = pd.to_numeric(peerj_v_str, errors='coerce')

# Parent: no version suffix OR v1
mask_peerj_parent = mask_peerj & (peerj_v_num.isna() | (peerj_v_num == 1))
df.loc[mask_peerj_parent, 'records_hierarchy'] = 'parent'

# Child: v2+
mask_peerj_child = mask_peerj & (peerj_v_num >= 2)
df.loc[mask_peerj_child, 'records_hierarchy'] = 'version'

# Optional quick check
print(df['records_hierarchy'].value_counts(dropna=False))
# Out:
# records_hierarchy
# parent              7956063
# review               175443
# part_of              149462
# version              105984
# NaN                   13108
# publish_version        9351
# correction              355
# comment                 325
# parent_duplicate          3
# Name: count, dtype: int64

# %% [markdown]
# #### Earth and Space Science Open Archive

# %%
import pandas as pd

# -------------------------------------------------------------------
# Normalize DOI strings:
# - ensure everything is string
# - remove leading/trailing spaces
# - lowercase for consistent matching
# -------------------------------------------------------------------
doi_s = df['doi'].astype(str).str.strip().str.lower()

# -------------------------------------------------------------------
# Identify records to process:
# - records_hierarchy not yet assigned
# - server is Earth and Space Science Open Archive (ESSOAr)
# -------------------------------------------------------------------
mask_essoar = (
    df['records_hierarchy'].isna()
    & (df['server_name'] == 'Earth and Space Science Open Archive')
)

# -------------------------------------------------------------------
# Extract the final numeric version from the DOI
#
# Examples:
#   10.1002/essoar.10500074.1  → n = 1
#   10.1002/essoar.10500061.2  → n = 2
#   10.22541/essoar.xxx.xxx.3  → n = 3
#
# Regex explanation:
#   \.        → literal dot
#   (?P<n>)  → capture group named "n"
#   \d+      → one or more digits
#   $        → end of string (must be the last segment)
# -------------------------------------------------------------------
essoar_n_str = (
    doi_s
    .where(mask_essoar)                # only evaluate ESSOAr rows
    .str.extract(r'\.(?P<n>\d+)$')['n']  # extract trailing version number
)

# Convert extracted version to numeric:
# - invalid or missing values become NaN (safe for comparisons)
essoar_n = pd.to_numeric(essoar_n_str, errors='coerce')

# -------------------------------------------------------------------
# Label parent records:
# - ESSOAr records
# - version suffix == ".1"
# -------------------------------------------------------------------
mask_essoar_parent = mask_essoar & (essoar_n == 1)
df.loc[mask_essoar_parent, 'records_hierarchy'] = 'parent'

# -------------------------------------------------------------------
# Label child records:
# - ESSOAr records
# - version suffix >= ".2"
# -------------------------------------------------------------------
mask_essoar_child = mask_essoar & (essoar_n >= 2)
df.loc[mask_essoar_child, 'records_hierarchy'] = 'child'

# -------------------------------------------------------------------
# Optional sanity check:
# Show distribution of hierarchy labels
# -------------------------------------------------------------------
print(df['records_hierarchy'].value_counts(dropna=False))
# Out:
# records_hierarchy
# parent              7967124
# review               175443
# part_of              149462
# version              105984
# publish_version        9351
# child                  2028
# correction              355
# comment                 325
# NaN                      19
# parent_duplicate          3
# Name: count, dtype: int64

# %%
df.loc[df['server_name'].eq('Earth and Space Science Open Archive'), 'records_hierarchy'].value_counts(dropna=False)
# Out:
# records_hierarchy
# parent             20047
# child               2028
# version              824
# publish_version       29
# part_of                4
# Name: count, dtype: int64

# %% [markdown]
# #### F1000Research

# %%
df.loc[df['server_name'].eq('F1000Research'), 'records_hierarchy'].value_counts(dropna=False)
# Out:
# records_hierarchy
# parent     11155
# version     5704
# NaN           14
# Name: count, dtype: int64

# %%
df_remain = df[df['records_hierarchy'].isna()]
df_remain['server_name'].value_counts()
# Out:
# server_name
# F1000Research           14
# Open Research Africa     1
# AMRC Open Research       1
# Gates Open Research      1
# MNI Open Research        1
# eLife                    1
# Name: count, dtype: int64

# %%
df_remain[df_remain['server_name']=='F1000Research']
# Out:
#                                              record_id    server_name  \
# 587381                crossref::10.12688/f1000research  F1000Research
# 588652        crossref::10.12688/f1000research.11198.1  F1000Research
# 580538       crossref::10.12688/f1000research.124059.1  F1000Research
# 588651        crossref::10.12688/f1000research.14416.1  F1000Research
# 588733       crossref::10.12688/f1000research.163729.1  F1000Research
# 588738       crossref::10.12688/f1000research.166247.1  F1000Research
# 588744       crossref::10.12688/f1000research.168206.1  F1000Research
# 572211  crossref::10.3410/10.3410/f1000devtestarticley  F1000Research
# 572499                       crossref::10.3410/123.430  F1000Research
# 572210          crossref::10.3410/f1000devtestarticlez  F1000Research
# 572209   crossref::10.3410/f1000devtestcrossmarkpolicy  F1000Research
# 572212                      crossref::10.3410/f1000res  F1000Research
# 572214                 crossref::10.3410/f1000research  F1000Research
# 572500        crossref::10.3410/http://www.someurl.com  F1000Research
#
#          backend                                   doi  \
# 587381  crossref                10.12688/f1000research
# 588652  crossref        10.12688/f1000research.11198.1
# 580538  crossref       10.12688/f1000research.124059.1
# 588651  crossref        10.12688/f1000research.14416.1
# 588733  crossref       10.12688/f1000research.163729.1
# 588738  crossref       10.12688/f1000research.166247.1
# 588744  crossref       10.12688/f1000research.168206.1
# 572211  crossref  10.3410/10.3410/f1000devtestarticley
# 572499  crossref                       10.3410/123.430
# 572210  crossref          10.3410/f1000devtestarticlez
# 572209  crossref   10.3410/f1000devtestcrossmarkpolicy
# 572212  crossref                      10.3410/f1000res
# 572214  crossref                 10.3410/f1000research
# 572500  crossref        10.3410/http://www.someurl.com
#
#                                                   doi_url  \
# 587381             https://doi.org/10.12688/f1000research
# 588652     https://doi.org/10.12688/f1000research.11198.1
# 580538    https://doi.org/10.12688/f1000research.124059.1
# 588651     https://doi.org/10.12688/f1000research.14416.1
# 588733    https://doi.org/10.12688/f1000research.163729.1
# 588738    https://doi.org/10.12688/f1000research.166247.1
# 588744    https://doi.org/10.12688/f1000research.168206.1
# 572211  https://doi.org/10.3410/10.3410/f1000devtestar...
# 572499                    https://doi.org/10.3410/123.430
# 572210       https://doi.org/10.3410/f1000devtestarticlez
# 572209  https://doi.org/10.3410/f1000devtestcrossmarkp...
# 572212                   https://doi.org/10.3410/f1000res
# 572214              https://doi.org/10.3410/f1000research
# 572500     https://doi.org/10.3410/http://www.someurl.com
#
#                                          landing_page_url  \
# 587381                       http://www.f1000research.com
# 588652          https://f1000research.com/articles/6-1014
# 580538        https://f1000research.com/articles/11-1230/
# 588651          https://f1000research.com/articles/7-1362
# 588733          https://f1000research.com/articles/14-656
# 588738          https://f1000research.com/articles/14-598
# 588744          https://f1000research.com/articles/14-975
# 572211                          http://www.xy.net/article
# 572499                             http://www.someURl.com
# 572210  http://researchdev.f1000.com/articles/F1000Dev...
# 572209                                           resource
# 572212                                          2046-1402
# 572214                      http://www.f1000research.com/
# 572500                             http://www.someURl.com
#
#                                                     title  \
# 587381                                      F1000Research
# 588652  New perspectives on the regulation of type II ...
# 580538  LiftoffTools: a toolkit for comparing gene ann...
# 588651  Recent advances in the understanding and manag...
# 588733  Autoimmune Patient Health Through a Flourishin...
# 588738  Anticipated Growth in Healthcare Spending: The...
# 588744  Scientific Productivity and Population Health:...
# 572211                                          someTitle
# 572499                                          someTitle
# 572210                               F1000DevTestArticleZ
# 572209                        F1000DevTestCrossMarkPolicy
# 572212                                     F1000 Research
# 572214                                      F1000Research
# 572500                                          someTitle
#
#                              authors_flat publication_year date_created  \
# 587381                               <NA>             None   2025-07-24
# 588652               Becerra-Diaz, Mireya           2017.0   2025-11-28
# 580538  Shumate, Alaina; Salzberg, Steven           2022.0   2022-10-28
# 588651                        Hay, Ashley           2018.0   2025-11-28
# 588733              Pasca Rina, Amherstia           2025.0   2025-12-01
# 588738               Rugchatjaroen, Krish           2025.0   2025-12-01
# 588744                     Altamimi, Omar           2025.0   2025-12-01
# 572211                        abcde, XXXX           2012.0   2012-06-11
# 572499                 someName, someName           2009.0   2012-09-13
# 572210                 LNameZ, firstnameZ           2012.0   2012-06-07
# 572209                    Manager, Policy           2012.0   2012-05-31
# 572212                               <NA>             None   2013-03-05
# 572214                               <NA>             None   2013-05-09
# 572500                 someName, someName           2009.0   2012-09-13
#
#        relations_json version_label is_version_of is_preprint_of has_preprint  \
# 587381           None          None
# 588652           None          None
# 580538           None          None
# 588651           None          None
# 588733           None          None
# 588738           None          None
# 588744           None          None
# 572211           None          None
# 572499           None          None
# 572210           None          None
# 572209           None          None
# 572212           None          None
# 572214           None          None
# 572500           None          None
#
#        has_review has_published_version published_version_ids_json  \
# 587381                            false                       None
# 588652                            false                       None
# 580538                            false                       None
# 588651                            false                       None
# 588733                            false                       None
# 588738                            false                       None
# 588744                            false                       None
# 572211                            false                       None
# 572499                            false                       None
# 572210                            false                       None
# 572209                            false                       None
# 572212                            false                       None
# 572214                            false                       None
# 572500                            false                       None
#
#        version_of_ids_json update_to_json raw_relationships_json  \
# 587381                None           None                   None
# 588652                None           None                   None
# 580538                None           None                   None
# 588651                None           None                   None
# 588733                None           None                   None
# 588738                None           None                   None
# 588744                None           None                   None
# 572211                None           None                   None
# 572499                None           None                   None
# 572210                None           None                   None
# 572209                None           None                   None
# 572212                None           None                   None
# 572214                None           None                   None
# 572500                None           None                   None
#
#        records_hierarchy                                       landing_norm  \
# 587381               NaN                       http://www.f1000research.com
# 588652               NaN          https://f1000research.com/articles/6-1014
# 580538               NaN        https://f1000research.com/articles/11-1230/
# 588651               NaN          https://f1000research.com/articles/7-1362
# 588733               NaN          https://f1000research.com/articles/14-656
# 588738               NaN          https://f1000research.com/articles/14-598
# 588744               NaN          https://f1000research.com/articles/14-975
# 572211               NaN                          http://www.xy.net/article
# 572499               NaN                             http://www.someurl.com
# 572210               NaN  http://researchdev.f1000.com/articles/f1000dev...
# 572209               NaN                                           resource
# 572212               NaN                                          2046-1402
# 572214               NaN                      http://www.f1000research.com/
# 572500               NaN                             http://www.someurl.com
#
#                                     doi_norm version_token_lp token_kind_lp  \
# 587381                10.12688/f1000research             None          None
# 588652        10.12688/f1000research.11198.1             None          None
# 580538       10.12688/f1000research.124059.1             None          None
# 588651        10.12688/f1000research.14416.1             None          None
# 588733       10.12688/f1000research.163729.1             None          None
# 588738       10.12688/f1000research.166247.1             None          None
# 588744       10.12688/f1000research.168206.1             None          None
# 572211  10.3410/10.3410/f1000devtestarticley             None          None
# 572499                       10.3410/123.430             None          None
# 572210          10.3410/f1000devtestarticlez             None          None
# 572209   10.3410/f1000devtestcrossmarkpolicy             None          None
# 572212                      10.3410/f1000res             None          None
# 572214                 10.3410/f1000research             None          None
# 572500        10.3410/http://www.someurl.com             None          None
#
#         vnum_lp version_token_doi token_kind_doi  vnum_doi
# 587381      NaN              None           None       NaN
# 588652      NaN              None           None       NaN
# 580538      NaN              None           None       NaN
# 588651      NaN              None           None       NaN
# 588733      NaN              None           None       NaN
# 588738      NaN              None           None       NaN
# 588744      NaN              None           None       NaN
# 572211      NaN              None           None       NaN
# 572499      NaN              None           None       NaN
# 572210      NaN              None           None       NaN
# 572209      NaN              None           None       NaN
# 572212      NaN              None           None       NaN
# 572214      NaN              None           None       NaN
# 572500      NaN              None           None       NaN

# %%
df_remain[df_remain['server_name']=='Open Research Africa']
# Out:
#                              record_id           server_name   backend  \
# 2121895  crossref::10.12688/aasopenres  Open Research Africa  crossref
#
#                          doi                              doi_url  \
# 2121895  10.12688/aasopenres  https://doi.org/10.12688/aasopenres
#
#                        landing_page_url              title authors_flat  \
# 2121895  http://www.aasopenresearch.org  AAS Open Research         <NA>
#
#         publication_year date_created relations_json version_label  \
# 2121895             None   2022-03-25           None          None
#
#         is_version_of is_preprint_of has_preprint has_review  \
# 2121895
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 2121895                 false                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 2121895           None                   None               NaN
#
#                            landing_norm             doi_norm version_token_lp  \
# 2121895  http://www.aasopenresearch.org  10.12688/aasopenres             None
#
#         token_kind_lp  vnum_lp version_token_doi token_kind_doi  vnum_doi
# 2121895          None      NaN              None           None       NaN

# %%
df_remain[df_remain['server_name']=='AMRC Open Research']
# Out:
#                           record_id         server_name   backend  \
# 178  crossref::10.12688/amrcopenres  AMRC Open Research  crossref
#
#                       doi                               doi_url  \
# 178  10.12688/amrcopenres  https://doi.org/10.12688/amrcopenres
#
#                     landing_page_url               title authors_flat  \
# 178  http://www.amrcopenresearch.org  AMRC Open Research         <NA>
#
#     publication_year date_created relations_json version_label is_version_of  \
# 178             None   2019-02-19           None          None
#
#     is_preprint_of has_preprint has_review has_published_version  \
# 178                                                        false
#
#     published_version_ids_json version_of_ids_json update_to_json  \
# 178                       None                None           None
#
#     raw_relationships_json records_hierarchy                     landing_norm  \
# 178                   None               NaN  http://www.amrcopenresearch.org
#
#                  doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 178  10.12688/amrcopenres             None          None      NaN
#
#     version_token_doi token_kind_doi  vnum_doi
# 178              None           None       NaN

# %%
df_remain[df_remain['server_name']=='MNI Open Research']
# Out:
#                              record_id        server_name   backend  \
# 2013305  crossref::10.12688/mniopenres  MNI Open Research  crossref
#
#                          doi                              doi_url  \
# 2013305  10.12688/mniopenres  https://doi.org/10.12688/mniopenres
#
#                        landing_page_url              title authors_flat  \
# 2013305  http://www.mniopenresearch.org  MNI Open Research         <NA>
#
#         publication_year date_created relations_json version_label  \
# 2013305             None   2021-06-21           None          None
#
#         is_version_of is_preprint_of has_preprint has_review  \
# 2013305
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 2013305                 false                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 2013305           None                   None               NaN
#
#                            landing_norm             doi_norm version_token_lp  \
# 2013305  http://www.mniopenresearch.org  10.12688/mniopenres             None
#
#         token_kind_lp  vnum_lp version_token_doi token_kind_doi  vnum_doi
# 2013305          None      NaN              None           None       NaN

# %%
df_remain[df_remain['server_name']=='Gates Open Research']
# Out:
#                               record_id          server_name   backend  \
# 590205  crossref::10.12688/gatesopenres  Gates Open Research  crossref
#
#                           doi                                doi_url  \
# 590205  10.12688/gatesopenres  https://doi.org/10.12688/gatesopenres
#
#                         landing_page_url                title authors_flat  \
# 590205  http://www.gatesopenresearch.org  Gates Open Research         <NA>
#
#        publication_year date_created relations_json version_label  \
# 590205             None   2017-11-06           None          None
#
#        is_version_of is_preprint_of has_preprint has_review  \
# 590205
#
#        has_published_version published_version_ids_json version_of_ids_json  \
# 590205                 false                       None                None
#
#        update_to_json raw_relationships_json records_hierarchy  \
# 590205           None                   None               NaN
#
#                             landing_norm               doi_norm  \
# 590205  http://www.gatesopenresearch.org  10.12688/gatesopenres
#
#        version_token_lp token_kind_lp  vnum_lp version_token_doi  \
# 590205             None          None      NaN              None
#
#        token_kind_doi  vnum_doi
# 590205           None       NaN

# %%
df_remain[df_remain['server_name']=='eLife']
# Out:
#                        record_id server_name   backend            doi  \
# 9130897  crossref::10.7554/elife       eLife  crossref  10.7554/elife
#
#                                doi_url            landing_page_url  title  \
# 9130897  https://doi.org/10.7554/elife  https://elifesciences.org/  eLife
#
#         authors_flat publication_year date_created relations_json  \
# 9130897         <NA>             None   2017-07-25           None
#
#         version_label is_version_of is_preprint_of has_preprint has_review  \
# 9130897          None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 9130897                 false                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 9130897           None                   None               NaN
#
#                        landing_norm       doi_norm version_token_lp  \
# 9130897  https://elifesciences.org/  10.7554/elife             None
#
#         token_kind_lp  vnum_lp version_token_doi token_kind_doi  vnum_doi
# 9130897          None      NaN              None           None       NaN

# %%
import pandas as pd

# Normalize DOI strings:
# - lower case
# - strip spaces
# - collapse accidental double slashes after the prefix (10.3410// -> 10.3410/)
doi_s = (
    df["doi"]
    .astype(str)
    .str.strip()
    .str.lower()
    .str.replace(r"^10\.3410//", "10.3410/", regex=True)
)

# ------------------------------------------------------------
# F1000Research
# We support TWO DOI "families" that exist in your data:
#
# A) 10.12688/f1000research[.<id>.<N>]
#    - root: 10.12688/f1000research            -> parent
#    - versioned: 10.12688/f1000research.11198.1 -> parent
#                 10.12688/f1000research.11198.2 -> child
#
# B) 10.3410/f1000research.<something>.vN
#    - 10.3410/f1000research.1-29.v1 -> parent
#    - 10.3410/f1000research.1-29.v2 -> child
#    - 10.3410/f1000research.2-72.v1 -> parent
# ------------------------------------------------------------
mask_f1000 = (
    df["records_hierarchy"].isna()
    & (df["server_name"] == "F1000Research")
)

# -------------------------
# Case A: 10.12688 root DOI
# -------------------------
mask_f1000_root = mask_f1000 & doi_s.eq("10.12688/f1000research")
df.loc[mask_f1000_root, "records_hierarchy"] = "parent"

# -----------------------------------------------
# Case A2: 10.12688/f1000research.<digits>.<N>
# -----------------------------------------------
f1000_v12688_str = (
    doi_s.where(mask_f1000)
         .str.extract(r"^10\.12688/f1000research\.\d+\.(?P<v>\d+)$")["v"]
)
f1000_v12688 = pd.to_numeric(f1000_v12688_str, errors="coerce")

mask_f1000_12688_parent = mask_f1000 & (f1000_v12688 == 1)
df.loc[mask_f1000_12688_parent, "records_hierarchy"] = "parent"

mask_f1000_12688_child = mask_f1000 & (f1000_v12688 >= 2)
df.loc[mask_f1000_12688_child, "records_hierarchy"] = "child"

# -----------------------------------------
# Case B: 10.3410/f1000research.<...>.vN
# - accept things like: 1-29, 2-72, 1-50, etc.
# - also accept possible extra dots inside the middle part
# -----------------------------------------
f1000_v3410_str = (
    doi_s.where(mask_f1000)
         .str.extract(r"^10\.3410/f1000research\.[a-z0-9.\-]+\.v(?P<v>\d+)$")["v"]
)
f1000_v3410 = pd.to_numeric(f1000_v3410_str, errors="coerce")

mask_f1000_3410_parent = mask_f1000 & (f1000_v3410 == 1)
df.loc[mask_f1000_3410_parent, "records_hierarchy"] = "parent"

mask_f1000_3410_child = mask_f1000 & (f1000_v3410 >= 2)
df.loc[mask_f1000_3410_child, "records_hierarchy"] = "child"

# -------------------------
# Optional: remaining -> others
# -------------------------
mask_f1000_left = mask_f1000 & df["records_hierarchy"].isna()
df.loc[mask_f1000_left, "records_hierarchy"] = "others"

# Quick check
print(df.loc[df["server_name"] == "F1000Research", "records_hierarchy"].value_counts(dropna=False))
# Out:
# records_hierarchy
# parent     11162
# version     5704
# others         7
# Name: count, dtype: int64

# %%
# Normalize DOI (same style you already use)
doi_s = df["doi"].astype(str).str.strip().str.lower()

# Only touch rows not yet labeled
mask_unlabeled = df["records_hierarchy"].isna()

# Root DOIs you want to classify as "others"
ROOT_OTHERS_DOIS = {
    "10.7554/elife",
    "10.12688/gatesopenres",
    "10.12688/mniopenres",
    "10.12688/amrcopenres",
    "10.12688/aasopenres",
}

mask_root_others = mask_unlabeled & doi_s.isin(ROOT_OTHERS_DOIS)
df.loc[mask_root_others, "records_hierarchy"] = "others"

# %%
# -------------------------------------------------------------------
# Optional sanity check:
# Show distribution of hierarchy labels
# -------------------------------------------------------------------
print(df['records_hierarchy'].value_counts(dropna=False))
# Out:
# records_hierarchy
# parent              7967131
# review               175443
# part_of              149462
# version              105984
# publish_version        9351
# child                  2028
# correction              355
# comment                 325
# others                   12
# parent_duplicate          3
# Name: count, dtype: int64

# %%
pattern = "others"


mask = df['records_hierarchy'].str.contains(pattern, regex=False, na=False)
result = df[mask]
result
# Out:
#                                               record_id           server_name  \
# 2121895                   crossref::10.12688/aasopenres  Open Research Africa
# 178                      crossref::10.12688/amrcopenres    AMRC Open Research
# 590205                  crossref::10.12688/gatesopenres   Gates Open Research
# 2013305                   crossref::10.12688/mniopenres     MNI Open Research
# 572211   crossref::10.3410/10.3410/f1000devtestarticley         F1000Research
# 572499                        crossref::10.3410/123.430         F1000Research
# 572210           crossref::10.3410/f1000devtestarticlez         F1000Research
# 572209    crossref::10.3410/f1000devtestcrossmarkpolicy         F1000Research
# 572212                       crossref::10.3410/f1000res         F1000Research
# 572214                  crossref::10.3410/f1000research         F1000Research
# 572500         crossref::10.3410/http://www.someurl.com         F1000Research
# 9130897                         crossref::10.7554/elife                 eLife
#
#           backend                                   doi  \
# 2121895  crossref                   10.12688/aasopenres
# 178      crossref                  10.12688/amrcopenres
# 590205   crossref                 10.12688/gatesopenres
# 2013305  crossref                   10.12688/mniopenres
# 572211   crossref  10.3410/10.3410/f1000devtestarticley
# 572499   crossref                       10.3410/123.430
# 572210   crossref          10.3410/f1000devtestarticlez
# 572209   crossref   10.3410/f1000devtestcrossmarkpolicy
# 572212   crossref                      10.3410/f1000res
# 572214   crossref                 10.3410/f1000research
# 572500   crossref        10.3410/http://www.someurl.com
# 9130897  crossref                         10.7554/elife
#
#                                                    doi_url  \
# 2121895                https://doi.org/10.12688/aasopenres
# 178                   https://doi.org/10.12688/amrcopenres
# 590205               https://doi.org/10.12688/gatesopenres
# 2013305                https://doi.org/10.12688/mniopenres
# 572211   https://doi.org/10.3410/10.3410/f1000devtestar...
# 572499                     https://doi.org/10.3410/123.430
# 572210        https://doi.org/10.3410/f1000devtestarticlez
# 572209   https://doi.org/10.3410/f1000devtestcrossmarkp...
# 572212                    https://doi.org/10.3410/f1000res
# 572214               https://doi.org/10.3410/f1000research
# 572500      https://doi.org/10.3410/http://www.someurl.com
# 9130897                      https://doi.org/10.7554/elife
#
#                                           landing_page_url  \
# 2121895                     http://www.aasopenresearch.org
# 178                        http://www.amrcopenresearch.org
# 590205                    http://www.gatesopenresearch.org
# 2013305                     http://www.mniopenresearch.org
# 572211                           http://www.xy.net/article
# 572499                              http://www.someURl.com
# 572210   http://researchdev.f1000.com/articles/F1000Dev...
# 572209                                            resource
# 572212                                           2046-1402
# 572214                       http://www.f1000research.com/
# 572500                              http://www.someURl.com
# 9130897                         https://elifesciences.org/
#
#                                title        authors_flat publication_year  \
# 2121895            AAS Open Research                <NA>             None
# 178               AMRC Open Research                <NA>             None
# 590205           Gates Open Research                <NA>             None
# 2013305            MNI Open Research                <NA>             None
# 572211                     someTitle         abcde, XXXX           2012.0
# 572499                     someTitle  someName, someName           2009.0
# 572210          F1000DevTestArticleZ  LNameZ, firstnameZ           2012.0
# 572209   F1000DevTestCrossMarkPolicy     Manager, Policy           2012.0
# 572212                F1000 Research                <NA>             None
# 572214                 F1000Research                <NA>             None
# 572500                     someTitle  someName, someName           2009.0
# 9130897                        eLife                <NA>             None
#
#         date_created relations_json version_label is_version_of  \
# 2121895   2022-03-25           None          None
# 178       2019-02-19           None          None
# 590205    2017-11-06           None          None
# 2013305   2021-06-21           None          None
# 572211    2012-06-11           None          None
# 572499    2012-09-13           None          None
# 572210    2012-06-07           None          None
# 572209    2012-05-31           None          None
# 572212    2013-03-05           None          None
# 572214    2013-05-09           None          None
# 572500    2012-09-13           None          None
# 9130897   2017-07-25           None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 2121895                                                        false
# 178                                                            false
# 590205                                                         false
# 2013305                                                        false
# 572211                                                         false
# 572499                                                         false
# 572210                                                         false
# 572209                                                         false
# 572212                                                         false
# 572214                                                         false
# 572500                                                         false
# 9130897                                                        false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 2121895                       None                None           None
# 178                           None                None           None
# 590205                        None                None           None
# 2013305                       None                None           None
# 572211                        None                None           None
# 572499                        None                None           None
# 572210                        None                None           None
# 572209                        None                None           None
# 572212                        None                None           None
# 572214                        None                None           None
# 572500                        None                None           None
# 9130897                       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 2121895                   None            others
# 178                       None            others
# 590205                    None            others
# 2013305                   None            others
# 572211                    None            others
# 572499                    None            others
# 572210                    None            others
# 572209                    None            others
# 572212                    None            others
# 572214                    None            others
# 572500                    None            others
# 9130897                   None            others
#
#                                               landing_norm  \
# 2121895                     http://www.aasopenresearch.org
# 178                        http://www.amrcopenresearch.org
# 590205                    http://www.gatesopenresearch.org
# 2013305                     http://www.mniopenresearch.org
# 572211                           http://www.xy.net/article
# 572499                              http://www.someurl.com
# 572210   http://researchdev.f1000.com/articles/f1000dev...
# 572209                                            resource
# 572212                                           2046-1402
# 572214                       http://www.f1000research.com/
# 572500                              http://www.someurl.com
# 9130897                         https://elifesciences.org/
#
#                                      doi_norm version_token_lp token_kind_lp  \
# 2121895                   10.12688/aasopenres             None          None
# 178                      10.12688/amrcopenres             None          None
# 590205                  10.12688/gatesopenres             None          None
# 2013305                   10.12688/mniopenres             None          None
# 572211   10.3410/10.3410/f1000devtestarticley             None          None
# 572499                        10.3410/123.430             None          None
# 572210           10.3410/f1000devtestarticlez             None          None
# 572209    10.3410/f1000devtestcrossmarkpolicy             None          None
# 572212                       10.3410/f1000res             None          None
# 572214                  10.3410/f1000research             None          None
# 572500         10.3410/http://www.someurl.com             None          None
# 9130897                         10.7554/elife             None          None
#
#          vnum_lp version_token_doi token_kind_doi  vnum_doi
# 2121895      NaN              None           None       NaN
# 178          NaN              None           None       NaN
# 590205       NaN              None           None       NaN
# 2013305      NaN              None           None       NaN
# 572211       NaN              None           None       NaN
# 572499       NaN              None           None       NaN
# 572210       NaN              None           None       NaN
# 572209       NaN              None           None       NaN
# 572212       NaN              None           None       NaN
# 572214       NaN              None           None       NaN
# 572500       NaN              None           None       NaN
# 9130897      NaN              None           None       NaN

# %%
df_remain = df[df['records_hierarchy'].isna()]
df_remain['server_name'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
# df_remain[df_remain['server_name']=='AgriRxiv']['landing_page_url'][207416]

# %%
# pattern = "others"


# mask = df[df['server_name']=='F1000Research']['records_hierarchy'].str.contains(pattern, regex=False, na=False)
# result = df[df['server_name']=='F1000Research'][mask]
# result

# %%
# df_remain['landing_page_url'][286254]

# %%
# pattern = ".1"


# mask = df[df['server_name']=='eLife']['doi'].str.contains(pattern, regex=False, na=False)
# result = df[df['server_name']=='eLife'][mask]
# result

# %%
# result['landing_page_url'][9366338]

# %%
# result['landing_page_url'][9297794]

# %%
# pattern = "10.7287/peerj.preprints.999"
# #video #media 

# mask = df['doi'].str.contains(pattern, regex=False, na=False)
# result = df[mask]
# result

# %%
# df_remain['relations_json'].value_counts()

# %%
# df_remain[df_remain['relations_json']=='{"is-preprint-of": [{"asserted-by": "subject", "id": "10.31237/osf.io/yr86k", "id-type": "doi"}]}']

# %% [markdown]
# ## Check duplicates in secondary preprint repositories

# %% [markdown]
# ### get list of accros server

# %%
import pandas as pd

# ============================================================
# Goal
# ============================================================
# Read the "rules" Google Sheet and extract a list of servers
# that are marked as primary sources.
#
# In the sheet:
# - Column "Field_server_name" contains the server name
# - Column "primary_source" contains "yes" for primary servers
#
# Output:
# - unique_servers: Python list of server names marked as primary
# ============================================================


# ============================================================
# 1) Read the Google Sheet tab as CSV
# ============================================================
# Google Sheets can be exported as CSV if the sheet is public
# (or shared with link access).
# You need:
# - SHEET_ID: the spreadsheet ID
# - GID: the tab id (worksheet id)
SHEET_ID = "10_7FdcpZjntqFsEHIii7bAM72uF__of_iUohSD5w8w4"
GID = "1230415212"  # tab gid for the rules sheet

# Build the CSV export URL
rules_csv_url = f"https://docs.google.com/spreadsheets/d/{SHEET_ID}/export?format=csv&gid={GID}"

# Read the rules table into a DataFrame
rules = pd.read_csv(rules_csv_url)


# ============================================================
# 2) Normalize column names
# ============================================================
# Sheets sometimes contain extra spaces/newlines in column headers.
# This normalizes them to reduce "column not found" errors.
rules.columns = (
    rules.columns.astype(str)
    .str.replace(r"\s+", " ", regex=True)  # collapse multiple spaces/newlines into 1 space
    .str.strip()                           # remove leading/trailing spaces
)


# ============================================================
# 3) Define which columns we rely on
# ============================================================
# SERVER_COL: server name column
# FLAG_COL: column marking primary servers ("yes")
SERVER_COL = "Field_server_name"
FLAG_COL = "primary_source"


# ============================================================
# 4) Safety check: make sure expected columns exist
# ============================================================
# If the sheet changes (renamed columns, etc.), we fail early with a helpful message.
if SERVER_COL not in rules.columns or FLAG_COL not in rules.columns:
    print("Columns available in the sheet:", rules.columns.tolist())
    raise KeyError(f"Expected columns not found. Need: {SERVER_COL!r} and {FLAG_COL!r}")


# ============================================================
# 5) Extract primary servers (where primary_source == "yes")
# ============================================================
# Steps:
# - normalize the flag column to text
# - strip spaces, lowercase
# - keep rows where value == "yes"
# - take the server names
# - drop missing names
# - strip spaces
# - keep unique values
primary_servers = (
    rules.loc[
        rules[FLAG_COL].astype(str).str.strip().str.lower().eq("yes"),
        SERVER_COL
    ]
    .dropna()                 # remove missing server names
    .astype(str)
    .str.strip()              # normalize server name text
    .unique()                 # keep distinct values only
    .tolist()                 # convert numpy array to normal Python list
)


# ============================================================
# 6) Quick preview
# ============================================================
print(f"Primary servers found: {len(primary_servers)}")
print(primary_servers[:30])  # show first 30 as a preview
# Out:
# Primary servers found: 73
# ['arXiv', 'SSRN', 'Research Square', 'bioRxiv', 'Preprints.org', 'Open Science Framework', 'Zenodo', 'medRxiv', 'Authorea Inc.', 'PsyArXiv', 'ChemRxiv', 'JMIR Preprints', 'AgEcon Search', 'TechRxiv', 'SocArXiv', 'Earth and Space Science Open Archive', 'INA-Rxiv', 'eLife', 'EarthArXiv', 'PeerJ Preprints', 'Nature Precedings', 'engrXiv', 'Advance', 'Thesis Commons', 'Cambridge Open Engage', 'EcoEvoRxiv', 'EdArXiv', 'ScienceOpen Preprints', 'Law Archive', 'APSA Preprints']

# %%
set(primary_servers[:5])
# Out:
# {'Preprints.org', 'Research Square', 'SSRN', 'arXiv', 'bioRxiv'}

# %% [markdown]
# ### doi

# %%
df_mirror = df.copy()

# %%
df_touse = df_mirror[df_mirror['doi'].notna()].copy()
df_touse
# Out:
#                                    record_id  \
# 429739   crossref::10.1002/essoar.10500000.1
# 429742   crossref::10.1002/essoar.10500002.1
# 429740   crossref::10.1002/essoar.10500004.1
# 429741   crossref::10.1002/essoar.10500007.1
# 429746   crossref::10.1002/essoar.10500009.1
# ...                                      ...
# 5667066                 openalex::W999063011
# 2245001                  openalex::W99945665
# 5667173                 openalex::W999508398
# 5673122                 openalex::W999509321
# 3149046                  openalex::W99988875
#
#                                    server_name   backend  \
# 429739    Earth and Space Science Open Archive  crossref
# 429742    Earth and Space Science Open Archive  crossref
# 429740    Earth and Space Science Open Archive  crossref
# 429741    Earth and Space Science Open Archive  crossref
# 429746    Earth and Space Science Open Archive  crossref
# ...                                        ...       ...
# 5667066  Social Science Open Access Repository  openalex
# 2245001                        Organic Eprints  openalex
# 5667173  Social Science Open Access Repository  openalex
# 5673122  Social Science Open Access Repository  openalex
# 3149046    RePEc: Research Papers in Economics  openalex
#
#                                   doi  \
# 429739      10.1002/essoar.10500000.1
# 429742      10.1002/essoar.10500002.1
# 429740      10.1002/essoar.10500004.1
# 429741      10.1002/essoar.10500007.1
# 429746      10.1002/essoar.10500009.1
# ...                               ...
# 5667066      10.15464/isi.42.2009.1-5
# 2245001         10.3220/rep_20_1_2014
# 5667173      10.15464/isi.38.2007.1-5
# 5673122  10.23668/psycharchives.13440
# 3149046     10.13140/rg.2.1.1218.2166
#
#                                               doi_url  \
# 429739      https://doi.org/10.1002/essoar.10500000.1
# 429742      https://doi.org/10.1002/essoar.10500002.1
# 429740      https://doi.org/10.1002/essoar.10500004.1
# 429741      https://doi.org/10.1002/essoar.10500007.1
# 429746      https://doi.org/10.1002/essoar.10500009.1
# ...                                               ...
# 5667066      https://doi.org/10.15464/isi.42.2009.1-5
# 2245001         https://doi.org/10.3220/rep_20_1_2014
# 5667173      https://doi.org/10.15464/isi.38.2007.1-5
# 5673122  https://doi.org/10.23668/psycharchives.13440
# 3149046     https://doi.org/10.13140/rg.2.1.1218.2166
#
#                                           landing_page_url  \
# 429739   https://essopenarchive.org/doi/full/10.1002/es...
# 429742   https://essopenarchive.org/doi/full/10.1002/es...
# 429740   https://essopenarchive.org/doi/full/10.1002/es...
# 429741   https://essopenarchive.org/doi/full/10.1002/es...
# 429746   https://essopenarchive.org/doi/full/10.1002/es...
# ...                                                    ...
# 5667066  http://www.ssoar.info/ssoar/handle/document/21392
# 2245001              https://doi.org/10.3220/rep_20_1_2014
# 5667173  http://www.ssoar.info/ssoar/handle/document/21635
# 5673122   http://www.ssoar.info/ssoar/handle/document/3368
# 3149046       https://ideas.repec.org/p/guc/wpaper/36.html
#
#                                                      title  \
# 429739   Long-term monitoring of land surface phenologi...
# 429742   Impact of spatial scale for phenological indic...
# 429740   Observations of Low Latitude Red Aurora in Mex...
# 429741   Pipeline oil fire detection with MODIS active ...
# 429746   Land Product Validation of MODIS Derived FPAR ...
# ...                                                    ...
# 5667066  Jeder fünfte Erwerbstätige ist aus beruflichen...
# 2245001  Earthworm abundance and species richness: Cont...
# 5667173  Berufstätigkeit von Müttern bleibt kontrovers:...
# 5673122  Rezension: Edward Timms (Hg.), Freud und das K...
# 3149046  Ration Cards in Egypt Targeting, Leakage, and ...
#
#                                               authors_flat publication_year  \
# 429739                                Tsutsumida, Narumasa           2018.0
# 429742                   Tsutsumida, Narumasa; Kaduk, Jörg           2018.0
# 429740   Gonzalez-Esparza, J. Americo; Cuevas-Cardona, ...           2018.0
# 429741   Ogungbuyi, Michael Gbenga; Martinez, Peter; Ec...           2018.0
# 429746   Sharp, Iain; Sanchez-Azofeifa, Arturo; Musilek...           2018.0
# ...                                                    ...              ...
# 5667066                     Silvia Ruppenthal; Detlev Lück           2009.0
# 2245001  Anna-Sophie Köhler; Julia Huber; Sebastian Wol...           2014.0
# 5667173                    Angelika Scheuer; Jörg Dittmann           2007.0
# 5673122                                   Wolfgang Hegener           1997.0
# 3149046                                 Hebatallah Ghoneim           2013.0
#
#                 date_created  \
# 429739            2019-11-13
# 429742            2019-11-13
# 429740            2019-11-13
# 429741            2019-11-13
# 429746            2019-12-03
# ...                      ...
# 5667066  2025-10-10T00:00:00
# 2245001  2025-10-10T00:00:00
# 5667173  2025-10-10T00:00:00
# 5673122  2025-10-10T00:00:00
# 3149046  2025-10-10T00:00:00
#
#                                             relations_json version_label  \
# 429739                                                None          None
# 429742                                                None          None
# 429740   {"is-preprint-of": [{"asserted-by": "subject",...          None
# 429741                                                None          None
# 429746                                                None          None
# ...                                                    ...           ...
# 5667066                                               None          None
# 2245001                                               None          None
# 5667173                                               None          None
# 5673122                                               None          None
# 3149046                                               None          None
#
#         is_version_of                             is_preprint_of has_preprint  \
# 429739
# 429742
# 429740                 10.1029/2017sw001789;10.1029/2018sw001995
# 429741
# 429746
# ...               ...                                        ...          ...
# 5667066          None                                       None         None
# 2245001          None                                       None         None
# 5667173          None                                       None         None
# 5673122          None                                       None         None
# 3149046          None                                       None         None
#
#         has_review has_published_version published_version_ids_json  \
# 429739                             false                       None
# 429742                             false                       None
# 429740                              true                       None
# 429741                             false                       None
# 429746                             false                       None
# ...            ...                   ...                        ...
# 5667066       None                  None                       None
# 2245001       None                  None                       None
# 5667173       None                  None                       None
# 5673122       None                  None                       None
# 3149046       None                  None                       None
#
#         version_of_ids_json update_to_json raw_relationships_json  \
# 429739                 None           None                   None
# 429742                 None           None                   None
# 429740                 None           None                   None
# 429741                 None           None                   None
# 429746                 None           None                   None
# ...                     ...            ...                    ...
# 5667066                None           None                   None
# 2245001                None           None                   None
# 5667173                None           None                   None
# 5673122                None           None                   None
# 3149046                None           None                   None
#
#         records_hierarchy                                       landing_norm  \
# 429739             parent  https://essopenarchive.org/doi/full/10.1002/es...
# 429742             parent  https://essopenarchive.org/doi/full/10.1002/es...
# 429740             parent  https://essopenarchive.org/doi/full/10.1002/es...
# 429741             parent  https://essopenarchive.org/doi/full/10.1002/es...
# 429746             parent  https://essopenarchive.org/doi/full/10.1002/es...
# ...                   ...                                                ...
# 5667066            parent  http://www.ssoar.info/ssoar/handle/document/21392
# 2245001            parent              https://doi.org/10.3220/rep_20_1_2014
# 5667173            parent  http://www.ssoar.info/ssoar/handle/document/21635
# 5673122            parent   http://www.ssoar.info/ssoar/handle/document/3368
# 3149046            parent       https://ideas.repec.org/p/guc/wpaper/36.html
#
#                              doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 429739      10.1002/essoar.10500000.1             None          None      NaN
# 429742      10.1002/essoar.10500002.1             None          None      NaN
# 429740      10.1002/essoar.10500004.1             None          None      NaN
# 429741      10.1002/essoar.10500007.1             None          None      NaN
# 429746      10.1002/essoar.10500009.1             None          None      NaN
# ...                               ...              ...           ...      ...
# 5667066      10.15464/isi.42.2009.1-5             None          None      NaN
# 2245001         10.3220/rep_20_1_2014             None          None      NaN
# 5667173      10.15464/isi.38.2007.1-5             None          None      NaN
# 5673122  10.23668/psycharchives.13440             None          None      NaN
# 3149046     10.13140/rg.2.1.1218.2166             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 429739               None           None       NaN
# 429742               None           None       NaN
# 429740               None           None       NaN
# 429741               None           None       NaN
# 429746               None           None       NaN
# ...                   ...            ...       ...
# 5667066              None           None       NaN
# 2245001              None           None       NaN
# 5667173              None           None       NaN
# 5673122              None           None       NaN
# 3149046              None           None       NaN
#
# [6784859 rows x 30 columns]

# %%
dupes = df_touse[df_touse.duplicated(subset=['doi'], keep=False)]
dupes
# Out:
#                                    record_id  \
# 8976641             crossref::10.1101/103937
# 9073833  crossref::10.1101/2019.12.23.887166
# 8986959  crossref::10.1101/2020.01.22.915215
# 8981770  crossref::10.1101/2020.02.03.919597
# 8891397  crossref::10.1101/2020.06.08.118984
# ...                                      ...
# 9486788                 openalex::W983039221
# 2806374                 openalex::W985302891
# 2817765                 openalex::W986721525
# 9486875                 openalex::W998010466
# 2245001                  openalex::W99945665
#
#                                  server_name   backend  \
# 8976641                              bioRxiv  crossref
# 9073833                              bioRxiv  crossref
# 8986959                              bioRxiv  crossref
# 8981770                              bioRxiv  crossref
# 8891397                              bioRxiv  crossref
# ...                                      ...       ...
# 9486788                                viXra  openalex
# 2806374  RePEc: Research Papers in Economics  openalex
# 2817765  RePEc: Research Papers in Economics  openalex
# 9486875                                viXra  openalex
# 2245001                      Organic Eprints  openalex
#
#                                  doi  \
# 8976641               10.1101/103937
# 9073833    10.1101/2019.12.23.887166
# 8986959    10.1101/2020.01.22.915215
# 8981770    10.1101/2020.02.03.919597
# 8891397    10.1101/2020.06.08.118984
# ...                              ...
# 9486788  10.13140/rg.2.2.29266.79041
# 2806374      10.22004/ag.econ.133088
# 2817765      10.22004/ag.econ.196816
# 9486875  10.13140/rg.2.2.36331.69924
# 2245001        10.3220/rep_20_1_2014
#
#                                              doi_url  \
# 8976641               https://doi.org/10.1101/103937
# 9073833    https://doi.org/10.1101/2019.12.23.887166
# 8986959    https://doi.org/10.1101/2020.01.22.915215
# 8981770    https://doi.org/10.1101/2020.02.03.919597
# 8891397    https://doi.org/10.1101/2020.06.08.118984
# ...                                              ...
# 9486788  https://doi.org/10.13140/rg.2.2.29266.79041
# 2806374      https://doi.org/10.22004/ag.econ.133088
# 2817765      https://doi.org/10.22004/ag.econ.196816
# 9486875  https://doi.org/10.13140/rg.2.2.36331.69924
# 2245001        https://doi.org/10.3220/rep_20_1_2014
#
#                                           landing_page_url  \
# 8976641       http://biorxiv.org/lookup/doi/10.1101/103937
# 9073833  http://biorxiv.org/lookup/doi/10.1101/2019.12....
# 8986959  http://biorxiv.org/lookup/doi/10.1101/2020.01....
# 8981770  http://biorxiv.org/lookup/doi/10.1101/2020.02....
# 8891397  http://biorxiv.org/lookup/doi/10.1101/2020.06....
# ...                                                    ...
# 9486788           http://www.vixra.org/pdf/1503.0004v1.pdf
# 2806374  https://ageconsearch.umn.edu/record/133088/fil...
# 2817765  https://ageconsearch.umn.edu/record/196816/fil...
# 9486875              https://vixra.org/pdf/1409.0185v1.pdf
# 2245001              https://doi.org/10.3220/rep_20_1_2014
#
#                                                      title  \
# 8976641  LET-99-dependent spatial restriction of active...
# 9073833  Model balancing: in search of consistent metab...
# 8986959  Not only compulsivity: The SAPAP3-KO mouse rec...
# 8981770  Germline inherited small RNAs clear untranslat...
# 8891397  TBPL2/TFIIA complex establishes the maternal t...
# ...                                                    ...
# 9486788  Ionization chamber noise fluctuations during l...
# 2806374     Farmland price bubbles: wavelet-based evidence
# 2817765  Assessing the Value of Broadband Connectivity ...
# 9486875  TGD view about homeopathy, water memory, and e...
# 2245001  Earthworm abundance and species richness: Cont...
#
#                                               authors_flat publication_year  \
# 8976641  Bouvrais, H.; Chesneau, L.; Pastezeur, S.; Del...           2017.0
# 9073833                 Liebermeister, Wolfram; Noor, Elad           2019.0
# 8986959  Lamothe, H; Schreiweis, C; Lavielle, O; Mallet...           2020.0
# 8981770  Quarato, Piergiuseppe; Singh, Meetali; Cornes,...           2020.0
# 8891397  Yu, Changwei; Cvetesic, Nevena; Hisler, Vincen...           2020.0
# ...                                                    ...              ...
# 9486788  A. D. Skorbun; M. V. Efetov; G. I. Odinokin; O...           2020.0
# 2806374                  Gabriel J. Power; Calum G. Turvey           2006.0
# 2817765       Tyler Mark; Brian E. Whitacre; Terry Griffin           2015.0
# 9486875                                     Matti Pitkänen           2014.0
# 2245001  Anna-Sophie Köhler; Julia Huber; Sebastian Wol...           2014.0
#
#                 date_created  \
# 8976641           2017-01-29
# 9073833           2019-12-24
# 8986959           2020-01-23
# 8981770           2020-02-04
# 8891397           2020-06-09
# ...                      ...
# 9486788  2025-10-10T00:00:00
# 2806374  2025-10-10T00:00:00
# 2817765  2025-10-10T00:00:00
# 9486875  2025-10-10T00:00:00
# 2245001  2025-10-10T00:00:00
#
#                                             relations_json version_label  \
# 8976641                                               None          None
# 9073833  {"is-preprint-of": [{"asserted-by": "subject",...          None
# 8986959                                               None          None
# 8981770                                               None          None
# 8891397  {"is-preprint-of": [{"asserted-by": "subject",...          None
# ...                                                    ...           ...
# 9486788                                               None          None
# 2806374                                               None          None
# 2817765                                               None          None
# 9486875                                               None          None
# 2245001                                               None          None
#
#         is_version_of              is_preprint_of has_preprint has_review  \
# 8976641
# 9073833                    10.3390/metabo11110749
# 8986959
# 8981770
# 8891397                10.1038/s41467-020-20239-4
# ...               ...                         ...          ...        ...
# 9486788          None                        None         None       None
# 2806374          None                        None         None       None
# 2817765          None                        None         None       None
# 9486875          None                        None         None       None
# 2245001          None                        None         None       None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 8976641                 false                       None                None
# 9073833                  true                       None                None
# 8986959                 false                       None                None
# 8981770                 false                       None                None
# 8891397                  true                       None                None
# ...                       ...                        ...                 ...
# 9486788                  None                       None                None
# 2806374                  None                       None                None
# 2817765                  None                       None                None
# 9486875                  None                       None                None
# 2245001                  None                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 8976641           None                   None            parent
# 9073833           None                   None            parent
# 8986959           None                   None            parent
# 8981770           None                   None            parent
# 8891397           None                   None            parent
# ...                ...                    ...               ...
# 9486788           None                   None            parent
# 2806374           None                   None            parent
# 2817765           None                   None            parent
# 9486875           None                   None            parent
# 2245001           None                   None            parent
#
#                                               landing_norm  \
# 8976641       http://biorxiv.org/lookup/doi/10.1101/103937
# 9073833  http://biorxiv.org/lookup/doi/10.1101/2019.12....
# 8986959  http://biorxiv.org/lookup/doi/10.1101/2020.01....
# 8981770  http://biorxiv.org/lookup/doi/10.1101/2020.02....
# 8891397  http://biorxiv.org/lookup/doi/10.1101/2020.06....
# ...                                                    ...
# 9486788           http://www.vixra.org/pdf/1503.0004v1.pdf
# 2806374  https://ageconsearch.umn.edu/record/133088/fil...
# 2817765  https://ageconsearch.umn.edu/record/196816/fil...
# 9486875              https://vixra.org/pdf/1409.0185v1.pdf
# 2245001              https://doi.org/10.3220/rep_20_1_2014
#
#                             doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 8976641               10.1101/103937             None          None      NaN
# 9073833    10.1101/2019.12.23.887166             None          None      NaN
# 8986959    10.1101/2020.01.22.915215             None          None      NaN
# 8981770    10.1101/2020.02.03.919597             None          None      NaN
# 8891397    10.1101/2020.06.08.118984             None          None      NaN
# ...                              ...              ...           ...      ...
# 9486788  10.13140/rg.2.2.29266.79041             None          None      NaN
# 2806374      10.22004/ag.econ.133088             None          None      NaN
# 2817765      10.22004/ag.econ.196816             None          None      NaN
# 9486875  10.13140/rg.2.2.36331.69924             None          None      NaN
# 2245001        10.3220/rep_20_1_2014             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 8976641              None           None       NaN
# 9073833              None           None       NaN
# 8986959              None           None       NaN
# 8981770              None           None       NaN
# 8891397              None           None       NaN
# ...                   ...            ...       ...
# 9486788              None           None       NaN
# 2806374              None           None       NaN
# 2817765              None           None       NaN
# 9486875              None           None       NaN
# 2245001              None           None       NaN
#
# [34714 rows x 30 columns]

# %%
dupes['server_name'].value_counts()
# Out:
# server_name
# RePEc: Research Papers in Economics                                     10494
# arXiv                                                                    8236
# AgEcon Search                                                            6540
# HAL                                                                      4041
# ResearchGate                                                             1633
# DSpace@MIT                                                               1082
# viXra                                                                     826
# EconStor Preprints                                                        559
# Munich Personal RePEc Archive                                             443
# Zenodo                                                                    297
# PhilSci-Archive                                                           161
# IACR Cryptology ePrint Archive                                             91
# Digital Access to Scholarship at Harvard (DASH) (Harvard University)       68
# Organic Eprints                                                            46
# Open Science Framework                                                     31
# bioRxiv                                                                    29
# SSRN                                                                       29
# E-LIS Repository                                                           28
# Social Science Open Access Repository                                      24
# Humanities Commons CORE                                                    24
# CogPrints                                                                  14
# eLife                                                                       3
# Research Square                                                             2
# CERN document server                                                        2
# medRxiv                                                                     1
# Open Research Europe                                                        1
# SocArXiv                                                                    1
# Oroboros Instruments                                                        1
# Thesis Commons                                                              1
# TechRxiv                                                                    1
# Wellcome Open Research                                                      1
# AgriRxiv                                                                    1
# EarthArXiv                                                                  1
# Law Archive                                                                 1
# National Bureau of Economic Research                                        1
# Name: count, dtype: int64

# %%
dupes[dupes['server_name']=='ResearchGate']
# Out:
#                                      record_id   server_name   backend  \
# 3322080       datacite::10.13140/2.1.2328.2569  ResearchGate  datacite
# 3322083       datacite::10.13140/2.1.2910.4001  ResearchGate  datacite
# 3322151    datacite::10.13140/rg.2.1.1007.9848  ResearchGate  datacite
# 3322312    datacite::10.13140/rg.2.1.1103.1281  ResearchGate  datacite
# 3322200    datacite::10.13140/rg.2.1.1103.9445  ResearchGate  datacite
# ...                                        ...           ...       ...
# 3354289  datacite::10.13140/rg.2.2.36811.13607  ResearchGate  datacite
# 3332704  datacite::10.13140/rg.2.2.36825.57442  ResearchGate  datacite
# 3350078  datacite::10.13140/rg.2.2.36829.77284  ResearchGate  datacite
# 3463359  datacite::10.13140/rg.2.2.36831.37285  ResearchGate  datacite
# 3405608  datacite::10.13140/rg.2.2.36835.84009  ResearchGate  datacite
#
#                                  doi  \
# 3322080       10.13140/2.1.2328.2569
# 3322083       10.13140/2.1.2910.4001
# 3322151    10.13140/rg.2.1.1007.9848
# 3322312    10.13140/rg.2.1.1103.1281
# 3322200    10.13140/rg.2.1.1103.9445
# ...                              ...
# 3354289  10.13140/rg.2.2.36811.13607
# 3332704  10.13140/rg.2.2.36825.57442
# 3350078  10.13140/rg.2.2.36829.77284
# 3463359  10.13140/rg.2.2.36831.37285
# 3405608  10.13140/rg.2.2.36835.84009
#
#                                              doi_url  \
# 3322080       https://doi.org/10.13140/2.1.2328.2569
# 3322083       https://doi.org/10.13140/2.1.2910.4001
# 3322151    https://doi.org/10.13140/rg.2.1.1007.9848
# 3322312    https://doi.org/10.13140/rg.2.1.1103.1281
# 3322200    https://doi.org/10.13140/rg.2.1.1103.9445
# ...                                              ...
# 3354289  https://doi.org/10.13140/rg.2.2.36811.13607
# 3332704  https://doi.org/10.13140/rg.2.2.36825.57442
# 3350078  https://doi.org/10.13140/rg.2.2.36829.77284
# 3463359  https://doi.org/10.13140/rg.2.2.36831.37285
# 3405608  https://doi.org/10.13140/rg.2.2.36835.84009
#
#                                           landing_page_url  \
# 3322080  https://www.researchgate.net/doi/10.13140/2.1....
# 3322083  https://www.researchgate.net/doi/10.13140/2.1....
# 3322151  https://www.researchgate.net/doi/10.13140/RG.2...
# 3322312  https://www.researchgate.net/doi/10.13140/RG.2...
# 3322200  https://www.researchgate.net/doi/10.13140/RG.2...
# ...                                                    ...
# 3354289  https://www.researchgate.net/doi/10.13140/RG.2...
# 3332704  https://www.researchgate.net/doi/10.13140/RG.2...
# 3350078  https://www.researchgate.net/doi/10.13140/RG.2...
# 3463359  https://www.researchgate.net/doi/10.13140/RG.2...
# 3405608  https://www.researchgate.net/doi/10.13140/RG.2...
#
#                                                      title  \
# 3322080  Dirac-like equation and the excited states of ...
# 3322083  Polymer physics, the quantum harmonic oscillat...
# 3322151  classEx - an online software for classroom exp...
# 3322312  A TOPOLOGICAL BRAIN ELUCIDATES SYNTACTIC AND S...
# 3322200                              TIME AS A GAUGE FIELD
# ...                                                    ...
# 3354289  Concurrent Sourcing in Local Public Services: ...
# 3332704  The Effects of Education on Health: An Interge...
# 3350078       Non-Euclidean metric using Geometric Algebra
# 3463359  FERTILITY DYNAMICS IN SWEDEN, SPAIN, THE CZECH...
# 3405608  Clarification of the Relative Minimum Distance...
#
#                                               authors_flat publication_year  \
# 3322080                               Silva, Paulo Roberto           2014.0
# 3322083                                          P R Silva           2014.0
# 3322151         Giamattei, Marcus; Lambsdorff, Johann Graf           2015.0
# 3322312                     Tozzi, Arturo; Peters, James F           2016.0
# 3322200  Tozzi, Arturo; Chafin, Clifford; Falco, Domeni...           2015.0
# ...                                                    ...              ...
# 3354289                                     Porcher, Simon           2019.0
# 3332704                                  Huebener, Mathias           2018.0
# 3350078                                     Sánchez, Jesús           2019.0
# 3463359                        Soldan, Elena; Gagauz, Olga           2018.0
# 3405608                                     Valere Huypens           2022.0
#
#         date_created relations_json version_label is_version_of  \
# 3322080   2014-08-19             []          None
# 3322083   2014-08-27             []          None
# 3322151   2015-07-20             []          None
# 3322312   2016-08-09             []          None
# 3322200   2015-10-13             []          None
# ...              ...            ...           ...           ...
# 3354289   2019-12-13             []          None
# 3332704   2018-09-18             []          None
# 3350078   2019-09-20             []          None
# 3463359   2025-01-08             []          None
# 3405608   2022-07-20             []          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 3322080                                                        false
# 3322083                                                        false
# 3322151                                                        false
# 3322312                                                        false
# 3322200                                                        false
# ...                ...          ...        ...                   ...
# 3354289                                                        false
# 3332704                                                        false
# 3350078                                                        false
# 3463359                                                        false
# 3405608                                                        false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 3322080                       None                None           None
# 3322083                       None                None           None
# 3322151                       None                None           None
# 3322312                       None                None           None
# 3322200                       None                None           None
# ...                            ...                 ...            ...
# 3354289                       None                None           None
# 3332704                       None                None           None
# 3350078                       None                None           None
# 3463359                       None                None           None
# 3405608                       None                None           None
#
#                                     raw_relationships_json records_hierarchy  \
# 3322080  {"client": {"data": {"id": "rg.rg", "type": "c...            parent
# 3322083  {"client": {"data": {"id": "rg.rg", "type": "c...            parent
# 3322151  {"client": {"data": {"id": "rg.rg", "type": "c...            parent
# 3322312  {"client": {"data": {"id": "rg.rg", "type": "c...            parent
# 3322200  {"client": {"data": {"id": "rg.rg", "type": "c...            parent
# ...                                                    ...               ...
# 3354289  {"client": {"data": {"id": "rg.rg", "type": "c...            parent
# 3332704  {"client": {"data": {"id": "rg.rg", "type": "c...            parent
# 3350078  {"client": {"data": {"id": "rg.rg", "type": "c...            parent
# 3463359  {"client": {"data": {"id": "rg.rg", "type": "c...            parent
# 3405608  {"client": {"data": {"id": "rg.rg", "type": "c...            parent
#
#                                               landing_norm  \
# 3322080  https://www.researchgate.net/doi/10.13140/2.1....
# 3322083  https://www.researchgate.net/doi/10.13140/2.1....
# 3322151  https://www.researchgate.net/doi/10.13140/rg.2...
# 3322312  https://www.researchgate.net/doi/10.13140/rg.2...
# 3322200  https://www.researchgate.net/doi/10.13140/rg.2...
# ...                                                    ...
# 3354289  https://www.researchgate.net/doi/10.13140/rg.2...
# 3332704  https://www.researchgate.net/doi/10.13140/rg.2...
# 3350078  https://www.researchgate.net/doi/10.13140/rg.2...
# 3463359  https://www.researchgate.net/doi/10.13140/rg.2...
# 3405608  https://www.researchgate.net/doi/10.13140/rg.2...
#
#                             doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 3322080       10.13140/2.1.2328.2569             None          None      NaN
# 3322083       10.13140/2.1.2910.4001             None          None      NaN
# 3322151    10.13140/rg.2.1.1007.9848             None          None      NaN
# 3322312    10.13140/rg.2.1.1103.1281             None          None      NaN
# 3322200    10.13140/rg.2.1.1103.9445             None          None      NaN
# ...                              ...              ...           ...      ...
# 3354289  10.13140/rg.2.2.36811.13607             None          None      NaN
# 3332704  10.13140/rg.2.2.36825.57442             None          None      NaN
# 3350078  10.13140/rg.2.2.36829.77284             None          None      NaN
# 3463359  10.13140/rg.2.2.36831.37285             None          None      NaN
# 3405608  10.13140/rg.2.2.36835.84009             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 3322080              None           None       NaN
# 3322083              None           None       NaN
# 3322151              None           None       NaN
# 3322312              None           None       NaN
# 3322200              None           None       NaN
# ...                   ...            ...       ...
# 3354289              None           None       NaN
# 3332704              None           None       NaN
# 3350078              None           None       NaN
# 3463359              None           None       NaN
# 3405608              None           None       NaN
#
# [1633 rows x 30 columns]

# %%
df[df['doi']=='10.13140/rg.2.2.36331.69924']
# Out:
#                                      record_id   server_name   backend  \
# 3349993  datacite::10.13140/rg.2.2.36331.69924  ResearchGate  datacite
# 9486875                   openalex::W998010466         viXra  openalex
#
#                                  doi  \
# 3349993  10.13140/rg.2.2.36331.69924
# 9486875  10.13140/rg.2.2.36331.69924
#
#                                              doi_url  \
# 3349993  https://doi.org/10.13140/rg.2.2.36331.69924
# 9486875  https://doi.org/10.13140/rg.2.2.36331.69924
#
#                                           landing_page_url  \
# 3349993  https://www.researchgate.net/doi/10.13140/RG.2...
# 9486875              https://vixra.org/pdf/1409.0185v1.pdf
#
#                                                      title    authors_flat  \
# 3349993  TGD view about homeopathy, water memory, and e...      M Pitkänen
# 9486875  TGD view about homeopathy, water memory, and e...  Matti Pitkänen
#
#         publication_year         date_created relations_json version_label  \
# 3349993           2014.0           2019-09-19             []          None
# 9486875           2014.0  2025-10-10T00:00:00           None          None
#
#         is_version_of is_preprint_of has_preprint has_review  \
# 3349993
# 9486875          None           None         None       None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 3349993                 false                       None                None
# 9486875                  None                       None                None
#
#         update_to_json                             raw_relationships_json  \
# 3349993           None  {"client": {"data": {"id": "rg.rg", "type": "c...
# 9486875           None                                               None
#
#         records_hierarchy                                       landing_norm  \
# 3349993            parent  https://www.researchgate.net/doi/10.13140/rg.2...
# 9486875            parent              https://vixra.org/pdf/1409.0185v1.pdf
#
#                             doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 3349993  10.13140/rg.2.2.36331.69924             None          None      NaN
# 9486875  10.13140/rg.2.2.36331.69924             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 3349993              None           None       NaN
# 9486875              None           None       NaN

# %%
df[df['doi']=='10.22004/ag.econ.133088']
# Out:
#                                  record_id  \
# 102633   datacite::10.22004/ag.econ.133088
# 2806374               openalex::W985302891
#
#                                  server_name   backend  \
# 102633                         AgEcon Search  datacite
# 2806374  RePEc: Research Papers in Economics  openalex
#
#                              doi                                  doi_url  \
# 102633   10.22004/ag.econ.133088  https://doi.org/10.22004/ag.econ.133088
# 2806374  10.22004/ag.econ.133088  https://doi.org/10.22004/ag.econ.133088
#
#                                           landing_page_url  \
# 102633          https://ageconsearch.umn.edu/record/133088
# 2806374  https://ageconsearch.umn.edu/record/133088/fil...
#
#                                                   title  \
# 102633   Farmland price bubbles: wavelet-based evidence
# 2806374  Farmland price bubbles: wavelet-based evidence
#
#                                 authors_flat publication_year  \
# 102633   Power, Gabriel J.; Turvey, Calum G.           2006.0
# 2806374    Gabriel J. Power; Calum G. Turvey           2006.0
#
#                 date_created relations_json version_label is_version_of  \
# 102633            2019-08-30             []          None
# 2806374  2025-10-10T00:00:00           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 102633                                                         false
# 2806374           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 102633                        None                None           None
# 2806374                       None                None           None
#
#                                     raw_relationships_json records_hierarchy  \
# 102633   {"client": {"data": {"id": "tind.agecon", "typ...            parent
# 2806374                                               None            parent
#
#                                               landing_norm  \
# 102633          https://ageconsearch.umn.edu/record/133088
# 2806374  https://ageconsearch.umn.edu/record/133088/fil...
#
#                         doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 102633   10.22004/ag.econ.133088             None          None      NaN
# 2806374  10.22004/ag.econ.133088             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 102633               None           None       NaN
# 2806374              None           None       NaN

# %%
df[df['doi']=='10.1101/2019.12.23.887166']
# Out:
#                                    record_id server_name   backend  \
# 9073833  crossref::10.1101/2019.12.23.887166     bioRxiv  crossref
# 1555009                openalex::W2995005865         HAL  openalex
#
#                                doi                                    doi_url  \
# 9073833  10.1101/2019.12.23.887166  https://doi.org/10.1101/2019.12.23.887166
# 1555009  10.1101/2019.12.23.887166  https://doi.org/10.1101/2019.12.23.887166
#
#                                           landing_page_url  \
# 9073833  http://biorxiv.org/lookup/doi/10.1101/2019.12....
# 1555009                   https://hal.science/hal-02437604
#
#                                                      title  \
# 9073833  Model balancing: in search of consistent metab...
# 1555009  Model balancing: consistent in-vivo kinetic co...
#
#                                authors_flat publication_year  \
# 9073833  Liebermeister, Wolfram; Noor, Elad           2019.0
# 1555009               Wolfram Liebermeister           2019.0
#
#                 date_created  \
# 9073833           2019-12-24
# 1555009  2025-10-10T00:00:00
#
#                                             relations_json version_label  \
# 9073833  {"is-preprint-of": [{"asserted-by": "subject",...          None
# 1555009                                               None          None
#
#         is_version_of          is_preprint_of has_preprint has_review  \
# 9073833                10.3390/metabo11110749
# 1555009          None                    None         None       None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 9073833                  true                       None                None
# 1555009                  None                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 9073833           None                   None            parent
# 1555009           None                   None            parent
#
#                                               landing_norm  \
# 9073833  http://biorxiv.org/lookup/doi/10.1101/2019.12....
# 1555009                   https://hal.science/hal-02437604
#
#                           doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 9073833  10.1101/2019.12.23.887166             None          None      NaN
# 1555009  10.1101/2019.12.23.887166             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 9073833              None           None       NaN
# 1555009              None           None       NaN

# %%
df[df['doi']=='10.1101/2020.02.03.919597']
# Out:
#                                    record_id server_name   backend  \
# 8981770  crossref::10.1101/2020.02.03.919597     bioRxiv  crossref
# 1731345                openalex::W3004251285         HAL  openalex
#
#                                doi                                    doi_url  \
# 8981770  10.1101/2020.02.03.919597  https://doi.org/10.1101/2020.02.03.919597
# 1731345  10.1101/2020.02.03.919597  https://doi.org/10.1101/2020.02.03.919597
#
#                                           landing_page_url  \
# 8981770  http://biorxiv.org/lookup/doi/10.1101/2020.02....
# 1731345       https://pasteur.hal.science/pasteur-02626442
#
#                                                      title  \
# 8981770  Germline inherited small RNAs clear untranslat...
# 1731345  Argonaute catalytic activity is required for m...
#
#                                               authors_flat publication_year  \
# 8981770  Quarato, Piergiuseppe; Singh, Meetali; Cornes,...           2020.0
# 1731345  Piergiuseppe Quarato; Meetali Singh; Eric Corn...           2020.0
#
#                 date_created relations_json version_label is_version_of  \
# 8981770           2020-02-04           None          None
# 1731345  2020-02-07T00:00:00           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 8981770                                                        false
# 1731345           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 8981770                       None                None           None
# 1731345                       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 8981770                   None            parent
# 1731345                   None            parent
#
#                                               landing_norm  \
# 8981770  http://biorxiv.org/lookup/doi/10.1101/2020.02....
# 1731345       https://pasteur.hal.science/pasteur-02626442
#
#                           doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 8981770  10.1101/2020.02.03.919597             None          None      NaN
# 1731345  10.1101/2020.02.03.919597             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 8981770              None           None       NaN
# 1731345              None           None       NaN

# %%
df[df['doi']=='10.3220/rep_20_1_2014']
# Out:
#                     record_id      server_name   backend  \
# 2246907  openalex::W102989963  Organic Eprints  openalex
# 2245787  openalex::W106941238  Organic Eprints  openalex
# 2247124  openalex::W111413393  Organic Eprints  openalex
# 2245890  openalex::W113337753  Organic Eprints  openalex
# 2251234   openalex::W25719276  Organic Eprints  openalex
# 2255867   openalex::W46898626  Organic Eprints  openalex
# 2255967   openalex::W49926529  Organic Eprints  openalex
# 2244068   openalex::W50328423  Organic Eprints  openalex
# 2256029   openalex::W53160016  Organic Eprints  openalex
# 2244962   openalex::W60459218  Organic Eprints  openalex
       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 2246907                   None            parent
# 2245787                   None            parent
# 2247124                   None            parent
# 2245890                   None            parent
# 2251234                   None            parent
# 2255867                   None            parent
# 2255967                   None            parent
# 2244068                   None            parent
# 2256029                   None            parent
# 2244962                   None            parent
# 2256308                   None            parent
# 2256491                   None            parent
# 2256544                   None            parent
# 2245698                   None            parent
# 2244654                   None            parent
# 2256571                   None            parent
# 2245706                   None            parent
# 2256655                   None            parent
# 2256831                   None            parent
# 2244017                   None            parent
# 2244981                   None            parent
# 2257049                   None            parent
# 2257068                   None            parent
# 2257092                   None            parent
# 2244074                   None            parent
# 2257146                   None            parent
# 2245001                   None            parent
#
#                                   landing_norm               doi_norm  \
# 2246907  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2245787  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2247124  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2245890  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2251234  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2255867  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2255967  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2244068  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2256029  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2244962  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2256308  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2256491  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2256544  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2245698  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2244654  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2256571  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2245706  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2256655  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2256831  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2244017  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2244981  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2257049  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2257068  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2257092  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2244074  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2257146  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
# 2245001  https://doi.org/10.3220/rep_20_1_2014  10.3220/rep_20_1_2014
#
#         version_token_lp token_kind_lp  vnum_lp version_token_doi  \
# 2246907             None          None      NaN              None
# 2245787             None          None      NaN              None
# 2247124             None          None      NaN              None
# 2245890             None          None      NaN              None
# 2251234             None          None      NaN              None
# 2255867             None          None      NaN              None
# 2255967             None          None      NaN              None
# 2244068             None          None      NaN              None
# 2256029             None          None      NaN              None
# 2244962             None          None      NaN              None
# 2256308             None          None      NaN              None
# 2256491             None          None      NaN              None
# 2256544             None          None      NaN              None
# 2245698             None          None      NaN              None
# 2244654             None          None      NaN              None
# 2256571             None          None      NaN              None
# 2245706             None          None      NaN              None
# 2256655             None          None      NaN              None
# 2256831             None          None      NaN              None
# 2244017             None          None      NaN              None
# 2244981             None          None      NaN              None
# 2257049             None          None      NaN              None
# 2257068             None          None      NaN              None
# 2257092             None          None      NaN              None
# 2244074             None          None      NaN              None
# 2257146             None          None      NaN              None
# 2245001             None          None      NaN              None
#
#         token_kind_doi  vnum_doi
# 2246907           None       NaN
# 2245787           None       NaN
# 2247124           None       NaN
# 2245890           None       NaN
# 2251234           None       NaN
# 2255867           None       NaN
# 2255967           None       NaN
# 2244068           None       NaN
# 2256029           None       NaN
# 2244962           None       NaN
# 2256308           None       NaN
# 2256491           None       NaN
# 2256544           None       NaN
# 2245698           None       NaN
# 2244654           None       NaN
# 2256571           None       NaN
# 2245706           None       NaN
# 2256655           None       NaN
# 2256831           None       NaN
# 2244017           None       NaN
# 2244981           None       NaN
# 2257049           None       NaN
# 2257068           None       NaN
# 2257092           None       NaN
# 2244074           None       NaN
# 2257146           None       NaN
# 2245001           None       NaN

# %%
df[df['doi']=='10.48550/arxiv.0704.0324']
# Out:
#                                   record_id server_name   backend  \
# 6936795  datacite::10.48550/arxiv.0704.0324       arXiv  datacite
# 640498                openalex::W2951243300         HAL  openalex
#
#                               doi                                   doi_url  \
# 6936795  10.48550/arxiv.0704.0324  https://doi.org/10.48550/arxiv.0704.0324
# 640498   10.48550/arxiv.0704.0324  https://doi.org/10.48550/arxiv.0704.0324
#
#                          landing_page_url  \
# 6936795   https://arxiv.org/abs/0704.0324
# 640498   https://hal.science/hal-00139490
#
#                                                      title  \
# 6936795  On the pseudospectrum of elliptic quadratic di...
# 640498   On the pseudospectrum of elliptic quadratic di...
#
#                  authors_flat publication_year         date_created  \
# 6936795  Pravda-Starov, Karel           2007.0           2022-03-16
# 640498    Karel Pravda‐Starov           2007.0  2025-10-10T00:00:00
#
#         relations_json version_label is_version_of is_preprint_of  \
# 6936795             []             1
# 640498            None          None          None           None
#
#         has_preprint has_review has_published_version  \
# 6936795                                         false
# 640498          None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 6936795                       None                None           None
# 640498                        None                None           None
#
#                                     raw_relationships_json records_hierarchy  \
# 6936795  {"client": {"data": {"id": "arxiv.content", "t...            parent
# 640498                                                None            parent
#
#                              landing_norm                  doi_norm  \
# 6936795   https://arxiv.org/abs/0704.0324  10.48550/arxiv.0704.0324
# 640498   https://hal.science/hal-00139490  10.48550/arxiv.0704.0324
#
#         version_token_lp token_kind_lp  vnum_lp version_token_doi  \
# 6936795             None          None      NaN              None
# 640498              None          None      NaN              None
#
#         token_kind_doi  vnum_doi
# 6936795           None       NaN
# 640498            None       NaN

# %%
df[df['doi']=='10.13140/2.1.2910.4001']
# Out:
#                                 record_id   server_name   backend  \
# 3322083  datacite::10.13140/2.1.2910.4001  ResearchGate  datacite
# 9465428              openalex::W135550700         viXra  openalex
#
#                             doi                                 doi_url  \
# 3322083  10.13140/2.1.2910.4001  https://doi.org/10.13140/2.1.2910.4001
# 9465428  10.13140/2.1.2910.4001  https://doi.org/10.13140/2.1.2910.4001
#
#                                           landing_page_url  \
# 3322083  https://www.researchgate.net/doi/10.13140/2.1....
# 9465428              https://vixra.org/pdf/1402.0082v1.pdf
#
#                                                      title authors_flat  \
# 3322083  Polymer physics, the quantum harmonic oscillat...    P R Silva
# 9465428  Polymer physics, the quantum harmonic oscillat...  P. R. Silva
#
#         publication_year         date_created relations_json version_label  \
# 3322083           2014.0           2014-08-27             []          None
# 9465428           2014.0  2025-10-10T00:00:00           None          None
#
#         is_version_of is_preprint_of has_preprint has_review  \
# 3322083
# 9465428          None           None         None       None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 3322083                 false                       None                None
# 9465428                  None                       None                None
#
#         update_to_json                             raw_relationships_json  \
# 3322083           None  {"client": {"data": {"id": "rg.rg", "type": "c...
# 9465428           None                                               None
#
#         records_hierarchy                                       landing_norm  \
# 3322083            parent  https://www.researchgate.net/doi/10.13140/2.1....
# 9465428            parent              https://vixra.org/pdf/1402.0082v1.pdf
#
#                        doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 3322083  10.13140/2.1.2910.4001             None          None      NaN
# 9465428  10.13140/2.1.2910.4001             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 3322083              None           None       NaN
# 9465428              None           None       NaN

# %%
df['records_hierarchy'].value_counts()
# Out:
# records_hierarchy
# parent              7967131
# review               175443
# part_of              149462
# version              105984
# publish_version        9351
# child                  2028
# correction              355
# comment                 325
# others                   12
# parent_duplicate          3
# Name: count, dtype: int64

# %% [markdown]
# #### function

# %%
import pandas as pd

# -----------------------------
# 0) Define primary servers
# -----------------------------
# PRIMARY_SERVERS = {
#     "arXiv",
#     "bioRxiv",
#     "medRxiv",
#     "SSRN",
#     "TechRxiv",
#     "Wellcome Open Research",
#     "AgriRxiv",
#     "EarthArXiv",
#     "Law Archive",
#     "SocArXiv",
#     "Thesis Commons",
#     "Research Square",
#     "Open Research Europe",
#     "Oroboros Instruments",
#     "ResearchGate",
#     "AgEcon Search",
#     "Zenodo",
#     "Open Science Framework",
#     "Humanities Commons CORE",
#     "CERN document server",
#     "eLife",
# }

PRIMARY_SERVERS = set(primary_servers)  
# -----------------------------
# 1) Normalize DOI
# -----------------------------
doi_norm = (
    df_mirror["doi"]
    .astype("string")
    .str.strip()
    .str.lower()
    .replace({"": pd.NA, "none": pd.NA, "nan": pd.NA, "null": pd.NA})
)

# -----------------------------
# 2) Flags
# -----------------------------
is_primary = df_mirror["server_name"].isin(PRIMARY_SERVERS)
is_dup = doi_norm.notna() & doi_norm.duplicated(keep=False)

# -----------------------------
# 3) Identify DOI → primary server mapping (ONLY ONCE)
# -----------------------------
primary_by_doi = (
    df_mirror.loc[is_primary & is_dup, ["server_name"]]
    .assign(doi=doi_norm[is_primary & is_dup])
    .dropna(subset=["doi"])
    .groupby("doi")["server_name"]
    .first()   # take first primary (fast & deterministic)
)

# -----------------------------
# 4) Mark mirror rows
# -----------------------------
mask_mirror = is_dup & ~is_primary & doi_norm.isin(primary_by_doi.index)

df_mirror.loc[mask_mirror, "records_hierarchy"] = (
    "mirror (" + doi_norm[mask_mirror].map(primary_by_doi) + ")"
)


# primary_origin = doi_norm[mask_mirror].map(primary_by_doi).fillna("unknown").astype(str)

# df_mirror.loc[mask_mirror, "records_hierarchy"] = "mirror (" + primary_origin + ")"

# -----------------------------
# 5) Sanity check
# -----------------------------
print("Mirror rows:", mask_mirror.sum())
print(df_mirror["records_hierarchy"].value_counts(dropna=False).head(20))
# Out:
# Mirror rows: 16840
# records_hierarchy
# parent                              7950306
# review                               175443
# part_of                              149454
# version                              105977
# publish_version                        9351
# mirror (arXiv)                         8240
# mirror (AgEcon Search)                 6541
# child                                  2028
# mirror (ResearchGate)                  1633
# correction                              355
# comment                                 325
# mirror (Zenodo)                         297
# mirror (Open Science Framework)          31
# mirror (SSRN)                            30
# mirror (bioRxiv)                         29
# mirror (Humanities Commons CORE)         24
# others                                   12
# parent_duplicate                          3
# mirror (eLife)                            3
# mirror (CERN document server)             2
# Name: count, dtype: int64

# %%
df_mirror['records_hierarchy'].value_counts()
# Out:
# records_hierarchy
# parent                              7950306
# review                               175443
# part_of                              149454
# version                              105977
# publish_version                        9351
# mirror (arXiv)                         8240
# mirror (AgEcon Search)                 6541
# child                                  2028
# mirror (ResearchGate)                  1633
# correction                              355
# comment                                 325
# mirror (Zenodo)                         297
# mirror (Open Science Framework)          31
# mirror (SSRN)                            30
# mirror (bioRxiv)                         29
# mirror (Humanities Commons CORE)         24
# others                                   12
# parent_duplicate                          3
# mirror (eLife)                            3
# mirror (CERN document server)             2
# mirror (Research Square)                  2
# mirror (AgriRxiv)                         1
# mirror (EarthArXiv)                       1
# mirror (SocArXiv)                         1
# mirror (Law Archive)                      1
# mirror (Thesis Commons)                   1
# mirror (Oroboros Instruments)             1
# mirror (TechRxiv)                         1
# mirror (medRxiv)                          1
# Name: count, dtype: int64

# %%
dupes[dupes['server_name']=='EconStor Preprints']#.tail(60)
# Out:
#                     record_id         server_name   backend  \
# 495549   openalex::W107243416  EconStor Preprints  openalex
# 495567  openalex::W1122477516  EconStor Preprints  openalex
# 495592  openalex::W1150235247  EconStor Preprints  openalex
# 495606  openalex::W1166988194  EconStor Preprints  openalex
# 488791  openalex::W1198321170  EconStor Preprints  openalex
# ...                       ...                 ...       ...
# 527697   openalex::W822245089  EconStor Preprints  openalex
# 457459   openalex::W854544018  EconStor Preprints  openalex
# 488736   openalex::W872556750  EconStor Preprints  openalex
# 527752   openalex::W930520461  EconStor Preprints  openalex
# 527759   openalex::W938603975  EconStor Preprints  openalex
#
#                                 doi  \
# 495549    10.1007/s10273-008-0850-2
# 495567    10.1007/s10273-012-1319-x
# 495592    10.1007/s10273-014-1758-7
# 495606    10.1007/s10272-006-0174-7
# 488791    10.1007/s10273-008-0758-x
# ...                             ...
# 527697  10.13140/rg.2.2.31319.42409
# 457459    10.1007/s10272-005-0163-2
# 488736    10.1007/s10273-008-0758-x
# 527752    10.1007/s10273-008-0872-9
# 527759    10.1007/s10273-014-1724-4
#
#                                             doi_url  \
# 495549    https://doi.org/10.1007/s10273-008-0850-2
# 495567    https://doi.org/10.1007/s10273-012-1319-x
# 495592    https://doi.org/10.1007/s10273-014-1758-7
# 495606    https://doi.org/10.1007/s10272-006-0174-7
# 488791    https://doi.org/10.1007/s10273-008-0758-x
# ...                                             ...
# 527697  https://doi.org/10.13140/rg.2.2.31319.42409
# 457459    https://doi.org/10.1007/s10272-005-0163-2
# 488736    https://doi.org/10.1007/s10273-008-0758-x
# 527752    https://doi.org/10.1007/s10273-008-0872-9
# 527759    https://doi.org/10.1007/s10273-014-1724-4
#
#                           landing_page_url  \
# 495549   http://hdl.handle.net/10419/42949
# 495567   http://hdl.handle.net/10419/68395
# 495592  http://hdl.handle.net/10419/106724
# 495606   http://hdl.handle.net/10419/41893
# 488791   http://hdl.handle.net/10419/42977
# ...                                    ...
# 527697   http://hdl.handle.net/10419/95827
# 457459   http://hdl.handle.net/10419/41835
# 488736   http://hdl.handle.net/10419/42941
# 527752   http://hdl.handle.net/10419/43019
# 527759  http://hdl.handle.net/10419/106714
#
#                                                     title  \
# 495549  Am Vorabend des Gesundheitsfonds: Kaum ein Pro...
# 495567                    Zähe Liberalisierung: Blue Card
# 495592  Deutsche Parallelveranstaltung? EU-Emissionsha...
# 495606  Negotiating future climate policy: The role of...
# 488791  Weiterentwicklung des SGB II: Flexible Lösunge...
# ...                                                   ...
# 527697                      Zur Industriepolitk in Europa
# 457459                 Some tough love on 'aid for trade'
# 488736                            Das Hartz-IV-Experiment
# 527752  Schutz der geistigen Eigentumsrechte: Ein Pläd...
# 527759     Bundeshilfe ist auf dem Weg: Armutszuwanderung
#
#                                         authors_flat publication_year  \
# 495549                                  Klaus Jacobs           2008.0
# 495567                      Max Friedrich Steinhardt           2012.0
# 495592                               Andreas Löschel           2014.0
# 495606                            Preety M. Bhandari           2006.0
# 488791                   Susanne Koch; Ulrich Walwei           2008.0
# ...                                              ...              ...
# 527697  Georg Erber; Harald Hagemann; Stephan Seiter           1996.0
# 457459                              Simon J. Evenett           2005.0
# 488736                                   Hugh Mosley           2008.0
# 527752                               Cornelia Tausch           2008.0
# 527759                                Gerd Landsberg           2014.0
#
#                date_created relations_json version_label is_version_of  \
# 495549  2016-06-24T00:00:00           None          None          None
# 495567  2016-06-24T00:00:00           None          None          None
# 495592  2016-06-24T00:00:00           None          None          None
# 495606  2016-06-24T00:00:00           None          None          None
# 488791  2016-06-24T00:00:00           None          None          None
# ...                     ...            ...           ...           ...
# 527697  2025-10-10T00:00:00           None          None          None
# 457459  2016-06-24T00:00:00           None          None          None
# 488736  2016-06-24T00:00:00           None          None          None
# 527752  2016-06-24T00:00:00           None          None          None
# 527759  2016-06-24T00:00:00           None          None          None
#
#        is_preprint_of has_preprint has_review has_published_version  \
# 495549           None         None       None                  None
# 495567           None         None       None                  None
# 495592           None         None       None                  None
# 495606           None         None       None                  None
# 488791           None         None       None                  None
# ...               ...          ...        ...                   ...
# 527697           None         None       None                  None
# 457459           None         None       None                  None
# 488736           None         None       None                  None
# 527752           None         None       None                  None
# 527759           None         None       None                  None
#
#        published_version_ids_json version_of_ids_json update_to_json  \
# 495549                       None                None           None
# 495567                       None                None           None
# 495592                       None                None           None
# 495606                       None                None           None
# 488791                       None                None           None
# ...                           ...                 ...            ...
# 527697                       None                None           None
# 457459                       None                None           None
# 488736                       None                None           None
# 527752                       None                None           None
# 527759                       None                None           None
#
#        raw_relationships_json records_hierarchy  \
# 495549                   None            parent
# 495567                   None            parent
# 495592                   None            parent
# 495606                   None            parent
# 488791                   None            parent
# ...                       ...               ...
# 527697                   None            parent
# 457459                   None            parent
# 488736                   None            parent
# 527752                   None            parent
# 527759                   None            parent
#
#                               landing_norm                     doi_norm  \
# 495549   http://hdl.handle.net/10419/42949    10.1007/s10273-008-0850-2
# 495567   http://hdl.handle.net/10419/68395    10.1007/s10273-012-1319-x
# 495592  http://hdl.handle.net/10419/106724    10.1007/s10273-014-1758-7
# 495606   http://hdl.handle.net/10419/41893    10.1007/s10272-006-0174-7
# 488791   http://hdl.handle.net/10419/42977    10.1007/s10273-008-0758-x
# ...                                    ...                          ...
# 527697   http://hdl.handle.net/10419/95827  10.13140/rg.2.2.31319.42409
# 457459   http://hdl.handle.net/10419/41835    10.1007/s10272-005-0163-2
# 488736   http://hdl.handle.net/10419/42941    10.1007/s10273-008-0758-x
# 527752   http://hdl.handle.net/10419/43019    10.1007/s10273-008-0872-9
# 527759  http://hdl.handle.net/10419/106714    10.1007/s10273-014-1724-4
#
#        version_token_lp token_kind_lp  vnum_lp version_token_doi  \
# 495549             None          None      NaN              None
# 495567             None          None      NaN              None
# 495592             None          None      NaN              None
# 495606             None          None      NaN              None
# 488791             None          None      NaN              None
# ...                 ...           ...      ...               ...
# 527697             None          None      NaN              None
# 457459             None          None      NaN              None
# 488736             None          None      NaN              None
# 527752             None          None      NaN              None
# 527759             None          None      NaN              None
#
#        token_kind_doi  vnum_doi
# 495549           None       NaN
# 495567           None       NaN
# 495592           None       NaN
# 495606           None       NaN
# 488791           None       NaN
# ...               ...       ...
# 527697           None       NaN
# 457459           None       NaN
# 488736           None       NaN
# 527752           None       NaN
# 527759           None       NaN
#
# [559 rows x 30 columns]

# %%
df_mirror[df_mirror['doi']=='10.1007/s10273-008-0850-2']
# Out:
#                     record_id         server_name   backend  \
# 495549   openalex::W107243416  EconStor Preprints  openalex
# 466923   openalex::W218899851  EconStor Preprints  openalex
# 504836  openalex::W2230538860  EconStor Preprints  openalex
#
#                               doi                                    doi_url  \
# 495549  10.1007/s10273-008-0850-2  https://doi.org/10.1007/s10273-008-0850-2
# 466923  10.1007/s10273-008-0850-2  https://doi.org/10.1007/s10273-008-0850-2
# 504836  10.1007/s10273-008-0850-2  https://doi.org/10.1007/s10273-008-0850-2
#
#                          landing_page_url  \
# 495549  http://hdl.handle.net/10419/42949
# 466923  http://hdl.handle.net/10419/42931
# 504836  http://hdl.handle.net/10419/42921
#
#                                                     title  \
# 495549  Am Vorabend des Gesundheitsfonds: Kaum ein Pro...
# 466923  Reform der ambulanten ärztlichen Vergütung: Me...
# 504836  Widerspruchsvolle und ambivalente Strukturwand...
#
#                         authors_flat publication_year         date_created  \
# 495549                  Klaus Jacobs           2008.0  2016-06-24T00:00:00
# 466923  Jürgen Wasem; Anke Walendzik           2008.0  2016-06-24T00:00:00
# 504836        Frank Schulz‐Nieswandt           2008.0  2016-06-24T00:00:00
#
#        relations_json version_label is_version_of is_preprint_of has_preprint  \
# 495549           None          None          None           None         None
# 466923           None          None          None           None         None
# 504836           None          None          None           None         None
#
#        has_review has_published_version published_version_ids_json  \
# 495549       None                  None                       None
# 466923       None                  None                       None
# 504836       None                  None                       None
#
#        version_of_ids_json update_to_json raw_relationships_json  \
# 495549                None           None                   None
# 466923                None           None                   None
# 504836                None           None                   None
#
#        records_hierarchy                       landing_norm  \
# 495549            parent  http://hdl.handle.net/10419/42949
# 466923            parent  http://hdl.handle.net/10419/42931
# 504836            parent  http://hdl.handle.net/10419/42921
#
#                          doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 495549  10.1007/s10273-008-0850-2             None          None      NaN
# 466923  10.1007/s10273-008-0850-2             None          None      NaN
# 504836  10.1007/s10273-008-0850-2             None          None      NaN
#
#        version_token_doi token_kind_doi  vnum_doi
# 495549              None           None       NaN
# 466923              None           None       NaN
# 504836              None           None       NaN

# %%
# pattern = "osf.io"


# mask = ~dupes[dupes['server_name']=='Open Science Framework']['doi'].str.contains(pattern, regex=False, na=False)
# result = dupes[dupes['server_name']=='Open Science Framework'][mask]
# result

# %%
df_mirror[df_mirror['doi']=='10.1101/2019.12.23.887166']
# Out:
#                                    record_id server_name   backend  \
# 9073833  crossref::10.1101/2019.12.23.887166     bioRxiv  crossref
# 1555009                openalex::W2995005865         HAL  openalex
#
#                                doi                                    doi_url  \
# 9073833  10.1101/2019.12.23.887166  https://doi.org/10.1101/2019.12.23.887166
# 1555009  10.1101/2019.12.23.887166  https://doi.org/10.1101/2019.12.23.887166
#
#                                           landing_page_url  \
# 9073833  http://biorxiv.org/lookup/doi/10.1101/2019.12....
# 1555009                   https://hal.science/hal-02437604
#
#                                                      title  \
# 9073833  Model balancing: in search of consistent metab...
# 1555009  Model balancing: consistent in-vivo kinetic co...
#
#                                authors_flat publication_year  \
# 9073833  Liebermeister, Wolfram; Noor, Elad           2019.0
# 1555009               Wolfram Liebermeister           2019.0
#
#                 date_created  \
# 9073833           2019-12-24
# 1555009  2025-10-10T00:00:00
#
#                                             relations_json version_label  \
# 9073833  {"is-preprint-of": [{"asserted-by": "subject",...          None
# 1555009                                               None          None
#
#         is_version_of          is_preprint_of has_preprint has_review  \
# 9073833                10.3390/metabo11110749
# 1555009          None                    None         None       None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 9073833                  true                       None                None
# 1555009                  None                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 9073833           None                   None            parent
# 1555009           None                   None  mirror (bioRxiv)
#
#                                               landing_norm  \
# 9073833  http://biorxiv.org/lookup/doi/10.1101/2019.12....
# 1555009                   https://hal.science/hal-02437604
#
#                           doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 9073833  10.1101/2019.12.23.887166             None          None      NaN
# 1555009  10.1101/2019.12.23.887166             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 9073833              None           None       NaN
# 1555009              None           None       NaN

# %%
pattern = "mirror"


mask = df_mirror[df_mirror['server_name']=='F1000Research']['records_hierarchy'].str.contains(pattern, regex=False, na=False)
result = df_mirror[df_mirror['server_name']=='F1000Research'][mask]
result
# Out:
# Empty DataFrame
# Columns: [record_id, server_name, backend, doi, doi_url, landing_page_url, title, authors_flat, publication_year, date_created, relations_json, version_label, is_version_of, is_preprint_of, has_preprint, has_review, has_published_version, published_version_ids_json, version_of_ids_json, update_to_json, raw_relationships_json, records_hierarchy, landing_norm, doi_norm, version_token_lp, token_kind_lp, vnum_lp, version_token_doi, token_kind_doi, vnum_doi]
# Index: []

# %%
pattern = "mirror"


mask = df_mirror['records_hierarchy'].str.contains(pattern, regex=False, na=False)
result = df_mirror[mask]
result
# Out:
#                      record_id                          server_name   backend  \
# 9464662  openalex::W1003383974                                viXra  openalex
# 9461657    openalex::W10037114                                viXra  openalex
# 2713165   openalex::W100680786  RePEc: Research Papers in Economics  openalex
# 9464726   openalex::W101331951                                viXra  openalex
# 2713230   openalex::W101709879  RePEc: Research Papers in Economics  openalex
# ...                        ...                                  ...       ...
# 2810559    openalex::W98271585  RePEc: Research Papers in Economics  openalex
# 9486788   openalex::W983039221                                viXra  openalex
# 2806374   openalex::W985302891  RePEc: Research Papers in Economics  openalex
# 2817765   openalex::W986721525  RePEc: Research Papers in Economics  openalex
# 9486875   openalex::W998010466                                viXra  openalex
#
#                                  doi  \
# 9464662  10.13140/rg.2.2.14101.88805
# 9461657    10.13140/rg.2.1.4248.2403
# 2713165       10.22004/ag.econ.50567
# 9464726  10.13140/rg.2.2.17278.64326
# 2713230      10.22004/ag.econ.131335
# ...                              ...
# 2810559      10.22004/ag.econ.149739
# 9486788  10.13140/rg.2.2.29266.79041
# 2806374      10.22004/ag.econ.133088
# 2817765      10.22004/ag.econ.196816
# 9486875  10.13140/rg.2.2.36331.69924
#
#                                              doi_url  \
# 9464662  https://doi.org/10.13140/rg.2.2.14101.88805
# 9461657    https://doi.org/10.13140/rg.2.1.4248.2403
# 2713165       https://doi.org/10.22004/ag.econ.50567
# 9464726  https://doi.org/10.13140/rg.2.2.17278.64326
# 2713230      https://doi.org/10.22004/ag.econ.131335
# ...                                              ...
# 2810559      https://doi.org/10.22004/ag.econ.149739
# 9486788  https://doi.org/10.13140/rg.2.2.29266.79041
# 2806374      https://doi.org/10.22004/ag.econ.133088
# 2817765      https://doi.org/10.22004/ag.econ.196816
# 9486875  https://doi.org/10.13140/rg.2.2.36331.69924
#
#                                           landing_page_url  \
# 9464662              https://vixra.org/pdf/1501.0014v1.pdf
# 9461657              https://vixra.org/pdf/1407.0122v1.pdf
# 2713165          https://ageconsearch.umn.edu/record/50567
# 9464726              https://vixra.org/pdf/1306.0071v1.pdf
# 2713230  https://ageconsearch.umn.edu/record/131335/fil...
# ...                                                    ...
# 2810559        https://ageconsearch.umn.edu/record/149739/
# 9486788           http://www.vixra.org/pdf/1503.0004v1.pdf
# 2806374  https://ageconsearch.umn.edu/record/133088/fil...
# 2817765  https://ageconsearch.umn.edu/record/196816/fil...
# 9486875              https://vixra.org/pdf/1409.0185v1.pdf
#
#                                                      title  \
# 9464662           How are the visual percepts constructed?
# 9461657             A Reformulation of Classical Mechanics
# 2713165  The Impact of Oil Prices on the U.S. and Mexic...
# 9464726  The Optical Breakdown Density Limit Gamma givi...
# 2713230                 Explaining Farmland Price Dynamics
# ...                                                    ...
# 2810559  Impacts of Climate Change on Corn and Soybean ...
# 9486788  Ionization chamber noise fluctuations during l...
# 2806374     Farmland price bubbles: wavelet-based evidence
# 2817765  Assessing the Value of Broadband Connectivity ...
# 9486875  TGD view about homeopathy, water memory, and e...
#
#                                               authors_flat publication_year  \
# 9464662                                     Minna Pitkänen           2014.0
# 9461657                               Alejandro A. Torassa           2015.0
# 2713165                                        Owen Wagner           2009.0
# 9464726                                    Peter A Jackson           2013.0
# 2713230                Madhab R. Khoju; Bruce L. Ahrendsen           1993.0
# ...                                                    ...              ...
# 2810559              Shuai Chen; Xiaoguang Chen; Jintao Xu           2013.0
# 9486788  A. D. Skorbun; M. V. Efetov; G. I. Odinokin; O...           2020.0
# 2806374                  Gabriel J. Power; Calum G. Turvey           2006.0
# 2817765       Tyler Mark; Brian E. Whitacre; Terry Griffin           2015.0
# 9486875                                     Matti Pitkänen           2014.0
#
#                 date_created relations_json version_label is_version_of  \
# 9464662  2025-10-10T00:00:00           None          None          None
# 9461657  2025-10-10T00:00:00           None          None          None
# 2713165  2025-10-10T00:00:00           None          None          None
# 9464726  2025-10-10T00:00:00           None          None          None
# 2713230  2025-10-10T00:00:00           None          None          None
# ...                      ...            ...           ...           ...
# 2810559  2025-10-10T00:00:00           None          None          None
# 9486788  2025-10-10T00:00:00           None          None          None
# 2806374  2025-10-10T00:00:00           None          None          None
# 2817765  2025-10-10T00:00:00           None          None          None
# 9486875  2025-10-10T00:00:00           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 9464662           None         None       None                  None
# 9461657           None         None       None                  None
# 2713165           None         None       None                  None
# 9464726           None         None       None                  None
# 2713230           None         None       None                  None
# ...                ...          ...        ...                   ...
# 2810559           None         None       None                  None
# 9486788           None         None       None                  None
# 2806374           None         None       None                  None
# 2817765           None         None       None                  None
# 9486875           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 9464662                       None                None           None
# 9461657                       None                None           None
# 2713165                       None                None           None
# 9464726                       None                None           None
# 2713230                       None                None           None
# ...                            ...                 ...            ...
# 2810559                       None                None           None
# 9486788                       None                None           None
# 2806374                       None                None           None
# 2817765                       None                None           None
# 9486875                       None                None           None
#
#         raw_relationships_json       records_hierarchy  \
# 9464662                   None   mirror (ResearchGate)
# 9461657                   None   mirror (ResearchGate)
# 2713165                   None  mirror (AgEcon Search)
# 9464726                   None   mirror (ResearchGate)
# 2713230                   None  mirror (AgEcon Search)
# ...                        ...                     ...
# 2810559                   None  mirror (AgEcon Search)
# 9486788                   None   mirror (ResearchGate)
# 2806374                   None  mirror (AgEcon Search)
# 2817765                   None  mirror (AgEcon Search)
# 9486875                   None   mirror (ResearchGate)
#
#                                               landing_norm  \
# 9464662              https://vixra.org/pdf/1501.0014v1.pdf
# 9461657              https://vixra.org/pdf/1407.0122v1.pdf
# 2713165          https://ageconsearch.umn.edu/record/50567
# 9464726              https://vixra.org/pdf/1306.0071v1.pdf
# 2713230  https://ageconsearch.umn.edu/record/131335/fil...
# ...                                                    ...
# 2810559        https://ageconsearch.umn.edu/record/149739/
# 9486788           http://www.vixra.org/pdf/1503.0004v1.pdf
# 2806374  https://ageconsearch.umn.edu/record/133088/fil...
# 2817765  https://ageconsearch.umn.edu/record/196816/fil...
# 9486875              https://vixra.org/pdf/1409.0185v1.pdf
#
#                             doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 9464662  10.13140/rg.2.2.14101.88805             None          None      NaN
# 9461657    10.13140/rg.2.1.4248.2403             None          None      NaN
# 2713165       10.22004/ag.econ.50567             None          None      NaN
# 9464726  10.13140/rg.2.2.17278.64326             None          None      NaN
# 2713230      10.22004/ag.econ.131335             None          None      NaN
# ...                              ...              ...           ...      ...
# 2810559      10.22004/ag.econ.149739             None          None      NaN
# 9486788  10.13140/rg.2.2.29266.79041             None          None      NaN
# 2806374      10.22004/ag.econ.133088             None          None      NaN
# 2817765      10.22004/ag.econ.196816             None          None      NaN
# 9486875  10.13140/rg.2.2.36331.69924             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 9464662              None           None       NaN
# 9461657              None           None       NaN
# 2713165              None           None       NaN
# 9464726              None           None       NaN
# 2713230              None           None       NaN
# ...                   ...            ...       ...
# 2810559              None           None       NaN
# 9486788              None           None       NaN
# 2806374              None           None       NaN
# 2817765              None           None       NaN
# 9486875              None           None       NaN
#
# [16840 rows x 30 columns]

# %%
result['server_name'].value_counts()
# Out:
# server_name
# RePEc: Research Papers in Economics                                     9994
# HAL                                                                     3923
# DSpace@MIT                                                              1082
# viXra                                                                    826
# Munich Personal RePEc Archive                                            423
# EconStor Preprints                                                       197
# PhilSci-Archive                                                          161
# IACR Cryptology ePrint Archive                                            91
# Digital Access to Scholarship at Harvard (DASH) (Harvard University)      67
# E-LIS Repository                                                          28
# Social Science Open Access Repository                                     19
# Organic Eprints                                                           14
# CogPrints                                                                 14
# National Bureau of Economic Research                                       1
# Name: count, dtype: int64

# %%
dupes_mirror_df = df_mirror[df_mirror['doi'].notna()]
dupes_mirror_df
# Out:
#                                    record_id  \
# 429739   crossref::10.1002/essoar.10500000.1
# 429742   crossref::10.1002/essoar.10500002.1
# 429740   crossref::10.1002/essoar.10500004.1
# 429741   crossref::10.1002/essoar.10500007.1
# 429746   crossref::10.1002/essoar.10500009.1
# ...                                      ...
# 5667066                 openalex::W999063011
# 2245001                  openalex::W99945665
# 5667173                 openalex::W999508398
# 5673122                 openalex::W999509321
# 3149046                  openalex::W99988875
#
#                                    server_name   backend  \
# 429739    Earth and Space Science Open Archive  crossref
# 429742    Earth and Space Science Open Archive  crossref
# 429740    Earth and Space Science Open Archive  crossref
# 429741    Earth and Space Science Open Archive  crossref
# 429746    Earth and Space Science Open Archive  crossref
# ...                                        ...       ...
# 5667066  Social Science Open Access Repository  openalex
# 2245001                        Organic Eprints  openalex
# 5667173  Social Science Open Access Repository  openalex
# 5673122  Social Science Open Access Repository  openalex
# 3149046    RePEc: Research Papers in Economics  openalex
#
#                                   doi  \
# 429739      10.1002/essoar.10500000.1
# 429742      10.1002/essoar.10500002.1
# 429740      10.1002/essoar.10500004.1
# 429741      10.1002/essoar.10500007.1
# 429746      10.1002/essoar.10500009.1
# ...                               ...
# 5667066      10.15464/isi.42.2009.1-5
# 2245001         10.3220/rep_20_1_2014
# 5667173      10.15464/isi.38.2007.1-5
# 5673122  10.23668/psycharchives.13440
# 3149046     10.13140/rg.2.1.1218.2166
#
#                                               doi_url  \
# 429739      https://doi.org/10.1002/essoar.10500000.1
# 429742      https://doi.org/10.1002/essoar.10500002.1
# 429740      https://doi.org/10.1002/essoar.10500004.1
# 429741      https://doi.org/10.1002/essoar.10500007.1
# 429746      https://doi.org/10.1002/essoar.10500009.1
# ...                                               ...
# 5667066      https://doi.org/10.15464/isi.42.2009.1-5
# 2245001         https://doi.org/10.3220/rep_20_1_2014
# 5667173      https://doi.org/10.15464/isi.38.2007.1-5
# 5673122  https://doi.org/10.23668/psycharchives.13440
# 3149046     https://doi.org/10.13140/rg.2.1.1218.2166
#
#                                           landing_page_url  \
# 429739   https://essopenarchive.org/doi/full/10.1002/es...
# 429742   https://essopenarchive.org/doi/full/10.1002/es...
# 429740   https://essopenarchive.org/doi/full/10.1002/es...
# 429741   https://essopenarchive.org/doi/full/10.1002/es...
# 429746   https://essopenarchive.org/doi/full/10.1002/es...
# ...                                                    ...
# 5667066  http://www.ssoar.info/ssoar/handle/document/21392
# 2245001              https://doi.org/10.3220/rep_20_1_2014
# 5667173  http://www.ssoar.info/ssoar/handle/document/21635
# 5673122   http://www.ssoar.info/ssoar/handle/document/3368
# 3149046       https://ideas.repec.org/p/guc/wpaper/36.html
#
#                                                      title  \
# 429739   Long-term monitoring of land surface phenologi...
# 429742   Impact of spatial scale for phenological indic...
# 429740   Observations of Low Latitude Red Aurora in Mex...
# 429741   Pipeline oil fire detection with MODIS active ...
# 429746   Land Product Validation of MODIS Derived FPAR ...
# ...                                                    ...
# 5667066  Jeder fünfte Erwerbstätige ist aus beruflichen...
# 2245001  Earthworm abundance and species richness: Cont...
# 5667173  Berufstätigkeit von Müttern bleibt kontrovers:...
# 5673122  Rezension: Edward Timms (Hg.), Freud und das K...
# 3149046  Ration Cards in Egypt Targeting, Leakage, and ...
#
#                                               authors_flat publication_year  \
# 429739                                Tsutsumida, Narumasa           2018.0
# 429742                   Tsutsumida, Narumasa; Kaduk, Jörg           2018.0
# 429740   Gonzalez-Esparza, J. Americo; Cuevas-Cardona, ...           2018.0
# 429741   Ogungbuyi, Michael Gbenga; Martinez, Peter; Ec...           2018.0
# 429746   Sharp, Iain; Sanchez-Azofeifa, Arturo; Musilek...           2018.0
# ...                                                    ...              ...
# 5667066                     Silvia Ruppenthal; Detlev Lück           2009.0
# 2245001  Anna-Sophie Köhler; Julia Huber; Sebastian Wol...           2014.0
# 5667173                    Angelika Scheuer; Jörg Dittmann           2007.0
# 5673122                                   Wolfgang Hegener           1997.0
# 3149046                                 Hebatallah Ghoneim           2013.0
#
#                 date_created  \
# 429739            2019-11-13
# 429742            2019-11-13
# 429740            2019-11-13
# 429741            2019-11-13
# 429746            2019-12-03
# ...                      ...
# 5667066  2025-10-10T00:00:00
# 2245001  2025-10-10T00:00:00
# 5667173  2025-10-10T00:00:00
# 5673122  2025-10-10T00:00:00
# 3149046  2025-10-10T00:00:00
#
#                                             relations_json version_label  \
# 429739                                                None          None
# 429742                                                None          None
# 429740   {"is-preprint-of": [{"asserted-by": "subject",...          None
# 429741                                                None          None
# 429746                                                None          None
# ...                                                    ...           ...
# 5667066                                               None          None
# 2245001                                               None          None
# 5667173                                               None          None
# 5673122                                               None          None
# 3149046                                               None          None
#
#         is_version_of                             is_preprint_of has_preprint  \
# 429739
# 429742
# 429740                 10.1029/2017sw001789;10.1029/2018sw001995
# 429741
# 429746
# ...               ...                                        ...          ...
# 5667066          None                                       None         None
# 2245001          None                                       None         None
# 5667173          None                                       None         None
# 5673122          None                                       None         None
# 3149046          None                                       None         None
#
#         has_review has_published_version published_version_ids_json  \
# 429739                             false                       None
# 429742                             false                       None
# 429740                              true                       None
# 429741                             false                       None
# 429746                             false                       None
# ...            ...                   ...                        ...
# 5667066       None                  None                       None
# 2245001       None                  None                       None
# 5667173       None                  None                       None
# 5673122       None                  None                       None
# 3149046       None                  None                       None
#
#         version_of_ids_json update_to_json raw_relationships_json  \
# 429739                 None           None                   None
# 429742                 None           None                   None
# 429740                 None           None                   None
# 429741                 None           None                   None
# 429746                 None           None                   None
# ...                     ...            ...                    ...
# 5667066                None           None                   None
# 2245001                None           None                   None
# 5667173                None           None                   None
# 5673122                None           None                   None
# 3149046                None           None                   None
#
#         records_hierarchy                                       landing_norm  \
# 429739             parent  https://essopenarchive.org/doi/full/10.1002/es...
# 429742             parent  https://essopenarchive.org/doi/full/10.1002/es...
# 429740             parent  https://essopenarchive.org/doi/full/10.1002/es...
# 429741             parent  https://essopenarchive.org/doi/full/10.1002/es...
# 429746             parent  https://essopenarchive.org/doi/full/10.1002/es...
# ...                   ...                                                ...
# 5667066            parent  http://www.ssoar.info/ssoar/handle/document/21392
# 2245001            parent              https://doi.org/10.3220/rep_20_1_2014
# 5667173            parent  http://www.ssoar.info/ssoar/handle/document/21635
# 5673122            parent   http://www.ssoar.info/ssoar/handle/document/3368
# 3149046            parent       https://ideas.repec.org/p/guc/wpaper/36.html
#
#                              doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 429739      10.1002/essoar.10500000.1             None          None      NaN
# 429742      10.1002/essoar.10500002.1             None          None      NaN
# 429740      10.1002/essoar.10500004.1             None          None      NaN
# 429741      10.1002/essoar.10500007.1             None          None      NaN
# 429746      10.1002/essoar.10500009.1             None          None      NaN
# ...                               ...              ...           ...      ...
# 5667066      10.15464/isi.42.2009.1-5             None          None      NaN
# 2245001         10.3220/rep_20_1_2014             None          None      NaN
# 5667173      10.15464/isi.38.2007.1-5             None          None      NaN
# 5673122  10.23668/psycharchives.13440             None          None      NaN
# 3149046     10.13140/rg.2.1.1218.2166             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 429739               None           None       NaN
# 429742               None           None       NaN
# 429740               None           None       NaN
# 429741               None           None       NaN
# 429746               None           None       NaN
# ...                   ...            ...       ...
# 5667066              None           None       NaN
# 2245001              None           None       NaN
# 5667173              None           None       NaN
# 5673122              None           None       NaN
# 3149046              None           None       NaN
#
# [6784859 rows x 30 columns]

# %%
dupes_mirror = dupes_mirror_df[dupes_mirror_df.duplicated(subset=['doi'], keep=False)]
dupes_mirror
# Out:
#                                    record_id  \
# 8976641             crossref::10.1101/103937
# 9073833  crossref::10.1101/2019.12.23.887166
# 8986959  crossref::10.1101/2020.01.22.915215
# 8981770  crossref::10.1101/2020.02.03.919597
# 8891397  crossref::10.1101/2020.06.08.118984
# ...                                      ...
# 9486788                 openalex::W983039221
# 2806374                 openalex::W985302891
# 2817765                 openalex::W986721525
# 9486875                 openalex::W998010466
# 2245001                  openalex::W99945665
#
#                                  server_name   backend  \
# 8976641                              bioRxiv  crossref
# 9073833                              bioRxiv  crossref
# 8986959                              bioRxiv  crossref
# 8981770                              bioRxiv  crossref
# 8891397                              bioRxiv  crossref
# ...                                      ...       ...
# 9486788                                viXra  openalex
# 2806374  RePEc: Research Papers in Economics  openalex
# 2817765  RePEc: Research Papers in Economics  openalex
# 9486875                                viXra  openalex
# 2245001                      Organic Eprints  openalex
#
#                                  doi  \
# 8976641               10.1101/103937
# 9073833    10.1101/2019.12.23.887166
# 8986959    10.1101/2020.01.22.915215
# 8981770    10.1101/2020.02.03.919597
# 8891397    10.1101/2020.06.08.118984
# ...                              ...
# 9486788  10.13140/rg.2.2.29266.79041
# 2806374      10.22004/ag.econ.133088
# 2817765      10.22004/ag.econ.196816
# 9486875  10.13140/rg.2.2.36331.69924
# 2245001        10.3220/rep_20_1_2014
#
#                                              doi_url  \
# 8976641               https://doi.org/10.1101/103937
# 9073833    https://doi.org/10.1101/2019.12.23.887166
# 8986959    https://doi.org/10.1101/2020.01.22.915215
# 8981770    https://doi.org/10.1101/2020.02.03.919597
# 8891397    https://doi.org/10.1101/2020.06.08.118984
# ...                                              ...
# 9486788  https://doi.org/10.13140/rg.2.2.29266.79041
# 2806374      https://doi.org/10.22004/ag.econ.133088
# 2817765      https://doi.org/10.22004/ag.econ.196816
# 9486875  https://doi.org/10.13140/rg.2.2.36331.69924
# 2245001        https://doi.org/10.3220/rep_20_1_2014
#
#                                           landing_page_url  \
# 8976641       http://biorxiv.org/lookup/doi/10.1101/103937
# 9073833  http://biorxiv.org/lookup/doi/10.1101/2019.12....
# 8986959  http://biorxiv.org/lookup/doi/10.1101/2020.01....
# 8981770  http://biorxiv.org/lookup/doi/10.1101/2020.02....
# 8891397  http://biorxiv.org/lookup/doi/10.1101/2020.06....
# ...                                                    ...
# 9486788           http://www.vixra.org/pdf/1503.0004v1.pdf
# 2806374  https://ageconsearch.umn.edu/record/133088/fil...
# 2817765  https://ageconsearch.umn.edu/record/196816/fil...
# 9486875              https://vixra.org/pdf/1409.0185v1.pdf
# 2245001              https://doi.org/10.3220/rep_20_1_2014
#
#                                                      title  \
# 8976641  LET-99-dependent spatial restriction of active...
# 9073833  Model balancing: in search of consistent metab...
# 8986959  Not only compulsivity: The SAPAP3-KO mouse rec...
# 8981770  Germline inherited small RNAs clear untranslat...
# 8891397  TBPL2/TFIIA complex establishes the maternal t...
# ...                                                    ...
# 9486788  Ionization chamber noise fluctuations during l...
# 2806374     Farmland price bubbles: wavelet-based evidence
# 2817765  Assessing the Value of Broadband Connectivity ...
# 9486875  TGD view about homeopathy, water memory, and e...
# 2245001  Earthworm abundance and species richness: Cont...
#
#                                               authors_flat publication_year  \
# 8976641  Bouvrais, H.; Chesneau, L.; Pastezeur, S.; Del...           2017.0
# 9073833                 Liebermeister, Wolfram; Noor, Elad           2019.0
# 8986959  Lamothe, H; Schreiweis, C; Lavielle, O; Mallet...           2020.0
# 8981770  Quarato, Piergiuseppe; Singh, Meetali; Cornes,...           2020.0
# 8891397  Yu, Changwei; Cvetesic, Nevena; Hisler, Vincen...           2020.0
# ...                                                    ...              ...
# 9486788  A. D. Skorbun; M. V. Efetov; G. I. Odinokin; O...           2020.0
# 2806374                  Gabriel J. Power; Calum G. Turvey           2006.0
# 2817765       Tyler Mark; Brian E. Whitacre; Terry Griffin           2015.0
# 9486875                                     Matti Pitkänen           2014.0
# 2245001  Anna-Sophie Köhler; Julia Huber; Sebastian Wol...           2014.0
#
#                 date_created  \
# 8976641           2017-01-29
# 9073833           2019-12-24
# 8986959           2020-01-23
# 8981770           2020-02-04
# 8891397           2020-06-09
# ...                      ...
# 9486788  2025-10-10T00:00:00
# 2806374  2025-10-10T00:00:00
# 2817765  2025-10-10T00:00:00
# 9486875  2025-10-10T00:00:00
# 2245001  2025-10-10T00:00:00
#
#                                             relations_json version_label  \
# 8976641                                               None          None
# 9073833  {"is-preprint-of": [{"asserted-by": "subject",...          None
# 8986959                                               None          None
# 8981770                                               None          None
# 8891397  {"is-preprint-of": [{"asserted-by": "subject",...          None
# ...                                                    ...           ...
# 9486788                                               None          None
# 2806374                                               None          None
# 2817765                                               None          None
# 9486875                                               None          None
# 2245001                                               None          None
#
#         is_version_of              is_preprint_of has_preprint has_review  \
# 8976641
# 9073833                    10.3390/metabo11110749
# 8986959
# 8981770
# 8891397                10.1038/s41467-020-20239-4
# ...               ...                         ...          ...        ...
# 9486788          None                        None         None       None
# 2806374          None                        None         None       None
# 2817765          None                        None         None       None
# 9486875          None                        None         None       None
# 2245001          None                        None         None       None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 8976641                 false                       None                None
# 9073833                  true                       None                None
# 8986959                 false                       None                None
# 8981770                 false                       None                None
# 8891397                  true                       None                None
# ...                       ...                        ...                 ...
# 9486788                  None                       None                None
# 2806374                  None                       None                None
# 2817765                  None                       None                None
# 9486875                  None                       None                None
# 2245001                  None                       None                None
#
#         update_to_json raw_relationships_json       records_hierarchy  \
# 8976641           None                   None                  parent
# 9073833           None                   None                  parent
# 8986959           None                   None                  parent
# 8981770           None                   None                  parent
# 8891397           None                   None                  parent
# ...                ...                    ...                     ...
# 9486788           None                   None   mirror (ResearchGate)
# 2806374           None                   None  mirror (AgEcon Search)
# 2817765           None                   None  mirror (AgEcon Search)
# 9486875           None                   None   mirror (ResearchGate)
# 2245001           None                   None                  parent
#
#                                               landing_norm  \
# 8976641       http://biorxiv.org/lookup/doi/10.1101/103937
# 9073833  http://biorxiv.org/lookup/doi/10.1101/2019.12....
# 8986959  http://biorxiv.org/lookup/doi/10.1101/2020.01....
# 8981770  http://biorxiv.org/lookup/doi/10.1101/2020.02....
# 8891397  http://biorxiv.org/lookup/doi/10.1101/2020.06....
# ...                                                    ...
# 9486788           http://www.vixra.org/pdf/1503.0004v1.pdf
# 2806374  https://ageconsearch.umn.edu/record/133088/fil...
# 2817765  https://ageconsearch.umn.edu/record/196816/fil...
# 9486875              https://vixra.org/pdf/1409.0185v1.pdf
# 2245001              https://doi.org/10.3220/rep_20_1_2014
#
#                             doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 8976641               10.1101/103937             None          None      NaN
# 9073833    10.1101/2019.12.23.887166             None          None      NaN
# 8986959    10.1101/2020.01.22.915215             None          None      NaN
# 8981770    10.1101/2020.02.03.919597             None          None      NaN
# 8891397    10.1101/2020.06.08.118984             None          None      NaN
# ...                              ...              ...           ...      ...
# 9486788  10.13140/rg.2.2.29266.79041             None          None      NaN
# 2806374      10.22004/ag.econ.133088             None          None      NaN
# 2817765      10.22004/ag.econ.196816             None          None      NaN
# 9486875  10.13140/rg.2.2.36331.69924             None          None      NaN
# 2245001        10.3220/rep_20_1_2014             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 8976641              None           None       NaN
# 9073833              None           None       NaN
# 8986959              None           None       NaN
# 8981770              None           None       NaN
# 8891397              None           None       NaN
# ...                   ...            ...       ...
# 9486788              None           None       NaN
# 2806374              None           None       NaN
# 2817765              None           None       NaN
# 9486875              None           None       NaN
# 2245001              None           None       NaN
#
# [34714 rows x 30 columns]

# %%
dupes_mirror['server_name'].value_counts()
# Out:
# server_name
# RePEc: Research Papers in Economics                                     10494
# arXiv                                                                    8236
# AgEcon Search                                                            6540
# HAL                                                                      4041
# ResearchGate                                                             1633
# DSpace@MIT                                                               1082
# viXra                                                                     826
# EconStor Preprints                                                        559
# Munich Personal RePEc Archive                                             443
# Zenodo                                                                    297
# PhilSci-Archive                                                           161
# IACR Cryptology ePrint Archive                                             91
# Digital Access to Scholarship at Harvard (DASH) (Harvard University)       68
# Organic Eprints                                                            46
# Open Science Framework                                                     31
# bioRxiv                                                                    29
# SSRN                                                                       29
# E-LIS Repository                                                           28
# Social Science Open Access Repository                                      24
# Humanities Commons CORE                                                    24
# CogPrints                                                                  14
# eLife                                                                       3
# Research Square                                                             2
# CERN document server                                                        2
# medRxiv                                                                     1
# Open Research Europe                                                        1
# SocArXiv                                                                    1
# Oroboros Instruments                                                        1
# Thesis Commons                                                              1
# TechRxiv                                                                    1
# Wellcome Open Research                                                      1
# AgriRxiv                                                                    1
# EarthArXiv                                                                  1
# Law Archive                                                                 1
# National Bureau of Economic Research                                        1
# Name: count, dtype: int64

# %%
dupes_mirror['records_hierarchy'].value_counts()
# Out:
# records_hierarchy
# parent                              17869
# mirror (arXiv)                       8240
# mirror (AgEcon Search)               6541
# mirror (ResearchGate)                1633
# mirror (Zenodo)                       297
# mirror (Open Science Framework)        31
# mirror (SSRN)                          30
# mirror (bioRxiv)                       29
# mirror (Humanities Commons CORE)       24
# version                                 3
# mirror (eLife)                          3
# part_of                                 2
# mirror (CERN document server)           2
# mirror (Research Square)                2
# mirror (AgriRxiv)                       1
# mirror (EarthArXiv)                     1
# mirror (SocArXiv)                       1
# mirror (Law Archive)                    1
# mirror (Thesis Commons)                 1
# mirror (Oroboros Instruments)           1
# mirror (TechRxiv)                       1
# mirror (medRxiv)                        1
# Name: count, dtype: int64

# %%
df_mirror['records_hierarchy'].value_counts()
# Out:
# records_hierarchy
# parent                              7950306
# review                               175443
# part_of                              149454
# version                              105977
# publish_version                        9351
# mirror (arXiv)                         8240
# mirror (AgEcon Search)                 6541
# child                                  2028
# mirror (ResearchGate)                  1633
# correction                              355
# comment                                 325
# mirror (Zenodo)                         297
# mirror (Open Science Framework)          31
# mirror (SSRN)                            30
# mirror (bioRxiv)                         29
# mirror (Humanities Commons CORE)         24
# others                                   12
# parent_duplicate                          3
# mirror (eLife)                            3
# mirror (CERN document server)             2
# mirror (Research Square)                  2
# mirror (AgriRxiv)                         1
# mirror (EarthArXiv)                       1
# mirror (SocArXiv)                         1
# mirror (Law Archive)                      1
# mirror (Thesis Commons)                   1
# mirror (Oroboros Instruments)             1
# mirror (TechRxiv)                         1
# mirror (medRxiv)                          1
# Name: count, dtype: int64

# %%
data_clean['server_name'].value_counts().head(60)
# Out:
# server_name
# arXiv                                                                   2920797
# SSRN                                                                    1258958
# HAL                                                                     1056424
# Research Square                                                          450818
# RePEc: Research Papers in Economics                                      389398
# bioRxiv                                                                  306948
# eLife                                                                    247558
# AgEcon Search                                                            188173
# ResearchGate                                                             181231
# Qeios                                                                    172316
# Zenodo                                                                   166786
# Open Science Framework                                                   119481
# Preprints.org                                                            115815
# medRxiv                                                                   75743
# EconStor Preprints                                                        71761
# Munich Personal RePEc Archive                                             68692
# Authorea Inc.                                                             62018
# EGUsphere                                                                 60396
# PsyArXiv                                                                  56866
# ChemRxiv                                                                  46475
# JMIR Preprints                                                            37631
# Humanities Commons CORE                                                   29584
# TechRxiv                                                                  29418
# Social Science Open Access Repository                                     27201
# viXra                                                                     25570
# Earth and Space Science Open Archive                                      22932
# SocArXiv                                                                  21541
# INA-Rxiv                                                                  17837
# F1000Research                                                             16873
# Organic Eprints                                                           13983
# DSpace@MIT                                                                12661
# IACR Cryptology ePrint Archive                                            11904
# Digital Access to Scholarship at Harvard (DASH) (Harvard University
# Open Research Europe                                                       1178
# APSA Preprints                                                             1101
# CERN document server                                                        972
# Name: count, dtype: int64

# %%
df_mirror[df_mirror['records_hierarchy']=='parent']['server_name'].value_counts().head(60)
# Out:
# server_name
# arXiv                                                                   2920797
# SSRN                                                                    1258958
# HAL                                                                     1052407
# Research Square                                                          401982
# RePEc: Research Papers in Economics                                      379124
# bioRxiv                                                                  306948
# AgEcon Search                                                            188173
# ResearchGate                                                             181231
# Zenodo                                                                   166784
# Open Science Framework                                                   117187
# Qeios                                                                    111902
# Preprints.org                                                            102231
# medRxiv                                                                   75743
# EconStor Preprints                                                        71545
# Munich Personal RePEc Archive                                             68266
# Authorea Inc.                                                             59957
# PsyArXiv                                                                  51325
# ChemRxiv                                                                  46475
# JMIR Preprints                                                            37631
# Humanities Commons CORE                                                   29394
# Social Science Open Access Repository                                     27132
# TechRxiv                                                                  25887
# viXra                                                                     24720
# SocArXiv                                                                  20517
# Earth and Space Science Open Archive                                      20047
# INA-Rxiv                                                                  17836
# Organic Eprints                                                           13966
# eLife                                                                     11824
# DSpace@MIT                                                                11549
# F1000Research                                                             11162
# IACR Cryptology ePrint Archive                                            10678
# EGUsphere                                                                 10242
# ART-Dok                                                                    9653
# Digital Access to Scholarship at Harvard (DASH) (Harvard University)       9635
# E-LIS Repository                                                           9096
# PropylaeumDok                                                              6750
# EarthArXiv                                                                 6537
# Nature Precedings                                                          5210
# PeerJ Preprints                                                            5071
# engrXiv                                                                    4929
# Advance                                                                    4148
# SciELO Preprints                                                           4140
# ScienceOpen Preprints                                                      4039
# Thesis Commons                                                             3916
# Wellcome Open Research                                                     3428
# UCL Open Environment                                                       3111
# EcoEvoRxiv                                                                 2886
# EdArXiv                                                                    2416
# PhilSci-Archive                                                            2200
# Cambridge Open Engage                                                      2089
# National Bureau of Economic Research                                       1854
# Law Archive                                                                1805
# ResearchHub                                                                1629
# CogPrints                                                                  1521
# PREPRINTS.RU                                                               1415
# CrimRxiv                                                                   1316
# Keldysh Institute Preprints                                                1258
# Open Research Europe                                                       1178
# APSA Preprints                                                             1101
# CERN document server                                                        972
# Name: count, dtype: int64

# %% [markdown]
# ### landing_page_url

# %%
df_landing_page_url = df_mirror[df_mirror['landing_page_url'].notna()]
df_landing_page_url = df_landing_page_url[df_landing_page_url['records_hierarchy']=='parent']

# %%
dupes_landing_page_url = df_landing_page_url[df_landing_page_url.duplicated(subset=['landing_page_url'], keep=False)]
dupes_landing_page_url
# Out:
#                                         record_id  \
# 572299   crossref::10.12688/f1000research.1-10.v1
# 572275   crossref::10.12688/f1000research.1-12.v1
# 572276    crossref::10.12688/f1000research.1-2.v1
# 572363   crossref::10.12688/f1000research.1-23.v1
# 572496   crossref::10.12688/f1000research.1-36.v1
# ...                                           ...
# 922077                       openalex::W975457731
# 3148996                      openalex::W985669677
# 2840713                      openalex::W988701864
# 3149018                      openalex::W991373209
# 2245001                       openalex::W99945665
#
#                                  server_name   backend  \
# 572299                         F1000Research  crossref
# 572275                         F1000Research  crossref
# 572276                         F1000Research  crossref
# 572363                         F1000Research  crossref
025-10-10T00:00:00           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 572299                                                         false
# 572275                                                         false
# 572276                                                         false
# 572363                                                         false
# 572496                                                         false
# ...                ...          ...        ...                   ...
# 922077            None         None       None                  None
# 3148996           None         None       None                  None
# 2840713           None         None       None                  None
# 3149018           None         None       None                  None
# 2245001           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 572299                        None                None           None
# 572275                        None                None           None
# 572276                        None                None           None
# 572363                        None                None           None
# 572496                        None                None           None
# ...                            ...                 ...            ...
# 922077                        None                None           None
# 3148996                       None                None           None
# 2840713                       None                None           None
# 3149018                       None                None           None
# 2245001                       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 572299                    None            parent
# 572275                    None            parent
# 572276                    None            parent
# 572363                    None            parent
# 572496                    None            parent
# ...                        ...               ...
# 922077                    None            parent
# 3148996                   None            parent
# 2840713                   None            parent
# 3149018                   None            parent
# 2245001                   None            parent
#
#                                               landing_norm  \
# 572299           http://f1000research.com/articles/1-10/v1
# 572275           http://f1000research.com/articles/1-12/v1
# 572276            http://f1000research.com/articles/1-2/v1
# 572363           http://f1000research.com/articles/1-23/v1
# 572496           http://f1000research.com/articles/1-36/v1
# ...                                                    ...
# 922077                   https://hal.inrae.fr/hal-02774168
# 3148996            https://foresight.forecasters.org/shop/
# 2840713  https://www.econstor.eu/bitstream/10419/105793...
# 3149018            https://foresight.forecasters.org/shop/
# 2245001              https://doi.org/10.3220/rep_20_1_2014
#
#                                doi_norm version_token_lp     token_kind_lp  \
# 572299   10.12688/f1000research.1-10.v1              /v1  explicit_version
# 572275   10.12688/f1000research.1-12.v1              /v1  explicit_version
# 572276    10.12688/f1000research.1-2.v1              /v1  explicit_version
# 572363   10.12688/f1000research.1-23.v1              /v1  explicit_version
# 572496   10.12688/f1000research.1-36.v1              /v1  explicit_version
# ...                                 ...              ...               ...
# 922077                             <na>             None              None
# 3148996                            <na>             None              None
# 2840713                            <na>             None              None
# 3149018                            <na>             None              None
# 2245001           10.3220/rep_20_1_2014             None              None
#
#          vnum_lp version_token_doi token_kind_doi  vnum_doi
# 572299       1.0               NaN            NaN       NaN
# 572275       1.0               NaN            NaN       NaN
# 572276       1.0               NaN            NaN       NaN
# 572363       1.0               NaN            NaN       NaN
# 572496       1.0               NaN            NaN       NaN
# ...          ...               ...            ...       ...
# 922077       NaN              None           None       NaN
# 3148996      NaN              None           None       NaN
# 2840713      NaN              None           None       NaN
# 3149018      NaN              None           None       NaN
# 2245001      NaN              None           None       NaN
#
# [6720 rows x 30 columns]

# %%
dupes_landing_page_url['server_name'].value_counts()
# Out:
# server_name
# HAL                                                                     3602
# RePEc: Research Papers in Economics                                     1589
# Qeios                                                                    191
# ResearchHub                                                              171
# Munich Personal RePEc Archive                                            169
# AgEcon Search                                                            122
# PsyArXiv                                                                 119
# Earth and Space Science Open Archive                                     116
# ScienceOpen Preprints                                                    111
# TechRxiv                                                                  65
# F1000Research                                                             62
# arXiv                                                                     46
# DSpace@MIT                                                                44
# Authorea Inc.                                                             42
# EarthArXiv                                                                32
# Digital Access to Scholarship at Harvard (DASH) (Harvard University)      32
# IACR Cryptology ePrint Archive                                            30
# Organic Eprints                                                           29
# SciELO Preprints                                                          24
# EcoEvoRxiv                                                                23
# Open Science Framework                                                    20
# Humanities Commons CORE                                                   10
# SocArXiv                                                                   9
# EconStor Preprints                                                         8
# ART-Dok                                                                    8
# viXra                                                                      6
# PeerJ Preprints                                                            6
# MetaArXiv                                                                  6
# UCL Open Environment                                                       4
# WikiJournal of Medicine                                                    4
# WikiJournal of Humanities                                                  4
# Social Science Open Access Repository                                      4
# Bepress Legal Repository                                                   4
# JMIR Preprints                                                             2
# Preprints.org                                                              2
# Advance                                                                    2
# National Bureau of Economic Research                                       2
# Name: count, dtype: int64

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='eLife']
# Out:
# Empty DataFrame
# Columns: [record_id, server_name, backend, doi, doi_url, landing_page_url, title, authors_flat, publication_year, date_created, relations_json, version_label, is_version_of, is_preprint_of, has_preprint, has_review, has_published_version, published_version_ids_json, version_of_ids_json, update_to_json, raw_relationships_json, records_hierarchy, landing_norm, doi_norm, version_token_lp, token_kind_lp, vnum_lp, version_token_doi, token_kind_doi, vnum_doi]
# Index: []

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='HAL'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                      record_id server_name   backend   doi doi_url  \
# 1898157  openalex::W4391556995         HAL  openalex  <NA>    None
# 1899437  openalex::W4402466855         HAL  openalex  <NA>    None
# 1898156  openalex::W4391556994         HAL  openalex  <NA>    None
# 1899435  openalex::W4402466852         HAL  openalex  <NA>    None
# 1497927  openalex::W4300758384         HAL  openalex  <NA>    None
# ...                        ...         ...       ...   ...     ...
# 612448   openalex::W2267354779         HAL  openalex  <NA>    None
# 1559497  openalex::W2766068608         HAL  openalex  <NA>    None
# 1724449  openalex::W4394975358         HAL  openalex  <NA>    None
# 830106   openalex::W4298862399         HAL  openalex  <NA>    None
# 602575   openalex::W2614659248         HAL  openalex  <NA>    None
#
#                                 landing_page_url  \
# 1898157    https://uphf.hal.science/hal-04427814
# 1899437    https://uphf.hal.science/hal-04427814
# 1898156    https://uphf.hal.science/hal-04427807
# 1899435    https://uphf.hal.science/hal-04427807
# 1497927    https://uphf.hal.science/hal-03402279
# ...                                          ...
# 612448                        http://www.utc.fr/
# 1559497  http://hal.univ-reunion.fr/hal-01620054
# 1724449  http://hal.univ-reunion.fr/hal-01620054
# 830106                          http://atief.org
# 602575                          http://atief.org
#
#                                                      title  \
# 1898157  Recherche &amp; Conception Centrées sur l’Huma...
# 1899437  Recherche et Conception Centrées sur l’Humain ...
# 1898156  Human-Centred Research &amp; Design for Inclus...
# 1899435  Human-Centred Research and Design for Inclusiv...
# 1497927  L’aide à la décision comme cadre de gouvernanc...
# ...                                                    ...
# 612448   HNLS : une approche constructiviste de connais...
# 1559497  A multi-physics optimization problem in natura...
# 1724449  A multi-objective optimization problem in natu...
# 830106   Un site web pour l'enseignement interdisciplin...
# 602575   Analyse didactique de protocoles obtenus dans ...
#
#                                               authors_flat publication_year  \
# 1898157                                      Bako Rajaonah           2024.0
rows x 30 columns]

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='RePEc: Research Papers in Economics'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                      record_id                          server_name   backend  \
# 2678434     openalex::W5759233  RePEc: Research Papers in Economics  openalex
# 2765475  openalex::W2396705024  RePEc: Research Papers in Economics  openalex
# 2766088    openalex::W25120768  RePEc: Research Papers in Economics  openalex
# 3150826  openalex::W1440470170  RePEc: Research Papers in Economics  openalex
# 2668133  openalex::W2418493038  RePEc: Research Papers in Economics  openalex
# ...                        ...                                  ...       ...
# 3195781    openalex::W96404234  RePEc: Research Papers in Economics  openalex
# 3152394  openalex::W1533821926  RePEc: Research Papers in Economics  openalex
# 3169286  openalex::W1538117148  RePEc: Research Papers in Economics  openalex
# 3157650   openalex::W113954667  RePEc: Research Papers in Economics  openalex
# 3163325   openalex::W625462578  RePEc: Research Papers in Economics  openalex
#
#           doi doi_url                                   landing_page_url  \
# 2678434  <NA>    None  https://www.rimisp.org/wp-content/files_mf/137...
# 2765475  <NA>    None  https://www.rimisp.org/wp-content/files_mf/137...
# 2766088  <NA>    None  https://www.rba.gov.au/publications/confs/2006...
# 3150826  <NA>    None  https://www.rba.gov.au/publications/confs/2006...
# 2668133  <NA>    None            https://www.nber.org/chapters/c9003.pdf
# ...       ...     ...                                                ...
# 3195781  <NA>    None     http://asers.eu/journals/jemt/jemt-issues.html
# 3152394  <NA>    None     http://asers.eu/journals/jemt/jemt-issues.html
# 3169286  <NA>    None     http://asers.eu/journals/jemt/jemt-issues.html
# 3157650  <NA>    None     http://asers.eu/journals/jasf/jasf-issues.html
# 3163325  <NA>    None     http://asers.eu/journals/jasf/jasf-issues.html
#
#                                                      title  \
# 2678434   Caracterización de los actores de Chiloé Central
# 2765475   Caracterización de los actores de Chiloé Central
# 2766088                                 Wrap-up Discussion
# 3150826  Overexpression of MAGE-D4 in colorectal cancer...
# 2668133  Introduction to "Concentrated Corporate Owners...
# ...                                                    ...
# 3195781  DEMAND OF REGIONAL TOURISTS VISITING LAO PEOPL...
# 3152394  NATURE BASED TOURISM, SEASONAL VARIATION AND I...
# 3169286  SEEKING SUSTAINABILITY IN AN AGE OF COMPLEXITY...
# 3157650      EFFICIENCY ANALYSIS OF TURKISH BANKING SYSTEM
# 3163325     PREDICTABILITY OF MAJOR SWEDISH EXCHANGE RATES
#
#                                               authors_flat publication_year  \
# 2678434  Eduardo Ramı́rez; Félix Modrego; Julie Claire ...           2009.0
# 2765475                      C Revaz; Aude Favier du Noyer           2009.0
# 2766088     Gary Burtless; James K. Glassman; Adair Turner           2006.0
# 3150826  Qingmei Zhang; Shu-Jia He; Ning Shen; Bin Luo;...           2014.0
# 2668133                                         Felix Sahm           2000.0
# ...                                                    ...              ...
# 3195781              Sakkarin Nonthapot; Thanet Wattanakul           2016.0
# 3152394                        Utpal Kumar De; Amrita Devi           2016.0
# 3169286                                    Laura Ungureanu           2010.0
# 3157650                                 Ayşe Altıok Yilmaz           2013.0
# 3163325                                     Kenneth A. Tah           2013.0
#
#                 date_created relations_json version_label is_version_of  \
# 2678434  2025-10-10T00:00:00           None          None          None
# 2765475  2016-06-24T00:00:00           None          None          None
# 2766088  2016-06-24T00:00:00           None          None          None
# 3150826  2025-10-10T00:00:00           None          None          None
# 2668133  2016-06-24T00:00:00           None          None          None
# ...                      ...            ...           ...           ...
# 3195781  2025-10-10T00:00:00           None          None          None
# 3152394  2025-10-10T00:00:00           None          None          None
# 3169286  2025-10-10T00:00:00           None          None          None
# 3157650  2025-10-10T00:00:00           None          None          None
# 3163325  2025-10-10T00:00:00           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 2678434           None         None       None                  None
# 2765475           None         None       None                  None
# 2766088           None         None       None                  None
# 3150826           None         None       None                  None
# 2668133           None         None       None                  None
# ...                ...          ...        ...                   ...
# 3195781           None         None       None                  None
# 3152394           None         None       None                  None
# 3169286           None         None       None                  None
# 3157650           None         None       None                  None
# 3163325           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 2678434                       None                None           None
# 2765475                       None                None           None
# 2766088                       None                None           None
# 3150826                       None                None           None
# 2668133                       None                None           None
# ...                            ...                 ...            ...
# 3195781                       None                None           None
# 3152394                       None                None           None
# 3169286                       None                None           None
# 3157650                       None                None           None
# 3163325                       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 2678434                   None            parent
# 2765475                   None            parent
# 2766088                   None            parent
# 3150826                   None            parent
# 2668133                   None            parent
# ...                        ...               ...
# 3195781                   None            parent
# 3152394                   None            parent
# 3169286                   None            parent
# 3157650                   None            parent
# 3163325                   None            parent
#
#                                               landing_norm doi_norm  \
# 2678434  https://www.rimisp.org/wp-content/files_mf/137...     <na>
# 2765475  https://www.rimisp.org/wp-content/files_mf/137...     <na>
# 2766088  https://www.rba.gov.au/publications/confs/2006...     <na>
# 3150826  https://www.rba.gov.au/publications/confs/2006...     <na>
# 2668133            https://www.nber.org/chapters/c9003.pdf     <na>
# ...                                                    ...      ...
# 3195781     http://asers.eu/journals/jemt/jemt-issues.html     <na>
# 3152394     http://asers.eu/journals/jemt/jemt-issues.html     <na>
# 3169286     http://asers.eu/journals/jemt/jemt-issues.html     <na>
# 3157650     http://asers.eu/journals/jasf/jasf-issues.html     <na>
# 3163325     http://asers.eu/journals/jasf/jasf-issues.html     <na>
#
#         version_token_lp token_kind_lp  vnum_lp version_token_doi  \
# 2678434             None          None      NaN              None
# 2765475             None          None      NaN              None
# 2766088             None          None      NaN              None
# 3150826             None          None      NaN              None
# 2668133             None          None      NaN              None
# ...                  ...           ...      ...               ...
# 3195781             None          None      NaN              None
# 3152394             None          None      NaN              None
# 3169286             None          None      NaN              None
# 3157650             None          None      NaN              None
# 3163325             None          None      NaN              None
#
#         token_kind_doi  vnum_doi
# 2678434           None       NaN
# 2765475           None       NaN
# 2766088           None       NaN
# 3150826           None       NaN
# 2668133           None       NaN
# ...                ...       ...
# 3195781           None       NaN
# 3152394           None       NaN
# 3169286           None       NaN
# 3157650           None       NaN
# 3163325           None       NaN
#
# [1589 rows x 30 columns]

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='arXiv'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                    record_id server_name   backend  \
# 6438978  datacite::10.48550/arxiv.1911.02734       arXiv  datacite
# 6064798  datacite::10.48550/arxiv.1911.01396       arXiv  datacite
# 6473812  datacite::10.48550/arxiv.1905.11483       arXiv  datacite
# 6472098  datacite::10.48550/arxiv.1903.00148       arXiv  datacite
# 6496334  datacite::10.48550/arxiv.1901.02401       arXiv  datacite
# 6505988  datacite::10.48550/arxiv.1812.08127       arXiv  datacite
# 6505699  datacite::10.48550/arxiv.1812.07964       arXiv  datacite
# 6502106  datacite::10.48550/arxiv.1812.05819       arXiv  datacite
# 6509970  datacite::10.48550/arxiv.1811.10215       arXiv  datacite
# 6503045  datacite::10.48550/arxiv.1810.05321       arXiv  datacite
# 6496367  datacite::10.48550/arxiv.1810.01394       arXiv  datacite
# 6531855  datacite::10.48550/arxiv.1808.08324       arXiv  datacite
# 6528268  datacite::10.48550/arxiv.1808.04695       arXiv  datacite
# 6536857  datacite::10.48550/arxiv.1806.01247       arXiv  datacite
# 6559383  datacite::10.48550/arxiv.1802.06541       arXiv  datacite
# 6563854  datacite::10.48550/arxiv.1802.04480       arXiv  datacite
# 6555847  datacite::10.48550/arxiv.1802.02818       arXiv  datacite
# 7189438  datacite::10.48550/arxiv.1711.10020       arXiv  datacite
# 6590993  datacite::10.48550/arxiv.1711.09763       arXiv  datacite
# 6589354  datacite::10.48550/arxiv.1711.08811       arXiv  datacite
# 6582406  datacite::10.48550/arxiv.1711.01852       arXiv  datacite
# 7184492  datacite::10.48550/arxiv.1710.09634       arXiv  datacite
# 6585297  datacite::10.48550/arxiv.1710.05607       arXiv  datacite
# 6584437  datacite::10.48550/arxiv.1710.04715       arXiv  datacite
# 6591655  datacite::10.48550/arxiv.1709.09845       arXiv  datacite
# 6589425  datacite::10.48550/arxiv.1709.08497       arXiv  datacite
# 6582530  datacite::10.48550/arxiv.1709.02889       arXiv  datacite
# 6582388  datacite::10.48550/arxiv.1709.02749       arXiv  datacite
# 6582980  datacite::10.48550/arxiv.1709.02598       arXiv  datacite
# 6582195  datacite::10.48550/arxiv.1709.02545       arXiv  datacite
# 6580754  datacite::10.48550/arxiv.1709.01290       arXiv  datacite
# 6580159  datacite::10.48550/arxiv.1709.00841       arXiv  datacite
# 6579851  datacite::10.48550/arxiv.1709.00618       arXiv  datacite
# 6579370  datacite::10.48550/arxiv.1709.00288       arXiv  datacite
# 6579092  datacite::10.48550/arxiv.1709.00100       arXiv  datacite
# 6605865  datacite::10.48550/arxiv.1708.09674       arXiv  datacite
# 6604943  datacite::10.48550/arxiv.1708.08747       arXiv  datacite
# 6604476  datacite::10.48550/arxiv.1708.08264       arXiv  datacite
# 6603380  datacite::10.48550/arxiv.1708.07318       arXiv  datacite
# 6590523  datacite::10.48550/arxiv.1707.03211       arXiv  datacite
# 7200537  datacite::10.48550/arxiv.1706.10210       arXiv  datacite
# 6610658  datacite::10.48550/arxiv.1706.08471       arXiv  datacite
# 6596029  datacite::10.48550/arxiv.1706.05223       arXiv  datacite
# 6608391  datacite::10.48550/arxiv.1706.01401       arXiv  datacite
# 6620154  datacite::10.48550/arxiv.1705.05147       arXiv  datacite
# 6614991  datacite::10.48550/arxiv.1703.02360       arXiv  datacite
#
#                                doi                                    doi_url  \
# 6438978  10.48550/arxiv.1911.02734  https://doi.org/10.48550/arxiv.1911.02734
# 6064798  10.48550/arxiv.1911.01396  https://doi.org/10.48550/arxiv.1911.01396
# 6473812  10.48550/arxiv.1905.11483  https://doi.org/10.48550/arxiv.1905.11483
#
#                                                      title  \
# 6438978  Dipolar condensed atomic mixtures and miscibil...
# 6064798   D meson sensitivity to a system size scan at LHC
# 6473812  Scaling properties of firearm homicides in Bra...
# 6472098  Comment on Daya Bay's definition and use of De...
# 6496334  The Buzzard Flock: Dark Energy Survey Syntheti...
# 6505988  Nuclear Dependence of Transverse Single-Spin A...
# 6505699  Searches for Higgs bosons with dark matter at ...
# 6502106                               Top quark properties
# 6509970                Higgs boson measurements at the LHC
# 6503045    PHENIX results on collectivity in small systems
# 6496367  Muon Spectrometer Phase-I Upgrade for the ATLA...
# 6531855  Phase factors of periodically driven two-level...
# 6528268             Searches for new heavy quarks in ATLAS
# 6536857  Non-Extensive Transport Equations in Magnetize...
# 6559383                      Electroweak probes with ATLAS
# 6563854  RoboChain: A Secure Data-Sharing Framework for...
# 6555847                       Soft QCD measurements at LHC
# 7189438  Renormalization group equation for Tsallis sta...
# 6590993                            Top quark mass in ATLAS
# 6589354  Machine Learning Algorithms for $b$-Jet Taggin...
# 6582406  Search for flavour-changing neutral currents w...
# 7184492  Charmonium production in p-Pb collisions with ...
# 6585297  The ALICE O2 common driver for the C-RORC and ...
# 6584437             New results on collectivity with ALICE
# 6591655  Measurements of the top quark mass with the AT...
# 6589425  Machine and deep learning techniques in heavy-...
# 6582530             Jet and photon measurements with ATLAS
# 6582388  SM and BSM physics in single top quark at the LHC
# 6582980     Lepton and photon performance at ATLAS and CMS
# 6582195  Quarkonium production in proton-proton collisi...
# 6580754                         b tagging in ATLAS and CMS
# 6580159              Single top t-channel in ATLAS and CMS
# 6579851  Tracking performance in high multiplicities en...
# 6579370       Particle identification performance at ALICE
# 6579092  Performance of the ATLAS hadronic Tile calorim...
# 6605865                  Searches for Dark Matter in ATLAS
# 6604943  Production of vector bosons in association wit...
# 6604476            Boosted top production in ATLAS and CMS
# 6603380                High mass searches in CMS and ATLAS
# 6590523         Soft-QCD physics in pp and p-Pb with ALICE
# 7200537  Study of charged-particle multiplicities with ...
# 6610658  Loop groups and diffeomorphism groups of the c...
# 6596029  Open heavy-flavour measurements in pp and p--P...
# 6608391   The scaling structure of the global road network
# 6620154  Measurement of D-meson production in pp collis...
# 6614991  Single-top quark cross-section measurements in...
#
#                                               authors_flat publication_year  \
# 6438978  Tomio, Lauro; Kumar, Ramavarmaraja Kishor; Gam...           2019.0
# 6064798  Katz, Roland; Noronha-Hostler, Jacquelyn; Prad...           2019.0
# 6473812                                    Deppman, Airton           2019.0
# 6472098      Parke, Stephen J.; Funchal, Renata Zukanovich           2019.0
# 6496334  DeRose, Joseph; Wechsler, Risa H.; Becker, Mat...           2019.0
# 6505988                                      Pate, Stephen           2018.0
# 6505699                                 Gallinaro, Michele           2018.0
# 6502106                                 Van Mulders, Petra           2018.0
# 6509970                                    Unal, Guillaume           2018.0
# 6503045                                     Morrow, Sylvia           2018.0
# 6496367                                   Lefebvre, Benoit           2018.0
# 6531855         Gontijo, Marcela Muniz; Barata, João C. A.           2018.0
# 6528268                               Nikiforou, Nikiforos           2018.0
# 6582388  https://arxiv.org/abs/1709.02749  10.48550/arxiv.1709.02749
# 6582980  https://arxiv.org/abs/1709.02598  10.48550/arxiv.1709.02598
# 6582195  https://arxiv.org/abs/1709.02545  10.48550/arxiv.1709.02545
# 6580754  https://arxiv.org/abs/1709.01290  10.48550/arxiv.1709.01290
# 6580159  https://arxiv.org/abs/1709.00841  10.48550/arxiv.1709.00841
# 6579851  https://arxiv.org/abs/1709.00618  10.48550/arxiv.1709.00618
# 6579370  https://arxiv.org/abs/1709.00288  10.48550/arxiv.1709.00288
# 6579092  https://arxiv.org/abs/1709.00100  10.48550/arxiv.1709.00100
# 6605865  https://arxiv.org/abs/1708.09674  10.48550/arxiv.1708.09674
# 6604943  https://arxiv.org/abs/1708.08747  10.48550/arxiv.1708.08747
# 6604476  https://arxiv.org/abs/1708.08264  10.48550/arxiv.1708.08264
# 6603380  https://arxiv.org/abs/1708.07318  10.48550/arxiv.1708.07318
# 6590523  https://arxiv.org/abs/1707.03211  10.48550/arxiv.1707.03211
# 7200537  https://arxiv.org/abs/1706.10210  10.48550/arxiv.1706.10210
# 6610658  https://arxiv.org/abs/1706.08471  10.48550/arxiv.1706.08471
# 6596029  https://arxiv.org/abs/1706.05223  10.48550/arxiv.1706.05223
# 6608391  https://arxiv.org/abs/1706.01401  10.48550/arxiv.1706.01401
# 6620154  https://arxiv.org/abs/1705.05147  10.48550/arxiv.1705.05147
# 6614991  https://arxiv.org/abs/1703.02360  10.48550/arxiv.1703.02360
#
#         version_token_lp token_kind_lp  vnum_lp version_token_doi  \
# 6438978             None          None      NaN              None
# 6064798             None          None      NaN              None
# 6473812             None          None      NaN              None
# 6472098             None          None      NaN              None
# 6496334             None          None      NaN              None
# 6505988             None          None      NaN              None
# 6505699             None          None      NaN              None
# 6502106             None          None      NaN              None
# 6509970             None          None      NaN              None
# 6503045             None          None      NaN              None
# 6496367             None          None      NaN              None
# 6531855             None          None      NaN              None
# 6528268             None          None      NaN              None
# 6536857             None          None      NaN              None
# 6559383             None          None      NaN              None
# 6563854             None          None      NaN              None
# 6555847             None          None      NaN              None
# 7189438             None          None      NaN              None
# 6590993             None          None      NaN              None
# 6589354             None          None      NaN              None
# 6582406             None          None      NaN              None
# 7184492             None          None      NaN              None
# 6585297             None          None      NaN              None
# 6584437             None          None      NaN              None
# 6591655             None          None      NaN              None
# 6589425             None          None      NaN              None
# 6582530             None          None      NaN              None
# 6582388             None          None      NaN              None
# 6582980             None          None      NaN              None
# 6582195             None          None      NaN              None
# 6580754             None          None      NaN              None
# 6580159             None          None      NaN              None
# 6579851             None          None      NaN              None
# 6579370             None          None      NaN              None
# 6579092             None          None      NaN              None
# 6605865             None          None      NaN              None
# 6604943             None          None      NaN              None
# 6604476             None          None      NaN              None
# 6603380             None          None      NaN              None
# 6590523             None          None      NaN              None
# 7200537             None          None      NaN              None
# 6610658             None          None      NaN              None
# 6596029             None          None      NaN              None
# 6608391             None          None      NaN              None
# 6620154             None          None      NaN              None
# 6614991             None          None      NaN              None
#
#         token_kind_doi  vnum_doi
# 6438978           None       NaN
# 6064798           None       NaN
# 6473812           None       NaN
# 6472098           None       NaN
# 6496334           None       NaN
# 6505988           None       NaN
# 6505699           None       NaN
# 6502106           None       NaN
# 6509970           None       NaN
# 6503045           None       NaN
# 6496367           None       NaN
# 6531855           None       NaN
# 6528268           None       NaN
# 6536857           None       NaN
# 6559383           None       NaN
# 6563854           None       NaN
# 6555847           None       NaN
# 7189438           None       NaN
# 6590993           None       NaN
# 6589354           None       NaN
# 6582406           None       NaN
# 7184492           None       NaN
# 6585297           None       NaN
# 6584437           None       NaN
# 6591655           None       NaN
# 6589425           None       NaN
# 6582530           None       NaN
# 6582388           None       NaN
# 6582980           None       NaN
# 6582195           None       NaN
# 6580754           None       NaN
# 6580159           None       NaN
# 6579851           None       NaN
# 6579370           None       NaN
# 6579092           None       NaN
# 6605865           None       NaN
# 6604943           None       NaN
# 6604476           None       NaN
# 6603380           None       NaN
# 6590523           None       NaN
# 7200537           None       NaN
# 6610658           None       NaN
# 6596029           None       NaN
# 6608391           None       NaN
# 6620154           None       NaN
# 6614991           None       NaN

# %%
df_mirror[df_mirror['landing_page_url']=='https://arxiv.org/abs/1703.02360']
# Out:
#                                    record_id                    server_name  \
# 6614991  datacite::10.48550/arxiv.1703.02360                          arXiv
# 2050450                openalex::W4300531380  Munich Personal RePEc Archive
#
#           backend                        doi  \
# 6614991  datacite  10.48550/arxiv.1703.02360
# 2050450  openalex                       <NA>
#
#                                            doi_url  \
# 6614991  https://doi.org/10.48550/arxiv.1703.02360
# 2050450                                       None
#
#                          landing_page_url  \
# 6614991  https://arxiv.org/abs/1703.02360
# 2050450  https://arxiv.org/abs/1703.02360
#
#                                                      title  \
# 6614991  Single-top quark cross-section measurements in...
# 2050450  Single-top quark cross-section measurements in...
#
#                  authors_flat publication_year         date_created  \
# 6614991  Hirschbuehl, Dominic           2017.0           2022-03-04
# 2050450        D. Hirschbuehl           2017.0  2025-10-10T00:00:00
#
#         relations_json version_label is_version_of is_preprint_of  \
# 6614991             []             1
# 2050450           None          None          None           None
#
#         has_preprint has_review has_published_version  \
# 6614991                                         false
# 2050450         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 6614991                       None                None           None
# 2050450                       None                None           None
#
#                                     raw_relationships_json records_hierarchy  \
# 6614991  {"client": {"data": {"id": "arxiv.content", "t...            parent
# 2050450                                               None            parent
#
#                              landing_norm                   doi_norm  \
# 6614991  https://arxiv.org/abs/1703.02360  10.48550/arxiv.1703.02360
# 2050450  https://arxiv.org/abs/1703.02360                       <na>
#
#         version_token_lp token_kind_lp  vnum_lp version_token_doi  \
# 6614991             None          None      NaN              None
# 2050450             None          None      NaN              None
#
#         token_kind_doi  vnum_doi
# 6614991           None       NaN
# 2050450           None       NaN

# %%
df_mirror[df_mirror['landing_page_url']=='https://www.nber.org/chapters/c9003.pdf']
# Out:
#                      record_id                          server_name   backend  \
# 2664750    openalex::W13745406  RePEc: Research Papers in Economics  openalex
# 2668133  openalex::W2418493038  RePEc: Research Papers in Economics  openalex
#
#           doi doi_url                         landing_page_url  \
# 2664750  <NA>    None  https://www.nber.org/chapters/c9003.pdf
# 2668133  <NA>    None  https://www.nber.org/chapters/c9003.pdf
#
#                                                      title   authors_flat  \
# 2664750  Introduction to "Concentrated Corporate Owners...  Randall Mørck
# 2668133  Introduction to "Concentrated Corporate Owners...     Felix Sahm
#
#         publication_year         date_created relations_json version_label  \
# 2664750           2000.0  2025-10-10T00:00:00           None          None
# 2668133           2000.0  2016-06-24T00:00:00           None          None
#
#         is_version_of is_preprint_of has_preprint has_review  \
# 2664750          None           None         None       None
# 2668133          None           None         None       None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 2664750                  None                       None                None
# 2668133                  None                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 2664750           None                   None            parent
# 2668133           None                   None            parent
#
#                                     landing_norm doi_norm version_token_lp  \
# 2664750  https://www.nber.org/chapters/c9003.pdf     <na>             None
# 2668133  https://www.nber.org/chapters/c9003.pdf     <na>             None
#
#         token_kind_lp  vnum_lp version_token_doi token_kind_doi  vnum_doi
# 2664750          None      NaN              None           None       NaN
# 2668133          None      NaN              None           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='Qeios'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                                  record_id server_name  \
# 2571958                          crossref::10.32388/045113       Qeios
# 2572398                          crossref::10.32388/fopnva       Qeios
# 2572387                        crossref::10.32388/d8ebqn.3       Qeios
# 2572459                        crossref::10.32388/d8ebqn.4       Qeios
# 2567916                          crossref::10.32388/dtdoz7       Qeios
# ...                                                    ...         ...
# 2618389                    crossref::10.32388/subst.test.1       Qeios
# 2618460  crossref::10.32388/subst.lyons.modern_cinema_s...       Qeios
# 2618575  crossref::10.32388/subst.lyons.modern_cinema.2025       Qeios
# 2618459  crossref::10.32388/subst.lyons.knights_vs_snai...       Qeios
# 2618574  crossref::10.32388/subst.lyons.knight_vs_snail...       Qeios
#
#           backend                                             doi  \
# 2571958  crossref                                 10.32388/045113
# 2572398  crossref                                 10.32388/fopnva
# 2572387  crossref                               10.32388/d8ebqn.3
# 2572459  crossref                               10.32388/d8ebqn.4
# 2567916  crossref                                 10.32388/dtdoz7
# ...           ...                                             ...
# 2618389  crossref                           10.32388/subst.test.1
# 2618460  crossref  10.32388/subst.lyons.modern_cinema_snails.2025
# 2618575  crossref         10.32388/subst.lyons.modern_cinema.2025
# 2618459  crossref     10.32388/subst.lyons.knights_vs_snails.2025
# 2618574  crossref       10.32388/subst.lyons.knight_vs_snail.2025
#
#                                                    doi_url  \
# 2571958                    https://doi.org/10.32388/045113
# 2572398                    https://doi.org/10.32388/fopnva
# 2572387                  https://doi.org/10.32388/d8ebqn.3
# 2572459                  https://doi.org/10.32388/d8ebqn.4
# 2567916                    https://doi.org/10.32388/dtdoz7
# ...                                                    ...
# 2618389              https://doi.org/10.32388/subst.test.1
# 2618460  https://doi.org/10.32388/subst.lyons.modern_ci...
# 2618575  https://doi.org/10.32388/subst.lyons.modern_ci...
# 2618459  https://doi.org/10.32388/subst.lyons.knights_v...
# 2618574  https://doi.org/10.32388/subst.lyons.knight_vs...
#
#                                           landing_page_url  \
# 2571958               https://www.qeios.com/withdrawn-work
# 2572398               https://www.qeios.com/withdrawn-work
# 2572387               https://www.qeios.com/withdrawn-work
# 2572459               https://www.qeios.com/withdrawn-work
# 2567916               https://www.qeios.com/withdrawn-work
# ...                                                    ...
# 2618389             https://www.qeios.com/tmp-test-subst-1
# 2618460  https://qeios.com/read/substack-lyons-snails-i...
# 2618575  https://qeios.com/read/substack-lyons-snails-i...
# 2618459  https://qeios.com/read/substack-lyons-knights-...
# 2618574  https://qeios.com/read/substack-lyons-knights-...
#
#                                                      title  \
# 2571958                                          WITHDRAWN
# 2572398                                          WITHDRAWN
# 2572387                                          WITHDRAWN
# 2572459                                          WITHDRAWN
# 2567916                                          WITHDRAWN
# ...                                                    ...
# 2618389  The History of Chocolate: From Ancient Beginni...
# 2618460  Snails in Modern Cinema: From Speed Dreams to ...
# 2618575  Snails in Modern Cinema: From Speed Dreams to ...
# 2618459  Knights vs. Snails: A History of a Tiny, Tenac...
# 2618574  Knights vs. Snails: A History of a Tiny, Tenac...
#
#                 authors_flat publication_year date_created relations_json  \
# 2571958            Doe, Jane           2020.0   2019-09-06           None
# 2572398            Doe, Jane           2020.0   2022-07-07           None
# 2572387            Doe, Jane           2020.0   2021-04-29           None
# 2572459            Doe, Jane           2020.0   2021-05-01           None
# 2567916            Doe, Jane           2020.0   2022-10-06           None
# ...                      ...              ...          ...            ...
# 2618389  Marinello, Gabriele           2025.0   2025-08-05           None
# 2618460        Lyons, Mansel           2025.0   2025-08-13           None
# 2618575        Lyons, Mansel           2025.0   2025-08-29           None
# 2618459        Lyons, Mansel           2025.0   2025-08-13           None
# 2618574        Lyons, Mansel           2025.0   2025-08-29           None
#
#         version_label is_version_of is_preprint_of has_preprint has_review  \
# 2571958          None
# 2572398          None
# 2572387          None
# 2572459          None
# 2567916          None
# ...               ...           ...            ...          ...        ...
# 2618389          None
# 2618460          None
# 2618575          None
# 2618459          None
# 2618574          None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 2571958                 false                       None                None
# 2572398                 false                       None                None
# 2572387                 false                       None                None
# 2572459                 false                       None                None
# 2567916                 false                       None                None
# ...                       ...                        ...                 ...
# 2618389                 false                       None                None
# 2618460                 false                       None                None
# 2618575                 false                       None                None
# 2618459                 false                       None                None
# 2618574                 false                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 2571958           None                   None            parent
# 2572398           None                   None            parent
# 2572387           None                   None            parent
# 2572459           None                   None            parent
# 2567916           None                   None            parent
# ...                ...                    ...               ...
# 2618389           None                   None            parent
# 2618460           None                   None            parent
# 2618575           None                   None            parent
# 2618459           None                   None            parent
# 2618574           None                   None            parent
#
#                                               landing_norm  \
# 2571958               https://www.qeios.com/withdrawn-work
# 2572398               https://www.qeios.com/withdrawn-work
# 2572387               https://www.qeios.com/withdrawn-work
# 2572459               https://www.qeios.com/withdrawn-work
# 2567916               https://www.qeios.com/withdrawn-work
# ...                                                    ...
# 2618389             https://www.qeios.com/tmp-test-subst-1
# 2618460  https://qeios.com/read/substack-lyons-snails-i...
# 2618575  https://qeios.com/read/substack-lyons-snails-i...
# 2618459  https://qeios.com/read/substack-lyons-knights-...
# 2618574  https://qeios.com/read/substack-lyons-knights-...
#
#                                                doi_norm version_token_lp  \
# 2571958                                 10.32388/045113             None
# 2572398                                 10.32388/fopnva             None
# 2572387                               10.32388/d8ebqn.3             None
# 2572459                               10.32388/d8ebqn.4             None
# 2567916                                 10.32388/dtdoz7             None
# ...                                                 ...              ...
# 2618389                           10.32388/subst.test.1             None
# 2618460  10.32388/subst.lyons.modern_cinema_snails.2025             None
# 2618575         10.32388/subst.lyons.modern_cinema.2025             None
# 2618459     10.32388/subst.lyons.knights_vs_snails.2025             None
# 2618574       10.32388/subst.lyons.knight_vs_snail.2025             None
#
#         token_kind_lp  vnum_lp version_token_doi token_kind_doi  vnum_doi
# 2571958          None      NaN              None           None       NaN
# 2572398          None      NaN              None           None       NaN
# 2572387          None      NaN              None           None       NaN
# 2572459          None      NaN              None           None       NaN
# 2567916          None      NaN              None           None       NaN
# ...               ...      ...               ...            ...       ...
# 2618389          None      NaN              None           None       NaN
# 2618460          None      NaN              None           None       NaN
# 2618575          None      NaN              None           None       NaN
# 2618459          None      NaN              None           None       NaN
# 2618574          None      NaN              None           None       NaN
#
# [191 rows x 30 columns]

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='ResearchHub'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                          record_id  server_name   backend  \
# 3503777    crossref::10.55277/researchhub.8i2kymwh  ResearchHub  crossref
# 3503779    crossref::10.55277/researchhub.7ewvh0rf  ResearchHub  crossref
# 3503778    crossref::10.55277/researchhub.2ihlexrg  ResearchHub  crossref
# 3503776    crossref::10.55277/researchhub.lrtyw6ah  ResearchHub  crossref
# 3503976            crossref::10.55277/rhj.8ksztm1x  ResearchHub  crossref
# ...                                            ...          ...       ...
# 3503708  crossref::10.55277/researchhub.s485ohw7.1  ResearchHub  crossref
# 3503644    crossref::10.55277/researchhub.71mugn7l  ResearchHub  crossref
# 3503703  crossref::10.55277/researchhub.71mugn7l.1  ResearchHub  crossref
# 3503710  crossref::10.55277/researchhub.hmhp8upd.1  ResearchHub  crossref
# 3503643    crossref::10.55277/researchhub.hmhp8upd  ResearchHub  crossref
#
#                                      doi  \
# 3503777    10.55277/researchhub.8i2kymwh
# 3503779    10.55277/researchhub.7ewvh0rf
# 3503778    10.55277/researchhub.2ihlexrg
# 3503776    10.55277/researchhub.lrtyw6ah
# 3503976            10.55277/rhj.8ksztm1x
# ...                                  ...
# 3503708  10.55277/researchhub.s485ohw7.1
# 3503644    10.55277/researchhub.71mugn7l
# 3503703  10.55277/researchhub.71mugn7l.1
# 3503710  10.55277/researchhub.hmhp8upd.1
# 3503643    10.55277/researchhub.hmhp8upd
#
#                                                  doi_url  \
# 3503777    https://doi.org/10.55277/researchhub.8i2kymwh
# 3503779    https://doi.org/10.55277/researchhub.7ewvh0rf
# 3503778    https://doi.org/10.55277/researchhub.2ihlexrg
# 3503776    https://doi.org/10.55277/researchhub.lrtyw6ah
# 3503976            https://doi.org/10.55277/rhj.8ksztm1x
# ...                                                  ...
# 3503708  https://doi.org/10.55277/researchhub.s485ohw7.1
# 3503644    https://doi.org/10.55277/researchhub.71mugn7l
# 3503703  https://doi.org/10.55277/researchhub.71mugn7l.1
# 3503710  https://doi.org/10.55277/researchhub.hmhp8upd.1
# 3503643    https://doi.org/10.55277/researchhub.hmhp8upd
#
#                                           landing_page_url  \
# 3503777  https://www.staging.researchhub.com/post/321/r...
# 3503779  https://www.staging.researchhub.com/post/321/r...
# 3503778  https://www.staging.researchhub.com/post/321/r...
# 3503776  https://www.staging.researchhub.com/post/321/r...
# 3503976  https://www.staging.researchhub.com/paper/3236...
# ...                                                    ...
# 3503708  https://www.researchhub.com/paper/8437957/fini...
# 3503644  https://www.researchhub.com/paper/8420046/alte...
# 3503703  https://www.researchhub.com/paper/8420046/alte...
# 3503710  https://www.researchhub.com/paper/8420045/fini...
# 3503643  https://www.researchhub.com/paper/8420045/fini...
#
#                                                      title  \
# 3503777                     02.26 Preregistration template
# 3503779                 02.26 Preregistration template v 3
# 3503778                     02.26 Preregistration template
# 3503776                           Research Article Title 2
# 3503976                                In the test journal
# ...                                                    ...
# 3503708  Finite Density Black Holes in a Quantum Gravit...
# 3503644  Alternate EoS for Finite Density Black Holes i...
# 3503703  Alternate EoS for Finite Density Black Holes i...
# 3503710  Finite Density Black Holes in a Quantum Gravit...
# 3503643  Finite Density Black Holes in a Quantum Gravit...
#
#                                authors_flat publication_year date_created  \
# 3503777                   Tytarenko, Mykola           2025.0   2025-02-26
# 3503779                   Tytarenko, Mykola           2025.0   2025-02-26
# 3503778                   Tytarenko, Mykola           2025.0   2025-02-26
# 3503776                   Tytarenko, Mykola           2025.0   2025-02-26
# 3503976                             K, Taki           2025.0   2025-05-29
# ...                                     ...              ...          ...
# 3503708  Brown, Jesse Daniel; Smith, McCade           2025.0   2025-01-09
# 3503644  Brown, Jesse Daniel; Smith, McCade           2024.0   2024-11-21
# 3503703  Brown, Jesse Daniel; Smith, McCade           2025.0   2025-01-09
# 3503710                       Smith, McCade           2025.0   2025-01-09
# 3503643  Brown, Jesse Daniel; Smith, McCade           2024.0   2024-11-21
#
#         relations_json version_label is_version_of is_preprint_of  \
# 3503777           None          None
# 3503779           None          None
# 3503778           None          None
# 3503776           None          None
# 3503976           None          None
# ...                ...           ...           ...            ...
# 3503708           None          None
# 3503644           None          None
# 3503703           None          None
# 3503710           None          None
# 3503643           None          None
#
#         has_preprint has_review has_published_version  \
# 3503777                                         false
# 3503779                                         false
# 3503778                                         false
# 3503776                                         false
# 3503976                                         false
# ...              ...        ...                   ...
# 3503708                                         false
# 3503644                                         false
# 3503703                                         false
# 3503710                                         false
# 3503643                                         false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 3503777                       None                None           None
# 3503779                       None                None           None
# 3503778                       None                None           None
# 3503776                       None                None           None
# 3503976                       None                None           None
# ...                            ...                 ...            ...
# 3503708                       None                None           None
# 3503644                       None                None           None
# 3503703                       None                None           None
# 3503710                       None                None           None
# 3503643                       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 3503777                   None            parent
# 3503779                   None            parent
# 3503778                   None            parent
# 3503776                   None            parent
# 3503976                   None            parent
# ...                        ...               ...
# 3503708                   None            parent
# 3503644                   None            parent
# 3503703                   None            parent
# 3503710                   None            parent
# 3503643                   None            parent
#
#                                               landing_norm  \
# 3503777  https://www.staging.researchhub.com/post/321/r...
# 3503779  https://www.staging.researchhub.com/post/321/r...
# 3503778  https://www.staging.researchhub.com/post/321/r...
# 3503776  https://www.staging.researchhub.com/post/321/r...
# 3503976  https://www.staging.researchhub.com/paper/3236...
# ...                                                    ...
# 3503708  https://www.researchhub.com/paper/8437957/fini...
# 3503644  https://www.researchhub.com/paper/8420046/alte...
# 3503703  https://www.researchhub.com/paper/8420046/alte...
# 3503710  https://www.researchhub.com/paper/8420045/fini...
# 3503643  https://www.researchhub.com/paper/8420045/fini...
#
#                                 doi_norm version_token_lp token_kind_lp  \
# 3503777    10.55277/researchhub.8i2kymwh             None          None
# 3503779    10.55277/researchhub.7ewvh0rf             None          None
# 3503778    10.55277/researchhub.2ihlexrg             None          None
# 3503776    10.55277/researchhub.lrtyw6ah             None          None
# 3503976            10.55277/rhj.8ksztm1x             None          None
# ...                                  ...              ...           ...
# 3503708  10.55277/researchhub.s485ohw7.1             None          None
# 3503644    10.55277/researchhub.71mugn7l             None          None
# 3503703  10.55277/researchhub.71mugn7l.1             None          None
# 3503710  10.55277/researchhub.hmhp8upd.1             None          None
# 3503643    10.55277/researchhub.hmhp8upd             None          None
#
#          vnum_lp version_token_doi token_kind_doi  vnum_doi
# 3503777      NaN              None           None       NaN
# 3503779      NaN              None           None       NaN
# 3503778      NaN              None           None       NaN
# 3503776      NaN              None           None       NaN
# 3503976      NaN              None           None       NaN
# ...          ...               ...            ...       ...
# 3503708      NaN              None           None       NaN
# 3503644      NaN              None           None       NaN
# 3503703      NaN              None           None       NaN
# 3503710      NaN              None           None       NaN
# 3503643      NaN              None           None       NaN
#
# [171 rows x 30 columns]

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='Munich Personal RePEc Archive'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                      record_id                    server_name   backend  \
# 2028824  openalex::W2912141608  Munich Personal RePEc Archive  openalex
# 2044972  openalex::W2981721423  Munich Personal RePEc Archive  openalex
# 2045632  openalex::W3020944286  Munich Personal RePEc Archive  openalex
# 2016916  openalex::W2767144409  Munich Personal RePEc Archive  openalex
# 2050299  openalex::W4288027439  Munich Personal RePEc Archive  openalex
# ...                        ...                            ...       ...
# 2034783    openalex::W82458165  Munich Personal RePEc Archive  openalex
# 2089086  openalex::W4395677280  Munich Personal RePEc Archive  openalex
# 2062907  openalex::W4392339766  Munich Personal RePEc Archive  openalex
# 2038452    openalex::W20541881  Munich Personal RePEc Archive  openalex
# 2087273  openalex::W4394799740  Munich Personal RePEc Archive  openalex
#
#                                     doi  \
# 2028824   10.1111/twec.2014.37.issue-12
# 2044972   10.1111/twec.2014.37.issue-12
# 2045632  10.1111/ecca.2015.82.issue-328
# 2016916  10.1111/(issn)1542-4774/issues
# 2050299                            <NA>
# ...                                 ...
# 2034783                            <NA>
# 2089086                            <NA>
# 2062907                            <NA>
# 2038452                            <NA>
# 2087273                            <NA>
#
#                                                 doi_url  \
# 2028824   https://doi.org/10.1111/twec.2014.37.issue-12
# 2044972   https://doi.org/10.1111/twec.2014.37.issue-12
# 2045632  https://doi.org/10.1111/ecca.2015.82.issue-328
# 2016916  https://doi.org/10.1111/(issn)1542-4774/issues
# 2050299                                            None
# ...                                                 ...
# 2034783                                            None
# 2089086                                            None
# 2062907                                            None
# 2038452                                            None
# 2087273                                            None
#
#                                        landing_page_url  \
# 2028824   https://doi.org/10.1111/twec.2014.37.issue-12
# 2044972   https://doi.org/10.1111/twec.2014.37.issue-12
# 2045632  https://doi.org/10.1111/ecca.2015.82.issue-328
# 2016916  https://doi.org/10.1111/(issn)1542-4774/issues
# 2050299                https://arxiv.org/abs/1911.02734
# ...                                                 ...
# 2034783      http://www.theses.fr/2010INPT0096/document
# 2089086      http://www.theses.fr/2010INPT0029/document
# 2062907      http://www.theses.fr/2010INPT0029/document
# 2038452      http://www.theses.fr/2010CLF22073/document
# 2087273      http://www.theses.fr/2010CLF22073/document
#
#                                                      title  \
# 2028824  The paradox of “preferences”: regional trade a...
# 2044972                   United Arab Emirates FDI Outlook
# 2045632  Does cigarette smoking affect body weight? cau...
# 2016916          Inattentive consumers and product quality
# 2050299  Dipolar condensed atomic mixtures and miscibil...
# ...                                                    ...
# 2034783  Gestion autonomique de performance, d'énergie ...
# 2089086  Architectures innovantes de systèmes de comman...
# 2062907  Innovative Architectures of Flight Control Sys...
# 2038452  Synthèse d'aminocyclitols, inhibiteurs potenti...
# 2087273  Synthesis of aminocyclitols, potential inhibit...
#
#                                     authors_flat publication_year  \
# 2028824         Sébastien Miroudot; Ben Shepherd           2012.0
# 2044972                             Wasseem Mina           2013.0
# 2045632               Luca Pieroni; Luca Salmasi           2012.0
# 2016916             Mark Armstrong; Yongmin Chen           2009.0
# 2050299  Lauro Tomio; R. Kishor Kumar; A. Gammal           2019.0
# ...                                          ...              ...
# 2034783                            Rémi Sharrock           2010.0
# 2089086                    Manel Sghairi Haouati           2010.0
# 2062907                    Manel Sghairi Haouati           2010.0
# 2038452                         Flora Camps Bres           2010.0
# 2087273                         Flora Camps Bres           2010.0
#
#                 date_created relations_json version_label is_version_of  \
# 2028824  2025-10-10T00:00:00           None          None          None
# 2044972  2025-10-10T00:00:00           None          None          None
# 2045632  2025-10-10T00:00:00           None          None          None
# 2016916  2025-10-10T00:00:00           None          None          None
# 2050299  2025-10-10T00:00:00           None          None          None
# ...                      ...            ...           ...           ...
# 2034783  2025-10-10T00:00:00           None          None          None
# 2089086  2025-10-10T00:00:00           None          None          None
# 2062907  2024-03-05T00:00:00           None          None          None
# 2038452  2016-06-24T00:00:00           None          None          None
# 2087273  2024-04-15T00:00:00           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 2028824           None         None       None                  None
# 2044972           None         None       None                  None
# 2045632           None         None       None                  None
# 2016916           None         None       None                  None
# 2050299           None         None       None                  None
# ...                ...          ...        ...                   ...
# 2034783           None         None       None                  None
# 2089086           None         None       None                  None
# 2062907           None         None       None                  None
# 2038452           None         None       None                  None
# 2087273           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 2028824                       None                None           None
# 2044972                       None                None           None
# 2045632                       None                None           None
# 2016916                       None                None           None
# 2050299                       None                None           None
# ...                            ...                 ...            ...
# 2034783                       None                None           None
# 2089086                       None                None           None
# 2062907                       None                None           None
# 2038452                       None                None           None
# 2087273                       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 2028824                   None            parent
# 2044972                   None            parent
# 2045632                   None            parent
# 2016916                   None            parent
# 2050299                   None            parent
# ...                        ...               ...
# 2034783                   None            parent
# 2089086                   None            parent
# 2062907                   None            parent
# 2038452                   None            parent
# 2087273                   None            parent
#
#                                            landing_norm  \
# 2028824   https://doi.org/10.1111/twec.2014.37.issue-12
# 2044972   https://doi.org/10.1111/twec.2014.37.issue-12
# 2045632  https://doi.org/10.1111/ecca.2015.82.issue-328
# 2016916  https://doi.org/10.1111/(issn)1542-4774/issues
# 2050299                https://arxiv.org/abs/1911.02734
# ...                                                 ...
# 2034783      http://www.theses.fr/2010inpt0096/document
# 2089086      http://www.theses.fr/2010inpt0029/document
# 2062907      http://www.theses.fr/2010inpt0029/document
# 2038452      http://www.theses.fr/2010clf22073/document
# 2087273      http://www.theses.fr/2010clf22073/document
#
#                                doi_norm version_token_lp token_kind_lp  \
# 2028824   10.1111/twec.2014.37.issue-12             None          None
# 2044972   10.1111/twec.2014.37.issue-12             None          None
# 2045632  10.1111/ecca.2015.82.issue-328             None          None
# 2016916  10.1111/(issn)1542-4774/issues             None          None
# 2050299                            <na>             None          None
# ...                                 ...              ...           ...
# 2034783                            <na>             None          None
# 2089086                            <na>             None          None
# 2062907                            <na>             None          None
# 2038452                            <na>             None          None
# 2087273                            <na>             None          None
#
#          vnum_lp version_token_doi token_kind_doi  vnum_doi
# 2028824      NaN              None           None       NaN
# 2044972      NaN              None           None       NaN
# 2045632      NaN              None           None       NaN
# 2016916      NaN              None           None       NaN
# 2050299      NaN              None           None       NaN
# ...          ...               ...            ...       ...
# 2034783      NaN              None           None       NaN
# 2089086      NaN              None           None       NaN
# 2062907      NaN              None           None       NaN
# 2038452      NaN              None           None       NaN
# 2087273      NaN              None           None       NaN
#
# [169 rows x 30 columns]

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='AgEcon Search'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                record_id    server_name   backend  \
# 57448   datacite::10.22004/ag.econ.98631  AgEcon Search  datacite
# 56302   datacite::10.22004/ag.econ.95334  AgEcon Search  datacite
# 56299   datacite::10.22004/ag.econ.95331  AgEcon Search  datacite
# 56236   datacite::10.22004/ag.econ.95214  AgEcon Search  datacite
# 17846    datacite::10.22004/ag.econ.6543  AgEcon Search  datacite
# ...                                  ...            ...       ...
# 58451  datacite::10.22004/ag.econ.103153  AgEcon Search  datacite
# 58441  datacite::10.22004/ag.econ.103117  AgEcon Search  datacite
# 58405  datacite::10.22004/ag.econ.102769  AgEcon Search  datacite
# 58393  datacite::10.22004/ag.econ.102727  AgEcon Search  datacite
# 58263  datacite::10.22004/ag.econ.102226  AgEcon Search  datacite
#
#                            doi                                  doi_url  \
# 57448   10.22004/ag.econ.98631   https://doi.org/10.22004/ag.econ.98631
# 56302   10.22004/ag.econ.95334   https://doi.org/10.22004/ag.econ.95334
# 56299   10.22004/ag.econ.95331   https://doi.org/10.22004/ag.econ.95331
# 56236   10.22004/ag.econ.95214   https://doi.org/10.22004/ag.econ.95214
# 17846    10.22004/ag.econ.6543    https://doi.org/10.22004/ag.econ.6543
# ...                        ...                                      ...
# 58451  10.22004/ag.econ.103153  https://doi.org/10.22004/ag.econ.103153
# 58441  10.22004/ag.econ.103117  https://doi.org/10.22004/ag.econ.103117
# 58405  10.22004/ag.econ.102769  https://doi.org/10.22004/ag.econ.102769
# 58393  10.22004/ag.econ.102727  https://doi.org/10.22004/ag.econ.102727
# 58263  10.22004/ag.econ.102226  https://doi.org/10.22004/ag.econ.102226
#
#                                  landing_page_url  \
# 57448   https://ageconsearch.umn.edu/record/98631
# 56302   https://ageconsearch.umn.edu/record/95334
# 56299   https://ageconsearch.umn.edu/record/95331
# 56236   https://ageconsearch.umn.edu/record/95214
# 17846    https://ageconsearch.umn.edu/record/6543
# ...                                           ...
# 58451  https://ageconsearch.umn.edu/record/103153
# 58441  https://ageconsearch.umn.edu/record/103117
# 58405  https://ageconsearch.umn.edu/record/102769
# 58393  https://ageconsearch.umn.edu/record/102727
# 58263  https://ageconsearch.umn.edu/record/102226
#
#                                                    title  \
# 57448        What do Haitians need after the earthquake?
# 56302  Análisis de la ampliación de los recursos loca...
# 56299  LAS VIAS PECUARIAS Y LA PLANIFICACION TERRITORIAL
# 56236  Los cambios en la división internacional del t...
# 17846  School District and Municipal Reorganization: ...
# ...                                                  ...
# 58451  PRODUÇÃO DE FLORES EM UMUARAMA, NOROESTE DO PA...
# 58441  A Trajetória das Pesquisas com Práticas Agríco...
# 58405  COOPERATIVAS COMO FORMA DE ORGANIZAÇÃO DA AGRI...
# 58393             The Value of EU Agricultural Landscape
# 58263  UMA ABORDAGEM APLICADA DE COMPONENTES PRINCIPA...
#
#                                             authors_flat publication_year  \
# 57448                       Andre, Rock; Lusk, Jayson L.           2011.0
# 56302                       Marin-Sanchez, Maria Del Mar           2010.0
# 56299  Guaita Pradas, Inmaculada; Barrachina Martinez...           2010.0
# 56236                   Pensado Leglise, Mario Del Roble           2010.0
# 17846                                     Scorsone, Eric           2007.0
# ...                                                  ...              ...
# 58451  Morita, Daniela Alves Dos Santos; Dias-Arieira...           2008.0
# 58441                     Borges Filho, Epaminondas Luiz           2008.0
# 58405  Rosa, Nadir Paula Da; Lago, Adriano; Santos Ju...           2008.0
# 58393              Pavel, Ciaian; Gomez Y Paloma, Sergio           2011.0
# 58263  Marzano Araujo, Vanessa; Mota, Vania Correa; D...           2008.0
#
#       date_created relations_json version_label is_version_of is_preprint_of  \
# 57448   2019-08-24             []          None
# 56302   2019-08-24             []          None
# 56299   2019-08-24             []          None
# 56236   2019-08-24             []          None
# 17846   2019-08-23             []          None
# ...            ...            ...           ...           ...            ...
# 58451   2019-08-24             []          None
# 58441   2019-08-24             []          None
# 58405   2019-08-24             []          None
# 58393   2019-08-24             []          None
# 58263   2019-08-24             []          None
#
#       has_preprint has_review has_published_version  \
# 57448                                         false
# 56302                                         false
# 56299                                         false
# 56236                                         false
# 17846                                         false
# ...            ...        ...                   ...
# 58451                                         false
# 58441                                         false
# 58405                                         false
# 58393                                         false
# 58263                                         false
#
#       published_version_ids_json version_of_ids_json update_to_json  \
# 57448                       None                None           None
# 56302                       None                None           None
# 56299                       None                None           None
# 56236                       None                None           None
# 17846                       None                None           None
# ...                          ...                 ...            ...
# 58451                       None                None           None
# 58441                       None                None           None
# 58405                       None                None           None
# 58393                       None                None           None
# 58263                       None                None           None
#
#                                   raw_relationships_json records_hierarchy  \
# 57448  {"client": {"data": {"id": "tind.agecon", "typ...            parent
# 56302  {"client": {"data": {"id": "tind.agecon", "typ...            parent
# 56299  {"client": {"data": {"id": "tind.agecon", "typ...            parent
# 56236  {"client": {"data": {"id": "tind.agecon", "typ...            parent
# 17846  {"client": {"data": {"id": "tind.agecon", "typ...            parent
# ...                                                  ...               ...
# 58451  {"client": {"data": {"id": "tind.agecon", "typ...            parent
# 58441  {"client": {"data": {"id": "tind.agecon", "typ...            parent
# 58405  {"client": {"data": {"id": "tind.agecon", "typ...            parent
# 58393  {"client": {"data": {"id": "tind.agecon", "typ...            parent
# 58263  {"client": {"data": {"id": "tind.agecon", "typ...            parent
#
#                                      landing_norm                 doi_norm  \
# 57448   https://ageconsearch.umn.edu/record/98631   10.22004/ag.econ.98631
# 56302   https://ageconsearch.umn.edu/record/95334   10.22004/ag.econ.95334
# 56299   https://ageconsearch.umn.edu/record/95331   10.22004/ag.econ.95331
# 56236   https://ageconsearch.umn.edu/record/95214   10.22004/ag.econ.95214
# 17846    https://ageconsearch.umn.edu/record/6543    10.22004/ag.econ.6543
# ...                                           ...                      ...
# 58451  https://ageconsearch.umn.edu/record/103153  10.22004/ag.econ.103153
# 58441  https://ageconsearch.umn.edu/record/103117  10.22004/ag.econ.103117
# 58405  https://ageconsearch.umn.edu/record/102769  10.22004/ag.econ.102769
# 58393  https://ageconsearch.umn.edu/record/102727  10.22004/ag.econ.102727
# 58263  https://ageconsearch.umn.edu/record/102226  10.22004/ag.econ.102226
#
#       version_token_lp token_kind_lp  vnum_lp version_token_doi  \
# 57448             None          None      NaN              None
# 56302             None          None      NaN              None
# 56299             None          None      NaN              None
# 56236             None          None      NaN              None
# 17846             None          None      NaN              None
# ...                ...           ...      ...               ...
# 58451             None          None      NaN              None
# 58441             None          None      NaN              None
# 58405             None          None      NaN              None
# 58393             None          None      NaN              None
# 58263             None          None      NaN              None
#
#       token_kind_doi  vnum_doi
# 57448           None       NaN
# 56302           None       NaN
# 56299           None       NaN
# 56236           None       NaN
# 17846           None       NaN
# ...              ...       ...
# 58451           None       NaN
# 58441           None       NaN
# 58405           None       NaN
# 58393           None       NaN
# 58263           None       NaN
#
# [122 rows x 30 columns]

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='PsyArXiv'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                   record_id server_name   backend  \
# 2398812  crossref::10.31234/osf.io/zq3fa_v1    PsyArXiv  crossref
# 2425581     crossref::10.31234/osf.io/zq3fa    PsyArXiv  crossref
# 2399047  crossref::10.31234/osf.io/zphx9_v1    PsyArXiv  crossref
# 2434853     crossref::10.31234/osf.io/zphx9    PsyArXiv  crossref
# 2398868  crossref::10.31234/osf.io/y39xu_v1    PsyArXiv  crossref
# ...                                     ...         ...       ...
# 2399054  crossref::10.31234/osf.io/37a9q_v1    PsyArXiv  crossref
# 2437167     crossref::10.31234/osf.io/2cvk7    PsyArXiv  crossref
# 2399033  crossref::10.31234/osf.io/2cvk7_v1    PsyArXiv  crossref
# 2398974  crossref::10.31234/osf.io/25qsu_v1    PsyArXiv  crossref
# 2441676     crossref::10.31234/osf.io/25qsu    PsyArXiv  crossref
#
#                               doi                                   doi_url  \
# 2398812  10.31234/osf.io/zq3fa_v1  https://doi.org/10.31234/osf.io/zq3fa_v1
# 2425581     10.31234/osf.io/zq3fa     https://doi.org/10.31234/osf.io/zq3fa
# 2399047  10.31234/osf.io/zphx9_v1  https://doi.org/10.31234/osf.io/zphx9_v1
# 2434853     10.31234/osf.io/zphx9     https://doi.org/10.31234/osf.io/zphx9
# 2398868  10.31234/osf.io/y39xu_v1  https://doi.org/10.31234/osf.io/y39xu_v1
# ...                           ...                                       ...
# 2399054  10.31234/osf.io/37a9q_v1  https://doi.org/10.31234/osf.io/37a9q_v1
# 2437167     10.31234/osf.io/2cvk7     https://doi.org/10.31234/osf.io/2cvk7
# 2399033  10.31234/osf.io/2cvk7_v1  https://doi.org/10.31234/osf.io/2cvk7_v1
# 2398974  10.31234/osf.io/25qsu_v1  https://doi.org/10.31234/osf.io/25qsu_v1
# 2434853                   None            parent  https://osf.io/zphx9_v1
# 2398868                   None            parent  https://osf.io/y39xu_v1
# ...                        ...               ...                      ...
# 2399054                   None            parent  https://osf.io/37a9q_v1
# 2437167                   None            parent  https://osf.io/2cvk7_v1
# 2399033                   None            parent  https://osf.io/2cvk7_v1
# 2398974                   None            parent  https://osf.io/25qsu_v1
# 2441676                   None            parent  https://osf.io/25qsu_v1
#
#                          doi_norm version_token_lp     token_kind_lp  vnum_lp  \
# 2398812  10.31234/osf.io/zq3fa_v1              _v1  explicit_version      1.0
# 2425581     10.31234/osf.io/zq3fa              _v1  explicit_version      1.0
# 2399047  10.31234/osf.io/zphx9_v1              _v1  explicit_version      1.0
# 2434853     10.31234/osf.io/zphx9              _v1  explicit_version      1.0
# 2398868  10.31234/osf.io/y39xu_v1              _v1  explicit_version      1.0
# ...                           ...              ...               ...      ...
# 2399054  10.31234/osf.io/37a9q_v1              _v1  explicit_version      1.0
# 2437167     10.31234/osf.io/2cvk7              _v1  explicit_version      1.0
# 2399033  10.31234/osf.io/2cvk7_v1              _v1  explicit_version      1.0
# 2398974  10.31234/osf.io/25qsu_v1              _v1  explicit_version      1.0
# 2441676     10.31234/osf.io/25qsu              _v1  explicit_version      1.0
#
#         version_token_doi token_kind_doi  vnum_doi
# 2398812               NaN            NaN       NaN
# 2425581               NaN            NaN       NaN
# 2399047               NaN            NaN       NaN
# 2434853               NaN            NaN       NaN
# 2398868               NaN            NaN       NaN
# ...                   ...            ...       ...
# 2399054               NaN            NaN       NaN
# 2437167               NaN            NaN       NaN
# 2399033               NaN            NaN       NaN
# 2398974               NaN            NaN       NaN
# 2441676               NaN            NaN       NaN
#
# [119 rows x 30 columns]

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='Earth and Space Science Open Archive'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                               record_id  \
# 447059  crossref::10.22541/essoar.171909800.07100465/v1
# 447028  crossref::10.22541/essoar.171865213.30368497/v1
# 447065  crossref::10.22541/essoar.171926236.62536302/v1
# 447045  crossref::10.22541/essoar.171867280.07560342/v1
# 447066  crossref::10.22541/essoar.171926256.62956465/v1
# ...                                                 ...
# 444907  crossref::10.22541/essoar.169711700.09344058/v1
# 445007  crossref::10.22541/essoar.169755311.15838743/v1
# 444918  crossref::10.22541/essoar.169711716.62687942/v1
# 447070  crossref::10.22541/essoar.171926407.71074494/v1
# 447042  crossref::10.22541/essoar.171865398.83614867/v1
#
#                                  server_name   backend  \
# 447059  Earth and Space Science Open Archive  crossref
# 447028  Earth and Space Science Open Archive  crossref
# 447065  Earth and Space Science Open Archive  crossref
# 447045  Earth and Space Science Open Archive  crossref
# 447066  Earth and Space Science Open Archive  crossref
# ...                                      ...       ...
# 444907  Earth and Space Science Open Archive  crossref
# 445007  Earth and Space Science Open Archive  crossref
# 444918  Earth and Space Science Open Archive  crossref
# 447070  Earth and Space Science Open Archive  crossref
# 447042  Earth and Space Science Open Archive  crossref
#
#                                           doi  \
# 447059  10.22541/essoar.171909800.07100465/v1
# 447028  10.22541/essoar.171865213.30368497/v1
# 447065  10.22541/essoar.171926236.62536302/v1
# 447045  10.22541/essoar.171867280.07560342/v1
# 447066   2024-06-24           None          None
# ...             ...            ...           ...           ...            ...
# 444907   2023-10-12           None          None
# 445007   2023-10-17           None          None
# 444918   2023-10-12           None          None
# 447070   2024-06-24           None          None
# 447042   2024-06-17           None          None
#
#        has_preprint has_review has_published_version  \
# 447059                                         false
# 447028                                         false
# 447065                                         false
# 447045                                         false
# 447066                                         false
# ...             ...        ...                   ...
# 444907                                         false
# 445007                                         false
# 444918                                         false
# 447070                                         false
# 447042                                         false
#
#        published_version_ids_json version_of_ids_json update_to_json  \
# 447059                       None                None           None
# 447028                       None                None           None
# 447065                       None                None           None
# 447045                       None                None           None
# 447066                       None                None           None
# ...                           ...                 ...            ...
# 444907                       None                None           None
# 445007                       None                None           None
# 444918                       None                None           None
# 447070                       None                None           None
# 447042                       None                None           None
#
#        raw_relationships_json records_hierarchy  \
# 447059                   None            parent
# 447028                   None            parent
# 447065                   None            parent
# 447045                   None            parent
# 447066                   None            parent
# ...                       ...               ...
# 444907                   None            parent
# 445007                   None            parent
# 444918                   None            parent
# 447070                   None            parent
# 447042                   None            parent
#
#                                              landing_norm  \
# 447059  https://essopenarchive.org/users/795535/articl...
# 447028  https://essopenarchive.org/users/795535/articl...
# 447065  https://essopenarchive.org/users/795502/articl...
# 447045  https://essopenarchive.org/users/795502/articl...
# 447066  https://essopenarchive.org/users/795498/articl...
# ...                                                   ...
# 444907  https://essopenarchive.org/users/530200/articl...
# 445007  https://essopenarchive.org/users/529502/articl...
# 444918  https://essopenarchive.org/users/529502/articl...
# 447070  https://essopenarchive.org/users/527213/articl...
# 447042  https://essopenarchive.org/users/527213/articl...
#
#                                      doi_norm version_token_lp token_kind_lp  \
# 447059  10.22541/essoar.171909800.07100465/v1             None          None
# 447028  10.22541/essoar.171865213.30368497/v1             None          None
# 447065  10.22541/essoar.171926236.62536302/v1             None          None
# 447045  10.22541/essoar.171867280.07560342/v1             None          None
# 447066  10.22541/essoar.171926256.62956465/v1             None          None
# ...                                       ...              ...           ...
# 444907  10.22541/essoar.169711700.09344058/v1             None          None
# 445007  10.22541/essoar.169755311.15838743/v1             None          None
# 444918  10.22541/essoar.169711716.62687942/v1             None          None
# 447070  10.22541/essoar.171926407.71074494/v1             None          None
# 447042  10.22541/essoar.171865398.83614867/v1             None          None
#
#         vnum_lp version_token_doi    token_kind_doi  vnum_doi
# 447059      NaN               /v1  explicit_version       1.0
# 447028      NaN               /v1  explicit_version       1.0
# 447065      NaN               /v1  explicit_version       1.0
# 447045      NaN               /v1  explicit_version       1.0
# 447066      NaN               /v1  explicit_version       1.0
# ...         ...               ...               ...       ...
# 444907      NaN               /v1  explicit_version       1.0
# 445007      NaN               /v1  explicit_version       1.0
# 444918      NaN               /v1  explicit_version       1.0
# 447070      NaN               /v1  explicit_version       1.0
# 447042      NaN               /v1  explicit_version       1.0
#
# [116 rows x 30 columns]

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='ScienceOpen Preprints'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                                  record_id  \
# 5639665  crossref::10.14293/s2199-1006.1.sor-med.cljwhk...
# 5639684  crossref::10.14293/s2199-1006.1.sor-med.clhzql...
# 5639343  crossref::10.14293/s2199-1006.1.sor-life.clcgo...
# 5639342  crossref::10.14293/s2199-1006.1.sor-life.clefm...
# 5639676  crossref::10.14293/s2199-1006.1.sor-lit.clwycr...
# ...                                                    ...
# 5639827  crossref::10.14293/s2199-1006.1.sor-law.clcgnl...
# 5639823  crossref::10.14293/s2199-1006.1.sor-socsci.clg...
# 5639821  crossref::10.14293/s2199-1006.1.sor-socsci.clf...
# 5642552  crossref::10.14293/s2199-1006.1.sor-hist.cl4ob...
# 5642555  crossref::10.14293/s2199-1006.1.sor-hist.clny8...
#
#                    server_name   backend  \
# 5639665  ScienceOpen Preprints  crossref
# 5639684  ScienceOpen Preprints  crossref
# 5639343  ScienceOpen Preprints  crossref
# 5639342  ScienceOpen Preprints  crossref
# 5639676  ScienceOpen Preprints  crossref
# ...                        ...       ...
# 5639827  ScienceOpen Preprints  crossref
# 5639823  ScienceOpen Preprints  crossref
# 5639821  ScienceOpen Preprints  crossref
# 5642552  ScienceOpen Preprints  crossref
# 5642555  ScienceOpen Preprints  crossref
#
#                                                  doi  \
# 5639665     10.14293/s2199-1006.1.sor-med.cljwhk7.v1
# 5639684     10.14293/s2199-1006.1.sor-med.clhzql4.v1
# 5639343    10.14293/s2199-1006.1.sor-life.clcgoo7.v1
# 5639342    10.14293/s2199-1006.1.sor-life.clefm4a.v1
# 5639676     10.14293/s2199-1006.1.sor-lit.clwycrh.v1
# ...                                              ...
# 5639827     10.14293/s2199-1006.1.sor-law.clcgnlz.v1
# 5639823  10.14293/s2199-1006.1.sor-socsci.clgkrdl.v1
# 5639821  10.14293/s2199-1006.1.sor-socsci.clfttbi.v1
# 5642552    10.14293/s2199-1006.1.sor-hist.cl4obbv.v1
# 5642555    10.14293/s2199-1006.1.sor-hist.clny8ev.v1
#
#                                                    doi_url  \
# 5639665  https://doi.org/10.14293/s2199-1006.1.sor-med....
# 5639684  https://doi.org/10.14293/s2199-1006.1.sor-med....
# 5639343  https://doi.org/10.14293/s2199-1006.1.sor-life...
# 5639342  https://doi.org/10.14293/s2199-1006.1.sor-life...
# 5639676  https://doi.org/10.14293/s2199-1006.1.sor-lit....
# ...                                                    ...
# 5639827  https://doi.org/10.14293/s2199-1006.1.sor-law....
# 5639823  https://doi.org/10.14293/s2199-1006.1.sor-socs...
# 5639821  https://doi.org/10.14293/s2199-1006.1.sor-socs...
# 5642552  https://doi.org/10.14293/s2199-1006.1.sor-hist...
# 5642555  https://doi.org/10.14293/s2199-1006.1.sor-hist...
#
#                                           landing_page_url  \
# 5639665  https://www.scienceopen.com/collection/tmresearch
# 5639684  https://www.scienceopen.com/collection/tmresearch
# 5639343  https://www.scienceopen.com/collection/ticksan...
# 5639342  https://www.scienceopen.com/collection/ticksan...
# 5639676  https://www.scienceopen.com/collection/sylvia-...
# ...                                                    ...
# 5639827  https://www.scienceopen.com/collection/CarlGro...
# 5639823  https://www.scienceopen.com/collection/AKJourn...
# 5639821  https://www.scienceopen.com/collection/AKJourn...
# 5642552  https://scienceopen.com/collection/e5717391-c6...
# 5642555  https://scienceopen.com/collection/e5717391-c6...
#
#                                                      title  \
# 5639665                      Traditional Medicine Research
# 5639684                      Traditional Medicine Research
# 5639343                     Ticks and tick-borne pathogens
# 5639342                     Ticks and tick-borne pathogens
# 5639676  The Journal of the Sylvia Townsend Warner Society
# ...                                                    ...
# 5639827                               Carl Grossmann Books
# 5639823                           Psychology by AKJournals
# 5639821                           Psychology by AKJournals
# 5642552                      Leuven University Press Books
# 5642555                      Leuven University Press Books
#
#                   authors_flat publication_year date_created relations_json  \
# 5639665  Tóth-Czifra, Erzsébet           2017.0   2017-09-05           None
# 5639684  Tóth-Czifra, Erzsébet           2017.0   2017-09-05           None
# 5639343  Estrada Peña, Agustín           2017.0   2017-04-25           None
# 5639342  Estrada Peña, Agustín           2017.0   2017-04-24           None
# 5639676     Admin, ScienceOpen           2017.0   2017-09-11           None
# ...                        ...              ...          ...            ...
# 5639827     Admin, ScienceOpen           2019.0   2019-10-17           None
# 5639823     Admin, ScienceOpen           2019.0   2019-10-09           None
# 5639821     Admin, ScienceOpen           2019.0   2019-10-09           None
# 5642552     Admin, ScienceOpen           2023.0   2023-10-23           None
# 5642555     Admin, ScienceOpen           2023.0   2023-10-24           None
#
#         version_label is_version_of is_preprint_of has_preprint has_review  \
# 5639665          None
# 5639684          None
# 5639343          None
# 5639342          None
# 5639676          None
# ...               ...           ...            ...          ...        ...
# 5639827          None
# 5639823          None
# 5639821          None
# 5642552          None
# 5642555          None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 5639665                 false                       None                None
# 5639684                 false                       None                None
# 5639343                 false                       None                None
# 5639342                 false                       None                None
# 5639676                 false                       None                None
# ...                       ...                        ...                 ...
# 5639827                 false                       None                None
# 5639823                 false                       None                None
# 5639821                 false                       None                None
# 5642552                 false                       None                None
# 5642555                 false                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 5639665           None                   None            parent
# 5639684           None                   None            parent
# 5639343           None                   None            parent
# 5639342           None                   None            parent
# 5639676           None                   None            parent
# ...                ...                    ...               ...
# 5639827           None                   None            parent
# 5639823           None                   None            parent
# 5639821           None                   None            parent
# 5642552           None                   None            parent
# 5642555           None                   None            parent
#
#                                               landing_norm  \
# 5639665  https://www.scienceopen.com/collection/tmresearch
# 5639684  https://www.scienceopen.com/collection/tmresearch
# 5639343  https://www.scienceopen.com/collection/ticksan...
# 5639342  https://www.scienceopen.com/collection/ticksan...
# 5639676  https://www.scienceopen.com/collection/sylvia-...
# ...                                                    ...
# 5639827  https://www.scienceopen.com/collection/carlgro...
# 5639823  https://www.scienceopen.com/collection/akjourn...
# 5639821  https://www.scienceopen.com/collection/akjourn...
# 5642552  https://scienceopen.com/collection/e5717391-c6...
# 5642555  https://scienceopen.com/collection/e5717391-c6...
#
#                                             doi_norm version_token_lp  \
# 5639665     10.14293/s2199-1006.1.sor-med.cljwhk7.v1             None
# 5639684     10.14293/s2199-1006.1.sor-med.clhzql4.v1             None
# 5639343    10.14293/s2199-1006.1.sor-life.clcgoo7.v1             None
# 5639342    10.14293/s2199-1006.1.sor-life.clefm4a.v1             None
# 5639676     10.14293/s2199-1006.1.sor-lit.clwycrh.v1             None
# ...                                              ...              ...
# 5639827     10.14293/s2199-1006.1.sor-law.clcgnlz.v1             None
# 5639823  10.14293/s2199-1006.1.sor-socsci.clgkrdl.v1             None
# 5639821  10.14293/s2199-1006.1.sor-socsci.clfttbi.v1             None
# 5642552    10.14293/s2199-1006.1.sor-hist.cl4obbv.v1             None
# 5642555    10.14293/s2199-1006.1.sor-hist.clny8ev.v1             None
#
#         token_kind_lp  vnum_lp version_token_doi    token_kind_doi  vnum_doi
# 5639665          None      NaN               .v1  explicit_version       1.0
# 5639684          None      NaN               .v1  explicit_version       1.0
# 5639343          None      NaN               .v1  explicit_version       1.0
# 5639342          None      NaN               .v1  explicit_version       1.0
# 5639676          None      NaN               .v1  explicit_version       1.0
# ...               ...      ...               ...               ...       ...
# 5639827          None      NaN               .v1  explicit_version       1.0
# 5639823          None      NaN               .v1  explicit_version       1.0
# 5639821          None      NaN               .v1  explicit_version       1.0
# 5642552          None      NaN               .v1  explicit_version       1.0
# 5642555          None      NaN               .v1  explicit_version       1.0
#
# [111 rows x 30 columns]

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='TechRxiv'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                                  record_id server_name  \
# 5718712  crossref::10.36227/techrxiv.174613156.61394999/v1    TechRxiv
# 5718638  crossref::10.36227/techrxiv.174594289.98518288/v1    TechRxiv
# 5718635  crossref::10.36227/techrxiv.174593999.98386877/v1    TechRxiv
# 5718710  crossref::10.36227/techrxiv.174613113.39438286/v1    TechRxiv
# 5718709  crossref::10.36227/techrxiv.174613072.24623819/v1    TechRxiv
# ...                                                    ...         ...
# 5714424  crossref::10.36227/techrxiv.171925125.59769255/v1    TechRxiv
# 5714354  crossref::10.36227/techrxiv.171863936.68554917/v1    TechRxiv
# 5714355  crossref::10.36227/techrxiv.171863948.81280772/v1    TechRxiv
# 5714425  crossref::10.36227/techrxiv.171925132.27898180/v1    TechRxiv
# 5702952            crossref::10.36227/techrxiv.19174772.v1    TechRxiv
#
#           backend                                      doi  \
# 5718712  crossref  10.36227/techrxiv.174613156.61394999/v1
# 5718638  crossref  10.36227/techrxiv.174594289.98518288/v1
# 5718635  crossref  10.36227/techrxiv.174593999.98386877/v1
# 5718710  crossref  10.36227/techrxiv.174613113.39438286/v1
# 5718709  crossref  10.36227/techrxiv.174613072.24623819/v1
# ...           ...                                      ...
# 5714424  crossref  10.36227/techrxiv.171925125.59769255/v1
# 5714354  crossref  10.36227/techrxiv.171863936.68554917/v1
# 5714355  crossref  10.36227/techrxiv.171863948.81280772/v1
# 5714425  crossref  10.36227/techrxiv.171925132.27898180/v1
# 5702952  crossref            10.36227/techrxiv.19174772.v1
#
#                                                    doi_url  \
# 5718712  https://doi.org/10.36227/techrxiv.174613156.61...
# 5718638  https://doi.org/10.36227/techrxiv.174594289.98...
# 5718635  https://doi.org/10.36227/techrxiv.174593999.98...
# 5718710  https://doi.org/10.36227/techrxiv.174613113.39...
# 5718709  https://doi.org/10.36227/techrxiv.174613072.24...
# ...                                                    ...
# 5714424  https://doi.org/10.36227/techrxiv.171925125.59...
# 5714354  https://doi.org/10.36227/techrxiv.171863936.68...
# 5714355  https://doi.org/10.36227/techrxiv.171863948.81...
       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 5718712                   None            parent
# 5718638                   None            parent
# 5718635                   None            parent
# 5718710                   None            parent
# 5718709                   None            parent
# ...                        ...               ...
# 5714424                   None            parent
# 5714354                   None            parent
# 5714355                   None            parent
# 5714425                   None            parent
# 5702952                   None            parent
#
#                                               landing_norm  \
# 5718712  https://www.techrxiv.org/users/918312/articles...
# 5718638  https://www.techrxiv.org/users/918312/articles...
# 5718635  https://www.techrxiv.org/users/917216/articles...
# 5718710  https://www.techrxiv.org/users/917216/articles...
# 5718709  https://www.techrxiv.org/users/916644/articles...
# ...                                                    ...
# 5714424  https://www.techrxiv.org/users/681556/articles...
# 5714354  https://www.techrxiv.org/users/681556/articles...
# 5714355  https://www.techrxiv.org/users/623064/articles...
# 5714425  https://www.techrxiv.org/users/623064/articles...
# 5702952  https://www.techrxiv.org/doi/full/10.36227/tec...
#
#                                         doi_norm version_token_lp  \
# 5718712  10.36227/techrxiv.174613156.61394999/v1             None
# 5718638  10.36227/techrxiv.174594289.98518288/v1             None
# 5718635  10.36227/techrxiv.174593999.98386877/v1             None
# 5718710  10.36227/techrxiv.174613113.39438286/v1             None
# 5718709  10.36227/techrxiv.174613072.24623819/v1             None
# ...                                          ...              ...
# 5714424  10.36227/techrxiv.171925125.59769255/v1             None
# 5714354  10.36227/techrxiv.171863936.68554917/v1             None
# 5714355  10.36227/techrxiv.171863948.81280772/v1             None
# 5714425  10.36227/techrxiv.171925132.27898180/v1             None
# 5702952            10.36227/techrxiv.19174772.v1              .v1
#
#             token_kind_lp  vnum_lp version_token_doi    token_kind_doi  \
# 5718712              None      NaN               /v1  explicit_version
# 5718638              None      NaN               /v1  explicit_version
# 5718635              None      NaN               /v1  explicit_version
# 5718710              None      NaN               /v1  explicit_version
# 5718709              None      NaN               /v1  explicit_version
# ...                   ...      ...               ...               ...
# 5714424              None      NaN               /v1  explicit_version
# 5714354              None      NaN               /v1  explicit_version
# 5714355              None      NaN               /v1  explicit_version
# 5714425              None      NaN               /v1  explicit_version
# 5702952  explicit_version      1.0               NaN               NaN
#
#          vnum_doi
# 5718712       1.0
# 5718638       1.0
# 5718635       1.0
# 5718710       1.0
# 5718709       1.0
# ...           ...
# 5714424       1.0
# 5714354       1.0
# 5714355       1.0
# 5714425       1.0
# 5702952       NaN
#
# [65 rows x 30 columns]

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='F1000Research'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                        record_id    server_name   backend  \
# 572326   crossref::10.12688/f1000research.3979.1  F1000Research  crossref
# 572328     crossref::10.12688/f1000research.4264  F1000Research  crossref
# 572462     crossref::10.12688/f1000research.4162  F1000Research  crossref
# 572461   crossref::10.12688/f1000research.3886.1  F1000Research  crossref
# 572231     crossref::10.12688/f1000research.4019  F1000Research  crossref
# ...                                          ...            ...       ...
# 572276   crossref::10.12688/f1000research.1-2.v1  F1000Research  crossref
# 572286   crossref::10.3410/f1000research.1-12.v1  F1000Research  crossref
# 572275  crossref::10.12688/f1000research.1-12.v1  F1000Research  crossref
# 572314   crossref::10.3410/f1000research.1-10.v1  F1000Research  crossref
# 572299  crossref::10.12688/f1000research.1-10.v1  F1000Research  crossref
#
#                                    doi  \
# 572326   10.12688/f1000research.3979.1
# 572328     10.12688/f1000research.4264
#
#        published_version_ids_json version_of_ids_json update_to_json  \
# 572326                       None                None           None
# 572328                       None                None           None
# 572462                       None                None           None
# 572461                       None                None           None
# 572231                       None                None           None
# ...                           ...                 ...            ...
# 572276                       None                None           None
# 572286                       None                None           None
# 572275                       None                None           None
# 572314                       None                None           None
# 572299                       None                None           None
#
#        raw_relationships_json records_hierarchy  \
# 572326                   None            parent
# 572328                   None            parent
# 572462                   None            parent
# 572461                   None            parent
# 572231                   None            parent
# ...                       ...               ...
# 572276                   None            parent
# 572286                   None            parent
# 572275                   None            parent
# 572314                   None            parent
# 572299                   None            parent
#
#                                      landing_norm  \
# 572326  http://f1000research.com/articles/3-94/v1
# 572328  http://f1000research.com/articles/3-94/v1
# 572462  http://f1000research.com/articles/3-91/v1
# 572461  http://f1000research.com/articles/3-91/v1
# 572231  http://f1000research.com/articles/3-83/v1
# ...                                           ...
# 572276   http://f1000research.com/articles/1-2/v1
# 572286  http://f1000research.com/articles/1-12/v1
# 572275  http://f1000research.com/articles/1-12/v1
# 572314  http://f1000research.com/articles/1-10/v1
# 572299  http://f1000research.com/articles/1-10/v1
#
#                               doi_norm version_token_lp     token_kind_lp  \
# 572326   10.12688/f1000research.3979.1              /v1  explicit_version
# 572328     10.12688/f1000research.4264              /v1  explicit_version
# 572462     10.12688/f1000research.4162              /v1  explicit_version
# 572461   10.12688/f1000research.3886.1              /v1  explicit_version
# 572231     10.12688/f1000research.4019              /v1  explicit_version
# ...                                ...              ...               ...
# 572276   10.12688/f1000research.1-2.v1              /v1  explicit_version
# 572286   10.3410/f1000research.1-12.v1              /v1  explicit_version
# 572275  10.12688/f1000research.1-12.v1              /v1  explicit_version
# 572314   10.3410/f1000research.1-10.v1              /v1  explicit_version
# 572299  10.12688/f1000research.1-10.v1              /v1  explicit_version
#
#         vnum_lp version_token_doi token_kind_doi  vnum_doi
# 572326      1.0               NaN            NaN       NaN
# 572328      1.0               NaN            NaN       NaN
# 572462      1.0               NaN            NaN       NaN
# 572461      1.0               NaN            NaN       NaN
# 572231      1.0               NaN            NaN       NaN
# ...         ...               ...            ...       ...
# 572276      1.0               NaN            NaN       NaN
# 572286      1.0               NaN            NaN       NaN
# 572275      1.0               NaN            NaN       NaN
# 572314      1.0               NaN            NaN       NaN
# 572299      1.0               NaN            NaN       NaN
#
# [62 rows x 30 columns]

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='DSpace@MIT'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                     record_id server_name   backend   doi doi_url  \
# 335214  openalex::W4297798537  DSpace@MIT  openalex  <NA>    None
# 335088  openalex::W3102404986  DSpace@MIT  openalex  <NA>    None
# 332101  openalex::W1499052255  DSpace@MIT  openalex  <NA>    None
# 334098  openalex::W3024898576  DSpace@MIT  openalex  <NA>    None
# 336939  openalex::W1586102975  DSpace@MIT  openalex  <NA>    None
# 336006  openalex::W2905992706  DSpace@MIT  openalex  <NA>    None
# 340005  openalex::W2737630491  DSpace@MIT  openalex  <NA>    None
# 339951  openalex::W2734455347  DSpace@MIT  openalex  <NA>    None
# 343384  openalex::W3215857213  DSpace@MIT  openalex  <NA>    None
# 340031  openalex::W2739208627  DSpace@MIT  openalex  <NA>    None
# 342652  openalex::W3094122426  DSpace@MIT  openalex  <NA>    None
# 339727  openalex::W2616633165  DSpace@MIT  openalex  <NA>    None
# 339957  openalex::W2735131093  DSpace@MIT  openalex  <NA>    None
# 339599  openalex::W2607724552  DSpace@MIT  openalex  <NA>    None
# 339829  openalex::W2626076641  DSpace@MIT  openalex  <NA>    None
# 339828  openalex::W2626074197  DSpace@MIT  openalex  <NA>    None
# 339517  openalex::W2598112458  DSpace@MIT  openalex  <NA>    None
# 339713  openalex::W2614729374  DSpace@MIT  openalex  <NA>    None
# 339613  openalex::W2609246625  DSpace@MIT  openalex  <NA>    None
# 339603  openalex::W2608134440  DSpace@MIT  openalex  <NA>    None
# 339607  openalex::W2608825275  DSpace@MIT  openalex  <NA>    None
# 339608  openalex::W2608859941  DSpace@MIT  openalex  <NA>    None
# 339610  openalex::W2608999422  DSpace@MIT  openalex  <NA>    None
# 339711  openalex::W2614662120  DSpace@MIT  openalex  <NA>    None
# 339612  openalex::W2609107626  DSpace@MIT  openalex  <NA>    None
# 339615  openalex::W2609456999  DSpace@MIT  openalex  <NA>    None
# 339617  openalex::W2609583521  DSpace@MIT  openalex  <NA>    None
# 339648  openalex::W2611670471  DSpace@MIT  openalex  <NA>    None
# 339675  openalex::W2612578381  DSpace@MIT  openalex  <NA>    None
# 339756  openalex::W2619647472  DSpace@MIT  openalex  <NA>    None
# 339988  openalex::W2736645195  DSpace@MIT  openalex  <NA>    None
# 335121  openalex::W3102188392  DSpace@MIT  openalex  <NA>    None
# 339820  openalex::W2625544948  DSpace@MIT  openalex  <NA>    None
# 343242  openalex::W3202946520  DSpace@MIT  openalex  <NA>    None
# 339880  openalex::W2724807298  DSpace@MIT  openalex  <NA>    None
# 332419  openalex::W3020437581  DSpace@MIT  openalex  <NA>    None
# 335157  openalex::W3104635521  DSpace@MIT  openalex  <NA>    None
# 339916  openalex::W2729489288  DSpace@MIT  openalex  <NA>    None
# 343389  openalex::W3216328012  DSpace@MIT  openalex  <NA>    None
# 339884  openalex::W2724988277  DSpace@MIT  openalex  <NA>    None
# 339490  openalex::W2596111461  DSpace@MIT  openalex  <NA>    None
# 335217  openalex::W3123129672  DSpace@MIT  openalex  <NA>    None
# 342815  openalex::W3133392775  DSpace@MIT  openalex  <NA>    None
# 341801  openalex::W2997232791  DSpace@MIT  openalex  <NA>    None
#
#                            landing_page_url  \
# 335214     https://arxiv.org/abs/1802.04480
# 335088   http://hdl.handle.net/1721.1/77925
# 332101   http://hdl.handle.net/1721.1/77925
# 334098   http://hdl.handle.net/1721.1/60550
# 336939   http://hdl.handle.net/1721.1/60550
# 336006  http://hdl.handle.net/1721.1/110743
# 340005  http://hdl.handle.net/1721.1/110743
# 339951  http://hdl.handle.net/1721.1/110608
# 343384  http://hdl.handle.net/1721.1/110608
# 340031  http://hdl.handle.net/1721.1/110227
# 342652  http://hdl.handle.net/1721.1/110227
# 339727  http://hdl.handle.net/1721.1/110082
# 339957  http://hdl.handle.net/1721.1/110082
# 339599  http://hdl.handle.net/1721.1/110082
# 339829  http://hdl.handle.net/1721.1/110082
# 339828  http://hdl.handle.net/1721.1/110082
# 339517  http://hdl.handle.net/1721.1/110082
# 339713  http://hdl.handle.net/1721.1/110082
# 339613  http://hdl.handle.net/1721.1/110082
# 339603  http://hdl.handle.net/1721.1/110082
# 339607  http://hdl.handle.net/1721.1/110082
# 339608  http://hdl.handle.net/1721.1/110082
# 339610  http://hdl.handle.net/1721.1/110082
# 339711  http://hdl.handle.net/1721.1/110082
# 339612  http://hdl.handle.net/1721.1/110082
# 339615  http://hdl.handle.net/1721.1/110082
# 339617  http://hdl.handle.net/1721.1/110082
# 339648  http://hdl.handle.net/1721.1/110082
# 339675  http://hdl.handle.net/1721.1/110082
# 339756  http://hdl.handle.net/1721.1/110082
# 339988  http://hdl.handle.net/1721.1/110073
# 335121  http://hdl.handle.net/1721.1/110073
# 339820  http://hdl.handle.net/1721.1/109874
# 343242  http://hdl.handle.net/1721.1/109874
# 339880  http://hdl.handle.net/1721.1/109742
# 332419  http://hdl.handle.net/1721.1/109742
# 335157  http://hdl.handle.net/1721.1/109589
# 339916  http://hdl.handle.net/1721.1/109589
# 343389  http://hdl.handle.net/1721.1/109580
# 339884  http://hdl.handle.net/1721.1/109580
# 339490  http://hdl.handle.net/1721.1/106902
# 335217  http://hdl.handle.net/1721.1/106902
# 342815  http://hdl.handle.net/1721.1/105160
# 341801  http://hdl.handle.net/1721.1/105160
#
#                                                     title  \
# 335214  RoboChain: A Secure Data-Sharing Framework for...
# 335088  Coherency Strain and the Kinetics of Phase Sep...
# 332101  Coherency Strain and the Kinetics of Phase Sep...
# 334098  Spin and Valence States of Iron in Mg0.8Fe0.2S...
# 336939  Spin and valence states of iron in (Mg[subscri...
# 336006  Kinetic isotope effects of 12CH3D  + OH and 13...
# 340005  Kinetic isotope effects of [superscript 12]CH[...
# 339951  The rotation-vibration structure of the SO[sub...
# 343384  The rotation-vibration structure of the SO2 C ...
# 340031  Observation of B[subscript c][superscript +]→J...
# 342652  Observation of $B_{c}^{+} \to J/ψD^{(*)} K^{(*...
# 339727  In silico discovery and rational prediction of...
# 339957  Effect of ionizing radiation on the proliferat...
# 339599  Amniotic fluid: A new approach to biologics an...
# 339829  Relationship between anesthetic-induced toxici...
# 339828  Generation of high quality iPS cells (super iP...
# 339517  A self-assembly peptide nanofiber scaffold con...
# 339713  A unique network involving CXCR4 and CXCR7 coo...
# 339613  Social collaboration network analysis of anima...
# 339603  A targeted drug delivery system for selective ...
# 339607                       Nitromedicine: a new concept
# 339608  The effectiveness of treatment of patients wit...
# 339610  Faster engraftment dependent to better mobiliz...
# 339711  Role of point of care pharmacist in patient re...
# 339612  Application of neural stem cells to assess gen...
# 339615  Study on the diagnostic and prognostic aspects...
# 339617  Manipulation of adult stem cells plasticity wi...
_kind_lp  vnum_lp version_token_doi token_kind_doi  vnum_doi
# 335214          None      NaN              None           None       NaN
# 335088          None      NaN              None           None       NaN
# 332101          None      NaN              None           None       NaN
# 334098          None      NaN              None           None       NaN
# 336939          None      NaN              None           None       NaN
# 336006          None      NaN              None           None       NaN
# 340005          None      NaN              None           None       NaN
# 339951          None      NaN              None           None       NaN
# 343384          None      NaN              None           None       NaN
# 340031          None      NaN              None           None       NaN
# 342652          None      NaN              None           None       NaN
# 339727          None      NaN              None           None       NaN
# 339957          None      NaN              None           None       NaN
# 339599          None      NaN              None           None       NaN
# 339829          None      NaN              None           None       NaN
# 339828          None      NaN              None           None       NaN
# 339517          None      NaN              None           None       NaN
# 339713          None      NaN              None           None       NaN
# 339613          None      NaN              None           None       NaN
# 339603          None      NaN              None           None       NaN
# 339607          None      NaN              None           None       NaN
# 339608          None      NaN              None           None       NaN
# 339610          None      NaN              None           None       NaN
# 339711          None      NaN              None           None       NaN
# 339612          None      NaN              None           None       NaN
# 339615          None      NaN              None           None       NaN
# 339617          None      NaN              None           None       NaN
# 339648          None      NaN              None           None       NaN
# 339675          None      NaN              None           None       NaN
# 339756          None      NaN              None           None       NaN
# 339988          None      NaN              None           None       NaN
# 335121          None      NaN              None           None       NaN
# 339820          None      NaN              None           None       NaN
# 343242          None      NaN              None           None       NaN
# 339880          None      NaN              None           None       NaN
# 332419          None      NaN              None           None       NaN
# 335157          None      NaN              None           None       NaN
# 339916          None      NaN              None           None       NaN
# 343389          None      NaN              None           None       NaN
# 339884          None      NaN              None           None       NaN
# 339490          None      NaN              None           None       NaN
# 335217          None      NaN              None           None       NaN
# 342815          None      NaN              None           None       NaN
# 341801          None      NaN              None           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='Authorea Inc.'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                           record_id    server_name   backend  \
# 266149  crossref::10.22541/au.166013641.15972664/v1  Authorea Inc.  crossref
# 263047  crossref::10.22541/au.174111107.77253989/v1  Authorea Inc.  crossref
# 263038  crossref::10.22541/au.174110059.99710888/v1  Authorea Inc.  crossref
# 243970  crossref::10.22541/au.169754906.69651455/v1  Authorea Inc.  crossref
# 243763  crossref::10.22541/au.169710870.00119117/v1  Authorea Inc.  crossref
# 243767  crossref::10.22541/au.169710892.20614312/v1  Authorea Inc.  crossref
# 243981  crossref::10.22541/au.169754941.18437909/v1  Authorea Inc.  crossref
# 242953  crossref::10.22541/au.169516707.74001061/v1  Authorea Inc.  crossref
# 242935  crossref::10.22541/au.169513747.79521287/v1  Authorea Inc.  crossref
# 242952  crossref::10.22541/au.169516707.71218203/v1  Authorea Inc.  crossref
# 242931  crossref::10.22541/au.169513398.86167710/v1  Authorea Inc.  crossref
# 243979  crossref::10.22541/au.169754941.14890859/v1  Authorea Inc.  crossref
# 243766  crossref::10.22541/au.169710889.93444781/v1  Authorea Inc.  crossref
# 240963  crossref::10.22541/au.169038544.41077246/v1  Authorea Inc.  crossref
# 240983  crossref::10.22541/au.169046170.06036436/v1  Authorea Inc.  crossref
# 236928  crossref::10.22541/au.168097145.50721783/v1  Authorea Inc.  crossref
# 236966  crossref::10.22541/au.168113706.62697801/v1  Authorea Inc.  crossref
# 234563  crossref::10.22541/au.167519164.46902663/v1  Authorea Inc.  crossref
# 234628  crossref::10.22541/au.167528128.84600842/v1  Authorea Inc.  crossref
# 229416  Otomo, Yuri; Masuda, Reiji; Osada, Yutaka; Kaw...           2022.0
# 264854  Rubio-San-Simon, Alba; Buendía, Susana; Gómez,...           2025.0
# 264865  Rubio-San-Simon, Alba; Buendía, Susana; Gómez,...           2025.0
# 243768  Diamandis, Dr. Carolina; Shirazi, Ali; Honda, ...           2023.0
# 243982  Diamandis, Dr. Carolina; Shirazi, Ali; Honda, ...           2023.0
# 219491           Kwon, Yelee; Kang, Pil Je; Cho, Won chul           2021.0
# 219476           Kwon, Yelee; Kang, Pil Je; Cho, Won chul           2021.0
# 233101  Hans, Stéphane; Circiu, Marta; Crevier-Buchman...           2022.0
# 233089  Hans, Stéphane; Circiu, Marta; Crevier-Buchman...           2022.0
# 211306  Christensen, Thomas; Kyvsgaard, Marianne; Vind...           2020.0
# 211304  Christensen, Thomas; Kyvsgaard, Marianne; Vind...           2020.0
# 211305  Christensen, Thomas; Kyvsgaard, Marianne; Vind...           2020.0
# 211296                                         Jain, Amit           2020.0
# 211295                                         Jain, Amit           2020.0
# 243765                                   L., Sina Mansour           2023.0
# 243976                                   L., Sina Mansour           2023.0
# 224520                                    Rigon, Riccardo           2022.0
# 224519                                    Rigon, Riccardo           2022.0
#
#        date_created relations_json version_label is_version_of is_preprint_of  \
# 266149   2022-08-10           None          None
# 263047   2025-03-04           None          None
# 263038   2025-03-04           None          None
# 243970   2023-10-17           None          None
# 243763   2023-10-12           None          None
# 243767   2023-10-12           None          None
# 243981   2023-10-17           None          None
# 242953   2023-09-19           None          None
# 242935   2023-09-19           None          None
# 242952   2023-09-19           None          None
# 242931   2023-09-19           None          None
# 243979   2023-10-17           None          None
# 243766   2023-10-12           None          None
# 240963   2023-07-26           None          None
# 240983   2023-07-27           None          None
# 236928   2023-04-08           None          None
# 236966   2023-04-10           None          None
# 234563   2023-01-31           None          None
# 234628   2023-02-01           None          None
# 243769   2023-10-12           None          None
# 243986   2023-10-17           None          None
# 229827   2022-08-09           None          None
# 229936   2022-08-11           None          None
# 229431   2022-07-20           None          None
# 229416   2022-07-19           None          None
# 264854   2025-04-29           None          None
# 264865   2025-04-29           None          None
# 243768   2023-10-12           None          None
# 243982   2023-10-17           None          None
# 219491   2021-04-20           None          None
# 219476   2021-04-20           None          None
# 233101   2022-12-20           None          None
# 233089   2022-12-20           None          None
# 211306   2020-07-07           None          None
# 211304   2020-07-07           None          None
# 211305   2020-07-07           None          None
# 211296   2020-07-07           None          None
# 211295   2020-07-07           None          None
# 243765   2023-10-12           None          None
# 243976   2023-10-17           None          None
# 224520   2022-01-11           None          None
# 224519   2022-01-11           None          None
#
#        has_preprint has_review has_published_version  \
# 266149                                         false
# 263047                                         false
# 263038                                         false
# 243970                                         false
# 243763                                         false
# 243767                                         false
# 243981                                         false
# 242953                                         false
# 242935                                         false
# 242952                                         false
# 242931                                         false
# 243979                                         false
# 243766                                         false
# 240963                                         false
# 240983                                         false
# 236928                                         false
# 236966                                         false
# 234563                                         false
# 234628                                         false
# 243769                                         false
# 243986                                         false
# 229827                                         false
# 229936                                         false
# 229431                                         false
# 229416                                         false
# 264854                                         false
# 264865                                         false
# 243768                                         false
# 243982                                         false
# 219491                                         false
# 219476                                         false
# 233101                                         false
# 233089                                         false
# 211306                                         false
# 211304                                         false
# 211305                                         false
# 211296                                         false
# 211295                                         false
# 243765                                         false
# 243976                                         false
# 224520                                         false
# 224519                                         false
#
#        published_version_ids_json version_of_ids_json update_to_json  \
# 266149                       None                None           None
# 263047                       None                None           None
# 263038                       None                None           None
# 243970                       None                None           None
# 243763                       None                None           None
# 243767                       None                None           None
# 243981                       None                None           None
# 242953                       None                None           None
# 242935                       None                None           None
# 242952                       None                None           None
# 242931                       None                None           None
# 243979                       None                None           None
# 243766                       None                None           None
# 240963                       None                None           None
# 240983                       None                None           None
# 236928                       None                None           None
# 236966                       None                None           None
# 234563                       None                None           None
# 234628                       None                None           None
# 243769                       None                None           None
# 243986                       None                None           None
# 229827                       None                None           None
# 229936                       None                None           None
# 229431                       None                None           None
# 229416                       None                None           None
# 264854                       None                None           None
# 264865                       None                None           None
# 243768                       None                None           None
# 243982                       None                None           None
# 219491                       None                None           None
# 219476                       None                None           None
# 233101                       None                None           None
# 233089                       None                None           None
# 211306                       None                None           None
# 211304                       None                None           None
# 211305                       None                None           None
# 211296                       None                None           None
# 211295                       None                None           None
# 243765                       None                None           None
# 243976                       None                None           None
# 224520                       None                None           None
# 224519                       None                None           None
#
#        raw_relationships_json records_hierarchy  \
# 266149                   None            parent
# 263047                   None            parent
# 263038                   None            parent
# 243970                   None            parent
# 243763                   None            parent
# 243767                   None            parent
# 243981                   None            parent
# 242953                   None            parent
# 242935                   None            parent
# 242952                   None            parent
# 242931                   None            parent
# 243979                   None            parent
# 243766                   None            parent
# 240963                   None            parent
# 240983                   None            parent
# 236928                   None            parent
# 236966                   None            parent
# 234563                   None            parent
# 234628                   None            parent
# 243769                   None            parent
# 243986                   None            parent
# 229827                   None            parent
# 229936                   None            parent
# 229431                   None            parent
# 229416                   None            parent
# 264854                   None            parent
# 264865                   None            parent
# 243768                   None            parent
# 243982                   None            parent
# 219491                   None            parent
# 219476                   None            parent
# 233101                   None            parent
# 233089                   None            parent
# 211306                   None            parent
# 211304                   None            parent
# 211305                   None            parent
# 211296                   None            parent
# 211295                   None            parent
# 243765                   None            parent
# 243976                   None            parent
# 224520                   None            parent
# 224519                   None            parent
#
#                                              landing_norm  \
# 266149  https://www.techrxiv.org/doi/full/10.36227/tec...
# 263047  https://www.authorea.com/users/898379/articles...
# 263038  https://www.authorea.com/users/898379/articles...
# 243970  https://www.authorea.com/users/672717/articles...
# 243763  https://www.authorea.com/users/672717/articles...
# 243767  https://www.authorea.com/users/672139/articles...
# 243981  https://www.authorea.com/users/672139/articles...
# 242953  https://www.authorea.com/users/666294/articles...
# 242935  https://www.authorea.com/users/666294/articles...
# 242952  https://www.authorea.com/users/666262/articles...
# 242931  https://www.authorea.com/users/666262/articles...
# 243979  https://www.authorea.com/users/656501/articles...
# 243766  https://www.authorea.com/users/656501/articles...
# 240963  https://www.authorea.com/users/643528/articles...
# 219476  10.22541/au.161891178.85235678/v1             None              None
# 233101  10.22541/au.167156295.54994822/v1             None              None
# 233089  10.22541/au.167155024.46493489/v1             None              None
# 211306     10.22541/au.159413746.69457665             None              None
# 211304     10.22541/au.159413682.29725879             None              None
# 211305     10.22541/au.159413676.68369277             None              None
# 211296     10.22541/au.159413613.34574154             None              None
# 211295     10.22541/au.159413604.48894097             None              None
# 243765  10.22541/au.169710888.89906082/v1             None              None
# 243976  10.22541/au.169754928.88571819/v1             None              None
# 224520  10.22541/au.164192095.59225943/v1             None              None
# 224519  10.22541/au.164192090.06394208/v1             None              None
#
#         vnum_lp version_token_doi    token_kind_doi  vnum_doi
# 266149      1.0               NaN               NaN       NaN
# 263047      NaN               /v1  explicit_version       1.0
# 263038      NaN               /v1  explicit_version       1.0
# 243970      NaN               /v1  explicit_version       1.0
# 243763      NaN               /v1  explicit_version       1.0
# 243767      NaN               /v1  explicit_version       1.0
# 243981      NaN               /v1  explicit_version       1.0
# 242953      NaN               /v1  explicit_version       1.0
# 242935      NaN               /v1  explicit_version       1.0
# 242952      NaN               /v1  explicit_version       1.0
# 242931      NaN               /v1  explicit_version       1.0
# 243979      NaN               /v1  explicit_version       1.0
# 243766      NaN               /v1  explicit_version       1.0
# 240963      NaN               /v1  explicit_version       1.0
# 240983      NaN               /v1  explicit_version       1.0
# 236928      NaN               /v1  explicit_version       1.0
# 236966      NaN               /v1  explicit_version       1.0
# 234563      NaN               /v1  explicit_version       1.0
# 234628      NaN               /v1  explicit_version       1.0
# 243769      NaN               /v1  explicit_version       1.0
# 243986      NaN               /v1  explicit_version       1.0
# 229827      NaN               /v1  explicit_version       1.0
# 229936      NaN               /v1  explicit_version       1.0
# 229431      NaN               /v1  explicit_version       1.0
# 229416      NaN               /v1  explicit_version       1.0
# 264854      NaN               /v1  explicit_version       1.0
# 264865      NaN               /v1  explicit_version       1.0
# 243768      NaN               /v1  explicit_version       1.0
# 243982      NaN               /v1  explicit_version       1.0
# 219491      NaN               /v1  explicit_version       1.0
# 219476      NaN               /v1  explicit_version       1.0
# 233101      NaN               /v1  explicit_version       1.0
# 233089      NaN               /v1  explicit_version       1.0
# 211306      NaN              None              None       NaN
# 211304      NaN              None              None       NaN
# 211305      NaN              None              None       NaN
# 211296      NaN              None              None       NaN
# 211295      NaN              None              None       NaN
# 243765      NaN               /v1  explicit_version       1.0
# 243976      NaN               /v1  explicit_version       1.0
# 224520      NaN               /v1  explicit_version       1.0
# 224519      NaN               /v1  explicit_version       1.0

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='Digital Access to Scholarship at Harvard (DASH) (Harvard University)'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                     record_id  \
# 349916  openalex::W7112397115
# 351402  openalex::W7113012407
# 350917  openalex::W7112816552
# 350846  openalex::W7112788517
# 351422  openalex::W7113021182
# 350563  openalex::W7112670930
# 350530  openalex::W7112658728
# 350078  openalex::W7112462899
# 349980  openalex::W7112425060
# 349954  openalex::W7112414740
# 351948  openalex::W7113238094
# 349510  openalex::W7112234141
# 349444  openalex::W7112208813
# 349207  openalex::W7112115309
# 349090  openalex::W7112066825
# 349031  openalex::W7112037407
http://nrs.harvard.edu/urn-3:hul.eresource:cla...     <na>
# 352660  http://nrs.harvard.edu/urn-3:hul.eresource:cla...     <na>
# 345703  http://nrs.harvard.edu/urn-3:hul.instrepos:472...     <na>
# 347950  http://nrs.harvard.edu/urn-3:hul.instrepos:472...     <na>
# 344495  http://nrs.harvard.edu/urn-3:hul.instrepos:111...     <na>
# 348183  http://nrs.harvard.edu/urn-3:hul.instrepos:111...     <na>
# 350588                            http://nrs.harvard.edu/     <na>
# 353056                            http://nrs.harvard.edu/     <na>
#
#        version_token_lp token_kind_lp  vnum_lp version_token_doi  \
# 349916             None          None      NaN              None
# 351402             None          None      NaN              None
# 350917             None          None      NaN              None
# 350846             None          None      NaN              None
# 351422             None          None      NaN              None
# 350563             None          None      NaN              None
# 350530             None          None      NaN              None
# 350078             None          None      NaN              None
# 349980             None          None      NaN              None
# 349954             None          None      NaN              None
# 351948             None          None      NaN              None
# 349510             None          None      NaN              None
# 349444             None          None      NaN              None
# 349207             None          None      NaN              None
# 349090             None          None      NaN              None
# 349031             None          None      NaN              None
# 348711             None          None      NaN              None
# 348536             None          None      NaN              None
# 348409             None          None      NaN              None
# 348260             None          None      NaN              None
# 352902             None          None      NaN              None
# 347834             None          None      NaN              None
# 347010             None          None      NaN              None
# 351201             None          None      NaN              None
# 348523             None          None      NaN              None
# 352660             None          None      NaN              None
# 345703             None          None      NaN              None
# 347950             None          None      NaN              None
# 344495             None          None      NaN              None
# 348183             None          None      NaN              None
# 350588             None          None      NaN              None
# 353056             None          None      NaN              None
#
#        token_kind_doi  vnum_doi
# 349916           None       NaN
# 351402           None       NaN
# 350917           None       NaN
# 350846           None       NaN
# 351422           None       NaN
# 350563           None       NaN
# 350530           None       NaN
# 350078           None       NaN
# 349980           None       NaN
# 349954           None       NaN
# 351948           None       NaN
# 349510           None       NaN
# 349444           None       NaN
# 349207           None       NaN
# 349090           None       NaN
# 349031           None       NaN
# 348711           None       NaN
# 348536           None       NaN
# 348409           None       NaN
# 348260           None       NaN
# 352902           None       NaN
# 347834           None       NaN
# 347010           None       NaN
# 351201           None       NaN
# 348523           None       NaN
# 352660           None       NaN
# 345703           None       NaN
# 347950           None       NaN
# 344495           None       NaN
# 348183           None       NaN
# 350588           None       NaN
# 353056           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='EarthArXiv'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                          record_id server_name   backend               doi  \
# 428821   crossref::10.31223/x5kt7m  EarthArXiv  crossref   10.31223/x5kt7m
# 429050   crossref::10.31223/x58h6b  EarthArXiv  crossref   10.31223/x58h6b
# 427419   crossref::10.31223/x5fd5g  EarthArXiv  crossref   10.31223/x5fd5g
# 427420   crossref::10.31223/x52t1p  EarthArXiv  crossref   10.31223/x52t1p
# 426685   crossref::10.31223/x54s90  EarthArXiv  crossref   10.31223/x54s90
# 426406   crossref::10.31223/x58m1g  EarthArXiv  crossref   10.31223/x58m1g
# 425234   crossref::10.31223/x59922  EarthArXiv  crossref   10.31223/x59922
# 425241   crossref::10.31223/x5gs6z  EarthArXiv  crossref   10.31223/x5gs6z
# 425697   crossref::10.31223/x5fk9q  EarthArXiv  crossref   10.31223/x5fk9q
# 425698   crossref::10.31223/x59w6f  EarthArXiv  crossref   10.31223/x59w6f
# 425691   crossref::10.31223/x5bp6p  EarthArXiv  crossref   10.31223/x5bp6p
# 425172   crossref::10.31223/x5633f  EarthArXiv  crossref   10.31223/x5633f
# 425171   crossref::10.31223/x59w52  EarthArXiv  crossref   10.31223/x59w52
# 423278   https://doi.org/10.31223/x5ms5t
# 423209   https://doi.org/10.31223/x5xp46
#
#                                     landing_page_url  \
# 428821  https://eartharxiv.org/repository/view/6898/
# 429050  https://eartharxiv.org/repository/view/6898/
# 427419  https://eartharxiv.org/repository/view/6821/
# 427420  https://eartharxiv.org/repository/view/6821/
# 426685  https://eartharxiv.org/repository/view/5038/
# 426406  https://eartharxiv.org/repository/view/5038/
# 425234   http://eartharxiv.org/repository/view/2855/
# 425241   http://eartharxiv.org/repository/view/2855/
# 425697   http://eartharxiv.org/repository/view/2730/
# 425698   http://eartharxiv.org/repository/view/2730/
# 425691   http://eartharxiv.org/repository/view/2730/
# 425172   http://eartharxiv.org/repository/view/2704/
# 425171   http://eartharxiv.org/repository/view/2704/
# 425149   http://eartharxiv.org/repository/view/2672/
# 425150   http://eartharxiv.org/repository/view/2672/
# 425139   http://eartharxiv.org/repository/view/2623/
# 425138   http://eartharxiv.org/repository/view/2623/
# 425141   http://eartharxiv.org/repository/view/2601/
# 425140   http://eartharxiv.org/repository/view/2601/
# 425091   http://eartharxiv.org/repository/view/2512/
# 425090   http://eartharxiv.org/repository/view/2512/
# 429442   http://eartharxiv.org/repository/view/2433/
# 425892   http://eartharxiv.org/repository/view/2433/
# 429441   http://eartharxiv.org/repository/view/2433/
# 424662   http://eartharxiv.org/repository/view/2201/
# 424661   http://eartharxiv.org/repository/view/2201/
# 423310   http://eartharxiv.org/repository/view/2182/
# 423311   http://eartharxiv.org/repository/view/2182/
# 423296   http://eartharxiv.org/repository/view/2153/
# 423300   http://eartharxiv.org/repository/view/2153/
# 423278   http://eartharxiv.org/repository/view/1994/
# 423209   http://eartharxiv.org/repository/view/1994/
#
#                                                     title  \
# 428821  Can spinodal decomposition occur during decomp...
# 429050  Can spinodal decomposition occur during decomp...
# 427419  Moving graphs: Predicting barchan dune migrati...
# 427420  Moving graphs: Predicting barchan dune migrati...
# 426685  Statistical precursor signals for Dansgaard-Oe...
# 426406  Predictability of abrupt northern-hemisphere c...
# 425234  The Influence of Grain Shape and Size on the R...
# 425241  The Influence of Grain Shape and Size on the R...
# 425697  Evaluating the Evolution of ECMWF Precipitatio...
# 425698  Evaluating the Evolution of ECMWF Precipitatio...
# 425691  Evaluating the Evolution of ECMWF Precipitatio...
# 425172  Missing or Underrated Super-emitters of Nitrog...
# 425171  Missing or Underrated Super-emitters of Nitrog...
# 425149  Higher Long-Term Soil Moisture Increases Organ...
# 425150  Higher Long-Term Soil Moisture Increases Organ...
# 425139  SUBSTRATE ENTRAINMENT, DEPOSITIONAL RELIEF, AN...
# 425138  SUBSTRATE ENTRAINMENT, DEPOSITIONAL RELIEF, AN...
# 425141                   Fire-Generated Tornadic Vortices
# 425140                   Fire-Generated Tornadic Vortices
# 425091  Reconstructing Aerosols Vertical Profiles with...
# 425090  Reconstructing Aerosols Vertical Profiles with...
# 429442  WITHDRAWN: Using Synthetic Data Trained Convol...
# 425892  Independent constraints on deep-sea temperatur...
# 429441  WITHDRAWN: Using Synthetic Data Trained Convol...
# 428821            parent  https://eartharxiv.org/repository/view/6898/
# 429050            parent  https://eartharxiv.org/repository/view/6898/
# 427419            parent  https://eartharxiv.org/repository/view/6821/
# 427420            parent  https://eartharxiv.org/repository/view/6821/
# 426685            parent  https://eartharxiv.org/repository/view/5038/
# 426406            parent  https://eartharxiv.org/repository/view/5038/
# 425234            parent   http://eartharxiv.org/repository/view/2855/
# 425241            parent   http://eartharxiv.org/repository/view/2855/
# 425697            parent   http://eartharxiv.org/repository/view/2730/
# 425698            parent   http://eartharxiv.org/repository/view/2730/
# 425691            parent   http://eartharxiv.org/repository/view/2730/
# 425172            parent   http://eartharxiv.org/repository/view/2704/
# 425171            parent   http://eartharxiv.org/repository/view/2704/
# 425149            parent   http://eartharxiv.org/repository/view/2672/
# 425150            parent   http://eartharxiv.org/repository/view/2672/
# 425139            parent   http://eartharxiv.org/repository/view/2623/
# 425138            parent   http://eartharxiv.org/repository/view/2623/
# 425141            parent   http://eartharxiv.org/repository/view/2601/
# 425140            parent   http://eartharxiv.org/repository/view/2601/
# 425091            parent   http://eartharxiv.org/repository/view/2512/
# 425090            parent   http://eartharxiv.org/repository/view/2512/
# 429442            parent   http://eartharxiv.org/repository/view/2433/
# 425892            parent   http://eartharxiv.org/repository/view/2433/
# 429441            parent   http://eartharxiv.org/repository/view/2433/
# 424662            parent   http://eartharxiv.org/repository/view/2201/
# 424661            parent   http://eartharxiv.org/repository/view/2201/
# 423310            parent   http://eartharxiv.org/repository/view/2182/
# 423311            parent   http://eartharxiv.org/repository/view/2182/
# 423296            parent   http://eartharxiv.org/repository/view/2153/
# 423300            parent   http://eartharxiv.org/repository/view/2153/
# 423278            parent   http://eartharxiv.org/repository/view/1994/
# 423209            parent   http://eartharxiv.org/repository/view/1994/
#
#                 doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 428821   10.31223/x5kt7m             None          None      NaN
# 429050   10.31223/x58h6b             None          None      NaN
# 427419   10.31223/x5fd5g             None          None      NaN
# 427420   10.31223/x52t1p             None          None      NaN
# 426685   10.31223/x54s90             None          None      NaN
# 426406   10.31223/x58m1g             None          None      NaN
# 425234   10.31223/x59922             None          None      NaN
# 425241   10.31223/x5gs6z             None          None      NaN
# 425697   10.31223/x5fk9q             None          None      NaN
# 425698   10.31223/x59w6f             None          None      NaN
# 425691   10.31223/x5bp6p             None          None      NaN
# 425172   10.31223/x5633f             None          None      NaN
# 425171   10.31223/x59w52             None          None      NaN
# 425149   10.31223/x5v039             None          None      NaN
# 425150   10.31223/x5q91d             None          None      NaN
# 425139   10.31223/x5xw5n             None          None      NaN
# 425138   10.31223/x52p7k             None          None      NaN
# 425141   10.31223/x5pd14             None          None      NaN
# 425140   10.31223/x5t62p             None          None      NaN
# 425091   10.31223/x5qw5s             None          None      NaN
# 425090   10.31223/x5vk69             None          None      NaN
# 429442  10.15697/fk2v59g             None          None      NaN
# 425892   10.31223/x5nc9h             None          None      NaN
# 429441  10.15697/fk20022             None          None      NaN
# 424662   10.31223/x5t02m             None          None      NaN
# 424661   10.31223/x5xs5m             None          None      NaN
# 423310   10.31223/x5d038             None          None      NaN
# 423311   10.31223/x5860z             None          None      NaN
# 423296   10.31223/x5mk7h             None          None      NaN
# 423300   10.31223/x53k7v             None          None      NaN
# 423278   10.31223/x5ms5t             None          None      NaN
# 423209   10.31223/x5xp46             None          None      NaN
#
#        version_token_doi token_kind_doi  vnum_doi
# 428821              None           None       NaN
# 429050              None           None       NaN
# 427419              None           None       NaN
# 427420              None           None       NaN
# 426685              None           None       NaN
# 426406              None           None       NaN
# 425234              None           None       NaN
# 425241              None           None       NaN
# 425697              None           None       NaN
# 425698              None           None       NaN
# 425691              None           None       NaN
# 425172              None           None       NaN
# 425171              None           None       NaN
# 425149              None           None       NaN
# 425150              None           None       NaN
# 425139              None           None       NaN
# 425138              None           None       NaN
# 425141              None           None       NaN
# 425140              None           None       NaN
# 425091              None           None       NaN
# 425090              None           None       NaN
# 429442              None           None       NaN
# 425892              None           None       NaN
# 429441              None           None       NaN
# 424662              None           None       NaN
# 424661              None           None       NaN
# 423310              None           None       NaN
# 423311              None           None       NaN
# 423296              None           None       NaN
# 423300              None           None       NaN
# 423278              None           None       NaN
# 423209              None           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='IACR Cryptology ePrint Archive'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                      record_id                     server_name   backend  \
# 1953806  openalex::W3207917365  IACR Cryptology ePrint Archive  openalex
# 1946913  openalex::W2952233364  IACR Cryptology ePrint Archive  openalex
# 1949116  openalex::W3217563045  IACR Cryptology ePrint Archive  openalex
# 1943071  openalex::W2398691649  IACR Cryptology ePrint Archive  openalex
# 1949071  openalex::W3207746821  IACR Cryptology ePrint Archive  openalex
# 1942923  openalex::W2403700287  IACR Cryptology ePrint Archive  openalex
# 1946601  openalex::W2791898560  IACR Cryptology ePrint Archive  openalex
# 1945645  openalex::W3210407932  IACR Cryptology ePrint Archive  openalex
# 1953716  openalex::W3204639541  IACR Cryptology ePrint Archive  openalex
# 1943516  openalex::W2402265787  IACR Cryptology ePrint Archive  openalex
# 1949204  openalex::W2394784395  IACR Cryptology ePrint Archive  openalex
# 1953795  openalex::W3207370840  IACR Cryptology ePrint Archive  openalex
# 1943261  openalex::W2949486339  IACR Cryptology ePrint Archive  openalex
# 1944460  openalex::W3207301265  IACR Cryptology ePrint Archive  openalex
# 1945898  openalex::W2949177658  IACR Cryptology ePrint Archive  openalex
# 1944018  openalex::W3213195093  IACR Cryptology ePrint Archive  openalex
# 1949214  openalex::W2395173570  IACR Cryptology ePrint Archive  openalex
# 1953818  openalex::W3208962841  IACR Cryptology ePrint Archive  openalex
# 1953943  openalex::W3217343854  IACR Cryptology ePrint Archive  openalex
# 1945785  openalex::W2404776267  IACR Cryptology ePrint Archive  openalex
# 1953762  openalex::W3206229324  IACR Cryptology ePrint Archive  openalex
# 1945956  openalex::W2950073973  IACR Cryptology ePrint Archive  openalex
# 1949490  openalex::W2402724531  IACR Cryptology ePrint Archive  openalex
# 1953794  openalex::W3207325271  IACR Cryptology ePrint Archive  openalex
# 1945217  openalex::W2402256104  IACR Cryptology ePrint Archive  openalex
# 1953844  openalex::W3210870794  IACR Cryptology ePrint Archive  openalex
None
#
#         token_kind_lp  vnum_lp version_token_doi token_kind_doi  vnum_doi
# 1953806          None      NaN              None           None       NaN
# 1946913          None      NaN              None           None       NaN
# 1949116          None      NaN              None           None       NaN
# 1943071          None      NaN              None           None       NaN
# 1949071          None      NaN              None           None       NaN
# 1942923          None      NaN              None           None       NaN
# 1946601          None      NaN              None           None       NaN
# 1945645          None      NaN              None           None       NaN
# 1953716          None      NaN              None           None       NaN
# 1943516          None      NaN              None           None       NaN
# 1949204          None      NaN              None           None       NaN
# 1953795          None      NaN              None           None       NaN
# 1943261          None      NaN              None           None       NaN
# 1944460          None      NaN              None           None       NaN
# 1945898          None      NaN              None           None       NaN
# 1944018          None      NaN              None           None       NaN
# 1949214          None      NaN              None           None       NaN
# 1953818          None      NaN              None           None       NaN
# 1953943          None      NaN              None           None       NaN
# 1945785          None      NaN              None           None       NaN
# 1953762          None      NaN              None           None       NaN
# 1945956          None      NaN              None           None       NaN
# 1949490          None      NaN              None           None       NaN
# 1953794          None      NaN              None           None       NaN
# 1945217          None      NaN              None           None       NaN
# 1953844          None      NaN              None           None       NaN
# 1945158          None      NaN              None           None       NaN
# 1949086          None      NaN              None           None       NaN
# 1953729          None      NaN              None           None       NaN
# 1947977          None      NaN              None           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='Organic Eprints'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                      record_id      server_name   backend  \
# 2246907   openalex::W102989963  Organic Eprints  openalex
# 2245698    openalex::W70345073  Organic Eprints  openalex
# 2257146    openalex::W92931842  Organic Eprints  openalex
# 2244074    openalex::W91005601  Organic Eprints  openalex
# 2257092    openalex::W90975811  Organic Eprints  openalex
# 2257068    openalex::W89980577  Organic Eprints  openalex
# 2257049    openalex::W89340078  Organic Eprints  openalex
# 2244981    openalex::W82371600  Organic Eprints  openalex
# 2244017    openalex::W81918905  Organic Eprints  openalex
# 2256831    openalex::W81372898  Organic Eprints  openalex
# 2256655    openalex::W75853297  Organic Eprints  openalex
# 2245706    openalex::W73293428  Organic Eprints  openalex
# 2256571    openalex::W72050753  Organic Eprints  openalex
# 2244654    openalex::W70977810  Organic Eprints  openalex
# 2256544    openalex::W70216071  Organic Eprints  openalex
# 2245787   openalex::W106941238  Organic Eprints  openalex
# 2256491    openalex::W67817875  Organic Eprints  openalex
# 2256308    openalex::W61906627  Organic Eprints  openalex
# 2244962    openalex::W60459218  Organic Eprints  openalex
# 2256029    openalex::W53160016  Organic Eprints  openalex
# 2244068    openalex::W50328423  Organic Eprints  openalex
# 2255967    openalex::W49926529  Organic Eprints  openalex
# 2255867    openalex::W46898626  Organic Eprints  openalex
# 2251234    openalex::W25719276  Organic Eprints  openalex
# 2245890   openalex::W113337753  Organic Eprints  openalex
# 2247124   openalex::W111413393  Organic Eprints  openalex
# 2245001    openalex::W99945665  Organic Eprints  openalex
# 2244941  openalex::W4291166484  Organic Eprints  openalex
# 2244194  openalex::W2768556435  Organic Eprints  openalex
#
#                               doi                                   doi_url  \
# 2246907     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2245698     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2257146     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2244074     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2257092     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2257068     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2257049     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2244981     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2244017     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2256831     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2256655     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2245706     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2256571     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2244654     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2256544     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2245787     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2256491     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2256308     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2244962     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2256029     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2244068     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2255967     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2255867     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2251234     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2245890     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 2247124     10.3220/rep_20_1_2014     https://doi.org/10.3220/rep_20_1_2014
# 
https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2245698     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2257146     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2244074     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2257092     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2257068     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2257049     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2244981     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2244017     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2256831     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2256655     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2245706     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2256571     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2244654     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2256544     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2245787     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2256491     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2256308     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2244962     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2256029     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2244068     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2255967     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2255867     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2251234     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2245890     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2247124     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2245001     https://doi.org/10.3220/rep_20_1_2014     10.3220/rep_20_1_2014
# 2244941  https://doi.org/10.3220/rep1510908963000  10.3220/rep1510908963000
# 2244194  https://doi.org/10.3220/rep1510908963000  10.3220/rep1510908963000
#
#         version_token_lp token_kind_lp  vnum_lp version_token_doi  \
# 2246907             None          None      NaN              None
# 2245698             None          None      NaN              None
# 2257146             None          None      NaN              None
# 2244074             None          None      NaN              None
# 2257092             None          None      NaN              None
# 2257068             None          None      NaN              None
# 2257049             None          None      NaN              None
# 2244981             None          None      NaN              None
# 2244017             None          None      NaN              None
# 2256831             None          None      NaN              None
# 2256655             None          None      NaN              None
# 2245706             None          None      NaN              None
# 2256571             None          None      NaN              None
# 2244654             None          None      NaN              None
# 2256544             None          None      NaN              None
# 2245787             None          None      NaN              None
# 2256491             None          None      NaN              None
# 2256308             None          None      NaN              None
# 2244962             None          None      NaN              None
# 2256029             None          None      NaN              None
# 2244068             None          None      NaN              None
# 2255967             None          None      NaN              None
# 2255867             None          None      NaN              None
# 2251234             None          None      NaN              None
# 2245890             None          None      NaN              None
# 2247124             None          None      NaN              None
# 2245001             None          None      NaN              None
# 2244941             None          None      NaN              None
# 2244194             None          None      NaN              None
#
#         token_kind_doi  vnum_doi
# 2246907           None       NaN
# 2245698           None       NaN
# 2257146           None       NaN
# 2244074           None       NaN
# 2257092           None       NaN
# 2257068           None       NaN
# 2257049           None       NaN
# 2244981           None       NaN
# 2244017           None       NaN
# 2256831           None       NaN
# 2256655           None       NaN
# 2245706           None       NaN
# 2256571           None       NaN
# 2244654           None       NaN
# 2256544           None       NaN
# 2245787           None       NaN
# 2256491           None       NaN
# 2256308           None       NaN
# 2244962           None       NaN
# 2256029           None       NaN
# 2244068           None       NaN
# 2255967           None       NaN
# 2255867           None       NaN
# 2251234           None       NaN
# 2245890           None       NaN
# 2247124           None       NaN
# 2245001           None       NaN
# 2244941           None       NaN
# 2244194           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='Open Science Framework'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                   record_id             server_name   backend  \
# 2156227  crossref::10.31219/osf.io/wcks6_v1  Open Science Framework  crossref
# 2227441     crossref::10.31219/osf.io/wcks6  Open Science Framework  crossref
# 2123947     crossref::10.31219/osf.io/w8kue  Open Science Framework  crossref
# 2133659     crossref::10.31219/osf.io/w4mhc  Open Science Framework  crossref
# 2157098  crossref::10.31219/osf.io/sdzfq_v1  Open Science Framework  crossref
# 2226663     crossref::10.31219/osf.io/sdzfq  Open Science Framework  crossref
# 2145107     crossref::10.31219/osf.io/rfvy5  Open Science Framework  crossref
# 2227472     crossref::10.31219/osf.io/p5gm4  Open Science Framework  crossref
# 2156392  crossref::10.31219/osf.io/p5gm4_v1  Open Science Framework  crossref
# 2227441     10.31219/osf.io/wcks6              _v1  explicit_version      1.0
# 2123947     10.31219/osf.io/w8kue             None              None      NaN
# 2133659     10.31219/osf.io/w4mhc             None              None      NaN
# 2157098  10.31219/osf.io/sdzfq_v1              _v1  explicit_version      1.0
# 2226663     10.31219/osf.io/sdzfq              _v1  explicit_version      1.0
# 2145107     10.31219/osf.io/rfvy5             None              None      NaN
# 2227472     10.31219/osf.io/p5gm4              _v1  explicit_version      1.0
# 2156392  10.31219/osf.io/p5gm4_v1              _v1  explicit_version      1.0
# 2156403  10.31219/osf.io/mztwg_v1              _v1  explicit_version      1.0
# 2225980     10.31219/osf.io/mztwg              _v1  explicit_version      1.0
# 2157090  10.31219/osf.io/ms27r_v1              _v1  explicit_version      1.0
# 2225100     10.31219/osf.io/ms27r              _v1  explicit_version      1.0
# 2124489     10.31219/osf.io/f6tza             None              None      NaN
# 2156712  10.31219/osf.io/cgfmz_v1              _v1  explicit_version      1.0
# 2211325     10.31219/osf.io/cgfmz              _v1  explicit_version      1.0
# 2157084  10.31219/osf.io/3jrcm_v1              _v1  explicit_version      1.0
# 2217841     10.31219/osf.io/3jrcm              _v1  explicit_version      1.0
# 2157080  10.31219/osf.io/2e9x4_v1              _v1  explicit_version      1.0
# 2221297     10.31219/osf.io/2e9x4              _v1  explicit_version      1.0
#
#         version_token_doi token_kind_doi  vnum_doi
# 2156227               NaN            NaN       NaN
# 2227441               NaN            NaN       NaN
# 2123947              None           None       NaN
# 2133659              None           None       NaN
# 2157098               NaN            NaN       NaN
# 2226663               NaN            NaN       NaN
# 2145107              None           None       NaN
# 2227472               NaN            NaN       NaN
# 2156392               NaN            NaN       NaN
# 2156403               NaN            NaN       NaN
# 2225980               NaN            NaN       NaN
# 2157090               NaN            NaN       NaN
# 2225100               NaN            NaN       NaN
# 2124489              None           None       NaN
# 2156712               NaN            NaN       NaN
# 2211325               NaN            NaN       NaN
# 2157084               NaN            NaN       NaN
# 2217841               NaN            NaN       NaN
# 2157080               NaN            NaN       NaN
# 2221297               NaN            NaN       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='SciELO Preprints'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                           record_id       server_name  \
# 5637898       crossref::10.1590/scielopreprints9984  SciELO Preprints
# 5637921      crossref::10.1590/scielopreprints.9984  SciELO Preprints
# 5635263      crossref::10.1590/scielopreprints.2690  SciELO Preprints
# 5634999      crossref::10.1590/scielopreprints.1690  SciELO Preprints
# 5638844  crossref::10.1590/2596-304x202527e20251386  SciELO Preprints
# 5638827     crossref::10.1590/scielopreprints.13933  SciELO Preprints
# 5638845  crossref::10.1590/2596-304x202527e20251278  SciELO Preprints
# 5638826     crossref::10.1590/scielopreprints.13919  SciELO Preprints
# 5638846  crossref::10.1590/2596-304x202527e20251120  SciELO Preprints
# 5638824     crossref::10.1590/scielopreprints.13907  SciELO Preprints
# 5638822     crossref::10.1590/scielopreprints.13906  SciELO Preprints
# 5638847  crossref::10.1590/2596-304x202527e20251118  SciELO Preprints
# 5638932        crossref::10.1590/2675-2824073.25084  SciELO Preprints
# 5637921      10.1590/scielopreprints.9984             None          None
# 5635263      10.1590/scielopreprints.2690             None          None
# 5634999      10.1590/scielopreprints.1690             None          None
# 5638844  10.1590/2596-304x202527e20251386             None          None
# 5638827     10.1590/scielopreprints.13933             None          None
# 5638845  10.1590/2596-304x202527e20251278             None          None
# 5638826     10.1590/scielopreprints.13919             None          None
# 5638846  10.1590/2596-304x202527e20251120             None          None
# 5638824     10.1590/scielopreprints.13907             None          None
# 5638822     10.1590/scielopreprints.13906             None          None
# 5638847  10.1590/2596-304x202527e20251118             None          None
# 5638932        10.1590/2675-2824073.25084             None          None
# 5638804     10.1590/scielopreprints.13872             None          None
# 5638933        10.1590/2675-2824073.25109             None          None
# 5638797     10.1590/scielopreprints.13816             None          None
# 5638843  10.1590/2596-304x202527e20251018             None          None
# 5638723     10.1590/scielopreprints.13580             None          None
# 5639052  10.1590/2596-304x202527e20251103             None          None
# 5639077     10.1590/scielopreprints.13384             None          None
# 5639068  10.1590/2596-304x202527e20251102             None          None
# 5638638     10.1590/scielopreprints.13269             None          None
# 5638637     10.1590/scielopreprints.13245             None          None
# 5638663  10.1590/2596-304x202527e20251105             None          None
#
#          vnum_lp version_token_doi token_kind_doi  vnum_doi
# 5637898      NaN              None           None       NaN
# 5637921      NaN              None           None       NaN
# 5635263      NaN              None           None       NaN
# 5634999      NaN              None           None       NaN
# 5638844      NaN              None           None       NaN
# 5638827      NaN              None           None       NaN
# 5638845      NaN              None           None       NaN
# 5638826      NaN              None           None       NaN
# 5638846      NaN              None           None       NaN
# 5638824      NaN              None           None       NaN
# 5638822      NaN              None           None       NaN
# 5638847      NaN              None           None       NaN
# 5638932      NaN              None           None       NaN
# 5638804      NaN              None           None       NaN
# 5638933      NaN              None           None       NaN
# 5638797      NaN              None           None       NaN
# 5638843      NaN              None           None       NaN
# 5638723      NaN              None           None       NaN
# 5639052      NaN              None           None       NaN
# 5639077      NaN              None           None       NaN
# 5639068      NaN              None           None       NaN
# 5638638      NaN              None           None       NaN
# 5638637      NaN              None           None       NaN
# 5638663      NaN              None           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='EcoEvoRxiv'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                               record_id server_name   backend  \
# 455996  crossref::10.31219/osf.io/wu5vz  EcoEvoRxiv  crossref
# 456000  crossref::10.32942/osf.io/wu5vz  EcoEvoRxiv  crossref
# 455999  crossref::10.32942/osf.io/k85eq  EcoEvoRxiv  crossref
# 455997  crossref::10.31219/osf.io/k85eq  EcoEvoRxiv  crossref
# 455998  crossref::10.31219/osf.io/gzunx  EcoEvoRxiv  crossref
# 456001  crossref::10.32942/osf.io/gzunx  EcoEvoRxiv  crossref
# 454497        crossref::10.32942/x2qc8z  EcoEvoRxiv  crossref
# 454505        crossref::10.32942/x2pc91  EcoEvoRxiv  crossref
# 454463        crossref::10.32942/x23s40  EcoEvoRxiv  crossref
# 454456        crossref::10.32942/x2102p  EcoEvoRxiv  crossref
# 454379        crossref::10.32942/x2zg6d  EcoEvoRxiv  crossref
# 454378        crossref::10.32942/x2389q  EcoEvoRxiv  crossref
# 455682        crossref::10.32942/x24w2k  EcoEvoRxiv  crossref
# 455688  https://ecoevorxiv.org/repository/view/10075/
# 455687  https://ecoevorxiv.org/repository/view/10075/
# 455686  https://ecoevorxiv.org/repository/view/10075/
# 455683  https://ecoevorxiv.org/repository/view/10075/
# 455691  https://ecoevorxiv.org/repository/view/10075/
# 455685  https://ecoevorxiv.org/repository/view/10075/
# 455692  https://ecoevorxiv.org/repository/view/10075/
# 455684  https://ecoevorxiv.org/repository/view/10075/
# 455690  https://ecoevorxiv.org/repository/view/10075/
#
#                                                     title  \
# 455996                                               Test
# 456000                                               <NA>
# 455999                                               <NA>
# 455997                                           testtest
# 455998                                       testtesttest
# 456001                                               <NA>
# 454497     The trade-offs of honest and dishonest signals
# 454505     The trade-offs of honest and dishonest signals
# 454463  Amazonian soundscapes: unravelling the secrets...
# 454456  Amazonian soundscapes: unravelling the secrets...
# 454379  Datathons: fostering equitability in data reus...
# 454378  Datathons: fostering equitability in data reus...
# 455682  BPGA: an interactive Shiny application for bas...
# 455689  BPGA: an interactive Shiny application for bas...
# 455688  BPGA: an interactive Shiny application for bas...
# 455687  BPGA: an interactive Shiny application for bas...
# 455686  BPGA: an interactive Shiny application for bas...
# 455683  BPGA: an interactive Shiny application for bas...
# 455691  BPGA: an interactive Shiny application for bas...
# 455685  BPGA: an interactive Shiny application for bas...
# 455692  BPGA: an interactive Shiny application for bas...
# 455684  Revealing the unknown world of the endangered ...
# 455690  BPGA: an interactive Shiny application for bas...
#
#                                              authors_flat publication_year  \
# 455996                             Rosenblatt, Rebecca P.           2018.0
# 456000                                               <NA>           2018.0
# 455999                                               <NA>           2018.0
# 455997                             Rosenblatt, Rebecca P.           2018.0
# 455998                             Rosenblatt, Rebecca P.           2018.0
# 456001                                               <NA>           2018.0
# 454497                       Zachar, István; Penn, Dustin           2023.0
# 454505    Számadó, Szabolcs; Zachar, István; Penn, Dustin           2023.0
# 454463  Do Nascimento, Leandro; Pérez-Granados, Cristi...           2023.0
# 454456  Do Nascimento, Leandro; Pérez-Granados, Cristi...           2023.0
# 454379  Jurburg, Stephanie; Alvarez Blanco, Maria J.; ...           2023.0
# 454378  Jurburg, Stephanie; Alvarez Blanco, Maria J.; ...           2023.0
# 455682                                        Fibla, Joan           2025.0
# 455689                                        Fibla, Joan           2025.0
# 455688                                        Fibla, Joan           2025.0
# 455687                                        Fibla, Joan           2025.0
# 455686                                        Fibla, Joan           2025.0
# 455683                                        Fibla, Joan           2025.0
# 455691                                        Fibla, Joan           2025.0
# 455685                                        Fibla, Joan           2025.0
# 455692                                        Fibla, Joan           2025.0
# 455684  Riera Paschotto, Fernanda; Pacífico, Erica; Fi...           2025.0
# 455690                                        Fibla, Joan           2025.0
#
#        date_created relations_json version_label is_version_of is_preprint_of  \
# 455996   2018-11-09           None          None
# 456000   2018-11-09           None          None
# 455999   2018-11-09           None          None
# 455997   2018-11-09           None          None
# 455998   2018-11-09           None          None
# 456001   2018-11-09           None          None
# 454497   2023-12-13           None          None
# 454505   2023-12-14           None          None
# 454463   2023-11-28           None          None
# 454456   2023-11-22           None          None
# 454379   2023-10-06           None          None
# 454378   2023-10-06           None          None
# 455682   2022-10-26           None          None
# 455689   2022-11-01           None          None
# 455688   2022-10-31           None          None
# 455687   2022-10-30           None          None
# 455686   2022-10-28           None          None
# 455683   2022-10-27           None          None
# 455691   2022-11-01           None          None
# 455685   2022-10-28           None          None
# 455692   2022-11-02           None          None
# 455684   2022-10-28           None          None
# 455690   2022-11-01           None          None
#
#        has_preprint has_review has_published_version  \
# 455996                                         false
# 456000                                         false
# 455999                                         false
# 455997                                         false
# 455998                                         false
# 456001                                         false
# 454497                                         false
# 454505                                         false
# 454463                                         false
# 454456                                         false
# 454379                                         false
# 454378                                         false
# 455682                                         false
# 455689                                         false
# 455688                                         false
# 455687                                         false
# 455686                                         false
# 455683                                         false
# 455691                                         false
# 455685                                         false
# 455692                                         false
# 455684                                         false
# 455690                                         false
#
#        published_version_ids_json version_of_ids_json update_to_json  \
# 455996                       None                None           None
# 456000                       None                None           None
# 455999                       None                None           None
# 455997                       None                None           None
# 455998                       None                None           None
# 456001                       None                None           None
# 454497                       None                None           None
# 454505                       None                None           None
# 454463                       None                None           None
# 454456                       None                None           None
# 454379                       None                None           None
# 454378                       None                None           None
# 455682                       None                None           None
# 455689                       None                None           None
# 455688                       None                None           None
# 455687                       None                None           None
# 455686                       None                None           None
# 455683                       None                None           None
# 455691                       None                None           None
# 455685                       None                None           None
# 455692                       None                None           None
# 455684                       None                None           None
# 455690                       None                None           None
#
#        raw_relationships_json records_hierarchy  \
# 455996                   None            parent
# 456000                   None            parent
# 455999                   None            parent
# 455997                   None            parent
# 455998                   None            parent
# 456001                   None            parent
# 454497                   None            parent
# 454505                   None            parent
# 454463                   None            parent
# 454456                   None            parent
# 454379                   None            parent
# 454378                   None            parent
# 455682                   None            parent
# 455689                   None            parent
# 455688                   None            parent
# 455687                   None            parent
# 455686                   None            parent
# 455683                   None            parent
# 455691                   None            parent
# 455685                   None            parent
# 455692                   None            parent
# 455684                   None            parent
# 455690                   None            parent
#
#                                          landing_norm               doi_norm  \
# 455996                           https://osf.io/wu5vz  10.31219/osf.io/wu5vz
# 456000                           https://osf.io/wu5vz  10.32942/osf.io/wu5vz
# 455999                           https://osf.io/k85eq  10.32942/osf.io/k85eq
# 455997                           https://osf.io/k85eq  10.31219/osf.io/k85eq
# 455998                           https://osf.io/gzunx  10.31219/osf.io/gzunx
# 456001                           https://osf.io/gzunx  10.32942/osf.io/gzunx
# 454497   https://ecoevorxiv.org/repository/view/6403/        10.32942/x2qc8z
# 454505   https://ecoevorxiv.org/repository/view/6403/        10.32942/x2pc91
# 454463   https://ecoevorxiv.org/repository/view/6292/        10.32942/x23s40
# 454456   https://ecoevorxiv.org/repository/view/6292/        10.32942/x2102p
# 454379   https://ecoevorxiv.org/repository/view/6051/        10.32942/x2zg6d
# 454378   https://ecoevorxiv.org/repository/view/6051/        10.32942/x2389q
# 455682  https://ecoevorxiv.org/repository/view/10075/        10.32942/x24w2k
# 455689  https://ecoevorxiv.org/repository/view/10075/        10.32942/x27p46
# 455688  https://ecoevorxiv.org/repository/view/10075/        10.32942/x2cc7g
# 455687  https://ecoevorxiv.org/repository/view/10075/        10.32942/x2h59d
# 455686  https://ecoevorxiv.org/repository/view/10075/        10.32942/x2mw2x
# 455683  https://ecoevorxiv.org/repository/view/10075/        10.32942/x21592
# 455691  https://ecoevorxiv.org/repository/view/10075/        10.32942/x2059r
# 455685  https://ecoevorxiv.org/repository/view/10075/        10.32942/x2rp4v
# 455692  https://ecoevorxiv.org/repository/view/10075/        10.32942/x2vc7t
# 455684  https://ecoevorxiv.org/repository/view/10075/        10.32942/x2wc74
# 455690  https://ecoevorxiv.org/repository/view/10075/        10.32942/x23w28
#
#        version_token_lp token_kind_lp  vnum_lp version_token_doi  \
# 455996             None          None      NaN              None
# 456000             None          None      NaN              None
# 455999             None          None      NaN              None
# 455997             None          None      NaN              None
# 455998             None          None      NaN              None
# 456001             None          None      NaN              None
# 454497             None          None      NaN              None
# 454505             None          None      NaN              None
# 454463             None          None      NaN              None
# 454456             None          None      NaN              None
# 454379             None          None      NaN              None
# 454378             None          None      NaN              None
# 455682             None          None      NaN              None
# 455689             None          None      NaN              None
# 455688             None          None      NaN              None
# 455687             None          None      NaN              None
# 455686             None          None      NaN              None
# 455683             None          None      NaN              None
# 455691             None          None      NaN              None
# 455685             None          None      NaN              None
# 455692             None          None      NaN              None
# 455684             None          None      NaN              None
# 455690             None          None      NaN              None
#
#        token_kind_doi  vnum_doi
# 455996           None       NaN
# 456000           None       NaN
# 455999           None       NaN
# 455997           None       NaN
# 455998           None       NaN
# 456001           None       NaN
# 454497           None       NaN
# 454505           None       NaN
# 454463           None       NaN
# 454456           None       NaN
# 454379           None       NaN
# 454378           None       NaN
# 455682           None       NaN
# 455689           None       NaN
# 455688           None       NaN
# 455687           None       NaN
# 455686           None       NaN
# 455683           None       NaN
# 455691           None       NaN
# 455685           None       NaN
# 455692           None       NaN
# 455684           None       NaN
# 455690           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='UCL Open Environment'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                        record_id           server_name  \
# 5729973  crossref::10.14324/111.444/ucloe.000068  UCL Open Environment
# 5729972            crossref::10.14324/ucloe.1982  UCL Open Environment
# 5730003                crossref::10.5334/ai.0311  UCL Open Environment
# 5727433                crossref::10.5334/ai.3011  UCL Open Environment
#
#           backend                            doi  \
# 5729973  crossref  10.14324/111.444/ucloe.000068
# 5729972  crossref            10.14324/ucloe.1982
# 5730003  crossref                10.5334/ai.0311
# 5727433  crossref                10.5334/ai.3011
#
#                                                doi_url  \
# 5729973  https://doi.org/10.14324/111.444/ucloe.000068
# 5729972            https://doi.org/10.14324/ucloe.1982
# 5730003                https://doi.org/10.5334/ai.0311
# 5727433                https://doi.org/10.5334/ai.3011
#
#                                           landing_page_url  \
# 5729973  https://journals.uclpress.co.uk/ucloe/article/...
# 5729972  https://journals.uclpress.co.uk/ucloe/article/...
# 5730003  https://journals.uclpress.co.uk/ai/article/id/...
# 5727433  https://journals.uclpress.co.uk/ai/article/id/...
#
#                                                      title     authors_flat  \
# 5729973  Use of evidence and expertise in UK climate go...  Willis, Rebecca
# 5729972  Use of evidence and expertise in UK climate go...  Willis, Rebecca
# 5730003  Hittites and "barbarians" in the Late Bronze A...  Matthews, Roger
# 5727433  Hittites and "barbarians" in the Late Bronze A...  Matthews, Roger
#
#         publication_year date_created relations_json version_label  \
# 5729973           2024.0   2024-02-08           None          None
# 5729972           2024.0   2024-01-30           None          None
# 5730003           2012.0   2024-02-27           None          None
# 5727433           1999.0   2013-05-03           None          None
#
#         is_version_of is_preprint_of has_preprint has_review  \
# 5729973
# 5729972
# 5730003
# 5727433
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 5729973                 false                       None                None
# 5729972                 false                       None                None
# 5730003                 false                       None                None
# 5727433                 false                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 5729973           None                   None            parent
# 5729972           None                   None            parent
# 5730003           None                   None            parent
# 5727433           None                   None            parent
#
#                                               landing_norm  \
# 5729973  https://journals.uclpress.co.uk/ucloe/article/...
# 5729972  https://journals.uclpress.co.uk/ucloe/article/...
# 5730003  https://journals.uclpress.co.uk/ai/article/id/...
# 5727433  https://journals.uclpress.co.uk/ai/article/id/...
#
#                               doi_norm version_token_lp token_kind_lp  \
# 5729973  10.14324/111.444/ucloe.000068             None          None
# 5729972            10.14324/ucloe.1982             None          None
# 5730003                10.5334/ai.0311             None          None
# 5727433                10.5334/ai.3011             None          None
#
#          vnum_lp version_token_doi token_kind_doi  vnum_doi
# 5729973      NaN              None           None       NaN
# 5729972      NaN              None           None       NaN
# 5730003      NaN              None           None       NaN
# 5727433      NaN              None           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='Humanities Commons CORE'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                             record_id              server_name   backend  \
# 1925010  datacite::10.17613/bah4-vw03  Humanities Commons CORE  datacite
# 1918000  datacite::10.17613/hs98-7t33  Humanities Commons CORE  datacite
# 1933841  datacite::10.17613/sbns-7n85  Humanities Commons CORE  datacite
# 1918005  datacite::10.17613/w01d-y281  Humanities Commons CORE  datacite
# 1918008  datacite::10.17613/x5jz-ym79  Humanities Commons CORE  datacite
# 1915118  datacite::10.17613/0smm-ms52  Humanities Commons CORE  datacite
# 1913978  datacite::10.17613/m67w67553  Humanities Commons CORE  datacite
# 1914556  datacite::10.17613/mxjy-1d38  Humanities Commons CORE  datacite
# 1915211  datacite::10.17613/pyew-7h37  Humanities Commons CORE  datacite
# 1924561  datacite::10.17613/zb50-ft02  Humanities Commons CORE  datacite
#
#                         doi                             doi_url  \
# 1925010  10.17613/bah4-vw03  https://doi.org/10.17613/bah4-vw03
# 1918000  10.17613/hs98-7t33  https://doi.org/10.17613/hs98-7t33
# 1933841  10.17613/sbns-7n85  https://doi.org/10.17613/sbns-7n85
# 1918005  10.17613/w01d-y281  https://doi.org/10.17613/w01d-y281
# 1918008  10.17613/x5jz-ym79  https://doi.org/10.17613/x5jz-ym79
# 1915118  10.17613/0smm-ms52  https://doi.org/10.17613/0smm-ms52
# 1913978  10.17613/m67w67553  https://doi.org/10.17613/m67w67553
# 1914556  10.17613/mxjy-1d38  https://doi.org/10.17613/mxjy-1d38
# 1915211  10.17613/pyew-7h37  https://doi.org/10.17613/pyew-7h37
# 1924561  10.17613/zb50-ft02  https://doi.org/10.17613/zb50-ft02
#
#                                landing_page_url title authors_flat  \
# 1925010  https://hcommons.org/deposits/removed/  <NA>     N/A, N/A
# 1918000  https://hcommons.org/deposits/removed/  <NA>         <NA>
# 1933841  https://hcommons.org/deposits/removed/  <NA>     N/A, N/A
# 1918005  https://hcommons.org/deposits/removed/  <NA>         <NA>
# 1918008  https://hcommons.org/deposits/removed/  <NA>         <NA>
# 1915118   https://hcommons.org/deposits/removed  <NA>     N/A, N/A
# 1913978   https://hcommons.org/deposits/removed  <NA>     N/A, N/A
# 1914556   https://hcommons.org/deposits/removed  <NA>     N/A, N/A
# 1915211   https://hcommons.org/deposits/removed  <NA>     N/A, N/A
# 1924561   https://hcommons.org/deposits/removed  <NA>     N/A, N/A
#
#         publication_year date_created relations_json version_label  \
# 1925010           2026.0   2024-05-03             []          None
# 1918000           2020.0   2021-11-30             []          None
# 1933841           2024.0   2024-07-20             []          None
# 1918005           2021.0   2021-12-01             []          None
# 1918008           2022.0   2021-12-02             []          None
# 1915118           2019.0   2019-09-15             []          None
# 1913978           2017.0   2018-10-14             []          None
# 1914556           2015.0   2019-04-12             []          None
# 1915211           2019.0   2019-10-19             []          None
# 1924561           2016.0   2024-03-11             []          None
#
#         is_version_of is_preprint_of has_preprint has_review  \
# 1925010
# 1918000
# 1933841
# 1918005
# 1918008
# 1915118
# 1913978
# 1914556
# 1915211
# 1924561
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 1925010                 false                       None                None
# 1918000                 false                       None                None
# 1933841                 false                       None                None
# 1918005                 false                       None                None
# 1918008                 false                       None                None
# 1915118                 false                       None                None
# 1913978                 false                       None                None
# 1914556                 false                       None                None
# 1915211                 false                       None                None
# 1924561                 false                       None                None
#
#         update_to_json                             raw_relationships_json  \
# 1925010           None  {"client": {"data": {"id": "msu.core", "type":...
# 1918000           None  {"client": {"data": {"id": "msu.core", "type":...
# 1933841           None  {"client": {"data": {"id": "msu.core", "type":...
# 1918005           None  {"client": {"data": {"id": "msu.core", "type":...
# 1918008           None  {"client": {"data": {"id": "msu.core", "type":...
# 1915118           None  {"client": {"data": {"id": "msu.core", "type":...
# 1913978           None  {"client": {"data": {"id": "msu.core", "type":...
# 1914556           None  {"client": {"data": {"id": "msu.core", "type":...
# 1915211           None  {"client": {"data": {"id": "msu.core", "type":...
# 1924561           None  {"client": {"data": {"id": "msu.core", "type":...
#
#         records_hierarchy                            landing_norm  \
# 1925010            parent  https://hcommons.org/deposits/removed/
# 1918000            parent  https://hcommons.org/deposits/removed/
# 1933841            parent  https://hcommons.org/deposits/removed/
# 1918005            parent  https://hcommons.org/deposits/removed/
# 1918008            parent  https://hcommons.org/deposits/removed/
# 1915118            parent   https://hcommons.org/deposits/removed
# 1913978            parent   https://hcommons.org/deposits/removed
# 1914556            parent   https://hcommons.org/deposits/removed
# 1915211            parent   https://hcommons.org/deposits/removed
# 1924561            parent   https://hcommons.org/deposits/removed
#
#                    doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 1925010  10.17613/bah4-vw03             None          None      NaN
# 1918000  10.17613/hs98-7t33             None          None      NaN
# 1933841  10.17613/sbns-7n85             None          None      NaN
# 1918005  10.17613/w01d-y281             None          None      NaN
# 1918008  10.17613/x5jz-ym79             None          None      NaN
# 1915118  10.17613/0smm-ms52             None          None      NaN
# 1913978  10.17613/m67w67553             None          None      NaN
# 1914556  10.17613/mxjy-1d38             None          None      NaN
# 1915211  10.17613/pyew-7h37             None          None      NaN
# 1924561  10.17613/zb50-ft02             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
#
# 5660039              Midtgård, Kenneth; Selart, Marcus           2024.0
# 5649248              Midtgård, Kenneth; Selart, Marcus           2024.0
# 5664484             Schnakenberg, Keith; Turner, Ian R           2023.0
# 5649343             Schnakenberg, Keith; Turner, Ian R           2023.0
#
#         date_created                                     relations_json  \
# 5645994   2022-03-14                                               None
# 5664641   2023-12-16                                               None
# 5649227   2025-06-12                                               None
# 5658710   2021-01-07                                               None
# 5649266   2025-06-17                                               None
# 5660039   2024-03-02                                               None
# 5649248   2025-06-13                                               None
# 5664484   2023-01-07  {"is-preprint-of": [{"asserted-by": "subject",...
# 5649343   2025-06-24  {"is-preprint-of": [{"asserted-by": "subject",...
#
#         version_label is_version_of  is_preprint_of has_preprint has_review  \
# 5645994          None
# 5664641          None
# 5649227          None
# 5658710          None
# 5649266          None
# 5660039          None
# 5649248          None
# 5664484          None                10.1086/734548
# 5649343          None                10.1086/734548
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 5645994                 false                       None                None
# 5664641                 false                       None                None
# 5649227                 false                       None                None
# 5658710                 false                       None                None
# 5649266                 false                       None                None
# 5660039                 false                       None                None
# 5649248                 false                       None                None
# 5664484                  true                       None                None
# 5649343                  true                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 5645994           None                   None            parent
# 5664641           None                   None            parent
# 5649227           None                   None            parent
# 5658710           None                   None            parent
# 5649266           None                   None            parent
# 5660039           None                   None            parent
# 5649248           None                   None            parent
# 5664484           None                   None            parent
# 5649343           None                   None            parent
#
#                     landing_norm                  doi_norm version_token_lp  \
# 5645994     https://osf.io/w4mhc     10.31235/osf.io/w4mhc             None
# 5664641  https://osf.io/8zejr_v1     10.31235/osf.io/8zejr              _v1
# 5649227  https://osf.io/8zejr_v1  10.31235/osf.io/8zejr_v1              _v1
# 5658710  https://osf.io/8hvm6_v1     10.31235/osf.io/8hvm6              _v1
# 5649266  https://osf.io/8hvm6_v1  10.31235/osf.io/8hvm6_v1              _v1
# 5660039  https://osf.io/4xpza_v1     10.31235/osf.io/4xpza              _v1
# 5649248  https://osf.io/4xpza_v1  10.31235/osf.io/4xpza_v1              _v1
# 5664484  https://osf.io/3bzex_v1     10.31235/osf.io/3bzex              _v1
# 5649343  https://osf.io/3bzex_v1  10.31235/osf.io/3bzex_v1              _v1
#
#             token_kind_lp  vnum_lp version_token_doi token_kind_doi  vnum_doi
# 5645994              None      NaN              None           None       NaN
# 5664641  explicit_version      1.0               NaN            NaN       NaN
# 5649227  explicit_version      1.0               NaN            NaN       NaN
# 5658710  explicit_version      1.0               NaN            NaN       NaN
# 5649266  explicit_version      1.0               NaN            NaN       NaN
# 5660039  explicit_version      1.0               NaN            NaN       NaN
# 5649248  explicit_version      1.0               NaN            NaN       NaN
# 5664484  explicit_version      1.0               NaN            NaN       NaN
# 5649343  explicit_version      1.0               NaN            NaN       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='ART-Dok'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                 record_id server_name   backend  \
# 5612   datacite::10.11588/artdok.00002463     ART-Dok  datacite
# 5613   datacite::10.11588/artdok.00002464     ART-Dok  datacite
# 10433  datacite::10.11588/artdok.00008068     ART-Dok  datacite
# 10521  datacite::10.11588/artdok.00008143     ART-Dok  datacite
# 5910   datacite::10.11588/artdok.00002777     ART-Dok  datacite
# 10130  datacite::10.11588/artdok.00007786     ART-Dok  datacite
# 8987   datacite::10.11588/artdok.00006572     ART-Dok  datacite
# 9039   datacite::10.11588/artdok.00006627     ART-Dok  datacite
#
#                             doi                                   doi_url  \
# 5612   10.11588/artdok.00002463  https://doi.org/10.11588/artdok.00002463
# 5613   10.11588/artdok.00002464  https://doi.org/10.11588/artdok.00002464
# 10433  10.11588/artdok.00008068  https://doi.org/10.11588/artdok.00008068
# 10521  10.11588/artdok.00008143  https://doi.org/10.11588/artdok.00008143
# 5910   10.11588/artdok.00002777  https://doi.org/10.11588/artdok.00002777
# 10130  10.11588/artdok.00007786  https://doi.org/10.11588/artdok.00007786
# 8987   10.11588/artdok.00006572  https://doi.org/10.11588/artdok.00006572
# 9039   10.11588/artdok.00006627  https://doi.org/10.11588/artdok.00006627
#
#                                         landing_page_url  \
# 5612   https://www.ub.uni-heidelberg.de/helios/digi/r...
# 5613   https://www.ub.uni-heidelberg.de/helios/digi/r...
# 10433  https://archiv.ub.uni-heidelberg.de/artdok/id/...
# 10521  https://archiv.ub.uni-heidelberg.de/artdok/id/...
# 5910   https://archiv.ub.uni-heidelberg.de/artdok/id/...
# 10130  https://archiv.ub.uni-heidelberg.de/artdok/id/...
# 8987   http://archiv.ub.uni-heidelberg.de/artdok/id/e...
# 9039   http://archiv.ub.uni-heidelberg.de/artdok/id/e...
#
#                                                    title  \
# 5612   Sprachtäter, Ausschließensmechanismus, Reine\r...
# 5613   Die nicht zum Ausdruck gekommene Moderne und e...
# 10433                                Malarstwo witrażowe
# 10521                                Malarstwo witrażowe
# 5910   Visuelle Topoi um 1600. Annibale Carracci zwis...
# 10130  Visuelle Topoi um 1600. Annibale Carracci zwis...
# 8987   Una versione sconosciuta della tela di Giovann...
# 9039   Una versione sconosciuta della tela di Giovann...
#
#                                             authors_flat publication_year  \
# 5612                       Riahi, Azam; Zafani Rad, Nika           2014.0
# 5613                                         Riahi, Azam           2014.0
# 10433  Labuda, Adam S. [Hrsg.]; Secomska, Krystyna [H...           2023.0
# 10521  Labuda, Adam S. [Hrsg.]; Secomska, Krystyna [H...           2023.0
# 5910   Dickhut, Wolfgang [Hrsg.]; Manns, Stefan [Hrsg...           2022.0
# 10130  Dickhut, Wolfgang [Hrsg.]; Manns, Stefan [Hrsg...           2022.0
# 8987                                Kienlechner, Susanne           2019.0
# 9039                                Kienlechner, Susanne           2019.0
#
#       date_created relations_json version_label is_version_of is_preprint_of  \
# 5612    2017-02-15             []          None
# 5613    2017-02-15             []          None
# 10433   2022-12-07             []          None
# 10521   2023-02-08             []          None
# 5910    2017-02-15             []          None
# 10130   2022-04-25             []          None
# 8987    2019-09-17             []          None
# 9039    2019-10-18             []          None
#
#       has_preprint has_review has_published_version  \
# 5612                                          false
# 5613                                          false
# 10433                                         false
# 10521                                         false
# 5910                                          false
# 10130                                         false
# 8987                                          false
# 9039                                          false
#
#       published_version_ids_json version_of_ids_json update_to_json  \
# 5612                        None                None           None
# 5613                        None                None           None
# 10433                       None                None           None
# 10521                       None                None           None
# 5910                        None                None           None
# 10130                       None                None           None
# 8987                        None                None           None
# 9039                        None                None           None
#
#                                   raw_relationships_json records_hierarchy  \
# 5612   {"client": {"data": {"id": "gesis.ubhd", "type...            parent
# 5613   {"client": {"data": {"id": "gesis.ubhd", "type...            parent
# 10433  {"client": {"data": {"id": "gesis.ubhd", "type...            parent
# 10521  {"client": {"data": {"id": "gesis.ubhd", "type...            parent
# 5910   {"client": {"data": {"id": "gesis.ubhd", "type...            parent
# 10130  {"client": {"data": {"id": "gesis.ubhd", "type...            parent
# 8987   {"client": {"data": {"id": "gesis.ubhd", "type...            parent
# 9039   {"client": {"data": {"id": "gesis.ubhd", "type...            parent
#
#                                             landing_norm  \
# 5612   https://www.ub.uni-heidelberg.de/helios/digi/r...
# 5613   https://www.ub.uni-heidelberg.de/helios/digi/r...
# 10433  https://archiv.ub.uni-heidelberg.de/artdok/id/...
# 10521  https://archiv.ub.uni-heidelberg.de/artdok/id/...
# 5910   https://archiv.ub.uni-heidelberg.de/artdok/id/...
# 10130  https://archiv.ub.uni-heidelberg.de/artdok/id/...
# 8987   http://archiv.ub.uni-heidelberg.de/artdok/id/e...
# 9039   http://archiv.ub.uni-heidelberg.de/artdok/id/e...
#
#                        doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 5612   10.11588/artdok.00002463             None          None      NaN
# 5613   10.11588/artdok.00002464             None          None      NaN
# 10433  10.11588/artdok.00008068             None          None      NaN
# 10521  10.11588/artdok.00008143             None          None      NaN
# 5910   10.11588/artdok.00002777             None          None      NaN
# 10130  10.11588/artdok.00007786             None          None      NaN
# 8987   10.11588/artdok.00006572             None          None      NaN
# 9039   10.11588/artdok.00006627             None          None      NaN
#
#       version_token_doi token_kind_doi  vnum_doi
# 5612               None           None       NaN
# 5613               None           None       NaN
# 10433              None           None       NaN
# 10521              None           None       NaN
# 5910               None           None       NaN
# 10130              None           None       NaN
# 8987               None           None       NaN
# 9039               None           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='EconStor Preprints'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                     record_id         server_name   backend   doi doi_url  \
# 505270  openalex::W2241195487  EconStor Preprints  openalex  <NA>    None
# 470304  openalex::W2888303629  EconStor Preprints  openalex  <NA>    None
# 518111  openalex::W3049474313  EconStor Preprints  openalex  <NA>    None
# 526939  openalex::W7112520020  EconStor Preprints  openalex  <NA>    None
# 513062  openalex::W2756173876  EconStor Preprints  openalex  <NA>    None
# 513356  openalex::W2774257793  EconStor Preprints  openalex  <NA>    None
# 469269  openalex::W2265687887  EconStor Preprints  openalex  <NA>    None
# 526731  openalex::W7112003676  EconStor Preprints  openalex  <NA>    None
#
#                                          landing_page_url  \
# 505270  https://econpapers.repec.org/RePEc:zbw:espost:...
# 470304  https://econpapers.repec.org/RePEc:zbw:espost:...
# 518111                 http://hdl.handle.net/10419/218808
# 526939                 http://hdl.handle.net/10419/218808
# 513062                 http://hdl.handle.net/10419/172735
# 513356                 http://hdl.handle.net/10419/172735
# 469269                 http://hdl.handle.net/10419/124252
# 526731                 http://hdl.handle.net/10419/124252
#
#                                                     title  \
# 505270  Electric Vehicles in Imperfect Electricity Mar...
# 470304  Electric Vehicles in Imperfect Electricity Mar...
# 518111       Industrie dämpft die konjunkturelle Erholung
# 526939       Industrie dämpft die konjunkturelle Erholung
# 513062  Neue Ordnung, neues Glück? Ordnungs- und fiska...
# 513356  Neue Ordnung, neues Glück?New Rules, New Luck?...
# 469269  Technological Progress and Economic Geography_...
# 526731      Technological Progress and Economic Geography
#
#                                              authors_flat publication_year  \
# 505270                                  Wolf-Peter Schill           2011.0
# 470304                                  Wolf-Peter Schill           2011.0
# 518111  Schmidt Torsten; György Barabás; Boris Blagov;...           2019.0
# 526939  Schmidt Torsten; Barabás, György; Blagov, Bori...           2019.0
# 513062                     Markus Breuer; Luca Rebeggiani           2017.0
# 513356                     Luca Rebeggiani; Markus Breuer           2017.0
# 469269       Jacques Thisse; Takatoshi Tabuchi; Xiwei Zhu           2014.0
# 526731       Thisse Jacques; Tabuchi Takatoshi; Zhu Xiwei           2014.0
#
#                date_created relations_json version_label is_version_of  \
# 505270  2025-10-10T00:00:00           None          None          None
# 470304  2025-10-10T00:00:00           None          None          None
# 518111  2025-10-10T00:00:00           None          None          None
# 526939  2025-12-10T00:00:00           None          None          None
# 513062  2025-10-10T00:00:00           None          None          None
# 513356  2025-10-10T00:00:00           None          None          None
# 469269  2025-10-10T00:00:00           None          None          None
# 526731  2025-12-10T00:00:00           None          None          None
#
#        is_preprint_of has_preprint has_review has_published_version  \
# 505270           None         None       None                  None
# 470304           None         None       None                  None
# 518111           None         None       None                  None
# 526939           None         None       None                  None
# 513062           None         None       None                  None
# 513356           None         None       None                  None
# 469269           None         None       None                  None
# 526731           None         None       None                  None
#
#        published_version_ids_json version_of_ids_json update_to_json  \
# 505270                       None                None           None
# 470304                       None                None           None
# 518111                       None                None           None
# 526939                       None                None           None
# 513062                       None                None           None
# 513356                       None                None           None
# 469269                       None                None           None
# 526731                       None                None           None
#
#        raw_relationships_json records_hierarchy  \
# 505270                   None            parent
# 470304                   None            parent
# 518111                   None            parent
# 526939                   None            parent
# 513062                   None            parent
# 513356                   None            parent
# 469269                   None            parent
# 526731                   None            parent
#
#                                              landing_norm doi_norm  \
# 505270  https://econpapers.repec.org/repec:zbw:espost:...     <na>
# 470304  https://econpapers.repec.org/repec:zbw:espost:...     <na>
# 518111                 http://hdl.handle.net/10419/218808     <na>
# 526939                 http://hdl.handle.net/10419/218808     <na>
# 513062                 http://hdl.handle.net/10419/172735     <na>
# 513356                 http://hdl.handle.net/10419/172735     <na>
# 469269                 http://hdl.handle.net/10419/124252     <na>
# 526731                 http://hdl.handle.net/10419/124252     <na>
#
#        version_token_lp token_kind_lp  vnum_lp version_token_doi  \
# 505270             None          None      NaN              None
# 470304             None          None      NaN              None
# 518111             None          None      NaN              None
# 526939             None          None      NaN              None
# 513062             None          None      NaN              None
# 513356             None          None      NaN              None
# 469269             None          None      NaN              None
# 526731             None          None      NaN              None
#
#        token_kind_doi  vnum_doi
# 505270           None       NaN
# 470304           None       NaN
# 518111           None       NaN
# 526939           None       NaN
# 513062           None       NaN
# 513356           None       NaN
# 469269           None       NaN
# 526731           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='viXra'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                      record_id server_name   backend   doi doi_url  \
# 9461323  openalex::W2419579416       viXra  openalex  <NA>    None
# 9471642    openalex::W26151073       viXra  openalex  <NA>    None
# 9461459    openalex::W18990831       viXra  openalex  <NA>    None
# 9480335  openalex::W2994514029       viXra  openalex  <NA>    None
# 9461995  openalex::W2412976284       viXra  openalex  <NA>    None
# 9485177     openalex::W4706860       viXra  openalex  <NA>    None
#
#                                        landing_page_url  \
# 9461323           https://vixra.org/pdf/1405.0153v1.pdf
# 9471642           https://vixra.org/pdf/1405.0153v1.pdf
# 9461459           https://vixra.org/pdf/1405.0117v1.pdf
# 9480335           https://vixra.org/pdf/1405.0117v1.pdf
# 9461995  http://article.aascit.org/file/pdf/9090755.pdf
# 9485177  http://article.aascit.org/file/pdf/9090755.pdf
#
#                                                      title  \
# 9461323      Pregnancy hormones in cardiovascular disease.
# 9471642  Structure of Chromatic Polynomials on Quasi - ...
# 9461459  Optimization of Green Sand Casting Process Par...
# 9480335  Optimization of Green Sand Casting Process Par...
# 9461995  Ether-medium and a new constant on photons rad...
# 9485177  Ether-medium and a new constant on photons rad...
#
#                                               authors_flat publication_year  \
# 9461323                            Denise Hilfiker‐Kleiner           2015.0
# 9471642  R.V.N. SrinivasaRao; J. VenkateswaraRao; T. Na...           2014.0
# 9461459     Sanjay S. Jamkar; M. J. Deshmukh; N.A. Vidhate           2014.0
# 9480335                                      John Casillas           2014.0
# 9461995                      Edward F. Donnelly; T N Chase           2014.0
# 9485177                               Jian Ding; HU Xiuqin           2014.0
#
#                 date_created relations_json version_label is_version_of  \
# 9461323  2025-10-10T00:00:00           None          None          None
# 9471642  2016-06-24T00:00:00           None          None          None
# 9461459  2016-06-24T00:00:00           None          None          None
# 9480335  2019-12-13T00:00:00           None          None          None
# 9461995  2025-10-10T00:00:00           None          None          None
# 9485177  2016-06-24T00:00:00           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 9461323           None         None       None                  None
# 9471642           None         None       None                  None
# 9461459           None         None       None                  None
# 9480335           None         None       None                  None
# 9461995           None         None       None                  None
# 9485177           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 9461323                       None                None           None
# 9471642                       None                None           None
# 9461459                       None                None           None
# 9480335                       None                None           None
# 9461995                       None                None           None
# 9485177                       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 9461323                   None            parent
# 9471642                   None            parent
# 9461459                   None            parent
# 9480335                   None            parent
# 9461995                   None            parent
# 9485177                   None            parent
#
#                                            landing_norm doi_norm  \
# 9461323           https://vixra.org/pdf/1405.0153v1.pdf     <na>
# 9471642           https://vixra.org/pdf/1405.0153v1.pdf     <na>
# 9461459           https://vixra.org/pdf/1405.0117v1.pdf     <na>
# 9480335           https://vixra.org/pdf/1405.0117v1.pdf     <na>
# 9461995  http://article.aascit.org/file/pdf/9090755.pdf     <na>
# 9485177  http://article.aascit.org/file/pdf/9090755.pdf     <na>
#
#         version_token_lp token_kind_lp  vnum_lp version_token_doi  \
# 9461323             None          None      NaN              None
# 9471642             None          None      NaN              None
# 9461459             None          None      NaN              None
# 9480335             None          None      NaN              None
# 9461995             None          None      NaN              None
# 9485177             None          None      NaN              None
#
#         token_kind_doi  vnum_doi
# 9461323           None       NaN
# 9471642           None       NaN
# 9461459           None       NaN
# 9480335           None       NaN
# 9461995           None       NaN
# 9485177           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='PeerJ Preprints'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                          record_id      server_name   backend  \
# 2259283     crossref::10.7287/peerj.preprints.3516  PeerJ Preprints  crossref
# 2259284   crossref::10.7287/peerj.preprints.3516v1  PeerJ Preprints  crossref
# 2259289    crossref::10.7287/peerj.preprints.26897  PeerJ Preprints  crossref
# 2259288  crossref::10.7287/peerj.preprints.26897v1  PeerJ Preprints  crossref
# 2259286    crossref::10.7287/peerj.preprints.26769  PeerJ Preprints  crossref
# 2259285  crossref::10.7287/peerj.preprints.26769v1  PeerJ Preprints  crossref
#
#                                      doi  \
# 2259283     10.7287/peerj.preprints.3516
# 2259284   10.7287/peerj.preprints.3516v1
# 2259289    10.7287/peerj.preprints.26897
# 2259288  10.7287/peerj.preprints.26897v1
# 2259286    10.7287/peerj.preprints.26769
# 2259285  10.7287/peerj.preprints.26769v1
#
#                                                  doi_url  \
# 2259283     https://doi.org/10.7287/peerj.preprints.3516
# 2259284   https://doi.org/10.7287/peerj.preprints.3516v1
# 2259289    https://doi.org/10.7287/peerj.preprints.26897
# 2259288  https://doi.org/10.7287/peerj.preprints.26897v1
# 2259286    https://doi.org/10.7287/peerj.preprints.26769
# 2259285  https://doi.org/10.7287/peerj.preprints.26769v1
#
#                           landing_page_url  \
# 2259283   https://peerj.com/preprints/3516
# 2259284   https://peerj.com/preprints/3516
# 2259289  https://peerj.com/preprints/26897
# 2259288  https://peerj.com/preprints/26897
# 2259286  https://peerj.com/preprints/26769
# 2259285  https://peerj.com/preprints/26769
#
#                                                      title  \
# 2259283  Factors affecting silk production in Japanese ...
# 2259284  Factors affecting silk production in Japanese ...
# 2259289  The effect of intestinal <i>Bifidobacterium</i...
# 2259288  The effect of intestinal <i>Bifidobacterium</i...
# 2259286  The effect of cyclical stimulation on the prim...
# 2259285  The effect of cyclical stimulation on the prim...
#
#                      authors_flat publication_year date_created  \
# 2259283  Zuko, Yeti; Maeda, Kazuo           2018.0   2018-01-09
# 2259284  Zuko, Yeti; Maeda, Kazuo           2018.0   2018-01-09
# 2259289  Zuko, Yeti; Maeda, Kazuo           2018.0   2018-04-26
# 2259288  Zuko, Yeti; Maeda, Kazuo           2018.0   2018-04-26
# 2259286  Zuko, Yeti; Maeda, Kazuo           2018.0   2018-03-25
# 2259285  Zuko, Yeti; Maeda, Kazuo           2018.0   2018-03-25
#
#         relations_json version_label is_version_of is_preprint_of  \
# 2259283           None          None
# 2259284           None          None
# 2259289           None          None
# 2259288           None          None
# 2259286           None          None
# 2259285           None          None
#
#         has_preprint has_review has_published_version  \
# 2259283                                         false
# 2259284                                         false
# 2259289                                         false
# 2259288                                         false
# 2259286                                         false
# 2259285                                         false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 2259283                       None                None           None
# 2259284                       None                None           None
# 2259289                       None                None           None
# 2259288                       None                None           None
# 2259286                       None                None           None
# 2259285                       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 2259283                   None            parent
# 2259284                   None            parent
# 2259289                   None            parent
# 2259288                   None            parent
# 2259286                   None            parent
# 2259285                   None            parent
#
#                               landing_norm                         doi_norm  \
# 2259283   https://peerj.com/preprints/3516     10.7287/peerj.preprints.3516
# 2259284   https://peerj.com/preprints/3516   10.7287/peerj.preprints.3516v1
# 2259289  https://peerj.com/preprints/26897    10.7287/peerj.preprints.26897
# 2259288  https://peerj.com/preprints/26897  10.7287/peerj.preprints.26897v1
# 2259286  https://peerj.com/preprints/26769    10.7287/peerj.preprints.26769
# 2259285  https://peerj.com/preprints/26769  10.7287/peerj.preprints.26769v1
#
#         version_token_lp token_kind_lp  vnum_lp version_token_doi  \
# 2259283             None          None      NaN              None
# 2259284             None          None      NaN              None
# 2259289             None          None      NaN              None
# 2259288             None          None      NaN              None
# 2259286             None          None      NaN              None
# 2259285             None          None      NaN              None
#
#         token_kind_doi  vnum_doi
# 2259283           None       NaN
# 2259284           None       NaN
# 2259289           None       NaN
# 2259288           None       NaN
# 2259286           None       NaN
# 2259285           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='MetaArXiv'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                   record_id server_name   backend  \
# 2014772     crossref::10.31222/osf.io/uxf39   MetaArXiv  crossref
# 2014395  crossref::10.31222/osf.io/uxf39_v1   MetaArXiv  crossref
# 2014770     crossref::10.31222/osf.io/a9vhr   MetaArXiv  crossref
# 2014396  crossref::10.31222/osf.io/a9vhr_v1   MetaArXiv  crossref
# 2014776     crossref::10.31222/osf.io/8ya3m   MetaArXiv  crossref
# 2014401  crossref::10.31222/osf.io/8ya3m_v1   MetaArXiv  crossref
#
#                               doi                                   doi_url  \
# 2014772     10.31222/osf.io/uxf39     https://doi.org/10.31222/osf.io/uxf39
# 2014395  10.31222/osf.io/uxf39_v1  https://doi.org/10.31222/osf.io/uxf39_v1
# 2014770     10.31222/osf.io/a9vhr     https://doi.org/10.31222/osf.io/a9vhr
# 2014396  10.31222/osf.io/a9vhr_v1  https://doi.org/10.31222/osf.io/a9vhr_v1
# 2014776     10.31222/osf.io/8ya3m     https://doi.org/10.31222/osf.io/8ya3m
# 2014401  10.31222/osf.io/8ya3m_v1  https://doi.org/10.31222/osf.io/8ya3m_v1
#
#                 landing_page_url  \
# 2014772  https://osf.io/uxf39_v1
# 2014395  https://osf.io/uxf39_v1
# 2014770  https://osf.io/a9vhr_v1
# 2014396  https://osf.io/a9vhr_v1
# 2014776  https://osf.io/8ya3m_v1
# 2014401  https://osf.io/8ya3m_v1
#
#                                                      title  \
# 2014772  Do Pre-Registration and Pre-analysis Plans Red...
# 2014395  Do Pre-Registration and Pre-analysis Plans Red...
# 2014770  We Need to Talk about Mechanical Turk: What 22...
# 2014396  We Need to Talk about Mechanical Turk: What 22...
# 2014776  The influence of journal submission guidelines...
# 2014401  The influence of journal submission guidelines...
#
#                                               authors_flat publication_year  \
# 2014772  Brodeur, Abel; Cook, Nikolai; Hartley, Jonatha...           2022.0
# 2014395  Brodeur, Abel; Cook, Nikolai; Hartley, Jonatha...           2022.0
# 2014770       Brodeur, Abel; Cook, Nikolai; Heyes, Anthony           2022.0
# 2014396       Brodeur, Abel; Cook, Nikolai; Heyes, Anthony           2022.0
# 2014776  Giofrè, David; Boedker, Ingrid; Cumming, Geoff...           2022.0
# 2014401  Giofrè, David; Boedker, Ingrid; Cumming, Geoff...           2022.0
#
#         date_created relations_json version_label is_version_of  \
# 2014772   2022-08-11           None          None
# 2014395   2025-06-23           None          None
# 2014770   2022-08-11           None          None
# 2014396   2025-06-23           None          None
# 2014776   2022-03-07           None          None
# 2014401   2025-06-25           None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 2014772                                                        false
# 2014395                                                        false
# 2014770                                                        false
# 2014396                                                        false
# 2014776                                                        false
# 2014401                                                        false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 2014772                       None                None           None
# 2014395                       None                None           None
# 2014770                       None                None           None
# 2014396                       None                None           None
# 2014776                       None                None           None
# 2014401                       None                None           None
#
#         raw_relationships_json records_hierarchy             landing_norm  \
# 2014772                   None            parent  https://osf.io/uxf39_v1
# 2014395                   None            parent  https://osf.io/uxf39_v1
# 2014770                   None            parent  https://osf.io/a9vhr_v1
# 2014396                   None            parent  https://osf.io/a9vhr_v1
# 2014776                   None            parent  https://osf.io/8ya3m_v1
# 2014401                   None            parent  https://osf.io/8ya3m_v1
#
#                          doi_norm version_token_lp     token_kind_lp  vnum_lp  \
# 2014772     10.31222/osf.io/uxf39              _v1  explicit_version      1.0
# 2014395  10.31222/osf.io/uxf39_v1              _v1  explicit_version      1.0
# 2014770     10.31222/osf.io/a9vhr              _v1  explicit_version      1.0
# 2014396  10.31222/osf.io/a9vhr_v1              _v1  explicit_version      1.0
# 2014776     10.31222/osf.io/8ya3m              _v1  explicit_version      1.0
# 2014401  10.31222/osf.io/8ya3m_v1              _v1  explicit_version      1.0
#
#         version_token_doi token_kind_doi  vnum_doi
# 2014772               NaN            NaN       NaN
# 2014395               NaN            NaN       NaN
# 2014770               NaN            NaN       NaN
# 2014396               NaN            NaN       NaN
# 2014776               NaN            NaN       NaN
# 2014401               NaN            NaN       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='WikiJournal of Humanities'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                record_id                server_name   backend  \
# 5736146           crossref::10.15347/wjh  WikiJournal of Humanities  crossref
# 5736152  crossref::10.15347/wjh/2023.001  WikiJournal of Humanities  crossref
# 5736145  crossref::10.15347/wjh/2019.004  WikiJournal of Humanities  crossref
# 5736143  crossref::10.15347/wjx/2019.004  WikiJournal of Humanities  crossref
#
#                            doi                                doi_url  \
# 5736146           10.15347/wjh           https://doi.org/10.15347/wjh
# 5736152  10.15347/wjh/2023.001  https://doi.org/10.15347/wjh/2023.001
# 5736145  10.15347/wjh/2019.004  https://doi.org/10.15347/wjh/2019.004
# 5736143  10.15347/wjx/2019.004  https://doi.org/10.15347/wjx/2019.004
#
#                                           landing_page_url  \
# 5736146  https://en.wikiversity.org/wiki/WikiJournal_of...
# 5736152  https://en.wikiversity.org/wiki/WikiJournal_of...
# 5736145  https://en.wikiversity.org/wiki/WikiJournal_of...
# 5736143  https://en.wikiversity.org/wiki/WikiJournal_of...
#
#                              title     authors_flat publication_year  \
# 5736146  WikiJournal of Humanities             <NA>             None
# 5736152              Loveday, 1458             <NA>           2023.0
# 5736145         Hilda Rix Nicholas  Holland, Hannah           2019.0
# 5736143         Hilda Rix Nicholas  Holland, Hannah           2019.0
#
#         date_created relations_json version_label is_version_of  \
# 5736146   2017-10-25           None          None
# 5736152   2023-06-19           None          None
# 5736145   2019-12-04           None          None
# 5736143   2019-12-04           None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 5736146                                                        false
# 5736152                                                        false
# 5736145                                                        false
# 5736143                                                        false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 5736146                       None                None           None
# 5736152                       None                None           None
# 5736145                       None                None           None
# 5736143                       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 5736146                   None            parent
# 5736152                   None            parent
# 5736145                   None            parent
# 5736143                   None            parent
#
#                                               landing_norm  \
# 5736146  https://en.wikiversity.org/wiki/wikijournal_of...
# 5736152  https://en.wikiversity.org/wiki/wikijournal_of...
# 5736145  https://en.wikiversity.org/wiki/wikijournal_of...
# 5736143  https://en.wikiversity.org/wiki/wikijournal_of...
#
#                       doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 5736146           10.15347/wjh             None          None      NaN
# 5736152  10.15347/wjh/2023.001             None          None      NaN
# 5736145  10.15347/wjh/2019.004             None          None      NaN
# 5736143  10.15347/wjx/2019.004             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 5736146              None           None       NaN
# 5736152              None           None       NaN
# 5736145              None           None       NaN
# 5736143              None           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='WikiJournal of Medicine'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                  record_id              server_name   backend  \
# 5736159    crossref::10.15347/wjm/2019.009  WikiJournal of Medicine  crossref
# 5736172  crossref::10.15347/wjm/2020.001.2  WikiJournal of Medicine  crossref
# 5736210             crossref::10.15347/wjm  WikiJournal of Medicine  crossref
# 5736211    crossref::10.15347/wjm/2024.001  WikiJournal of Medicine  crossref
#
#                              doi                                  doi_url  \
# 5736159    10.15347/wjm/2019.009    https://doi.org/10.15347/wjm/2019.009
# 5736172  10.15347/wjm/2020.001.2  https://doi.org/10.15347/wjm/2020.001.2
# 5736210             10.15347/wjm             https://doi.org/10.15347/wjm
# 5736211    10.15347/wjm/2024.001    https://doi.org/10.15347/wjm/2024.001
#
#                                           landing_page_url  \
# 5736159  https://en.wikiversity.org/wiki/WikiJournal_of...
# 5736172  https://en.wikiversity.org/wiki/WikiJournal_of...
# 5736210  https://en.wikiversity.org/wiki/WikiJournal_Pr...
# 5736211  https://en.wikiversity.org/wiki/WikiJournal_Pr...
#
#                                               title  \
# 5736159       Epidemiology of the Hepatitis D virus
# 5736172       Epidemiology of the Hepatitis D virus
# 5736210                     WikiJournal of Medicine
# 5736211  Body image disturbance in eating disorders
#
#                                          authors_flat publication_year  \
# 5736159  University of Torino, Italy; Rizzetto, Mario           2020.0
# 5736172                               Rizzetto, Mario           2020.0
# 5736210                                          <NA>             None
# 5736211                                 Artoni, Paolo           2024.0
#
#         date_created relations_json version_label is_version_of  \
# 5736159   2020-03-29           None          None
# 5736172   2020-04-06           None          None
# 5736210   2024-05-01           None          None
# 5736211   2024-05-01           None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 5736159                                                        false
# 5736172                                                        false
# 5736210                                                        false
# 5736211                                                        false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 5736159                       None                None           None
# 5736172                       None                None           None
# 5736210                       None                None           None
# 5736211                       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 5736159                   None            parent
# 5736172                   None            parent
# 5736210                   None            parent
# 5736211                   None            parent
#
#                                               landing_norm  \
# 5736159  https://en.wikiversity.org/wiki/wikijournal_of...
# 5736172  https://en.wikiversity.org/wiki/wikijournal_of...
# 5736210  https://en.wikiversity.org/wiki/wikijournal_pr...
# 5736211  https://en.wikiversity.org/wiki/wikijournal_pr...
#
#                         doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 5736159    10.15347/wjm/2019.009             None          None      NaN
# 5736172  10.15347/wjm/2020.001.2             None          None      NaN
# 5736210             10.15347/wjm             None          None      NaN
# 5736211    10.15347/wjm/2024.001             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 5736159              None           None       NaN
# 5736172              None           None       NaN
# 5736210              None           None       NaN
# 5736211              None           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='Bepress Legal Repository'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                     record_id               server_name   backend  \
# 274423  openalex::W1562651827  Bepress Legal Repository  openalex
# 274426  openalex::W1672512695  Bepress Legal Repository  openalex
# 274427   openalex::W784155097  Bepress Legal Repository  openalex
# 274428    openalex::W79364033  Bepress Legal Repository  openalex
#
#                              doi                                   doi_url  \
# 274423  10.1017/cbo9780511921476  https://doi.org/10.1017/cbo9780511921476
# 274426                      <NA>                                      None
# 274427                      <NA>                                      None
# 274428                      <NA>                                      None
#
#                                          landing_page_url  \
# 274423  https://chicagounbound.uchicago.edu/cgi/viewco...
# 274426  https://chicagounbound.uchicago.edu/cgi/viewco...
# 274427  https://chicagounbound.uchicago.edu/cgi/viewco...
# 274428  https://chicagounbound.uchicago.edu/cgi/viewco...
#
#                                                     title      authors_flat  \
# 274423  Building global democracy?: civil society and ...  Jan Aart Scholte
# 274426  Building Global Democracy?: List of abbreviations  Jan Aart Scholte
# 274427  Building Global Democracy?: Editor's acknowled...  Jan Aart Scholte
# 274428   Building Global Democracy?: List of contributors  Jan Aart Scholte
#
#        publication_year         date_created relations_json version_label  \
# 274423           2011.0  2025-10-10T00:00:00           None          None
# 274426           2011.0  2025-10-10T00:00:00           None          None
# 274427           2011.0  2025-10-10T00:00:00           None          None
# 274428           2011.0  2025-10-10T00:00:00           None          None
#
#        is_version_of is_preprint_of has_preprint has_review  \
# 274423          None           None         None       None
# 274426          None           None         None       None
# 274427          None           None         None       None
# 274428          None           None         None       None
#
#        has_published_version published_version_ids_json version_of_ids_json  \
# 274423                  None                       None                None
# 274426                  None                       None                None
# 274427                  None                       None                None
# 274428                  None                       None                None
#
#        update_to_json raw_relationships_json records_hierarchy  \
# 274423           None                   None            parent
# 274426           None                   None            parent
# 274427           None                   None            parent
# 274428           None                   None            parent
#
#                                              landing_norm  \
# 274423  https://chicagounbound.uchicago.edu/cgi/viewco...
# 274426  https://chicagounbound.uchicago.edu/cgi/viewco...
# 274427  https://chicagounbound.uchicago.edu/cgi/viewco...
# 274428  https://chicagounbound.uchicago.edu/cgi/viewco...
#
#                         doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 274423  10.1017/cbo9780511921476             None          None      NaN
# 274426                      <na>             None          None      NaN
# 274427                      <na>             None          None      NaN
# 274428                      <na>             None          None      NaN
#
#        version_token_doi token_kind_doi  vnum_doi
# 274423              None           None       NaN
# 274426              None           None       NaN
# 274427              None           None       NaN
# 274428              None           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='Social Science Open Access Repository'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                      record_id                            server_name  \
# 5689205  openalex::W2948778104  Social Science Open Access Repository
# 5691773  openalex::W3198948865  Social Science Open Access Repository
# 5669183  openalex::W2748208804  Social Science Open Access Repository
# 5691957  openalex::W3208177612  Social Science Open Access Repository
#
#           backend                 doi                             doi_url  \
# 5689205  openalex  10.5167/uzh-160317  https://doi.org/10.5167/uzh-160317
# 5691773  openalex                <NA>                                None
# 5669183  openalex                <NA>                                None
# 5691957  openalex                <NA>                                None
#
#                                           landing_page_url  \
# 5689205  https://www.ssoar.info/ssoar/handle/document/6...
# 5691773  https://www.ssoar.info/ssoar/handle/document/6...
# 5669183  https://www.ssoar.info/ssoar/handle/document/6...
# 5691957  https://www.ssoar.info/ssoar/handle/document/6...
#
#                                                      title  \
# 5689205  Kommentar zu Meiser, T. et al. (2018). Positio...
# 5691773  Fachgruppe Gesundheitspsychologie: Methoden si...
# 5669183  Deutscher Alterssurvey (DEAS): Kurzbeschreibun...
# 5691957  Deutscher Alterssurvey (DEAS): Kurzbeschreibun...
#
#                                               authors_flat publication_year  \
# 5689205  Natalie Nagowski; Peter Kirsch; Andrea Kübler;...           2018.0
# 5691773  Petra Warschburger; Gudrun Sproesser; Daniela ...           2018.0
# 5669183                Heribert Engstler; Nicole Hameister           2019.0
# 5691957                Heribert Engstler; Nicole Hameister           2021.0
#
#                 date_created relations_json version_label is_version_of  \
# 5689205  2025-10-10T00:00:00           None          None          None
# 5691773  2025-10-10T00:00:00           None          None          None
# 5669183  2025-10-10T00:00:00           None          None          None
# 5691957  2025-10-10T00:00:00           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 5689205           None         None       None                  None
# 5691773           None         None       None                  None
# 5669183           None         None       None                  None
# 5691957           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 5689205                       None                None           None
# 5691773                       None                None           None
# 5669183                       None                None           None
# 5691957                       None                None           None
#
#         raw_relationships_json records_hierarchy  \
# 5689205                   None            parent
# 5691773                   None            parent
# 5669183                   None            parent
# 5691957                   None            parent
#
#                                               landing_norm  \
# 5689205  https://www.ssoar.info/ssoar/handle/document/6...
# 5691773  https://www.ssoar.info/ssoar/handle/document/6...
# 5669183  https://www.ssoar.info/ssoar/handle/document/6...
# 5691957  https://www.ssoar.info/ssoar/handle/document/6...
#
#                    doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 5689205  10.5167/uzh-160317             None          None      NaN
# 5691773                <na>             None          None      NaN
# 5669183                <na>             None          None      NaN
# 5691957                <na>             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 5689205              None           None       NaN
# 5691773              None           None       NaN
# 5669183              None           None       NaN
# 5691957              None           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='Advance'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                               record_id server_name   backend  \
# 16252  crossref::10.31124/advance.171863606.69452326/v1     Advance  crossref
# 16256  crossref::10.31124/advance.171897777.74136883/v1     Advance  crossref
#
#                                           doi  \
# 16252  10.31124/advance.171863606.69452326/v1
# 16256  10.31124/advance.171897777.74136883/v1
#
#                                                  doi_url  \
# 16252  https://doi.org/10.31124/advance.171863606.694...
# 16256  https://doi.org/10.31124/advance.171897777.741...
#
#                                         landing_page_url  \
# 16252  https://advance.sagepub.com/users/719316/artic...
# 16256  https://advance.sagepub.com/users/719316/artic...
#
#                                      title       authors_flat  \
# 16252  CLUSTER DEVELOPMENT ECONOMIC POLICY  Lomsadze, Tinatin
# 16256  CLUSTER DEVELOPMENT ECONOMIC POLICY  Lomsadze, Tinatin
#
#       publication_year date_created relations_json version_label  \
# 16252           2024.0   2024-06-17           None          None
# 16256           2024.0   2024-07-03           None          None
#
#       is_version_of is_preprint_of has_preprint has_review  \
# 16252
# 16256
#
#       has_published_version published_version_ids_json version_of_ids_json  \
# 16252                 false                       None                None
# 16256                 false                       None                None
#
#       update_to_json raw_relationships_json records_hierarchy  \
# 16252           None                   None            parent
# 16256           None                   None            parent
#
#                                             landing_norm  \
# 16252  https://advance.sagepub.com/users/719316/artic...
# 16256  https://advance.sagepub.com/users/719316/artic...
#
#                                      doi_norm version_token_lp token_kind_lp  \
# 16252  10.31124/advance.171863606.69452326/v1             None          None
# 16256  10.31124/advance.171897777.74136883/v1             None          None
#
#        vnum_lp version_token_doi    token_kind_doi  vnum_doi
# 16252      NaN               /v1  explicit_version       1.0
# 16256      NaN               /v1  explicit_version       1.0

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='Preprints.org'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                           record_id    server_name   backend  \
# 2271995  crossref::10.20944/preprints201904.0246.v1  Preprints.org  crossref
# 2272001  crossref::10.20944/preprints201904.0246.v2  Preprints.org  crossref
#
#                                       doi  \
# 2271995  10.20944/preprints201904.0246.v1
# 2272001  10.20944/preprints201904.0246.v2
#
#                                                   doi_url  \
# 2271995  https://doi.org/10.20944/preprints201904.0246.v1
# 2272001  https://doi.org/10.20944/preprints201904.0246.v2
#
#                                           landing_page_url  \
# 2271995  http://www.preprints.org/manuscript/201904.024...
# 2272001  http://www.preprints.org/manuscript/201904.024...
#
#                                                      title    authors_flat  \
# 2271995  Mathematical Models for Possible Roles of Oxyt...  Gottlieb, Mark
# 2272001  Mathematical Models for Possible Roles of Oxyt...  Gottlieb, Mark
#
#         publication_year date_created relations_json version_label  \
# 2271995           2019.0   2019-04-22           None          None
# 2272001           2019.0   2019-04-24           None          None
#
#         is_version_of is_preprint_of has_preprint has_review  \
# 2271995
# 2272001
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 2271995                 false                       None                None
# 2272001                 false                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 2271995           None                   None            parent
# 2272001           None                   None            parent
#
#                                               landing_norm  \
# 2271995  http://www.preprints.org/manuscript/201904.024...
# 2272001  http://www.preprints.org/manuscript/201904.024...
#
#                                  doi_norm version_token_lp     token_kind_lp  \
# 2271995  10.20944/preprints201904.0246.v1              /v1  explicit_version
# 2272001  10.20944/preprints201904.0246.v2              /v1  explicit_version
#
#          vnum_lp version_token_doi token_kind_doi  vnum_doi
# 2271995      1.0               NaN            NaN       NaN
# 2272001      1.0               NaN            NaN       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='JMIR Preprints'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                                 record_id     server_name   backend  \
# 1972015      crossref::10.2196/iproc.8586  JMIR Preprints  crossref
# 1972952  crossref::10.2196/preprints.8989  JMIR Preprints  crossref
#
#                             doi                                 doi_url  \
# 1972015      10.2196/iproc.8586      https://doi.org/10.2196/iproc.8586
# 1972952  10.2196/preprints.8989  https://doi.org/10.2196/preprints.8989
#
#                                 landing_page_url  \
# 1972015  http://preprints.jmir.org/preprint/8989
# 1972952  http://preprints.jmir.org/preprint/8989
#
#                                                      title  \
# 1972015  Barriers and facilitators to patient portal im...
# 1972952  Barriers and Facilitators Affecting Patient Po...
#
#                                           authors_flat publication_year  \
# 1972015  Kooij, Laura; Groen, Wim G; van Harten, Wim H           2017.0
# 1972952  Kooij, Laura; Groen, Wim G; van Harten, Wim H           2017.0
#
#         date_created                                     relations_json  \
# 1972015   2017-09-25                                               None
# 1972952   2017-09-26  {"is-preprint-of": [{"asserted-by": "subject",...
#
#         version_label is_version_of     is_preprint_of has_preprint  \
# 1972015          None
# 1972952          None                10.2196/jmir.8989
#
#         has_review has_published_version published_version_ids_json  \
# 1972015                            false                       None
# 1972952                             true                       None
#
#         version_of_ids_json update_to_json raw_relationships_json  \
# 1972015                None           None                   None
# 1972952                None           None                   None
#
#         records_hierarchy                             landing_norm  \
# 1972015            parent  http://preprints.jmir.org/preprint/8989
# 1972952            parent  http://preprints.jmir.org/preprint/8989
#
#                        doi_norm version_token_lp token_kind_lp  vnum_lp  \
# 1972015      10.2196/iproc.8586             None          None      NaN
# 1972952  10.2196/preprints.8989             None          None      NaN
#
#         version_token_doi token_kind_doi  vnum_doi
# 1972015              None           None       NaN
# 1972952              None           None       NaN

# %%
dupes_landing_page_url[dupes_landing_page_url['server_name']=='National Bureau of Economic Research'].sort_values(by='landing_page_url', ascending=False)
# Out:
#                      record_id                           server_name  \
# 2116112  openalex::W2567960855  National Bureau of Economic Research
# 2116118  openalex::W2913912915  National Bureau of Economic Research
#
#           backend   doi doi_url                  landing_page_url  \
# 2116112  openalex  <NA>    None  https://eric.ed.gov/?id=ED524978
# 2116118  openalex  <NA>    None  https://eric.ed.gov/?id=ED524978
#
#                                                      title     authors_flat  \
# 2116112  Creating "No Excuses" (Traditional) Public Sch...  Roland G. Fryer
# 2116118  Injecting Successful Charter School Strategies...  Roland G. Fryer
#
#         publication_year         date_created relations_json version_label  \
# 2116112           2011.0  2025-10-10T00:00:00           None          None
# 2116118           2011.0  2025-10-10T00:00:00           None          None
#
#         is_version_of is_preprint_of has_preprint has_review  \
# 2116112          None           None         None       None
# 2116118          None           None         None       None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 2116112                  None                       None                None
# 2116118                  None                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 2116112           None                   None            parent
# 2116118           None                   None            parent
#
#                              landing_norm doi_norm version_token_lp  \
# 2116112  https://eric.ed.gov/?id=ed524978     <na>             None
# 2116118  https://eric.ed.gov/?id=ed524978     <na>             None
#
#         token_kind_lp  vnum_lp version_token_doi token_kind_doi  vnum_doi
# 2116112          None      NaN              None           None       NaN
# 2116118          None      NaN              None           None       NaN

# %% [markdown]
# #### function

# %%
import pandas as pd
import re

# -----------------------------
# 0) Define primary servers
# -----------------------------
# PRIMARY_SERVERS = {
#     "arXiv",
#     "bioRxiv",
#     "medRxiv",
#     "SSRN",
#     "TechRxiv",
#     "Wellcome Open Research",
#     "AgriRxiv",
#     "EarthArXiv",
#     "Law Archive",
#     "SocArXiv",
#     "Thesis Commons",
#     "Research Square",
#     "Open Research Europe",
#     "Oroboros Instruments",
#     "ResearchGate",
#     "AgEcon Search",
#     "Zenodo",
#     "Open Science Framework",
#     "Humanities Commons CORE",
#     "CERN document server",
#     "eLife",
# }

PRIMARY_SERVERS = set(primary_servers) 
# -----------------------------
# 1) Normalize landing_page_url
# -----------------------------
url_norm = (
    df_mirror["landing_page_url"]
    .astype('string')
    .str.strip()
    .str.lower()
    .replace({"": pd.NA, "none": pd.NA, "nan": pd.NA, "null": pd.NA})
    # .replace({"": pd.NA, "none": pd.NA})
    # remove query strings and fragments
    .str.replace(r"[?#].*$", "", regex=True)
    # remove trailing slash
    .str.rstrip("/")
)


# -----------------------------
# 2) Flags
# -----------------------------
is_primary = df_mirror["server_name"].isin(PRIMARY_SERVERS)

# duplicated URL groups
is_dup = url_norm.notna() & url_norm.duplicated(keep=False)

# -----------------------------
# 3) Build URL → primary server mapping (FAST)
#    Only once, only for duplicated URLs
# -----------------------------
primary_by_url = (
    df_mirror.loc[is_primary & is_dup, ["server_name"]]
    .assign(url=url_norm[is_primary & is_dup])
    .dropna(subset=["url"])
    .groupby("url")["server_name"]
    .first()   # deterministic + fast
)

# -----------------------------
# 4) Label mirrors
#    - non-primary
#    - duplicated URL
#    - duplicated with at least one primary
# -----------------------------
mask_mirror = (
    is_dup
    & ~is_primary
    & url_norm.isin(primary_by_url.index)
)

df_mirror.loc[mask_mirror, "records_hierarchy"] = (
    "mirror (" + url_norm[mask_mirror].map(primary_by_url) + ")"
)

# -----------------------------
# 5) Sanity checks
# -----------------------------
print("Mirror rows set:", mask_mirror.sum())
print(df_mirror["records_hierarchy"].value_counts(dropna=False))
# Out:
# Mirror rows set: 2905
# records_hierarchy
# parent                              7950093
# review                               175443
# part_of                              149454
# version                              105977
# publish_version                        9351
# mirror (arXiv)                         8286
# mirror (AgEcon Search)                 6702
# child                                  2028
# mirror (ResearchGate)                  1633
# correction                              355
# comment                                 325
# mirror (Zenodo)                         297
# mirror (SSRN)                            36
# mirror (Open Science Framework)          31
# mirror (bioRxiv)                         29
# mirror (Humanities Commons CORE)         24
# others                                   12
# parent_duplicate                          3
# mirror (eLife)                            3
# mirror (CERN document server)             2
# mirror (Research Square)                  2
# mirror (AgriRxiv)                         1
# mirror (EarthArXiv)                       1
# mirror (SocArXiv)                         1
# mirror (Law Archive)                      1
# mirror (Thesis Commons)                   1
# mirror (Oroboros Instruments)             1
# mirror (TechRxiv)                         1
# mirror (medRxiv)                          1
# Name: count, dtype: int64

# %% [markdown]
# # Resolve duplicates across OSF + OSF communities using the OSF id (osf.io/<id>)

# %% [raw]
# Open Science Framework 	datacite 	10.17605/osf.io/86f5a 	https://doi.org/10.17605/osf.io/86f5a 	https://osf.io/preprints/socarxiv/86f5a/ 	""In the case of Africa in general, there is a... 	Wahutu, Siguru
#
# SocArXiv 	crossref 	10.31235/osf.io/86f5a 	https://doi.org/10.31235/osf.io/86f5a 	https://osf.io/86f5a 	""In the case of Africa in general, there is a... 	Wahutu, Siguru james

# %%
## Quick proof (diagnostic)

# %%
# import pandas as pd
# import re

# def extract_osf_id(x):
#     if pd.isna(x):
#         return pd.NA
#     m = re.search(r"osf\.io/([a-z0-9]+)", str(x).lower())
#     return m.group(1) if m else pd.NA

# tmp = df_mirror.copy()

# tmp["osf_id_from_doi"] = tmp["doi"].map(extract_osf_id) if "doi" in tmp.columns else pd.NA
# tmp["osf_id_from_lp"]  = tmp["landing_page_url"].map(extract_osf_id) if "landing_page_url" in tmp.columns else pd.NA

# tmp["osf_id"] = tmp["osf_id_from_doi"].fillna(tmp["osf_id_from_lp"])

# print("Rows with OSF id:", tmp["osf_id"].notna().sum())
# print("Duplicated OSF id rows:", tmp["osf_id"].notna().sum() - tmp["osf_id"].dropna().nunique())
# print(tmp.loc[tmp["osf_id"].notna(), "server_name"].value_counts().head(20))

# %%
## function: resolve OSF duplicates by OSF ID (works across different DOI prefixes)

# %%
# import pandas as pd
# import numpy as np
# import re

# def resolve_osf_duplicates_fast(
#     df: pd.DataFrame,
#     preferred_parent_servers: set,
#     prefer_backend: str = "crossref",
#     choose_parent: str = "oldest",           # "oldest" or "most_recent"
#     date_col: str = "date_created",          # if missing -> record_id fallback
#     overwrite_mode: str = "parent_only",     # "any" | "parent_only" | "unlabeled_only"
#     # columns
#     server_col: str = "server_name",
#     backend_col: str = "backend",
#     record_id_col: str = "record_id",
#     doi_col: str = "doi",
#     landing_col: str = "landing_page_url",
#     hierarchy_col: str = "records_hierarchy",
#     parent_id_col: str = "parent_record_id",
#     # perf knobs
#     coarse_filter: str = "osf.io/",          # cheap contains() filter before regex
#     min_group_size: int = 2
# ) -> pd.DataFrame:
#     """
#     Fast OSF duplicate resolver for huge frames (millions of rows).

#     Key idea:
#       - Avoid regex over the full dataframe.
#       - First, cheaply filter rows that likely contain 'osf.io/' in doi or landing_page_url.
#       - Only then extract OSF id and group to resolve duplicates.
#       - Finally, write results back only for touched rows.

#     Parent selection priority:
#       1) preferred community servers first (SocArXiv, PsyArXiv, etc.)
#       2) prefer backend == prefer_backend (crossref)
#       3) date (oldest/most_recent)
#       4) record_id numeric key (tie-break)
#     """

#     out = df.copy()

#     # Ensure output cols exist
#     if hierarchy_col not in out.columns:
#         out[hierarchy_col] = pd.NA
#     if parent_id_col not in out.columns:
#         out[parent_id_col] = pd.NA

#     # Eligibility mask (run only where you allow overwriting)
#     h = out[hierarchy_col]
#     if overwrite_mode == "any":
#         eligible = pd.Series(True, index=out.index)
#     elif overwrite_mode == "parent_only":
#         eligible = h.astype(str).str.strip().str.lower().eq("parent")
#     elif overwrite_mode == "unlabeled_only":
#         eligible = h.isna()
#     else:
#         raise ValueError("overwrite_mode must be: any | parent_only | unlabeled_only")

#     # ---- 1) Coarse filter: only rows likely to be OSF-related (very fast)
#     # Use fillna("") so .str.contains doesn't create object issues
#     m_osf = pd.Series(False, index=out.index)

#     if doi_col in out.columns:
#         m_osf |= out[doi_col].fillna("").astype(str).str.contains(coarse_filter, case=False, regex=False)
#     if landing_col in out.columns:
#         m_osf |= out[landing_col].fillna("").astype(str).str.contains(coarse_filter, case=False, regex=False)

#     m = eligible & m_osf
#     if not m.any():
#         return out

#     # Work on subset only
#     sub = out.loc[m, [server_col, backend_col, record_id_col]].copy()

#     # ---- 2) Extract OSF id from subset (regex only on ~235k rows, not 8M)
#     pat = re.compile(r"osf\.io/([a-z0-9]+)", re.I)

#     def extract_osf_id_series(s: pd.Series) -> pd.Series:
#         return s.fillna("").astype(str).str.lower().str.extract(pat, expand=False)

#     osf_id = pd.Series(pd.NA, index=sub.index, dtype="object")
#     if doi_col in out.columns:
#         osf_id = extract_osf_id_series(out.loc[m, doi_col])
#     if landing_col in out.columns:
#         osf_id = osf_id.fillna(extract_osf_id_series(out.loc[m, landing_col]))

#     # drop rows with no extracted id (coarse filter can include a few false positives)
#     sub["_osf_id"] = osf_id
#     sub = sub[sub["_osf_id"].notna()].copy()
#     if sub.empty:
#         return out

#     # ---- 3) Prepare sort keys on subset
#     sub["_is_pref_server"] = sub[server_col].isin(preferred_parent_servers)

#     # backend preference (vectorized)
#     sub["_is_pref_backend"] = (
#         sub[backend_col].fillna("").astype(str).str.lower().eq(str(prefer_backend).lower())
#     )

#     # date key
#     if date_col in out.columns:
#         sub["_dt"] = pd.to_datetime(out.loc[sub.index, date_col], errors="coerce")
#     else:
#         sub["_dt"] = pd.NaT

#     # record_id numeric key (extract digits)
#     rid_digits = sub[record_id_col].astype(str).str.extract(r"(\d+)")[0]
#     sub["_rid_key"] = pd.to_numeric(rid_digits, errors="coerce")

#     if choose_parent not in {"oldest", "most_recent"}:
#         raise ValueError("choose_parent must be: oldest | most_recent")
#     date_asc = (choose_parent == "oldest")

#     # ---- 4) Only group IDs that actually have duplicates (saves time)
#     # value_counts on 235k rows is cheap
#     dup_ids = sub["_osf_id"].value_counts()
#     dup_ids = dup_ids[dup_ids >= min_group_size].index
#     sub = sub[sub["_osf_id"].isin(dup_ids)].copy()
#     if sub.empty:
#         return out

#     # ---- 5) Resolve per OSF id
#     # Sorting once, then picking first per group is faster than looping all groups with Python
#     sub_sorted = sub.sort_values(
#         by=["_osf_id", "_is_pref_server", "_is_pref_backend", "_dt", "_rid_key"],
#         ascending=[True, False, False, date_asc, True],
#         na_position="last"
#     )

#     # Parent idx per osf_id = first row after sorting
#     parent_idx_by_id = sub_sorted.groupby("_osf_id", sort=False).head(1)
#     parent_map_rid = parent_idx_by_id.set_index("_osf_id")[record_id_col]
#     parent_map_srv = parent_idx_by_id.set_index("_osf_id")[server_col]

#     # For all rows in sub_sorted, map parent rid & parent server
#     sub_sorted["_parent_rid"] = sub_sorted["_osf_id"].map(parent_map_rid)
#     sub_sorted["_parent_srv"] = sub_sorted["_osf_id"].map(parent_map_srv)

#     # Identify which rows are parent vs child
#     is_parent_row = sub_sorted[record_id_col].eq(sub_sorted["_parent_rid"])

#     # Write back to OUT
#     parent_rows = sub_sorted.index[is_parent_row]
#     child_rows  = sub_sorted.index[~is_parent_row]

#     out.loc[parent_rows, hierarchy_col] = "parent"
#     out.loc[parent_rows, parent_id_col] = pd.NA

#     out.loc[child_rows, hierarchy_col] = "mirror (" + sub_sorted.loc[child_rows, "_parent_srv"].astype(str) + ")"
#     out.loc[child_rows, parent_id_col] = sub_sorted.loc[child_rows, "_parent_rid"].values

#     return out

# %%
# PREFERRED_OSF_PARENT = {
#     "SocArXiv","Law Archive","PsyArXiv","EdArXiv","EarthArXiv","Thesis Commons",
#     "LIS Scholarship Archive","SportRxiv","INA-Rxiv","Arabixiv","engrXiv","MetaArXiv",
#     "MindRxiv","MarXiv","AgriRxiv","NutriXiv","ECSarXiv","FocUS Archive","Frenxiv",
#     "EcoEvoRxiv","IndiaRxiv","PaleorXiv","AfricArXiv","BioHackrXiv","MediArXiv"
# }

# df_mirror = resolve_osf_duplicates_fast(
#     df=df_mirror,
#     preferred_parent_servers=PREFERRED_OSF_PARENT,
#     prefer_backend="crossref",
#     choose_parent="oldest",
#     date_col="date_created",
#     overwrite_mode="parent_only",
# )

# print(df_mirror["records_hierarchy"].value_counts(dropna=False).head(30))

# %% [markdown]
# # save

# %%
records_hierarchy_df = df_mirror[['record_id','server_name','records_hierarchy']]
records_hierarchy_df
# Out:
#                                    record_id  \
# 429739   crossref::10.1002/essoar.10500000.1
# 429742   crossref::10.1002/essoar.10500002.1
# 429740   crossref::10.1002/essoar.10500004.1
# 429741   crossref::10.1002/essoar.10500007.1
# 429746   crossref::10.1002/essoar.10500009.1
# ...                                      ...
# 2806404                 openalex::W999921877
# 1016201                 openalex::W999947037
# 2713111                 openalex::W999974616
# 1015101                 openalex::W999989114
# 2893587                 openalex::W999989584
#
#                                   server_name records_hierarchy
# 429739   Earth and Space Science Open Archive            parent
# 429742   Earth and Space Science Open Archive            parent
# 429740   Earth and Space Science Open Archive            parent
# 429741   Earth and Space Science Open Archive            parent
# 429746   Earth and Space Science Open Archive            parent
# ...                                       ...               ...
# 2806404   RePEc: Research Papers in Economics            parent
# 1016201                                   HAL            parent
# 2713111   RePEc: Research Papers in Economics            parent
# 1015101                                   HAL            parent
# 2893587   RePEc: Research Papers in Economics            parent
#
# [8410094 rows x 3 columns]

# %%
records_hierarchy_df.to_csv("outputs/records_hierarchy_df.csv", index=False)
records_hierarchy_df.to_pickle("outputs/records_hierarchy_df.pkl")

# %%
ccc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[185], line 1
# ----> 1 ccc
#
# NameError: name 'ccc' is not defined

# %%
some paper have same title and author infos, but different may have different doi or landing page url in the same servers. 
    we need to clean title first or decide that the title have to be equal at 90% per example to overcome some little typo difference
    could it be possibe to write a code that will get one version of rows, 
        the version choose will be label parent and others childs (duplicate),
        we need also to work server by server and a way for each server to decide if we get the most recent or the old on as parent. 



how to have a function, that, we can add as input, server, or list of server, the columns one or multiples columns we need to use to find duplicates, wich records id to choose, the most recent or old one by sorting

# %% [markdown]
# # VeriXiv and Gate

# %%
data[data['server_name']=='VeriXiv']
# Out:
#                                  record_id server_name   backend  \
# 5731134  crossref::10.12688/verixiv.1003.1     VeriXiv  crossref
# 5730998  crossref::10.12688/verixiv.1007.1     VeriXiv  crossref
# 5730985  crossref::10.12688/verixiv.1008.1     VeriXiv  crossref
# 5730991  crossref::10.12688/verixiv.1022.1     VeriXiv  crossref
# 5731326  crossref::10.12688/verixiv.1025.1     VeriXiv  crossref
# ...                                    ...         ...       ...
# 5730990   crossref::10.12688/verixiv.982.1     VeriXiv  crossref
# 5730986   crossref::10.12688/verixiv.986.1     VeriXiv  crossref
# 5731118   crossref::10.12688/verixiv.989.1     VeriXiv  crossref
# 5731107   crossref::10.12688/verixiv.994.1     VeriXiv  crossref
# 5730993   crossref::10.12688/verixiv.999.1     VeriXiv  crossref
#
#                              doi                                  doi_url  \
# 5731134  10.12688/verixiv.1003.1  https://doi.org/10.12688/verixiv.1003.1
# 5730998  10.12688/verixiv.1007.1  https://doi.org/10.12688/verixiv.1007.1
# 5730985  10.12688/verixiv.1008.1  https://doi.org/10.12688/verixiv.1008.1
# 5730991  10.12688/verixiv.1022.1  https://doi.org/10.12688/verixiv.1022.1
# 5731326  10.12688/verixiv.1025.1  https://doi.org/10.12688/verixiv.1025.1
# ...                          ...                                      ...
# 5730990   10.12688/verixiv.982.1   https://doi.org/10.12688/verixiv.982.1
# 5730986   10.12688/verixiv.986.1   https://doi.org/10.12688/verixiv.986.1
# 5731118   10.12688/verixiv.989.1   https://doi.org/10.12688/verixiv.989.1
# 5731107   10.12688/verixiv.994.1   https://doi.org/10.12688/verixiv.994.1
# 5730993   10.12688/verixiv.999.1   https://doi.org/10.12688/verixiv.999.1
#
#                               landing_page_url  \
# 5731134   https://verixiv.org/articles/2-72/v1
# 5730998  https://verixiv.org/articles/2-106/v1
# 5730985   https://verixiv.org/articles/2-86/v1
# 5730991   https://verixiv.org/articles/2-97/v1
# 5731326  https://verixiv.org/articles/2-189/v1
# ...                                        ...
# 5730990   https://verixiv.org/articles/2-96/v1
# 5730986   https://verixiv.org/articles/2-92/v1
# 5731118   https://verixiv.org/articles/2-99/v1
# 5731107  https://verixiv.org/articles/2-136/v1
# 5730993  https://verixiv.org/articles/2-103/v1
#
#                                                      title  \
# 5731134  Estimation of Seasonal, Additive and Non-addit...
# 5730998  Human-Centered Design in Public Health: A Case...
# 5730985  What it takes to sustain: A realist evaluation...
# 5730991  Exploring the role of small and medium food en...
# 5731326  Small and medium-sized type of food business: ...
# ...                                                    ...
# 5730990  Comparative technical and operational assessme...
# 5730986  Evaluation of private sector engagement for TB...
# 5731118  traveltime: an R package to calculate travel t...
# 5731107  Mass Balance, Pharmacokinetics, Metabolism and...
# 5730993  Effects of urban sanitation upgrades on enteri...
#
#                                               authors_flat publication_year  \
# 5731134  Akech, Violet; Bayo, Stanley; Bengtsson, Theré...           2025.0
# 5730998  Olarewaju, Olajumoke; Poddar, Manvi; Stephens,...           2025.0
# 5730985  Elaraby, Sarah; Yahner, Melanie; Krishna Sarke...           2025.0
# 5730991  Fitawek, Wegayehu; Karuaihe, Selma Tuemumunu; ...           2025.0
# 5731326  Owusu-Sekyere, Enoch; Karuaihe, Selma Tuemumun...           2025.0
# ...                                                    ...              ...
# 5730990  Zhu, Changcheng; Roa, Nerie; Neathery, Estelle...           2025.0
# 5730986  Shukla, Anupam; Borhade, Priyanka; Dholakia, Y...           2025.0
# 5731118  Ryan, Gerard E.; Tierney, Nicholas; Golding, N...           2025.0
# 5731107  Gillon, Jean-Yves; Simon, François; Sidhu, Sha...           2025.0
# 5730993  Kowalsky, Erin; Monteiro, Vanessa; Holcomb, Da...           2025.0
#
#         date_created                                     relations_json  \
# 5731134   2025-04-23  {"is-preprint-of": [{"asserted-by": "subject",...
# 5730998   2025-05-27                                               None
# 5730985   2025-05-06                                               None
# 5730991   2025-05-20                                               None
# 5731326   2025-07-21                                               None
# ...              ...                                                ...
# 5730990   2025-05-20                                               None
# 5730986   2025-05-12                                               None
# 5731118   2025-05-21  {"has-review": [{"asserted-by": "subject", "id...
# 5731107   2025-08-03                                               None
# 5730993   2025-05-23                                               None
#
#         version_label is_version_of              is_preprint_of has_preprint  \
# 5731134          None                10.1007/s10681-025-03598-1
# 5730998          None
# 5730985          None
# 5730991          None
# 5731326          None
# ...               ...           ...                         ...          ...
# 5730990          None
# 5730986          None
# 5731118          None
# 5731107          None
# 5730993          None
#
#                                                 has_review  \
# 5731134
# 5730998
# 5730985
# 5730991
# 5731326
# ...                                                    ...
# 5730990
# 5730986
# 5731118  10.21956/verixiv.1007.r1274;10.21956/verixiv.1...
# 5731107
# 5730993
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 5731134                  true                       None                None
# 5730998                 false                       None                None
# 5730985                 false                       None                None
# 5730991                 false                       None                None
# 5731326                 false                       None                None
# ...                       ...                        ...                 ...
# 5730990                 false                       None                None
# 5730986                 false                       None                None
# 5731118                 false                       None                None
# 5731107                 false                       None                None
# 5730993                 false                       None                None
#
#         update_to_json raw_relationships_json
# 5731134           None                   None
# 5730998           None                   None
# 5730985           None                   None
# 5730991           None                   None
# 5731326           None                   None
# ...                ...                    ...
# 5730990           None                   None
# 5730986           None                   None
# 5731118           None                   None
# 5731107           None                   None
# 5730993           None                   None
#
# [504 rows x 21 columns]

# %%
gate_data = data[data['server_name']=='Gates Open Research']
gate_data
# Out:
#                                       record_id          server_name  \
# 590205          crossref::10.12688/gatesopenres  Gates Open Research
# 589471  crossref::10.12688/gatesopenres.12749.1  Gates Open Research
# 589358  crossref::10.12688/gatesopenres.12749.2  Gates Open Research
# 589685  crossref::10.12688/gatesopenres.12750.1  Gates Open Research
# 589470  crossref::10.12688/gatesopenres.12751.1  Gates Open Research
# ...                                         ...                  ...
# 590198  crossref::10.12688/gatesopenres.16368.1  Gates Open Research
# 590200  crossref::10.12688/gatesopenres.16369.1  Gates Open Research
# 590193  crossref::10.12688/gatesopenres.16370.1  Gates Open Research
# 590197  crossref::10.12688/gatesopenres.16371.1  Gates Open Research
# 590196  crossref::10.12688/gatesopenres.16372.1  Gates Open Research
#
#          backend                            doi  \
# 590205  crossref          10.12688/gatesopenres
# 589471  crossref  10.12688/gatesopenres.12749.1
# 589358  crossref  10.12688/gatesopenres.12749.2
# 589685  crossref  10.12688/gatesopenres.12750.1
# 589470  crossref  10.12688/gatesopenres.12751.1
# ...          ...                            ...
# 590198  crossref  10.12688/gatesopenres.16368.1
# 590200  crossref  10.12688/gatesopenres.16369.1
# 590193  crossref  10.12688/gatesopenres.16370.1
# 590197  crossref  10.12688/gatesopenres.16371.1
# 590196  crossref  10.12688/gatesopenres.16372.1
#
#                                               doi_url  \
# 590205          https://doi.org/10.12688/gatesopenres
# 589471  https://doi.org/10.12688/gatesopenres.12749.1
# 589358  https://doi.org/10.12688/gatesopenres.12749.2
# 589685  https://doi.org/10.12688/gatesopenres.12750.1
# 589470  https://doi.org/10.12688/gatesopenres.12751.1
# ...                                               ...
# 590198  https://doi.org/10.12688/gatesopenres.16368.1
# 590200  https://doi.org/10.12688/gatesopenres.16369.1
# 590193  https://doi.org/10.12688/gatesopenres.16370.1
# 590197  https://doi.org/10.12688/gatesopenres.16371.1
# 590196  https://doi.org/10.12688/gatesopenres.16372.1
#
#                                        landing_page_url  \
# 590205                 http://www.gatesopenresearch.org
# 589471    https://gatesopenresearch.org/articles/1-7/v1
# 589358    https://gatesopenresearch.org/articles/1-7/v2
# 589685    https://gatesopenresearch.org/articles/1-9/v1
# 589470    https://gatesopenresearch.org/articles/1-8/v1
# ...                                                 ...
# 590198   https://gatesopenresearch.org/articles/9-92/v1
# 590200   https://gatesopenresearch.org/articles/9-91/v1
# 590193  https://gatesopenresearch.org/articles/9-101/v1
# 590197  https://gatesopenresearch.org/articles/9-100/v1
# 590196  https://gatesopenresearch.org/articles/9-103/v1
#
#                                                     title  \
# 590205                                Gates Open Research
# 589471  A superhydrophobic cone to facilitate the xeno...
# 589358  A superhydrophobic cone to facilitate the xeno...
# 589685  Using biomarkers to predict TB treatment durat...
# 589470  Point-of-contact Interactive Record Linkage (P...
# ...                                                   ...
# 590198  Addressing Research Readiness Challenges in Af...
# 590200  Evaluation of an ultra-portable pocket-sized d...
# 590193  CYP2D6 Pharmacogenetics in Nigerian Sickle Cel...
# 590197  Potential for Family Planning Program Sustaina...
# 590196  Discoverability of African Journals by Google ...
#
#                                              authors_flat publication_year  \
# 590205                                               <NA>             None
# 589471  Cook, Darren A.N.; Pilotte, Nils; Minetti, Cor...           2017.0
# 589358  Cook, Darren A.N.; Pilotte, Nils; Minetti, Cor...           2018.0
# 589685  Chen, Ray Y.; Via, Laura E.; Dodd, Lori E.; Wa...           2017.0
# 589470  Rentsch, Christopher T.; Kabudula, Chodziwadzi...           2017.0
# ...                                                   ...              ...
# 590198  Amboka, Patrick; Kariuki, H; Orobaton, Nosa; N...           2025.0
# 590200  Fuentes, Segundo; Ogero, Kwame; Perez, Ana; Kr...           2025.0
# 590193  Adeagbo, Babatunde; Olarewaju, Olusola; Orherh...           2025.0
# 590197  Hardee, Karen; Rosenberg, Rebecca; Zosa-Ferani...           2025.0
# 590196  Amboka, Patrick; Kirimi Sindi, Julius; Wamukoy...           2025.0
#
#        date_created                                     relations_json  \
# 590205   2017-11-06                                               None
# 589471   2017-11-06  {"has-review": [{"asserted-by": "subject", "id...
# 589358   2018-04-27                                               None
# 589685   2017-11-06  {"has-review": [{"asserted-by": "subject", "id...
# 589470   2017-11-06  {"has-review": [{"asserted-by": "subject", "id...
# ...             ...                                                ...
# 590198   2025-11-21  {"has-preprint": [{"asserted-by": "subject", "...
# 590200   2025-11-21  {"has-preprint": [{"asserted-by": "subject", "...
# 590193   2025-11-10  {"has-preprint": [{"asserted-by": "subject", "...
# 590197   2025-11-21  {"has-preprint": [{"asserted-by": "subject", "...
# 590196   2025-11-21  {"has-preprint": [{"asserted-by": "subject", "...
#
#        version_label is_version_of is_preprint_of             has_preprint  \
# 590205          None
# 589471          None
# 589358   New version
# 589685          None
# 589470          None
# ...              ...           ...            ...                      ...
# 590198          None                                10.12688/verixiv.558.3
# 590200          None                               10.12688/verixiv.1161.1
# 590193          None                               10.12688/verixiv.1323.2
# 590197          None                                10.12688/verixiv.888.2
# 590196          None                                10.12688/verixiv.244.3
#
#                                                has_review  \
# 590205
# 589471  10.21956/gatesopenres.13809.r26053;10.21956/ga...
# 589358
# 589685  10.21956/gatesopenres.13810.r26114;10.21956/ga...
# 589470  10.21956/gatesopenres.13811.r26151;10.21956/ga...
# ...                                                   ...
# 590198
# 590200
# 590193
# 590197
# 590196
#
#        has_published_version published_version_ids_json version_of_ids_json  \
# 590205                 false                       None                None
# 589471                 false                       None                None
# 589358                 false                       None                None
# 589685                 false                       None                None
# 589470                 false                       None                None
# ...                      ...                        ...                 ...
# 590198                 false                       None                None
# 590200                 false                       None                None
# 590193                 false                       None                None
# 590197                 false                       None                None
# 590196                 false                       None                None
#
#                                            update_to_json  \
# 590205                                               None
# 589471                                               None
# 589358  [{"DOI": "10.12688/gatesopenres.12749.1", "lab...
# 589685                                               None
# 589470                                               None
# ...                                                   ...
# 590198                                               None
# 590200                                               None
# 590193                                               None
# 590197                                               None
# 590196                                               None
#
#        raw_relationships_json
# 590205                   None
# 589471                   None
# 589358                   None
# 589685                   None
# 589470                   None
# ...                       ...
# 590198                   None
# 590200                   None
# 590193                   None
# 590197                   None
# 590196                   None
#
# [863 rows x 21 columns]

# %%
pattern = "10.12688/verixiv.244"

mask = data['doi'].str.contains(pattern, regex=False, na=False)
result = data[mask]
result
# Out:
#                                  record_id server_name   backend  \
# 5730930   crossref::10.12688/verixiv.244.1     VeriXiv  crossref
# 5731336   crossref::10.12688/verixiv.244.2     VeriXiv  crossref
# 5731262   crossref::10.12688/verixiv.244.3     VeriXiv  crossref
# 5731377  crossref::10.12688/verixiv.2443.1     VeriXiv  crossref
#
#                              doi                                  doi_url  \
# 5730930   10.12688/verixiv.244.1   https://doi.org/10.12688/verixiv.244.1
# 5731336   10.12688/verixiv.244.2   https://doi.org/10.12688/verixiv.244.2
# 5731262   10.12688/verixiv.244.3   https://doi.org/10.12688/verixiv.244.3
# 5731377  10.12688/verixiv.2443.1  https://doi.org/10.12688/verixiv.2443.1
#
#                               landing_page_url  \
# 5730930   https://verixiv.org/articles/1-17/v1
# 5731336   https://verixiv.org/articles/1-17/v2
# 5731262   https://verixiv.org/articles/1-17/v3
# 5731377  https://verixiv.org/articles/2-412/v1
#
#                                                      title  \
# 5730930  Discoverability of African Journals by Google ...
# 5731336  Discoverability of African Journals by Google ...
# 5731262  Discoverability of African Journals by Google ...
# 5731377  DHIS2 Integrated App usability and Challenges ...
#
#                                               authors_flat publication_year  \
# 5730930  Amboka, Patrick; Kirimi Sindi, Julius; Wamukoy...           2024.0
# 5731336  Amboka, Patrick; Kirimi Sindi, Julius; Wamukoy...           2025.0
# 5731262  Amboka, Patrick; Kirimi Sindi, Julius; Wamukoy...           2025.0
# 5731377  Mesfin, Araya; Getachew, Redet; Biruk, Ephrem;...           2025.0
#
#         date_created                                     relations_json  \
# 5730930   2024-11-01  {"has-review": [{"asserted-by": "subject", "id...
# 5731336   2025-08-05  {"has-version": [{"asserted-by": "subject", "i...
# 5731262   2025-11-04  {"has-review": [{"asserted-by": "subject", "id...
# 5731377   2025-12-09                                               None
#
#         version_label                                  is_version_of  \
# 5730930          None
# 5731336          None                         10.12688/verixiv.244.1
# 5731262          None  10.12688/verixiv.244.2;10.12688/verixiv.244.1
# 5731377          None
#
#         is_preprint_of has_preprint  \
# 5730930
# 5731336
# 5731262
# 5731377
#
#                                                 has_review  \
# 5730930                          10.21956/verixiv.248.r101
# 5731336
# 5731262  10.21956/verixiv.1894.r3555;10.21956/verixiv.1...
# 5731377
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 5730930                 false                       None                None
# 5731336                 false                       None                None
# 5731262                 false                       None                None
# 5731377                 false                       None                None
#
#         update_to_json raw_relationships_json
# 5730930           None                   None
# 5731336           None                   None
# 5731262           None                   None
# 5731377           None                   None

# %%
pattern = "10.12688/gatesopenres.16372"

mask = data['doi'].str.contains(pattern, regex=False, na=False)
result = data[mask]
result
# Out:
#                                       record_id          server_name  \
# 590196  crossref::10.12688/gatesopenres.16372.1  Gates Open Research
#
#          backend                            doi  \
# 590196  crossref  10.12688/gatesopenres.16372.1
#
#                                               doi_url  \
# 590196  https://doi.org/10.12688/gatesopenres.16372.1
#
#                                        landing_page_url  \
# 590196  https://gatesopenresearch.org/articles/9-103/v1
#
#                                                     title  \
# 590196  Discoverability of African Journals by Google ...
#
#                                              authors_flat publication_year  \
# 590196  Amboka, Patrick; Kirimi Sindi, Julius; Wamukoy...           2025.0
#
#        date_created                                     relations_json  \
# 590196   2025-11-21  {"has-preprint": [{"asserted-by": "subject", "...
#
#        version_label is_version_of is_preprint_of            has_preprint  \
# 590196          None                               10.12688/verixiv.244.3
#
#        has_review has_published_version published_version_ids_json  \
# 590196                            false                       None
#
#        version_of_ids_json update_to_json raw_relationships_json
# 590196                None           None                   None

# %%
result['relations_json'][590196]

# %%
pattern = "10.12688/verixiv.244.3"

mask = data['doi'].str.contains(pattern, regex=False, na=False)
result = data[mask]
result

# %%
gate_data

# %%
pattern = "10.12688/verixiv."

mask = gate_data['relations_json'].str.contains(pattern, regex=False, na=False)
result = gate_data[mask]
result

# %%
result.shape

# %%
pattern = "has-preprint"

mask = gate_data['relations_json'].str.contains(pattern, regex=False, na=False)
result = gate_data[mask]
print(result.shape)
result

# %%
gate_data2025 = gate_data[gate_data['publication_year'] == '2025.0']
print(gate_data2025.shape)
gate_data2025

# %%
gate_data2025first = gate_data2025[gate_data2025['is_version_of']=='']
print(gate_data2025first.shape)
gate_data2025first

# %%
pattern = "has-preprint"

mask = ~gate_data2025['relations_json'].str.contains(pattern, regex=False, na=False)
result = gate_data2025[mask]
print(result.shape)
result

# %%
pattern = "10.12688/gatesopenres.15431.1"

mask = data['doi'].str.contains(pattern, regex=False, na=False)
result = data[mask]
print(result.shape)
result

# %% [markdown]
# ## Keldysh Institute Preprints

# %%
data[data['server_name']=='Keldysh Institute Preprints']
