# %%
import duckdb
import pandas as pd

print("DuckDB:", duckdb.__version__)
print("Pandas:", pd.__version__)
# Out:
# DuckDB: 1.4.3
# Pandas: 2.3.3

# %%
import duckdb
from pathlib import Path

# 1) Always create ONE connection and keep using it
con = duckdb.connect()  # in-memory is fine for analysis

# 2) Build paths robustly from the notebook folder
ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

BASE = ROOT / "data" / "all_backends"

# Your structure is: all_crossref/backend=crossref/data_0.parquet
crossref_glob = (BASE / "all_crossref" / "*" / "*.parquet").as_posix()
datacite_glob = (BASE / "all_datacite" / "*" / "*.parquet").as_posix()
openalex_glob = (BASE / "all_openalex" / "*" / "*.parquet").as_posix()

print("BASE:", BASE)
print("crossref_glob:", crossref_glob)
print("datacite_glob:", datacite_glob)
print("openalex_glob:", openalex_glob)
# Out:
# BASE: /mnt/c/SCHOLCOMMLAB/APPs/preprint-harvester/data/all_backends
# crossref_glob: /mnt/c/SCHOLCOMMLAB/APPs/preprint-harvester/data/all_backends/all_crossref/*/*.parquet
# datacite_glob: /mnt/c/SCHOLCOMMLAB/APPs/preprint-harvester/data/all_backends/all_datacite/*/*.parquet
# openalex_glob: /mnt/c/SCHOLCOMMLAB/APPs/preprint-harvester/data/all_backends/all_openalex/*/*.parquet

# %%
con.execute(f"""
CREATE OR REPLACE VIEW crossref AS
SELECT * FROM read_parquet('{crossref_glob}', hive_partitioning=true, union_by_name=true);
""")

con.execute(f"""
CREATE OR REPLACE VIEW datacite AS
SELECT * FROM read_parquet('{datacite_glob}', hive_partitioning=true, union_by_name=true);
""")

con.execute(f"""
CREATE OR REPLACE VIEW openalex AS
SELECT * FROM read_parquet('{openalex_glob}', hive_partitioning=true, union_by_name=true);
""")

# %%
con.execute("SHOW TABLES").fetchall()
# Out:
# [('crossref',), ('datacite',), ('openalex',)]

# %%
con.execute("SELECT COUNT(*) FROM crossref").fetchone()
# Out:
# (3612833,)

# %%
con.execute("""
CREATE OR REPLACE VIEW all_rows AS
SELECT * FROM crossref
UNION ALL
SELECT * FROM datacite
UNION ALL
SELECT * FROM openalex;
""")

con.execute("""
CREATE OR REPLACE VIEW all_dedup AS
SELECT * EXCLUDE(rn)
FROM (
  SELECT
    *,
    row_number() OVER (
      PARTITION BY record_id
      ORDER BY COALESCE(date_updated, date_indexed, date_deposited, date_created) DESC NULLS LAST
    ) AS rn
  FROM all_rows
)
WHERE rn = 1;
""")

# %%
total_raw   = con.execute("SELECT COUNT(*) FROM all_rows").fetchone()[0]
total_dedup = con.execute("SELECT COUNT(*) FROM all_dedup").fetchone()[0]
(total_raw, total_dedup, total_raw - total_dedup)
# Out:
# (9502846, 8426047, 1076799)

# %%
con.execute("""
SELECT server_name, COUNT(*) AS n
FROM all_dedup
GROUP BY 1
ORDER BY n DESC;
""").df()
# Out:
#                              server_name        n
# 0                                  arXiv  2920797
# 1                                   SSRN  1258958
# 2                                    HAL  1056424
# 3                        Research Square   450818
# 4    RePEc: Research Papers in Economics   389398
# ..                                   ...      ...
# 107         Prepublicaciones OpenCiencia        8
# 108                            Therapoid        7
# 109                       NewAddictionsX        7
# 110             Bepress Legal Repository        6
# 111                           searchRxiv        2
#
# [112 rows x 2 columns]

# %%
con.execute("SHOW TABLES").fetchall()
# Out:
# [('all_dedup',), ('all_rows',), ('crossref',), ('datacite',), ('openalex',)]

# %%
con.execute("""
SELECT column_name
FROM information_schema.columns
WHERE table_name = 'all_dedup'
  AND (
    lower(column_name) LIKE '%url%'
    OR lower(column_name) LIKE '%landing%'
    OR lower(column_name) LIKE '%primary%'
  )
ORDER BY 1;
""").df()
# Out:
#         column_name
# 0           doi_url
# 1  landing_page_url

# %%
con.execute(r"""
CREATE OR REPLACE TABLE version_detection AS
WITH base AS (
  SELECT
    backend,
    server_name,
    record_id,

    /* ---- FORCE ALL STRINGS ---- */
    lower(coalesce(CAST(doi AS VARCHAR), ''))               AS doi_l,
    lower(coalesce(CAST(landing_page_url AS VARCHAR), '')) AS landing_l,
    lower(coalesce(CAST(version_label AS VARCHAR), ''))    AS vlabel_l,

    /* ---- FORCE BOOLEAN SAFELY ---- */
    CASE
      WHEN CAST(is_version_of AS VARCHAR) IN ('true','1','t','yes') THEN TRUE
      ELSE FALSE
    END AS is_version_of

  FROM all_dedup
),

flags AS (
  SELECT
    backend,
    server_name,
    record_id,

    /* DOI version patterns */
    regexp_matches(doi_l, '[-._]v[0-9]{1,3}([^0-9]|$)') AS doi_sep_vN,
    regexp_matches(doi_l, '[-._][0-9]{1,3}([^0-9]|$)')  AS doi_sep_N,

    /* URL version patterns */
    regexp_matches(landing_l, '([?&](version|ver|v)=([0-9]{1,3}))') AS landing_param_version,
    regexp_matches(landing_l, '(/v[0-9]{1,3})(/|$)')                AS landing_path_vN,

    /* Metadata signal */
    (vlabel_l <> '' AND vlabel_l <> 'null') AS version_label_present,

    /* Relationship signal */
    is_version_of AS metadata_is_version_of
  FROM base
),

scored AS (
  SELECT
    *,
    (CASE WHEN doi_sep_vN THEN 1 ELSE 0 END
     + CASE WHEN doi_sep_N THEN 1 ELSE 0 END
     + CASE WHEN landing_param_version THEN 1 ELSE 0 END
     + CASE WHEN landing_path_vN THEN 1 ELSE 0 END
     + CASE WHEN version_label_present THEN 1 ELSE 0 END
     + CASE WHEN metadata_is_version_of THEN 1 ELSE 0 END
    ) AS n_signals
  FROM flags
)

SELECT
  backend,
  server_name,
  record_id,

  CASE
    WHEN n_signals = 0 THEN 'no_signal'
    WHEN n_signals > 1 THEN 'multi_signal'
    WHEN doi_sep_vN THEN 'doi_sep_vN'
    WHEN doi_sep_N  THEN 'doi_sep_N'
    WHEN landing_param_version THEN 'landing_param_version'
    WHEN landing_path_vN THEN 'landing_path_vN'
    WHEN version_label_present THEN 'metadata_version_label'
    WHEN metadata_is_version_of THEN 'metadata_is_version_of'
    ELSE 'unknown'
  END AS version_signal_type,

  /* audit columns */
  n_signals,
  doi_sep_vN,
  doi_sep_N,
  landing_param_version,
  landing_path_vN,
  version_label_present,
  metadata_is_version_of

FROM scored;
""")

# %%
con.execute("""
SELECT version_signal_type, COUNT(*) AS n
FROM version_detection
GROUP BY 1
ORDER BY n DESC;
""").df()
# Out:
#       version_signal_type        n
# 0               no_signal  3991578
# 1  metadata_version_label  2959535
# 2               doi_sep_N   792447
# 3            multi_signal   607660
# 4              doi_sep_vN    74445
# 5         landing_path_vN      382

# %%
# Create a clean version-detection table
con.execute(r"""
CREATE OR REPLACE TABLE version_detection AS
WITH base AS (
  SELECT
    backend,
    server_name,
    record_id,

    -- normalize strings safely across drifted schemas
    lower(coalesce(CAST(doi AS VARCHAR), '')) AS doi_l,
    lower(coalesce(CAST(landing_page_url AS VARCHAR), '')) AS landing_l,
    lower(coalesce(CAST(version_label AS VARCHAR), '')) AS vlabel_l,

    -- normalize boolean safely
    CASE
      WHEN CAST(is_version_of AS VARCHAR) IN ('true','1','t','yes') THEN TRUE
      ELSE FALSE
    END AS is_version_of
  FROM all_dedup
),
flags AS (
  SELECT
    backend,
    server_name,
    record_id,

    -- DOI patterns (common: -v1, .v2, _v3, -1, .2, etc.)
    regexp_matches(doi_l, '[-._]v[0-9]{1,3}([^0-9]|$)') AS doi_sep_vN,
    regexp_matches(doi_l, '[-._][0-9]{1,3}([^0-9]|$)')  AS doi_sep_N,

    -- Landing URL patterns (query params or path versions)
    regexp_matches(landing_l, '([?&](version|ver|v)=([0-9]{1,3}))') AS landing_param_version,
    regexp_matches(landing_l, '(/v[0-9]{1,3})(/|$)')                AS landing_path_vN,

    -- Metadata signal (string present)
    (vlabel_l <> '' AND vlabel_l <> 'null') AS version_label_present,

    -- Relationship signal
    is_version_of AS metadata_is_version_of
  FROM base
),
scored AS (
  SELECT
    *,
    -- count how many signals are true
    (CASE WHEN doi_sep_vN THEN 1 ELSE 0 END
     + CASE WHEN doi_sep_N THEN 1 ELSE 0 END
     + CASE WHEN landing_param_version THEN 1 ELSE 0 END
     + CASE WHEN landing_path_vN THEN 1 ELSE 0 END
     + CASE WHEN version_label_present THEN 1 ELSE 0 END
     + CASE WHEN metadata_is_version_of THEN 1 ELSE 0 END
    ) AS n_signals
  FROM flags
)
SELECT
  backend,
  server_name,
  record_id,

  -- Primary label (single best category) + multi/no signal handling
  CASE
    WHEN n_signals = 0 THEN 'no_signal'
    WHEN n_signals > 1 THEN 'multi_signal'

    -- single-signal cases (priority order)
    WHEN doi_sep_vN THEN 'doi_sep_vN'
    WHEN doi_sep_N  THEN 'doi_sep_N'
    WHEN landing_param_version THEN 'landing_param_version'
    WHEN landing_path_vN       THEN 'landing_path_vN'
    WHEN version_label_present THEN 'metadata_version_label'
    WHEN metadata_is_version_of THEN 'metadata_is_version_of'
    ELSE 'unknown'
  END AS version_signal_type,

  -- Helpful audit columns (keep these!)
  n_signals,
  doi_sep_vN,
  doi_sep_N,
  landing_param_version,
  landing_path_vN,
  version_label_present,
  metadata_is_version_of

FROM scored;
""")

# quick peek
con.execute("SELECT version_signal_type, COUNT(*) AS n FROM version_detection GROUP BY 1 ORDER BY n DESC;").df()
# Out:
#       version_signal_type        n
# 0               no_signal  3991578
# 1  metadata_version_label  2959535
# 2               doi_sep_N   792447
# 3            multi_signal   607660
# 4              doi_sep_vN    74445
# 5         landing_path_vN      382

# %%
con.execute(r"""
CREATE OR REPLACE TABLE version_detection AS
WITH base AS (
  SELECT
    backend, server_name, record_id,
    lower(coalesce(CAST(doi AS VARCHAR), '')) AS doi_l,
    lower(coalesce(CAST(landing_page_url AS VARCHAR), '')) AS landing_l,
    lower(coalesce(CAST(version_label AS VARCHAR), '')) AS vlabel_l,
    
    CASE
      WHEN CAST(is_version_of AS VARCHAR) IN ('true','1','t','yes') THEN TRUE
      ELSE FALSE
    END AS is_version_of
  FROM all_dedup
),
flags AS (
  SELECT
    backend, server_name, record_id,
    regexp_matches(doi_l, '[-._]v[0-9]{1,3}([^0-9]|$)') AS doi_sep_vN,
    regexp_matches(doi_l, '[-._][0-9]{1,3}([^0-9]|$)')  AS doi_sep_N,
    regexp_matches(landing_l, '([?&](version|ver|v)=([0-9]{1,3}))') AS landing_param_version,
    regexp_matches(landing_l, '(/v[0-9]{1,3})(/|$)')                AS landing_path_vN,
    (vlabel_l <> '' AND vlabel_l <> 'null') AS version_label_present,
    is_version_of AS metadata_is_version_of
  FROM base
),
scored AS (
  SELECT
    *,
    (CASE WHEN doi_sep_vN THEN 1 ELSE 0 END
     + CASE WHEN doi_sep_N THEN 1 ELSE 0 END
     + CASE WHEN landing_param_version THEN 1 ELSE 0 END
     + CASE WHEN landing_path_vN THEN 1 ELSE 0 END
     + CASE WHEN version_label_present THEN 1 ELSE 0 END
     + CASE WHEN metadata_is_version_of THEN 1 ELSE 0 END
    ) AS n_signals
  FROM flags
),
reasons AS (
  SELECT
    *,
    trim(both '|' from
      (CASE WHEN doi_sep_vN THEN 'doi_sep_vN|' ELSE '' END) ||
      (CASE WHEN doi_sep_N  THEN 'doi_sep_N|'  ELSE '' END) ||
      (CASE WHEN landing_param_version THEN 'landing_param_version|' ELSE '' END) ||
      (CASE WHEN landing_path_vN       THEN 'landing_path_vN|'       ELSE '' END) ||
      (CASE WHEN version_label_present THEN 'metadata_version_label|' ELSE '' END) ||
      (CASE WHEN metadata_is_version_of THEN 'metadata_is_version_of|' ELSE '' END)
    ) AS version_signal_reasons
  FROM scored
)
SELECT
  backend,
  server_name,
  record_id,
  CASE
    WHEN n_signals = 0 THEN 'no_signal'
    WHEN n_signals > 1 THEN 'multi_signal'
    WHEN doi_sep_vN THEN 'doi_sep_vN'
    WHEN doi_sep_N  THEN 'doi_sep_N'
    WHEN landing_param_version THEN 'landing_param_version'
    WHEN landing_path_vN       THEN 'landing_path_vN'
    WHEN version_label_present THEN 'metadata_version_label'
    WHEN metadata_is_version_of THEN 'metadata_is_version_of'
    ELSE 'unknown'
  END AS version_signal_type,
  version_signal_reasons,
  n_signals,
  doi_sep_vN, doi_sep_N, landing_param_version, landing_path_vN, version_label_present, metadata_is_version_of
FROM reasons;
""")

# %%
con.execute("""
SELECT server_name, version_signal_type, COUNT(*) AS n
FROM version_detection
GROUP BY 1,2
ORDER BY server_name, n DESC;
""").df()
# Out:
#             server_name version_signal_type      n
# 0        AIJR Preprints           doi_sep_N    143
# 1    AMRC Open Research        multi_signal     38
# 2    AMRC Open Research           no_signal      1
# 3        APSA Preprints           no_signal    772
# 4        APSA Preprints           doi_sep_N    391
# ..                  ...                 ...    ...
# 244          searchRxiv           no_signal      2
# 245               viXra           no_signal  24275
# 246               viXra           doi_sep_N   1128
# 247               viXra          doi_sep_vN    165
# 248               viXra        multi_signal      2
#
# [249 rows x 3 columns]

# %%
con.execute("""
SELECT server_name,
       SUM(CASE WHEN version_signal_type <> 'no_signal' THEN 1 ELSE 0 END) AS n_with_signal,
       COUNT(*) AS n_total
FROM version_detection
GROUP BY 1
ORDER BY n_with_signal DESC
LIMIT 30;
""").df()
# Out:
#                               server_name  n_with_signal  n_total
# 0                                   arXiv      2920797.0  2920797
# 1                         Research Square       450818.0   450818
# 2                                 bioRxiv       239579.0   306948
# 3                                   eLife       209257.0   247558
# 4                            ResearchGate       181231.0   181231
# 5                           Preprints.org       115815.0   115815
# 6                                 medRxiv        74951.0    75743
# 7                                  Zenodo        38122.0   166786
# 8                                ChemRxiv        27959.0    46475
# 9                               EGUsphere        18002.0    60396
# 10                 Open Science Framework        17903.0   135434
# 11                          F1000Research        16866.0    16873
# 12                               PsyArXiv        15998.0    56866
# 13                                    HAL        13910.0  1056424
# 14   Earth and Space Science Open Archive        13265.0    21299
# 15                               TechRxiv        10842.0    29418
# 16    RePEc: Research Papers in Economics         7496.0   389398
# 17                Humanities Commons CORE         7170.0    29584
# 18                  ScienceOpen Preprints         4948.0     5087
# 19                               SocArXiv         4874.0    21541
# 20                 Wellcome Open Research         4727.0     4727
# 21                                  Qeios         4598.0   172316
# 22                      Nature Precedings         3535.0     5210
# 23  Social Science Open Access Repository         3383.0    27201
# 24                     EconStor Preprints         3340.0    71761
# 25                   UCL Open Environment         2834.0     3474
# 26                                Advance         1934.0     4399
# 27                   Open Research Europe         1877.0     1877
# 28                  Cambridge Open Engage         1621.0     3090
# 29                        PeerJ Preprints         1342.0     6446

# %%
con.execute(r"""
CREATE OR REPLACE TABLE version_detection AS
WITH base AS (
  SELECT
    backend,
    server_name,
    record_id,

    /* ---- normalize strings safely ---- */
    lower(coalesce(CAST(doi AS VARCHAR), ''))               AS doi_l,
    lower(coalesce(CAST(landing_page_url AS VARCHAR), '')) AS landing_l,
    lower(coalesce(CAST(version_label AS VARCHAR), ''))    AS vlabel_l,

    /* ---- normalize boolean safely ---- */
    CASE
      WHEN CAST(is_version_of AS VARCHAR) IN ('true','1','t','yes') THEN TRUE
      ELSE FALSE
    END AS is_version_of

  FROM all_dedup
),

flags AS (
  SELECT
    backend,
    server_name,
    record_id,

    /* DOI patterns */
    regexp_matches(doi_l, '[-._]v[0-9]{1,3}([^0-9]|$)') AS doi_sep_vN,
    regexp_matches(doi_l, '[-._][0-9]{1,3}([^0-9]|$)')  AS doi_sep_N,

    /* Landing URL patterns */
    regexp_matches(landing_l, '([?&](version|ver|v)=([0-9]{1,3}))') AS landing_param_version,
    regexp_matches(landing_l, '(/v[0-9]{1,3})(/|$)')                AS landing_path_vN,

    /* Metadata signal */
    (vlabel_l <> '' AND vlabel_l <> 'null') AS metadata_version_label,

    /* Relationship signal */
    is_version_of AS metadata_is_version_of
  FROM base
),

reasons AS (
  SELECT
    backend,
    server_name,
    record_id,

    /* Build explicit reason list */
    trim(both '|' FROM
      concat(
        CASE WHEN doi_sep_vN THEN 'doi_sep_vN|' ELSE '' END,
        CASE WHEN doi_sep_N THEN 'doi_sep_N|' ELSE '' END,
        CASE WHEN landing_param_version THEN 'landing_param_version|' ELSE '' END,
        CASE WHEN landing_path_vN THEN 'landing_path_vN|' ELSE '' END,
        CASE WHEN metadata_version_label THEN 'metadata_version_label|' ELSE '' END,
        CASE WHEN metadata_is_version_of THEN 'metadata_is_version_of|' ELSE '' END
      )
    ) AS version_signal_reasons,

    /* signal count (useful downstream) */
    (CASE WHEN doi_sep_vN THEN 1 ELSE 0 END
     + CASE WHEN doi_sep_N THEN 1 ELSE 0 END
     + CASE WHEN landing_param_version THEN 1 ELSE 0 END
     + CASE WHEN landing_path_vN THEN 1 ELSE 0 END
     + CASE WHEN metadata_version_label THEN 1 ELSE 0 END
     + CASE WHEN metadata_is_version_of THEN 1 ELSE 0 END
    ) AS n_signals

  FROM flags
)

SELECT
  backend,
  server_name,
  record_id,

  /* Final normalized output */
  CASE
    WHEN n_signals = 0 THEN 'no_signal'
    ELSE version_signal_reasons
  END AS version_signal_reasons,

  n_signals

FROM reasons;
""")

# %%
con.execute("""
SELECT version_signal_reasons, COUNT(*) AS n
FROM version_detection
GROUP BY 1
ORDER BY n DESC;
""").df()
# Out:
#                                version_signal_reasons        n
# 0                                           no_signal  3991578
# 1                              metadata_version_label  2959535
# 2                                           doi_sep_N   792447
# 3                           doi_sep_N|landing_path_vN   467897
# 4                          doi_sep_vN|landing_path_vN   115982
# 5                                          doi_sep_vN    74445
# 6                                doi_sep_vN|doi_sep_N     8304
# 7    doi_sep_N|landing_path_vN|metadata_version_label     8265
# 8                    doi_sep_N|metadata_version_label     6416
# 9                doi_sep_vN|doi_sep_N|landing_path_vN      565
# 10                                    landing_path_vN      382
# 11  doi_sep_vN|doi_sep_N|landing_path_vN|metadata_...      199
# 12                  doi_sep_vN|metadata_version_label       22
# 13             landing_path_vN|metadata_version_label        9
# 14  doi_sep_vN|landing_path_vN|metadata_version_label        1

# %%
con.execute("""
SELECT *
FROM version_detection
WHERE n_signals > 1
LIMIT 20;
""").df()
# Out:
#      backend                          server_name  \
# 0   openalex  RePEc: Research Papers in Economics
# 1   datacite                         ResearchGate
# 2   datacite                         ResearchGate
# 3   datacite                         ResearchGate
# 4   datacite                         ResearchGate
# 5   datacite                         ResearchGate
# 6   datacite                         ResearchGate
# 7   datacite                         ResearchGate
# 8   datacite                         ResearchGate
# 9   datacite                         ResearchGate
# 10  datacite                         ResearchGate
# 11  datacite                         ResearchGate
# 12  datacite                         ResearchGate
# 13  datacite                         ResearchGate
# 14  datacite                         ResearchGate
# 15  datacite                         ResearchGate
# 16  datacite                         ResearchGate
# 17  datacite                         ResearchGate
# 18  datacite                         ResearchGate
# 19  datacite                         ResearchGate
#
#                                   record_id            version_signal_reasons  \
# 0                     openalex::W3124501944              doi_sep_vN|doi_sep_N
# 1   datacite::10.13140/rg.2.2.15213.56805/1  doi_sep_N|metadata_version_label
# 2   datacite::10.13140/rg.2.2.15288.57604/1  doi_sep_N|metadata_version_label
# 3   datacite::10.13140/rg.2.2.16595.40484/1  doi_sep_N|metadata_version_label
# 4   datacite::10.13140/rg.2.2.16647.65443/1  doi_sep_N|metadata_version_label
# 5   datacite::10.13140/rg.2.2.16770.91843/1  doi_sep_N|metadata_version_label
# 6   datacite::10.13140/rg.2.2.17465.93281/1  doi_sep_N|metadata_version_label
# 7   datacite::10.13140/rg.2.2.18040.11524/2  doi_sep_N|metadata_version_label
# 8   datacite::10.13140/rg.2.2.19963.69922/1  doi_sep_N|metadata_version_label
# 9   datacite::10.13140/rg.2.2.20013.44002/2  doi_sep_N|metadata_version_label
# 10  datacite::10.13140/rg.2.2.20395.49446/1  doi_sep_N|metadata_version_label
# 11  datacite::10.13140/rg.2.2.21598.61761/2  doi_sep_N|metadata_version_label
# 12  datacite::10.13140/rg.2.2.22384.20483/1  doi_sep_N|metadata_version_label
# 13  datacite::10.13140/rg.2.2.24715.09765/1  doi_sep_N|metadata_version_label
# 14  datacite::10.13140/rg.2.2.26008.81920/1  doi_sep_N|metadata_version_label
# 15  datacite::10.13140/rg.2.2.26633.67689/2  doi_sep_N|metadata_version_label
# 16  datacite::10.13140/rg.2.2.26730.39367/1  doi_sep_N|metadata_version_label
# 17  datacite::10.13140/rg.2.2.27640.52488/1  doi_sep_N|metadata_version_label
# 18  datacite::10.13140/rg.2.2.27806.10561/1  doi_sep_N|metadata_version_label
# 19  datacite::10.13140/rg.2.2.27851.41765/1  doi_sep_N|metadata_version_label
#
#     n_signals
# 0           2
# 1           2
# 2           2
# 3           2
# 4           2
# 5           2
# 6           2
# 7           2
# 8           2
# 9           2
# 10          2
# 11          2
# 12          2
# 13          2
# 14          2
# 15          2
# 16          2
# 17          2
# 18          2
# 19          2

# %%
con.execute("DESCRIBE all_dedup").df()
# Out:
#                    column_name column_type null   key default extra
# 0                    record_id     VARCHAR  YES  None    None  None
# 1                  server_name     VARCHAR  YES  None    None  None
# 2                          doi     VARCHAR  YES  None    None  None
# 3                      doi_url     VARCHAR  YES  None    None  None
# 4             landing_page_url     VARCHAR  YES  None    None  None
# 5                        title     VARCHAR  YES  None    None  None
# 6             type_backend_raw     VARCHAR  YES  None    None  None
# 7          subtype_backend_raw     VARCHAR  YES  None    None  None
# 8               type_canonical     VARCHAR  YES  None    None  None
# 9        is_preprint_candidate     VARCHAR  YES  None    None  None
# 10                date_created     VARCHAR  YES  None    None  None
# 11                 date_posted     VARCHAR  YES  None    None  None
# 12              date_deposited     VARCHAR  YES  None    None  None
# 13                date_indexed     VARCHAR  YES  None    None  None
# 14                date_updated     VARCHAR  YES  None    None  None
# 15                 date_issued     VARCHAR  YES  None    None  None
# 16             date_registered     VARCHAR  YES  None    None  None
# 17              date_published     VARCHAR  YES  None    None  None
# 18       date_published_online     VARCHAR  YES  None    None  None
# 19            publication_year     VARCHAR  YES  None    None  None
# 20       date_published_source     VARCHAR  YES  None    None  None
# 21          date_posted_source     VARCHAR  YES  None    None  None
# 22             links_json_best     VARCHAR  YES  None    None  None
# 23              relations_json     VARCHAR  YES  None    None  None
# 24                has_preprint     VARCHAR  YES  None    None  None
# 25              is_preprint_of     VARCHAR  YES  None    None  None
# 26       has_published_version     VARCHAR  YES  None    None  None
# 27  published_version_ids_json     VARCHAR  YES  None    None  None
# 28               is_version_of     VARCHAR  YES  None    None  None
# 29         version_of_ids_json     VARCHAR  YES  None    None  None
# 30               version_label     VARCHAR  YES  None    None  None
# 31                  has_review     VARCHAR  YES  None    None  None
# 32              update_to_json     VARCHAR  YES  None    None  None
# 33                  parent_doi     VARCHAR  YES  None    None  None
# 34      raw_relationships_json     VARCHAR  YES  None    None  None
# 35                     backend     VARCHAR  YES  None    None  None

# %%
con.execute("""
SELECT column_name, data_type
FROM information_schema.columns
WHERE table_name = 'all_dedup'
ORDER BY ordinal_position
""").df()
# Out:
#                    column_name data_type
# 0                    record_id   VARCHAR
# 1                  server_name   VARCHAR
# 2                          doi   VARCHAR
# 3                      doi_url   VARCHAR
# 4             landing_page_url   VARCHAR
# 5                        title   VARCHAR
# 6             type_backend_raw   VARCHAR
# 7          subtype_backend_raw   VARCHAR
# 8               type_canonical   VARCHAR
# 9        is_preprint_candidate   VARCHAR
# 10                date_created   VARCHAR
# 11                 date_posted   VARCHAR
# 12              date_deposited   VARCHAR
# 13                date_indexed   VARCHAR
# 14                date_updated   VARCHAR
# 15                 date_issued   VARCHAR
# 16             date_registered   VARCHAR
# 17              date_published   VARCHAR
# 18       date_published_online   VARCHAR
# 19            publication_year   VARCHAR
# 20       date_published_source   VARCHAR
# 21          date_posted_source   VARCHAR
# 22             links_json_best   VARCHAR
# 23              relations_json   VARCHAR
# 24                has_preprint   VARCHAR
# 25              is_preprint_of   VARCHAR
# 26       has_published_version   VARCHAR
# 27  published_version_ids_json   VARCHAR
# 28               is_version_of   VARCHAR
# 29         version_of_ids_json   VARCHAR
# 30               version_label   VARCHAR
# 31                  has_review   VARCHAR
# 32              update_to_json   VARCHAR
# 33                  parent_doi   VARCHAR
# 34      raw_relationships_json   VARCHAR
# 35                     backend   VARCHAR

# %%
# con.execute("""
# SELECT *
# FROM all_dedup
# LIMIT 100
# """).df()

# %%
# con.execute("""
# SELECT *
# FROM all_dedup
# USING SAMPLE 100 ROWS
# """).df()

# %%
# con.execute("""
# SELECT *
# FROM all_dedup
# USING SAMPLE 0.01 PERCENT
# """).df()

# %%
# PAGE_SIZE = 1000

# for i in range(0, 5000, PAGE_SIZE):
#     df = con.execute(f"""
#         SELECT *
#         FROM all_dedup
#         LIMIT {PAGE_SIZE} OFFSET {i}
#     """).df()
#     display(df)

# %%
# df = con.execute("""
# SELECT *
# FROM all_dedup
# LIMIT 50_000
# """).df()

# %%
# con.execute("""
# COPY all_dedup
# TO 'all_dedup_full.parquet'
# (FORMAT PARQUET)
# """)

# %%
con.execute("""
SELECT backend, COUNT(*) 
FROM all_dedup 
GROUP BY backend
""").df()
# Out:
#     backend  count_star()
# 0  crossref       3187171
# 1  datacite       3520391
# 2  openalex       1718485

# %%
con.execute("""
SELECT server_name, COUNT(*) 
FROM all_dedup 
GROUP BY server_name
ORDER BY COUNT(*) DESC
""").df()
# Out:
#                              server_name  count_star()
# 0                                  arXiv       2920797
# 1                                   SSRN       1258958
# 2                                    HAL       1056424
# 3                        Research Square        450818
# 4    RePEc: Research Papers in Economics        389398
# ..                                   ...           ...
# 107                                EmeRI             8
# 108                            Therapoid             7
# 109                       NewAddictionsX             7
# 110             Bepress Legal Repository             6
# 111                           searchRxiv             2
#
# [112 rows x 2 columns]

# %%
import duckdb
from pathlib import Path

# con = duckdb.connect()  # or your existing connection

# Make DuckDB less memory-hungry during export
con.execute("PRAGMA threads=1;")                    # single thread uses less memory
con.execute("PRAGMA preserve_insertion_order=false;")
con.execute("PRAGMA enable_object_cache=false;")

# If you can: cap memory so it spills to disk earlier (tune if needed)
con.execute("PRAGMA memory_limit='2GB';")           # try 2GB; if still OOM, try 1GB
con.execute("PRAGMA temp_directory='data/tmp_duckdb';")

# %%
import math
from pathlib import Path

OUTDIR = Path("data/all_backends/all_dedup_parts")
OUTDIR.mkdir(parents=True, exist_ok=True)

ROWS_PER_PART = 200_000  # start small; increase later if stable

total = con.execute("SELECT COUNT(*) FROM all_dedup").fetchone()[0]
n_parts = math.ceil(total / ROWS_PER_PART)

print("total rows:", total, "parts:", n_parts)

for i in range(n_parts):
    offset = i * ROWS_PER_PART
    out_path = OUTDIR / f"part_{i:06d}.parquet"
    print("writing", out_path.name, "offset", offset)

    con.execute(f"""
        COPY (
            SELECT *
            FROM all_dedup
            LIMIT {ROWS_PER_PART} OFFSET {offset}
        )
        TO '{out_path.as_posix()}'
        (FORMAT PARQUET);
    """)
# Out:
# total rows: 8426047 parts: 43
# writing part_000000.parquet offset 0
# ---------------------------------------------------------------------------
# OutOfMemoryException                      Traceback (most recent call last)
# Cell In[31], line 19
#      16 out_path = OUTDIR / f"part_{i:06d}.parquet"
#      17 print("writing", out_path.name, "offset", offset)
# ---> 19 con.execute(f"""
#      20     COPY (
#      21         SELECT *
#      22         FROM all_dedup
#      23         LIMIT {ROWS_PER_PART} OFFSET {offset}
#      24     )
#      25     TO '{out_path.as_posix()}'
#      26     (FORMAT PARQUET);
#      27 """)
#
# OutOfMemoryException: Out of Memory Error: could not allocate block of size 256.0 KiB (1.8 GiB/1.8 GiB used)
#
# Possible solutions:
# * Reducing the number of threads (SET threads=X)
# * Disabling insertion-order preservation (SET preserve_insertion_order=false)
# * Increasing the memory limit (SET memory_limit='...GB')
#
# See also https://duckdb.org/docs/stable/guides/performance/how_to_tune_workloads
