# %%
import pandas as pd
# Set option to display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# # import data

# %%
import duckdb
from pathlib import Path

con = duckdb.connect()

# Low-memory settings
con.execute("PRAGMA threads=1;")
con.execute("PRAGMA preserve_insertion_order=false;")
con.execute("PRAGMA enable_object_cache=false;")
con.execute("PRAGMA memory_limit='2GB';")           # try 1GB if still unstable
con.execute("PRAGMA temp_directory='data/tmp_duckdb';")

# 2) Build paths robustly from the notebook folder
ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

BASE = ROOT / "data" / "by_server"

# IMPORTANT: your files are hive-partitioned like:
all_backends = (BASE / "*" / "*.parquet").as_posix()

con.execute(f"""
CREATE OR REPLACE VIEW all_backends AS
SELECT * FROM read_parquet('{all_backends}', hive_partitioning=true, union_by_name=true);
""")

# A unified "all_rows" view
con.execute("""
CREATE OR REPLACE VIEW all_rows AS
SELECT * FROM all_backends
""")

print(con.execute("SHOW TABLES").fetchall())
# Out:
# [('all_backends',), ('all_rows',)]

# %%
con.execute(f"""
CREATE OR REPLACE VIEW server_thin AS
SELECT
  CAST(record_id AS VARCHAR)           AS record_id,
  CAST(server_name AS VARCHAR)         AS server_name,
  CAST(backend AS VARCHAR)             AS backend,

  CAST(doi AS VARCHAR)                 AS doi,
  CAST(doi_url AS VARCHAR)             AS doi_url,
  CAST(landing_page_url AS VARCHAR)    AS landing_page_url,

  CAST(title AS VARCHAR) AS title,
  -- CAST(abstract_text AS VARCHAR)      AS abstract_text,
  CAST(authors_flat AS VARCHAR)      AS authors_flat,
  CAST(institutions_flat AS VARCHAR)      AS institutions_flat,
  CAST(countries_flat AS VARCHAR)      AS countries_flat,
  
  -- Dates (helpful for temporal patterns)
  -- CAST(publication_year AS VARCHAR)    AS publication_year,
  -- CAST(date_created AS VARCHAR)        AS date_created,
  -- CAST(date_posted AS VARCHAR)         AS date_posted,
  -- CAST(date_deposited AS VARCHAR)      AS date_deposited,
  -- CAST(date_published AS VARCHAR)      AS date_published,
  -- CAST(date_published_online AS VARCHAR)      AS date_published_online,
  -- CAST(date_issued AS VARCHAR)         AS date_issued,
  -- CAST(date_indexed AS VARCHAR)        AS date_indexed,
  -- CAST(date_updated AS VARCHAR)        AS date_updated,
  -- CAST(date_registered AS VARCHAR)     AS date_registered,

  -- Relationships (keep these for true version links)
  CAST(relations_json AS VARCHAR)       AS relations_json,
  CAST(version_label AS VARCHAR)       AS version_label,
  CAST(is_version_of AS VARCHAR)       AS is_version_of,      -- keep as text; we’ll interpret later
  CAST(is_preprint_of AS VARCHAR)      AS is_preprint_of,
  CAST(has_preprint AS VARCHAR)      AS has_preprint,
  CAST(has_review AS VARCHAR)      AS has_review,
  CAST(has_published_version AS VARCHAR)      AS has_published_version,
  CAST(published_version_ids_json AS VARCHAR) AS published_version_ids_json,
  CAST(version_of_ids_json AS VARCHAR) AS version_of_ids_json,
  CAST(update_to_json AS VARCHAR)      AS update_to_json,
  CAST(raw_relationships_json AS VARCHAR)       AS raw_relationships_json,
FROM all_backends
""")

con.execute("SELECT COUNT(*) AS n FROM server_thin").df()
# Out:
#          n
# 0  9486893

# %%
data = con.execute("SELECT * FROM server_thin").df()
# data.drop_duplicates(subset=['record_id'], keep='first', inplace=False)

data = data.drop_duplicates()
data
# Out:
#                                record_id     server_name   backend  \
# 0        crossref::10.21467/preprints.48  AIJR Preprints  crossref
# 1        crossref::10.21467/preprints.43  AIJR Preprints  crossref
# 2        crossref::10.21467/preprints.39  AIJR Preprints  crossref
# 3        crossref::10.21467/preprints.38  AIJR Preprints  crossref
# 4        crossref::10.21467/preprints.36  AIJR Preprints  crossref
# ...                                  ...             ...       ...
# 9486888             openalex::W999325625           viXra  openalex
# 9486889             openalex::W999460032           viXra  openalex
# 9486890              openalex::W99967155           viXra  openalex
# 9486891             openalex::W999790414           viXra  openalex
# 9486892             openalex::W999805801           viXra  openalex
#
#                            doi                                doi_url  \
# 0        10.21467/preprints.48  https://doi.org/10.21467/preprints.48
# 1        10.21467/preprints.43  https://doi.org/10.21467/preprints.43
# 2        10.21467/preprints.39  https://doi.org/10.21467/preprints.39
# 3        10.21467/preprints.38  https://doi.org/10.21467/preprints.38
# 4        10.21467/preprints.36  https://doi.org/10.21467/preprints.36
# ...                        ...                                    ...
# 9486888                   None                                   None
# 9486889                   None                                   None
# 9486890                   None                                   None
# 9486891                   None                                   None
# 9486892                   None                                   None
#
#                                           landing_page_url  \
# 0        https://preprints.aijr.org/index.php/ap/prepri...
# 1        https://preprints.aijr.org/index.php/ap/prepri...
# 2        https://preprints.aijr.org/index.php/ap/prepri...
# 3        https://preprints.aijr.org/index.php/ap/prepri...
# 4        https://preprints.aijr.org/index.php/ap/prepri...
# ...                                                    ...
# 9486888              https://vixra.org/pdf/1409.0090v1.pdf
# 9486889                    https://vixra.org/abs/1112.0094
# 9486890              https://vixra.org/pdf/1406.0019v1.pdf
# 9486891              https://vixra.org/pdf/1306.0105v3.pdf
# 9486892              https://vixra.org/pdf/1412.0197v3.pdf
#
#                                                      title  \
# 0        Bird’s Eye View on the Diagnosis, Treatment, &...
# 1        Doxycycline and Minocycline Drugs as a Treatme...
# 2        A Genetic Perspective of 2019-nCoV in Relation...
# 3        Marine Algae as a Natural Source for Antiviral...
# 4        Possible Prevention of COVID 19 by Using Linol...
# ...                                                    ...
# 9486888                 Three Objections to Modern Physics
# 9486889                               Particle Mass Ratios
# 9486890  Quantum FFF Theory Proposals for Some Unsolved...
# 9486891  Investigation of the Formalism of Particle Dyn...
# 9486892  Electromagnetic Energy and Electromagnetic For...
#
#                                               authors_flat institutions_flat  \
# 0                              Panchalingala, Sai Bhargavi              None
# 1                                         Mostafa, Mohamed              None
# 2                                        Dasgupta, Rimjhim              None
# 3        Musale, Amar S; G., Raja Krishna Kumar; Sapre,...              None
# 4        Subhash, Venkata; G, Raja Krishna Kumar; Sapre...              None
# ...                                                    ...               ...
# 9486888                                      Lubomir Vlcek              None
# 9486889                                         DT Froedge              None
# 9486890                                           Leo Vuyk              None
# 9486891                                        Chi-Yi Chen              None
# 9486892                                    Yu.A. Spirichev              None
#
#         countries_flat relations_json version_label is_version_of  \
# 0                 None           None          None
# 1                 None           None          None
# 2                 None           None          None
# 3                 None           None          None
# 4                 None           None          None
# ...                ...            ...           ...           ...
# 9486888           None           None          None          None
# 9486889           None           None          None          None
# 9486890           None           None          None          None
# 9486891           None           None          None          None
# 9486892           None           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 0                                                              false
# 1                                                              false
# 2                                                              false
# 3                                                              false
# 4                                                              false
# ...                ...          ...        ...                   ...
# 9486888           None         None       None                  None
# 9486889           None         None       None                  None
# 9486890           None         None       None                  None
# 9486891           None         None       None                  None
# 9486892           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 0                             None                None           None
# 1                             None                None           None
# 2                             None                None           None
# 3                             None                None           None
# 4                             None                None           None
# ...                            ...                 ...            ...
# 9486888                       None                None           None
# 9486889                       None                None           None
# 9486890                       None                None           None
# 9486891                       None                None           None
# 9486892                       None                None           None
#
#         raw_relationships_json
# 0                         None
# 1                         None
# 2                         None
# 3                         None
# 4                         None
# ...                        ...
# 9486888                   None
# 9486889                   None
# 9486890                   None
# 9486891                   None
# 9486892                   None
#
# [8413526 rows x 21 columns]

# %%
import pandas as pd

# ================================
# 1) Load saved artifacts
# ================================
records_hierarchy_df = pd.read_pickle("outputs/records_hierarchy_df.pkl")
date_first_seen_df   = pd.read_pickle("outputs/date_first_seen.pkl")

# ================================
# 2) Normalize keys
# ================================
def norm_key(s):
    return s.astype(str).str.strip()

for df_ in (records_hierarchy_df, date_first_seen_df):
    df_["record_id"] = norm_key(df_["record_id"])
    df_["server_name"] = norm_key(df_["server_name"])

data["record_id"] = norm_key(data["record_id"])
data["server_name"] = norm_key(data["server_name"])

# ================================
# 3) Ensure each RHS table is unique on (record_id, server_name)
# ================================
records_hierarchy_df = records_hierarchy_df.drop_duplicates(["record_id", "server_name"])
date_first_seen_df   = date_first_seen_df.drop_duplicates(["record_id", "server_name"])

# ================================
# 4) Build MASTER pairs from records_hierarchy_df
#    (this is what you said you want to keep)
# ================================
master_pairs = set(zip(records_hierarchy_df["record_id"], records_hierarchy_df["server_name"]))

# Filter helpers
def filter_to_master_pairs(df: pd.DataFrame) -> pd.DataFrame:
    pairs = list(zip(df["record_id"], df["server_name"]))
    return df.loc[pd.Series(pairs, index=df.index).isin(master_pairs)].copy()

# ================================
# 5) Filter data and date_first_seen to MASTER pairs
# ================================
data_master = filter_to_master_pairs(data)
date_first_seen_master = filter_to_master_pairs(date_first_seen_df)

# Optional safety: also dedupe data on the same key (should not change if clean)
data_master = data_master.drop_duplicates(["record_id", "server_name"], keep="first")

# ================================
# 6) Merge (left join from MASTER DATA)
# ================================
join_keys = ["record_id", "server_name"]

data_clean_hierarchy = (
    data_master
      .merge(records_hierarchy_df, on=join_keys, how="left", validate="one_to_one")
      .merge(date_first_seen_master, on=join_keys, how="left", validate="one_to_one")
)

# ================================
# 7) Sanity checks (correct ones)
# ================================
print("Master pairs (records_hierarchy_df rows):", len(records_hierarchy_df))
print("Master unique record_id:", records_hierarchy_df["record_id"].nunique())

print("Rows in raw data:", len(data))
print("Rows in data after filtering to master pairs:", len(data_master))

print("Rows in date_first_seen after filtering to master pairs:", len(date_first_seen_master))
print("Final rows in data_clean_hierarchy:", len(data_clean_hierarchy))

print("\nMissing records_hierarchy:", data_clean_hierarchy["records_hierarchy"].isna().sum())
print("Missing date_first_seen:", data_clean_hierarchy["date_first_seen"].isna().sum())
print("Missing publication_year_first_seen:", data_clean_hierarchy["publication_year_first_seen"].isna().sum())

print("\nDuplicates on (record_id, server_name) in final:",
      data_clean_hierarchy.duplicated(["record_id","server_name"]).sum())

print("\nHierarchy counts:")
print(data_clean_hierarchy["records_hierarchy"].value_counts(dropna=False).head(30))
# Out:
# Master pairs (records_hierarchy_df rows): 8410094
# Master unique record_id: 8410094
# Rows in raw data: 8413526
# Rows in data after filtering to master pairs: 8410094
# Rows in date_first_seen after filtering to master pairs: 8410094
# Final rows in data_clean_hierarchy: 8410094
#
# Missing records_hierarchy: 0
# Missing date_first_seen: 0
# Missing publication_year_first_seen: 0
#
# Duplicates on (record_id, server_name) in final: 0
#
# Hierarchy counts:
# records_hierarchy
# parent                              7950093
# review                               175443
# part_of                              149454
# version                              105977
# publish_version                        9351
# mirror (arXiv)                         8286
# mirror (AgEcon Search)                 6702
# child                                  2028
# mirror (ResearchGate)                  1633
# correction                              355
# comment                                 325
# mirror (Zenodo)                         297
# mirror (SSRN)                            36
# mirror (Open Science Framework)          31
# mirror (bioRxiv)                         29
# mirror (Humanities Commons CORE)         24
# others                                   12
# parent_duplicate                          3
# mirror (eLife)                            3
# mirror (Research Square)                  2
# mirror (CERN document server)             2
# mirror (TechRxiv)                         1
# mirror (EarthArXiv)                       1
# mirror (Oroboros Instruments)             1
# mirror (medRxiv)                          1
# mirror (Thesis Commons)                   1
# mirror (SocArXiv)                         1
# mirror (AgriRxiv)                         1
# mirror (Law Archive)                      1
# Name: count, dtype: int64

# %%
# 1. Create the backup copy in a new column
data_clean_hierarchy["records_hierarchy_backup"] = data_clean_hierarchy["records_hierarchy"].copy()

# 2. Overwrite all cells in the original column with the string 'parent'
data_clean_hierarchy["records_hierarchy"] = 'parent'

# %%
data_clean_hierarchy["records_hierarchy"].value_counts(dropna=False).head(60)
# Out:
# records_hierarchy
# parent    8410094
# Name: count, dtype: int64

# %%
data_clean_hierarchy["records_hierarchy_backup"].value_counts(dropna=False).head(60)
# Out:
# records_hierarchy_backup
# parent                              7950093
# review                               175443
# part_of                              149454
# version                              105977
# publish_version                        9351
# mirror (arXiv)                         8286
# mirror (AgEcon Search)                 6702
# child                                  2028
# mirror (ResearchGate)                  1633
# correction                              355
# comment                                 325
# mirror (Zenodo)                         297
# mirror (SSRN)                            36
# mirror (Open Science Framework)          31
# mirror (bioRxiv)                         29
# mirror (Humanities Commons CORE)         24
# others                                   12
# parent_duplicate                          3
# mirror (eLife)                            3
# mirror (Research Square)                  2
# mirror (CERN document server)             2
# mirror (TechRxiv)                         1
# mirror (EarthArXiv)                       1
# mirror (Oroboros Instruments)             1
# mirror (medRxiv)                          1
# mirror (Thesis Commons)                   1
# mirror (SocArXiv)                         1
# mirror (AgriRxiv)                         1
# mirror (Law Archive)                      1
# Name: count, dtype: int64

# %%
data_clean_hierarchy.count()
# Out:
# record_id                      8410094
# server_name                    8410094
# backend                        8410094
# doi                            6784859
# doi_url                        6784859
# landing_page_url               8330648
# title                          8410069
# authors_flat                   8194686
# institutions_flat              1865338
# countries_flat                  867847
# relations_json                 4253292
# version_label                  2974496
# is_version_of                  6707562
# is_preprint_of                 6707562
# has_preprint                   6707562
# has_review                     6707562
# has_published_version          6707562
# published_version_ids_json           0
# version_of_ids_json                  0
# update_to_json                    8899
# raw_relationships_json         3520391
# records_hierarchy              8410094
# date_first_seen                8410094
# publication_year_first_seen    8410094
# records_hierarchy_backup       8410094
# dtype: int64

# %% [markdown]
# # dedupe on title+authors (+ optional year)

# %%
"""
Reproducible 2-pass dedupe pipeline (Exact pass -> Fuzzy pass) with:
- Strong-but-cheap title normalization (cached)
- 3 author signatures: tokenbag | last_initial | last
- Stage A strict (title + authors_fp) exact
- Stage B relaxed (shared authors overlap) within exact-title groups (optional per stage)
- Optional fuzzy title fallback (token containment) BLOCKED by authors_fp (+ optional year)
- Prefilter modes:
    * title_dup  : keep rows where cleaned title repeats (fast exact stages)
    * author_dup : keep rows where authors_fp repeats (enables fuzzy stages when titles differ)
    * none       : keep all eligible (debug)

Includes:
- Metrics counters per stage
- Summary printing + early stop
- Deterministic labeling
- Designed for speed + low false positives (especially with last_initial)

USAGE:
1) Define STAGES_EXACT and STAGES_FUZZY
2) Run:
   df_out, metrics = run_dedupe_pipeline_two_passes(
       df,
       stages_exact=STAGES_EXACT,
       stages_fuzzy=STAGES_FUZZY,
       early_stop_if_new_labels_lt=500,
       print_summary=True,
       return_all_metrics=True,
       servers=None,
       across_servers=True,
       use_year=False,
       choose_parent="oldest",
       prefilter=True,
       date_candidates=('date_first_seen',),
       hierarchy_col="records_hierarchy",
       parent_id_col="parent_record_id",
       group_id_col="dup_group_id",
       add_authors_fingerprint_col=True,
       add_title_clean_col=True,
   )
"""

import pandas as pd
import numpy as np
import re
import time
import unicodedata
from typing import Iterable, Optional, Dict, Any, Tuple, List

# ============================================================
# 0) Regex + NA helpers
# ============================================================
_WS = re.compile(r"\s+")
_PUNCT_ALL = re.compile(r"[^\w\s]", re.UNICODE)  # remove everything except word chars + spaces
NA_LIKE = {"", "none", "null", "nan", "n/a", "[]", "{}", "na"}


# ============================================================
# 1) Utility: pick a date column + record_id numeric fallback
# ============================================================
def _pick_first_existing(df: pd.DataFrame, candidates: Iterable[str]) -> Optional[str]:
    for c in candidates:
        if c in df.columns:
            return c
    return None


def _record_id_key(s: pd.Series) -> pd.Series:
    """Fast numeric key from record_id (extract first digits)."""
    digits = s.astype("string").str.extract(r"(\d+)")[0]
    return pd.to_numeric(digits, errors="coerce")


# ============================================================
# 2) Title normalization (cheap, high ROI) + token containment
# ============================================================
def _strip_accents_text(x: str) -> str:
    return "".join(
        c for c in unicodedata.normalize("NFKD", x) if not unicodedata.combining(c)
    )


def _clean_title_series_v2(s: pd.Series) -> pd.Series:
    """
    Strong-but-cheap title normalization:
      - lowercase
      - strip accents
      - remove punctuation -> spaces
      - collapse whitespace
    """
    s = s.astype("string").fillna("").str.strip().str.lower()
    s = s.where(~s.isin(list(NA_LIKE)), "")
    s = s.apply(_strip_accents_text)
    s = s.str.replace(_PUNCT_ALL, " ", regex=True)
    s = s.str.replace(_WS, " ", regex=True).str.strip()
    return s


def _title_tokens_from_clean(title_clean: str) -> List[str]:
    """Tokenize already-clean title into tokens; drop very short tokens (len < 2)."""
    if not title_clean:
        return []
    return [t for t in title_clean.split(" ") if len(t) >= 2]


def _containment_score(a_tokens: List[str], b_tokens: List[str]) -> float:
    """
    Containment score:
        |A ∩ B| / min(|A|, |B|)
    Good for small title differences when tokens still mostly match.
    """
    if not a_tokens or not b_tokens:
        return 0.0
    A, B = set(a_tokens), set(b_tokens)
    denom = min(len(A), len(B))
    if denom <= 0:
        return 0.0
    return len(A & B) / denom


# ============================================================
# 3) Author canonicalization (3 modes)
# ============================================================
def _strip_accents(s: str) -> str:
    return "".join(
        c for c in unicodedata.normalize("NFKD", s) if not unicodedata.combining(c)
    )


def _normalize_one_author_tokenbag(author: str) -> str:
    """
    Token-bag per author:
    - remove punctuation
    - split tokens
    - sort tokens within author
    - join with "_"
    """
    if not author:
        return ""
    a = _strip_accents(str(author)).lower().strip()
    if not a or a in NA_LIKE:
        return ""
    a = _PUNCT_ALL.sub(" ", a)
    a = _WS.sub(" ", a).strip()
    if not a:
        return ""
    toks = [t for t in a.split(" ") if t]
    if not toks:
        return ""
    toks = sorted(toks)
    return "_".join(toks)


def _normalize_one_author_last_initial(author: str) -> str:
    """
    Middle-ground signature: "last|first_initial"
    Rules:
      - If comma: "Last, First ..." -> last = first token before comma;
                                     initial = first token after comma (first-name token only)
      - If no comma: "First ... Last" -> last = last token; initial = first token
      - If we can't find an initial, return "" (reduces false positives)
    """
    if not author:
        return ""
    a = _strip_accents(str(author)).lower().strip()
    if not a or a in NA_LIKE:
        return ""

    if "," in a:
        left, right = a.split(",", 1)
        left = _PUNCT_ALL.sub(" ", left)
        right = _PUNCT_ALL.sub(" ", right)
        left = _WS.sub(" ", left).strip()
        right = _WS.sub(" ", right).strip()
        if not left:
            return ""
        last_toks = [t for t in left.split(" ") if t]
        if not last_toks:
            return ""
        last = last_toks[0]  # keep your "first token if multi-token surname" philosophy

        first_toks = [t for t in right.split(" ") if t]
        if not first_toks:
            return ""  # avoid false positives
        ini = first_toks[0][:1]
        return f"{last}|{ini}" if ini else ""
    else:
        a = _PUNCT_ALL.sub(" ", a)
        a = _WS.sub(" ", a).strip()
        toks = [t for t in a.split(" ") if t]
        if len(toks) < 2:
            return ""
        ini = toks[0][:1]
        last = toks[-1]
        return f"{last}|{ini}" if (ini and last) else ""


def _normalize_one_author_last(author: str) -> str:
    """Last-name-only signature (high recall, more false positives)."""
    if not author:
        return ""
    a = _strip_accents(str(author)).lower().strip()
    if not a or a in NA_LIKE:
        return ""

    if "," in a:
        left = a.split(",", 1)[0].strip()
        left = _PUNCT_ALL.sub(" ", left)
        left = _WS.sub(" ", left).strip()
        if not left:
            return ""
        toks = [t for t in left.split(" ") if t]
        if not toks:
            return ""
        return toks[0]
    else:
        a = _PUNCT_ALL.sub(" ", a)
        a = _WS.sub(" ", a).strip()
        toks = [t for t in a.split(" ") if t]
        if not toks:
            return ""
        return toks[-1]


def build_authors_fingerprint_series(authors_flat: pd.Series, mode: str) -> pd.Series:
    """
    Build author fingerprint per row:
      - split authors on ';'
      - normalize each author (depends on mode)
      - drop empties
      - dedupe within row
      - sort
      - join with ';'
    """
    if mode not in {"tokenbag", "last_initial", "last"}:
        raise ValueError("mode must be tokenbag | last_initial | last")

    s = authors_flat.astype("string").fillna("").str.strip()
    s = s.where(~s.str.lower().isin(list(NA_LIKE)), "")

    if mode == "tokenbag":
        norm_fn = _normalize_one_author_tokenbag
    elif mode == "last_initial":
        norm_fn = _normalize_one_author_last_initial
    else:
        norm_fn = _normalize_one_author_last

    def row_to_fp(x: str) -> str:
        if not x:
            return ""
        authors = [a.strip() for a in str(x).split(";") if a.strip()]
        norm = [norm_fn(a) for a in authors]
        norm = [z for z in norm if z]
        norm = sorted(set(norm))
        return ";".join(norm)

    return s.apply(row_to_fp)


def _author_tokens_from_fp(fp: str) -> List[str]:
    if not fp:
        return []
    return [t for t in fp.split(";") if t]


def _overlap_count(a_tokens: List[str], b_tokens: List[str]) -> int:
    if not a_tokens or not b_tokens:
        return 0
    return len(set(a_tokens) & set(b_tokens))


# ============================================================
# 4) Single-stage dedupe:
#    - Prefilter (title_dup/author_dup/none)
#    - Stage A strict (title + authors_fp) exact match
#    - Optional fuzzy title fallback (within same authors_fp)
#    - Optional Stage B relaxed (shared authors overlap) within exact-title groups
# ============================================================
def dedupe_title_authors_stage(
    df: pd.DataFrame,
    *,
    # stage config
    stage_name: str = "stage",
    authors_fp_mode: str = "tokenbag",         # tokenbag | last_initial | last

    # fuzzy config (title containment), executed only if enabled
    title_fuzzy_fallback: bool = False,
    min_title_tokens: int = 6,
    min_title_containment: float = 0.70,
    fuzzy_compare_strategy: str = "parent_only",  # parent_only | all_pairs_small (parent_only is safest/fastest)

    # relaxed (shared authors overlap) config (exact title only)
    relaxed_shared_authors: bool = True,
    min_authors_required: int = 2,
    min_shared_authors: int = 2,

    # prefilter strategy (important!)
    prefilter_mode: str = "title_dup",         # title_dup | author_dup | none
    prefilter: bool = True,                    # if False, skip ">=2" group filter (slower)

    # global options
    servers=None,
    across_servers: bool = True,
    use_year: bool = False,
    choose_parent: str = "oldest",             # oldest | most_recent
    overwrite_mode: str = "parent_only",       # any | parent_only | unlabeled_only

    # columns
    server_col: str = "server_name",
    record_id_col: str = "record_id",
    title_col: str = "title",
    authors_col: str = "authors_flat",
    year_col: str = "publication_year_first_seen",
    date_candidates: Tuple[str, ...] = ("date_first_seen",),

    hierarchy_col: str = "records_hierarchy",
    parent_id_col: str = "parent_record_id",
    group_id_col: str = "dup_group_id",

    # caching/debug columns
    add_authors_fingerprint_col: bool = True,
    authors_fingerprint_col: str = "authors_fp",
    add_title_clean_col: bool = True,
    title_clean_col: str = "title_clean_v2",

    return_metrics: bool = False,
) -> pd.DataFrame | Tuple[pd.DataFrame, Dict[str, Any]]:
    """
    One dedupe stage. Designed to be composed into a multi-stage pipeline.
    """

    t0 = time.perf_counter()

    metrics: Dict[str, Any] = {
        "stage_name": stage_name,
        "n_rows_df": int(len(df)),
        "n_candidates_initial": 0,
        "prefilter_mode": prefilter_mode,
        "prefilter_rows": 0,
        "prefilter_groups": 0,
        "work_rows_after_keys": 0,

        "stageA_groups": 0,
        "stageA_children_labeled": 0,

        "fuzzy_enabled": bool(title_fuzzy_fallback),
        "fuzzy_groups": 0,
        "fuzzy_pairs_checked": 0,
        "fuzzy_children_labeled": 0,

        "stageB_enabled": bool(relaxed_shared_authors),
        "stageB_title_groups": 0,
        "stageB_clusters": 0,
        "stageB_children_labeled": 0,

        "time_s": 0.0,
    }

    # ------------------------------------------------------
    # Ensure output cols exist
    # ------------------------------------------------------
    for c in (hierarchy_col, parent_id_col, group_id_col):
        if c not in df.columns:
            df[c] = pd.NA

    if add_authors_fingerprint_col and authors_fingerprint_col not in df.columns:
        df[authors_fingerprint_col] = pd.NA
    if add_title_clean_col and title_clean_col not in df.columns:
        df[title_clean_col] = pd.NA

    # ------------------------------------------------------
    # Eligibility
    # ------------------------------------------------------
    h = df[hierarchy_col]
    if overwrite_mode == "any":
        eligible = pd.Series(True, index=df.index)
    elif overwrite_mode == "parent_only":
        eligible = h.astype("string").str.lower().str.strip().eq("parent")
    elif overwrite_mode == "unlabeled_only":
        eligible = h.isna()
    else:
        raise ValueError("overwrite_mode must be any | parent_only | unlabeled_only")

    # server filter
    if servers is None:
        server_mask = pd.Series(True, index=df.index)
    elif isinstance(servers, str):
        server_mask = df[server_col].eq(servers)
    else:
        server_mask = df[server_col].isin(list(servers))

    m = eligible & server_mask
    metrics["n_candidates_initial"] = int(m.sum())
    if not m.any():
        metrics["time_s"] = time.perf_counter() - t0
        return (df, metrics) if return_metrics else df

    # ------------------------------------------------------
    # Prefilter: decide which indices to consider in this stage
    # ------------------------------------------------------
    if prefilter_mode == "title_dup":
        # title-based prefilter (fast for exact title stages)
        t_clean = df.loc[m, title_clean_col] if (add_title_clean_col and title_clean_col in df.columns and df.loc[m, title_clean_col].notna().any()) else None
        if t_clean is None:
            t_clean = _clean_title_series_v2(df.loc[m, title_col])
        vc = t_clean.value_counts()
        keep_idx = t_clean[t_clean.isin(vc[vc >= 2].index)].index
        metrics["prefilter_groups"] = int((vc >= 2).sum())

    elif prefilter_mode == "author_dup":
        # author-fp based prefilter (crucial for fuzzy pass; titles may differ)
        # compute fp only for m rows
        a_fp = build_authors_fingerprint_series(df.loc[m, authors_col], mode=authors_fp_mode)
        vc = a_fp.value_counts()
        keep_idx = a_fp[a_fp.isin(vc[vc >= 2].index)].index
        metrics["prefilter_groups"] = int((vc >= 2).sum())

    elif prefilter_mode == "none":
        keep_idx = df.index[m]
        metrics["prefilter_groups"] = 0

    else:
        raise ValueError("prefilter_mode must be title_dup | author_dup | none")

    metrics["prefilter_rows"] = int(len(keep_idx))
    if len(keep_idx) == 0:
        metrics["time_s"] = time.perf_counter() - t0
        return (df, metrics) if return_metrics else df

    # ------------------------------------------------------
    # Work subset + compute/attach cached normalization keys
    # ------------------------------------------------------
    cols_needed = [server_col, record_id_col, title_col, authors_col]
    if use_year:
        cols_needed.append(year_col)
    date_col = _pick_first_existing(df, date_candidates)
    if date_col:
        cols_needed.append(date_col)

    work = df.loc[keep_idx, cols_needed].copy()

    # Title clean (cache to df if asked)
    if add_title_clean_col:
        # compute for missing only (cheap)
        t_missing = df.loc[work.index, title_clean_col].isna()
        if t_missing.any():
            df.loc[work.index[t_missing], title_clean_col] = _clean_title_series_v2(df.loc[work.index[t_missing], title_col]).values
        work["_t"] = df.loc[work.index, title_clean_col].astype("string").fillna("")
    else:
        work["_t"] = _clean_title_series_v2(work[title_col])

    # Authors fp (mode-specific; cache into df column if asked)
    work["_a_fp"] = build_authors_fingerprint_series(work[authors_col], mode=authors_fp_mode)
    if add_authors_fingerprint_col:
        df.loc[work.index, authors_fingerprint_col] = work["_a_fp"].values

    # Year (optional)
    if use_year:
        y = pd.to_numeric(work[year_col], errors="coerce")
        y = y.where((y >= 1000) & (y <= 3000)).round().astype("Int64")
        work["_y"] = y
    else:
        work["_y"] = pd.NA

    # require non-empty keys
    if use_year:
        work = work[(work["_t"] != "") & (work["_a_fp"] != "") & work["_y"].notna()].copy()
    else:
        work = work[(work["_t"] != "") & (work["_a_fp"] != "")].copy()

    metrics["work_rows_after_keys"] = int(len(work))
    if work.empty:
        metrics["time_s"] = time.perf_counter() - t0
        return (df, metrics) if return_metrics else df

    # ------------------------------------------------------
    # Stage A STRICT: exact match on (title_clean + authors_fp [+year] [+server scope])
    # ------------------------------------------------------
    if use_year:
        strict_base = work["_t"] + "||" + work["_a_fp"] + "||" + work["_y"].astype("string")
    else:
        strict_base = work["_t"] + "||" + work["_a_fp"]

    if across_servers:
        work["_grp_strict"] = strict_base
    else:
        work["_grp_strict"] = work[server_col].astype("string") + "||" + strict_base

    strict = work
    if prefilter:
        vcg = work["_grp_strict"].value_counts()
        dup_keys = vcg[vcg >= 2].index
        strict = work[work["_grp_strict"].isin(dup_keys)].copy()

    metrics["stageA_groups"] = int(strict["_grp_strict"].nunique()) if not strict.empty else 0

    # sort keys for parent choice
    if date_col and date_col in strict.columns:
        strict["_dt"] = pd.to_datetime(strict[date_col], errors="coerce")
    else:
        strict["_dt"] = pd.NaT
    strict["_rid"] = _record_id_key(strict[record_id_col])

    if not strict.empty:
        if choose_parent == "oldest":
            strict = strict.sort_values(
                by=["_grp_strict", "_dt", "_rid"],
                ascending=[True, True, True],
                na_position="last",
            )
        elif choose_parent == "most_recent":
            strict = strict.sort_values(
                by=["_grp_strict", "_dt", "_rid"],
                ascending=[True, False, False],
                na_position="last",
            )
        else:
            raise ValueError("choose_parent must be oldest | most_recent")

        parents = strict.groupby("_grp_strict", sort=False).head(1)
        parent_rid_map = parents.set_index("_grp_strict")[record_id_col]
        parent_srv_map = parents.set_index("_grp_strict")[server_col]

        strict["_parent_rid"] = strict["_grp_strict"].map(parent_rid_map)
        strict["_parent_srv"] = strict["_grp_strict"].map(parent_srv_map)

        is_parent = strict[record_id_col].eq(strict["_parent_rid"])
        parent_idx = strict.index[is_parent]
        child_idx = strict.index[~is_parent]

        metrics["stageA_children_labeled"] = int(len(child_idx))

        df.loc[parent_idx, hierarchy_col] = "parent"
        df.loc[parent_idx, parent_id_col] = pd.NA
        df.loc[child_idx, hierarchy_col] = (
            "parent - duplicate (" + strict.loc[child_idx, "_parent_srv"].astype("string") + ")"
        )
        df.loc[child_idx, parent_id_col] = strict.loc[child_idx, "_parent_rid"].values

        # deterministic group id
        df.loc[strict.index, group_id_col] = (
            pd.util.hash_pandas_object(strict["_grp_strict"], index=False)
            .astype("uint64")
            .astype(str)
            .values
        )

    # ------------------------------------------------------
    # Fuzzy title fallback (BLOCKED by authors_fp [+year], only remaining eligible)
    # Important: this can find near-duplicate titles because we do NOT rely on title_dup.
    # ------------------------------------------------------
    if title_fuzzy_fallback:
        # remaining eligible after Stage A
        h2 = df[hierarchy_col]
        if overwrite_mode == "parent_only":
            eligible2 = h2.astype("string").str.lower().str.strip().eq("parent")
        elif overwrite_mode == "unlabeled_only":
            eligible2 = h2.isna()
        else:
            eligible2 = pd.Series(True, index=df.index)

        remain_idx = work.index.intersection(df.index[eligible2])
        wF = work.loc[remain_idx].copy()

        if not wF.empty:
            # block by authors_fp (+year) because authors are "more trustworthy"
            if use_year:
                wF["_grp_auth"] = wF["_a_fp"] + "||" + wF["_y"].astype("string")
            else:
                wF["_grp_auth"] = wF["_a_fp"]

            # keep only blocks with >=2 rows
            vc_auth = wF["_grp_auth"].value_counts()
            keep_auth = vc_auth[vc_auth >= 2].index
            wF = wF[wF["_grp_auth"].isin(keep_auth)].copy()

            metrics["fuzzy_groups"] = int(wF["_grp_auth"].nunique()) if not wF.empty else 0

            if not wF.empty:
                # date/rid for parent selection
                if date_col and date_col in wF.columns:
                    wF["_dt"] = pd.to_datetime(wF[date_col], errors="coerce")
                else:
                    wF["_dt"] = pd.NaT
                wF["_rid"] = _record_id_key(wF[record_id_col])

                # tokens cache per row (within this stage)
                tokens_map = {idx: _title_tokens_from_clean(wF.loc[idx, "_t"]) for idx in wF.index}

                for grp, g in wF.groupby("_grp_auth", sort=False):
                    if len(g) < 2:
                        continue

                    # gate: ignore titles with too few tokens
                    idxs = [idx for idx in g.index if len(tokens_map.get(idx, [])) >= min_title_tokens]
                    if len(idxs) < 2:
                        continue

                    gg = g.loc[idxs].copy()
                    if choose_parent == "oldest":
                        gg = gg.sort_values(by=["_dt", "_rid"], ascending=[True, True], na_position="last")
                    else:
                        gg = gg.sort_values(by=["_dt", "_rid"], ascending=[False, False], na_position="last")

                    if fuzzy_compare_strategy == "parent_only":
                        parent_idx = gg.index[0]
                        parent_tokens = tokens_map[parent_idx]
                        parent_rid = gg.loc[parent_idx, record_id_col]
                        parent_srv = gg.loc[parent_idx, server_col]

                        # ensure parent labeled
                        df.loc[parent_idx, hierarchy_col] = "parent"
                        df.loc[parent_idx, parent_id_col] = pd.NA

                        for idx in gg.index[1:]:
                            metrics["fuzzy_pairs_checked"] += 1
                            sc = _containment_score(parent_tokens, tokens_map[idx])
                            if sc >= min_title_containment:
                                df.loc[idx, hierarchy_col] = f"parent - duplicate ({parent_srv})"
                                df.loc[idx, parent_id_col] = parent_rid
                                df.loc[idx, group_id_col] = f"fuzzy::{authors_fp_mode}::{grp}"
                                metrics["fuzzy_children_labeled"] += 1

                    elif fuzzy_compare_strategy == "all_pairs_small":
                        # safer than global all-pairs; still can be heavy if blocks are large.
                        # We'll cluster by greedy expansion (bounded within block).
                        idxs2 = gg.index.tolist()
                        used = set()
                        for i in idxs2:
                            if i in used:
                                continue
                            used.add(i)
                            cluster = [i]
                            for j in idxs2:
                                if j in used:
                                    continue
                                metrics["fuzzy_pairs_checked"] += 1
                                sc = _containment_score(tokens_map[i], tokens_map[j])
                                if sc >= min_title_containment:
                                    used.add(j)
                                    cluster.append(j)

                            if len(cluster) >= 2:
                                # choose parent (oldest/most recent) within cluster
                                cldf = gg.loc[cluster].copy()
                                if choose_parent == "oldest":
                                    cldf = cldf.sort_values(by=["_dt", "_rid"], ascending=[True, True], na_position="last")
                                else:
                                    cldf = cldf.sort_values(by=["_dt", "_rid"], ascending=[False, False], na_position="last")

                                p_idx = cldf.index[0]
                                p_rid = cldf.loc[p_idx, record_id_col]
                                p_srv = cldf.loc[p_idx, server_col]
                                df.loc[p_idx, hierarchy_col] = "parent"
                                df.loc[p_idx, parent_id_col] = pd.NA
                                for cidx in cldf.index[1:]:
                                    df.loc[cidx, hierarchy_col] = f"parent - duplicate ({p_srv})"
                                    df.loc[cidx, parent_id_col] = p_rid
                                    df.loc[cidx, group_id_col] = f"fuzzy::{authors_fp_mode}::{grp}"
                                    metrics["fuzzy_children_labeled"] += 1
                    else:
                        raise ValueError("fuzzy_compare_strategy must be parent_only | all_pairs_small")

    # ------------------------------------------------------
    # Stage B RELAXED (shared authors overlap) within exact title groups
    # ------------------------------------------------------
    if relaxed_shared_authors:
        h3 = df[hierarchy_col]
        if overwrite_mode == "parent_only":
            eligible3 = h3.astype("string").str.lower().str.strip().eq("parent")
        elif overwrite_mode == "unlabeled_only":
            eligible3 = h3.isna()
        else:
            eligible3 = pd.Series(True, index=df.index)

        remain_idx = work.index.intersection(df.index[eligible3])
        w2 = work.loc[remain_idx].copy()
        if not w2.empty:
            if use_year:
                relaxed_base = w2["_t"] + "||" + w2["_y"].astype("string")
            else:
                relaxed_base = w2["_t"]

            if across_servers:
                w2["_grp_title"] = relaxed_base
            else:
                w2["_grp_title"] = w2[server_col].astype("string") + "||" + relaxed_base

            # keep only repeated titles
            vc2 = w2["_grp_title"].value_counts()
            keep_groups = vc2[vc2 >= 2].index
            w2 = w2[w2["_grp_title"].isin(keep_groups)].copy()

            metrics["stageB_title_groups"] = int(w2["_grp_title"].nunique()) if not w2.empty else 0

            if not w2.empty:
                w2["_a_tokens"] = w2["_a_fp"].apply(_author_tokens_from_fp)
                w2["_a_n"] = w2["_a_tokens"].apply(len)

                if date_col and date_col in w2.columns:
                    w2["_dt"] = pd.to_datetime(w2[date_col], errors="coerce")
                else:
                    w2["_dt"] = pd.NaT
                w2["_rid"] = _record_id_key(w2[record_id_col])

                group_counter = 0
                children_total = 0

                for grp, g in w2.groupby("_grp_title", sort=False):
                    if len(g) < 2:
                        continue

                    g = g[g["_a_n"] >= min_authors_required].copy()
                    if len(g) < 2:
                        continue

                    idxs = g.index.tolist()
                    used = set()
                    clusters = []

                    # simple greedy clustering based on author overlap
                    for i in idxs:
                        if i in used:
                            continue
                        used.add(i)
                        cl = [i]
                        for j in idxs:
                            if j in used:
                                continue
                            if _overlap_count(g.loc[i, "_a_tokens"], g.loc[j, "_a_tokens"]) >= min_shared_authors:
                                used.add(j)
                                cl.append(j)
                        if len(cl) >= 2:
                            clusters.append(cl)

                    for cl in clusters:
                        group_counter += 1
                        cldf = g.loc[cl].copy()
                        if choose_parent == "oldest":
                            cldf = cldf.sort_values(by=["_dt", "_rid"], ascending=[True, True], na_position="last")
                        else:
                            cldf = cldf.sort_values(by=["_dt", "_rid"], ascending=[False, False], na_position="last")

                        parent_idx = cldf.index[0]
                        parent_rid = cldf.loc[parent_idx, record_id_col]
                        parent_srv = cldf.loc[parent_idx, server_col]

                        df.loc[parent_idx, hierarchy_col] = "parent"
                        df.loc[parent_idx, parent_id_col] = pd.NA
                        df.loc[parent_idx, group_id_col] = f"relaxed::{stage_name}::{group_counter}"

                        child_idxs = [x for x in cldf.index if x != parent_idx]
                        children_total += len(child_idxs)

                        df.loc[child_idxs, hierarchy_col] = f"parent - duplicate ({parent_srv})"
                        df.loc[child_idxs, parent_id_col] = parent_rid
                        df.loc[child_idxs, group_id_col] = f"relaxed::{stage_name}::{group_counter}"

                metrics["stageB_clusters"] = int(group_counter)
                metrics["stageB_children_labeled"] = int(children_total)

    metrics["time_s"] = time.perf_counter() - t0
    return (df, metrics) if return_metrics else df


# ============================================================
# 5) Stage runner with summary + early stop
# ============================================================
def _count_children_labels(series: pd.Series) -> int:
    s = series.astype("string").fillna("")
    return int(s.str.startswith("parent - duplicate").sum())


def run_dedupe_stages(
    df: pd.DataFrame,
    *,
    stages: List[Dict[str, Any]],
    early_stop_if_new_labels_lt: int = 100,
    print_summary: bool = True,
    return_all_metrics: bool = True,
    # common kwargs passed to every stage
    **common_kwargs,
) -> Tuple[pd.DataFrame, List[Dict[str, Any]]] | pd.DataFrame:
    """
    Runs a list of stages sequentially with:
      - delta duplicates added per stage
      - early stop
    """
    df_out = df
    metrics_all: List[Dict[str, Any]] = []

    prev_children = _count_children_labels(df_out[common_kwargs.get("hierarchy_col", "records_hierarchy")])

    for stage in stages:
        name = stage.get("name", stage.get("stage_name", "stage"))
        t0 = time.perf_counter()

        df_out, m = dedupe_title_authors_stage(
            df_out,
            return_metrics=True,
            stage_name=name,
            **common_kwargs,
            **{k: v for k, v in stage.items() if k not in {"name", "stage_name"}},
        )

        now_children = _count_children_labels(df_out[common_kwargs.get("hierarchy_col", "records_hierarchy")])
        delta = now_children - prev_children
        prev_children = now_children

        m["stage_runtime_s"] = time.perf_counter() - t0
        m["new_children_added"] = int(delta)
        metrics_all.append(m)

        if print_summary:
            print(
                f"[{name}] new_children={delta} | "
                f"cand={m['n_candidates_initial']} | "
                f"prefilter_rows={m['prefilter_rows']} | "
                f"A_children={m['stageA_children_labeled']} | "
                f"fuzzy_children={m['fuzzy_children_labeled']} | "
                f"B_children={m['stageB_children_labeled']} | "
                f"time={m['stage_runtime_s']:.2f}s"
            )

        if delta < early_stop_if_new_labels_lt:
            if print_summary:
                print(f"Early stop after {name}: delta {delta} < {early_stop_if_new_labels_lt}")
            break

    return (df_out, metrics_all) if return_all_metrics else df_out


# ============================================================
# 6) Two-pass pipeline: Exact pass -> Fuzzy pass on remaining parents
# ============================================================
def run_dedupe_pipeline_two_passes(
    df: pd.DataFrame,
    *,
    stages_exact: List[Dict[str, Any]],
    stages_fuzzy: List[Dict[str, Any]],
    early_stop_if_new_labels_lt: int = 100,
    print_summary: bool = True,
    return_all_metrics: bool = True,
    **common_kwargs,
) -> Tuple[pd.DataFrame, List[Dict[str, Any]]] | pd.DataFrame:
    """
    Pass A: run stages_exact (typically no fuzzy, prefilter_mode=title_dup).
    Pass B: run stages_fuzzy (fuzzy enabled, prefilter_mode=author_dup), on remaining parents only.

    IMPORTANT:
      - For Pass A, it is normal to use overwrite_mode="any" for stage1, then "parent_only" for stage2-3.
      - For Pass B, use overwrite_mode="parent_only" so we only touch unresolved parents.
    """
    all_metrics: List[Dict[str, Any]] = []
    df_out = df

    if print_summary:
        print("\n=== PASS A: EXACT ===")

    df_out, mA = run_dedupe_stages(
        df_out,
        stages=stages_exact,
        early_stop_if_new_labels_lt=early_stop_if_new_labels_lt,
        print_summary=print_summary,
        return_all_metrics=True,
        **common_kwargs,
    )
    all_metrics.extend(mA)

    if print_summary:
        print("\n=== PASS B: FUZZY (remaining parents) ===")

    df_out, mB = run_dedupe_stages(
        df_out,
        stages=stages_fuzzy,
        early_stop_if_new_labels_lt=early_stop_if_new_labels_lt,
        print_summary=print_summary,
        return_all_metrics=True,
        **common_kwargs,
    )
    all_metrics.extend(mB)

    return (df_out, all_metrics) if return_all_metrics else df_out


# ============================================================
# 7) Default stage configs (recommended)
# ============================================================

# PASS A (EXACT) — fast + high precision
STAGES_EXACT = [
    dict(
        name="A1_tokenbag_exact",
        authors_fp_mode="tokenbag",
        prefilter_mode="title_dup",
        title_fuzzy_fallback=False,
        relaxed_shared_authors=True,
        min_authors_required=1,
        min_shared_authors=1,
        overwrite_mode="parent_only",
        authors_fingerprint_col="authors_fp_tokenbag",
    ),
    dict(
        name="A2_last_initial_exact",
        authors_fp_mode="last_initial",
        prefilter_mode="title_dup",
        title_fuzzy_fallback=False,
        relaxed_shared_authors=True,
        min_authors_required=1,
        min_shared_authors=1,
        overwrite_mode="parent_only",
        authors_fingerprint_col="authors_fp_last_initial",
    ),
    dict(
        name="A3_last_exact_strict",
        authors_fp_mode="last",
        prefilter_mode="title_dup",
        title_fuzzy_fallback=False,
        relaxed_shared_authors=False,  # last-only already high recall; keep strict
        overwrite_mode="parent_only",
        authors_fingerprint_col="authors_fp_last",
    ),
]

# PASS B (FUZZY) — only remaining parents; block by authors_fp repetition
# Note: relaxed_shared_authors is usually OFF here to keep false positives down.
STAGES_FUZZY = [
    dict(
        name="B1_tokenbag_fuzzy",
        authors_fp_mode="tokenbag",
        prefilter_mode="author_dup",
        title_fuzzy_fallback=True,
        min_title_tokens=6,
        min_title_containment=0.75,  # start conservative; lower = more recall, more risk
        fuzzy_compare_strategy="parent_only",
        relaxed_shared_authors=False,
        # min_authors_required=1,
        # min_shared_authors=1,
        overwrite_mode="parent_only",
        authors_fingerprint_col="authors_fp_tokenbag",
    ),
    dict(
        name="B2_last_initial_fuzzy",
        authors_fp_mode="last_initial",
        prefilter_mode="author_dup",
        title_fuzzy_fallback=True,
        min_title_tokens=6,
        min_title_containment=0.80,
        fuzzy_compare_strategy="parent_only",
        relaxed_shared_authors=False,
        # min_authors_required=1,
        # min_shared_authors=1,
        overwrite_mode="parent_only",
        authors_fingerprint_col="authors_fp_last_initial",
    ),
]

# ============================================================
# 8) Example usage
# ============================================================
# df_out, metrics = run_dedupe_pipeline_two_passes(
#     df,
#     stages_exact=STAGES_EXACT,
#     stages_fuzzy=STAGES_FUZZY,
#     early_stop_if_new_labels_lt=500,
#     print_summary=True,
#     return_all_metrics=True,
#     servers=None,
#     across_servers=True,
#     use_year=False,
#     choose_parent="oldest",
#     prefilter=True,
#     date_candidates=('date_first_seen',),
#     hierarchy_col="records_hierarchy",
#     parent_id_col="parent_record_id",
#     group_id_col="dup_group_id",
#     add_authors_fingerprint_col=True,
#     add_title_clean_col=True,
#     title_clean_col="title_clean_v2",
# )
#
# print(metrics[-1])
# print(df_out["records_hierarchy"].value_counts(dropna=False).head(60))

# %%
data_out, metrics = run_dedupe_pipeline_two_passes(
    data_clean_hierarchy,
    stages_exact=STAGES_EXACT,
    stages_fuzzy=STAGES_FUZZY,
    early_stop_if_new_labels_lt=1,
    print_summary=True,
    return_all_metrics=True,
    servers=None,
    across_servers=True,
    use_year=False,
    choose_parent="oldest",
    prefilter=True,
    date_candidates=('date_first_seen',),
    hierarchy_col="records_hierarchy",
    parent_id_col="parent_record_id",
    group_id_col="dup_group_id",
    add_authors_fingerprint_col=True,
    add_title_clean_col=True,
    title_clean_col="title_clean_v2",
)

print(metrics[-1])
print(data_out["records_hierarchy"].value_counts(dropna=False).head(60))
# Out:
# === PASS A: EXACT ===
# [A1_tokenbag_exact] new_children=480047 | cand=8410094 | prefilter_rows=1073601 | A_children=406251 | fuzzy_children=0 | B_children=73796 | time=497.49s
# [A2_last_initial_exact] new_children=16338 | cand=7930047 | prefilter_rows=224930 | A_children=13750 | fuzzy_children=0 | B_children=2588 | time=240.06s
# [A3_last_exact_strict] new_children=4202 | cand=7913709 | prefilter_rows=194179 | A_children=4202 | fuzzy_children=0 | B_children=0 | time=5.49s
#
# === PASS B: FUZZY (remaining parents) ===
# [B1_tokenbag_fuzzy] new_children=134485 | cand=7909507 | prefilter_rows=3431714 | A_children=0 | fuzzy_children=134485 | B_children=0 | time=813.40s
# [B2_last_initial_fuzzy] new_children=16318 | cand=7775022 | prefilter_rows=3586018 | A_children=0 | fuzzy_children=16318 | B_children=0 | time=708.43s
# {'stage_name': 'B2_last_initial_fuzzy', 'n_rows_df': 8410094, 'n_candidates_initial': 7775022, 'prefilter_mode': 'author_dup', 'prefilter_rows': 3586018, 'prefilter_groups': 714875, 'work_rows_after_keys': 3352839, 'stageA_groups': 0, 'stageA_children_labeled': 0, 'fuzzy_enabled': True, 'fuzzy_groups': 714859, 'fuzzy_pairs_checked': 2185053, 'fuzzy_children_labeled': 16318, 'stageB_enabled': False, 'stageB_title_groups': 0, 'stageB_clusters': 0, 'stageB_children_labeled': 0, 'time_s': 705.8516967659998, 'stage_runtime_s': 708.4264941470001, 'new_children_added': 16318}
# records_hierarchy
# parent                                                                                       7758704
# parent - duplicate (SSRN)                                                                     119517
# parent - duplicate (Zenodo)                                                                    94805
# parent - duplicate (RePEc: Research Papers in Economics)                                       63302
# parent - duplicate (arXiv)                                                                     55403
# parent - duplicate (Research Square)                                                           47994
# parent - duplicate (bioRxiv)                                                                   33315
# parent - duplicate (HAL)                                                                       28173
# parent - duplicate (eLife)                                                                     20768
# parent - duplicate (Open Science Framework)                                                    20264
# parent - duplicate (ResearchGate)                                                              17592
# parent - duplicate (AgEcon Search)                                                             14408
# parent - duplicate (Humanities Commons CORE)                                                   12728
# parent - duplicate (TechRxiv)                                                                  12197
# parent - duplicate (EGUsphere)                                                                 11990
# parent - duplicate (Preprints.org)                                                             10559
# parent - duplicate (ChemRxiv)                                                                   9481
# parent - duplicate (PsyArXiv)                                                                   8894
# parent - duplicate (EconStor Preprints)                                                         7462
# parent - duplicate (Qeios)                                                                      6627
# parent - duplicate (INA-Rxiv)                                                                   5801
# parent - duplicate (F1000Research)                                                              5648
# parent - duplicate (SocArXiv)                                                                   4484
# parent - duplicate (medRxiv)                                                                    4297
# parent - duplicate (Authorea Inc.)                                                              4255
# parent - duplicate (Earth and Space Science Open Archive)                                       3848
# parent - duplicate (Munich Personal RePEc Archive)                                              3136
# parent - duplicate (DSpace@MIT)                                                                 2151
# parent - duplicate (Nature Precedings)                                                          2103
# parent - duplicate (Advance)                                                                    2021
# parent - duplicate (viXra)                                                                      1555
# parent - duplicate (JMIR Preprints)                                                             1457
# parent - duplicate (PeerJ Preprints)                                                            1339
# parent - duplicate (Wellcome Open Research)                                                     1242
# parent - duplicate (Law Archive)                                                                 916
# parent - duplicate (Cambridge Open Engage)                                                       851
# parent - duplicate (ScienceOpen Preprints)                                                       696
# parent - duplicate (Thesis Commons)                                                              694
# parent - duplicate (EarthArXiv)                                                                  668
# parent - duplicate (Open Research Europe)                                                        648
# parent - duplicate (National Bureau of Economic Research)                                        595
# parent - duplicate (CERN document server)                                                        546
# parent - duplicate (engrXiv)                                                                     468
# parent - duplicate (IACR Cryptology ePrint Archive)                                              439
# parent - duplicate (EdArXiv)                                                                     388
# parent - duplicate (Social Science Open Access Repository)                                       380
# parent - duplicate (HRB Open Research)                                                           354
# parent - duplicate (Covid-19 Preprints)                                                          354
# parent - duplicate (APSA Preprints)                                                              321
# parent - duplicate (Gates Open Research)                                                         321
# parent - duplicate (UCL Open Environment)                                                        298
# parent - duplicate (Digital Access to Scholarship at Harvard (DASH) (Harvard University))        290
# parent - duplicate (ResearchHub)                                                                 250
# parent - duplicate (Organic Eprints)                                                             242
# parent - duplicate (PhilSci-Archive)                                                             241
# parent - duplicate (MetaArXiv)                                                                   229
# parent - duplicate (MarXiv)                                                                      166
# parent - duplicate (LIS Scholarship Archive)                                                     163
# parent - duplicate (CrimRxiv)                                                                    143
# parent - duplicate (AgriRxiv)                                                                    142
# Name: count, dtype: int64

# %%
from pathlib import Path
import json
import pandas as pd

OUT_DIR = Path("outputs_new")
OUT_DIR.mkdir(parents=True, exist_ok=True)

# Save metrics
with open(OUT_DIR / "dedupe_metrics.json", "w") as f:
    json.dump(metrics, f, indent=2)

pd.DataFrame(metrics).to_csv(OUT_DIR / "dedupe_metrics.csv", index=False)

# Save dataset
data_out.to_parquet(OUT_DIR / "dedupe_data_out.parquet", index=False)

print("✅ All files saved to outputs/")
# Out:
# ✅ All files saved to outputs/

# %%
from pathlib import Path

OUT_DIR = Path("outputs_new")
OUT_DIR.mkdir(exist_ok=True)

new_cols = [
    "records_hierarchy_backup",
    "records_hierarchy",
    "parent_record_id",
    "dup_group_id",
    "authors_fp_tokenbag",
    "authors_fp_last_initial",
    "authors_fp_last",
    "title_clean_v2",
]
# original_cols = set(df.columns)

# detect new columns
# new_cols = [c for c in data_out.columns if c not in original_cols]

cols_to_save = ["record_id"] + new_cols

data_out[cols_to_save].to_parquet(
    OUT_DIR / "dedupe_data_out_new_cols.parquet",
    index=False
)
data_out[cols_to_save].to_csv(
    OUT_DIR / "dedupe_data_out_new_cols.csv",
    index=False
)
print("✅ Saved:", cols_to_save)
# Out:
# ✅ Saved: ['record_id', 'records_hierarchy_backup', 'records_hierarchy', 'parent_record_id', 'dup_group_id', 'authors_fp_tokenbag', 'authors_fp_last_initial', 'authors_fp_last', 'title_clean_v2']

# %%
metrics
# Out:
# [{'stage_name': 'A1_tokenbag_exact',
#   'n_rows_df': 8410094,
#   'n_candidates_initial': 8410094,
#   'prefilter_mode': 'title_dup',
#   'prefilter_rows': 1073601,
#   'prefilter_groups': 421611,
#   'work_rows_after_keys': 998989,
#   'stageA_groups': 320136,
#   'stageA_children_labeled': 406251,
#   'fuzzy_enabled': False,
#   'fuzzy_groups': 0,
#   'fuzzy_pairs_checked': 0,
#   'fuzzy_children_labeled': 0,
#   'stageB_enabled': True,
#   'stageB_title_groups': 105969,
#   'stageB_clusters': 71232,
#   'stageB_children_labeled': 73796,
#   'time_s': 495.854478934,
#   'stage_runtime_s': 497.49351292999995,
#   'new_children_added': 480047},
#  {'stage_name': 'A2_last_initial_exact',
#   'n_rows_df': 8410094,
#   'n_candidates_initial': 7930047,
#   'prefilter_mode': 'title_dup',
#   'prefilter_rows': 224930,
#   'prefilter_groups': 52987,
#   'work_rows_after_keys': 146423,
#   'stageA_groups': 12908,
#   'stageA_children_labeled': 13750,
#   'fuzzy_enabled': False,
#   'fuzzy_groups': 0,
#   'fuzzy_pairs_checked': 0,
#   'fuzzy_children_labeled': 0,
#   'stageB_enabled': True,
#   'stageB_title_groups': 21845,
#   'stageB_clusters': 2577,
#   'stageB_children_labeled': 2588,
#   'time_s': 239.02393281900004,
#   'stage_runtime_s': 240.06043285700002,
#   'new_children_added': 16338},
#  {'stage_name': 'A3_last_exact_strict',
#   'n_rows_df': 8410094,
#   'n_candidates_initial': 7913709,
#   'prefilter_mode': 'title_dup',
#   'prefilter_rows': 194179,
#   'prefilter_groups': 38574,
#   'work_rows_after_keys': 119377,
#   'stageA_groups': 2527,
#   'stageA_children_labeled': 4202,
#   'fuzzy_enabled': False,
#   'fuzzy_groups': 0,
#   'fuzzy_pairs_checked': 0,
#   'fuzzy_children_labeled': 0,
#   'stageB_enabled': False,
#   'stageB_title_groups': 0,
#   'stageB_clusters': 0,
#   'stageB_children_labeled': 0,
#   'time_s': 4.545115248999991,
#   'stage_runtime_s': 5.490449008000041,
#   'new_children_added': 4202},
#  {'stage_name': 'B1_tokenbag_fuzzy',
#   'n_rows_df': 8410094,
#   'n_candidates_initial': 7909507,
#   'prefilter_mode': 'author_dup',
#   'prefilter_rows': 3431714,
#   'prefilter_groups': 799559,
#   'work_rows_after_keys': 3216117,
#   'stageA_groups': 0,
#   'stageA_children_labeled': 0,
#   'fuzzy_enabled': True,
#   'fuzzy_groups': 799535,
#   'fuzzy_pairs_checked': 1988591,
#   'fuzzy_children_labeled': 134485,
#   'stageB_enabled': False,
#   'stageB_title_groups': 0,
#   'stageB_clusters': 0,
#   'stageB_children_labeled': 0,
#   'time_s': 811.3266194339999,
#   'stage_runtime_s': 813.4017950309999,
#   'new_children_added': 134485},
#  {'stage_name': 'B2_last_initial_fuzzy',
#   'n_rows_df': 8410094,
#   'n_candidates_initial': 7775022,
#   'prefilter_mode': 'author_dup',
#   'prefilter_rows': 3586018,
#   'prefilter_groups': 714875,
#   'work_rows_after_keys': 3352839,
#   'stageA_groups': 0,
#   'stageA_children_labeled': 0,
#   'fuzzy_enabled': True,
#   'fuzzy_groups': 714859,
#   'fuzzy_pairs_checked': 2185053,
#   'fuzzy_children_labeled': 16318,
#   'stageB_enabled': False,
#   'stageB_title_groups': 0,
#   'stageB_clusters': 0,
#   'stageB_children_labeled': 0,
#   'time_s': 705.8516967659998,
#   'stage_runtime_s': 708.4264941470001,
#   'new_children_added': 16318}]

# %%
data_out
# Out:
#                                record_id     server_name   backend  \
# 0        crossref::10.21467/preprints.48  AIJR Preprints  crossref
# 1        crossref::10.21467/preprints.43  AIJR Preprints  crossref
# 2        crossref::10.21467/preprints.39  AIJR Preprints  crossref
# 3        crossref::10.21467/preprints.38  AIJR Preprints  crossref
# 4        crossref::10.21467/preprints.36  AIJR Preprints  crossref
# ...                                  ...             ...       ...
# 8410089             openalex::W999325625           viXra  openalex
# 8410090             openalex::W999460032           viXra  openalex
# 8410091              openalex::W99967155           viXra  openalex
# 8410092             openalex::W999790414           viXra  openalex
# 8410093             openalex::W999805801           viXra  openalex
#
#                            doi                                doi_url  \
# 0        10.21467/preprints.48  https://doi.org/10.21467/preprints.48
# 1        10.21467/preprints.43  https://doi.org/10.21467/preprints.43
# 2        10.21467/preprints.39  https://doi.org/10.21467/preprints.39
# 3        10.21467/preprints.38  https://doi.org/10.21467/preprints.38
# 4        10.21467/preprints.36  https://doi.org/10.21467/preprints.36
# ...                        ...                                    ...
# 8410089                   None                                   None
# 8410090                   None                                   None
# 8410091                   None                                   None
# 8410092                   None                                   None
# 8410093                   None                                   None
#
#                                           landing_page_url  \
# 0        https://preprints.aijr.org/index.php/ap/prepri...
# 1        https://preprints.aijr.org/index.php/ap/prepri...
# 2        https://preprints.aijr.org/index.php/ap/prepri...
# 3        https://preprints.aijr.org/index.php/ap/prepri...
# 4        https://preprints.aijr.org/index.php/ap/prepri...
# ...                                                    ...
# 8410089              https://vixra.org/pdf/1409.0090v1.pdf
# 8410090                    https://vixra.org/abs/1112.0094
# 8410091              https://vixra.org/pdf/1406.0019v1.pdf
# 8410092              https://vixra.org/pdf/1306.0105v3.pdf
# 8410093              https://vixra.org/pdf/1412.0197v3.pdf
#
#                                                      title  \
# 0        Bird’s Eye View on the Diagnosis, Treatment, &...
# 1        Doxycycline and Minocycline Drugs as a Treatme...
# 2        A Genetic Perspective of 2019-nCoV in Relation...
# 3        Marine Algae as a Natural Source for Antiviral...
# 4        Possible Prevention of COVID 19 by Using Linol...
# ...                                                    ...
# 8410089                 Three Objections to Modern Physics
# 8410090                               Particle Mass Ratios
# 8410091  Quantum FFF Theory Proposals for Some Unsolved...
# 8410092  Investigation of the Formalism of Particle Dyn...
# 8410093  Electromagnetic Energy and Electromagnetic For...
#
#                                               authors_flat institutions_flat  \
# 0                              Panchalingala, Sai Bhargavi              None
# 1                                         Mostafa, Mohamed              None
# 2                                        Dasgupta, Rimjhim              None
# 3        Musale, Amar S; G., Raja Krishna Kumar; Sapre,...              None
# 4        Subhash, Venkata; G, Raja Krishna Kumar; Sapre...              None
# ...                                                    ...               ...
# 8410089                                      Lubomir Vlcek              None
# 8410090                                         DT Froedge              None
# 8410091                                           Leo Vuyk              None
# 8410092                                        Chi-Yi Chen              None
# 8410093                                    Yu.A. Spirichev              None
#
#         countries_flat relations_json version_label is_version_of  \
# 0                 None           None          None
# 1                 None           None          None
# 2                 None           None          None
# 3                 None           None          None
# 4                 None           None          None
# ...                ...            ...           ...           ...
# 8410089           None           None          None          None
# 8410090           None           None          None          None
# 8410091           None           None          None          None
# 8410092           None           None          None          None
# 8410093           None           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 0                                                              false
# 1                                                              false
# 2                                                              false
# 3                                                              false
# 4                                                              false
# ...                ...          ...        ...                   ...
# 8410089           None         None       None                  None
# 8410090           None         None       None                  None
# 8410091           None         None       None                  None
# 8410092           None         None       None                  None
# 8410093           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 0                             None                None           None
# 1                             None                None           None
# 2                             None                None           None
# 3                             None                None           None
# 4                             None                None           None
# ...                            ...                 ...            ...
# 8410089                       None                None           None
# 8410090                       None                None           None
# 8410091                       None                None           None
# 8410092                       None                None           None
# 8410093                       None                None           None
#
#         raw_relationships_json records_hierarchy date_first_seen  \
# 0                         None            parent      2020-05-03
# 1                         None            parent      2020-04-25
# 2                         None            parent      2020-04-16
# 3                         None            parent      2020-04-15
# 4                         None            parent      2020-04-15
# ...                        ...               ...             ...
# 8410089                   None            parent      2014-09-01
# 8410090                   None            parent      2011-12-01
# 8410091                   None            parent      2014-06-01
# 8410092                   None            parent      2013-06-01
# 8410093                   None            parent      2014-12-01
#
#          publication_year_first_seen records_hierarchy_backup  \
# 0                               2020                   parent
# 1                               2020                   parent
# 2                               2020                   parent
# 3                               2020                   parent
# 4                               2020                   parent
# ...                              ...                      ...
# 8410089                         2014                   parent
# 8410090                         2011                   parent
# 8410091                         2014                   parent
# 8410092                         2013                   parent
# 8410093                         2014                   parent
#
#         parent_record_id dup_group_id authors_fp_tokenbag  \
# 0                   <NA>         <NA>                <NA>
# 1                   <NA>         <NA>     mohamed_mostafa
# 2                   <NA>         <NA>    dasgupta_rimjhim
# 3                   <NA>         <NA>                <NA>
# 4                   <NA>         <NA>                <NA>
# ...                  ...          ...                 ...
# 8410089             <NA>         <NA>       lubomir_vlcek
# 8410090             <NA>         <NA>          dt_froedge
# 8410091             <NA>         <NA>            leo_vuyk
# 8410092             <NA>         <NA>         chen_chi_yi
# 8410093             <NA>         <NA>      a_spirichev_yu
#
#                                             title_clean_v2  \
# 0                                                     <NA>
# 1        doxycycline and minocycline drugs as a treatme...
# 2        a genetic perspective of 2019 ncov in relation...
# 3                                                     <NA>
# 4                                                     <NA>
# ...                                                    ...
# 8410089                 three objections to modern physics
# 8410090                               particle mass ratios
# 8410091  quantum fff theory proposals for some unsolved...
# 8410092  investigation of the formalism of particle dyn...
# 8410093  electromagnetic energy and electromagnetic for...
#
#         authors_fp_last_initial authors_fp_last
# 0                          <NA>            <NA>
# 1                     mostafa|m            <NA>
# 2                    dasgupta|r            <NA>
# 3                          <NA>            <NA>
# 4                          <NA>            <NA>
# ...                         ...             ...
# 8410089                 vlcek|l            <NA>
# 8410090               froedge|d            <NA>
# 8410091                  vuyk|l            <NA>
# 8410092                  chen|c            <NA>
# 8410093             spirichev|y            <NA>
#
# [8410094 rows x 31 columns]

# %%
print(data_out["records_hierarchy_backup"].value_counts(dropna=False).head(60))
# Out:
# records_hierarchy_backup
# parent                              7950093
# review                               175443
# part_of                              149454
# version                              105977
# publish_version                        9351
# mirror (arXiv)                         8286
# mirror (AgEcon Search)                 6702
# child                                  2028
# mirror (ResearchGate)                  1633
# correction                              355
# comment                                 325
# mirror (Zenodo)                         297
# mirror (SSRN)                            36
# mirror (Open Science Framework)          31
# mirror (bioRxiv)                         29
# mirror (Humanities Commons CORE)         24
# others                                   12
# parent_duplicate                          3
# mirror (eLife)                            3
# mirror (Research Square)                  2
# mirror (CERN document server)             2
# mirror (TechRxiv)                         1
# mirror (EarthArXiv)                       1
# mirror (Oroboros Instruments)             1
# mirror (medRxiv)                          1
# mirror (Thesis Commons)                   1
# mirror (SocArXiv)                         1
# mirror (AgriRxiv)                         1
# mirror (Law Archive)                      1
# Name: count, dtype: int64

# %%
print(data_out["parent_record_id"].value_counts(dropna=False).head(60))
# Out:
# parent_record_id
# <NA>                                         7758704
# datacite::10.5281/zenodo.14526038                663
# datacite::10.5281/zenodo.15609432                570
# datacite::10.22004/ag.econ.138684                449
# datacite::10.22004/ag.econ.136112                301
# datacite::10.22004/ag.econ.286599                300
# datacite::10.5281/zenodo.15832876                285
# datacite::10.5281/zenodo.15161515                260
# crossref::10.31219/osf.io/ed2a9                  209
# crossref::10.32388/174914                        183
# datacite::10.5281/zenodo.6784019                 181
# datacite::10.5281/zenodo.15631517                166
# crossref::10.2139/ssrn.2721313                   163
# datacite::10.5281/zenodo.15690627                158
# datacite::10.5281/zenodo.1297654                 140
# datacite::10.5281/zenodo.17172763                127
# datacite::10.5281/zenodo.16684574                118
# datacite::10.22004/ag.econ.286899                117
# crossref::10.21055/preprints-3112061             117
# crossref::10.31219/osf.io/uvpzc                  114
# datacite::10.5281/zenodo.17373284                114
# crossref::10.31219/osf.io/db2e6                  106
# crossref::10.31219/osf.io/9vysc                  106
# datacite::10.13140/rg.2.2.29925.91360/1          106
# datacite::10.22004/ag.econ.349464                105
# datacite::10.22004/ag.econ.268031                100
# crossref::10.31237/osf.io/yex9a                   99
# datacite::10.5281/zenodo.3648511                  99
# datacite::10.22004/ag.econ.268032                 97
# datacite::10.22004/ag.econ.138059                 97
# crossref::10.31219/osf.io/nw79r                   96
# crossref::10.31237/osf.io/f2zda                   95
# datacite::10.5281/zenodo.14599183                 95
# crossref::10.5194/egusphere-2022-294-cec2         92
# datacite::10.5281/zenodo.5805044                  91
# datacite::10.22004/ag.econ.286010                 88
# datacite::10.5281/zenodo.15379806                 87
# datacite::10.22004/ag.econ.136285                 85
# datacite::10.5281/zenodo.14873392                 83
# datacite::10.5281/zenodo.14599184                 80
# datacite::10.22004/ag.econ.369387                 79
# datacite::10.5281/zenodo.8140963                  78
# datacite::10.5281/zenodo.16145049                 77
# datacite::10.48550/arxiv.2506.00106               75
# datacite::10.5281/zenodo.15549944                 74
# crossref::10.21055/preprints-3112015              72
# datacite::10.22004/ag.econ.265989                 70
# datacite::10.5281/zenodo.15164567                 70
# datacite::10.22004/ag.econ.268039                 69
# datacite::10.5281/zenodo.16363016                 69
# datacite::10.22004/ag.econ.296966                 67
# datacite::10.22004/ag.econ.266003                 67
# datacite::10.5281/zenodo.14873391                 66
# datacite::10.22004/ag.econ.296938                 65
# datacite::10.5281/zenodo.16526238                 65
# datacite::10.22004/ag.econ.352028                 65
# datacite::10.5281/zenodo.3818302                  64
# datacite::10.13140/rg.2.2.35502.82245             64
# datacite::10.22004/ag.econ.286061                 61
# datacite::10.22004/ag.econ.268113                 60
# Name: count, dtype: int64

# %%
pattern = "fuzzy::las"

mask = data_out['dup_group_id'].str.contains(pattern, regex=False, na=False)
result = data_out[mask]
print(len(result))
result
# Out:
# 16318
#                                         record_id      server_name   backend  \
# 1210           crossref::10.33774/apsa-2024-xzkc5   APSA Preprints  crossref
# 1695      crossref::10.3897/arphapreprints.e86933  ARPHA Preprints  crossref
# 1750      crossref::10.3897/arphapreprints.e61912  ARPHA Preprints  crossref
# 1964     crossref::10.3897/arphapreprints.e101357  ARPHA Preprints  crossref
# 2144      crossref::10.3897/arphapreprints.e68669  ARPHA Preprints  crossref
# ...                                           ...              ...       ...
# 8398180                     openalex::W2888432452            viXra  openalex
# 8398232                     openalex::W2889056834            viXra  openalex
# 8398923                     openalex::W2902708990            viXra  openalex
# 8403090                     openalex::W2981112927            viXra  openalex
# 8409416                      openalex::W842557919            viXra  openalex
#
#                                     doi  \
# 1210           10.33774/apsa-2024-xzkc5
# 1695      10.3897/arphapreprints.e86933
# 1750      10.3897/arphapreprints.e61912
# 1964     10.3897/arphapreprints.e101357
# 2144      10.3897/arphapreprints.e68669
# ...                                 ...
# 8398180                            None
# 8398232                            None
# 8398923                            None
# 8403090                            None
# 8409416           10.5281/zenodo.813110
#
#                                                 doi_url  \
# 1210           https://doi.org/10.33774/apsa-2024-xzkc5
# 1695      https://doi.org/10.3897/arphapreprints.e86933
# 1750      https://doi.org/10.3897/arphapreprints.e61912
# 1964     https://doi.org/10.3897/arphapreprints.e101357
# 2144      https://doi.org/10.3897/arphapreprints.e68669
# ...                                                 ...
# 8398180                                            None
# 8398232                                            None
# 8398923                                            None
# 8403090                                            None
# 8409416           https://doi.org/10.5281/zenodo.813110
#
#                                           landing_page_url  \
# 1210     https://preprints.apsanet.org/engage/apsa/arti...
# 1695         https://preprints.arphahub.com/article/86933/
# 1750         https://preprints.arphahub.com/article/61912/
# 1964        https://preprints.arphahub.com/article/101357/
# 2144         https://preprints.arphahub.com/article/68669/
# ...                                                    ...
# 8398180              https://vixra.org/pdf/1808.0479v1.pdf
# 8398232              https://vixra.org/pdf/1808.0565v1.pdf
# 8398923              https://vixra.org/pdf/1811.0418v1.pdf
# 8403090              https://vixra.org/pdf/1910.0241v1.pdf
# 8409416              https://vixra.org/pdf/1201.0064v3.pdf
#
#                                                      title  \
# 1210     The Impact of Job Growth and Inflation on Pres...
# 1695     Evidence of plant-soil feedback in South Texas...
# 1750     EcoBank: A flexible database platform for shar...
# 1964     Two new species of the bamboo-feeding planthop...
# 2144     Phrynarachne birudis&amp;nbsp;sp. nov., a new ...
# ...                                                    ...
# 8398180  Optimization of WEDM Parameters for SUPER Ni-7...
# 8398232  The Accelerated Expansion of the Universe is E...
# 8398923  The Thermodynamic Properties of Zero Oscillati...
# 8403090   Energy and Matter Creation - The Poynting Vortex
# 8409416  The Obscure Precession Of Mercury'S Perihelion...
#
#                                               authors_flat  \
# 1210                            Doti, James; Campbell, Tom
# 1695     Bowman, Elizabeth; Plowes, Robert; Gilbert, La...
# 1750     Kim, Hyun Woo; Yoon, Sungsoo; Kim, Mokyoung; S...
# 1964            Li, Hongxing; Yang, Lin; Chen, Xiang-Sheng
# 2144          Im, Jae Seong; Kim, Seung Tae; Lee, Sue Yeon
# ...                                                    ...
# 8398180        Y. Rameswara Reddy; B. Chandra Mohana Reddy
# 8398232                                         Elkin Igor
# 8398923                       Miheeev Sergey Vladimirovich
# 8403090     Richard Lawrence Norman; Jeremy Dunning-Davies
# 8409416                                           R. Wayte
#
#           institutions_flat countries_flat  \
# 1210     Chapman University           None
# 1695                   None           None
# 1750                   None           None
# 1964                   None           None
# 2144                   None           None
# ...                     ...            ...
# 8398180                None           None
# 8398232                None           None
# 8398923                None           None
# 8403090                None           None
# 8409416                None           None
#
#                                             relations_json version_label  \
# 1210                                                  None          None
# 1695     {"is-preprint-of": [{"asserted-by": "subject",...          None
# 1750     {"is-preprint-of": [{"asserted-by": "subject",...          None
# 1964     {"is-preprint-of": [{"asserted-by": "subject",...          None
# 2144                                                  None          None
# ...                                                    ...           ...
# 8398180                                               None          None
# 8398232                                               None          None
# 8398923                                               None          None
# 8403090                                               None          None
# 8409416                                               None          None
#
#         is_version_of               is_preprint_of has_preprint has_review  \
# 1210
# 1695                     10.3897/neobiota.81.86672
# 1750                          10.3897/bdj.9.e61866
# 1964                   10.3897/zookeys.1183.101123
# 2144
# ...               ...                          ...          ...        ...
# 8398180          None                         None         None       None
# 8398232          None                         None         None       None
# 8398923          None                         None         None       None
# 8403090          None                         None         None       None
# 8409416          None                         None         None       None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 1210                    false                       None                None
# 1695                     true                       None                None
# 1750                     true                       None                None
# 1964                     true                       None                None
# 2144                    false                       None                None
# ...                       ...                        ...                 ...
# 8398180                  None                       None                None
# 8398232                  None                       None                None
# 8398923                  None                       None                None
# 8403090                  None                       None                None
# 8409416                  None                       None                None
#
#         update_to_json raw_relationships_json  \
# 1210              None                   None
# 1695              None                   None
# 1750              None                   None
# 1964              None                   None
# 2144              None                   None
# ...                ...                    ...
# 8398180           None                   None
# 8398232           None                   None
# 8398923           None                   None
# 8403090           None                   None
# 8409416           None                   None
#
#                             records_hierarchy date_first_seen  \
# 1210                parent - duplicate (SSRN)      2024-05-29
# 1695     parent - duplicate (Research Square)      2022-06-01
# 1750       parent - duplicate (Authorea Inc.)      2020-12-10
# 1964     parent - duplicate (ARPHA Preprints)      2023-02-06
# 2144     parent - duplicate (ARPHA Preprints)      2021-05-20
# ...                                       ...             ...
# 8398180            parent - duplicate (viXra)      2018-08-01
# 8398232            parent - duplicate (viXra)      2018-08-01
# 8398923            parent - duplicate (viXra)      2018-11-01
# 8403090     parent - duplicate (ResearchGate)      2019-10-01
# 8409416           parent - duplicate (Zenodo)      2017-06-19
#
#          publication_year_first_seen records_hierarchy_backup  \
# 1210                            2024                   parent
# 1695                            2022                   parent
# 1750                            2020                   parent
# 1964                            2023                   parent
# 2144                            2021                   parent
# ...                              ...                      ...
# 8398180                         2018                   parent
# 8398232                         2018                   parent
# 8398923                         2018                   parent
# 8403090                         2019                   parent
# 8409416                         2017                   parent
#
#                                     parent_record_id  \
# 1210                  crossref::10.2139/ssrn.4657592
# 1695            crossref::10.21203/rs.3.rs-668160/v1
# 1750     crossref::10.22541/au.160490531.17626170/v1
# 1964        crossref::10.3897/arphapreprints.e100712
# 2144         crossref::10.3897/arphapreprints.e67978
# ...                                              ...
# 8398180                        openalex::W2888102254
# 8398232                        openalex::W2888326560
# 8398923                        openalex::W2900995111
# 8403090        datacite::10.13140/rg.2.2.21002.16329
# 8409416               datacite::10.5281/zenodo.61179
#
#                                               dup_group_id  \
# 1210                fuzzy::last_initial::campbell|t;doti|j
# 1695      fuzzy::last_initial::bowman|e;gilbert|l;plowes|r
# 1750     fuzzy::last_initial::kim|h;kim|k;kim|m;shin|m;...
# 1964               fuzzy::last_initial::chen|x;li|h;yang|l
# 2144                 fuzzy::last_initial::im|j;kim|s;lee|s
# ...                                                    ...
# 8398180               fuzzy::last_initial::reddy|b;reddy|y
# 8398232                        fuzzy::last_initial::igor|e
# 8398923               fuzzy::last_initial::vladimirovich|m
# 8403090             fuzzy::last_initial::davies|j;norman|r
# 8409416                       fuzzy::last_initial::wayte|r
#
#                                    authors_fp_tokenbag  \
# 1210                           campbell_tom;doti_james
# 1695                                              <NA>
# 1750                                              <NA>
# 1964                                              <NA>
# 2144                                              <NA>
# ...                                                ...
# 8398180                                           <NA>
# 8398232                                     elkin_igor
# 8398923                                           <NA>
# 8403090  davies_dunning_jeremy;lawrence_norman_richard
# 8409416                                        r_wayte
#
#                                             title_clean_v2  \
# 1210     the impact of job growth and inflation on pres...
# 1695     evidence of plant soil feedback in south texas...
# 1750     ecobank a flexible database platform for shari...
# 1964     two new species of the bamboo feeding planthop...
# 2144     phrynarachne birudis amp nbsp sp nov a new cra...
# ...                                                    ...
# 8398180  optimization of wedm parameters for super ni 7...
# 8398232  the accelerated expansion of the universe is e...
# 8398923  the thermodynamic properties of zero oscillati...
# 8403090     energy and matter creation the poynting vortex
# 8409416  the obscure precession of mercury s perihelion...
#
#                         authors_fp_last_initial authors_fp_last
# 1210                          campbell|t;doti|j            <NA>
# 1695                bowman|e;gilbert|l;plowes|r            <NA>
# 1750     kim|h;kim|k;kim|m;shin|m;yoon|h;yoon|s            <NA>
# 1964                         chen|x;li|h;yang|l            <NA>
# 2144                           im|j;kim|s;lee|s            <NA>
# ...                                         ...             ...
# 8398180                         reddy|b;reddy|y            <NA>
# 8398232                                  igor|e            <NA>
# 8398923                         vladimirovich|m            <NA>
# 8403090                       davies|j;norman|r            <NA>
# 8409416                                 wayte|r            <NA>
#
# [16318 rows x 31 columns]

# %%
result['relations_json'][281751]
# Out:
# '{"is-preprint-of": [{"asserted-by": "subject", "id": "10.1021/acs.chemmater.1c03349", "id-type": "doi"}]}'

# %%
data_out[data_out["record_id"]=='crossref::10.26434/chemrxiv-2021-cj17s']
# Out:
#                                      record_id server_name   backend  \
# 281806  crossref::10.26434/chemrxiv-2021-cj17s    ChemRxiv  crossref
#
#                                  doi  \
# 281806  10.26434/chemrxiv-2021-cj17s
#
#                                              doi_url  \
# 281806  https://doi.org/10.26434/chemrxiv-2021-cj17s
#
#                                          landing_page_url  \
# 281806  https://chemrxiv.org/engage/chemrxiv/article-d...
#
#                                                     title  \
# 281806  First-Principles Plane-Wave-Based Exploration ...
#
#                                              authors_flat  \
# 281806  Ertural, Christina; Stoffel, Ralf; Müller, Pet...
#
#              institutions_flat countries_flat relations_json version_label  \
# 281806  RWTH Aachen University           None           None          None
#
#        is_version_of is_preprint_of has_preprint has_review  \
# 281806
#
#        has_published_version published_version_ids_json version_of_ids_json  \
# 281806                 false                       None                None
#
#        update_to_json raw_relationships_json records_hierarchy  \
# 281806           None                   None            parent
#
#        date_first_seen  publication_year_first_seen records_hierarchy_backup  \
# 281806      2021-07-26                         2021                   parent
#
#        parent_record_id dup_group_id authors_fp_tokenbag  \
# 281806             <NA>         <NA>                <NA>
#
#                                            title_clean_v2  \
# 281806  first principles plane wave based exploration ...
#
#                                   authors_fp_last_initial authors_fp_last
# 281806  dronskowski|r;ertural|c;muller|p;stoffel|r;vogt|c            <NA>

# %%
data_out[data_out["parent_record_id"]=='crossref::10.26434/chemrxiv-2022-fd190']
# Out:
#                                         record_id server_name   backend  \
# 282821  crossref::10.26434/chemrxiv-2022-fd190-v2    ChemRxiv  crossref
# 282876  crossref::10.26434/chemrxiv-2022-fd190-v3    ChemRxiv  crossref
# 282883  crossref::10.26434/chemrxiv-2022-fd190-v4    ChemRxiv  crossref
# 283800  crossref::10.26434/chemrxiv-2022-fd190-v5    ChemRxiv  crossref
# 309786  crossref::10.26434/chemrxiv-2022-fd190-v6    ChemRxiv  crossref
#
#                                     doi  \
# 282821  10.26434/chemrxiv-2022-fd190-v2
# 282876  10.26434/chemrxiv-2022-fd190-v3
# 282883  10.26434/chemrxiv-2022-fd190-v4
# 283800  10.26434/chemrxiv-2022-fd190-v5
# 309786  10.26434/chemrxiv-2022-fd190-v6
#
#                                                 doi_url  \
# 282821  https://doi.org/10.26434/chemrxiv-2022-fd190-v2
# 282876  https://doi.org/10.26434/chemrxiv-2022-fd190-v3
# 282883  https://doi.org/10.26434/chemrxiv-2022-fd190-v4
# 283800  https://doi.org/10.26434/chemrxiv-2022-fd190-v5
# 309786  https://doi.org/10.26434/chemrxiv-2022-fd190-v6
#
#                                          landing_page_url  \
# 282821  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282876  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282883  https://chemrxiv.org/engage/chemrxiv/article-d...
# 283800  https://chemrxiv.org/engage/chemrxiv/article-d...
# 309786  https://chemrxiv.org/engage/chemrxiv/article-d...
#
#                                                     title  \
# 282821  Selectivity and Intrinsic Activity of Function...
# 282876  Selectivity and Intrinsic Activity of Function...
# 282883  Selectivity and Intrinsic Activity of Function...
# 283800  Selectivity and Intrinsic Activity of Function...
# 309786  Can the CO2 Reduction Reaction be Improved on ...
#
#                                              authors_flat  \
# 282821  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
# 282876  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
# 282883  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
# 283800  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
# 309786  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
#
#                                   institutions_flat countries_flat  \
# 282821  University of Copenhagen; Aarhus University           None
# 282876  University of Copenhagen; Aarhus University           None
# 282883  University of Copenhagen; Aarhus University           None
# 283800  University of Copenhagen; Aarhus University           None
# 309786  University of Copenhagen; Aarhus University           None
#
#                                            relations_json version_label  \
# 282821  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282876  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282883  {"is-version-of": [{"asserted-by": "subject", ...          None
# 283800  {"is-version-of": [{"asserted-by": "subject", ...          None
# 309786  {"is-preprint-of": [{"asserted-by": "subject",...          None
#
#                                             is_version_of  \
# 282821                       10.26434/chemrxiv-2022-fd190
# 282876  10.26434/chemrxiv-2022-fd190;10.26434/chemrxiv...
# 282883  10.26434/chemrxiv-2022-fd190;10.26434/chemrxiv...
# 283800  10.26434/chemrxiv-2022-fd190;10.26434/chemrxiv...
# 309786  10.26434/chemrxiv-2022-fd190;10.26434/chemrxiv...
#
#                   is_preprint_of has_preprint has_review  \
# 282821
# 282876
# 282883
# 283800
# 309786  10.1021/acscatal.2c04200
#
#        has_published_version published_version_ids_json version_of_ids_json  \
# 282821                 false                       None                None
# 282876                 false                       None                None
# 282883                 false                       None                None
# 283800                 false                       None                None
# 309786                  true                       None                None
#
#        update_to_json raw_relationships_json              records_hierarchy  \
# 282821           None                   None  parent - duplicate (ChemRxiv)
# 282876           None                   None  parent - duplicate (ChemRxiv)
# 282883           None                   None  parent - duplicate (ChemRxiv)
# 283800           None                   None  parent - duplicate (ChemRxiv)
# 309786           None                   None  parent - duplicate (ChemRxiv)
#
#        date_first_seen  publication_year_first_seen records_hierarchy_backup  \
# 282821      2022-04-25                         2022                   parent
# 282876      2022-05-02                         2022                   parent
# 282883      2022-05-04                         2022                   parent
# 283800      2022-08-24                         2022                   parent
# 309786      2022-10-18                         2022                   parent
#
#                               parent_record_id  \
# 282821  crossref::10.26434/chemrxiv-2022-fd190
# 282876  crossref::10.26434/chemrxiv-2022-fd190
# 282883  crossref::10.26434/chemrxiv-2022-fd190
# 283800  crossref::10.26434/chemrxiv-2022-fd190
# 309786  crossref::10.26434/chemrxiv-2022-fd190
#
#                                              dup_group_id  \
# 282821                   relaxed::A1_tokenbag_exact::8264
# 282876                                8105542989974901890
# 282883                                8105542989974901890
# 283800                                8105542989974901890
# 309786  fuzzy::tokenbag::alexander_bagger;christensen_...
#
#                                       authors_fp_tokenbag  \
# 282821  alexander_bagger;alonso_hernandez_rosas;christ...
# 282876  alexander_bagger;christensen_oliver;daasbjerg_...
# 282883  alexander_bagger;christensen_oliver;daasbjerg_...
# 283800  alexander_bagger;christensen_oliver;daasbjerg_...
# 309786  alexander_bagger;christensen_oliver;daasbjerg_...
#
#                                            title_clean_v2  \
# 282821  selectivity and intrinsic activity of function...
# 282876  selectivity and intrinsic activity of function...
# 282883  selectivity and intrinsic activity of function...
# 283800  selectivity and intrinsic activity of function...
# 309786  can the co2 reduction reaction be improved on ...
#
#        authors_fp_last_initial authors_fp_last
# 282821                    <NA>            <NA>
# 282876                    <NA>            <NA>
# 282883                    <NA>            <NA>
# 283800                    <NA>            <NA>
# 309786                    <NA>            <NA>

# %%
pattern = "chemrxiv.11846943"


mask = data_out['doi'].str.contains(pattern, regex=False, na=False)
result = data_out[mask]
print(len(result))
result
# Out:
# 9
#                                       record_id server_name   backend  \
# 276994  crossref::10.26434/chemrxiv.11846943.v1    ChemRxiv  crossref
# 277030  crossref::10.26434/chemrxiv.11846943.v2    ChemRxiv  crossref
# 277064  crossref::10.26434/chemrxiv.11846943.v3    ChemRxiv  crossref
# 277093  crossref::10.26434/chemrxiv.11846943.v4    ChemRxiv  crossref
# 277128  crossref::10.26434/chemrxiv.11846943.v5    ChemRxiv  crossref
# 277157  crossref::10.26434/chemrxiv.11846943.v6    ChemRxiv  crossref
# 277180  crossref::10.26434/chemrxiv.11846943.v7    ChemRxiv  crossref
# 277210  crossref::10.26434/chemrxiv.11846943.v8    ChemRxiv  crossref
# 277240  crossref::10.26434/chemrxiv.11846943.v9    ChemRxiv  crossref
#
#                                   doi  \
# 276994  10.26434/chemrxiv.11846943.v1
# 277030  10.26434/chemrxiv.11846943.v2
# 277064  10.26434/chemrxiv.11846943.v3
# 277093  10.26434/chemrxiv.11846943.v4
# 277128  10.26434/chemrxiv.11846943.v5
# 277157  10.26434/chemrxiv.11846943.v6
# 277180  10.26434/chemrxiv.11846943.v7
# 277210  10.26434/chemrxiv.11846943.v8
# 277240  10.26434/chemrxiv.11846943.v9
#
#                                               doi_url  \
# 276994  https://doi.org/10.26434/chemrxiv.11846943.v1
# 277030  https://doi.org/10.26434/chemrxiv.11846943.v2
# 277064  https://doi.org/10.26434/chemrxiv.11846943.v3
# 277093  https://doi.org/10.26434/chemrxiv.11846943.v4
# 277128  https://doi.org/10.26434/chemrxiv.11846943.v5
# 277157  https://doi.org/10.26434/chemrxiv.11846943.v6
# 277180  https://doi.org/10.26434/chemrxiv.11846943.v7
# 277210  https://doi.org/10.26434/chemrxiv.11846943.v8
# 277240  https://doi.org/10.26434/chemrxiv.11846943.v9
#
#                                          landing_page_url  \
# 276994  https://chemrxiv.org/engage/chemrxiv/article-d...
# 277030  https://chemrxiv.org/engage/chemrxiv/article-d...
# 277064  https://chemrxiv.org/engage/chemrxiv/article-d...
# 277093  https://chemrxiv.org/engage/chemrxiv/article-d...
# 277128  https://chemrxiv.org/engage/chemrxiv/article-d...
# 277157  https://chemrxiv.org/engage/chemrxiv/article-d...
# 277180  https://chemrxiv.org/engage/chemrxiv/article-d...
# 277210  https://chemrxiv.org/engage/chemrxiv/article-d...
# 277240  https://chemrxiv.org/engage/chemrxiv/article-d...
#
#                                                     title  \
# 276994  Analysis of Whole Genome Sequences and Homolog...
# 277030  Analysis of Whole Genome Sequences and Homolog...
# 277064  Analysis of Whole Genome Sequences and Homolog...
# 277093  Whole Genome Sequences Analysis and Homology M...
# 277128  Whole Genome Sequence Analysis and Homology Mo...
# 277157  Whole Genome Sequence Analysis and Homology Mo...
# 277180  Whole Genome Sequence Analysis and Homology Mo...
# 277210  Whole Genome Sequence Analysis and Homology Mo...
# 277240  Whole Genome Sequence Analysis and Homology Mo...
#
#                                              authors_flat  \
# 276994       Shanker, Arun; Bhanu, Divya; Alluri, Anajani
# 277030       Shanker, Arun; Bhanu, Divya; Alluri, Anajani
# 277064        Shanker, Arun; Alluri, Anjani; Bhanu, Divya
# 277093        Shanker, Arun; Alluri, Anjani; Bhanu, Divya
# 277128        Shanker, Arun; Alluri, Anjani; Bhanu, Divya
# 277157        Shanker, Arun; Bhanu, Divya; Alluri, Anjani
# 277180        Shanker, Arun; Bhanu, Divya; Alluri, Anjani
# 277210        Shanker, Arun; Bhanu, Divya; Alluri, Anjani
# 277240  Shanker, Arun; Bhanu, Divya; Alluri, Anjani; G...
#
#                                         institutions_flat countries_flat  \
# 276994  Central Research Institute for Dryland Agricul...           None
# 277030  Central Research Institute for Dryland Agricul...           None
# 277064  Central Research Institute for Dryland Agricul...           None
# 277093  Central Research Institute for Dryland Agricul...           None
# 277128  Central Research Institute for Dryland Agricul...           None
# 277157  Central Research Institute for Dryland Agricul...           None
# 277180  Central Research Institute for Dryland Agricul...           None
# 277210  Central Research Institute for Dryland Agricul...           None
# 277240  Central Research Institute for Dryland Agricul...           None
#
#                                            relations_json version_label  \
# 276994  {"is-version-of": [{"asserted-by": "subject", ...          None
# 277030  {"is-version-of": [{"asserted-by": "subject", ...          None
# 277064  {"is-version-of": [{"asserted-by": "subject", ...          None
# 277093  {"is-version-of": [{"asserted-by": "subject", ...          None
# 277128  {"is-version-of": [{"asserted-by": "subject", ...          None
# 277157  {"is-version-of": [{"asserted-by": "subject", ...          None
# 277180  {"is-version-of": [{"asserted-by": "subject", ...          None
# 277210  {"is-version-of": [{"asserted-by": "subject", ...          None
# 277240  {"is-preprint-of": [{"asserted-by": "subject",...          None
#
#                                             is_version_of      is_preprint_of  \
# 276994  10.26434/chemrxiv.11846943.v2;10.26434/chemrxi...
# 277030  10.26434/chemrxiv.11846943.v1;10.26434/chemrxi...
# 277064  10.26434/chemrxiv.11846943.v1;10.26434/chemrxi...
# 277093  10.26434/chemrxiv.11846943.v1;10.26434/chemrxi...
# 277128  10.26434/chemrxiv.11846943.v1;10.26434/chemrxi...
# 277157  10.26434/chemrxiv.11846943.v1;10.26434/chemrxi...
# 277180  10.26434/chemrxiv.11846943.v1;10.26434/chemrxi...
# 277210  10.26434/chemrxiv.11846943.v1;10.26434/chemrxi...
# 277240  10.26434/chemrxiv.11846943.v1;10.26434/chemrxi...  10.1039/d0nj00974a
#
#        has_preprint has_review has_published_version  \
# 276994                                         false
# 277030                                         false
# 277064                                         false
# 277093                                         false
# 277128                                         false
# 277157                                         false
# 277180                                         false
# 277210                                         false
# 277240                                          true
#
#        published_version_ids_json version_of_ids_json update_to_json  \
# 276994                       None                None           None
# 277030                       None                None           None
# 277064                       None                None           None
# 277093                       None                None           None
# 277128                       None                None           None
# 277157                       None                None           None
# 277180                       None                None           None
# 277210                       None                None           None
# 277240                       None                None           None
#
#        raw_relationships_json                            records_hierarchy  \
# 276994                   None  parent - duplicate (Open Science Framework)
# 277030                   None  parent - duplicate (Open Science Framework)
# 277064                   None                parent - duplicate (ChemRxiv)
# 277093                   None  parent - duplicate (Open Science Framework)
# 277128                   None                parent - duplicate (ChemRxiv)
# 277157                   None                parent - duplicate (ChemRxiv)
# 277180                   None                parent - duplicate (ChemRxiv)
# 277210                   None                parent - duplicate (ChemRxiv)
# 277240                   None                parent - duplicate (ChemRxiv)
#
#        date_first_seen  publication_year_first_seen records_hierarchy_backup  \
# 276994      2020-02-13                         2020                   parent
# 277030      2020-02-14                         2020                   parent
# 277064      2020-02-17                         2020                   parent
# 277093      2020-02-21                         2020                   parent
# 277128      2020-03-10                         2020                   parent
# 277157      2020-03-30                         2020                   parent
# 277180      2020-04-03                         2020                   parent
# 277210      2020-04-24                         2020                   parent
# 277240      2020-04-27                         2020                   parent
#
#                                parent_record_id  \
# 276994          crossref::10.31219/osf.io/2zuea
# 277030          crossref::10.31219/osf.io/2zuea
# 277064  crossref::10.26434/chemrxiv.11846943.v2
# 277093          crossref::10.31219/osf.io/2zuea
# 277128  crossref::10.26434/chemrxiv.11846943.v4
# 277157  crossref::10.26434/chemrxiv.11846943.v5
# 277180  crossref::10.26434/chemrxiv.11846943.v5
# 277210  crossref::10.26434/chemrxiv.11846943.v5
# 277240  crossref::10.26434/chemrxiv.11846943.v5
#
#                                              dup_group_id  \
# 276994                               16256016634036771957
# 277030  fuzzy::tokenbag::alluri_anajani;arun_shanker;b...
# 277064                   relaxed::A1_tokenbag_exact::8040
# 277093    fuzzy::last_initial::alluri|a;bhanu|d;shanker|a
# 277128  fuzzy::tokenbag::alluri_anjani;arun_shanker;bh...
# 277157                                1890956516455513972
# 277180                                1890956516455513972
# 277210                                1890956516455513972
# 277240                   relaxed::A1_tokenbag_exact::8044
#
#                                       authors_fp_tokenbag  \
# 276994            alluri_anajani;arun_shanker;bhanu_divya
# 277030            alluri_anajani;arun_shanker;bhanu_divya
# 277064             alluri_anjani;arun_shanker;bhanu_divya
# 277093             alluri_anjani;arun_shanker;bhanu_divya
# 277128             alluri_anjani;arun_shanker;bhanu_divya
# 277157             alluri_anjani;arun_shanker;bhanu_divya
# 277180             alluri_anjani;arun_shanker;bhanu_divya
# 277210             alluri_anjani;arun_shanker;bhanu_divya
# 277240  alluri_anjani;arun_shanker;bhanu_divya;gupta_s...
#
#                                            title_clean_v2  \
# 276994  analysis of whole genome sequences and homolog...
# 277030  analysis of whole genome sequences and homolog...
# 277064  analysis of whole genome sequences and homolog...
# 277093  whole genome sequences analysis and homology m...
# 277128  whole genome sequence analysis and homology mo...
# 277157  whole genome sequence analysis and homology mo...
# 277180  whole genome sequence analysis and homology mo...
# 277210  whole genome sequence analysis and homology mo...
# 277240  whole genome sequence analysis and homology mo...
#
#            authors_fp_last_initial authors_fp_last
# 276994                        <NA>            <NA>
# 277030                        <NA>            <NA>
# 277064                        <NA>            <NA>
# 277093  alluri|a;bhanu|d;shanker|a            <NA>
# 277128                        <NA>            <NA>
# 277157                        <NA>            <NA>
# 277180                        <NA>            <NA>
# 277210                        <NA>            <NA>
# 277240                        <NA>            <NA>

# %%
result['records_hierarchy'].value_counts()
# Out:
# records_hierarchy
# parent - duplicate (ChemRxiv)                  6
# parent - duplicate (Open Science Framework)    3
# Name: count, dtype: int64

# %%
result['title'].value_counts()
# Out:
# title
# Whole Genome Sequence Analysis and Homology Modelling of a 3C Like Peptidase and a Non-Structural Protein 3 of the SARS-CoV-2 Shows Protein Ligand Interaction with an Aza-Peptide and a Noncovalent Lead Inhibitor with Possible Antiviral Properties                       5
# Analysis of Whole Genome Sequences and Homology Modelling of a 3-C Like Peptidase and a Non-Structural Protein of the Novel Coronavirus COVID-19 Shows Protein Ligand Interaction with an Aza-Peptide and a Noncovalent Lead Inhibitor with Possible Antiviral Properties    2
# Analysis of Whole Genome Sequences and Homology Modelling of a 3C Like Peptidase and a Non-Structural Protein of the Novel Coronavirus COVID-19 Shows Protein Ligand Interaction with an Aza-Peptide and a Noncovalent Lead Inhibitor with Possible Antiviral Properties     1
# Whole Genome Sequences Analysis and Homology Modelling of a 3C Like Peptidase and a Non-Structural Protein 3 of the SARS-CoV-2 Shows Protein Ligand Interaction with an Aza-Peptide and a Noncovalent Lead Inhibitor with Possible Antiviral Properties                      1
# Name: count, dtype: int64

# %%
result['authors_flat'].value_counts()
# Out:
# authors_flat
# Shanker, Arun; Alluri, Anjani; Bhanu, Divya                      3
# Shanker, Arun; Bhanu, Divya; Alluri, Anjani                      3
# Shanker, Arun; Bhanu, Divya; Alluri, Anajani                     2
# Shanker, Arun; Bhanu, Divya; Alluri, Anjani; Gupta, Samriddhi    1
# Name: count, dtype: int64

# %%
pattern = "10.26434/chemrxiv-2022-fd190"


mask = data_out['doi'].str.contains(pattern, regex=False, na=False)
result = data_out[mask]
print(len(result))
result
# Out:
# 6
#                                         record_id server_name   backend  \
# 282550     crossref::10.26434/chemrxiv-2022-fd190    ChemRxiv  crossref
# 282821  crossref::10.26434/chemrxiv-2022-fd190-v2    ChemRxiv  crossref
# 282876  crossref::10.26434/chemrxiv-2022-fd190-v3    ChemRxiv  crossref
# 282883  crossref::10.26434/chemrxiv-2022-fd190-v4    ChemRxiv  crossref
# 283800  crossref::10.26434/chemrxiv-2022-fd190-v5    ChemRxiv  crossref
# 309786  crossref::10.26434/chemrxiv-2022-fd190-v6    ChemRxiv  crossref
#
#                                     doi  \
# 282550     10.26434/chemrxiv-2022-fd190
# 282821  10.26434/chemrxiv-2022-fd190-v2
# 282876  10.26434/chemrxiv-2022-fd190-v3
# 282883  10.26434/chemrxiv-2022-fd190-v4
# 283800  10.26434/chemrxiv-2022-fd190-v5
# 309786  10.26434/chemrxiv-2022-fd190-v6
#
#                                                 doi_url  \
# 282550     https://doi.org/10.26434/chemrxiv-2022-fd190
# 282821  https://doi.org/10.26434/chemrxiv-2022-fd190-v2
# 282876  https://doi.org/10.26434/chemrxiv-2022-fd190-v3
# 282883  https://doi.org/10.26434/chemrxiv-2022-fd190-v4
# 283800  https://doi.org/10.26434/chemrxiv-2022-fd190-v5
# 309786  https://doi.org/10.26434/chemrxiv-2022-fd190-v6
#
#                                          landing_page_url  \
# 282550  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282821  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282876  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282883  https://chemrxiv.org/engage/chemrxiv/article-d...
# 283800  https://chemrxiv.org/engage/chemrxiv/article-d...
# 309786  https://chemrxiv.org/engage/chemrxiv/article-d...
#
#                                                     title  \
# 282550  Selectivity and Intrinsic Activity of Function...
# 282821  Selectivity and Intrinsic Activity of Function...
# 282876  Selectivity and Intrinsic Activity of Function...
# 282883  Selectivity and Intrinsic Activity of Function...
# 283800  Selectivity and Intrinsic Activity of Function...
# 309786  Can the CO2 Reduction Reaction be Improved on ...
#
#                                              authors_flat  \
# 282550  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
# 282821  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
# 282876  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
# 282883  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
# 283800  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
# 309786  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
#
#                                   institutions_flat countries_flat  \
# 282550  University of Copenhagen; Aarhus University           None
# 282821  University of Copenhagen; Aarhus University           None
# 282876  University of Copenhagen; Aarhus University           None
# 282883  University of Copenhagen; Aarhus University           None
# 283800  University of Copenhagen; Aarhus University           None
# 309786  University of Copenhagen; Aarhus University           None
#
#                                            relations_json version_label  \
# 282550                                               None          None
# 282821  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282876  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282883  {"is-version-of": [{"asserted-by": "subject", ...          None
# 283800  {"is-version-of": [{"asserted-by": "subject", ...          None
# 309786  {"is-preprint-of": [{"asserted-by": "subject",...          None
#
#                                             is_version_of  \
# 282550
# 282821                       10.26434/chemrxiv-2022-fd190
# 282876  10.26434/chemrxiv-2022-fd190;10.26434/chemrxiv...
# 282883  10.26434/chemrxiv-2022-fd190;10.26434/chemrxiv...
# 283800  10.26434/chemrxiv-2022-fd190;10.26434/chemrxiv...
# 309786  10.26434/chemrxiv-2022-fd190;10.26434/chemrxiv...
#
#                   is_preprint_of has_preprint has_review  \
# 282550
# 282821
# 282876
# 282883
# 283800
# 309786  10.1021/acscatal.2c04200
#
#        has_published_version published_version_ids_json version_of_ids_json  \
# 282550                 false                       None                None
# 282821                 false                       None                None
# 282876                 false                       None                None
# 282883                 false                       None                None
# 283800                 false                       None                None
# 309786                  true                       None                None
#
#        update_to_json raw_relationships_json              records_hierarchy  \
# 282550           None                   None                         parent
# 282821           None                   None  parent - duplicate (ChemRxiv)
# 282876           None                   None  parent - duplicate (ChemRxiv)
# 282883           None                   None  parent - duplicate (ChemRxiv)
# 283800           None                   None  parent - duplicate (ChemRxiv)
# 309786           None                   None  parent - duplicate (ChemRxiv)
#
#        date_first_seen  publication_year_first_seen records_hierarchy_backup  \
# 282550      2022-03-18                         2022                   parent
# 282821      2022-04-25                         2022                   parent
# 282876      2022-05-02                         2022                   parent
# 282883      2022-05-04                         2022                   parent
# 283800      2022-08-24                         2022                   parent
# 309786      2022-10-18                         2022                   parent
#
#                               parent_record_id  \
# 282550                                    <NA>
# 282821  crossref::10.26434/chemrxiv-2022-fd190
# 282876  crossref::10.26434/chemrxiv-2022-fd190
# 282883  crossref::10.26434/chemrxiv-2022-fd190
# 283800  crossref::10.26434/chemrxiv-2022-fd190
# 309786  crossref::10.26434/chemrxiv-2022-fd190
#
#                                              dup_group_id  \
# 282550                   relaxed::A1_tokenbag_exact::8264
# 282821                   relaxed::A1_tokenbag_exact::8264
# 282876                                8105542989974901890
# 282883                                8105542989974901890
# 283800                                8105542989974901890
# 309786  fuzzy::tokenbag::alexander_bagger;christensen_...
#
#                                       authors_fp_tokenbag  \
# 282550  alexander_bagger;christensen_oliver;daasbjerg_...
# 282821  alexander_bagger;alonso_hernandez_rosas;christ...
# 282876  alexander_bagger;christensen_oliver;daasbjerg_...
# 282883  alexander_bagger;christensen_oliver;daasbjerg_...
# 283800  alexander_bagger;christensen_oliver;daasbjerg_...
# 309786  alexander_bagger;christensen_oliver;daasbjerg_...
#
#                                            title_clean_v2  \
# 282550  selectivity and intrinsic activity of function...
# 282821  selectivity and intrinsic activity of function...
# 282876  selectivity and intrinsic activity of function...
# 282883  selectivity and intrinsic activity of function...
# 283800  selectivity and intrinsic activity of function...
# 309786  can the co2 reduction reaction be improved on ...
#
#        authors_fp_last_initial authors_fp_last
# 282550                    <NA>            <NA>
# 282821                    <NA>            <NA>
# 282876                    <NA>            <NA>
# 282883                    <NA>            <NA>
# 283800                    <NA>            <NA>
# 309786                    <NA>            <NA>

# %%
pattern = "10.26434/chemrxiv-2022-fd190"


mask = data['doi'].str.contains(pattern, regex=False, na=False)
result = data[mask]
print(len(result))
result
# Out:
# 6
#                                         record_id server_name   backend  \
# 287671     crossref::10.26434/chemrxiv-2022-fd190    ChemRxiv  crossref
# 287942  crossref::10.26434/chemrxiv-2022-fd190-v2    ChemRxiv  crossref
# 287997  crossref::10.26434/chemrxiv-2022-fd190-v3    ChemRxiv  crossref
# 288004  crossref::10.26434/chemrxiv-2022-fd190-v4    ChemRxiv  crossref
# 288921  crossref::10.26434/chemrxiv-2022-fd190-v5    ChemRxiv  crossref
# 314907  crossref::10.26434/chemrxiv-2022-fd190-v6    ChemRxiv  crossref
#
#                                     doi  \
# 287671     10.26434/chemrxiv-2022-fd190
# 287942  10.26434/chemrxiv-2022-fd190-v2
# 287997  10.26434/chemrxiv-2022-fd190-v3
# 288004  10.26434/chemrxiv-2022-fd190-v4
# 288921  10.26434/chemrxiv-2022-fd190-v5
# 314907  10.26434/chemrxiv-2022-fd190-v6
#
#                                                 doi_url  \
# 287671     https://doi.org/10.26434/chemrxiv-2022-fd190
# 287942  https://doi.org/10.26434/chemrxiv-2022-fd190-v2
# 287997  https://doi.org/10.26434/chemrxiv-2022-fd190-v3
# 288004  https://doi.org/10.26434/chemrxiv-2022-fd190-v4
# 288921  https://doi.org/10.26434/chemrxiv-2022-fd190-v5
# 314907  https://doi.org/10.26434/chemrxiv-2022-fd190-v6
#
#                                          landing_page_url  \
# 287671  https://chemrxiv.org/engage/chemrxiv/article-d...
# 287942  https://chemrxiv.org/engage/chemrxiv/article-d...
# 287997  https://chemrxiv.org/engage/chemrxiv/article-d...
# 288004  https://chemrxiv.org/engage/chemrxiv/article-d...
# 288921  https://chemrxiv.org/engage/chemrxiv/article-d...
# 314907  https://chemrxiv.org/engage/chemrxiv/article-d...
#
#                                                     title  \
# 287671  Selectivity and Intrinsic Activity of Function...
# 287942  Selectivity and Intrinsic Activity of Function...
# 287997  Selectivity and Intrinsic Activity of Function...
# 288004  Selectivity and Intrinsic Activity of Function...
# 288921  Selectivity and Intrinsic Activity of Function...
# 314907  Can the CO2 Reduction Reaction be Improved on ...
#
#                                              authors_flat  \
# 287671  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
# 287942  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
# 287997  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
# 288004  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
# 288921  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
# 314907  Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong...
#
#                                   institutions_flat countries_flat  \
# 287671  University of Copenhagen; Aarhus University           None
# 287942  University of Copenhagen; Aarhus University           None
# 287997  University of Copenhagen; Aarhus University           None
# 288004  University of Copenhagen; Aarhus University           None
# 288921  University of Copenhagen; Aarhus University           None
# 314907  University of Copenhagen; Aarhus University           None
#
#                                            relations_json version_label  \
# 287671                                               None          None
# 287942  {"is-version-of": [{"asserted-by": "subject", ...          None
# 287997  {"is-version-of": [{"asserted-by": "subject", ...          None
# 288004  {"is-version-of": [{"asserted-by": "subject", ...          None
# 288921  {"is-version-of": [{"asserted-by": "subject", ...          None
# 314907  {"is-preprint-of": [{"asserted-by": "subject",...          None
#
#                                             is_version_of  \
# 287671
# 287942                       10.26434/chemrxiv-2022-fd190
# 287997  10.26434/chemrxiv-2022-fd190;10.26434/chemrxiv...
# 288004  10.26434/chemrxiv-2022-fd190;10.26434/chemrxiv...
# 288921  10.26434/chemrxiv-2022-fd190;10.26434/chemrxiv...
# 314907  10.26434/chemrxiv-2022-fd190;10.26434/chemrxiv...
#
#                   is_preprint_of has_preprint has_review  \
# 287671
# 287942
# 287997
# 288004
# 288921
# 314907  10.1021/acscatal.2c04200
#
#        has_published_version published_version_ids_json version_of_ids_json  \
# 287671                 false                       None                None
# 287942                 false                       None                None
# 287997                 false                       None                None
# 288004                 false                       None                None
# 288921                 false                       None                None
# 314907                  true                       None                None
#
#        update_to_json raw_relationships_json
# 287671           None                   None
# 287942           None                   None
# 287997           None                   None
# 288004           None                   None
# 288921           None                   None
# 314907           None                   None

# %%
result['title'].value_counts()
# Out:
# title
# Selectivity and Intrinsic Activity of Functionalized Cu Surfaces: Can the CO2 Reduction Reaction be Improved on Cu?    5
# Can the CO2 Reduction Reaction be Improved on Cu: Selectivity and Intrinsic Activity of Functionalized Cu Surfaces     1
# Name: count, dtype: int64

# %%
result['authors_flat'].value_counts()
# Out:
# authors_flat
# Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong; Bagger, Alexander; Vang Lauritsen, Jeppe; Uttrup Pedersen, Steen; Daasbjerg, Kim; Rossmeisl, Jan                             5
# Christensen, Oliver; Zhao, Siqi; Sun, Zhaozong; Bagger, Alexander; Rosas-Hernández, Alonso; Vang Lauritsen, Jeppe; Uttrup Pedersen, Steen; Daasbjerg, Kim; Rossmeisl, Jan    1
# Name: count, dtype: int64

# %%
sample_titles = data_out.sample(5)[['title', 'authors_flat']].title
data_out[data_out.title.isin(sample_titles)][['title','authors_flat','records_hierarchy','date_first_seen']]
# Out:
#                                                      title  \
# 1399962                    Jacques Derrida on Recognition
# 4737852  Using Predictive Analytics to Optimize Digital...
# 4737853  Using Predictive Analytics to Optimize Digital...
# 6950072  Enhancement and suppression of heat transfer b...
# 7203389  A Log-domain Interior Point Method for Convex ...
# 7370026  Video Summarisation with Incident and Context ...
#
#                                               authors_flat  \
# 1399962                                    Isabelle Aubert
# 4737852                                    Aindri, Jaiswal
# 4737853                                    Aindri, Jaiswal
# 6950072                                       Lazarian, A.
# 7203389               Liu, Bingqi; Liao-McPherson, Dominic
# 7370026  De Silva, Ulindu; Fernando, Leon; Bandara, Kal...
#
#                    records_hierarchy date_first_seen
# 1399962                       parent      2018-01-01
# 4737852    parent - duplicate (SSRN)      2025-08-25
# 4737853  parent - duplicate (Zenodo)      2025-08-25
# 6950072                       parent      2022-03-21
# 7203389                       parent      2024-03-21
# 7370026                       parent      2025-01-10

# %%
pattern = "10.26434/chemrxiv.13102877"


mask = data_out['doi'].str.contains(pattern, regex=False, na=False)
result = data_out[mask]
print(len(result))
result
# Out:
# 32
#                                        record_id server_name   backend  \
# 279942   crossref::10.26434/chemrxiv.13102877.v1    ChemRxiv  crossref
# 279972   crossref::10.26434/chemrxiv.13102877.v2    ChemRxiv  crossref
# 279999   crossref::10.26434/chemrxiv.13102877.v3    ChemRxiv  crossref
# 280030   crossref::10.26434/chemrxiv.13102877.v4    ChemRxiv  crossref
# 280070   crossref::10.26434/chemrxiv.13102877.v5    ChemRxiv  crossref
# 280100   crossref::10.26434/chemrxiv.13102877.v6    ChemRxiv  crossref
# 280155   crossref::10.26434/chemrxiv.13102877.v7    ChemRxiv  crossref
# 280205   crossref::10.26434/chemrxiv.13102877.v8    ChemRxiv  crossref
# 280247   crossref::10.26434/chemrxiv.13102877.v9    ChemRxiv  crossref
# 280295  crossref::10.26434/chemrxiv.13102877.v10    ChemRxiv  crossref
# 280344  crossref::10.26434/chemrxiv.13102877.v11    ChemRxiv  crossref
# 280390  crossref::10.26434/chemrxiv.13102877.v12    ChemRxiv  crossref
# 280431  crossref::10.26434/chemrxiv.13102877.v13    ChemRxiv  crossref
# 280481  crossref::10.26434/chemrxiv.13102877.v14    ChemRxiv  crossref
# 280540  crossref::10.26434/chemrxiv.13102877.v15    ChemRxiv  crossref
# 280557  crossref::10.26434/chemrxiv.13102877.v16    ChemRxiv  crossref
# 280566  crossref::10.26434/chemrxiv.13102877.v17    ChemRxiv  crossref
# 280569  crossref::10.26434/chemrxiv.13102877.v19    ChemRxiv  crossref
# 280570  crossref::10.26434/chemrxiv.13102877.v20    ChemRxiv  crossref
# 280571  crossref::10.26434/chemrxiv.13102877.v18    ChemRxiv  crossref
# 280575  crossref::10.26434/chemrxiv.13102877.v21    ChemRxiv  crossref
# 280577  crossref::10.26434/chemrxiv.13102877.v22    ChemRxiv  crossref
# 280578  crossref::10.26434/chemrxiv.13102877.v23    ChemRxiv  crossref
# 280583  crossref::10.26434/chemrxiv.13102877.v24    ChemRxiv  crossref
# 280584  crossref::10.26434/chemrxiv.13102877.v25    ChemRxiv  crossref
# 280586  crossref::10.26434/chemrxiv.13102877.v26    ChemRxiv  crossref
# 280587  crossref::10.26434/chemrxiv.13102877.v27    ChemRxiv  crossref
# 280588  crossref::10.26434/chemrxiv.13102877.v28    ChemRxiv  crossref
# 280589  crossref::10.26434/chemrxiv.13102877.v29    ChemRxiv  crossref
# 280590  crossref::10.26434/chemrxiv.13102877.v30    ChemRxiv  crossref
# 280593  crossref::10.26434/chemrxiv.13102877.v31    ChemRxiv  crossref
# 280596  crossref::10.26434/chemrxiv.13102877.v32    ChemRxiv  crossref
#
#                                    doi  \
# 279942   10.26434/chemrxiv.13102877.v1
# 279972   10.26434/chemrxiv.13102877.v2
# 279999   10.26434/chemrxiv.13102877.v3
# 280030   10.26434/chemrxiv.13102877.v4
# 280070   10.26434/chemrxiv.13102877.v5
# 280100   10.26434/chemrxiv.13102877.v6
# 280155   10.26434/chemrxiv.13102877.v7
# 280205   10.26434/chemrxiv.13102877.v8
# 280247   10.26434/chemrxiv.13102877.v9
# 280295  10.26434/chemrxiv.13102877.v10
# 280344  10.26434/chemrxiv.13102877.v11
# 280390  10.26434/chemrxiv.13102877.v12
# 280431  10.26434/chemrxiv.13102877.v13
# 280481  10.26434/chemrxiv.13102877.v14
# 280540  10.26434/chemrxiv.13102877.v15
# 280557  10.26434/chemrxiv.13102877.v16
# 280566  10.26434/chemrxiv.13102877.v17
# 280569  10.26434/chemrxiv.13102877.v19
# 280570  10.26434/chemrxiv.13102877.v20
# 280571  10.26434/chemrxiv.13102877.v18
# 280575  10.26434/chemrxiv.13102877.v21
# 280577  10.26434/chemrxiv.13102877.v22
# 280578  10.26434/chemrxiv.13102877.v23
# 280583  10.26434/chemrxiv.13102877.v24
# 280584  10.26434/chemrxiv.13102877.v25
# 280586  10.26434/chemrxiv.13102877.v26
# 280587  10.26434/chemrxiv.13102877.v27
# 280588  10.26434/chemrxiv.13102877.v28
# 280589  10.26434/chemrxiv.13102877.v29
# 280590  10.26434/chemrxiv.13102877.v30
# 280593  10.26434/chemrxiv.13102877.v31
# 280596  10.26434/chemrxiv.13102877.v32
#
#                                                doi_url  \
# 279942   https://doi.org/10.26434/chemrxiv.13102877.v1
# 279972   https://doi.org/10.26434/chemrxiv.13102877.v2
# 279999   https://doi.org/10.26434/chemrxiv.13102877.v3
# 280030   https://doi.org/10.26434/chemrxiv.13102877.v4
# 280070   https://doi.org/10.26434/chemrxiv.13102877.v5
# 280100   https://doi.org/10.26434/chemrxiv.13102877.v6
# 280155   https://doi.org/10.26434/chemrxiv.13102877.v7
# 280205   https://doi.org/10.26434/chemrxiv.13102877.v8
# 280247   https://doi.org/10.26434/chemrxiv.13102877.v9
# 280295  https://doi.org/10.26434/chemrxiv.13102877.v10
# 280344  https://doi.org/10.26434/chemrxiv.13102877.v11
# 280390  https://doi.org/10.26434/chemrxiv.13102877.v12
# 280431  https://doi.org/10.26434/chemrxiv.13102877.v13
# 280481  https://doi.org/10.26434/chemrxiv.13102877.v14
# 280540  https://doi.org/10.26434/chemrxiv.13102877.v15
# 280557  https://doi.org/10.26434/chemrxiv.13102877.v16
# 280566  https://doi.org/10.26434/chemrxiv.13102877.v17
# 280569  https://doi.org/10.26434/chemrxiv.13102877.v19
# 280570  https://doi.org/10.26434/chemrxiv.13102877.v20
# 280571  https://doi.org/10.26434/chemrxiv.13102877.v18
# 280575  https://doi.org/10.26434/chemrxiv.13102877.v21
# 280577  https://doi.org/10.26434/chemrxiv.13102877.v22
# 280578  https://doi.org/10.26434/chemrxiv.13102877.v23
# 280583  https://doi.org/10.26434/chemrxiv.13102877.v24
# 280584  https://doi.org/10.26434/chemrxiv.13102877.v25
# 280586  https://doi.org/10.26434/chemrxiv.13102877.v26
# 280587  https://doi.org/10.26434/chemrxiv.13102877.v27
# 280588  https://doi.org/10.26434/chemrxiv.13102877.v28
# 280589  https://doi.org/10.26434/chemrxiv.13102877.v29
# 280590  https://doi.org/10.26434/chemrxiv.13102877.v30
# 280593  https://doi.org/10.26434/chemrxiv.13102877.v31
# 280596  https://doi.org/10.26434/chemrxiv.13102877.v32
#
#                                          landing_page_url  \
# 279942  https://chemrxiv.org/engage/chemrxiv/article-d...
# 279972  https://chemrxiv.org/engage/chemrxiv/article-d...
# 279999  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280030  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280070  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280100  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280155  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280205  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280247  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280295  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280344  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280390  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280431  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280481  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280540  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280557  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280566  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280569  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280570  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280571  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280575  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280577  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280578  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280583  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280584  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280586  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280587  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280588  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280589  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280590  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280593  https://chemrxiv.org/engage/chemrxiv/article-d...
# 280596  https://chemrxiv.org/engage/chemrxiv/article-d...
#
#                                                     title    authors_flat  \
# 279942  Aptamers for Detection and Diagnostics (ADD): ...  Datta, Shoumen
# 279972  Aptamers for Detection and Diagnostics (ADD): ...  Datta, Shoumen
# 279999  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280030  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280070  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280100  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280155  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280205  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280247  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280295  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280344  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280390  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280431  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280481  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280540  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280557  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280566  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280569  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280570  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280571  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280575  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280577  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280578  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280583  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280584  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280586  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280587  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280588  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280589  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280590  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 280593  Aptamers for Detection and Diagnostics (ADD): ...  Datta, Shoumen
# 280596  Aptamers for Detection and Diagnostics (ADD): ...  Datta, Shoumen
#
#        institutions_flat countries_flat  \
# 279942               MIT           None
# 279972               MIT           None
# 279999               MIT           None
# 280030               MIT           None
# 280070               MIT           None
# 280100               MIT           None
# 280155               MIT           None
# 280205               MIT           None
# 280247               MIT           None
# 280295               MIT           None
# 280344               MIT           None
# 280390               MIT           None
# 280431               MIT           None
# 280481               MIT           None
# 280540               MIT           None
# 280557               MIT           None
# 280566               MIT           None
# 280569               MIT           None
# 280570               MIT           None
# 280571               MIT           None
# 280575               MIT           None
# 280577               MIT           None
# 280578               MIT           None
# 280583               MIT           None
# 280584               MIT           None
# 280586               MIT           None
# 280587               MIT           None
# 280588               MIT           None
# 280589               MIT           None
# 280590               MIT           None
# 280593               MIT           None
# 280596               MIT           None
#
#                                            relations_json version_label  \
# 279942  {"is-version-of": [{"asserted-by": "subject", ...          None
# 279972  {"is-version-of": [{"asserted-by": "subject", ...          None
# 279999  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280030  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280070  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280100  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280155  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280205  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280247  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280295  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280344  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280390  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280431  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280481  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280540  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280557  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280566  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280569  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280570  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280571  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280575  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280577  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280578  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280583  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280584  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280586  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280587  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280588  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280589  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280590  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280593  {"is-version-of": [{"asserted-by": "subject", ...          None
# 280596  {"is-version-of": [{"asserted-by": "subject", ...          None
#
#                                             is_version_of is_preprint_of  \
# 279942  10.26434/chemrxiv.13102877.v2;10.26434/chemrxi...
# 279972  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 279999  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280030  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280070  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280100  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280155  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280205  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280247  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280295  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280344  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280390  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280431  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280481  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280540  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280557  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280566  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280569  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280570  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280571  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280575  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280577  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280578  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280583  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280584  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280586  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280587  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280588  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280589  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280590  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280593  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 280596  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
#
#        has_preprint has_review has_published_version  \
# 279942                                         false
# 279972                                         false
# 279999                                         false
# 280030                                         false
# 280070                                         false
# 280100                                         false
# 280155                                         false
# 280205                                         false
# 280247                                         false
# 280295                                         false
# 280344                                         false
# 280390                                         false
# 280431                                         false
# 280481                                         false
# 280540                                         false
# 280557                                         false
# 280566                                         false
# 280569                                         false
# 280570                                         false
# 280571                                         false
# 280575                                         false
# 280577                                         false
# 280578                                         false
# 280583                                         false
# 280584                                         false
# 280586                                         false
# 280587                                         false
# 280588                                         false
# 280589                                         false
# 280590                                         false
# 280593                                         false
# 280596                                         false
#
#        published_version_ids_json version_of_ids_json update_to_json  \
# 279942                       None                None           None
# 279972                       None                None           None
# 279999                       None                None           None
# 280030                       None                None           None
# 280070                       None                None           None
# 280100                       None                None           None
# 280155                       None                None           None
# 280205                       None                None           None
# 280247                       None                None           None
# 280295                       None                None           None
# 280344                       None                None           None
# 280390                       None                None           None
# 280431                       None                None           None
# 280481                       None                None           None
# 280540                       None                None           None
# 280557                       None                None           None
# 280566                       None                None           None
# 280569                       None                None           None
# 280570                       None                None           None
# 280571                       None                None           None
# 280575                       None                None           None
# 280577                       None                None           None
# 280578                       None                None           None
# 280583                       None                None           None
# 280584                       None                None           None
# 280586                       None                None           None
# 280587                       None                None           None
# 280588                       None                None           None
# 280589                       None                None           None
# 280590                       None                None           None
# 280593                       None                None           None
# 280596                       None                None           None
#
#        raw_relationships_json              records_hierarchy date_first_seen  \
# 279942                   None                         parent      2020-10-23
# 279972                   None  parent - duplicate (ChemRxiv)      2020-10-27
# 279999                   None                         parent      2020-11-06
# 280030                   None  parent - duplicate (ChemRxiv)      2020-11-09
# 280070                   None  parent - duplicate (ChemRxiv)      2020-11-11
# 280100                   None  parent - duplicate (ChemRxiv)      2020-11-16
# 280155                   None  parent - duplicate (ChemRxiv)      2020-11-23
# 280205                   None  parent - duplicate (ChemRxiv)      2020-11-24
# 280247                   None  parent - duplicate (ChemRxiv)      2020-11-30
# 280295                   None  parent - duplicate (ChemRxiv)      2020-12-03
# 280344                   None  parent - duplicate (ChemRxiv)      2020-12-04
# 280390                   None  parent - duplicate (ChemRxiv)      2020-12-07
# 280431                   None  parent - duplicate (ChemRxiv)      2020-12-10
# 280481                   None  parent - duplicate (ChemRxiv)      2020-12-22
# 280540                   None  parent - duplicate (ChemRxiv)      2020-12-30
# 280557                   None  parent - duplicate (ChemRxiv)      2021-01-04
# 280566                   None  parent - duplicate (ChemRxiv)      2021-01-05
# 280569                   None  parent - duplicate (ChemRxiv)      2021-01-12
# 280570                   None  parent - duplicate (ChemRxiv)      2021-01-13
# 280571                   None  parent - duplicate (ChemRxiv)      2021-01-08
# 280575                   None  parent - duplicate (ChemRxiv)      2021-01-20
# 280577                   None  parent - duplicate (ChemRxiv)      2021-01-27
# 280578                   None  parent - duplicate (ChemRxiv)      2021-02-01
# 280583                   None  parent - duplicate (ChemRxiv)      2021-02-03
# 280584                   None  parent - duplicate (ChemRxiv)      2021-02-04
# 280586                   None  parent - duplicate (ChemRxiv)      2021-02-18
# 280587                   None  parent - duplicate (ChemRxiv)      2021-02-22
# 280588                   None  parent - duplicate (ChemRxiv)      2021-03-01
# 280589                   None  parent - duplicate (ChemRxiv)      2021-03-03
# 280590                   None  parent - duplicate (ChemRxiv)      2021-03-08
# 280593                   None                         parent      2021-03-15
# 280596                   None  parent - duplicate (ChemRxiv)      2021-03-16
#
#         publication_year_first_seen records_hierarchy_backup  \
# 279942                         2020                   parent
# 279972                         2020                   parent
# 279999                         2020                   parent
# 280030                         2020                   parent
# 280070                         2020                   parent
# 280100                         2020                   parent
# 280155                         2020                   parent
# 280205                         2020                   parent
# 280247                         2020                   parent
# 280295                         2020                   parent
# 280344                         2020                   parent
# 280390                         2020                   parent
# 280431                         2020                   parent
# 280481                         2020                   parent
# 280540                         2020                   parent
# 280557                         2021                   parent
# 280566                         2021                   parent
# 280569                         2021                   parent
# 280570                         2021                   parent
# 280571                         2021                   parent
# 280575                         2021                   parent
# 280577                         2021                   parent
# 280578                         2021                   parent
# 280583                         2021                   parent
# 280584                         2021                   parent
# 280586                         2021                   parent
# 280587                         2021                   parent
# 280588                         2021                   parent
# 280589                         2021                   parent
# 280590                         2021                   parent
# 280593                         2021                   parent
# 280596                         2021                   parent
#
#                                 parent_record_id          dup_group_id  \
# 279942                                      <NA>  16854196709595633026
# 279972   crossref::10.26434/chemrxiv.13102877.v1  16854196709595633026
# 279999                                      <NA>  15378799223749550050
# 280030   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280070   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280100   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280155   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280205   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280247   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280295   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280344   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280390   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280431   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280481   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280540   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280557   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280566   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280569   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280570   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280571   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280575   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280577   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280578   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280583   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280584   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280586   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280587   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280588   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280589   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280590   crossref::10.26434/chemrxiv.13102877.v3  15378799223749550050
# 280593                                      <NA>  15120014104423475792
# 280596  crossref::10.26434/chemrxiv.13102877.v31  15120014104423475792
#
#        authors_fp_tokenbag                                     title_clean_v2  \
# 279942       datta_shoumen  aptamers for detection and diagnostics add pro...
# 279972       datta_shoumen  aptamers for detection and diagnostics add pro...
# 279999       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280030       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280070       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280100       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280155       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280205       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280247       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280295       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280344       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280390       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280431       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280481       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280540       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280557       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280566       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280569       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280570       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280571       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280575       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280577       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280578       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280583       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280584       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280586       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280587       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280588       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280589       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280590       datta_shoumen  aptamers for detection and diagnostics add is ...
# 280593       datta_shoumen  aptamers for detection and diagnostics add can...
# 280596       datta_shoumen  aptamers for detection and diagnostics add can...
#
#        authors_fp_last_initial authors_fp_last
# 279942                 datta|s            <NA>
# 279972                    <NA>            <NA>
# 279999                 datta|s            <NA>
# 280030                    <NA>            <NA>
# 280070                    <NA>            <NA>
# 280100                    <NA>            <NA>
# 280155                    <NA>            <NA>
# 280205                    <NA>            <NA>
# 280247                    <NA>            <NA>
# 280295                    <NA>            <NA>
# 280344                    <NA>            <NA>
# 280390                    <NA>            <NA>
# 280431                    <NA>            <NA>
# 280481                    <NA>            <NA>
# 280540                    <NA>            <NA>
# 280557                    <NA>            <NA>
# 280566                    <NA>            <NA>
# 280569                    <NA>            <NA>
# 280570                    <NA>            <NA>
# 280571                    <NA>            <NA>
# 280575                    <NA>            <NA>
# 280577                    <NA>            <NA>
# 280578                    <NA>            <NA>
# 280583                    <NA>            <NA>
# 280584                    <NA>            <NA>
# 280586                    <NA>            <NA>
# 280587                    <NA>            <NA>
# 280588                    <NA>            <NA>
# 280589                    <NA>            <NA>
# 280590                    <NA>            <NA>
# 280593                 datta|s            <NA>
# 280596                    <NA>            <NA>
