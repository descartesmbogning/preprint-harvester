# %% [markdown]
# # import data

# %%
import pandas as pd
import numpy as np

# Set option to display all columns
pd.set_option('display.max_columns', None)

# %%
data = pd.read_parquet("outputs_new/dedupe_data_out.parquet")
data
# Out:
#                                record_id     server_name   backend  \
# 0        crossref::10.21467/preprints.48  AIJR Preprints  crossref
# 1        crossref::10.21467/preprints.43  AIJR Preprints  crossref
# 2        crossref::10.21467/preprints.39  AIJR Preprints  crossref
# 3        crossref::10.21467/preprints.38  AIJR Preprints  crossref
# 4        crossref::10.21467/preprints.36  AIJR Preprints  crossref
# ...                                  ...             ...       ...
# 7911896             openalex::W999325625           viXra  openalex
# 7911897             openalex::W999460032           viXra  openalex
# 7911898              openalex::W99967155           viXra  openalex
# 7911899             openalex::W999790414           viXra  openalex
# 7911900             openalex::W999805801           viXra  openalex
#
#                            doi                                doi_url  \
# 0        10.21467/preprints.48  https://doi.org/10.21467/preprints.48
# 1        10.21467/preprints.43  https://doi.org/10.21467/preprints.43
# 2        10.21467/preprints.39  https://doi.org/10.21467/preprints.39
# 3        10.21467/preprints.38  https://doi.org/10.21467/preprints.38
# 4        10.21467/preprints.36  https://doi.org/10.21467/preprints.36
# ...                        ...                                    ...
# 7911896                   None                                   None
# 7911897                   None                                   None
# 7911898                   None                                   None
# 7911899                   None                                   None
# 7911900                   None                                   None
#
#                                           landing_page_url type_backend_raw  \
# 0        https://preprints.aijr.org/index.php/ap/prepri...   posted-content
# 1        https://preprints.aijr.org/index.php/ap/prepri...   posted-content
# 2        https://preprints.aijr.org/index.php/ap/prepri...   posted-content
# 3        https://preprints.aijr.org/index.php/ap/prepri...   posted-content
# 4        https://preprints.aijr.org/index.php/ap/prepri...   posted-content
# ...                                                    ...              ...
# 7911896              https://vixra.org/pdf/1409.0090v1.pdf         preprint
# 7911897                    https://vixra.org/abs/1112.0094         preprint
# 7911898              https://vixra.org/pdf/1406.0019v1.pdf         preprint
# 7911899              https://vixra.org/pdf/1306.0105v3.pdf         preprint
# 7911900              https://vixra.org/pdf/1412.0197v3.pdf         preprint
#
#         subtype_backend_raw  \
# 0                  preprint
# 1                  preprint
# 2                  preprint
# 3                  preprint
# 4                  preprint
# ...                     ...
# 7911896                None
# 7911897                None
# 7911898                None
# 7911899                None
# 7911900                None
#
#                                                      title  \
# 0        Bird’s Eye View on the Diagnosis, Treatment, &...
# 1        Doxycycline and Minocycline Drugs as a Treatme...
# 2        A Genetic Perspective of 2019-nCoV in Relation...
# 3        Marine Algae as a Natural Source for Antiviral...
# 4        Possible Prevention of COVID 19 by Using Linol...
# ...                                                    ...
# 7911896                 Three Objections to Modern Physics
# 7911897                               Particle Mass Ratios
# 7911898  Quantum FFF Theory Proposals for Some Unsolved...
# 7911899  Investigation of the Formalism of Particle Dyn...
# 7911900  Electromagnetic Energy and Electromagnetic For...
#
#                                               authors_flat institutions_flat  \
# 0                              Panchalingala, Sai Bhargavi              None
# 1                                         Mostafa, Mohamed              None
# 2                                        Dasgupta, Rimjhim              None
# 3        Musale, Amar S; G., Raja Krishna Kumar; Sapre,...              None
# 4        Subhash, Venkata; G, Raja Krishna Kumar; Sapre...              None
# ...                                                    ...               ...
# 7911896                                      Lubomir Vlcek              None
# 7911897                                         DT Froedge              None
# 7911898                                           Leo Vuyk              None
# 7911899                                        Chi-Yi Chen              None
# 7911900                                    Yu.A. Spirichev              None
#
#         countries_flat relations_json version_label is_version_of  \
# 0                 None           None          None
# 1                 None           None          None
# 2                 None           None          None
# 3                 None           None          None
# 4                 None           None          None
# ...                ...            ...           ...           ...
# 7911896           None           None          None          None
# 7911897           None           None          None          None
# 7911898           None           None          None          None
# 7911899           None           None          None          None
# 7911900           None           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 0                                                              false
# 1                                                              false
# 2                                                              false
# 3                                                              false
# 4                                                              false
# ...                ...          ...        ...                   ...
# 7911896           None         None       None                  None
# 7911897           None         None       None                  None
# 7911898           None         None       None                  None
# 7911899           None         None       None                  None
# 7911900           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 0                             None                None           None
# 1                             None                None           None
# 2                             None                None           None
# 3                             None                None           None
# 4                             None                None           None
# ...                            ...                 ...            ...
# 7911896                       None                None           None
# 7911897                       None                None           None
# 7911898                       None                None           None
# 7911899                       None                None           None
# 7911900                       None                None           None
#
#         raw_relationships_json records_hierarchy date_first_seen  \
# 0                         None            parent      2020-05-03
# 1                         None            parent      2020-04-25
# 2                         None            parent      2020-04-16
# 3                         None            parent      2020-04-15
# 4                         None            parent      2020-04-15
# ...                        ...               ...             ...
# 7911896                   None            parent      2014-09-01
# 7911897                   None            parent      2011-12-01
# 7911898                   None            parent      2014-06-01
# 7911899                   None            parent      2013-06-01
# 7911900                   None            parent      2014-12-01
#
#          publication_year  publication_year_first_seen raw_dates  \
# 0                  2020.0                         2020      None
# 1                  2020.0                         2020      None
# 2                  2020.0                         2020      None
# 3                  2020.0                         2020      None
# 4                  2020.0                         2020      None
# ...                   ...                          ...       ...
# 7911896            2014.0                         2014      None
# 7911897            2011.0                         2011      None
# 7911898            2014.0                         2014      None
# 7911899            2013.0                         2013      None
# 7911900            2014.0                         2014      None
#
#         records_hierarchy_backup parent_record_id dup_group_id  \
# 0                         parent             None         None
# 1                         parent             None         None
# 2                         parent             None         None
# 3                         parent             None         None
# 4                         parent             None         None
# ...                          ...              ...          ...
# 7911896                   parent             None         None
# 7911897                   parent             None         None
# 7911898                   parent             None         None
# 7911899                   parent             None         None
# 7911900                   parent             None         None
#
#         authors_fp_tokenbag  \
# 0                      None
# 1           mohamed_mostafa
# 2          dasgupta_rimjhim
# 3                      None
# 4                      None
# ...                     ...
# 7911896       lubomir_vlcek
# 7911897          dt_froedge
# 7911898            leo_vuyk
# 7911899         chen_chi_yi
# 7911900      a_spirichev_yu
#
#                                             title_clean_v2  \
# 0                                                     None
# 1        doxycycline and minocycline drugs as a treatme...
# 2        a genetic perspective of 2019 ncov in relation...
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 7911896                 three objections to modern physics
# 7911897                               particle mass ratios
# 7911898  quantum fff theory proposals for some unsolved...
# 7911899  investigation of the formalism of particle dyn...
# 7911900  electromagnetic energy and electromagnetic for...
#
#         authors_fp_last_initial authors_fp_last
# 0                          None            None
# 1                     mostafa|m            None
# 2                    dasgupta|r            None
# 3                          None            None
# 4                          None            None
# ...                         ...             ...
# 7911896                 vlcek|l            None
# 7911897               froedge|d            None
# 7911898                  vuyk|l            None
# 7911899                  chen|c            None
# 7911900             spirichev|y            None
#
# [7911901 rows x 35 columns]

# %%
data.columns
# Out:
# Index(['record_id', 'server_name', 'backend', 'doi', 'doi_url',
#        'landing_page_url', 'type_backend_raw', 'subtype_backend_raw', 'title',
#        'authors_flat', 'institutions_flat', 'countries_flat', 'relations_json',
#        'version_label', 'is_version_of', 'is_preprint_of', 'has_preprint',
#        'has_review', 'has_published_version', 'published_version_ids_json',
#        'version_of_ids_json', 'update_to_json', 'raw_relationships_json',
#        'records_hierarchy', 'date_first_seen', 'publication_year',
#        'publication_year_first_seen', 'raw_dates', 'records_hierarchy_backup',
#        'parent_record_id', 'dup_group_id', 'authors_fp_tokenbag',
#        'title_clean_v2', 'authors_fp_last_initial', 'authors_fp_last'],
#       dtype='object')

# %%
data['is_version_of'] = data['is_version_of'].replace('', np.nan)

relation_ship_count = data['is_version_of'].value_counts()
relation_ship_count
# Out:
# is_version_of
# 10.2139/ssrn.2721313                                                                                  152
# 10.5281/zenodo.16899882                                                                                73
# 10.5281/zenodo.15408957                                                                                50
# 10.5281/zenodo.16944712                                                                                29
# 10.5281/zenodo.15571875                                                                                22
#                                                                                                      ...
# 10.20944/preprints202209.0202.v2                                                                        1
# 10.20944/preprints202012.0703.v1;10.20944/preprints202012.0703.v2;10.20944/preprints202012.0703.v3      1
# 10.20944/preprints202012.0703.v1;10.20944/preprints202012.0703.v2;10.20944/preprints202012.0703.v4      1
# 10.20944/preprints202012.0703.v1;10.20944/preprints202012.0703.v3;10.20944/preprints202012.0703.v4      1
# 10.20944/preprints202212.0117.v1                                                                        1
# Name: count, Length: 79895, dtype: int64

# %%
# Columns to duplicate
cols_to_duplicate = ['records_hierarchy', 'parent_record_id','dup_group_id']

# Duplicate the columns with new names
data[['records_hierarchy_dedupe_backup', 'parent_record_id_dedupe_backup', 'dup_group_id_dedupe_backup']] = data[cols_to_duplicate].copy()

data.columns
# Out:
# Index(['record_id', 'server_name', 'backend', 'doi', 'doi_url',
#        'landing_page_url', 'type_backend_raw', 'subtype_backend_raw', 'title',
#        'authors_flat', 'institutions_flat', 'countries_flat', 'relations_json',
#        'version_label', 'is_version_of', 'is_preprint_of', 'has_preprint',
#        'has_review', 'has_published_version', 'published_version_ids_json',
#        'version_of_ids_json', 'update_to_json', 'raw_relationships_json',
#        'records_hierarchy', 'date_first_seen', 'publication_year',
#        'publication_year_first_seen', 'raw_dates', 'records_hierarchy_backup',
#        'parent_record_id', 'dup_group_id', 'authors_fp_tokenbag',
#        'title_clean_v2', 'authors_fp_last_initial', 'authors_fp_last',
#        'records_hierarchy_dedupe_backup', 'parent_record_id_dedupe_backup',
#        'dup_group_id_dedupe_backup'],
#       dtype='object')

# %%
bad_values = {"others", "part_of", "comment", "review"}

mask = ~data["records_hierarchy_backup"].astype(str).str.contains(
    r"\b(" + "|".join(bad_values) + r")\b",
    case=False,
    regex=True
)

data_clean = data[mask].copy()
# Out:
# /tmp/ipykernel_5490/2399585284.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = ~data["records_hierarchy_backup"].astype(str).str.contains(

# %%
data_clean['records_hierarchy'].unique()
# Out:
# array(['parent', 'parent - duplicate (SSRN)',
#        'parent - duplicate (AfricArXiv)',
#        'parent - duplicate (AMRC Open Research)',
#        'parent - duplicate (Open Science Framework)',
#        'parent - duplicate (APSA Preprints)',
#        'parent - duplicate (medRxiv)',
#        'parent - duplicate (ResearchGate)', 'parent - duplicate (arXiv)',
#        'parent - duplicate (SocArXiv)',
#        'parent - duplicate (PREPRINTS.RU)',
#        'parent - duplicate (MediArXiv)',
#        'parent - duplicate (ARPHA Preprints)',
#        'parent - duplicate (Research Square)',
#        'parent - duplicate (Authorea Inc.)',
#        'parent - duplicate (bioRxiv)', 'parent - duplicate (Zenodo)',
#        'parent - duplicate (ART-Dok)', 'parent - duplicate (HAL)',
#        'parent - duplicate (Social Science Open Access Repository)',
#        'parent - duplicate (Humanities Commons CORE)',
#        'parent - duplicate (Advance)',
#        'parent - duplicate (AgEcon Search)',
#        'parent - duplicate (Preprints.org)',
#        'parent - duplicate (PsyArXiv)', 'parent - duplicate (EdArXiv)',
#        'parent - duplicate (Cambridge Open Engage)',
#        'parent - duplicate (TechRxiv)',
#        'parent - duplicate (Thesis Commons)',
#        'parent - duplicate (RePEc: Research Papers in Economics)',
#        'parent - duplicate (EconStor Preprints)',
#        'parent - duplicate (Munich Personal RePEc Archive)',
#        'parent - duplicate (Organic Eprints)',
#        'parent - duplicate (National Bureau of Economic Research)',
#        'parent - duplicate (AgriRxiv)', 'parent - duplicate (MetaArXiv)',
#        'parent - duplicate (VeriXiv)', 'parent - duplicate (INA-Rxiv)',
#        'parent - duplicate (Earth and Space Science Open Archive)',
#        'parent - duplicate (Arabixiv)',
#        'parent - duplicate (LIS Scholarship Archive)',
#        'parent - duplicate (PeerJ Preprints)',
#        'parent - duplicate (ChemRxiv)', 'parent - duplicate (EcoEvoRxiv)',
#        'parent - duplicate (ScienceOpen Preprints)',
#        'parent - duplicate (JMIR Preprints)',
#        'parent - duplicate (engrXiv)', 'parent - duplicate (EarthArXiv)',
#        'parent - duplicate (Qeios)', 'parent - duplicate (eLife)',
#        'parent - duplicate (Wellcome Open Research)',
#        'parent - duplicate (F1000Research)',
#        'parent - duplicate (EGUsphere)',
#        'parent - duplicate (ResearchHub)',
#        'parent - duplicate (BioHackrXiv)',
#        'parent - duplicate (BodoArXiv)',
#        'parent - duplicate (CERN document server)',
#        'parent - duplicate (IndiaRxiv)',
#        'parent - duplicate (Beilstein Archives)',
#        'parent - duplicate (CoP)', 'parent - duplicate (CogPrints)',
#        'parent - duplicate (Covid-19 Preprints)',
#        'parent - duplicate (CrimRxiv)',
#        'parent - duplicate (Law Archive)',
#        'parent - duplicate (CrossAsia-Repository)',
#        'parent - duplicate (DSpace@MIT)',
#        'parent - duplicate (IACR Cryptology ePrint Archive)',
#        'parent - duplicate (Digital Access to Scholarship at Harvard (DASH) (Harvard University))',
#        'parent - duplicate (E-LIS Repository)',
#        'parent - duplicate (ECSarXiv)',
#        'parent - duplicate (EasyChair preprint)',
#        'parent - duplicate (LSE Research Online Documents on Economics)',
#        'parent - duplicate (Frenxiv)', 'parent - duplicate (MarXiv)',
#        'parent - duplicate (Electron Colloquium Comput Complex)',
#        'parent - duplicate (Encyclopedia)',
#        'parent - duplicate (EnerarXiv)',
#        'parent - duplicate (Nature Precedings)',
#        'parent - duplicate (viXra)',
#        'parent - duplicate (Open Research Africa)',
#        'parent - duplicate (FocUS Archive)',
#        'parent - duplicate (Gates Open Research)',
#        'parent - duplicate (PhilSci-Archive)',
#        'parent - duplicate (HRB Open Research)',
#        'parent - duplicate (NutriXiv)', 'parent - duplicate (SportRxiv)',
#        'parent - duplicate (searchRxiv)', 'parent - duplicate (Jxiv)',
#        'parent - duplicate (Keldysh Institute Preprints)',
#        'parent - duplicate (LatArXiv)',
#        'parent - duplicate (MNI Open Research)',
#        'parent - duplicate (MindRxiv)',
#        'parent - duplicate (NewAddictionsX)',
#        'parent - duplicate (Open Research Europe)',
#        'parent - duplicate (AIJR Preprints)',
#        'parent - duplicate (PaleorXiv)',
#        'parent - duplicate (Oroboros Instruments)',
#        'parent - duplicate (SciELO Preprints)',
#        'parent - duplicate (Prepublicaciones OpenCiencia)',
#        'parent - duplicate (PropylaeumDok)',
#        'parent - duplicate (UCL Open Environment)',
#        'parent - duplicate (UnisaRxiv)', 'parent - duplicate (prepare@u)',
#        'parent - duplicate (SAE Mobilus®)',
#        'parent - duplicate (Therapoid)'], dtype=object)

# %%
data_clean['records_hierarchy_backup'].value_counts().head(60)
# Out:
# records_hierarchy_backup
# parent                              7771465
# version                              102316
# publish_version                       12888
# mirror (AgEcon Search)                 6607
# mirror (arXiv)                         6419
# child                                  2061
# mirror (ResearchGate)                   827
# correction                              354
# mirror (Zenodo)                         191
# mirror (bioRxiv)                         29
# mirror (SSRN)                            23
# mirror (Open Science Framework)          21
# mirror (Humanities Commons CORE)         16
# parent_duplicate                          4
# mirror (AfricArXiv)                       2
# mirror (Research Square)                  2
# mirror (EarthArXiv)                       2
# mirror (TechRxiv)                         1
# mirror (eLife)                            1
# mirror (Oroboros Instruments)             1
# mirror (medRxiv)                          1
# mirror (Law Archive)                      1
# mirror (Thesis Commons)                   1
# mirror (SocArXiv)                         1
# mirror (AgriRxiv)                         1
# Name: count, dtype: int64

# %%
len(data_clean["server_name"].value_counts())
# Out:
# 109

# %% [markdown]
# # extract_has_version_dois

# %%
import pandas as pd
import json

VERSION_RELATION_TYPES = {
    # "HasPart",
    "IsIdenticalTo",
    # "IsSupplementedBy",
    # "IsSupplementTo",
    "IsNewVersionOf",
    "IsVersionOf",
    # "IsPartOf",
    "IsPreviousVersionOf",
    "HasVersion",
}

# Pre-build the quick string pre-check
VERSION_RELATION_PATTERNS = tuple(f'"{r}"' for r in VERSION_RELATION_TYPES)


def extract_has_version_dois(relations_json_value):
    """
    Extract DOIs whose relationType is any of VERSION_RELATION_TYPES from relations_json.
    Returns semicolon-joined string or None.
    """
    if pd.isna(relations_json_value) or not relations_json_value:
        return None

    # Quick pre-check: skip JSON parsing if none of the patterns are present
    if not any(pattern in relations_json_value for pattern in VERSION_RELATION_PATTERNS):
        return None

    try:
        relations = json.loads(relations_json_value)
        dois = [
            r["relatedIdentifier"]
            for r in relations
            if isinstance(r, dict)
            and r.get("relationType") in VERSION_RELATION_TYPES
            and r.get("relatedIdentifierType") == "DOI"
            and r.get("relatedIdentifier")
        ]
        return ";".join(dois) if dois else None
    except (json.JSONDecodeError, TypeError):
        return None


def apply_extract_has_version(df, col="relations_json", new_col="has_version_dois", chunksize=500_000):
    """
    Apply extraction in chunks to manage memory on large DataFrames.
    Adds `new_col` to df in-place.
    """
    results = []
    total = len(df)

    for start in range(0, total, chunksize):
        end = min(start + chunksize, total)
        chunk = df[col].iloc[start:end]
        results.append(chunk.map(extract_has_version_dois))
        print(f"Processed {end:,} / {total:,} rows", end="\r")

    df[new_col] = pd.concat(results)
    print(f"\nDone. Non-null values: {df[new_col].notna().sum():,}")
    return df


# Usage
# df = apply_extract_has_version(df)

# %%
data_clean_isversionof = apply_extract_has_version(data_clean)
data_clean_isversionof
# Out:
# Processed 7,905,699 / 7,905,699 rows
# Done. Non-null values: 1,476,586
#                                record_id     server_name   backend  \
# 0        crossref::10.21467/preprints.48  AIJR Preprints  crossref
# 1        crossref::10.21467/preprints.43  AIJR Preprints  crossref
# 2        crossref::10.21467/preprints.39  AIJR Preprints  crossref
# 3        crossref::10.21467/preprints.38  AIJR Preprints  crossref
# 4        crossref::10.21467/preprints.36  AIJR Preprints  crossref
# ...                                  ...             ...       ...
# 7911896             openalex::W999325625           viXra  openalex
# 7911897             openalex::W999460032           viXra  openalex
# 7911898              openalex::W99967155           viXra  openalex
# 7911899             openalex::W999790414           viXra  openalex
# 7911900             openalex::W999805801           viXra  openalex
#
#                            doi                                doi_url  \
# 0        10.21467/preprints.48  https://doi.org/10.21467/preprints.48
# 1        10.21467/preprints.43  https://doi.org/10.21467/preprints.43
# 2        10.21467/preprints.39  https://doi.org/10.21467/preprints.39
# 3        10.21467/preprints.38  https://doi.org/10.21467/preprints.38
# 4        10.21467/preprints.36  https://doi.org/10.21467/preprints.36
# ...                        ...                                    ...
# 7911896                   None                                   None
# 7911897                   None                                   None
# 7911898                   None                                   None
# 7911899                   None                                   None
# 7911900                   None                                   None
#
#                                           landing_page_url type_backend_raw  \
# 0        https://preprints.aijr.org/index.php/ap/prepri...   posted-content
# 1        https://preprints.aijr.org/index.php/ap/prepri...   posted-content
# 2        https://preprints.aijr.org/index.php/ap/prepri...   posted-content
# 3        https://preprints.aijr.org/index.php/ap/prepri...   posted-content
# 4        https://preprints.aijr.org/index.php/ap/prepri...   posted-content
# ...                                                    ...              ...
# 7911896              https://vixra.org/pdf/1409.0090v1.pdf         preprint
# 7911897                    https://vixra.org/abs/1112.0094         preprint
# 7911898              https://vixra.org/pdf/1406.0019v1.pdf         preprint
# 7911899              https://vixra.org/pdf/1306.0105v3.pdf         preprint
# 7911900              https://vixra.org/pdf/1412.0197v3.pdf         preprint
#
#         subtype_backend_raw  \
# 0                  preprint
# 1                  preprint
# 2                  preprint
# 3                  preprint
# 4                  preprint
# ...                     ...
# 7911896                None
# 7911897                None
# 7911898                None
# 7911899                None
# 7911900                None
#
#                                                      title  \
# 0        Bird’s Eye View on the Diagnosis, Treatment, &...
# 1        Doxycycline and Minocycline Drugs as a Treatme...
# 2        A Genetic Perspective of 2019-nCoV in Relation...
# 3        Marine Algae as a Natural Source for Antiviral...
# 4        Possible Prevention of COVID 19 by Using Linol...
# ...                                                    ...
# 7911896                 Three Objections to Modern Physics
# 7911897                               Particle Mass Ratios
# 7911898  Quantum FFF Theory Proposals for Some Unsolved...
# 7911899  Investigation of the Formalism of Particle Dyn...
# 7911900  Electromagnetic Energy and Electromagnetic For...
#
#                                               authors_flat institutions_flat  \
# 0                              Panchalingala, Sai Bhargavi              None
# 1                                         Mostafa, Mohamed              None
# 2                                        Dasgupta, Rimjhim              None
# 3        Musale, Amar S; G., Raja Krishna Kumar; Sapre,...              None
# 4        Subhash, Venkata; G, Raja Krishna Kumar; Sapre...              None
# ...                                                    ...               ...
# 7911896                                      Lubomir Vlcek              None
# 7911897                                         DT Froedge              None
# 7911898                                           Leo Vuyk              None
# 7911899                                        Chi-Yi Chen              None
# 7911900                                    Yu.A. Spirichev              None
#
#         countries_flat relations_json version_label is_version_of  \
# 0                 None           None          None           NaN
# 1                 None           None          None           NaN
# 2                 None           None          None           NaN
# 3                 None           None          None           NaN
# 4                 None           None          None           NaN
# ...                ...            ...           ...           ...
# 7911896           None           None          None          None
# 7911897           None           None          None          None
# 7911898           None           None          None          None
# 7911899           None           None          None          None
# 7911900           None           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 0                                                              false
# 1                                                              false
# 2                                                              false
# 3                                                              false
# 4                                                              false
# ...                ...          ...        ...                   ...
# 7911896           None         None       None                  None
# 7911897           None         None       None                  None
# 7911898           None         None       None                  None
# 7911899           None         None       None                  None
# 7911900           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 0                             None                None           None
# 1                             None                None           None
# 2                             None                None           None
# 3                             None                None           None
# 4                             None                None           None
# ...                            ...                 ...            ...
# 7911896                       None                None           None
# 7911897                       None                None           None
# 7911898                       None                None           None
# 7911899                       None                None           None
# 7911900                       None                None           None
#
#         raw_relationships_json records_hierarchy date_first_seen  \
# 0                         None            parent      2020-05-03
# 1                         None            parent      2020-04-25
# 2                         None            parent      2020-04-16
# 3                         None            parent      2020-04-15
# 4                         None            parent      2020-04-15
# ...                        ...               ...             ...
# 7911896                   None            parent      2014-09-01
# 7911897                   None            parent      2011-12-01
# 7911898                   None            parent      2014-06-01
# 7911899                   None            parent      2013-06-01
# 7911900                   None            parent      2014-12-01
#
#          publication_year  publication_year_first_seen raw_dates  \
# 0                  2020.0                         2020      None
# 1                  2020.0                         2020      None
# 2                  2020.0                         2020      None
# 3                  2020.0                         2020      None
# 4                  2020.0                         2020      None
# ...                   ...                          ...       ...
# 7911896            2014.0                         2014      None
# 7911897            2011.0                         2011      None
# 7911898            2014.0                         2014      None
# 7911899            2013.0                         2013      None
# 7911900            2014.0                         2014      None
#
#         records_hierarchy_backup parent_record_id dup_group_id  \
# 0                         parent             None         None
# 1                         parent             None         None
# 2                         parent             None         None
# 3                         parent             None         None
# 4                         parent             None         None
# ...                          ...              ...          ...
# 7911896                   parent             None         None
# 7911897                   parent             None         None
# 7911898                   parent             None         None
# 7911899                   parent             None         None
# 7911900                   parent             None         None
#
#         authors_fp_tokenbag  \
# 0                      None
# 1           mohamed_mostafa
# 2          dasgupta_rimjhim
# 3                      None
# 4                      None
# ...                     ...
# 7911896       lubomir_vlcek
# 7911897          dt_froedge
# 7911898            leo_vuyk
# 7911899         chen_chi_yi
# 7911900      a_spirichev_yu
#
#                                             title_clean_v2  \
# 0                                                     None
# 1        doxycycline and minocycline drugs as a treatme...
# 2        a genetic perspective of 2019 ncov in relation...
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 7911896                 three objections to modern physics
# 7911897                               particle mass ratios
# 7911898  quantum fff theory proposals for some unsolved...
# 7911899  investigation of the formalism of particle dyn...
# 7911900  electromagnetic energy and electromagnetic for...
#
#         authors_fp_last_initial authors_fp_last  \
# 0                          None            None
# 1                     mostafa|m            None
# 2                    dasgupta|r            None
# 3                          None            None
# 4                          None            None
# ...                         ...             ...
# 7911896                 vlcek|l            None
# 7911897               froedge|d            None
# 7911898                  vuyk|l            None
# 7911899                  chen|c            None
# 7911900             spirichev|y            None
#
#         records_hierarchy_dedupe_backup parent_record_id_dedupe_backup  \
# 0                                parent                           None
# 1                                parent                           None
# 2                                parent                           None
# 3                                parent                           None
# 4                                parent                           None
# ...                                 ...                            ...
# 7911896                          parent                           None
# 7911897                          parent                           None
# 7911898                          parent                           None
# 7911899                          parent                           None
# 7911900                          parent                           None
#
#         dup_group_id_dedupe_backup has_version_dois
# 0                             None             None
# 1                             None             None
# 2                             None             None
# 3                             None             None
# 4                             None             None
# ...                            ...              ...
# 7911896                       None             None
# 7911897                       None             None
# 7911898                       None             None
# 7911899                       None             None
# 7911900                       None             None
#
# [7905699 rows x 39 columns]

# %%
def has_relations_but_no_has_version(relations_json_value):
    """
    Returns True if the cell has {"relatedIdentifier" patterns 
    but none with relationType == 'HasVersion'.
    """
    if pd.isna(relations_json_value) or not relations_json_value:
        return False
    
    if '"relatedIdentifier"' not in relations_json_value:
        return False
    
    # Has relatedIdentifier but no HasVersion at all
    return '"HasVersion"' not in relations_json_value


# --- Get the subset of rows matching this condition ---
mask = data_clean_isversionof["relations_json"].map(has_relations_but_no_has_version)
df_no_has_version = data_clean_isversionof[mask]

print(f"Rows with relatedIdentifier but no HasVersion: {mask.sum():,}")
print(f"Out of rows with any relatedIdentifier: {data_clean_isversionof['relations_json'].str.contains('relatedIdentifier', na=False).sum():,}")
# Out:
# Rows with relatedIdentifier but no HasVersion: 1,401,165
# Out of rows with any relatedIdentifier: 1,480,296

# %%
import pandas as pd
import json
from collections import Counter

def get_all_relation_types(df, col="relations_json", chunksize=500_000):
    """
    Extract and count all distinct relationType values across the entire DataFrame.
    Returns a sorted DataFrame with relationType and their counts.
    """
    relation_type_counter = Counter()
    total = len(df)

    for start in range(0, total, chunksize):
        end = min(start + chunksize, total)
        chunk = data_clean_isversionof[col].iloc[start:end].dropna()

        for val in chunk:
            if '"relationType"' not in val:
                continue
            try:
                relations = json.loads(val)
                for r in relations:
                    if isinstance(r, dict) and r.get("relationType"):
                        relation_type_counter[r["relationType"]] += 1
            except (json.JSONDecodeError, TypeError):
                pass

        print(f"Processed {end:,} / {total:,} rows", end="\r")

    print("\nDone.")

    result = pd.DataFrame(
        relation_type_counter.most_common(),
        columns=["relationType", "count"]
    )
    result["count"] = result["count"].astype(int)
    result["percentage"] = (result["count"] / result["count"].sum() * 100).round(2)

    return result


# Usage
relation_types_df = get_all_relation_types(data_clean_isversionof)
print(relation_types_df.to_string(index=False))
# Out:
# Processed 7,905,699 / 7,905,699 rows
# Done.
#        relationType   count  percentage
#         IsVersionOf 1394754       88.19
#          HasVersion  111412        7.04
#      IsSupplementTo   13772        0.87
#            IsPartOf   10960        0.69
#               Cites   10106        0.64
#      IsNewVersionOf    7516        0.48
#          References    6913        0.44
#    IsSupplementedBy    5471        0.35
#           Continues    5092        0.32
#       IsDerivedFrom    2901        0.18
# IsPreviousVersionOf    2404        0.15
#      IsReferencedBy    1517        0.10
#       IsContinuedBy    1211        0.08
#       IsIdenticalTo    1071        0.07
#             HasPart     821        0.05
#       IsDescribedBy     756        0.05
#           IsCitedBy     708        0.04
#       IsPublishedIn     640        0.04
#           Describes     584        0.04
#          IsSourceOf     582        0.04
#         HasMetadata     529        0.03
#     IsVariantFormOf     382        0.02
#      IsDocumentedBy     283        0.02
#           Documents     171        0.01
#    IsOriginalFormOf     141        0.01
#           Obsoletes     141        0.01
#            Requires     136        0.01
#        IsCompiledBy     122        0.01
#       IsObsoletedBy     111        0.01
#            Compiles     106        0.01
#             Reviews      72        0.00
#       IsMetadataFor      70        0.00
#        IsReviewedBy      61        0.00
#        IsRequiredBy      49        0.00

# %%
pattern = '"HasVersion"'

mask = data_clean_isversionof['relations_json'].str.contains(pattern, regex=False, na=False)
result2 = data_clean_isversionof[mask]
result2
# Out:
#                                 record_id           server_name   backend  \
# 223589     datacite::10.17181/y2gch-sv478  CERN document server  datacite
# 223590     datacite::10.17181/2gfvb-1rw11  CERN document server  datacite
# 223592     datacite::10.17181/5m6et-4k782  CERN document server  datacite
# 223596     datacite::10.17181/0gb45-t5f55  CERN document server  datacite
# 223598     datacite::10.17181/224fq-qtf30  CERN document server  datacite
# ...                                   ...                   ...       ...
# 4549197  datacite::10.5281/zenodo.5464508                Zenodo  datacite
# 4549199  datacite::10.5281/zenodo.5477448                Zenodo  datacite
# 4549201  datacite::10.5281/zenodo.5482410                Zenodo  datacite
# 4549203  datacite::10.5281/zenodo.5482851                Zenodo  datacite
# 4549205  datacite::10.5281/zenodo.5493584                Zenodo  datacite
#
#                             doi                                 doi_url  \
# 223589     10.17181/y2gch-sv478    https://doi.org/10.17181/y2gch-sv478
# 223590     10.17181/2gfvb-1rw11    https://doi.org/10.17181/2gfvb-1rw11
# 223592     10.17181/5m6et-4k782    https://doi.org/10.17181/5m6et-4k782
# 223596     10.17181/0gb45-t5f55    https://doi.org/10.17181/0gb45-t5f55
# 223598     10.17181/224fq-qtf30    https://doi.org/10.17181/224fq-qtf30
# ...                         ...                                     ...
# 4549197  10.5281/zenodo.5464508  https://doi.org/10.5281/zenodo.5464508
# 4549199  10.5281/zenodo.5477448  https://doi.org/10.5281/zenodo.5477448
# 4549201  10.5281/zenodo.5482410  https://doi.org/10.5281/zenodo.5482410
# 4549203  10.5281/zenodo.5482851  https://doi.org/10.5281/zenodo.5482851
# 4549205  10.5281/zenodo.5493584  https://doi.org/10.5281/zenodo.5493584
#
#                                          landing_page_url type_backend_raw  \
# 223589   https://repository.cern/doi/10.17181/y2gch-sv478             Text
# 223590   https://repository.cern/doi/10.17181/2gfvb-1rw11             Text
# 223592   https://repository.cern/doi/10.17181/5m6et-4k782         Preprint
# 223596   https://repository.cern/doi/10.17181/0gb45-t5f55             Text
# 223598   https://repository.cern/doi/10.17181/224fq-qtf30             Text
# ...                                                   ...              ...
# 4549197                 https://zenodo.org/record/5464508             Text
# 4549199                 https://zenodo.org/record/5477448             Text
# 4549201                 https://zenodo.org/record/5482410             Text
# 4549203                 https://zenodo.org/record/5482851             Text
# 4549205                 https://zenodo.org/record/5493584             Text
#
#         subtype_backend_raw  \
# 223589       Technical note
# 223590       Technical note
# 223592
# 223596
# 223598       Technical note
# ...                     ...
# 4549197            Preprint
# 4549199            Preprint
# 4549201            Preprint
# 4549203            Preprint
# 4549205            Preprint
#
#                                                      title  \
# 223589   Recovery of bremsstrahlung photons in a FCC-ee...
# 223590          A selection of benchmark studies at FCC-ee
# 223592   FCC-ee Detector requirements: geometric accept...
# 223596   Accelerator and physics requirements for the c...
# 223598   Particle Physics considerations for the FCC-ee...
# ...                                                    ...
# 4549197  Measuring trust in automated driving using a m...
# 4549199                                Spin ½ and Matrices
# 4549201  Wormholes Do Not Exist, They are Mathematical ...
# 4549203  Towards a Global Public Repository of Communit...
# 4549205  Data from paper "Targeted Search for Weak Sate...
#
#                                               authors_flat  \
# 223589                  Perez, Emmanuel; Selvaggi, Michele
# 223590                      The FCC PED Coordination group
# 223592                         Blondel, Alain; Dam, Mogens
# 223596   Aßmann, Ralph; Bauche, Jeremie; Barber, Desmon...
# 223598   Blondel, Alain; Grojean, Christophe; Janot, Pa...
# ...                                                    ...
# 4549197  Clement, Philipp; Danzinger, Herbert; Veledar,...
# 4549199                              Ruggeri, Francesco R.
# 4549201                                        Haug, Espen
# 4549203  Samuel, Robyn M.; Meyer, Raissa; Buttigieg, Pi...
# 4549205  Prabu, Steve; Hancock, Paul; Zhang, Xiang; Tin...
#
#                                          institutions_flat countries_flat  \
# 223589                                                CERN           None
# 223590                                                None           None
# 223592   LPNHE, Paris-Sorbonne, FRANCE; Niels Bohr Isti...           None
# 223596   DESY; CERN; University of Geneva; Istituto Naz...           None
# 223598   LPNHE Paris and Université de Genève; DESY, Ha...           None
# ...                                                    ...            ...
# 4549197  AVL List GmbH; University of Graz; Graz Univer...           None
# 4549199                                               None           None
# 4549201              Norwegian University of Life Sciences           None
# 4549203  School of Ocean and Earth Science, University ...           None
# 4549205                           Curtin University; CSIRO           None
#
#                                             relations_json  \
# 223589   [{"relatedIdentifier": "10.17181/87nyk-0rg63",...
# 223590   [{"relatedIdentifier": "10.17181/r7xwv-3s961",...
# 223592   [{"relatedIdentifier": "10.17181/v47k3-arh69",...
# 223596   [{"relatedIdentifier": "10.17181/zb0qc-acj59",...
# 223598   [{"relatedIdentifier": "10.17181/qttzk-wpe74",...
# ...                                                    ...
# 4549197  [{"relatedIdentifier": "10.5281/zenodo.5464509...
# 4549199  [{"relatedIdentifier": "10.5281/zenodo.5477449...
# 4549201  [{"relatedIdentifier": "10.5281/zenodo.5482411...
# 4549203  [{"relatedIdentifier": "10.5281/zenodo.5482852...
# 4549205  [{"relatedIdentifier": "10.5281/zenodo.5493585...
#
#                 version_label is_version_of is_preprint_of has_preprint  \
# 223589                   None           NaN
# 223590                   None           NaN
# 223592   V2- 5 September 2023           NaN
# 223596                   None           NaN
# 223598                   None           NaN
# ...                       ...           ...            ...          ...
# 4549197              PREPRINT           NaN
# 4549199                     1           NaN
# 4549201                     2           NaN
# 4549203                  None           NaN
# 4549205                  None           NaN
#
#         has_review has_published_version published_version_ids_json  \
# 223589                             false                       None
# 223590                             false                       None
# 223592                             false                       None
# 223596                             false                       None
# 223598                             false                       None
# ...            ...                   ...                        ...
# 4549197                            false                       None
# 4549199                            false                       None
# 4549201                            false                       None
# 4549203                            false                       None
# 4549205                            false                       None
#
#         version_of_ids_json update_to_json  \
# 223589                 None           None
# 223590                 None           None
# 223592                 None           None
# 223596                 None           None
# 223598                 None           None
# ...                     ...            ...
# 4549197                None           None
# 4549199                None           None
# 4549201                None           None
# 4549203                None           None
# 4549205                None           None
#
#                                     raw_relationships_json  \
# 223589   {"client": {"data": {"id": "cern.cds", "type":...
# 223590   {"client": {"data": {"id": "cern.cds", "type":...
# 223592   {"client": {"data": {"id": "cern.cds", "type":...
# 223596   {"client": {"data": {"id": "cern.cds", "type":...
# 223598   {"client": {"data": {"id": "cern.cds", "type":...
# ...                                                    ...
# 4549197  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4549199  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4549201  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4549203  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4549205  {"client": {"data": {"id": "cern.zenodo", "typ...
#
#                                  records_hierarchy date_first_seen  \
# 223589   parent - duplicate (CERN document server)      2023-08-01
# 223590                                      parent      2021-01-01
# 223592                                      parent      2023-08-14
# 223596                                      parent      2023-08-16
# 223598                                      parent      2023-08-18
# ...                                            ...             ...
# 4549197                parent - duplicate (Zenodo)      2021-09-06
# 4549199                                     parent      2021-09-06
# 4549201                parent - duplicate (Zenodo)      2021-09-07
# 4549203                parent - duplicate (Zenodo)      2021-09-07
# 4549205                parent - duplicate (Zenodo)      2021-09-08
#
#          publication_year  publication_year_first_seen  \
# 223589             2023.0                         2023
# 223590             2021.0                         2021
# 223592             2023.0                         2023
# 223596             2023.0                         2023
# 223598             2023.0                         2023
# ...                   ...                          ...
# 4549197            2021.0                         2021
# 4549199            2021.0                         2021
# 4549201            2021.0                         2021
# 4549203            2021.0                         2021
# 4549205            2021.0                         2021
#
#                                               raw_dates  \
# 223589   [{"date": "2023-08-01", "dateType": "Issued"}]
# 223590         [{"date": "2021", "dateType": "Issued"}]
# 223592   [{"date": "2023-09-05", "dateType": "Issued"}]
# 223596   [{"date": "2023-08-16", "dateType": "Issued"}]
# 223598   [{"date": "2023-08-18", "dateType": "Issued"}]
# ...                                                 ...
# 4549197  [{"date": "2021-09-06", "dateType": "Issued"}]
# 4549199  [{"date": "2021-09-06", "dateType": "Issued"}]
# 4549201  [{"date": "2021-09-07", "dateType": "Issued"}]
# 4549203  [{"date": "2021-09-07", "dateType": "Issued"}]
# 4549205  [{"date": "2021-09-08", "dateType": "Issued"}]
#
#         records_hierarchy_backup                  parent_record_id  \
# 223589                    parent    datacite::10.17181/87nyk-0rg63
# 223590                    parent                              None
# 223592                    parent                              None
# 223596                    parent                              None
# 223598                    parent                              None
# ...                          ...                               ...
# 4549197                   parent  datacite::10.5281/zenodo.5464509
# 4549199                   parent                              None
# 4549201                   parent  datacite::10.5281/zenodo.5482411
# 4549203                   parent  datacite::10.5281/zenodo.5482852
# 4549205                   parent  datacite::10.5281/zenodo.5493585
#
#                  dup_group_id  \
# 223589    4143106710772787967
# 223590   11853318414248413722
# 223592    9605108797428949011
# 223596      86457416207560753
# 223598   16853275075220311313
# ...                       ...
# 4549197  16841712529322977442
# 4549199                  None
# 4549201   1018103201769658577
# 4549203  17691485959976298526
# 4549205   5498235216209304411
#
#                                        authors_fp_tokenbag  \
# 223589                     emmanuel_perez;michele_selvaggi
# 223590                      coordination_fcc_group_ped_the
# 223592                            alain_blondel;dam_mogens
# 223596   alain_blondel;andrea_ciarma;angeles_faus_golfe...
# 223598   alain_blondel;christophe_grojean;guy_wilkinson...
# ...                                                    ...
# 4549197  arno_eichberger;clemens_koenczoel;clement_phil...
# 4549199                                francesco_r_ruggeri
# 4549201                                         espen_haug
# 4549203  alison_watts;buttigieg_luigi_pier;christina_pa...
# 4549205  hancock_paul;prabu_steve;steven_tingay;xiang_z...
#
#                                             title_clean_v2  \
# 223589   recovery of bremsstrahlung photons in a fcc ee...
# 223590          a selection of benchmark studies at fcc ee
# 223592   fcc ee detector requirements geometric accepta...
# 223596   accelerator and physics requirements for the c...
# 223598   particle physics considerations for the fcc ee...
# ...                                                    ...
# 4549197  measuring trust in automated driving using a m...
# 4549199                              spin 1 2 and matrices
# 4549201  wormholes do not exist they are mathematical a...
# 4549203  towards a global public repository of communit...
# 4549205  data from paper targeted search for weak satel...
#
#                          authors_fp_last_initial authors_fp_last  \
# 223589                                      None            None
# 223590                                   group|t            None
# 223592                                      None            None
# 223596                                      None            None
# 223598   blondel|a;grojean|c;janot|p;wilkinson|g            None
# ...                                          ...             ...
# 4549197                                     None            None
# 4549199                                ruggeri|f         ruggeri
# 4549201                                     None            None
# 4549203                                     None            None
# 4549205                                     None            None
#
#                    records_hierarchy_dedupe_backup  \
# 223589   parent - duplicate (CERN document server)
# 223590                                      parent
# 223592                                      parent
# 223596                                      parent
# 223598                                      parent
# ...                                            ...
# 4549197                parent - duplicate (Zenodo)
# 4549199                                     parent
# 4549201                parent - duplicate (Zenodo)
# 4549203                parent - duplicate (Zenodo)
# 4549205                parent - duplicate (Zenodo)
#
#            parent_record_id_dedupe_backup dup_group_id_dedupe_backup  \
# 223589     datacite::10.17181/87nyk-0rg63        4143106710772787967
# 223590                               None       11853318414248413722
# 223592                               None        9605108797428949011
# 223596                               None          86457416207560753
# 223598                               None       16853275075220311313
# ...                                   ...                        ...
# 4549197  datacite::10.5281/zenodo.5464509       16841712529322977442
# 4549199                              None                       None
# 4549201  datacite::10.5281/zenodo.5482411        1018103201769658577
# 4549203  datacite::10.5281/zenodo.5482852       17691485959976298526
# 4549205  datacite::10.5281/zenodo.5493585        5498235216209304411
#
#                                   has_version_dois
# 223589                        10.17181/87nyk-0rg63
# 223590                        10.17181/r7xwv-3s961
# 223592   10.17181/v47k3-arh69;10.17181/f1fs5-0jr59
# 223596                        10.17181/zb0qc-acj59
# 223598                        10.17181/qttzk-wpe74
# ...                                            ...
# 4549197                     10.5281/zenodo.5464509
# 4549199                     10.5281/zenodo.5477449
# 4549201                     10.5281/zenodo.5482411
# 4549203                     10.5281/zenodo.5482852
# 4549205                     10.5281/zenodo.5493585
#
# [79014 rows x 39 columns]

# %%
pattern = '"relatedIdentifier"'

mask = data_clean_isversionof['relations_json'].str.contains(pattern, regex=False, na=False)
result = data_clean_isversionof[mask]
result
# Out:
#                                    record_id           server_name   backend  \
# 223569     datacite::10.17181/cern.5m67.mtcg  CERN document server  datacite
# 223570     datacite::10.17181/cern.k7md.n3vz  CERN document server  datacite
# 223571     datacite::10.17181/cern.l5n9.2gcs  CERN document server  datacite
# 223572     datacite::10.17181/cern.0hnz.7z6x  CERN document server  datacite
# 223573     datacite::10.17181/cern.r8qg.wacq  CERN document server  datacite
# ...                                      ...                   ...       ...
# 7469989  datacite::10.48550/arxiv.2505.11244                 arXiv  datacite
# 7469990  datacite::10.48550/arxiv.2505.11272                 arXiv  datacite
# 7469991  datacite::10.48550/arxiv.2505.11372                 arXiv  datacite
# 7469992  datacite::10.48550/arxiv.2505.11408                 arXiv  datacite
# 7469994  datacite::10.48550/arxiv.2505.11498                 arXiv  datacite
#
#                                doi                                    doi_url  \
# 223569     10.17181/cern.5m67.mtcg    https://doi.org/10.17181/cern.5m67.mtcg
# 223570     10.17181/cern.k7md.n3vz    https://doi.org/10.17181/cern.k7md.n3vz
# 223571     10.17181/cern.l5n9.2gcs    https://doi.org/10.17181/cern.l5n9.2gcs
# 223572     10.17181/cern.0hnz.7z6x    https://doi.org/10.17181/cern.0hnz.7z6x
# 223573     10.17181/cern.r8qg.wacq    https://doi.org/10.17181/cern.r8qg.wacq
# ...                            ...                                        ...
# 7469989  10.48550/arxiv.2505.11244  https://doi.org/10.48550/arxiv.2505.11244
# 7469990  10.48550/arxiv.2505.11272  https://doi.org/10.48550/arxiv.2505.11272
# 7469991  10.48550/arxiv.2505.11372  https://doi.org/10.48550/arxiv.2505.11372
# 7469992  10.48550/arxiv.2505.11408  https://doi.org/10.48550/arxiv.2505.11408
# 7469994  10.48550/arxiv.2505.11498  https://doi.org/10.48550/arxiv.2505.11498
#
#                                           landing_page_url type_backend_raw  \
# 223569   https://repository.cern/doi/10.17181/CERN.5M67...             Text
# 223570   https://repository.cern/doi/10.17181/CERN.K7MD...             Text
# 223571   https://repository.cern/doi/10.17181/CERN.L5N9...             Text
# 223572   https://repository.cern/doi/10.17181/CERN.0HNZ...             Text
# 223573   https://repository.cern/doi/10.17181/CERN.R8QG...             Text
# ...                                                    ...              ...
# 7469989                   https://arxiv.org/abs/2505.11244             Text
# 7469990                   https://arxiv.org/abs/2505.11272             Text
# 7469991                   https://arxiv.org/abs/2505.11372             Text
# 7469992                   https://arxiv.org/abs/2505.11408             Text
# 7469994                   https://arxiv.org/abs/2505.11498             Text
#
#         subtype_backend_raw  \
# 223569               Thesis
# 223570               Thesis
# 223571               Thesis
# 223572               Thesis
# 223573               Thesis
# ...                     ...
# 7469989             Article
# 7469990             Article
# 7469991             Article
# 7469992             Article
# 7469994             Article
#
#                                                      title  \
# 223569                           Pushing SUSY's boundaries
# 223570   A Silicon Strip Detector for the Phase II High...
# 223571   A Distributed Monitoring and Control System fo...
# 223572   An all-solid state laser system for the laser ...
# 223573   Improving the Selectivity of the ISOLDE Resona...
# ...                                                    ...
# 7469989  A Review of Tools and Techniques for Optimizat...
# 7469990  Resistivity of non-Galilean invariant two dime...
# 7469991  Increasing delay as a strategy to prove stability
# 7469992  Acceleration Potential and Density Profile of ...
# 7469994  Evolution of granular salty ice analogs for Eu...
#
#                                               authors_flat  \
# 223569                                   Besjes, Geert Jan
# 223570                                García-Argos, Carlos
# 223571                                   Rossel, Ralf Erik
# 223572                                    Rothe, Sebastian
# 223573                                Fink, Daniel Andreas
# ...                                                    ...
# 7469989               Sharma, Aasish Kumar; Kunkel, Julian
# 7469990  Kovalev, V. M.; Entin, M. V.; Kvon, Z. D.; Lev...
# 7469991                 AlSharawi, Ziyad; Cánovas, Jose S.
# 7469992     Istomin, A. Yu.; Kniazev, F. A.; Beskin, V. S.
# 7469994  Ottersberg, Rafael; Pommerol, Antoine; Stöckli...
#
#                           institutions_flat countries_flat  \
# 223569   NIKHEF Amsterdam; Nijmegen U IMAPP           None
# 223570                           Valencia U           None
# 223571                              Mainz U           None
# 223572                Mainz U Inst Kernphys           None
# 223573                         Heidelberg U           None
# ...                                     ...            ...
# 7469989                                None           None
# 7469990                                None           None
# 7469991                                None           None
# 7469992                                None           None
# 7469994                                None           None
#
#                                             relations_json version_label  \
# 223569   [{"relatedIdentifier": "978-94-6259-545-3", "r...          None
# 223570   [{"relatedIdentifier": "10.17181/f704t-8kc16",...          None
# 223571   [{"relatedIdentifier": "10.17181/16k78-yx461",...          None
# 223572   [{"relatedIdentifier": "10.17181/za31q-phx67",...          None
# 223573   [{"relatedIdentifier": "10.17181/t4eej-q2647",...          None
# ...                                                    ...           ...
# 7469989  [{"relatedIdentifier": "10.1177/tobeassigned",...             1
# 7469990  [{"relatedIdentifier": "10.1103/physrevlett.13...             1
# 7469991  [{"relatedIdentifier": "10.1080/10236198.2025....             1
# 7469992  [{"relatedIdentifier": "10.1134/s1063772925701...             1
# 7469994  [{"relatedIdentifier": "10.1016/j.icarus.2025....             1
#
#         is_version_of                  is_preprint_of has_preprint has_review  \
# 223569            NaN            10.17181/3nhw7-23q32
# 223570            NaN            10.17181/f704t-8kc16
# 223571            NaN            10.17181/16k78-yx461
# 223572            NaN            10.17181/za31q-phx67
# 223573            NaN            10.17181/t4eej-q2647
# ...               ...                             ...          ...        ...
# 7469989           NaN            10.1177/tobeassigned
# 7469990           NaN  10.1103/physrevlett.134.196303
# 7469991           NaN   10.1080/10236198.2025.2508263
# 7469992           NaN       10.1134/s1063772925701264
# 7469994           NaN    10.1016/j.icarus.2025.116590
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 223569                   true                       None                None
# 223570                   true                       None                None
# 223571                   true                       None                None
# 223572                   true                       None                None
# 223573                   true                       None                None
# ...                       ...                        ...                 ...
# 7469989                  true                       None                None
# 7469990                  true                       None                None
# 7469991                  true                       None                None
# 7469992                  true                       None                None
# 7469994                  true                       None                None
#
#         update_to_json                             raw_relationships_json  \
# 223569            None  {"client": {"data": {"id": "cern.cds", "type":...
# 223570            None  {"client": {"data": {"id": "cern.cds", "type":...
# 223571            None  {"client": {"data": {"id": "cern.cds", "type":...
# 223572            None  {"client": {"data": {"id": "cern.cds", "type":...
# 223573            None  {"client": {"data": {"id": "cern.cds", "type":...
# ...                ...                                                ...
# 7469989           None  {"client": {"data": {"id": "arxiv.content", "t...
# 7469990           None  {"client": {"data": {"id": "arxiv.content", "t...
# 7469991           None  {"client": {"data": {"id": "arxiv.content", "t...
# 7469992           None  {"client": {"data": {"id": "arxiv.content", "t...
# 7469994           None  {"client": {"data": {"id": "arxiv.content", "t...
#
#                   records_hierarchy date_first_seen  publication_year  \
# 223569                       parent      2015-01-21            2015.0
# 223570   parent - duplicate (arXiv)      2015-01-28            2015.0
# 223571                       parent      2015-11-09            2015.0
# 223572                       parent      2013-02-25            2013.0
# 223573                       parent      2014-04-30            2014.0
# ...                             ...             ...               ...
# 7469989                      parent      2025-05-16            2025.0
# 7469990                      parent      2025-05-16            2025.0
# 7469991                      parent      2025-05-16            2025.0
# 7469992                      parent      2025-05-16            2025.0
# 7469994                      parent      2025-05-16            2025.0
#
#          publication_year_first_seen  \
# 223569                          2015
# 223570                          2015
# 223571                          2015
# 223572                          2013
# 223573                          2014
# ...                              ...
# 7469989                         2025
# 7469990                         2025
# 7469991                         2025
# 7469992                         2025
# 7469994                         2025
#
#                                                  raw_dates  \
# 223569      [{"date": "2015-05-15", "dateType": "Issued"}]
# 223570      [{"date": "2015-05-15", "dateType": "Issued"}]
# 223571      [{"date": "2015-11-09", "dateType": "Issued"}]
# 223572      [{"date": "2013-02-25", "dateType": "Issued"}]
# 223573      [{"date": "2014-04-30", "dateType": "Issued"}]
# ...                                                    ...
# 7469989  [{"date": "2025-05-16T13:38:23Z", "dateInforma...
# 7469990  [{"date": "2025-05-16T14:05:30Z", "dateInforma...
# 7469991  [{"date": "2025-05-16T15:35:13Z", "dateInforma...
# 7469992  [{"date": "2025-05-16T16:17:03Z", "dateInforma...
# 7469994  [{"date": "2025-05-16T17:59:54Z", "dateInforma...
#
#         records_hierarchy_backup                     parent_record_id  \
# 223569                    parent                                 None
# 223570                    parent  datacite::10.48550/arxiv.1501.02903
# 223571                    parent                                 None
# 223572                    parent                                 None
# 223573                    parent                                 None
# ...                          ...                                  ...
# 7469989                   parent                                 None
# 7469990                   parent                                 None
# 7469991                   parent                                 None
# 7469992                   parent                                 None
# 7469994                   parent                                 None
#
#                  dup_group_id                  authors_fp_tokenbag  \
# 223569   14994520479402268836                     besjes_geert_jan
# 223570    2386049772774676724                  argos_carlos_garcia
# 223571   13169882856165365376                     erik_ralf_rossel
# 223572   10706844190754784103                      rothe_sebastian
# 223573    8595515513845681595                  andreas_daniel_fink
# ...                       ...                                  ...
# 7469989                  None    aasish_kumar_sharma;julian_kunkel
# 7469990                  None                                 None
# 7469991                  None       alsharawi_ziyad;canovas_jose_s
# 7469992                  None  a_f_kniazev;a_istomin_yu;beskin_s_v
# 7469994                  None                                 None
#
#                                             title_clean_v2  \
# 223569                           pushing susy s boundaries
# 223570   a silicon strip detector for the phase ii high...
# 223571   a distributed monitoring and control system fo...
# 223572   an all solid state laser system for the laser ...
# 223573   improving the selectivity of the isolde resona...
# ...                                                    ...
# 7469989  a review of tools and techniques for optimizat...
# 7469990                                               None
# 7469991  increasing delay as a strategy to prove stability
# 7469992  acceleration potential and density profile of ...
# 7469994                                               None
#
#               authors_fp_last_initial authors_fp_last  \
# 223569                           None            None
# 223570                           None            None
# 223571                       rossel|r            None
# 223572                        rothe|s            None
# 223573                         fink|d            None
# ...                               ...             ...
# 7469989             kunkel|j;sharma|a            None
# 7469990                          None            None
# 7469991         alsharawi|z;canovas|j            None
# 7469992  beskin|v;istomin|a;kniazev|f            None
# 7469994                          None            None
#
#         records_hierarchy_dedupe_backup       parent_record_id_dedupe_backup  \
# 223569                           parent                                 None
# 223570       parent - duplicate (arXiv)  datacite::10.48550/arxiv.1501.02903
# 223571                           parent                                 None
# 223572                           parent                                 None
# 223573                           parent                                 None
# ...                                 ...                                  ...
# 7469989                          parent                                 None
# 7469990                          parent                                 None
# 7469991                          parent                                 None
# 7469992                          parent                                 None
# 7469994                          parent                                 None
#
#         dup_group_id_dedupe_backup                has_version_dois
# 223569        14994520479402268836            10.17181/3nhw7-23q32
# 223570         2386049772774676724            10.17181/f704t-8kc16
# 223571        13169882856165365376            10.17181/16k78-yx461
# 223572        10706844190754784103            10.17181/za31q-phx67
# 223573         8595515513845681595            10.17181/t4eej-q2647
# ...                            ...                             ...
# 7469989                       None            10.1177/tobeassigned
# 7469990                       None  10.1103/physrevlett.134.196303
# 7469991                       None   10.1080/10236198.2025.2508263
# 7469992                       None       10.1134/s1063772925701264
# 7469994                       None    10.1016/j.icarus.2025.116590
#
# [1480179 rows x 39 columns]

# %%
nothas_version_dois = result[result['has_version_dois'].isna()]
nothas_version_dois
# Out:
#                                record_id           server_name   backend  \
# 280771   datacite::10.48796/20220501-000  CrossAsia-Repository  datacite
# 280772   datacite::10.48796/20220508-000  CrossAsia-Repository  datacite
# 280773   datacite::10.48796/20220508-001  CrossAsia-Repository  datacite
# 4541701  Giunti, Guido; Caulfield, Brian; Guisado-Ferna...
# 4541702  Giunti, Guido; Giunta, Diego H.; Hors-Fraile, ...
#
#                                          institutions_flat countries_flat  \
# 280771                                                None           None
# 280772                                                None           None
# 280773                                                None           None
# 280774                                                None           None
# 280775                                                None           None
# ...                                                    ...            ...
# 4541677                                               None           None
# 4541678                                               None           None
# 4541694                                               None           None
# 4541701   Salumedia Tecnologias; University College Dublin           None
# 4541702  Salumedia Tecnologias; Hospital Italiano de Bu...           None
#
#                                             relations_json version_label  \
# 280771   [{"relatedIdentifier": "https://repository.cro...          None
# 280772   [{"relatedIdentifier": "https://repository.cro...          None
# 280773   [{"relatedIdentifier": "https://repository.cro...          None
# 280774   [{"relatedIdentifier": "https://repository.cro...          None
# 280775   [{"relatedIdentifier": "https://repository.cro...          None
# ...                                                    ...           ...
# 4541677  [{"relatedIdentifier": "doi 10.5281/zenodo.345...          None
# 4541678  [{"relatedIdentifier": "doi 10.5281/zenodo.345...          None
# 4541694  [{"relatedIdentifier": "urn:nbn:it:unipi-20250...          None
# 4541701  [{"relatedIdentifier": "arXiv:1705.03227", "re...          None
# 4541702  [{"relatedIdentifier": "arXiv:1705.03228", "re...          None
#
#         is_version_of is_preprint_of has_preprint has_review  \
# 280771            NaN
# 280772            NaN
# 280773            NaN
# 280774            NaN
# 280775            NaN
# ...               ...            ...          ...        ...
# 4541677           NaN
# 4541678           NaN
# 4541694           NaN
# 4541701           NaN
# 4541702           NaN
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 280771                  false                       None                None
# 280772                  false                       None                None
# 280773                  false                       None                None
# 280774                  false                       None                None
# 280775                  false                       None                None
# ...                       ...                        ...                 ...
# 4541677                 false                       None                None
# 4541678                 false                       None                None
# 4541694                 false                       None                None
# 4541701                 false                       None                None
# 4541702                 false                       None                None
#
#         update_to_json                             raw_relationships_json  \
# 280771            None  {"client": {"data": {"id": "shkl.lofhsj", "typ...
# 280772            None  {"client": {"data": {"id": "shkl.lofhsj", "typ...
# 280773            None  {"client": {"data": {"id": "shkl.lofhsj", "typ...
# 280774            None  {"client": {"data": {"id": "shkl.lofhsj", "typ...
# 280775            None  {"client": {"data": {"id": "shkl.lofhsj", "typ...
# ...                ...                                                ...
# 4541677           None  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4541678           None  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4541694           None  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4541701           None  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4541702           None  {"client": {"data": {"id": "cern.zenodo", "typ...
#
#                    records_hierarchy date_first_seen  publication_year  \
# 280771                        parent      2022-05-10            2022.0
# 280772                        parent      2021-01-01            2021.0
# 280773                        parent      2021-01-01            2021.0
# 280774                        parent      2021-01-01            2021.0
# 280775                        parent      2021-01-01            2021.0
# ...                              ...             ...               ...
# 4541677  parent - duplicate (Zenodo)      2017-03-18            2017.0
# 4541678  parent - duplicate (Zenodo)      2017-03-18            2017.0
# 4541694                       parent      2017-04-30            2017.0
# 4541701   parent - duplicate (arXiv)      2017-05-10            2017.0
# 4541702   parent - duplicate (arXiv)      2017-05-10            2017.0
#
#          publication_year_first_seen  \
# 280771                          2022
# 280772                          2021
# 280773                          2021
# 280774                          2021
# 280775                          2021
# ...                              ...
# 4541677                         2017
# 4541678                         2017
# 4541694                         2017
# 4541701                         2017
# 4541702                         2017
#
#                                               raw_dates  \
# 280771         [{"date": "2022", "dateType": "Issued"}]
# 280772         [{"date": "2021", "dateType": "Issued"}]
# 280773         [{"date": "2021", "dateType": "Issued"}]
# 280774         [{"date": "2021", "dateType": "Issued"}]
# 280775         [{"date": "2021", "dateType": "Issued"}]
# ...                                                 ...
# 4541677  [{"date": "2017-03-18", "dateType": "Issued"}]
# 4541678  [{"date": "2017-03-18", "dateType": "Issued"}]
# 4541694  [{"date": "2017-04-30", "dateType": "Issued"}]
# 4541701  [{"date": "2017-05-10", "dateType": "Issued"}]
# 4541702  [{"date": "2017-05-10", "dateType": "Issued"}]
#
#         records_hierarchy_backup                     parent_record_id  \
# 280771                    parent                                 None
# 280772                    parent                                 None
# 280773                    parent                                 None
# 280774                    parent                                 None
# 280775                    parent                                 None
# ...                          ...                                  ...
# 4541677                   parent      datacite::10.5281/zenodo.400637
# 4541678                   parent      datacite::10.5281/zenodo.221108
# 4541694                   parent                                 None
# 4541701                   parent  datacite::10.48550/arxiv.1705.03227
# 4541702                   parent  datacite::10.48550/arxiv.1705.03228
#
#                               dup_group_id  \
# 280771                                None
# 280772                                None
# 280773                                None
# 280774                                None
# 280775                                None
# ...                                    ...
# 4541677                2244344397505640975
# 4541678                6099717425929547452
# 4541694                               None
# 4541701  relaxed::A1_tokenbag_exact::63245
# 4541702               10993758934354772358
#
#                                        authors_fp_tokenbag  \
# 280771                                       johannes_kurz
# 280772                                                none
# 280773                                                None
# 280774                      christian_gohlert;morse_ronald
# 280775                                                None
# ...                                                    ...
# 4541677                              baruah_gautam_narayan
# 4541678                              baruah_gautam_narayan
# 4541694                             chiara_maria_pievatolo
# 4541701  brian_caulfield;estafania_fernandez_guisado;gi...
# 4541702  diana_karoseviciute;diego_giunta_h;fraile_hors...
#
#                                             title_clean_v2  \
# 280771           locating dashi 大食 in song dynasty sources
# 280772   yanagita kunio and japanese folklore studies i...
# 280773   introduction yanagita kunio in global perspective
# 280774              brief outline of yanagita kunio s life
# 280775   yokai and yanagita kunio a view from the 21st ...
# ...                                                    ...
# 4541677  mathematical proof of a feasible warp drive an...
# 4541678  mathematical proof of a feasible warp drive an...
# 4541694  la bilancia e la spada scienza di stato e valu...
# 4541701  connected health in multiple sclerosis a mobil...
# 4541702  detecting gamification in breast cancer apps a...
#
#         authors_fp_last_initial authors_fp_last  \
# 280771                   kurz|j            None
# 280772                                     None
# 280773                  morse|r            None
# 280774        gohlert|c;morse|r            None
# 280775                 foster|m            None
# ...                         ...             ...
# 4541677                    None            None
# 4541678                    None            None
# 4541694                chiara|p            None
# 4541701                    None            None
# 4541702                    None            None
#
#         records_hierarchy_dedupe_backup       parent_record_id_dedupe_backup  \
# 280771                           parent                                 None
# 280772                           parent                                 None
# 280773                           parent                                 None
# 280774                           parent                                 None
# 280775                           parent                                 None
# ...                                 ...                                  ...
# 4541677     parent - duplicate (Zenodo)      datacite::10.5281/zenodo.400637
# 4541678     parent - duplicate (Zenodo)      datacite::10.5281/zenodo.221108
# 4541694                          parent                                 None
# 4541701      parent - duplicate (arXiv)  datacite::10.48550/arxiv.1705.03227
# 4541702      parent - duplicate (arXiv)  datacite::10.48550/arxiv.1705.03228
#
#                 dup_group_id_dedupe_backup has_version_dois
# 4480603  FEDI 2.1: Fion-Enhanced Distributed Intelligen...
# 4483851  Hidden Mixture-of-Experts: Emergent Bipolar Ro...
# 4488782     Deterministic Three-Frequency Prefilter (D3FP)
# 4488788     Deterministic Three-Frequency PRIMES Prefilter
# 4488796      Deterministic Three-Frequency Prime Prefilter
# 4489073  The Fionic Theory of Consciousness, Cognition,...
# 4493191  Influence of Thermal and Populational Variable...
# 4534271  Memory of the Universe: Rheological Signatures...
#
#                                           authors_flat  \
# 4427835               Artykbayev, Marat Dzhanybekovich
# 4434777                                  Gavant, D. S.
# 4480603                       Chomiuk, Paweł Krzysztof
# 4483851                                  Choi, Seungho
# 4488782                        Cárdenas Campos, Héctor
# 4488788                        Cárdenas Campos, Héctor
# 4488796                        Cárdenas Campos, Héctor
# 4489073                       Chomiuk, Paweł Krzysztof
# 4493191  Gracidas Reyes, Eduardo; Diaz-Arango, Gerardo
# 4534271                                  Zeleny, Tomáš
#
#                                          institutions_flat countries_flat  \
# 4427835                             Independent Researcher           None
# 4434777                                               None           None
# 4480603                                               None           None
# 4483851                                               None           None
# 4488782                                               None           None
# 4488788                                               None           None
# 4488796                                               None           None
# 4489073                                               None           None
# 4493191  Universidad de las Américas Puebla; Universida...           None
# 4534271                                               None           None
#
#                                             relations_json version_label  \
# 4427835  [{"relatedIdentifier": "10.5281/зенодо.1548870...  v1 (English)
# 4434777  [{"relatedIdentifier": "10.5281/zenodo.1393599...          None
# 4480603  [{"relatedIdentifier": "10.5281/zenodo.1722048...          None
# 4483851  [{"relatedIdentifier": "10.5281/zenodo.1735534...        v1.0.0
# 4488782  [{"relatedIdentifier": "10.5281/zenodo.1527762...           1.0
# 4488788  [{"relatedIdentifier": "10.5281/zenodo.1527762...           1.0
# 4488796  [{"relatedIdentifier": "10.5281/zenodo.1527762...           1.0
# 4489073  [{"relatedIdentifier": "10.5281/zenodo.1745372...          None
# 4493191  [{"relatedIdentifier": "10.1371/journal.pone.0...           0.1
# 4534271  [{"relatedIdentifier": "10.5281/zenodo.1800462...          None
#
#                    is_version_of is_preprint_of has_preprint  \
# 4427835  10.5281/зенодо.15488700
# 4434777  10.5281/zenodo.13935996
# 4480603  10.5281/zenodo.17220485
# 4483851  10.5281/zenodo.17355345
# 4488782  10.5281/zenodo.15277629
# 4488788  10.5281/zenodo.15277629
# 4488796  10.5281/zenodo.15277629
# 4489073  10.5281/zenodo.17453722
# 4493191  10.5281/zenodo.16888053
# 4534271  10.5281/zenodo.18004625
#
#                       has_review has_published_version  \
# 4427835                                          false
# 4434777                                          false
# 4480603  10.5281/zenodo.17428408                 false
# 4483851                                          false
# 4488782                                          false
# 4488788                                          false
# 4488796                                          false
# 4489073                                          false
# 4493191                                          false
# 4534271                                          false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 4427835                       None                None           None
# 4434777                       None                None           None
# 4480603                       None                None           None
# 4483851                       None                None           None
# 4488782                       None                None           None
# 4488788                       None                None           None
# 4488796                       None                None           None
# 4489073                       None                None           None
# 4493191                       None                None           None
# 4534271                       None                None           None
#
#                                     raw_relationships_json  \
# 4427835  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4434777  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4480603  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4483851  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4488782  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4488788  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4488796  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4489073  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4493191  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4534271  {"client": {"data": {"id": "cern.zenodo", "typ...
#
#                    records_hierarchy date_first_seen  publication_year  \
# 4427835    parent - duplicate (SSRN)      2025-03-31            2025.0
# 4434777                       parent      2025-06-16            2025.0
# 4480603                       parent      2025-10-11            2025.0
# 4483851                       parent      2025-10-17            2025.0
# 4488782                       parent      2025-10-26            2025.0
# 4488788                       parent      2025-10-26            2025.0
# 4488796                       parent      2025-10-26            2025.0
# 4489073  parent - duplicate (Zenodo)      2025-10-27            2025.0
# 4493191                       parent      2025-09-01            2025.0
# 4534271                       parent      2025-12-23            2025.0
#
#          publication_year_first_seen  \
# 4427835                         2025
# 4434777                         2025
# 4480603                         2025
# 4483851                         2025
# 4488782                         2025
# 4488788                         2025
# 4488796                         2025
# 4489073                         2025
# 4493191                         2025
# 4534271                         2025
#
#                                                  raw_dates  \
# 4427835  [{"date": "2025-03-31", "dateType": "Issued"},...
# 4434777  [{"date": "2025-06-16", "dateType": "Issued"},...
# 4480603     [{"date": "2025-10-11", "dateType": "Issued"}]
# 4483851     [{"date": "2025-10-17", "dateType": "Issued"}]
# 4488782     [{"date": "2025-10-26", "dateType": "Issued"}]
# 4488788     [{"date": "2025-10-26", "dateType": "Issued"}]
# 4488796     [{"date": "2025-10-26", "dateType": "Issued"}]
# 4489073     [{"date": "2025-10-27", "dateType": "Issued"}]
# 4493191  [{"date": "2025-09-01", "dateType": "Issued"},...
# 4534271  [{"date": "2025-12-24", "dateType": "Issued"},...
#
#         records_hierarchy_backup                   parent_record_id  \
# 4427835                   parent     crossref::10.2139/ssrn.5326951
# 4434777                   parent                               None
# 4480603                   parent                               None
# 4483851                   parent                               None
# 4488782                   parent                               None
# 4488788                   parent                               None
# 4488796                   parent                               None
# 4489073                   parent  datacite::10.5281/zenodo.17453721
# 4493191                   parent                               None
# 4534271                   parent                               None
#
#                               dup_group_id  \
# 4427835                1744535453716478300
# 4434777                               None
# 4480603                               None
# 4483851                               None
# 4488782                               None
# 4488788                               None
# 4488796                               None
# 4489073                 324985474322091992
# 4493191  relaxed::A1_tokenbag_exact::45506
# 4534271                               None
#
#                                 authors_fp_tokenbag  \
# 4427835             artykbayev_dzhanybekovich_marat
# 4434777                                  d_gavant_s
# 4480603                     chomiuk_krzysztof_paweł
# 4483851                                choi_seungho
# 4488782                      campos_cardenas_hector
# 4488788                      campos_cardenas_hector
# 4488796                      campos_cardenas_hector
# 4489073                     chomiuk_krzysztof_paweł
# 4493191  arango_diaz_gerardo;eduardo_gracidas_reyes
# 4534271                                tomas_zeleny
#
#                                             title_clean_v2  \
# 4427835  the riemann hypothesis and its proof abstracti...
# 4434777  energy density gravity a scalar potential toy ...
# 4480603  fedi 2 1 fion enhanced distributed intelligenc...
# 4483851  hidden mixture of experts emergent bipolar rou...
# 4488782       deterministic three frequency prefilter d3fp
# 4488788     deterministic three frequency primes prefilter
# 4488796      deterministic three frequency prime prefilter
# 4489073  the fionic theory of consciousness cognition a...
# 4493191  influence of thermal and populational variable...
# 4534271  memory of the universe rheological signatures ...
#
#         authors_fp_last_initial authors_fp_last  \
# 4427835                    None            None
# 4434777                gavant|d            None
# 4480603               chomiuk|p            None
# 4483851                  choi|s            None
# 4488782              cardenas|h            None
# 4488788              cardenas|h            None
# 4488796              cardenas|h            None
# 4489073                    None            None
# 4493191                    None            None
# 4534271                zeleny|t            None
#
#         records_hierarchy_dedupe_backup     parent_record_id_dedupe_backup  \
# 4427835       parent - duplicate (SSRN)     crossref::10.2139/ssrn.5326951
# 4434777                          parent                               None
# 4480603                          parent                               None
# 4483851                          parent                               None
# 4488782                          parent                               None
# 4488788                          parent                               None
# 4488796                          parent                               None
# 4489073     parent - duplicate (Zenodo)  datacite::10.5281/zenodo.17453721
# 4493191                          parent                               None
# 4534271                          parent                               None
#
#                 dup_group_id_dedupe_backup has_version_dois
# 4427835                1744535453716478300             None
# 4434777                               None             None
# 4480603                               None             None
# 4483851                               None             None
# 4488782                               None             None
# 4488788                               None             None
# 4488796                               None             None
# 4489073                 324985474322091992             None
# 4493191  relaxed::A1_tokenbag_exact::45506             None
# 4534271                               None             None

# %%
result['backend'].value_counts()
# Out:
# backend
# datacite    1480179
# Name: count, dtype: int64

# %%
has_version_dois_isna = result[result['has_version_dois'].isna()]
has_version_dois_isna
# Out:
#                                record_id           server_name   backend  \
# 280771   datacite::10.48796/20220501-000  CrossAsia-Repository  datacite
# 280772   datacite::10.48796/20220508-000  CrossAsia-Repository  datacite
# 280773   datacite::10.48796/20220508-001  CrossAsia-Repository  datacite
# 280774   datacite::10.48796/20220508-002  CrossAsia-Repository  datacite
# 280775   datacite::10.48796/20220508-003  CrossAsia-Repository  datacite
# ...                                  ...                   ...       ...
# 4541677  datacite::10.5281/zenodo.400639                Zenodo  datacite
# 4541678  datacite::10.5281/zenodo.400652                Zenodo  datacite
# 4541694  datacite::10.5281/zenodo.570042                Zenodo  datacite
# 4541701  datacite::10.5281/zenodo.573579                Zenodo  datacite
# 4541702  datacite::10.5281/zenodo.573639                Zenodo  datacite
#
#                            doi                                doi_url  \
# 280771   10.48796/20220501-000  https://doi.org/10.48796/20220501-000
# 280772   10.48796/20220508-000  https://doi.org/10.48796/20220508-000
# 280773   10.48796/20220508-001  https://doi.org/10.48796/20220508-001
# 280774   10.48796/20220508-002  https://doi.org/10.48796/20220508-002
# 280775   10.48796/20220508-003  https://doi.org/10.48796/20220508-003
# ...                        ...                                    ...
# 4541677  10.5281/zenodo.400639  https://doi.org/10.5281/zenodo.400639
# 4541678  10.5281/zenodo.400652  https://doi.org/10.5281/zenodo.400652
# 4541694  10.5281/zenodo.570042  https://doi.org/10.5281/zenodo.570042
# 4541701  10.5281/zenodo.573579  https://doi.org/10.5281/zenodo.573579
# 4541702  10.5281/zenodo.573639  https://doi.org/10.5281/zenodo.573639
#
#                                           landing_page_url type_backend_raw  \
# 280771   https://repository.crossasia.org/receive/cross...             Text
# 280772   https://repository.crossasia.org/receive/cross...             Text
# 280773   https://repository.crossasia.org/receive/cross...             Text
# 280774   https://repository.crossasia.org/receive/cross...             Text
# 280775   https://repository.crossasia.org/receive/cross...             Text
# ...                                                    ...              ...
# 4541677                   https://zenodo.org/record/400639             Text
# 4541678                   https://zenodo.org/record/400652             Text
# 4541694                   https://zenodo.org/record/570042             Text
# 4541701                   https://zenodo.org/record/573579             Text
# 4541702                   https://zenodo.org/record/573639             Text
#
#         subtype_backend_raw  \
# 280771              article
# 280772           collection
# 280773              chapter
# 280774              chapter
# 280775              chapter
# ...                     ...
# 4541677            Preprint
# 4541678            Preprint
# 4541694            Preprint
# 4541701            Preprint
# 4541702            Preprint
#
#                                                      title  \
# 280771           Locating Dashi 大食 in Song Dynasty Sources
# 280772   Yanagita Kunio and Japanese Folklore Studies i...
# 280773   Introduction: Yanagita Kunio in Global Perspec...
# 280774              Brief Outline of Yanagita Kunio’s Life
# 280775   Yōkai and Yanagita Kunio: A View from the 21st...
# ...                                                    ...
# 4541677  Mathematical Proof Of A Feasible Warp Drive An...
# 4541678  Mathematical Proof Of A Feasible Warp Drive An...
# 4541694  La Bilancia E La Spada: Scienza Di Stato E Val...
# 4541701  Connected Health In Multiple Sclerosis: A Mobi...
# 4541702  Detecting Gamification In Breast Cancer Apps: ...
#
#                                               authors_flat  \
# 280771                                      Kurz, Johannes
# 280772                                               :None
# 280773                                       Morse, Ronald
# 280774                   Morse, Ronald; Göhlert, Christian
# 280775                                     Foster, Michael
# ...                                                    ...
# 4541677                              Baruah Gautam Narayan
# 4541678                              Baruah Gautam Narayan
# 4541694                             Pievatolo Maria Chiara
# 4541701  Giunti, Guido; Caulfield, Brian; Guisado-Ferna...
# 4541702  Giunti, Guido; Giunta, Diego H.; Hors-Fraile, ...
#
#                                          institutions_flat countries_flat  \
# 280771                                                None           None
# 280772                                                None           None
# 280773                                                None           None
# 280774                                                None           None
# 280775                                                None           None
# ...                                                    ...            ...
# 4541677                                               None           None
# 4541678                                               None           None
# 4541694                                               None           None
# 4541701   Salumedia Tecnologias; University College Dublin           None
# 4541702  Salumedia Tecnologias; Hospital Italiano de Bu...           None
#
#                                             relations_json version_label  \
# 280771   [{"relatedIdentifier": "https://repository.cro...          None
# 280772   [{"relatedIdentifier": "https://repository.cro...          None
# 280773   [{"relatedIdentifier": "https://repository.cro...          None
# 280774   [{"relatedIdentifier": "https://repository.cro...          None
# 280775   [{"relatedIdentifier": "https://repository.cro...          None
# ...                                                    ...           ...
# 4541677  [{"relatedIdentifier": "doi 10.5281/zenodo.345...          None
# 4541678  [{"relatedIdentifier": "doi 10.5281/zenodo.345...          None
# 4541694  [{"relatedIdentifier": "urn:nbn:it:unipi-20250...          None
# 4541701  [{"relatedIdentifier": "arXiv:1705.03227", "re...          None
# 4541702  [{"relatedIdentifier": "arXiv:1705.03228", "re...          None
#
#         is_version_of is_preprint_of has_preprint has_review  \
# 280771            NaN
# 280772            NaN
# 280773            NaN
# 280774            NaN
# 280775            NaN
# ...               ...            ...          ...        ...
# 4541677           NaN
# 4541678           NaN
# 4541694           NaN
# 4541701           NaN
# 4541702           NaN
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 280771                  false                       None                None
# 280772                  false                       None                None
# 280773                  false                       None                None
# 280774                  false                       None                None
# 280775                  false                       None                None
# ...                       ...                        ...                 ...
# 4541677                 false                       None                None
# 4541678                 false                       None                None
# 4541694                 false                       None                None
# 4541701                 false                       None                None
# 4541702                 false                       None                None
#
#         update_to_json                             raw_relationships_json  \
# 280771            None  {"client": {"data": {"id": "shkl.lofhsj", "typ...
# 280772            None  {"client": {"data": {"id": "shkl.lofhsj", "typ...
# 280773            None  {"client": {"data": {"id": "shkl.lofhsj", "typ...
# 280774            None  {"client": {"data": {"id": "shkl.lofhsj", "typ...
# 280775            None  {"client": {"data": {"id": "shkl.lofhsj", "typ...
# ...                ...                                                ...
# 4541677           None  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4541678           None  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4541694           None  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4541701           None  {"client": {"data": {"id": "cern.zenodo", "typ...
# 4541702           None  {"client": {"data": {"id": "cern.zenodo", "typ...
#
#                    records_hierarchy date_first_seen  publication_year  \
# 280771                        parent      2022-05-10            2022.0
# 280772                        parent      2021-01-01            2021.0
# 280773                        parent      2021-01-01            2021.0
# 280774                        parent      2021-01-01            2021.0
# 280775                        parent      2021-01-01            2021.0
# ...                              ...             ...               ...
# 4541677  parent - duplicate (Zenodo)      2017-03-18            2017.0
# 4541678  parent - duplicate (Zenodo)      2017-03-18            2017.0
# 4541694                       parent      2017-04-30            2017.0
# 4541701   parent - duplicate (arXiv)      2017-05-10            2017.0
# 4541702   parent - duplicate (arXiv)      2017-05-10            2017.0
#
#          publication_year_first_seen  \
# 280771                          2022
# 280772                          2021
# 280773                          2021
# 280774                          2021
# 280775                          2021
# ...                              ...
# 4541677                         2017
# 4541678                         2017
# 4541694                         2017
# 4541701                         2017
# 4541702                         2017
#
#                                               raw_dates  \
# 280771         [{"date": "2022", "dateType": "Issued"}]
# 280772         [{"date": "2021", "dateType": "Issued"}]
# 280773         [{"date": "2021", "dateType": "Issued"}]
# 280774         [{"date": "2021", "dateType": "Issued"}]
# 280775         [{"date": "2021", "dateType": "Issued"}]
# ...                                                 ...
# 4541677  [{"date": "2017-03-18", "dateType": "Issued"}]
# 4541678  [{"date": "2017-03-18", "dateType": "Issued"}]
# 4541694  [{"date": "2017-04-30", "dateType": "Issued"}]
# 4541701  [{"date": "2017-05-10", "dateType": "Issued"}]
# 4541702  [{"date": "2017-05-10", "dateType": "Issued"}]
#
#         records_hierarchy_backup                     parent_record_id  \
# 280771                    parent                                 None
# 280772                    parent                                 None
# 280773                    parent                                 None
# 280774                    parent                                 None
# 280775                    parent                                 None
# ...                          ...                                  ...
# 4541677                   parent      datacite::10.5281/zenodo.400637
# 4541678                   parent      datacite::10.5281/zenodo.221108
# 4541694                   parent                                 None
# 4541701                   parent  datacite::10.48550/arxiv.1705.03227
# 4541702                   parent  datacite::10.48550/arxiv.1705.03228
#
#                               dup_group_id  \
# 280771                                None
# 280772                                None
# 280773                                None
# 280774                                None
# 280775                                None
# ...                                    ...
# 4541677                2244344397505640975
# 4541678                6099717425929547452
# 4541694                               None
# 4541701  relaxed::A1_tokenbag_exact::63245
# 4541702               10993758934354772358
#
#                                        authors_fp_tokenbag  \
# 280771                                       johannes_kurz
# 280772                                                none
# 280773                                                None
# 280774                      christian_gohlert;morse_ronald
# 280775                                                None
# ...                                                    ...
# 4541677                              baruah_gautam_narayan
# 4541678                              baruah_gautam_narayan
# 4541694                             chiara_maria_pievatolo
# 4541701  brian_caulfield;estafania_fernandez_guisado;gi...
# 4541702  diana_karoseviciute;diego_giunta_h;fraile_hors...
#
#                                             title_clean_v2  \
# 280771           locating dashi 大食 in song dynasty sources
# 280772   yanagita kunio and japanese folklore studies i...
# 280773   introduction yanagita kunio in global perspective
# 280774              brief outline of yanagita kunio s life
# 280775   yokai and yanagita kunio a view from the 21st ...
# ...                                                    ...
# 4541677  mathematical proof of a feasible warp drive an...
# 4541678  mathematical proof of a feasible warp drive an...
# 4541694  la bilancia e la spada scienza di stato e valu...
# 4541701  connected health in multiple sclerosis a mobil...
# 4541702  detecting gamification in breast cancer apps a...
#
#         authors_fp_last_initial authors_fp_last  \
# 280771                   kurz|j            None
# 280772                                     None
# 280773                  morse|r            None
# 280774        gohlert|c;morse|r            None
# 280775                 foster|m            None
# ...                         ...             ...
# 4541677                    None            None
# 4541678                    None            None
# 4541694                chiara|p            None
# 4541701                    None            None
# 4541702                    None            None
#
#         records_hierarchy_dedupe_backup       parent_record_id_dedupe_backup  \
# 280771                           parent                                 None
# 280772                           parent                                 None
# 280773                           parent                                 None
# 280774                           parent                                 None
# 280775                           parent                                 None
# ...                                 ...                                  ...
# 4541677     parent - duplicate (Zenodo)      datacite::10.5281/zenodo.400637
# 4541678     parent - duplicate (Zenodo)      datacite::10.5281/zenodo.221108
# 4541694                          parent                                 None
# 4541701      parent - duplicate (arXiv)  datacite::10.48550/arxiv.1705.03227
# 4541702      parent - duplicate (arXiv)  datacite::10.48550/arxiv.1705.03228
#
#                 dup_group_id_dedupe_backup has_version_dois
# 280771                                None             None
# 280772                                None             None
# 280773                                None             None
# 280774                                None             None
# 280775                                None             None
# ...                                    ...              ...
# 4541677                2244344397505640975             None
# 4541678                6099717425929547452             None
# 4541694                               None             None
# 4541701  relaxed::A1_tokenbag_exact::63245             None
# 4541702               10993758934354772358             None
#
# [3593 rows x 39 columns]

# %%
has_version_dois_isna['server_name'].value_counts()
# Out:
# server_name
# Open Science Framework    2335
# CrossAsia-Repository       479
# Zenodo                     269
# PsyArXiv                   219
# EarthArXiv                 102
# MarXiv                      80
# engrXiv                     43
# Arabixiv                    25
# PaleorXiv                   24
# Thesis Commons               8
# MindRxiv                     8
# AgriRxiv                     1
# Name: count, dtype: int64

# %%
get_all_relation_types(has_version_dois_isna)
# Out:
# Processed 3,593 / 3,593 rows
# Done.
# Empty DataFrame
# Columns: [relationType, count, percentage]
# Index: []

# %%
pattern = '"IsPreviousVersionOf"'

mask = has_version_dois_isna['relations_json'].str.contains(pattern, regex=False, na=False)
result3 = has_version_dois_isna[mask]
result3
# Out:
#                                  record_id             server_name   backend  \
# 1789219    datacite::10.17605/osf.io/8crzu  Open Science Framework  datacite
# 1789222    datacite::10.17605/osf.io/utnnu  Open Science Framework  datacite
# 1789224    datacite::10.17605/osf.io/aypws  Open Science Framework  datacite
# 1789230    datacite::10.17605/osf.io/tjk9y  Open Science Framework  datacite
# 1789231    datacite::10.17605/osf.io/tvbgf  Open Science Framework  datacite
# ...                                    ...                     ...       ...
# 1797483    datacite::10.17605/osf.io/r5mga                PsyArXiv  datacite
# 1797497    datacite::10.17605/osf.io/29qp6  Open Science Framework  datacite
# 1797498    datacite::10.17605/osf.io/djv8y  Open Science Framework  datacite
# 1797499    datacite::10.17605/osf.io/349ja  Open Science Framework  datacite
# 4480767  datacite::10.5281/zenodo.17330008                  Zenodo  datacite
#
#                              doi                                  doi_url  \
# 1789219    10.17605/osf.io/8crzu    https://doi.org/10.17605/osf.io/8crzu
# 1789222    10.17605/osf.io/utnnu    https://doi.org/10.17605/osf.io/utnnu
# 1789224    10.17605/osf.io/aypws    https://doi.org/10.17605/osf.io/aypws
# 1789230    10.17605/osf.io/tjk9y    https://doi.org/10.17605/osf.io/tjk9y
# 1789231    10.17605/osf.io/tvbgf    https://doi.org/10.17605/osf.io/tvbgf
# ...                          ...                                      ...
# 1797483    10.17605/osf.io/r5mga    https://doi.org/10.17605/osf.io/r5mga
# 1797497    10.17605/osf.io/29qp6    https://doi.org/10.17605/osf.io/29qp6
# 1797498    10.17605/osf.io/djv8y    https://doi.org/10.17605/osf.io/djv8y
# 1797499    10.17605/osf.io/349ja    https://doi.org/10.17605/osf.io/349ja
# 4480767  10.5281/zenodo.17330008  https://doi.org/10.5281/zenodo.17330008
#
#                                        landing_page_url type_backend_raw  \
# 1789219           https://doi.org/10.31234/osf.io/8crzu             Text
# 1789222           https://doi.org/10.31224/osf.io/utnnu             Text
# 1789224           https://doi.org/10.31234/osf.io/aypws             Text
# 1789230           https://doi.org/10.31234/osf.io/tjk9y             Text
# 1789231           https://doi.org/10.31234/osf.io/tvbgf             Text
# ...                                                 ...              ...
# 1797483                     https://psyarxiv.com/r5mga/             Text
# 1797497                           https://osf.io/29qp6/             Text
# 1797498                           https://osf.io/djv8y/             Text
# 1797499                           https://osf.io/349ja/             Text
# 4480767  https://zenodo.org/doi/10.5281/zenodo.17330008         Preprint
#
#         subtype_backend_raw  \
# 1789219            Preprint
# 1789222            Preprint
# 1789224            Preprint
# 1789230            Preprint
# 1789231            Preprint
# ...                     ...
# 1797483            Preprint
# 1797497            Preprint
# 1797498            Preprint
# 1797499            Preprint
# 4480767
#
#                                                      title  \
# 1789219                   Predicting Ideological Prejudice
# 1789222  Low-cost methodology for skin strain measureme...
# 1789224  The effects of winning and losing on perceived...
# 1789230  The relationship between the need for closure ...
# 1789231  A cross-sectional investigation of parenting s...
# ...                                                    ...
# 1797483     Empirically investigating the concept of lying
# 1797497  EXAMINING THE RELEVANCE OF JOB SATISFACTION ON...
# 1797498  STILL MOTIVATED TO IMPROVE PERFORMANCE? A STUD...
# 1797499  HRM PRACTICES AND ITS IMPACT ON EMPLOYEE PERFO...
# 4480767  Triadic Fixpoint v3 — Algebraic and Physical F...
#
#                                               authors_flat institutions_flat  \
# 1789219                                       Brandt, Mark              None
# 1789222  Lin, Bevin; Moerman, Kevin; McMahan, Connor; P...              None
# 1789224                                        Rubin, Mark              None
# 1789230                                        Rubin, Mark              None
# 1789231                                        Rubin, Mark              None
# ...                                                    ...               ...
# 1797483  Wiegmann, Alex; Rutschmann, Ronja; Willemsen, ...              None
# 1797497                                       Syahrir, Hj.              None
# 1797498                                 Abdurrahman, Ahmad              None
# 1797499                                           , Ridwan              None
# 4480767                                 Omezzolli, Roberto       Indipendent
#
#         countries_flat                                     relations_json  \
# 1789219           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1789222           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1789224           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1789230           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1789231           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# ...                ...                                                ...
# 1797483           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797497           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797498           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797499           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 4480767           None  [{"relatedIdentifier": "https://zenodo.org/rec...
#
#                                    version_label is_version_of is_preprint_of  \
# 1789219                                     None           NaN
# 1789222                                     None           NaN
# 1789224                                     None           NaN
# 1789230                                     None           NaN
# 1789231                                     None           NaN
# ...                                          ...           ...            ...
# 1797483                                     None           NaN
# 1797497                                     None           NaN
# 1797498                                     None           NaN
# 1797499                                     None           NaN
# 4480767  v3 – Algebraic and Physical Foundations           NaN
#
#         has_preprint has_review has_published_version  \
# 1789219                                         false
# 1789222                                         false
# 1789224                                         false
# 1789230                                         false
# 1789231                                         false
# ...              ...        ...                   ...
# 1797483                                         false
# 1797497                                         false
# 1797498                                         false
# 1797499                                         false
# 4480767                                         false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 1789219                       None                None           None
# 1789222                       None                None           None
# 1789224                       None                None           None
# 1789230                       None                None           None
# 1789231                       None                None           None
# ...                            ...                 ...            ...
# 1797483                       None                None           None
# 1797497                       None                None           None
# 1797498                       None                None           None
# 1797499                       None                None           None
# 4480767                       None                None           None
#
#                                     raw_relationships_json  \
# 1789219  {"client": {"data": {"id": "cos.osf", "type": ...
# 1789222  {"client": {"data": {"id": "cos.osf", "type": ...
# 1789224  {"client": {"data": {"id": "cos.osf", "type": ...
# 1789230  {"client": {"data": {"id": "cos.osf", "type": ...
# 1789231  {"client": {"data": {"id": "cos.osf", "type": ...
# ...                                                    ...
# 1797483  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797497  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797498  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797499  {"client": {"data": {"id": "cos.osf", "type": ...
# 4480767  {"client": {"data": {"id": "cern.zenodo", "typ...
#
#                                    records_hierarchy date_first_seen  \
# 1789219                parent - duplicate (PsyArXiv)      2016-11-01
# 1789222                                       parent      2016-11-09
# 1789224                parent - duplicate (PsyArXiv)      2017-05-31
# 1789230                parent - duplicate (PsyArXiv)      2017-05-31
# 1789231                parent - duplicate (PsyArXiv)      2017-05-31
# ...                                              ...             ...
# 1797483                                       parent      2018-06-29
# 1797497  parent - duplicate (Open Science Framework)      2018-06-30
# 1797498  parent - duplicate (Open Science Framework)      2018-06-30
# 1797499  parent - duplicate (Open Science Framework)      2018-06-30
# 4480767                                       parent      2025-10-12
#
#          publication_year  publication_year_first_seen  \
# 1789219            2016.0                         2016
# 1789222            2016.0                         2016
# 1789224            2017.0                         2017
# 1789230            2017.0                         2017
# 1789231            2017.0                         2017
# ...                   ...                          ...
# 1797483            2018.0                         2018
# 1797497            2018.0                         2018
# 1797498            2018.0                         2018
# 1797499            2018.0                         2018
# 4480767            2025.0                         2025
#
#                                                  raw_dates  \
# 1789219  [{"date": "2016-12-30T12:49:27.409000+00:00", ...
# 1789222  [{"date": "2017-04-28T19:07:01.047270+00:00", ...
# 1789224  [{"date": "2017-05-31T16:09:33.823815+00:00", ...
# 1789230  [{"date": "2017-05-31T16:09:57.539164+00:00", ...
# 1789231  [{"date": "2017-05-31T16:09:54.559051+00:00", ...
# ...                                                    ...
# 1797483  [{"date": "2018-06-29T12:55:11.076720+00:00", ...
# 1797497  [{"date": "2018-06-30T03:28:26.057983+00:00", ...
# 1797498  [{"date": "2018-06-30T04:28:24.060534+00:00", ...
# 1797499  [{"date": "2018-06-30T04:37:08.549093+00:00", ...
# 4480767  [{"date": "2025-10-12", "dateType": "Issued"},...
#
#         records_hierarchy_backup                 parent_record_id  \
# 1789219                   parent  crossref::10.31234/osf.io/8crzu
# 1789222                   parent                             None
# 1789224                   parent  crossref::10.31234/osf.io/aypws
# 1789230                   parent  crossref::10.31234/osf.io/tjk9y
# 1789231                   parent  crossref::10.31234/osf.io/tvbgf
# ...                          ...                              ...
# 1797483                   parent                             None
# 1797497                   parent  crossref::10.31219/osf.io/29qp6
# 1797498                   parent  crossref::10.31219/osf.io/djv8y
# 1797499                   parent  crossref::10.31219/osf.io/349ja
# 4480767                   parent                             None
#
#                               dup_group_id  \
# 1789219               14199177091707795996
# 1789222  relaxed::A1_tokenbag_exact::18557
# 1789224                7729529042595144458
# 1789230                6355195737513386506
# 1789231                7549943593415132084
# ...                                    ...
# 1797483                8529968580530660375
# 1797497               11848005325480586822
# 1797498                8818916254800012530
# 1797499                7111439308487034371
# 4480767                               None
#
#                                        authors_fp_tokenbag  \
# 1789219                                        brandt_mark
# 1789222  bevin_lin;connor_mcmahan;herr_hugh;kenneth_pas...
# 1789224                                         mark_rubin
# 1789230                                         mark_rubin
# 1789231                                         mark_rubin
# ...                                                    ...
# 1797483   alex_wiegmann;pascale_willemsen;ronja_rutschmann
# 1797497                                         hj_syahrir
# 1797498                                  abdurrahman_ahmad
# 1797499                                             ridwan
# 4480767                                  omezzolli_roberto
#
#                                             title_clean_v2  \
# 1789219                   predicting ideological prejudice
# 1789222  low cost methodology for skin strain measureme...
# 1789224  the effects of winning and losing on perceived...
# 1789230  the relationship between the need for closure ...
# 1789231  a cross sectional investigation of parenting s...
# ...                                                    ...
# 1797483     empirically investigating the concept of lying
# 1797497  examining the relevance of job satisfaction on...
# 1797498  still motivated to improve performance a study...
# 1797499  hrm practices and its impact on employee perfo...
# 4480767  triadic fixpoint v3 algebraic and physical fou...
#
#         authors_fp_last_initial authors_fp_last  \
# 1789219                brandt|m            None
# 1789222                    None            None
# 1789224                    None            None
# 1789230                    None            None
# 1789231                    None            None
# ...                         ...             ...
# 1797483                    None            None
# 1797497               syahrir|h            None
# 1797498           abdurrahman|a            None
# 1797499                    None            None
# 4480767             omezzolli|r            None
#
#                      records_hierarchy_dedupe_backup  \
# 1789219                parent - duplicate (PsyArXiv)
# 1789222                                       parent
# 1789224                parent - duplicate (PsyArXiv)
# 1789230                parent - duplicate (PsyArXiv)
# 1789231                parent - duplicate (PsyArXiv)
# ...                                              ...
# 1797483                                       parent
# 1797497  parent - duplicate (Open Science Framework)
# 1797498  parent - duplicate (Open Science Framework)
# 1797499  parent - duplicate (Open Science Framework)
# 4480767                                       parent
#
#           parent_record_id_dedupe_backup         dup_group_id_dedupe_backup  \
# 1789219  crossref::10.31234/osf.io/8crzu               14199177091707795996
# 1789222                             None  relaxed::A1_tokenbag_exact::18557
# 1789224  crossref::10.31234/osf.io/aypws                7729529042595144458
# 1789230  crossref::10.31234/osf.io/tjk9y                6355195737513386506
# 1789231  crossref::10.31234/osf.io/tvbgf                7549943593415132084
# ...                                  ...                                ...
# 1797483                             None                8529968580530660375
# 1797497  crossref::10.31219/osf.io/29qp6               11848005325480586822
# 1797498  crossref::10.31219/osf.io/djv8y                8818916254800012530
# 1797499  crossref::10.31219/osf.io/349ja                7111439308487034371
# 4480767                             None                               None
#
#         has_version_dois
# 1789219             None
# 1789222             None
# 1789224             None
# 1789230             None
# 1789231             None
# ...                  ...
# 1797483             None
# 1797497             None
# 1797498             None
# 1797499             None
# 4480767             None
#
# [1449 rows x 39 columns]

# %%
result3.tail(60)
# Out:
#                                  record_id             server_name   backend  \
# 1797198    datacite::10.17605/osf.io/7rmu6                PsyArXiv  datacite
# 1797209    datacite::10.17605/osf.io/42rza                PsyArXiv  datacite
# 1797214    datacite::10.17605/osf.io/3fu2a                PsyArXiv  datacite
# 1797227    datacite::10.17605/osf.io/jgp3m              EarthArXiv  datacite
# 1797233    datacite::10.17605/osf.io/uvfsr                PsyArXiv  datacite
# 1797241    datacite::10.17605/osf.io/8b73v                 engrXiv  datacite
# 1797242    datacite::10.17605/osf.io/qw2gh                PsyArXiv  datacite
# 1797243    datacite::10.17605/osf.io/d8rfy                PsyArXiv  datacite
# 1797247    datacite::10.17605/osf.io/qgaj5              EarthArXiv  datacite
# 1797248    datacite::10.17605/osf.io/b9m84                  MarXiv  datacite
# 1797264    datacite::10.17605/osf.io/52tdf                MindRxiv  datacite
# 1797290    datacite::10.17605/osf.io/ewb68                  MarXiv  datacite
# 1797294    datacite::10.17605/osf.io/bzywv                  MarXiv  datacite
# 1797295    datacite::10.17605/osf.io/947ae                  MarXiv  datacite
# 1797296    datacite::10.17605/osf.io/yz97p                  MarXiv  datacite
# 1797315    datacite::10.17605/osf.io/7dkhs                PsyArXiv  datacite
# 1797316    datacite::10.17605/osf.io/8c2ks                  MarXiv  datacite
# 1797322    datacite::10.17605/osf.io/n6wjd                  MarXiv  datacite
# 1797324    datacite::10.17605/osf.io/2rctj                  MarXiv  datacite
# 1797325    datacite::10.17605/osf.io/x2jft                  MarXiv  datacite
# 1797326    datacite::10.17605/osf.io/qgcxj                PsyArXiv  datacite
# 1797332    datacite::10.17605/osf.io/cm68n                  MarXiv  datacite
# 1797338    datacite::10.17605/osf.io/x4fb7                  MarXiv  datacite
# 1797342    datacite::10.17605/osf.io/5dua6                  MarXiv  datacite
# 1797347    datacite::10.17605/osf.io/2s8rv                PsyArXiv  datacite
# 1797361    datacite::10.17605/osf.io/7fa3m  Open Science Framework  datacite
# 1797366    datacite::10.17605/osf.io/cygwq                PsyArXiv  datacite
# 1797394    datacite::10.17605/osf.io/xasgz                  MarXiv  datacite
# 1797395    datacite::10.17605/osf.io/jgazf                  MarXiv  datacite
# 1797396    datacite::10.17605/osf.io/zc4tq                  MarXiv  datacite
# 1797397    datacite::10.17605/osf.io/qywm8                  MarXiv  datacite
# 1797398    datacite::10.17605/osf.io/74cfx                  MarXiv  datacite
# 1797399    datacite::10.17605/osf.io/w8a79  Open Science Framework  datacite
# 1797402    datacite::10.17605/osf.io/8qrgx                PsyArXiv  datacite
# 1797403    datacite::10.17605/osf.io/fxnqj                  MarXiv  datacite
# 1797404    datacite::10.17605/osf.io/zv4kw                PsyArXiv  datacite
# 1797422    datacite::10.17605/osf.io/rkz4s  Open Science Framework  datacite
# 1797423    datacite::10.17605/osf.io/rh9xw  Open Science Framework  datacite
# 1797425    datacite::10.17605/osf.io/9azju  Open Science Framework  datacite
# 1797426    datacite::10.17605/osf.io/buh26  Open Science Framework  datacite
# 1797428    datacite::10.17605/osf.io/b8w7j  Open Science Framework  datacite
# 1797429    datacite::10.17605/osf.io/xt6fe  Open Science Framework  datacite
# 1797430    datacite::10.17605/osf.io/gtdkm  Open Science Framework  datacite
# 1797431    datacite::10.17605/osf.io/39uf2  Open Science Framework  datacite
# 1797439    datacite::10.17605/osf.io/8scm9                PsyArXiv  datacite
# 1797440    datacite::10.17605/osf.io/kzbwf                PsyArXiv  datacite
# 1797441    datacite::10.17605/osf.io/tsr36  Open Science Framework  datacite
# 1797443    datacite::10.17605/osf.io/t5aj2                PsyArXiv  datacite
# 1797451    datacite::10.17605/osf.io/8ntzw                  MarXiv  datacite
# 1797457    datacite::10.17605/osf.io/hrqez                 engrXiv  datacite
# 1797458    datacite::10.17605/osf.io/etgc8                 engrXiv  datacite
# 1797471    datacite::10.17605/osf.io/k2gdz                  MarXiv  datacite
# 1797473    datacite::10.17605/osf.io/9f65j                MindRxiv  datacite
# 1797474    datacite::10.17605/osf.io/c5xqb                  MarXiv  datacite
# 1797482    datacite::10.17605/osf.io/5y3pn              EarthArXiv  datacite
# 1797483    datacite::10.17605/osf.io/r5mga                PsyArXiv  datacite
# 1797497    datacite::10.17605/osf.io/29qp6  Open Science Framework  datacite
# 1797498    datacite::10.17605/osf.io/djv8y  Open Science Framework  datacite
# 1797499    datacite::10.17605/osf.io/349ja  Open Science Framework  datacite
# 4480767  datacite::10.5281/zenodo.17330008                  Zenodo  datacite
#
#                              doi                                  doi_url  \
# 1797198    10.17605/osf.io/7rmu6    https://doi.org/10.17605/osf.io/7rmu6
# 1797209    10.17605/osf.io/42rza    https://doi.org/10.17605/osf.io/42rza
# 1797214    10.17605/osf.io/3fu2a    https://doi.org/10.17605/osf.io/3fu2a
# 1797430                                           Gani, H.              None
# 1797431                                    Makka, Tajuddin              None
# 1797439  Ramiro, Christian; Srinivasan, Mahesh; Malt, B...              None
# 1797440        Xu, Yang; Malt, Barbara; Srinivasan, Mahesh              None
# 1797441  Subramaniapillai, Sivaniya; Rajah, Maria; Pasv...              None
# 1797443   Wang, Iris; Michalak, Nicholas; Ackerman, Joshua              None
# 1797451  Christie, Patrick; Fluharty, David; Kennard, H...              None
# 1797457                       Fröscher, Agnes; Hasse, Hans              None
# 1797458  Forte, Ester; von Harbou, Erik; Burger, Jakob;...              None
# 1797471                                Kristianson, Gerald              None
# 1797473                                     Dorjee, Dusana              None
# 1797474  Christie, Patrick; Bennett, Nathan; Gray, Noel...              None
# 1797482                                       Leah, Harold              None
# 1797483  Wiegmann, Alex; Rutschmann, Ronja; Willemsen, ...              None
# 1797497                                       Syahrir, Hj.              None
# 1797498                                 Abdurrahman, Ahmad              None
# 1797499                                           , Ridwan              None
# 4480767                                 Omezzolli, Roberto       Indipendent
#
#         countries_flat                                     relations_json  \
# 1797198           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797209           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797214           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797227           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797233           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797241           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797242           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797243           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797247           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797248           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797264           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797290           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797294           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797295           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797296           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797315           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797316           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797322           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797324           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797325           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797326           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797332           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797338           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797342           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797347           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797361           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797366           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797394           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797395           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797396           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797397           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797398           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797399           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797402           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797403           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797404           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797422           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797423           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797425           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797426           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797428           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797429           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797430           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797431           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797439           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797440           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797441           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797443           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797451           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797457           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797458           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797471           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797473           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797474           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797482           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797483           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797497           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797498           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 1797499           None  [{"relatedIdentifier": "https://dx.doi.org/10....
# 4480767           None  [{"relatedIdentifier": "https://zenodo.org/rec...
#
#                                    version_label is_version_of is_preprint_of  \
# 1797198                                     None           NaN
# 1797209                                     None           NaN
# 1797214                                     None           NaN
# 1797227                                     None           NaN
# 1797233                                     None           NaN
# 1797241                                     None           NaN
# 1797242                                     None           NaN
# 1797243                                     None           NaN
# 1797247                                     None           NaN
# 1797248                                     None           NaN
# 1797264                                     None           NaN
# 1797290                                     None           NaN
# 1797294                                     None           NaN
# 1797295                                     None           NaN
# 1797296                                     None           NaN
# 1797315                                     None           NaN
# 1797316                                     None           NaN
# 1797322                                     None           NaN
# 1797324                                     None           NaN
# 1797325                                     None           NaN
# 1797326                                     None           NaN
# 1797332                                     None           NaN
# 1797338                                     None           NaN
# 1797342                                     None           NaN
# 1797347                                     None           NaN
# 1797361                                     None           NaN
# 1797366                                     None           NaN
# 1797394                                     None           NaN
# 1797395                                     None           NaN
# 1797396                                     None           NaN
# 1797397                                     None           NaN
# 1797398                                     None           NaN
# 1797399                                     None           NaN
# 1797402                                     None           NaN
# 1797403                                     None           NaN
# 1797404                                     None           NaN
# 1797422                                     None           NaN
# 1797423                                     None           NaN
# 1797425                                     None           NaN
# 1797426                                     None           NaN
# 1797428                                     None           NaN
# 1797429                                     None           NaN
# 1797430                                     None           NaN
# 1797431                                     None           NaN
# 1797439                                     None           NaN
# 1797440                                     None           NaN
# 1797441                                     None           NaN
# 1797443                                     None           NaN
{"client": {"data": {"id": "cos.osf", "type": ...
# 1797209  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797214  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797227  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797233  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797241  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797242  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797243  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797247  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797248  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797264  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797290  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797294  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797295  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797296  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797315  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797316  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797322  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797324  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797325  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797326  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797332  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797338  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797342  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797347  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797361  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797366  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797394  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797395  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797396  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797397  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797398  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797399  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797402  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797403  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797404  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797422  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797423  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797425  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797426  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797428  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797429  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797430  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797431  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797439  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797440  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797441  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797443  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797451  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797457  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797458  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797471  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797473  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797474  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797482  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797483  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797497  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797498  {"client": {"data": {"id": "cos.osf", "type": ...
# 1797499  {"client": {"data": {"id": "cos.osf", "type": ...
# 4480767  {"client": {"data": {"id": "cern.zenodo", "typ...
#
#                                    records_hierarchy date_first_seen  \
# 1797198                                       parent      2018-06-10
# 1797209                                       parent      2018-06-11
# 1797214                                       parent      2018-06-12
# 1797227              parent - duplicate (EarthArXiv)      2018-06-13
# 1797233                                       parent      2018-06-13
# 1797241                                       parent      2018-06-14
# 1797242                                       parent      2018-06-14
# 1797243                                       parent      2018-06-14
# 1797247              parent - duplicate (EarthArXiv)      2018-06-14
# 1797248                  parent - duplicate (MarXiv)      2018-06-14
# 1797264                parent - duplicate (MindRxiv)      2018-06-16
# 1797290                  parent - duplicate (MarXiv)      2018-06-19
# 1797294                  parent - duplicate (MarXiv)      2018-06-19
# 1797295                  parent - duplicate (MarXiv)      2018-06-19
# 1797296                  parent - duplicate (MarXiv)      2018-06-19
# 1797315                                       parent      2018-06-20
# 1797316                  parent - duplicate (MarXiv)      2018-06-20
# 1797322                  parent - duplicate (MarXiv)      2018-06-21
# 1797324                  parent - duplicate (MarXiv)      2018-06-21
# 1797325                  parent - duplicate (MarXiv)      2018-06-21
# 1797326                                       parent      2018-06-21
# 1797332                  parent - duplicate (MarXiv)      2018-06-22
# 1797338                  parent - duplicate (MarXiv)      2018-06-22
# 1797342                  parent - duplicate (MarXiv)      2018-06-22
# 1797347                                       parent      2018-06-23
# ...
# 1797366  quantifying insightful problem solving a modif...
# 1797394  predictors of local support for a seawater des...
# 1797395  managing the spread of pathogens and aquatic i...
# 1797396  indicators to evaluate the social dimensions o...
# 1797397  human dimensions information needs of fishery ...
# 1797398  the integration of social science information ...
# 1797399  association between investment production expo...
# 1797402  identity influence and intervention the roles ...
# 1797403  a sea of troubles brexit and the fisheries que...
# 1797404  when god is your only friend religious beliefs...
# 1797422  the nature of legal certainty on the utilizati...
# 1797423  evaluating financial performance in local gove...
# 1797425  determinants of profitability and firm values ...
# 1797426  the effect of leadership style work motivation...
# 1797428      hotels and restaurant tax revenues management
# 1797429  the mediating role of employee performance the...
# 1797430  the impacts of competence work motivation job ...
# 1797431  the antecedents consequences and mediating rol...
# 1797439  algorithms in the historical emergence of word...
# 1797440  evolution of word meanings through metaphorica...
# 1797441  bilingual experience and executive control ove...
# 1797443                            life history strategies
# 1797451  policy pivot in puget sound lessons learned fr...
# 1797457                                               None
# 1797395                  parent - duplicate (MarXiv)
# 1797396                  parent - duplicate (MarXiv)
# 1797397                  parent - duplicate (MarXiv)
# 1797398                  parent - duplicate (MarXiv)
# 1797399  parent - duplicate (Open Science Framework)
# 1797402                                       parent
# 1797403                  parent - duplicate (MarXiv)
# 1797404                                       parent
# 1797422  parent - duplicate (Open Science Framework)
# 1797423  parent - duplicate (Open Science Framework)
# 1797425  parent - duplicate (Open Science Framework)
# 1797426  parent - duplicate (Open Science Framework)
# 1797428  parent - duplicate (Open Science Framework)
# 1797429  parent - duplicate (Open Science Framework)
# 1797430  parent - duplicate (Open Science Framework)
# 1797431  parent - duplicate (Open Science Framework)
# 1797439                                       parent
# 1797440                                       parent
# 1797441  parent - duplicate (Open Science Framework)
# 1797443                                       parent
# 1797451                  parent - duplicate (MarXiv)
# 1797457                                       parent
# 1797458                                       parent
# 1797471                  parent - duplicate (MarXiv)
# 1797473                parent - duplicate (MindRxiv)
# 1797474                  parent - duplicate (MarXiv)
# 1797482                                       parent
# 1797483                                       parent
# 1797497  parent - duplicate (Open Science Framework)
# 1797498  parent - duplicate (Open Science Framework)
# 1797499  parent - duplicate (Open Science Framework)
# 4480767                                       parent
#
#           parent_record_id_dedupe_backup         dup_group_id_dedupe_backup  \
# 1797198                             None  relaxed::A1_tokenbag_exact::19586
# 1797209                             None                8149411324577153602
# 1797214                             None               10835013044646619781
# 1797227  crossref::10.31223/osf.io/jgp3m                7317120953095148458
# 1797233                             None  relaxed::A1_tokenbag_exact::19595
# 1797241                             None               12143966257048467297
# 1797242                             None                7491714752272196220
# 1797243                             None  relaxed::A1_tokenbag_exact::19598
# 1797247  crossref::10.31223/osf.io/qgaj5                4054228053267077598
# 1797248  crossref::10.31230/osf.io/b9m84  relaxed::A1_tokenbag_exact::16051
# 1797264  crossref::10.31231/osf.io/52tdf  relaxed::A1_tokenbag_exact::16114
# 1797290  crossref::10.31230/osf.io/ewb68                6643220939953781943
# 1797294  crossref::10.31230/osf.io/bzywv                6386185577395458263
# 1797295  crossref::10.31230/osf.io/947ae               14289484070736187829
# 1797296  crossref::10.31230/osf.io/yz97p  relaxed::A1_tokenbag_exact::16053
# 1797315                             None  relaxed::A1_tokenbag_exact::19607
# 1797316  crossref::10.31230/osf.io/8c2ks                6208755677271324050
# 1797322  crossref::10.31230/osf.io/n6wjd  relaxed::A1_tokenbag_exact::16046
# 1797324  crossref::10.31230/osf.io/2rctj  relaxed::A1_tokenbag_exact::16050
# 1797325  crossref::10.31230/osf.io/x2jft               16017149976655087433
# 1797326                             None               15377926100702288702
# 1797332  crossref::10.31230/osf.io/cm68n  relaxed::A1_tokenbag_exact::16052
# 1797338  crossref::10.31230/osf.io/x4fb7                4508312528506938120
# 1797342  crossref::10.31230/osf.io/5dua6  relaxed::A1_tokenbag_exact::16054
# 1797347                             None                6375251174364923464
# 1797361  crossref::10.31219/osf.io/7fa3m  relaxed::A1_tokenbag_exact::18099
# 1797366                             None                5225862528686244830
# 1797394  crossref::10.31230/osf.io/xasgz               14915428423343411667
# 4480767             None

# %%
osfdf = result3[result3['server_name']=='Open Science Framework']#.sample(60)

# %%
pattern = 'osf.io/preprints/'

mask = osfdf['landing_page_url'].str.contains(pattern, regex=False, na=False)
osfdfs = osfdf[mask]
osfdfs
# Out:
# Empty DataFrame
# Columns: [record_id, server_name, backend, doi, doi_url, landing_page_url, type_backend_raw, subtype_backend_raw, title, authors_flat, institutions_flat, countries_flat, relations_json, version_label, is_version_of, is_preprint_of, has_preprint, has_review, has_published_version, published_version_ids_json, version_of_ids_json, update_to_json, raw_relationships_json, records_hierarchy, date_first_seen, publication_year, publication_year_first_seen, raw_dates, records_hierarchy_backup, parent_record_id, dup_group_id, authors_fp_tokenbag, title_clean_v2, authors_fp_last_initial, authors_fp_last, records_hierarchy_dedupe_backup, parent_record_id_dedupe_backup, dup_group_id_dedupe_backup, has_version_dois]
# Index: []

# %%
record_ex = data_clean_isversionof[data_clean_isversionof['record_id']=='datacite::10.5281/zenodo.15050897']
record_ex
# Out:
#                                  record_id server_name   backend  \
# 4414186  datacite::10.5281/zenodo.15050897      Zenodo  datacite
#
#                              doi                                  doi_url  \
# 4414186  10.5281/zenodo.15050897  https://doi.org/10.5281/zenodo.15050897
#
#                                        landing_page_url type_backend_raw  \
# 4414186  https://zenodo.org/doi/10.5281/zenodo.15050897         Preprint
#
#         subtype_backend_raw  \
# 4414186
#
#                                                      title  \
# 4414186  The Indeterminacy Space as the Foundation of S...
#
#                     authors_flat institutions_flat countries_flat  \
# 4414186  Paruzel, Katarzyna Anna              None           None
#
#                                             relations_json version_label  \
# 4414186  [{"relatedIdentifier": "10.5281/zenodo.1505347...          None
#
#                                              is_version_of is_preprint_of  \
# 4414186  10.5281/zenodo.15053474;10.5281/zenodo.1505352...
#
#         has_preprint has_review has_published_version  \
# 4414186                                         false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 4414186                       None                None           None
#
#                                     raw_relationships_json records_hierarchy  \
# 4414186  {"client": {"data": {"id": "cern.zenodo", "typ...            parent
#
#         date_first_seen  publication_year  publication_year_first_seen  \
# 4414186      2025-02-26            2025.0                         2025
#
#                                                  raw_dates  \
# 4414186  [{"date": "2025-02-26", "dateType": "Issued"},...
#
#         records_hierarchy_backup parent_record_id         dup_group_id  \
# 4414186                   parent             None  2507215253830421560
#
#             authors_fp_tokenbag  \
# 4414186  anna_katarzyna_paruzel
#
#                                             title_clean_v2  \
# 4414186  the indeterminacy space as the foundation of s...
#
#         authors_fp_last_initial authors_fp_last  \
# 4414186               paruzel|k            None
#
#         records_hierarchy_dedupe_backup parent_record_id_dedupe_backup  \
# 4414186                          parent                           None
#
#         dup_group_id_dedupe_backup  \
# 4414186        2507215253830421560
#
#                                         has_version_dois
# 4414186  10.5281/zenodo.16944639;10.5281/zenodo.15050898

# %%
data_clean_isversionof[data_clean_isversionof['has_version_dois'].isna()]
# Out:
#                                record_id     server_name   backend  \
# 0        crossref::10.21467/preprints.48  AIJR Preprints  crossref
# 1        crossref::10.21467/preprints.43  AIJR Preprints  crossref
# 2        crossref::10.21467/preprints.39  AIJR Preprints  crossref
# 3        crossref::10.21467/preprints.38  AIJR Preprints  crossref
# 4        crossref::10.21467/preprints.36  AIJR Preprints  crossref
# ...                                  ...             ...       ...
# 7911896             openalex::W999325625           viXra  openalex
# 7911897             openalex::W999460032           viXra  openalex
# 7911898              openalex::W99967155           viXra  openalex
# 7911899             openalex::W999790414           viXra  openalex
# 7911900             openalex::W999805801           viXra  openalex
#
#                            doi                                doi_url  \
# 0        10.21467/preprints.48  https://doi.org/10.21467/preprints.48
# 1        10.21467/preprints.43  https://doi.org/10.21467/preprints.43
# 2        10.21467/preprints.39  https://doi.org/10.21467/preprints.39
# 3        10.21467/preprints.38  https://doi.org/10.21467/preprints.38
# 4        10.21467/preprints.36  https://doi.org/10.21467/preprints.36
# ...                        ...                                    ...
# 7911896                   None                                   None
# 7911897                   None                                   None
# 7911898                   None                                   None
# 7911899                   None                                   None
# 7911900                   None                                   None
#
#                                           landing_page_url type_backend_raw  \
# 0        https://preprints.aijr.org/index.php/ap/prepri...   posted-content
# 1        https://preprints.aijr.org/index.php/ap/prepri...   posted-content
# 2        https://preprints.aijr.org/index.php/ap/prepri...   posted-content
# 3        https://preprints.aijr.org/index.php/ap/prepri...   posted-content
# 4        https://preprints.aijr.org/index.php/ap/prepri...   posted-content
# ...                                                    ...              ...
# 7911896              https://vixra.org/pdf/1409.0090v1.pdf         preprint
# 7911897                    https://vixra.org/abs/1112.0094         preprint
# 7911898              https://vixra.org/pdf/1406.0019v1.pdf         preprint
# 7911899              https://vixra.org/pdf/1306.0105v3.pdf         preprint
# 7911900              https://vixra.org/pdf/1412.0197v3.pdf         preprint
#
#         subtype_backend_raw  \
# 0                  preprint
# 1                  preprint
# 2                  preprint
# 3                  preprint
# 4                  preprint
# ...                     ...
# 7911896                None
# 7911897                None
# 7911898                None
# 7911899                None
# 7911900                None
#
#                                                      title  \
# 0        Bird’s Eye View on the Diagnosis, Treatment, &...
# 1        Doxycycline and Minocycline Drugs as a Treatme...
# 2        A Genetic Perspective of 2019-nCoV in Relation...
# 3        Marine Algae as a Natural Source for Antiviral...
# 4        Possible Prevention of COVID 19 by Using Linol...
# ...                                                    ...
# 7911896                 Three Objections to Modern Physics
# 7911897                               Particle Mass Ratios
# 7911898  Quantum FFF Theory Proposals for Some Unsolved...
# 7911899  Investigation of the Formalism of Particle Dyn...
# 7911900  Electromagnetic Energy and Electromagnetic For...
#
#                                               authors_flat institutions_flat  \
# 0                              Panchalingala, Sai Bhargavi              None
# 1                                         Mostafa, Mohamed              None
# 2                                        Dasgupta, Rimjhim              None
# 3        Musale, Amar S; G., Raja Krishna Kumar; Sapre,...              None
# 4        Subhash, Venkata; G, Raja Krishna Kumar; Sapre...              None
# ...                                                    ...               ...
# 7911896                                      Lubomir Vlcek              None
# 7911897                                         DT Froedge              None
# 7911898                                           Leo Vuyk              None
# 7911899                                        Chi-Yi Chen              None
# 7911900                                    Yu.A. Spirichev              None
#
#         countries_flat relations_json version_label is_version_of  \
# 0                 None           None          None           NaN
# 1                 None           None          None           NaN
# 2                 None           None          None           NaN
# 3                 None           None          None           NaN
# 4                 None           None          None           NaN
# ...                ...            ...           ...           ...
# 7911896           None           None          None          None
# 7911897           None           None          None          None
# 7911898           None           None          None          None
# 7911899           None           None          None          None
# 7911900           None           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 0                                                              false
# 1                                                              false
# 2                                                              false
# 3                                                              false
# 4                                                              false
# ...                ...          ...        ...                   ...
# 7911896           None         None       None                  None
# 7911897           None         None       None                  None
# 7911898           None         None       None                  None
# 7911899           None         None       None                  None
# 7911900           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 0                             None                None           None
# 1                             None                None           None
# 2                             None                None           None
# 3                             None                None           None
# 4                             None                None           None
# ...                            ...                 ...            ...
# 7911896                       None                None           None
# 7911897                       None                None           None
# 7911898                       None                None           None
# 7911899                       None                None           None
# 7911900                       None                None           None
#
#         raw_relationships_json records_hierarchy date_first_seen  \
# 0                         None            parent      2020-05-03
# 1                         None            parent      2020-04-25
# 2                         None            parent      2020-04-16
# 3                         None            parent      2020-04-15
# 4                         None            parent      2020-04-15
# ...                        ...               ...             ...
# 7911896                   None            parent      2014-09-01
# 7911897                   None            parent      2011-12-01
# 7911898                   None            parent      2014-06-01
# 7911899                   None            parent      2013-06-01
# 7911900                   None            parent      2014-12-01
#
#          publication_year  publication_year_first_seen raw_dates  \
# 0                  2020.0                         2020      None
# 1                  2020.0                         2020      None
# 2                  2020.0                         2020      None
# 3                  2020.0                         2020      None
# 4                  2020.0                         2020      None
# ...                   ...                          ...       ...
# 7911896            2014.0                         2014      None
# 7911897            2011.0                         2011      None
# 7911898            2014.0                         2014      None
# 7911899            2013.0                         2013      None
# 7911900            2014.0                         2014      None
#
#         records_hierarchy_backup parent_record_id dup_group_id  \
# 0                         parent             None         None
# 1                         parent             None         None
# 2                         parent             None         None
# 3                         parent             None         None
# 4                         parent             None         None
# ...                          ...              ...          ...
# 7911896                   parent             None         None
# 7911897                   parent             None         None
# 7911898                   parent             None         None
# 7911899                   parent             None         None
# 7911900                   parent             None         None
#
#         authors_fp_tokenbag  \
# 0                      None
# 1           mohamed_mostafa
# 2          dasgupta_rimjhim
# 3                      None
# 4                      None
# ...                     ...
# 7911896       lubomir_vlcek
# 7911897          dt_froedge
# 7911898            leo_vuyk
# 7911899         chen_chi_yi
# 7911900      a_spirichev_yu
#
#                                             title_clean_v2  \
# 0                                                     None
# 1        doxycycline and minocycline drugs as a treatme...
# 2        a genetic perspective of 2019 ncov in relation...
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 7911896                 three objections to modern physics
# 7911897                               particle mass ratios
# 7911898  quantum fff theory proposals for some unsolved...
# 7911899  investigation of the formalism of particle dyn...
# 7911900  electromagnetic energy and electromagnetic for...
#
#         authors_fp_last_initial authors_fp_last  \
# 0                          None            None
# 1                     mostafa|m            None
# 2                    dasgupta|r            None
# 3                          None            None
# 4                          None            None
# ...                         ...             ...
# 7911896                 vlcek|l            None
# 7911897               froedge|d            None
# 7911898                  vuyk|l            None
# 7911899                  chen|c            None
# 7911900             spirichev|y            None
#
#         records_hierarchy_dedupe_backup parent_record_id_dedupe_backup  \
# 0                                parent                           None
# 1                                parent                           None
# 2                                parent                           None
# 3                                parent                           None
# 4                                parent                           None
# ...                                 ...                            ...
# 7911896                          parent                           None
# 7911897                          parent                           None
# 7911898                          parent                           None
# 7911899                          parent                           None
# 7911900                          parent                           None
#
#         dup_group_id_dedupe_backup has_version_dois
# 0                             None             None
# 1                             None             None
# 2                             None             None
# 3                             None             None
# 4                             None             None
# ...                            ...              ...
# 7911896                       None             None
# 7911897                       None             None
# 7911898                       None             None
# 7911899                       None             None
# 7911900                       None             None
#
# [6429113 rows x 39 columns]

# %% [markdown]
# ## apply the modifications in is_version_of columns

# %%
pattern = '"relatedIdentifier"'

mask = data_clean_isversionof["relations_json"].str.contains(pattern, na=False)

data_clean_isversionof.loc[mask, "is_version_of"] = data_clean_isversionof.loc[mask, "has_version_dois"]

print(f"Rows updated: {mask.sum():,}")
print(f"Non-null is_version_of after update: {data_clean_isversionof['is_version_of'].notna().sum():,}")
# Out:
# Rows updated: 1,480,179
# Non-null is_version_of after update: 1,553,399

# %%
data_clean_isversionof = data_clean_isversionof.sort_values(by='record_id')

# %% [markdown]
# # function

# %%
import time
import pandas as pd
import numpy as np
from typing import Dict, Any, Optional

# ------------------------------------------------------------
# Union-Find (Disjoint Set Union) for fast connected-components
# ------------------------------------------------------------
class _UnionFind:
    __slots__ = ("parent", "size")

    def __init__(self, n: int):
        self.parent = np.arange(n, dtype=np.int32)
        self.size = np.ones(n, dtype=np.int32)

    def find(self, x: int) -> int:
        parent = self.parent
        while parent[x] != x:
            parent[x] = parent[parent[x]]
            x = parent[x]
        return x

    def union(self, a: int, b: int) -> bool:
        pa = self.find(a)
        pb = self.find(b)
        if pa == pb:
            return False
        # union by size
        if self.size[pa] < self.size[pb]:
            pa, pb = pb, pa
        self.parent[pb] = pa
        self.size[pa] += self.size[pb]
        return True


def unify_groups_by_version_links(
    df: pd.DataFrame,
    *,
    # core cols
    record_id_col: str = "record_id",
    doi_col: str = "doi",
    is_version_of_col: str = "is_version_of",

    # output cols
    hierarchy_col: str = "records_hierarchy",
    parent_id_col: str = "parent_record_id",
    group_id_col: str = "dup_group_id",

    # parent choice
    date_col: Optional[str] = "date_first_seen",      # if None, will use record_id numeric fallback only
    choose_parent: str = "oldest",                    # "oldest" | "newest"

    # how safe to overwrite
    # - "unlabeled_only": only rows with NA hierarchy are eligible
    # - "parent_only": only rows currently labeled "parent" are eligible
    # - "any": any row is eligible
    overwrite_mode: str = "unlabeled_only",

    # labeling
    label_duplicate_suffix: str = "version-link",     # becomes "parent - duplicate (version-link)"

    # performance
    chunk_size: int = 300_000,                        # only affects the union loop; tune for RAM/CPU
    min_component_size: int = 2,                      # ignore components of size < 2
) -> tuple[pd.DataFrame, Dict[str, Any]]:
    """
    Unify clusters using explicit version relationships (is_version_of) as a HIGH-CONFIDENCE step.

    How it works (fast + robust):
      1) For rows that have either a DOI or an is_version_of list, build a graph where:
         - each row is a node
         - edges exist when two rows share any DOI in their version-set (self DOI + is_version_of DOIs)
      2) Compute connected components via Union-Find (near O(N)).
      3) For each component (size>=2), choose ONE parent (oldest/newest by date, tie-break by record_id numeric).
      4) Update:
         - hierarchy_col: "parent" for parent, "parent - duplicate (version-link)" for others
         - parent_id_col: parent record_id for duplicates
         - group_id_col: stable id "version::<root_record_id>" (can be merged later with other stages)

    Safe overwrite:
      - overwrite_mode controls WHICH rows get updated (eligible), but parents are chosen using all rows in component.

    Returns:
      (df, metrics)
    """

    t0 = time.perf_counter()
    metrics: Dict[str, Any] = {
        "n_rows_df": int(len(df)),
        "n_rows_with_any_version_signal": 0,
        "n_rows_considered_in_graph": 0,
        "n_edges_unions_attempted": 0,
        "n_unions_done": 0,
        "n_components_total": 0,
        "n_components_size_ge_2": 0,
        "n_rows_in_components_size_ge_2": 0,
        "n_rows_eligible_to_update": 0,
        "n_rows_updated": 0,
        "n_parents_set": 0,
        "n_children_set": 0,
        "runtime_s": 0.0,
    }

    # -----------------------------
    # Basic column checks / setup
    # -----------------------------
    for c in (hierarchy_col, parent_id_col, group_id_col):
        if c not in df.columns:
            df[c] = pd.NA

    if record_id_col not in df.columns:
        raise ValueError(f"Missing required column: {record_id_col}")
    if doi_col not in df.columns:
        raise ValueError(f"Missing required column: {doi_col}")
    if is_version_of_col not in df.columns:
        raise ValueError(f"Missing required column: {is_version_of_col}")

    if choose_parent not in {"oldest", "newest"}:
        raise ValueError("choose_parent must be 'oldest' or 'newest'")
    if overwrite_mode not in {"unlabeled_only", "parent_only", "any"}:
        raise ValueError("overwrite_mode must be 'unlabeled_only' | 'parent_only' | 'any'")

    # eligibility mask (safe overwrite)
    h = df[hierarchy_col]
    if overwrite_mode == "any":
        eligible_mask = pd.Series(True, index=df.index)
    elif overwrite_mode == "unlabeled_only":
        eligible_mask = h.isna()
    else:  # parent_only
        eligible_mask = h.astype("string").str.strip().str.lower().eq("parent")

    metrics["n_rows_eligible_to_update"] = int(eligible_mask.sum())

    # ------------------------------------------------------------
    # Build the subset to include in the VERSION graph
    # (We include rows that have DOI OR is_version_of list,
    #  because some rows might have missing doi but have version list.)
    # ------------------------------------------------------------
    doi_s = df[doi_col].astype("string").fillna("").str.strip()
    v_s = df[is_version_of_col].astype("string").fillna("").str.strip()

    has_signal = (doi_s != "") | (v_s != "")
    metrics["n_rows_with_any_version_signal"] = int(has_signal.sum())

    idx = df.index[has_signal].to_numpy()
    if idx.size == 0:
        metrics["runtime_s"] = time.perf_counter() - t0
        return df, metrics

    # Compact indexing for Union-Find arrays
    # local_i: 0..k-1 corresponds to df index idx[local_i]
    k = idx.size
    metrics["n_rows_considered_in_graph"] = int(k)

    # For parent selection: precompute helpers on this subset
    rid = df.loc[idx, record_id_col].astype("string").fillna("")
    # numeric fallback from record_id: extract digits
    rid_num = pd.to_numeric(rid.str.extract(r"(\d+)")[0], errors="coerce")

    if date_col and date_col in df.columns:
        dt = pd.to_datetime(df.loc[idx, date_col], errors="coerce")
    else:
        dt = pd.Series(pd.NaT, index=idx)

    # union-find structure
    uf = _UnionFind(k)

    # ------------------------------------------------------------
    # Union phase: stream through rows and connect by shared DOIs
    # Using a dict: doi -> first_local_index_seen
    # ------------------------------------------------------------
    doi_to_rep: Dict[str, int] = {}

    def _iter_version_set(self_doi: str, is_version_of_str: str):
        """
        Yield DOIs in (self DOI + is_version_of list).
        Designed to be cheap: split ';' only.
        """
        if self_doi:
            yield self_doi
        if is_version_of_str:
            # common case: "doi1;doi2;doi3"
            for part in is_version_of_str.split(";"):
                d = part.strip()
                if d:
                    yield d

    # Process in chunks for cache friendliness (still single pass)
    unions_attempted = 0
    unions_done = 0

    # Pre-pull arrays for speed
    doi_arr = doi_s.loc[idx].to_numpy(dtype=object)
    v_arr = v_s.loc[idx].to_numpy(dtype=object)

    for start in range(0, k, chunk_size):
        end = min(k, start + chunk_size)
        for local_i in range(start, end):
            sd = doi_arr[local_i]
            sv = v_arr[local_i]
            # build edges for this row: union with representative of each doi token
            first_rep = None
            for d in _iter_version_set(sd, sv):
                rep = doi_to_rep.get(d)
                if rep is None:
                    doi_to_rep[d] = local_i
                    if first_rep is None:
                        first_rep = local_i
                else:
                    unions_attempted += 1
                    if uf.union(local_i, rep):
                        unions_done += 1

    metrics["n_edges_unions_attempted"] = int(unions_attempted)
    metrics["n_unions_done"] = int(unions_done)

    # ------------------------------------------------------------
    # Build components: root -> list of local indices
    # ------------------------------------------------------------
    roots = np.empty(k, dtype=np.int32)
    for i in range(k):
        roots[i] = uf.find(i)

    # group by root using pandas (fast enough); avoid Python dict of lists for k large
    comp_df = pd.DataFrame({"root": roots, "local_i": np.arange(k, dtype=np.int32)})
    comp_sizes = comp_df["root"].value_counts()
    metrics["n_components_total"] = int(comp_sizes.shape[0])

    big_roots = comp_sizes[comp_sizes >= min_component_size].index.to_numpy(dtype=np.int32)
    metrics["n_components_size_ge_2"] = int(big_roots.size)
    if big_roots.size == 0:
        metrics["runtime_s"] = time.perf_counter() - t0
        return df, metrics

    # Filter to only components we will act on
    comp_big = comp_df[comp_df["root"].isin(big_roots)].copy()
    metrics["n_rows_in_components_size_ge_2"] = int(len(comp_big))

    # ------------------------------------------------------------
    # Parent selection per component
    # Parent = oldest/newest dt, tie-break by record_id numeric (rid_num)
    # ------------------------------------------------------------
    # Map local_i -> df index
    df_index_for_local = idx  # numpy array length k

    # Create selection frame with sortable keys
    # Note: dt index is df idx; align via local index mapping
    sel_idx = df_index_for_local[comp_big["local_i"].to_numpy()]
    sel = pd.DataFrame({
        "root": comp_big["root"].to_numpy(),
        "df_idx": sel_idx,
        "record_id": df.loc[sel_idx, record_id_col].astype("string").to_numpy(),
        "dt": dt.loc[sel_idx].to_numpy(),
        "rid_num": rid_num.loc[sel_idx].to_numpy(),
    })

    # Sort for parent picking
    asc_dt = True if choose_parent == "oldest" else False
    asc_rn = True if choose_parent == "oldest" else False

    # When dt is NaT, push to end for "oldest" and to start for "newest"
    # pandas sort_values uses na_position; we’ll handle by two sorts:
    na_pos = "last" if choose_parent == "oldest" else "first"

    sel_sorted = sel.sort_values(
        by=["root", "dt", "rid_num"],
        ascending=[True, asc_dt, asc_rn],
        na_position=na_pos,
        kind="mergesort",  # stable
    )

    # parent per root = first row per root
    parents = sel_sorted.groupby("root", sort=False).head(1)[["root", "df_idx", "record_id"]].rename(
        columns={"df_idx": "parent_df_idx", "record_id": "parent_record_id"}
    )

    parent_map_idx = parents.set_index("root")["parent_df_idx"]
    parent_map_rid = parents.set_index("root")["parent_record_id"]

    # ------------------------------------------------------------
    # Apply updates safely (only eligible rows)
    # ------------------------------------------------------------
    # Create per-row root for ALL rows in big components (same as sel_idx rows)
    sel["parent_df_idx"] = sel["root"].map(parent_map_idx).to_numpy()
    sel["parent_record_id"] = sel["root"].map(parent_map_rid).to_numpy()

    # Determine which df rows in these components are eligible to update
    sel["eligible"] = eligible_mask.loc[sel["df_idx"]].to_numpy()

    # Update parents/children among eligible rows only
    is_parent_row = sel["df_idx"].to_numpy() == sel["parent_df_idx"].to_numpy()
    eligible_parent = sel["eligible"].to_numpy() & is_parent_row
    eligible_child = sel["eligible"].to_numpy() & (~is_parent_row)

    parent_idxs = sel.loc[eligible_parent, "df_idx"].to_numpy()
    child_idxs  = sel.loc[eligible_child, "df_idx"].to_numpy()

    # Group id strategy:
    # - stable and readable: "version::<parent_record_id>"
    # This is perfect for later merging with other stages.
    #gid = "version::" + sel["parent_record_id"].astype("string")
    gid = sel["parent_record_id"].astype("string")

    # Apply
    if parent_idxs.size:
        df.loc[parent_idxs, hierarchy_col] = "parent"
        df.loc[parent_idxs, parent_id_col] = pd.NA
        df.loc[parent_idxs, group_id_col] = gid.loc[sel["df_idx"].isin(parent_idxs)].to_numpy()
    if child_idxs.size:
        df.loc[child_idxs, hierarchy_col] = f"parent - duplicate ({label_duplicate_suffix})"
        df.loc[child_idxs, parent_id_col] = sel.loc[sel["df_idx"].isin(child_idxs), "parent_record_id"].to_numpy()
        df.loc[child_idxs, group_id_col] = gid.loc[sel["df_idx"].isin(child_idxs)].to_numpy()

    metrics["n_rows_updated"] = int(parent_idxs.size + child_idxs.size)
    metrics["n_parents_set"] = int(parent_idxs.size)
    metrics["n_children_set"] = int(child_idxs.size)

    metrics["runtime_s"] = time.perf_counter() - t0
    return df, metrics


# ------------------------------------------------------------
# Example usage
# ------------------------------------------------------------
# df2, m = unify_groups_by_version_links(
#     data_out,
#     overwrite_mode="unlabeled_only",   # safest: only fill missing
#     choose_parent="oldest",
#     date_col="date_first_seen",
#     chunk_size=300_000,
# )
# print(m)

# %%
data_out, metric = unify_groups_by_version_links(
    data_clean_isversionof,
    overwrite_mode="any",   
    choose_parent="oldest",
    date_col="date_first_seen",
    chunk_size=300_000,
)
print(metric)
# Out:
# {'n_rows_df': 7905699, 'n_rows_with_any_version_signal': 6281118, 'n_rows_considered_in_graph': 6281118, 'n_edges_unions_attempted': 398342, 'n_unions_done': 189511, 'n_components_total': 6091607, 'n_components_size_ge_2': 132374, 'n_rows_in_components_size_ge_2': 321885, 'n_rows_eligible_to_update': 7905699, 'n_rows_updated': 321885, 'n_parents_set': 132374, 'n_children_set': 189511, 'runtime_s': 32.883286376}

# %% [markdown]
# # save

# %%
from pathlib import Path
import json
import pandas as pd

OUT_DIR = Path("outputs_new")
OUT_DIR.mkdir(parents=True, exist_ok=True)

# Save metrics
with open(OUT_DIR / "dedupe_metrics_version_links.json", "w") as f:
    json.dump(metric, f, indent=2)

#pd.DataFrame(metric).to_csv(OUT_DIR / "dedupe_metrics_version_links.csv", index=False)

# Save dataset
data_out.to_parquet(OUT_DIR / "dedupe_data_out_version_links.parquet", index=False)

print("✅ All files saved to outputs/")
# Out:
# ✅ All files saved to outputs/

# %%
data_out['records_hierarchy'].value_counts()
# Out:
# records_hierarchy
# parent                                  7332296
# parent - duplicate (version-link)        189511
# parent - duplicate (SSRN)                112595
# parent - duplicate (arXiv)                59662
# parent - duplicate (Research Square)      40015
#                                          ...
# parent - duplicate (LatArXiv)                 2
# parent - duplicate (SAE Mobilus®)             2
# parent - duplicate (Encyclopedia)             1
# parent - duplicate (Therapoid)                1
# parent - duplicate (BioHackrXiv)              1
# Name: count, Length: 103, dtype: int64

# %%
data_out
# Out:
#                                    record_id  \
# 344247   crossref::10.1002/essoar.10500000.1
# 344248   crossref::10.1002/essoar.10500002.1
# 344243   crossref::10.1002/essoar.10500004.1
# 344269   crossref::10.1002/essoar.10500007.1
# 344264   crossref::10.1002/essoar.10500009.1
# ...                                      ...
# 2193176                 openalex::W999921877
# 868914                  openalex::W999947037
# 2099883                 openalex::W999974616
# 868068                  openalex::W999989114
# 2226731                 openalex::W999989584
#
#                                   server_name   backend  \
# 344247   Earth and Space Science Open Archive  crossref
# 344248   Earth and Space Science Open Archive  crossref
# 344243   Earth and Space Science Open Archive  crossref
# 344269   Earth and Space Science Open Archive  crossref
# 344264   Earth and Space Science Open Archive  crossref
# ...                                       ...       ...
# 2193176   RePEc: Research Papers in Economics  openalex
# 868914                                    HAL  openalex
# 2099883   RePEc: Research Papers in Economics  openalex
# 868068                                    HAL  openalex
# 2226731   RePEc: Research Papers in Economics  openalex
#
#                                doi                                    doi_url  \
# 344247   10.1002/essoar.10500000.1  https://doi.org/10.1002/essoar.10500000.1
# 344248   10.1002/essoar.10500002.1  https://doi.org/10.1002/essoar.10500002.1
# 344243   10.1002/essoar.10500004.1  https://doi.org/10.1002/essoar.10500004.1
# 344269   10.1002/essoar.10500007.1  https://doi.org/10.1002/essoar.10500007.1
# 344264   10.1002/essoar.10500009.1  https://doi.org/10.1002/essoar.10500009.1
# ...                            ...                                        ...
# 2193176                       None                                       None
# 868914                        None                                       None
# 2099883                       None                                       None
# 868068                        None                                       None
# 2226731                       None                                       None
#
#                                           landing_page_url type_backend_raw  \
# 344247   https://essopenarchive.org/doi/full/10.1002/es...   posted-content
# 344248   https://essopenarchive.org/doi/full/10.1002/es...   posted-content
# 344243   https://essopenarchive.org/doi/full/10.1002/es...   posted-content
# 344269   https://essopenarchive.org/doi/full/10.1002/es...   posted-content
# 344264   https://essopenarchive.org/doi/full/10.1002/es...   posted-content
# ...                                                    ...              ...
# 2193176  https://steconomice.uoradea.ro/anale/volume/20...         preprint
# 868914                    https://hal.science/hal-01922484         preprint
# 2099883   https://EconPapers.repec.org/RePEc:cde:cdewps:19         preprint
# 868068                    https://hal.science/hal-01268467         preprint
# 2226731  http://thred.devecon.org/papers/2014/2014-018_...         preprint
#
#         subtype_backend_raw  \
# 344247             preprint
# 344248             preprint
# 344243             preprint
# 344269             preprint
# 344264             preprint
# ...                     ...
# 2193176                None
# 868914                 None
# 2099883                None
# 868068                 None
# 2226731                None
#
#                                                      title  \
# 344247   Long-term monitoring of land surface phenologi...
# 344248   Impact of spatial scale for phenological indic...
# 344243   Observations of Low Latitude Red Aurora in Mex...
# 344269   Pipeline oil fire detection with MODIS active ...
# 344264   Land Product Validation of MODIS Derived FPAR ...
# ...                                                    ...
# 2193176  IDE sous l'influence du degré de l'intégration...
# 868914   Building realistic potential patients queries ...
# 2099883  Debt Financing with Limited Liability and Quan...
# 868068   Sustainable orchards' redesign: at the crossro...
# 2226731  When warm glow burns: Motivational (mis)alloca...
#
#                                               authors_flat  \
# 344247                                Tsutsumida, Narumasa
# 344248                   Tsutsumida, Narumasa; Kaduk, Jörg
# 344243   Gonzalez-Esparza, J. Americo; Cuevas-Cardona, ...
# 344269   Ogungbuyi, Michael Gbenga; Martinez, Peter; Ec...
# 344264   Sharp, Iain; Sanchez-Azofeifa, Arturo; Musilek...
# ...                                                    ...
# 2193176                        Simona-Gabriela Serbu Masca
# 868914   Lorraine Goeuriot; Wendy W. Chapman; Gareth Jf...
# 2099883                          Krishnendu Ghosh Dastidar
# 868068   Servane Penvern; Sylvaine Simon; Stéphane Bell...
# 2226731  Gani Aldashev; Esteban Jaimovich; Thierry Verdier
#
#                                          institutions_flat  countries_flat  \
# 344247                                                None            None
# 344248                                                None            None
# 344243          Universidad Autónoma del Estado de Hidalgo            None
# 344269                                                None            None
# 344264                                                None            None
# ...                                                    ...             ...
# 2193176                            Babeș-Bolyai University              RO
# 868914   Laboratoire d'Informatique de Grenoble; Dublin...          FR; IE
# 2099883                                               None            None
# 868068   Institut National de Recherche pour l'Agricult...              FR
# 2226731  University of Namur; University of Surrey; Éco...  BE; GB; BI; FR
#
#                                             relations_json version_label  \
# 344247                                                None          None
# 344248                                                None          None
# 344243   {"is-preprint-of": [{"asserted-by": "subject",...          None
# 344269                                                None          None
# 344264                                                None          None
# ...                                                    ...           ...
# 2193176                                               None          None
# 868914                                                None          None
# 2099883                                               None          None
# 868068                                                None          None
# 2226731                                               None          None
#
#         is_version_of        is_preprint_of has_preprint has_review  \
# 344247            NaN
# 344248            NaN
# 344243            NaN  10.1029/2018sw001995
# 344269            NaN
# 344264            NaN
# ...               ...                   ...          ...        ...
# 2193176          None                  None         None       None
# 868914           None                  None         None       None
# 2099883          None                  None         None       None
# 868068           None                  None         None       None
# 2226731          None                  None         None       None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 344247                  false                       None                None
# 344248                  false                       None                None
# 344243                   true                       None                None
# 344269                  false                       None                None
# 344264                  false                       None                None
# ...                       ...                        ...                 ...
# 2193176                  None                       None                None
# 868914                   None                       None                None
# 2099883                  None                       None                None
# 868068                   None                       None                None
# 2226731                  None                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 344247            None                   None            parent
# 344248            None                   None            parent
# 344243            None                   None            parent
# 344269            None                   None            parent
# 344264            None                   None            parent
# ...                ...                    ...               ...
# 2193176           None                   None            parent
# 868914            None                   None            parent
# 2099883           None                   None            parent
# 868068            None                   None            parent
# 2226731           None                   None            parent
#
#         date_first_seen  publication_year  publication_year_first_seen  \
# 344247       2018-05-24            2018.0                         2018
# 344248       2018-05-27            2018.0                         2018
# 344243       2018-05-28            2018.0                         2018
# 344269       2018-05-30            2018.0                         2018
# 344264       2018-06-05            2018.0                         2018
# ...                 ...               ...                          ...
# 2193176      2008-01-01            2008.0                         2008
# 868914       2014-01-01            2014.0                         2014
# 2099883      1994-08-01            1994.0                         1994
# 868068       2012-07-01            2012.0                         2012
# 2226731      2015-02-01            2015.0                         2015
#
#         raw_dates records_hierarchy_backup parent_record_id dup_group_id  \
# 344247       None                   parent             None         None
# 344248       None                   parent             None         None
# 344243       None                   parent             None         None
# 344269       None                   parent             None         None
# 344264       None                   parent             None         None
# ...           ...                      ...              ...          ...
# 2193176      None                   parent             None         None
# 868914       None                   parent             None         None
# 2099883      None                   parent             None         None
# 868068       None                   parent             None         None
# 2226731      None                   parent             None         None
#
#                                      authors_fp_tokenbag  \
# 344247                                              None
# 344248                                              None
# 344243                                              None
# 344269                                              None
# 344264                                              None
# ...                                                  ...
# 2193176                      gabriela_masca_serbu_simona
# 868914                                              None
# 2099883                        dastidar_ghosh_krishnendu
# 868068                                              None
# 2226731  aldashev_gani;esteban_jaimovich;thierry_verdier
#
#                                             title_clean_v2  \
# 344247                                                None
# 344248                                                None
# 344243                                                None
# 344269                                                None
# 344264                                                None
# ...                                                    ...
# 2193176  ide sous l influence du degre de l integration...
# 868914                                                None
# 2099883  debt financing with limited liability and quan...
# 868068                                                None
# 2226731  when warm glow burns motivational mis allocati...
#
#                   authors_fp_last_initial authors_fp_last  \
# 344247                               None            None
# 344248                               None            None
# 344243                               None            None
# 344269                               None            None
# 344264                               None            None
# ...                                   ...             ...
# 2193176                           masca|s            None
# 868914                               None            None
# 2099883                        dastidar|k            None
# 868068                               None            None
# 2226731  aldashev|g;jaimovich|e;verdier|t            None
#
#         records_hierarchy_dedupe_backup parent_record_id_dedupe_backup  \
# 344247                           parent                           None
# 344248                           parent                           None
# 344243                           parent                           None
# 344269                           parent                           None
# 344264                           parent                           None
# ...                                 ...                            ...
# 2193176                          parent                           None
# 868914                           parent                           None
# 2099883                          parent                           None
# 868068                           parent                           None
# 2226731                          parent                           None
#
#         dup_group_id_dedupe_backup has_version_dois
# 344247                        None             None
# 344248                        None             None
# 344243                        None             None
# 344269                        None             None
# 344264                        None             None
# ...                            ...              ...
# 2193176                       None             None
# 868914                        None             None
# 2099883                       None             None
# 868068                        None             None
# 2226731                       None             None
#
# [7905699 rows x 39 columns]

# %%
# to check records_hierarchy

# %%
pattern = "10.26434/chemrxiv.13102877"


mask = data_out['doi'].str.contains(pattern, regex=False, na=False)
result = data_out[mask]
print(len(result))
result
# Out:
# 32
#                                        record_id server_name   backend  \
# 235547   crossref::10.26434/chemrxiv.13102877.v1    ChemRxiv  crossref
# 235900  crossref::10.26434/chemrxiv.13102877.v10    ChemRxiv  crossref
# 235949  crossref::10.26434/chemrxiv.13102877.v11    ChemRxiv  crossref
10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 235852  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
#
#        has_preprint has_review has_published_version  \
# 235547                                         false
# 235900                                         false
# 235949                                         false
# 235995                                         false
# 236036                                         false
# 236086                                         false
# 236145                                         false
# 236162                                         false
# 236171                                         false
# 236176                                         false
# 236174                                         false
# 235577                                         false
# 236175                                         false
# 236180                                         false
# 236182                                         false
# 236183                                         false
# 236188                                         false
# 236189                                         false
# 236191                                         false
# 236192                                         false
# 236193                                         false
# 236194                                         false
# 235604                                         false
# 236195                                         false
# 236198                                         false
# 236201                                         false
# 235635                                         false
# 235675                                         false
# 235705                                         false
# 235760                                         false
# 235810                                         false
# 235852                                         false
#
#        published_version_ids_json version_of_ids_json update_to_json  \
# 235547                       None                None           None
# 235900                       None                None           None
# 235949                       None                None           None
# 235995                       None                None           None
# 236036                       None                None           None
# 236086                       None                None           None
# 236145                       None                None           None
# 236162                       None                None           None
# 236171                       None                None           None
# 236176                       None                None           None
# 236174                       None                None           None
# 235577                       None                None           None
# 236175                       None                None           None
# 236180                       None                None           None
# 236182                       None                None           None
# 236183                       None                None           None
# 236188                       None                None           None
# 236189                       None                None           None
# 236191                       None                None           None
# 236192                       None                None           None
# 236193                       None                None           None
# 236194                       None                None           None
# 235604                       None                None           None
# 236195                       None                None           None
# 236198                       None                None           None
# 236201                       None                None           None
# 235635                       None                None           None
# 235675                       None                None           None
# 235705                       None                None           None
# 235760                       None                None           None
# 235810                       None                None           None
# 235852                       None                None           None
#
#        raw_relationships_json                  records_hierarchy  \
# 235547                   None                             parent
# 235900                   None  parent - duplicate (version-link)
# 235949                   None  parent - duplicate (version-link)
# 235995                   None  parent - duplicate (version-link)
# 236036                   None  parent - duplicate (version-link)
# 236086                   None  parent - duplicate (version-link)
# 236145                   None  parent - duplicate (version-link)
# 236162                   None  parent - duplicate (version-link)
# 236171                   None  parent - duplicate (version-link)
# 236176                   None  parent - duplicate (version-link)
# 236174                   None  parent - duplicate (version-link)
# 235577                   None  parent - duplicate (version-link)
# 236175                   None  parent - duplicate (version-link)
# 236180                   None  parent - duplicate (version-link)
# 236182                   None  parent - duplicate (version-link)
# 236183                   None  parent - duplicate (version-link)
# 236188                   None  parent - duplicate (version-link)
# 236189                   None  parent - duplicate (version-link)
# 236191                   None  parent - duplicate (version-link)
# 236192                   None  parent - duplicate (version-link)
# 236193                   None  parent - duplicate (version-link)
# 236194                   None  parent - duplicate (version-link)
# 235604                   None  parent - duplicate (version-link)
# 236195                   None  parent - duplicate (version-link)
# 236198                   None  parent - duplicate (version-link)
# 236201                   None  parent - duplicate (version-link)
# 235635                   None  parent - duplicate (version-link)
# 235675                   None  parent - duplicate (version-link)
# 235705                   None  parent - duplicate (version-link)
# 235760                   None  parent - duplicate (version-link)
# 235810                   None  parent - duplicate (version-link)
# 235852                   None  parent - duplicate (version-link)
#
#        date_first_seen  publication_year  publication_year_first_seen  \
# 235547      2020-10-23            2020.0                         2020
# 235900      2020-12-03            2020.0                         2020
# 235949      2020-12-04            2020.0                         2020
# 235995      2020-12-07            2020.0                         2020
# 236193  crossref::10.26434/chemrxiv.13102877.v1
# 236194  crossref::10.26434/chemrxiv.13102877.v1
# 235604  crossref::10.26434/chemrxiv.13102877.v1
# 236195  crossref::10.26434/chemrxiv.13102877.v1
# 236198  crossref::10.26434/chemrxiv.13102877.v1
# 236201  crossref::10.26434/chemrxiv.13102877.v1
# 235635  crossref::10.26434/chemrxiv.13102877.v1
# 235675  crossref::10.26434/chemrxiv.13102877.v1
# 235705  crossref::10.26434/chemrxiv.13102877.v1
# 235760  crossref::10.26434/chemrxiv.13102877.v1
# 235810  crossref::10.26434/chemrxiv.13102877.v1
# 235852  crossref::10.26434/chemrxiv.13102877.v1
#
#                                    dup_group_id authors_fp_tokenbag  \
# 235547  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 235900  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 235949  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 235995  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236036  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236086  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236145  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236162  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236171  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236176  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236174  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 235577  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236175  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236180  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236182  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236183  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236188  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236189  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236191  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236192  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236193  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236194  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 235604  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236195  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236198  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 236201  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 235635  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 235675  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 235705  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 235760  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 235810  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 235852  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
#
#                                            title_clean_v2  \
# 235547  aptamers for detection and diagnostics add pro...
# 235900  aptamers for detection and diagnostics add is ...
# 235949  aptamers for detection and diagnostics add is ...
# 235995  aptamers for detection and diagnostics add is ...
# 236036  aptamers for detection and diagnostics add is ...
# 236086  aptamers for detection and diagnostics add is ...
# 236145  aptamers for detection and diagnostics add is ...
# 236162  aptamers for detection and diagnostics add is ...
# 236171  aptamers for detection and diagnostics add is ...
# 236176  aptamers for detection and diagnostics add is ...
# 236174  aptamers for detection and diagnostics add is ...
# 235577  aptamers for detection and diagnostics add pro...
# 236175  aptamers for detection and diagnostics add is ...
# 236180  aptamers for detection and diagnostics add is ...
# 236182  aptamers for detection and diagnostics add is ...
# 236183  aptamers for detection and diagnostics add is ...
# 236188  aptamers for detection and diagnostics add is ...
# 236189  aptamers for detection and diagnostics add is ...
# 236191  aptamers for detection and diagnostics add is ...
# 236192  aptamers for detection and diagnostics add is ...
# 236193  aptamers for detection and diagnostics add is ...
# 236194  aptamers for detection and diagnostics add is ...
# 235604  aptamers for detection and diagnostics add is ...
# 236195  aptamers for detection and diagnostics add is ...
# 236198  aptamers for detection and diagnostics add can...
# 236201  aptamers for detection and diagnostics add can...
# 235635  aptamers for detection and diagnostics add is ...
# 235675  aptamers for detection and diagnostics add is ...
# 235705  aptamers for detection and diagnostics add is ...
# 235760  aptamers for detection and diagnostics add is ...
# 235810  aptamers for detection and diagnostics add is ...
# 235852  aptamers for detection and diagnostics add is ...
#
#        authors_fp_last_initial authors_fp_last  \
# 235547                 datta|s            None
# 235900                    None            None
# 235949                    None            None
# 235995                    None            None
# 236036                    None            None
# 236086                    None            None
# 236145                    None            None
# 236162                    None            None
# 236171                    None            None
# 236176                    None            None
# 236174                    None            None
# 235577                    None            None
# 236175                    None            None
# 236180                    None            None
# 236182                    None            None
# 236183                    None            None
# 236188                    None            None
# 236189                    None            None
# 236191                    None            None
# 236192                    None            None
# 236193                    None            None
# 236194                    None            None
# 235604                 datta|s            None
# 236195                    None            None
# 236198                 datta|s            None
# 236201                    None            None
# 235635                    None            None
# 235675                    None            None
# 235705                    None            None
# 235760                    None            None
# 235810                    None            None
# 235852                    None            None
#
#        records_hierarchy_dedupe_backup  \
# 235547                          parent
# 235900   parent - duplicate (ChemRxiv)
# 235949   parent - duplicate (ChemRxiv)
# 235995   parent - duplicate (ChemRxiv)
# 236036   parent - duplicate (ChemRxiv)
# 236086   parent - duplicate (ChemRxiv)
# 236145   parent - duplicate (ChemRxiv)
# 236162   parent - duplicate (ChemRxiv)
# 236171   parent - duplicate (ChemRxiv)
# 236176   parent - duplicate (ChemRxiv)
# 236174   parent - duplicate (ChemRxiv)
# 235577   parent - duplicate (ChemRxiv)
# 236175   parent - duplicate (ChemRxiv)
# 236180   parent - duplicate (ChemRxiv)
# 236182   parent - duplicate (ChemRxiv)
# 236183   parent - duplicate (ChemRxiv)
# 236188   parent - duplicate (ChemRxiv)
# 236189   parent - duplicate (ChemRxiv)
# 236191   parent - duplicate (ChemRxiv)
# 236192   parent - duplicate (ChemRxiv)
# 236193   parent - duplicate (ChemRxiv)
# 236194   parent - duplicate (ChemRxiv)
# 235604                          parent
# 236195   parent - duplicate (ChemRxiv)
# 236198                          parent
# 236201   parent - duplicate (ChemRxiv)
# 235635   parent - duplicate (ChemRxiv)
# 235675   parent - duplicate (ChemRxiv)
# 235705   parent - duplicate (ChemRxiv)
# 235760   parent - duplicate (ChemRxiv)
# 235810   parent - duplicate (ChemRxiv)
# 235852   parent - duplicate (ChemRxiv)
#
#                   parent_record_id_dedupe_backup dup_group_id_dedupe_backup  \
# 235547                                      None       16854196709595633026
# 235900   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 235949   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 235995   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236036   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236086   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236145   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236162   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236171   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236176   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236174   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 235577   crossref::10.26434/chemrxiv.13102877.v1       16854196709595633026
# 236175   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236180   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236182   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236183   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236188   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236189   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236191   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236192   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236193   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236194   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 235604                                      None       15378799223749550050
# 236195   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 236198                                      None       15120014104423475792
# 236201  crossref::10.26434/chemrxiv.13102877.v31       15120014104423475792
# 235635   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 235675   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 235705   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 235760   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 235810   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 235852   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
#
#        has_version_dois
# 235547             None
# 235900             None
# 235949             None
# 235995             None
# 236036             None
# 236086             None
# 236145             None
# 236162             None
# 236171             None
# 236176             None
# 236174             None
# 235577             None
# 236175             None
# 236180             None
# 236182             None
# 236183             None
# 236188             None
# 236189             None
# 236191             None
# 236192             None
# 236193             None
# 236194             None
# 235604             None
# 236195             None
# 236198             None
# 236201             None
# 235635             None
# 235675             None
# 235705             None
# 235760             None
# 235810             None
# 235852             None

# %%
result['dup_group_id'].value_counts()
# Out:
# dup_group_id
# crossref::10.26434/chemrxiv.13102877.v1    32
# Name: count, dtype: int64

# %%
result['parent_record_id'].value_counts()
# Out:
# parent_record_id
# crossref::10.26434/chemrxiv.13102877.v1    31
# Name: count, dtype: int64

# %%
result['records_hierarchy'].value_counts()
# Out:
# records_hierarchy
# parent - duplicate (version-link)    31
# parent                                1
# Name: count, dtype: int64
