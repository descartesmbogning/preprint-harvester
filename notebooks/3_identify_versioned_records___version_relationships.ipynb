# %%
import pandas as pd
# Set option to display all columns
pd.set_option('display.max_columns', None)

# %%
data = pd.read_parquet("outputs_new/dedupe_data_out.parquet")
data
# Out:
#                                record_id     server_name   backend  \
# 0        crossref::10.21467/preprints.48  AIJR Preprints  crossref
# 1        crossref::10.21467/preprints.43  AIJR Preprints  crossref
# 2        crossref::10.21467/preprints.39  AIJR Preprints  crossref
# 3        crossref::10.21467/preprints.38  AIJR Preprints  crossref
# 4        crossref::10.21467/preprints.36  AIJR Preprints  crossref
# ...                                  ...             ...       ...
# 8412647             openalex::W999325625           viXra  openalex
# 8412648             openalex::W999460032           viXra  openalex
# 8412649              openalex::W99967155           viXra  openalex
# 8412650             openalex::W999790414           viXra  openalex
# 8412651             openalex::W999805801           viXra  openalex
#
#                            doi                                doi_url  \
# 0        10.21467/preprints.48  https://doi.org/10.21467/preprints.48
# 1        10.21467/preprints.43  https://doi.org/10.21467/preprints.43
# 2        10.21467/preprints.39  https://doi.org/10.21467/preprints.39
# 3        10.21467/preprints.38  https://doi.org/10.21467/preprints.38
# 4        10.21467/preprints.36  https://doi.org/10.21467/preprints.36
# ...                        ...                                    ...
# 8412647                   None                                   None
# 8412648                   None                                   None
# 8412649                   None                                   None
# 8412650                   None                                   None
# 8412651                   None                                   None
#
#                                           landing_page_url  \
# 0        https://preprints.aijr.org/index.php/ap/prepri...
# 1        https://preprints.aijr.org/index.php/ap/prepri...
# 2        https://preprints.aijr.org/index.php/ap/prepri...
# 3        https://preprints.aijr.org/index.php/ap/prepri...
# 4        https://preprints.aijr.org/index.php/ap/prepri...
# ...                                                    ...
# 8412647              https://vixra.org/pdf/1409.0090v1.pdf
# 8412648                    https://vixra.org/abs/1112.0094
# 8412649              https://vixra.org/pdf/1406.0019v1.pdf
# 8412650              https://vixra.org/pdf/1306.0105v3.pdf
# 8412651              https://vixra.org/pdf/1412.0197v3.pdf
#
#                                                      title  \
# 0        Bird’s Eye View on the Diagnosis, Treatment, &...
# 1        Doxycycline and Minocycline Drugs as a Treatme...
# 2        A Genetic Perspective of 2019-nCoV in Relation...
# 3        Marine Algae as a Natural Source for Antiviral...
# 4        Possible Prevention of COVID 19 by Using Linol...
# ...                                                    ...
# 8412647                 Three Objections to Modern Physics
# 8412648                               Particle Mass Ratios
# 8412649  Quantum FFF Theory Proposals for Some Unsolved...
# 8412650  Investigation of the Formalism of Particle Dyn...
# 8412651  Electromagnetic Energy and Electromagnetic For...
#
#                                               authors_flat institutions_flat  \
# 0                              Panchalingala, Sai Bhargavi              None
# 1                                         Mostafa, Mohamed              None
# 2                                        Dasgupta, Rimjhim              None
# 3        Musale, Amar S; G., Raja Krishna Kumar; Sapre,...              None
# 4        Subhash, Venkata; G, Raja Krishna Kumar; Sapre...              None
# ...                                                    ...               ...
# 8412647                                      Lubomir Vlcek              None
# 8412648                                         DT Froedge              None
# 8412649                                           Leo Vuyk              None
# 8412650                                        Chi-Yi Chen              None
# 8412651                                    Yu.A. Spirichev              None
#
#         countries_flat relations_json version_label is_version_of  \
# 0                 None           None          None
# 1                 None           None          None
# 2                 None           None          None
# 3                 None           None          None
# 4                 None           None          None
# ...                ...            ...           ...           ...
# 8412647           None           None          None          None
# 8412648           None           None          None          None
# 8412649           None           None          None          None
# 8412650           None           None          None          None
# 8412651           None           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 0                                                              false
# 1                                                              false
# 2                                                              false
# 3                                                              false
# 4                                                              false
# ...                ...          ...        ...                   ...
# 8412647           None         None       None                  None
# 8412648           None         None       None                  None
# 8412649           None         None       None                  None
# 8412650           None         None       None                  None
# 8412651           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 0                             None                None           None
# 1                             None                None           None
# 2                             None                None           None
# 3                             None                None           None
# 4                             None                None           None
# ...                            ...                 ...            ...
# 8412647                       None                None           None
# 8412648                       None                None           None
# 8412649                       None                None           None
# 8412650                       None                None           None
# 8412651                       None                None           None
#
#         raw_relationships_json records_hierarchy date_first_seen  \
# 0                         None            parent      2020-05-03
# 1                         None            parent      2020-04-25
# 2                         None            parent      2020-04-16
# 3                         None            parent      2020-04-15
# 4                         None            parent      2020-04-15
# ...                        ...               ...             ...
# 8412647                   None            parent      2014-09-01
# 8412648                   None            parent      2011-12-01
# 8412649                   None            parent      2014-06-01
# 8412650                   None            parent      2013-06-01
# 8412651                   None            parent      2014-12-01
#
#          publication_year_first_seen records_hierarchy_backup  \
# 0                               2020                   parent
# 1                               2020                   parent
# 2                               2020                   parent
# 3                               2020                   parent
# 4                               2020                   parent
# ...                              ...                      ...
# 8412647                         2014                   parent
# 8412648                         2011                   parent
# 8412649                         2014                   parent
# 8412650                         2013                   parent
# 8412651                         2014                   parent
#
#         parent_record_id dup_group_id authors_fp_tokenbag  \
# 0                   None         None                None
# 1                   None         None     mohamed_mostafa
# 2                   None         None    dasgupta_rimjhim
# 3                   None         None                None
# 4                   None         None                None
# ...                  ...          ...                 ...
# 8412647             None         None       lubomir_vlcek
# 8412648             None         None          dt_froedge
# 8412649             None         None            leo_vuyk
# 8412650             None         None         chen_chi_yi
# 8412651             None         None      a_spirichev_yu
#
#                                             title_clean_v2  \
# 0                                                     None
# 1        doxycycline and minocycline drugs as a treatme...
# 2        a genetic perspective of 2019 ncov in relation...
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 8412647                 three objections to modern physics
# 8412648                               particle mass ratios
# 8412649  quantum fff theory proposals for some unsolved...
# 8412650  investigation of the formalism of particle dyn...
# 8412651  electromagnetic energy and electromagnetic for...
#
#         authors_fp_last_initial authors_fp_last
# 0                          None            None
# 1                     mostafa|m            None
# 2                    dasgupta|r            None
# 3                          None            None
# 4                          None            None
# ...                         ...             ...
# 8412647                 vlcek|l            None
# 8412648               froedge|d            None
# 8412649                  vuyk|l            None
# 8412650                  chen|c            None
# 8412651             spirichev|y            None
#
# [8412652 rows x 31 columns]

# %%
data.columns
# Out:
# Index(['record_id', 'server_name', 'backend', 'doi', 'doi_url',
#        'landing_page_url', 'title', 'authors_flat', 'institutions_flat',
#        'countries_flat', 'relations_json', 'version_label', 'is_version_of',
#        'is_preprint_of', 'has_preprint', 'has_review', 'has_published_version',
#        'published_version_ids_json', 'version_of_ids_json', 'update_to_json',
#        'raw_relationships_json', 'records_hierarchy', 'date_first_seen',
#        'publication_year_first_seen', 'records_hierarchy_backup',
#        'parent_record_id', 'dup_group_id', 'authors_fp_tokenbag',
#        'title_clean_v2', 'authors_fp_last_initial', 'authors_fp_last'],
#       dtype='object')

# %%
import numpy as np
data['is_version_of'] = data['is_version_of'].replace('', np.nan)

relation_ship_count = data['is_version_of'].value_counts()
relation_ship_count
# Out:
# is_version_of
# 10.2139/ssrn.2721313                152
# 10.5281/zenodo.16899882              73
# 10.5281/zenodo.15408957              50
# 10.5281/zenodo.16944712              29
# 10.5281/zenodo.15571875              22
#                                    ...
# 10.20944/preprints202208.0284.v2      1
# 10.20944/preprints202108.0448.v2      1
# 10.20944/preprints202010.0374.v2      1
# 10.20944/preprints202006.0203.v2      1
# 10.20944/preprints202210.0057.v1      1
# Name: count, Length: 81606, dtype: int64

# %%
import pandas as pd
import numpy as np

# Columns to duplicate
cols_to_duplicate = ['records_hierarchy', 'parent_record_id','dup_group_id']

# Duplicate the columns with new names
data[['records_hierarchy_dedupe_backup', 'parent_record_id_dedupe_backup', 'dup_group_id_dedupe_backup']] = data[cols_to_duplicate].copy()

data.columns
# Out:
# Index(['record_id', 'server_name', 'backend', 'doi', 'doi_url',
#        'landing_page_url', 'title', 'authors_flat', 'institutions_flat',
#        'countries_flat', 'relations_json', 'version_label', 'is_version_of',
#        'is_preprint_of', 'has_preprint', 'has_review', 'has_published_version',
#        'published_version_ids_json', 'version_of_ids_json', 'update_to_json',
#        'raw_relationships_json', 'records_hierarchy', 'date_first_seen',
#        'publication_year_first_seen', 'records_hierarchy_backup',
#        'parent_record_id', 'dup_group_id', 'authors_fp_tokenbag',
#        'title_clean_v2', 'authors_fp_last_initial', 'authors_fp_last',
#        'records_hierarchy_dedupe_backup', 'parent_record_id_dedupe_backup',
#        'dup_group_id_dedupe_backup'],
#       dtype='object')

# %%
bad_values = {"others", "part_of", "comment", "review"}

mask = ~data["records_hierarchy_backup"].astype(str).str.contains(
    r"\b(" + "|".join(bad_values) + r")\b",
    case=False,
    regex=True
)

data_clean = data[mask].copy()
# Out:
# /tmp/ipykernel_175359/2399585284.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = ~data["records_hierarchy_backup"].astype(str).str.contains(

# %%
data_clean['records_hierarchy'].unique()
# Out:
# array(['parent', 'parent - duplicate (SSRN)',
#        'parent - duplicate (Preprints.org)',
#        'parent - duplicate (AMRC Open Research)',
#        'parent - duplicate (APSA Preprints)',
#        'parent - duplicate (medRxiv)',
#        'parent - duplicate (ResearchGate)',
#        'parent - duplicate (EconStor Preprints)',
#        'parent - duplicate (ScienceOpen Preprints)',
#        'parent - duplicate (arXiv)', 'parent - duplicate (SocArXiv)',
#        'parent - duplicate (Open Science Framework)',
#        'parent - duplicate (PREPRINTS.RU)',
#        'parent - duplicate (MediArXiv)',
#        'parent - duplicate (ARPHA Preprints)',
#        'parent - duplicate (Research Square)',
#        'parent - duplicate (Authorea Inc.)',
#        'parent - duplicate (bioRxiv)', 'parent - duplicate (ART-Dok)',
#        'parent - duplicate (HAL)',
#        'parent - duplicate (Social Science Open Access Repository)',
#        'parent - duplicate (Humanities Commons CORE)',
#        'parent - duplicate (Advance)', 'parent - duplicate (PsyArXiv)',
#        'parent - duplicate (EdArXiv)', 'parent - duplicate (Zenodo)',
#        'parent - duplicate (AfricArXiv)', 'parent - duplicate (engrXiv)',
#        'parent - duplicate (Qeios)',
#        'parent - duplicate (Thesis Commons)',
#        'parent - duplicate (Gates Open Research)',
#        'parent - duplicate (UnisaRxiv)',
#        'parent - duplicate (AgEcon Search)',
#        'parent - duplicate (Munich Personal RePEc Archive)',
#        'parent - duplicate (AIJR Preprints)',
#        'parent - duplicate (Cambridge Open Engage)',
#        'parent - duplicate (TechRxiv)',
#        'parent - duplicate (RePEc: Research Papers in Economics)',
#        'parent - duplicate (Organic Eprints)',
#        'parent - duplicate (National Bureau of Economic Research)',
#        'parent - duplicate (AgriRxiv)', 'parent - duplicate (DSpace@MIT)',
#        'parent - duplicate (Digital Access to Scholarship at Harvard (DASH) (Harvard University))',
#        'parent - duplicate (MetaArXiv)', 'parent - duplicate (VeriXiv)',
#        'parent - duplicate (INA-Rxiv)',
#        'parent - duplicate (Earth and Space Science Open Archive)',
#        'parent - duplicate (Arabixiv)',
#        'parent - duplicate (LIS Scholarship Archive)',
#        'parent - duplicate (PeerJ Preprints)',
#        'parent - duplicate (ChemRxiv)', 'parent - duplicate (EcoEvoRxiv)',
#        'parent - duplicate (JMIR Preprints)',
#        'parent - duplicate (E-LIS Repository)',
#        'parent - duplicate (EarthArXiv)', 'parent - duplicate (eLife)',
#        'parent - duplicate (Wellcome Open Research)',
#        'parent - duplicate (F1000Research)',
#        'parent - duplicate (EGUsphere)',
#        'parent - duplicate (ResearchHub)',
#        'parent - duplicate (Bepress Legal Repository)',
#        'parent - duplicate (BioHackrXiv)',
#        'parent - duplicate (BodoArXiv)',
#        'parent - duplicate (CERN document server)',
#        'parent - duplicate (IndiaRxiv)',
#        'parent - duplicate (Beilstein Archives)',
#        'parent - duplicate (CoP)', 'parent - duplicate (CogPrints)',
#        'parent - duplicate (Covid-19 Preprints)',
#        'parent - duplicate (CrimRxiv)',
#        'parent - duplicate (Law Archive)',
#        'parent - duplicate (CrossAsia-Repository)',
#        'parent - duplicate (Nature Precedings)',
#        'parent - duplicate (IACR Cryptology ePrint Archive)',
#        'parent - duplicate (ECSarXiv)', 'parent - duplicate (viXra)',
#        'parent - duplicate (EasyChair preprint)',
#        'parent - duplicate (LSE Research Online Documents on Economics)',
#        'parent - duplicate (Frenxiv)', 'parent - duplicate (MarXiv)',
#        'parent - duplicate (Electron Colloquium Comput Complex)',
#        'parent - duplicate (Encyclopedia)',
#        'parent - duplicate (EnerarXiv)',
#        'parent - duplicate (Open Research Africa)',
#        'parent - duplicate (FocUS Archive)',
#        'parent - duplicate (PhilSci-Archive)',
#        'parent - duplicate (HRB Open Research)',
#        'parent - duplicate (NutriXiv)', 'parent - duplicate (SportRxiv)',
#        'parent - duplicate (None)',
#        'parent - duplicate (Keldysh Institute Preprints)',
#        'parent - duplicate (LatArXiv)',
#        'parent - duplicate (MNI Open Research)',
#        'parent - duplicate (MindRxiv)',
#        'parent - duplicate (NewAddictionsX)',
#        'parent - duplicate (Open Research Europe)',
#        'parent - duplicate (UCL Open Environment)',
#        'parent - duplicate (PaleorXiv)',
#        'parent - duplicate (Oroboros Instruments)',
#        'parent - duplicate (SciELO Preprints)',
#        'parent - duplicate (Prepublicaciones OpenCiencia)',
#        'parent - duplicate (PropylaeumDok)',
#        'parent - duplicate (WikiJournal of Medicine)',
#        'parent - duplicate (prepare@u)',
#        'parent - duplicate (SAE Mobilus®)',
#        'parent - duplicate (WikiJournal of Humanities)',
#        'parent - duplicate (Therapoid)',
#        'parent - duplicate (WikiJournal of Science)',
#        'parent - duplicate (searchRxiv)'], dtype=object)

# %%
data_clean['records_hierarchy_backup'].value_counts().head(60)
# Out:
# records_hierarchy_backup
# parent                              7950091
# version                              105977
# publish_version                        9351
# mirror (arXiv)                         8286
# mirror (AgEcon Search)                 6702
# child                                  2028
# mirror (ResearchGate)                  1633
# correction                              355
# mirror (Zenodo)                         297
# mirror (SSRN)                            36
# mirror (Open Science Framework)          31
# mirror (bioRxiv)                         29
# mirror (Humanities Commons CORE)         24
# mirror (eLife)                            3
# parent_duplicate                          3
# mirror (CERN document server)             2
# mirror (AfricArXiv)                       2
# mirror (Research Square)                  2
# mirror (medRxiv)                          1
# mirror (TechRxiv)                         1
# mirror (EarthArXiv)                       1
# mirror (Oroboros Instruments)             1
# mirror (Law Archive)                      1
# mirror (Thesis Commons)                   1
# mirror (SocArXiv)                         1
# mirror (AgriRxiv)                         1
# Name: count, dtype: int64

# %%
import time
import pandas as pd
import numpy as np
from typing import Dict, Any, Optional

# ------------------------------------------------------------
# Union-Find (Disjoint Set Union) for fast connected-components
# ------------------------------------------------------------
class _UnionFind:
    __slots__ = ("parent", "size")

    def __init__(self, n: int):
        self.parent = np.arange(n, dtype=np.int32)
        self.size = np.ones(n, dtype=np.int32)

    def find(self, x: int) -> int:
        parent = self.parent
        while parent[x] != x:
            parent[x] = parent[parent[x]]
            x = parent[x]
        return x

    def union(self, a: int, b: int) -> bool:
        pa = self.find(a)
        pb = self.find(b)
        if pa == pb:
            return False
        # union by size
        if self.size[pa] < self.size[pb]:
            pa, pb = pb, pa
        self.parent[pb] = pa
        self.size[pa] += self.size[pb]
        return True


def unify_groups_by_version_links(
    df: pd.DataFrame,
    *,
    # core cols
    record_id_col: str = "record_id",
    doi_col: str = "doi",
    is_version_of_col: str = "is_version_of",

    # output cols
    hierarchy_col: str = "records_hierarchy",
    parent_id_col: str = "parent_record_id",
    group_id_col: str = "dup_group_id",

    # parent choice
    date_col: Optional[str] = "date_first_seen",      # if None, will use record_id numeric fallback only
    choose_parent: str = "oldest",                    # "oldest" | "newest"

    # how safe to overwrite
    # - "unlabeled_only": only rows with NA hierarchy are eligible
    # - "parent_only": only rows currently labeled "parent" are eligible
    # - "any": any row is eligible
    overwrite_mode: str = "unlabeled_only",

    # labeling
    label_duplicate_suffix: str = "version-link",     # becomes "parent - duplicate (version-link)"

    # performance
    chunk_size: int = 300_000,                        # only affects the union loop; tune for RAM/CPU
    min_component_size: int = 2,                      # ignore components of size < 2
) -> tuple[pd.DataFrame, Dict[str, Any]]:
    """
    Unify clusters using explicit version relationships (is_version_of) as a HIGH-CONFIDENCE step.

    How it works (fast + robust):
      1) For rows that have either a DOI or an is_version_of list, build a graph where:
         - each row is a node
         - edges exist when two rows share any DOI in their version-set (self DOI + is_version_of DOIs)
      2) Compute connected components via Union-Find (near O(N)).
      3) For each component (size>=2), choose ONE parent (oldest/newest by date, tie-break by record_id numeric).
      4) Update:
         - hierarchy_col: "parent" for parent, "parent - duplicate (version-link)" for others
         - parent_id_col: parent record_id for duplicates
         - group_id_col: stable id "version::<root_record_id>" (can be merged later with other stages)

    Safe overwrite:
      - overwrite_mode controls WHICH rows get updated (eligible), but parents are chosen using all rows in component.

    Returns:
      (df, metrics)
    """

    t0 = time.perf_counter()
    metrics: Dict[str, Any] = {
        "n_rows_df": int(len(df)),
        "n_rows_with_any_version_signal": 0,
        "n_rows_considered_in_graph": 0,
        "n_edges_unions_attempted": 0,
        "n_unions_done": 0,
        "n_components_total": 0,
        "n_components_size_ge_2": 0,
        "n_rows_in_components_size_ge_2": 0,
        "n_rows_eligible_to_update": 0,
        "n_rows_updated": 0,
        "n_parents_set": 0,
        "n_children_set": 0,
        "runtime_s": 0.0,
    }

    # -----------------------------
    # Basic column checks / setup
    # -----------------------------
    for c in (hierarchy_col, parent_id_col, group_id_col):
        if c not in df.columns:
            df[c] = pd.NA

    if record_id_col not in df.columns:
        raise ValueError(f"Missing required column: {record_id_col}")
    if doi_col not in df.columns:
        raise ValueError(f"Missing required column: {doi_col}")
    if is_version_of_col not in df.columns:
        raise ValueError(f"Missing required column: {is_version_of_col}")

    if choose_parent not in {"oldest", "newest"}:
        raise ValueError("choose_parent must be 'oldest' or 'newest'")
    if overwrite_mode not in {"unlabeled_only", "parent_only", "any"}:
        raise ValueError("overwrite_mode must be 'unlabeled_only' | 'parent_only' | 'any'")

    # eligibility mask (safe overwrite)
    h = df[hierarchy_col]
    if overwrite_mode == "any":
        eligible_mask = pd.Series(True, index=df.index)
    elif overwrite_mode == "unlabeled_only":
        eligible_mask = h.isna()
    else:  # parent_only
        eligible_mask = h.astype("string").str.strip().str.lower().eq("parent")

    metrics["n_rows_eligible_to_update"] = int(eligible_mask.sum())

    # ------------------------------------------------------------
    # Build the subset to include in the VERSION graph
    # (We include rows that have DOI OR is_version_of list,
    #  because some rows might have missing doi but have version list.)
    # ------------------------------------------------------------
    doi_s = df[doi_col].astype("string").fillna("").str.strip()
    v_s = df[is_version_of_col].astype("string").fillna("").str.strip()

    has_signal = (doi_s != "") | (v_s != "")
    metrics["n_rows_with_any_version_signal"] = int(has_signal.sum())

    idx = df.index[has_signal].to_numpy()
    if idx.size == 0:
        metrics["runtime_s"] = time.perf_counter() - t0
        return df, metrics

    # Compact indexing for Union-Find arrays
    # local_i: 0..k-1 corresponds to df index idx[local_i]
    k = idx.size
    metrics["n_rows_considered_in_graph"] = int(k)

    # For parent selection: precompute helpers on this subset
    rid = df.loc[idx, record_id_col].astype("string").fillna("")
    # numeric fallback from record_id: extract digits
    rid_num = pd.to_numeric(rid.str.extract(r"(\d+)")[0], errors="coerce")

    if date_col and date_col in df.columns:
        dt = pd.to_datetime(df.loc[idx, date_col], errors="coerce")
    else:
        dt = pd.Series(pd.NaT, index=idx)

    # union-find structure
    uf = _UnionFind(k)

    # ------------------------------------------------------------
    # Union phase: stream through rows and connect by shared DOIs
    # Using a dict: doi -> first_local_index_seen
    # ------------------------------------------------------------
    doi_to_rep: Dict[str, int] = {}

    def _iter_version_set(self_doi: str, is_version_of_str: str):
        """
        Yield DOIs in (self DOI + is_version_of list).
        Designed to be cheap: split ';' only.
        """
        if self_doi:
            yield self_doi
        if is_version_of_str:
            # common case: "doi1;doi2;doi3"
            for part in is_version_of_str.split(";"):
                d = part.strip()
                if d:
                    yield d

    # Process in chunks for cache friendliness (still single pass)
    unions_attempted = 0
    unions_done = 0

    # Pre-pull arrays for speed
    doi_arr = doi_s.loc[idx].to_numpy(dtype=object)
    v_arr = v_s.loc[idx].to_numpy(dtype=object)

    for start in range(0, k, chunk_size):
        end = min(k, start + chunk_size)
        for local_i in range(start, end):
            sd = doi_arr[local_i]
            sv = v_arr[local_i]
            # build edges for this row: union with representative of each doi token
            first_rep = None
            for d in _iter_version_set(sd, sv):
                rep = doi_to_rep.get(d)
                if rep is None:
                    doi_to_rep[d] = local_i
                    if first_rep is None:
                        first_rep = local_i
                else:
                    unions_attempted += 1
                    if uf.union(local_i, rep):
                        unions_done += 1

    metrics["n_edges_unions_attempted"] = int(unions_attempted)
    metrics["n_unions_done"] = int(unions_done)

    # ------------------------------------------------------------
    # Build components: root -> list of local indices
    # ------------------------------------------------------------
    roots = np.empty(k, dtype=np.int32)
    for i in range(k):
        roots[i] = uf.find(i)

    # group by root using pandas (fast enough); avoid Python dict of lists for k large
    comp_df = pd.DataFrame({"root": roots, "local_i": np.arange(k, dtype=np.int32)})
    comp_sizes = comp_df["root"].value_counts()
    metrics["n_components_total"] = int(comp_sizes.shape[0])

    big_roots = comp_sizes[comp_sizes >= min_component_size].index.to_numpy(dtype=np.int32)
    metrics["n_components_size_ge_2"] = int(big_roots.size)
    if big_roots.size == 0:
        metrics["runtime_s"] = time.perf_counter() - t0
        return df, metrics

    # Filter to only components we will act on
    comp_big = comp_df[comp_df["root"].isin(big_roots)].copy()
    metrics["n_rows_in_components_size_ge_2"] = int(len(comp_big))

    # ------------------------------------------------------------
    # Parent selection per component
    # Parent = oldest/newest dt, tie-break by record_id numeric (rid_num)
    # ------------------------------------------------------------
    # Map local_i -> df index
    df_index_for_local = idx  # numpy array length k

    # Create selection frame with sortable keys
    # Note: dt index is df idx; align via local index mapping
    sel_idx = df_index_for_local[comp_big["local_i"].to_numpy()]
    sel = pd.DataFrame({
        "root": comp_big["root"].to_numpy(),
        "df_idx": sel_idx,
        "record_id": df.loc[sel_idx, record_id_col].astype("string").to_numpy(),
        "dt": dt.loc[sel_idx].to_numpy(),
        "rid_num": rid_num.loc[sel_idx].to_numpy(),
    })

    # Sort for parent picking
    asc_dt = True if choose_parent == "oldest" else False
    asc_rn = True if choose_parent == "oldest" else False

    # When dt is NaT, push to end for "oldest" and to start for "newest"
    # pandas sort_values uses na_position; we’ll handle by two sorts:
    na_pos = "last" if choose_parent == "oldest" else "first"

    sel_sorted = sel.sort_values(
        by=["root", "dt", "rid_num"],
        ascending=[True, asc_dt, asc_rn],
        na_position=na_pos,
        kind="mergesort",  # stable
    )

    # parent per root = first row per root
    parents = sel_sorted.groupby("root", sort=False).head(1)[["root", "df_idx", "record_id"]].rename(
        columns={"df_idx": "parent_df_idx", "record_id": "parent_record_id"}
    )

    parent_map_idx = parents.set_index("root")["parent_df_idx"]
    parent_map_rid = parents.set_index("root")["parent_record_id"]

    # ------------------------------------------------------------
    # Apply updates safely (only eligible rows)
    # ------------------------------------------------------------
    # Create per-row root for ALL rows in big components (same as sel_idx rows)
    sel["parent_df_idx"] = sel["root"].map(parent_map_idx).to_numpy()
    sel["parent_record_id"] = sel["root"].map(parent_map_rid).to_numpy()

    # Determine which df rows in these components are eligible to update
    sel["eligible"] = eligible_mask.loc[sel["df_idx"]].to_numpy()

    # Update parents/children among eligible rows only
    is_parent_row = sel["df_idx"].to_numpy() == sel["parent_df_idx"].to_numpy()
    eligible_parent = sel["eligible"].to_numpy() & is_parent_row
    eligible_child = sel["eligible"].to_numpy() & (~is_parent_row)

    parent_idxs = sel.loc[eligible_parent, "df_idx"].to_numpy()
    child_idxs  = sel.loc[eligible_child, "df_idx"].to_numpy()

    # Group id strategy:
    # - stable and readable: "version::<parent_record_id>"
    # This is perfect for later merging with other stages.
    #gid = "version::" + sel["parent_record_id"].astype("string")
    gid = sel["parent_record_id"].astype("string")

    # Apply
    if parent_idxs.size:
        df.loc[parent_idxs, hierarchy_col] = "parent"
        df.loc[parent_idxs, parent_id_col] = pd.NA
        df.loc[parent_idxs, group_id_col] = gid.loc[sel["df_idx"].isin(parent_idxs)].to_numpy()
    if child_idxs.size:
        df.loc[child_idxs, hierarchy_col] = f"parent - duplicate ({label_duplicate_suffix})"
        df.loc[child_idxs, parent_id_col] = sel.loc[sel["df_idx"].isin(child_idxs), "parent_record_id"].to_numpy()
        df.loc[child_idxs, group_id_col] = gid.loc[sel["df_idx"].isin(child_idxs)].to_numpy()

    metrics["n_rows_updated"] = int(parent_idxs.size + child_idxs.size)
    metrics["n_parents_set"] = int(parent_idxs.size)
    metrics["n_children_set"] = int(child_idxs.size)

    metrics["runtime_s"] = time.perf_counter() - t0
    return df, metrics


# ------------------------------------------------------------
# Example usage
# ------------------------------------------------------------
# df2, m = unify_groups_by_version_links(
#     data_out,
#     overwrite_mode="unlabeled_only",   # safest: only fill missing
#     choose_parent="oldest",
#     date_col="date_first_seen",
#     chunk_size=300_000,
# )
# print(m)

# %%
data_out, metric = unify_groups_by_version_links(
    data_clean,
    overwrite_mode="any",   
    choose_parent="oldest",
    date_col="date_first_seen",
    chunk_size=300_000,
)
print(metric)
# Out:
# {'n_rows_df': 8087418, 'n_rows_with_any_version_signal': 6463434, 'n_rows_considered_in_graph': 6463434, 'n_edges_unions_attempted': 178733, 'n_unions_done': 83497, 'n_components_total': 6379937, 'n_components_size_ge_2': 58024, 'n_rows_in_components_size_ge_2': 141521, 'n_rows_eligible_to_update': 8087418, 'n_rows_updated': 141521, 'n_parents_set': 58024, 'n_children_set': 83497, 'runtime_s': 14.397252369999478}

# %%
data_out, metric = unify_groups_by_version_links(
    data_clean,
    overwrite_mode="any",   
    choose_parent="oldest",
    date_col="date_first_seen",
    chunk_size=300_000,
)
print(metric)
# Out:
# {'n_rows_df': 8087418, 'n_rows_with_any_version_signal': 6463434, 'n_rows_considered_in_graph': 6463434, 'n_edges_unions_attempted': 178733, 'n_unions_done': 83497, 'n_components_total': 6379937, 'n_components_size_ge_2': 58024, 'n_rows_in_components_size_ge_2': 141521, 'n_rows_eligible_to_update': 8087418, 'n_rows_updated': 141521, 'n_parents_set': 58024, 'n_children_set': 83497, 'runtime_s': 14.279389653998805}

# %%
from pathlib import Path
import json
import pandas as pd

OUT_DIR = Path("outputs_new")
OUT_DIR.mkdir(parents=True, exist_ok=True)

# Save metrics
with open(OUT_DIR / "dedupe_metrics_version_links.json", "w") as f:
    json.dump(metric, f, indent=2)

#pd.DataFrame(metric).to_csv(OUT_DIR / "dedupe_metrics_version_links.csv", index=False)

# Save dataset
data_out.to_parquet(OUT_DIR / "dedupe_data_out_version_links.parquet", index=False)

print("✅ All files saved to outputs/")
# Out:
# ✅ All files saved to outputs/

# %%
data_out['records_hierarchy'].value_counts()
# Out:
# records_hierarchy
# parent                                            7460893
# parent - duplicate (SSRN)                          117992
# parent - duplicate (Zenodo)                         92335
# parent - duplicate (version-link)                   83497
# parent - duplicate (arXiv)                          54836
#                                                    ...
# parent - duplicate (WikiJournal of Humanities)          2
# parent - duplicate (Encyclopedia)                       1
# parent - duplicate (BioHackrXiv)                        1
# parent - duplicate (Therapoid)                          1
# parent - duplicate (searchRxiv)                         1
# Name: count, Length: 107, dtype: int64

# %%
data_out
# Out:
#                                record_id     server_name   backend  \
# 0        crossref::10.21467/preprints.48  AIJR Preprints  crossref
# 1        crossref::10.21467/preprints.43  AIJR Preprints  crossref
# 2        crossref::10.21467/preprints.39  AIJR Preprints  crossref
# 3        crossref::10.21467/preprints.38  AIJR Preprints  crossref
# 4        crossref::10.21467/preprints.36  AIJR Preprints  crossref
# ...                                  ...             ...       ...
# 8412647             openalex::W999325625           viXra  openalex
# 8412648             openalex::W999460032           viXra  openalex
# 8412649              openalex::W99967155           viXra  openalex
# 8412650             openalex::W999790414           viXra  openalex
# 8412651             openalex::W999805801           viXra  openalex
#
#                            doi                                doi_url  \
# 0        10.21467/preprints.48  https://doi.org/10.21467/preprints.48
# 1        10.21467/preprints.43  https://doi.org/10.21467/preprints.43
# 2        10.21467/preprints.39  https://doi.org/10.21467/preprints.39
# 3        10.21467/preprints.38  https://doi.org/10.21467/preprints.38
# 4        10.21467/preprints.36  https://doi.org/10.21467/preprints.36
# ...                        ...                                    ...
# 8412647                   None                                   None
# 8412648                   None                                   None
# 8412649                   None                                   None
# 8412650                   None                                   None
# 8412651                   None                                   None
#
#                                           landing_page_url  \
# 0        https://preprints.aijr.org/index.php/ap/prepri...
# 1        https://preprints.aijr.org/index.php/ap/prepri...
# 2        https://preprints.aijr.org/index.php/ap/prepri...
# 3        https://preprints.aijr.org/index.php/ap/prepri...
# 4        https://preprints.aijr.org/index.php/ap/prepri...
# ...                                                    ...
# 8412647              https://vixra.org/pdf/1409.0090v1.pdf
# 8412648                    https://vixra.org/abs/1112.0094
# 8412649              https://vixra.org/pdf/1406.0019v1.pdf
# 8412650              https://vixra.org/pdf/1306.0105v3.pdf
# 8412651              https://vixra.org/pdf/1412.0197v3.pdf
#
#                                                      title  \
# 0        Bird’s Eye View on the Diagnosis, Treatment, &...
# 1        Doxycycline and Minocycline Drugs as a Treatme...
# 2        A Genetic Perspective of 2019-nCoV in Relation...
# 3        Marine Algae as a Natural Source for Antiviral...
# 4        Possible Prevention of COVID 19 by Using Linol...
# ...                                                    ...
# 8412647                 Three Objections to Modern Physics
# 8412648                               Particle Mass Ratios
# 8412649  Quantum FFF Theory Proposals for Some Unsolved...
# 8412650  Investigation of the Formalism of Particle Dyn...
# 8412651  Electromagnetic Energy and Electromagnetic For...
#
#                                               authors_flat institutions_flat  \
# 0                              Panchalingala, Sai Bhargavi              None
# 1                                         Mostafa, Mohamed              None
# 2                                        Dasgupta, Rimjhim              None
# 3        Musale, Amar S; G., Raja Krishna Kumar; Sapre,...              None
# 4        Subhash, Venkata; G, Raja Krishna Kumar; Sapre...              None
# ...                                                    ...               ...
# 8412647                                      Lubomir Vlcek              None
# 8412648                                         DT Froedge              None
# 8412649                                           Leo Vuyk              None
# 8412650                                        Chi-Yi Chen              None
# 8412651                                    Yu.A. Spirichev              None
#
#         countries_flat relations_json version_label is_version_of  \
# 0                 None           None          None           NaN
# 1                 None           None          None           NaN
# 2                 None           None          None           NaN
# 3                 None           None          None           NaN
# 4                 None           None          None           NaN
# ...                ...            ...           ...           ...
# 8412647           None           None          None          None
# 8412648           None           None          None          None
# 8412649           None           None          None          None
# 8412650           None           None          None          None
# 8412651           None           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 0                                                              false
# 1                                                              false
# 2                                                              false
# 3                                                              false
# 4                                                              false
# ...                ...          ...        ...                   ...
# 8412647           None         None       None                  None
# 8412648           None         None       None                  None
# 8412649           None         None       None                  None
# 8412650           None         None       None                  None
# 8412651           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 0                             None                None           None
# 1                             None                None           None
# 2                             None                None           None
# 3                             None                None           None
# 4                             None                None           None
# ...                            ...                 ...            ...
# 8412647                       None                None           None
# 8412648                       None                None           None
# 8412649                       None                None           None
# 8412650                       None                None           None
# 8412651                       None                None           None
#
#         raw_relationships_json records_hierarchy date_first_seen  \
# 0                         None            parent      2020-05-03
# 1                         None            parent      2020-04-25
# 2                         None            parent      2020-04-16
# 3                         None            parent      2020-04-15
# 4                         None            parent      2020-04-15
# ...                        ...               ...             ...
# 8412647                   None            parent      2014-09-01
# 8412648                   None            parent      2011-12-01
# 8412649                   None            parent      2014-06-01
# 8412650                   None            parent      2013-06-01
# 8412651                   None            parent      2014-12-01
#
#          publication_year_first_seen records_hierarchy_backup  \
# 0                               2020                   parent
# 1                               2020                   parent
# 2                               2020                   parent
# 3                               2020                   parent
# 4                               2020                   parent
# ...                              ...                      ...
# 8412647                         2014                   parent
# 8412648                         2011                   parent
# 8412649                         2014                   parent
# 8412650                         2013                   parent
# 8412651                         2014                   parent
#
#         parent_record_id dup_group_id authors_fp_tokenbag  \
# 0                   None         None                None
# 1                   None         None     mohamed_mostafa
# 2                   None         None    dasgupta_rimjhim
# 3                   None         None                None
# 4                   None         None                None
# ...                  ...          ...                 ...
# 8412647             None         None       lubomir_vlcek
# 8412648             None         None          dt_froedge
# 8412649             None         None            leo_vuyk
# 8412650             None         None         chen_chi_yi
# 8412651             None         None      a_spirichev_yu
#
#                                             title_clean_v2  \
# 0                                                     None
# 1        doxycycline and minocycline drugs as a treatme...
# 2        a genetic perspective of 2019 ncov in relation...
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 8412647                 three objections to modern physics
# 8412648                               particle mass ratios
# 8412649  quantum fff theory proposals for some unsolved...
# 8412650  investigation of the formalism of particle dyn...
# 8412651  electromagnetic energy and electromagnetic for...
#
#         authors_fp_last_initial authors_fp_last  \
# 0                          None            None
# 1                     mostafa|m            None
# 2                    dasgupta|r            None
# 3                          None            None
# 4                          None            None
# ...                         ...             ...
# 8412647                 vlcek|l            None
# 8412648               froedge|d            None
# 8412649                  vuyk|l            None
# 8412650                  chen|c            None
# 8412651             spirichev|y            None
#
#         records_hierarchy_dedupe_backup parent_record_id_dedupe_backup  \
# 0                                parent                           None
# 1                                parent                           None
# 2                                parent                           None
# 3                                parent                           None
# 4                                parent                           None
# ...                                 ...                            ...
# 8412647                          parent                           None
# 8412648                          parent                           None
# 8412649                          parent                           None
# 8412650                          parent                           None
# 8412651                          parent                           None
#
#         dup_group_id_dedupe_backup
# 0                             None
# 1                             None
# 2                             None
# 3                             None
# 4                             None
# ...                            ...
# 8412647                       None
# 8412648                       None
# 8412649                       None
# 8412650                       None
# 8412651                       None
#
# [8087418 rows x 34 columns]

# %%
# to check records_hierarchy

# %%
pattern = "10.26434/chemrxiv.13102877"


mask = data_out['doi'].str.contains(pattern, regex=False, na=False)
result = data_out[mask]
print(len(result))
result
# Out:
# 32
#                                        record_id server_name   backend  \
# 281631   crossref::10.26434/chemrxiv.13102877.v1    ChemRxiv  crossref
# 281661   crossref::10.26434/chemrxiv.13102877.v2    ChemRxiv  crossref
# 281688   crossref::10.26434/chemrxiv.13102877.v3    ChemRxiv  crossref
# 281719   crossref::10.26434/chemrxiv.13102877.v4    ChemRxiv  crossref
# 281759   crossref::10.26434/chemrxiv.13102877.v5    ChemRxiv  crossref
# 281789   crossref::10.26434/chemrxiv.13102877.v6    ChemRxiv  crossref
# 281844   crossref::10.26434/chemrxiv.13102877.v7    ChemRxiv  crossref
# 281894   crossref::10.26434/chemrxiv.13102877.v8    ChemRxiv  crossref
# 281936   crossref::10.26434/chemrxiv.13102877.v9    ChemRxiv  crossref
# 281984  crossref::10.26434/chemrxiv.13102877.v10    ChemRxiv  crossref
# 282033  crossref::10.26434/chemrxiv.13102877.v11    ChemRxiv  crossref
# 282079  crossref::10.26434/chemrxiv.13102877.v12    ChemRxiv  crossref
# 282120  crossref::10.26434/chemrxiv.13102877.v13    ChemRxiv  crossref
# 282170  crossref::10.26434/chemrxiv.13102877.v14    ChemRxiv  crossref
# 282229  crossref::10.26434/chemrxiv.13102877.v15    ChemRxiv  crossref
# 282246  crossref::10.26434/chemrxiv.13102877.v16    ChemRxiv  crossref
# 282255  crossref::10.26434/chemrxiv.13102877.v17    ChemRxiv  crossref
# 282258  crossref::10.26434/chemrxiv.13102877.v19    ChemRxiv  crossref
# 282259  crossref::10.26434/chemrxiv.13102877.v20    ChemRxiv  crossref
# 282260  crossref::10.26434/chemrxiv.13102877.v18    ChemRxiv  crossref
# 282264  crossref::10.26434/chemrxiv.13102877.v21    ChemRxiv  crossref
# 282266  crossref::10.26434/chemrxiv.13102877.v22    ChemRxiv  crossref
# 282267  crossref::10.26434/chemrxiv.13102877.v23    ChemRxiv  crossref
# 282272  crossref::10.26434/chemrxiv.13102877.v24    ChemRxiv  crossref
# 282273  crossref::10.26434/chemrxiv.13102877.v25    ChemRxiv  crossref
# 282275  crossref::10.26434/chemrxiv.13102877.v26    ChemRxiv  crossref
# 282276  crossref::10.26434/chemrxiv.13102877.v27    ChemRxiv  crossref
# 282277  crossref::10.26434/chemrxiv.13102877.v28    ChemRxiv  crossref
# 282278  crossref::10.26434/chemrxiv.13102877.v29    ChemRxiv  crossref
# 282279  crossref::10.26434/chemrxiv.13102877.v30    ChemRxiv  crossref
# 282282  crossref::10.26434/chemrxiv.13102877.v31    ChemRxiv  crossref
# 282285  crossref::10.26434/chemrxiv.13102877.v32    ChemRxiv  crossref
#
#                                    doi  \
# 281631   10.26434/chemrxiv.13102877.v1
# 281661   10.26434/chemrxiv.13102877.v2
# 281688   10.26434/chemrxiv.13102877.v3
# 281719   10.26434/chemrxiv.13102877.v4
# 281759   10.26434/chemrxiv.13102877.v5
# 281789   10.26434/chemrxiv.13102877.v6
# 281844   10.26434/chemrxiv.13102877.v7
# 281894   10.26434/chemrxiv.13102877.v8
# 281936   10.26434/chemrxiv.13102877.v9
# 281984  10.26434/chemrxiv.13102877.v10
# 282033  10.26434/chemrxiv.13102877.v11
# 282079  10.26434/chemrxiv.13102877.v12
# 282120  10.26434/chemrxiv.13102877.v13
# 282170  10.26434/chemrxiv.13102877.v14
# 282229  10.26434/chemrxiv.13102877.v15
# 282246  10.26434/chemrxiv.13102877.v16
# 282255  10.26434/chemrxiv.13102877.v17
# 282258  10.26434/chemrxiv.13102877.v19
# 282259  10.26434/chemrxiv.13102877.v20
# 282260  10.26434/chemrxiv.13102877.v18
# 282264  10.26434/chemrxiv.13102877.v21
# 282266  10.26434/chemrxiv.13102877.v22
# 282267  10.26434/chemrxiv.13102877.v23
# 282272  10.26434/chemrxiv.13102877.v24
# 282273  10.26434/chemrxiv.13102877.v25
# 282275  10.26434/chemrxiv.13102877.v26
# 282276  10.26434/chemrxiv.13102877.v27
# 282277  10.26434/chemrxiv.13102877.v28
# 282278  10.26434/chemrxiv.13102877.v29
# 282279  10.26434/chemrxiv.13102877.v30
# 282282  10.26434/chemrxiv.13102877.v31
# 282285  10.26434/chemrxiv.13102877.v32
#
#                                                doi_url  \
# 281631   https://doi.org/10.26434/chemrxiv.13102877.v1
# 281661   https://doi.org/10.26434/chemrxiv.13102877.v2
# 281688   https://doi.org/10.26434/chemrxiv.13102877.v3
# 281719   https://doi.org/10.26434/chemrxiv.13102877.v4
# 281759   https://doi.org/10.26434/chemrxiv.13102877.v5
# 281789   https://doi.org/10.26434/chemrxiv.13102877.v6
# 281844   https://doi.org/10.26434/chemrxiv.13102877.v7
# 281894   https://doi.org/10.26434/chemrxiv.13102877.v8
# 281936   https://doi.org/10.26434/chemrxiv.13102877.v9
# 281984  https://doi.org/10.26434/chemrxiv.13102877.v10
# 282033  https://doi.org/10.26434/chemrxiv.13102877.v11
# 282079  https://doi.org/10.26434/chemrxiv.13102877.v12
# 282120  https://doi.org/10.26434/chemrxiv.13102877.v13
# 282170  https://doi.org/10.26434/chemrxiv.13102877.v14
# 282229  https://doi.org/10.26434/chemrxiv.13102877.v15
# 282246  https://doi.org/10.26434/chemrxiv.13102877.v16
# 282255  https://doi.org/10.26434/chemrxiv.13102877.v17
# 282258  https://doi.org/10.26434/chemrxiv.13102877.v19
# 282259  https://doi.org/10.26434/chemrxiv.13102877.v20
# 282260  https://doi.org/10.26434/chemrxiv.13102877.v18
# 282264  https://doi.org/10.26434/chemrxiv.13102877.v21
# 282266  https://doi.org/10.26434/chemrxiv.13102877.v22
# 282267  https://doi.org/10.26434/chemrxiv.13102877.v23
# 282272  https://doi.org/10.26434/chemrxiv.13102877.v24
# 282273  https://doi.org/10.26434/chemrxiv.13102877.v25
# 282275  https://doi.org/10.26434/chemrxiv.13102877.v26
# 282276  https://doi.org/10.26434/chemrxiv.13102877.v27
# 282277  https://doi.org/10.26434/chemrxiv.13102877.v28
# 282278  https://doi.org/10.26434/chemrxiv.13102877.v29
# 282279  https://doi.org/10.26434/chemrxiv.13102877.v30
# 282282  https://doi.org/10.26434/chemrxiv.13102877.v31
# 282285  https://doi.org/10.26434/chemrxiv.13102877.v32
#
#                                          landing_page_url  \
# 281631  https://chemrxiv.org/engage/chemrxiv/article-d...
# 281661  https://chemrxiv.org/engage/chemrxiv/article-d...
# 281688  https://chemrxiv.org/engage/chemrxiv/article-d...
# 281719  https://chemrxiv.org/engage/chemrxiv/article-d...
# 281759  https://chemrxiv.org/engage/chemrxiv/article-d...
# 281789  https://chemrxiv.org/engage/chemrxiv/article-d...
# 281844  https://chemrxiv.org/engage/chemrxiv/article-d...
# 281894  https://chemrxiv.org/engage/chemrxiv/article-d...
# 281936  https://chemrxiv.org/engage/chemrxiv/article-d...
# 281984  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282033  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282079  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282120  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282170  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282229  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282246  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282255  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282258  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282259  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282260  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282264  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282266  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282267  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282272  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282273  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282275  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282276  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282277  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282278  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282279  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282282  https://chemrxiv.org/engage/chemrxiv/article-d...
# 282285  https://chemrxiv.org/engage/chemrxiv/article-d...
#
#                                                     title    authors_flat  \
# 281631  Aptamers for Detection and Diagnostics (ADD): ...  Datta, Shoumen
# 281661  Aptamers for Detection and Diagnostics (ADD): ...  Datta, Shoumen
# 281688  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 281719  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 281759  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 281789  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 281844  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 281894  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 281936  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 281984  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282033  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282079  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282120  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282170  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282229  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282246  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282255  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282258  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282259  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282260  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282264  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282266  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282267  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282272  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282273  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282275  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282276  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282277  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282278  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282279  Aptamers for Detection and Diagnostics (ADD) i...  Datta, Shoumen
# 282282  Aptamers for Detection and Diagnostics (ADD): ...  Datta, Shoumen
# 282285  Aptamers for Detection and Diagnostics (ADD): ...  Datta, Shoumen
#
#        institutions_flat countries_flat  \
# 281631               MIT           None
# 281661               MIT           None
# 281688               MIT           None
# 281719               MIT           None
# 281759               MIT           None
# 281789               MIT           None
# 281844               MIT           None
# 281894               MIT           None
# 281936               MIT           None
# 281984               MIT           None
# 282033               MIT           None
# 282079               MIT           None
# 282120               MIT           None
# 282170               MIT           None
# 282229               MIT           None
# 282246               MIT           None
# 282255               MIT           None
# 282258               MIT           None
# 282259               MIT           None
# 282260               MIT           None
# 282264               MIT           None
# 282266               MIT           None
# 282267               MIT           None
# 282272               MIT           None
# 282273               MIT           None
# 282275               MIT           None
# 282276               MIT           None
# 282277               MIT           None
# 282278               MIT           None
# 282279               MIT           None
# 282282               MIT           None
# 282285               MIT           None
#
#                                            relations_json version_label  \
# 281631  {"is-version-of": [{"asserted-by": "subject", ...          None
# 281661  {"is-version-of": [{"asserted-by": "subject", ...          None
# 281688  {"is-version-of": [{"asserted-by": "subject", ...          None
# 281719  {"is-version-of": [{"asserted-by": "subject", ...          None
# 281759  {"is-version-of": [{"asserted-by": "subject", ...          None
# 281789  {"is-version-of": [{"asserted-by": "subject", ...          None
# 281844  {"is-version-of": [{"asserted-by": "subject", ...          None
# 281894  {"is-version-of": [{"asserted-by": "subject", ...          None
# 281936  {"is-version-of": [{"asserted-by": "subject", ...          None
# 281984  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282033  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282079  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282120  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282170  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282229  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282246  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282255  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282258  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282259  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282260  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282264  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282266  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282267  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282272  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282273  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282275  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282276  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282277  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282278  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282279  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282282  {"is-version-of": [{"asserted-by": "subject", ...          None
# 282285  {"is-version-of": [{"asserted-by": "subject", ...          None
#
#                                             is_version_of is_preprint_of  \
# 281631  10.26434/chemrxiv.13102877.v2;10.26434/chemrxi...
# 281661  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 281688  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 281719  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 281759  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 281789  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 281844  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 281894  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 281936  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 281984  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282033  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282079  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282120  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282170  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282229  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282246  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282255  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282258  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282259  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282260  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282264  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282266  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282267  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282272  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282273  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282275  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282276  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282277  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282278  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282279  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282282  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
# 282285  10.26434/chemrxiv.13102877.v1;10.26434/chemrxi...
#
#        has_preprint has_review has_published_version  \
# 281631                                         false
# 281661                                         false
# 281688                                         false
# 281719                                         false
# 281759                                         false
# 281789                                         false
# 281844                                         false
# 281894                                         false
# 281936                                         false
# 281984                                         false
# 282033                                         false
# 282079                                         false
# 282120                                         false
# 282170                                         false
# 282229                                         false
# 282246                                         false
# 282255                                         false
# 282258                                         false
# 282259                                         false
# 282260                                         false
# 282264                                         false
# 282266                                         false
# 282267                                         false
# 282272                                         false
# 282273                                         false
# 282275                                         false
# 282276                                         false
# 282277                                         false
# 282278                                         false
# 282279                                         false
# 282282                                         false
# 282285                                         false
#
#        published_version_ids_json version_of_ids_json update_to_json  \
# 281631                       None                None           None
# 281661                       None                None           None
# 281688                       None                None           None
# 281719                       None                None           None
# 281759                       None                None           None
# 281789                       None                None           None
# 281844                       None                None           None
# 281894                       None                None           None
# 281936                       None                None           None
# 281984                       None                None           None
# 282033                       None                None           None
# 282079                       None                None           None
# 282120                       None                None           None
# 282170                       None                None           None
# 282229                       None                None           None
# 282246                       None                None           None
# 282255                       None                None           None
# 282258                       None                None           None
# 282259                       None                None           None
# 282260                       None                None           None
# 282264                       None                None           None
# 282266                       None                None           None
# 282267                       None                None           None
# 282272                       None                None           None
# 282273                       None                None           None
# 282275                       None                None           None
# 282276                       None                None           None
# 282277                       None                None           None
# 282278                       None                None           None
# 282279                       None                None           None
# 282282                       None                None           None
# 282285                       None                None           None
#
#        raw_relationships_json                  records_hierarchy  \
# 281631                   None                             parent
# 281661                   None  parent - duplicate (version-link)
# 281688                   None  parent - duplicate (version-link)
# 281719                   None  parent - duplicate (version-link)
# 281759                   None  parent - duplicate (version-link)
# 281789                   None  parent - duplicate (version-link)
# 281844                   None  parent - duplicate (version-link)
# 281894                   None  parent - duplicate (version-link)
# 281936                   None  parent - duplicate (version-link)
# 281984                   None  parent - duplicate (version-link)
# 282033                   None  parent - duplicate (version-link)
# 282079                   None  parent - duplicate (version-link)
# 282120                   None  parent - duplicate (version-link)
# 282170                   None  parent - duplicate (version-link)
# 282229                   None  parent - duplicate (version-link)
# 282246                   None  parent - duplicate (version-link)
# 282255                   None  parent - duplicate (version-link)
# 282258                   None  parent - duplicate (version-link)
# 282259                   None  parent - duplicate (version-link)
# 282260                   None  parent - duplicate (version-link)
# 282264                   None  parent - duplicate (version-link)
# 282266                   None  parent - duplicate (version-link)
# 282267                   None  parent - duplicate (version-link)
# 282272                   None  parent - duplicate (version-link)
# 282273                   None  parent - duplicate (version-link)
# 282275                   None  parent - duplicate (version-link)
# 282276                   None  parent - duplicate (version-link)
# 282277                   None  parent - duplicate (version-link)
# 282278                   None  parent - duplicate (version-link)
# 282279                   None  parent - duplicate (version-link)
# 282282                   None  parent - duplicate (version-link)
# 282285                   None  parent - duplicate (version-link)
#
#        date_first_seen  publication_year_first_seen records_hierarchy_backup  \
# 281631      2020-10-23                         2020                   parent
# 281661      2020-10-27                         2020                   parent
# 281688      2020-11-06                         2020                   parent
# 281719      2020-11-09                         2020                   parent
# 281759      2020-11-11                         2020                   parent
# 281789      2020-11-16                         2020                   parent
# 281844      2020-11-23                         2020                   parent
# 281894      2020-11-24                         2020                   parent
# 281936      2020-11-30                         2020                   parent
# 281984      2020-12-03                         2020                   parent
# 282033      2020-12-04                         2020                   parent
# 282079      2020-12-07                         2020                   parent
# 282120      2020-12-10                         2020                   parent
# 282170      2020-12-22                         2020                   parent
# 282229      2020-12-30                         2020                   parent
# 282246      2021-01-04                         2021                   parent
# 282255      2021-01-05                         2021                   parent
# 282258      2021-01-12                         2021                   parent
# 282259      2021-01-13                         2021                   parent
# 282260      2021-01-08                         2021                   parent
# 282264      2021-01-20                         2021                   parent
# 282266      2021-01-27                         2021                   parent
# 282267      2021-02-01                         2021                   parent
# 282272      2021-02-03                         2021                   parent
# 282273      2021-02-04                         2021                   parent
# 282275      2021-02-18                         2021                   parent
# 282276      2021-02-22                         2021                   parent
# 282277      2021-03-01                         2021                   parent
# 282278      2021-03-03                         2021                   parent
# 282279      2021-03-08                         2021                   parent
# 282282      2021-03-15                         2021                   parent
# 282285      2021-03-16                         2021                   parent
#
#                                parent_record_id  \
# 281631                                     <NA>
# 281661  crossref::10.26434/chemrxiv.13102877.v1
# 281688  crossref::10.26434/chemrxiv.13102877.v1
# 281719  crossref::10.26434/chemrxiv.13102877.v1
# 281759  crossref::10.26434/chemrxiv.13102877.v1
# 281789  crossref::10.26434/chemrxiv.13102877.v1
# 281844  crossref::10.26434/chemrxiv.13102877.v1
# 281894  crossref::10.26434/chemrxiv.13102877.v1
# 281936  crossref::10.26434/chemrxiv.13102877.v1
# 281984  crossref::10.26434/chemrxiv.13102877.v1
# 282033  crossref::10.26434/chemrxiv.13102877.v1
# 282079  crossref::10.26434/chemrxiv.13102877.v1
# 282120  crossref::10.26434/chemrxiv.13102877.v1
# 282170  crossref::10.26434/chemrxiv.13102877.v1
# 282229  crossref::10.26434/chemrxiv.13102877.v1
# 282246  crossref::10.26434/chemrxiv.13102877.v1
# 282255  crossref::10.26434/chemrxiv.13102877.v1
# 282258  crossref::10.26434/chemrxiv.13102877.v1
# 282259  crossref::10.26434/chemrxiv.13102877.v1
# 282260  crossref::10.26434/chemrxiv.13102877.v1
# 282264  crossref::10.26434/chemrxiv.13102877.v1
# 282266  crossref::10.26434/chemrxiv.13102877.v1
# 282267  crossref::10.26434/chemrxiv.13102877.v1
# 282272  crossref::10.26434/chemrxiv.13102877.v1
# 282273  crossref::10.26434/chemrxiv.13102877.v1
# 282275  crossref::10.26434/chemrxiv.13102877.v1
# 282276  crossref::10.26434/chemrxiv.13102877.v1
# 282277  crossref::10.26434/chemrxiv.13102877.v1
# 282278  crossref::10.26434/chemrxiv.13102877.v1
# 282279  crossref::10.26434/chemrxiv.13102877.v1
# 282282  crossref::10.26434/chemrxiv.13102877.v1
# 282285  crossref::10.26434/chemrxiv.13102877.v1
#
#                                    dup_group_id authors_fp_tokenbag  \
# 281631  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 281661  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 281688  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 281719  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 281759  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 281789  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 281844  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 281894  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 281936  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 281984  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282033  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282079  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282120  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282170  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282229  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282246  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282255  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282258  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282259  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282260  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282264  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282266  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282267  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282272  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282273  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282275  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282276  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282277  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282278  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282279  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282282  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
# 282285  crossref::10.26434/chemrxiv.13102877.v1       datta_shoumen
#
#                                            title_clean_v2  \
# 281631  aptamers for detection and diagnostics add pro...
# 281661  aptamers for detection and diagnostics add pro...
# 281688  aptamers for detection and diagnostics add is ...
# 281719  aptamers for detection and diagnostics add is ...
# 281759  aptamers for detection and diagnostics add is ...
# 281789  aptamers for detection and diagnostics add is ...
# 281844  aptamers for detection and diagnostics add is ...
# 281894  aptamers for detection and diagnostics add is ...
# 281936  aptamers for detection and diagnostics add is ...
# 281984  aptamers for detection and diagnostics add is ...
# 282033  aptamers for detection and diagnostics add is ...
# 282079  aptamers for detection and diagnostics add is ...
# 282120  aptamers for detection and diagnostics add is ...
# 282170  aptamers for detection and diagnostics add is ...
# 282229  aptamers for detection and diagnostics add is ...
# 282246  aptamers for detection and diagnostics add is ...
# 282255  aptamers for detection and diagnostics add is ...
# 282258  aptamers for detection and diagnostics add is ...
# 282259  aptamers for detection and diagnostics add is ...
# 282260  aptamers for detection and diagnostics add is ...
# 282264  aptamers for detection and diagnostics add is ...
# 282266  aptamers for detection and diagnostics add is ...
# 282267  aptamers for detection and diagnostics add is ...
# 282272  aptamers for detection and diagnostics add is ...
# 282273  aptamers for detection and diagnostics add is ...
# 282275  aptamers for detection and diagnostics add is ...
# 282276  aptamers for detection and diagnostics add is ...
# 282277  aptamers for detection and diagnostics add is ...
# 282278  aptamers for detection and diagnostics add is ...
# 282279  aptamers for detection and diagnostics add is ...
# 282282  aptamers for detection and diagnostics add can...
# 282285  aptamers for detection and diagnostics add can...
#
#        authors_fp_last_initial authors_fp_last  \
# 281631                 datta|s            None
# 281661                    None            None
# 281688                 datta|s            None
# 281719                    None            None
# 281759                    None            None
# 281789                    None            None
# 281844                    None            None
# 281894                    None            None
# 281936                    None            None
# 281984                    None            None
# 282033                    None            None
# 282079                    None            None
# 282120                    None            None
# 282170                    None            None
# 282229                    None            None
# 282246                    None            None
# 282255                    None            None
# 282258                    None            None
# 282259                    None            None
# 282260                    None            None
# 282264                    None            None
# 282266                    None            None
# 282267                    None            None
# 282272                    None            None
# 282273                    None            None
# 282275                    None            None
# 282276                    None            None
# 282277                    None            None
# 282278                    None            None
# 282279                    None            None
# 282282                 datta|s            None
# 282285                    None            None
#
#        records_hierarchy_dedupe_backup  \
# 281631                          parent
# 281661   parent - duplicate (ChemRxiv)
# 281688                          parent
# 281719   parent - duplicate (ChemRxiv)
# 281759   parent - duplicate (ChemRxiv)
# 281789   parent - duplicate (ChemRxiv)
# 281844   parent - duplicate (ChemRxiv)
# 281894   parent - duplicate (ChemRxiv)
# 281936   parent - duplicate (ChemRxiv)
# 281984   parent - duplicate (ChemRxiv)
# 282033   parent - duplicate (ChemRxiv)
# 282079   parent - duplicate (ChemRxiv)
# 282120   parent - duplicate (ChemRxiv)
# 282170   parent - duplicate (ChemRxiv)
# 282229   parent - duplicate (ChemRxiv)
# 282246   parent - duplicate (ChemRxiv)
# 282255   parent - duplicate (ChemRxiv)
# 282258   parent - duplicate (ChemRxiv)
# 282259   parent - duplicate (ChemRxiv)
# 282260   parent - duplicate (ChemRxiv)
# 282264   parent - duplicate (ChemRxiv)
# 282266   parent - duplicate (ChemRxiv)
# 282267   parent - duplicate (ChemRxiv)
# 282272   parent - duplicate (ChemRxiv)
# 282273   parent - duplicate (ChemRxiv)
# 282275   parent - duplicate (ChemRxiv)
# 282276   parent - duplicate (ChemRxiv)
# 282277   parent - duplicate (ChemRxiv)
# 282278   parent - duplicate (ChemRxiv)
# 282279   parent - duplicate (ChemRxiv)
# 282282                          parent
# 282285   parent - duplicate (ChemRxiv)
#
#                   parent_record_id_dedupe_backup dup_group_id_dedupe_backup
# 281631                                      None       16854196709595633026
# 281661   crossref::10.26434/chemrxiv.13102877.v1       16854196709595633026
# 281688                                      None       15378799223749550050
# 281719   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 281759   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 281789   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 281844   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 281894   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 281936   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 281984   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282033   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282079   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282120   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282170   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282229   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282246   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282255   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282258   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282259   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282260   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282264   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282266   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282267   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282272   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282273   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282275   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282276   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282277   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282278   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282279   crossref::10.26434/chemrxiv.13102877.v3       15378799223749550050
# 282282                                      None       15120014104423475792
# 282285  crossref::10.26434/chemrxiv.13102877.v31       15120014104423475792

# %%
result['dup_group_id'].value_counts()
# Out:
# dup_group_id
# crossref::10.26434/chemrxiv.13102877.v1    32
# Name: count, dtype: int64

# %%
result['parent_record_id'].value_counts()
# Out:
# parent_record_id
# crossref::10.26434/chemrxiv.13102877.v1    31
# Name: count, dtype: int64

# %%
result['records_hierarchy'].value_counts()
# Out:
# records_hierarchy
# parent - duplicate (version-link)    31
# parent                                1
# Name: count, dtype: int64
