# %%
import pandas as pd
# Set option to display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# # import data

# %%
data = pd.read_pickle("outputs_new/dedupe_data_group_merge.pkl")
data
# Out:
#                                    record_id  \
# 0        crossref::10.1002/essoar.10500000.1
# 1        crossref::10.1002/essoar.10500002.1
# 2        crossref::10.1002/essoar.10500004.1
# 3        crossref::10.1002/essoar.10500007.1
# 4        crossref::10.1002/essoar.10500009.1
# ...                                      ...
# 7905694                 openalex::W999921877
# 7905695                 openalex::W999947037
# 7905696                 openalex::W999974616
# 7905697                 openalex::W999989114
# 7905698                 openalex::W999989584
#
#                                   server_name   backend  \
# 0        Earth and Space Science Open Archive  crossref
# 1        Earth and Space Science Open Archive  crossref
# 2        Earth and Space Science Open Archive  crossref
# 3        Earth and Space Science Open Archive  crossref
# 4        Earth and Space Science Open Archive  crossref
# ...                                       ...       ...
# 7905694   RePEc: Research Papers in Economics  openalex
# 7905695                                   HAL  openalex
# 7905696   RePEc: Research Papers in Economics  openalex
# 7905697                                   HAL  openalex
# 7905698   RePEc: Research Papers in Economics  openalex
#
#                                doi                                    doi_url  \
# 0        10.1002/essoar.10500000.1  https://doi.org/10.1002/essoar.10500000.1
# 1        10.1002/essoar.10500002.1  https://doi.org/10.1002/essoar.10500002.1
# 2        10.1002/essoar.10500004.1  https://doi.org/10.1002/essoar.10500004.1
# 3        10.1002/essoar.10500007.1  https://doi.org/10.1002/essoar.10500007.1
# 4        10.1002/essoar.10500009.1  https://doi.org/10.1002/essoar.10500009.1
# ...                            ...                                        ...
# 7905694                       None                                       None
# 7905695                       None                                       None
# 7905696                       None                                       None
# 7905697                       None                                       None
# 7905698                       None                                       None
#
#                                           landing_page_url type_backend_raw  \
# 0        https://essopenarchive.org/doi/full/10.1002/es...   posted-content
# 1        https://essopenarchive.org/doi/full/10.1002/es...   posted-content
# 2        https://essopenarchive.org/doi/full/10.1002/es...   posted-content
# 3        https://essopenarchive.org/doi/full/10.1002/es...   posted-content
# 4        https://essopenarchive.org/doi/full/10.1002/es...   posted-content
# ...                                                    ...              ...
# 7905694  https://steconomice.uoradea.ro/anale/volume/20...         preprint
# 7905695                   https://hal.science/hal-01922484         preprint
# 7905696   https://EconPapers.repec.org/RePEc:cde:cdewps:19         preprint
# 7905697                   https://hal.science/hal-01268467         preprint
# 7905698  http://thred.devecon.org/papers/2014/2014-018_...         preprint
#
#         subtype_backend_raw  \
# 0                  preprint
# 1                  preprint
# 2                  preprint
# 3                  preprint
# 4                  preprint
# ...                     ...
# 7905694                None
# 7905695                None
# 7905696                None
# 7905697                None
# 7905698                None
#
#                                                      title  \
# 0        Long-term monitoring of land surface phenologi...
# 1        Impact of spatial scale for phenological indic...
# 2        Observations of Low Latitude Red Aurora in Mex...
# 3        Pipeline oil fire detection with MODIS active ...
# 4        Land Product Validation of MODIS Derived FPAR ...
# ...                                                    ...
# 7905694  IDE sous l'influence du degré de l'intégration...
# 7905695  Building realistic potential patients queries ...
# 7905696  Debt Financing with Limited Liability and Quan...
# 7905697  Sustainable orchards' redesign: at the crossro...
# 7905698  When warm glow burns: Motivational (mis)alloca...
#
#                                               authors_flat  \
# 0                                     Tsutsumida, Narumasa
# 1                        Tsutsumida, Narumasa; Kaduk, Jörg
# 2        Gonzalez-Esparza, J. Americo; Cuevas-Cardona, ...
# 3        Ogungbuyi, Michael Gbenga; Martinez, Peter; Ec...
# 4        Sharp, Iain; Sanchez-Azofeifa, Arturo; Musilek...
# ...                                                    ...
# 7905694                        Simona-Gabriela Serbu Masca
# 7905695  Lorraine Goeuriot; Wendy W. Chapman; Gareth Jf...
# 7905696                          Krishnendu Ghosh Dastidar
# 7905697  Servane Penvern; Sylvaine Simon; Stéphane Bell...
# 7905698  Gani Aldashev; Esteban Jaimovich; Thierry Verdier
#
#                                          institutions_flat  countries_flat  \
# 0                                                     None            None
# 1                                                     None            None
# 2               Universidad Autónoma del Estado de Hidalgo            None
# 3                                                     None            None
# 4                                                     None            None
# ...                                                    ...             ...
# 7905694                            Babeș-Bolyai University              RO
# 7905695  Laboratoire d'Informatique de Grenoble; Dublin...          FR; IE
# 7905696                                               None            None
# 7905697  Institut National de Recherche pour l'Agricult...              FR
# 7905698  University of Namur; University of Surrey; Éco...  BE; GB; BI; FR
#
#                                             relations_json version_label  \
# 0                                                     None          None
# 1                                                     None          None
# 2        {"is-preprint-of": [{"asserted-by": "subject",...          None
# 3                                                     None          None
# 4                                                     None          None
# ...                                                    ...           ...
# 7905694                                               None          None
# 7905695                                               None          None
# 7905696                                               None          None
# 7905697                                               None          None
# 7905698                                               None          None
#
#         is_version_of        is_preprint_of has_preprint has_review  \
# 0                None
# 1                None
# 2                None  10.1029/2018sw001995
# 3                None
# 4                None
# ...               ...                   ...          ...        ...
# 7905694          None                  None         None       None
# 7905695          None                  None         None       None
# 7905696          None                  None         None       None
# 7905697          None                  None         None       None
# 7905698          None                  None         None       None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 0                       false                       None                None
# 1                       false                       None                None
# 2                        true                       None                None
# 3                       false                       None                None
# 4                       false                       None                None
# ...                       ...                        ...                 ...
# 7905694                  None                       None                None
# 7905695                  None                       None                None
# 7905696                  None                       None                None
# 7905697                  None                       None                None
# 7905698                  None                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 0                 None                   None            parent
# 1                 None                   None            parent
# 2                 None                   None            parent
# 3                 None                   None            parent
# 4                 None                   None            parent
# ...                ...                    ...               ...
# 7905694           None                   None            parent
# 7905695           None                   None            parent
# 7905696           None                   None            parent
# 7905697           None                   None            parent
# 7905698           None                   None            parent
#
#         date_first_seen  publication_year  publication_year_first_seen  \
# 0            2018-05-24            2018.0                         2018
# 1            2018-05-27            2018.0                         2018
# 2            2018-05-28            2018.0                         2018
# 3            2018-05-30            2018.0                         2018
# 4            2018-06-05            2018.0                         2018
# ...                 ...               ...                          ...
# 7905694      2008-01-01            2008.0                         2008
# 7905695      2014-01-01            2014.0                         2014
# 7905696      1994-08-01            1994.0                         1994
# 7905697      2012-07-01            2012.0                         2012
# 7905698      2015-02-01            2015.0                         2015
#
#         raw_dates records_hierarchy_backup parent_record_id dup_group_id  \
# 0            None                   parent             None         None
# 1            None                   parent             None         None
# 2            None                   parent             None         None
# 3            None                   parent             None         None
# 4            None                   parent             None         None
# ...           ...                      ...              ...          ...
# 7905694      None                   parent             None         None
# 7905695      None                   parent             None         None
# 7905696      None                   parent             None         None
# 7905697      None                   parent             None         None
# 7905698      None                   parent             None         None
#
#                                      authors_fp_tokenbag  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 7905694                      gabriela_masca_serbu_simona
# 7905695                                             None
# 7905696                        dastidar_ghosh_krishnendu
# 7905697                                             None
# 7905698  aldashev_gani;esteban_jaimovich;thierry_verdier
#
#                                             title_clean_v2  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 7905694  ide sous l influence du degre de l integration...
# 7905695                                               None
# 7905696  debt financing with limited liability and quan...
# 7905697                                               None
# 7905698  when warm glow burns motivational mis allocati...
#
#                   authors_fp_last_initial authors_fp_last  \
# 0                                    None            None
# 1                                    None            None
# 2                                    None            None
# 3                                    None            None
# 4                                    None            None
# ...                                   ...             ...
# 7905694                           masca|s            None
# 7905695                              None            None
# 7905696                        dastidar|k            None
# 7905697                              None            None
# 7905698  aldashev|g;jaimovich|e;verdier|t            None
#
#         records_hierarchy_dedupe_backup parent_record_id_dedupe_backup  \
# 0                                parent                           None
# 1                                parent                           None
# 2                                parent                           None
# 3                                parent                           None
# 4                                parent                           None
# ...                                 ...                            ...
# 7905694                          parent                           None
# 7905695                          parent                           None
# 7905696                          parent                           None
# 7905697                          parent                           None
# 7905698                          parent                           None
#
#         dup_group_id_dedupe_backup has_version_dois  \
# 0                             None             None
# 1                             None             None
# 2                             None             None
# 3                             None             None
# 4                             None             None
# ...                            ...              ...
# 7905694                       None             None
# 7905695                       None             None
# 7905696                       None             None
# 7905697                       None             None
# 7905698                       None             None
#
#         records_hierarchy_unify_version_backup  \
# 0                                       parent
# 1                                       parent
# 2                                       parent
# 3                                       parent
# 4                                       parent
# ...                                        ...
# 7905694                                 parent
# 7905695                                 parent
# 7905696                                 parent
# 7905697                                 parent
# 7905698                                 parent
#
#         parent_record_id_unify_version_backup  \
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# ...                                       ...
# 7905694                                  None
# 7905695                                  None
# 7905696                                  None
# 7905697                                  None
# 7905698                                  None
#
#         dup_group_id_unify_version_backup
# 0                                    None
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# ...                                   ...
# 7905694                              None
# 7905695                              None
# 7905696                              None
# 7905697                              None
# 7905698                              None
#
# [7905699 rows x 42 columns]

# %%
data.published_version_ids_json.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
data.records_hierarchy.value_counts()
# Out:
# records_hierarchy
# parent                                                     7332492
# parent - duplicate (SSRN)                                   127847
# parent - duplicate (Zenodo)                                  98478
# parent - duplicate (Research Square)                         59677
# parent - duplicate (arXiv)                                   54767
#                                                             ...
# parent - duplicate (Sciencepaper Online)                         2
# parent - duplicate (CoP)                                         1
# parent - duplicate (Therapoid)                                   1
# parent - duplicate (Prepublicaciones OpenCiencia)                1
# parent - duplicate (Electron Colloquium Comput Complex)          1
# Name: count, Length: 105, dtype: int64

# %%
data.update_to_json.value_counts()
# Out:
# update_to_json
# [{"DOI": "10.12688/aasopenres.13349.1", "label": "New version", "source": "publisher", "type": "new_version", "updated": {"date-parts": [[2022, 6, 27]], "date-time": "2022-06-27T00:00:00Z", "timestamp": 1656288000000}}]                                                                                                                                                                                                                                     2
# [{"DOI": "10.12688/gatesopenres.13119.1", "label": "New version", "source": "publisher", "type": "new_version", "updated": {"date-parts": [[2020, 8, 20]], "date-time": "2020-08-20T00:00:00Z", "timestamp": 1597881600000}}]                                                                                                                                                                                                                                   1
# [{"DOI": "10.12688/gatesopenres.13123.1", "label": "New version", "source": "publisher", "type": "new_version", "updated": {"date-parts": [[2020, 11, 26]], "date-time": "2020-11-26T00:00:00Z", "timestamp": 1606348800000}}]                                                                                                                                                                                                                                  1
# [{"DOI": "10.12688/gatesopenres.13124.1", "label": "New version", "source": "publisher", "type": "new_version", "updated": {"date-parts": [[2020, 8, 20]], "date-time": "2020-08-20T00:00:00Z", "timestamp": 1597881600000}}]                                                                                                                                                                                                                                   1
# [{"DOI": "10.12688/gatesopenres.13129.1", "label": "New version", "source": "publisher", "type": "new_version", "updated": {"date-parts": [[2020, 11, 13]], "date-time": "2020-11-13T00:00:00Z", "timestamp": 1605225600000}}]                                                                                                                                                                                                                                  1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                ..
# [{"DOI": "10.12688/f1000research.15995.1", "label": "New version", "source": "publisher", "type": "new_version", "updated": {"date-parts": [[2019, 4, 3]], "date-time": "2019-04-03T00:00:00Z", "timestamp": 1554249600000}}]                                                                                                                                                                                                                                   1
# [{"DOI": "10.12688/f1000research.159954.1", "label": "New version", "source": "publisher", "type": "new_version", "updated": {"date-parts": [[2025, 5, 21]], "date-time": "2025-05-21T00:00:00Z", "timestamp": 1747785600000}}]                                                                                                                                                                                                                                 1
# [{"DOI": "10.12688/f1000research.159997.1", "label": "New version", "source": "publisher", "type": "new_version", "updated": {"date-parts": [[2025, 2, 20]], "date-time": "2025-02-20T00:00:00Z", "timestamp": 1740009600000}}]                                                                                                                                                                                                                                 1
# [{"DOI": "10.12688/f1000research.160010.1", "label": "New version", "source": "publisher", "type": "new_version", "updated": {"date-parts": [[2025, 3, 17]], "date-time": "2025-03-17T00:00:00Z", "timestamp": 1742169600000}}]                                                                                                                                                                                                                                 1
# [{"DOI": "10.12688/f1000research.159731.1", "label": "New version", "source": "publisher", "type": "new_version", "updated": {"date-parts": [[2025, 9, 8]], "date-time": "2025-09-08T00:00:00Z", "timestamp": 1757289600000}}, {"DOI": "10.12688/f1000research.159731.2", "label": "New version", "source": "publisher", "type": "new_version", "updated": {"date-parts": [[2025, 9, 8]], "date-time": "2025-09-08T00:00:00Z", "timestamp": 1757289600000}}]    1
# Name: count, Length: 8914, dtype: int64

# %% [markdown]
# # build parent_index and long_full file

# %%
import os
import json
import duckdb
import pandas as pd

def build_parent_index_and_long_full_duckdb(
    df: pd.DataFrame,
    *,
    out_dir: str = "outputs",
    record_id_col: str = "record_id",
    server_col: str = "server_name",
    doi_col: str = "doi",
    url_col: str = "landing_page_url",
    title_col: str = "title",
    authors_col: str = "authors_flat",
    date_col: str = "date_first_seen",
    year_col: str = "publication_year_first_seen",
    group_id_col: str = "dup_group_id",
    # outputs
    long_full_name: str = "dedupe_clusters_long_full.parquet",
    parent_index_name: str = "parent_version_index_full.parquet",
    metrics_name: str = "dedupe_full_metrics.json",
):
    """
    Rules:
      - singleton rows: parent = itself
      - clustered rows: parent = oldest in cluster (date_col ASC, tie record_id ASC)
      - group id for full universe: dup_group_id_full = COALESCE(dup_group_id, record_id)

    Outputs (in out_dir):
      - dedupe_clusters_long_full.parquet  (ALL rows, includes parent_record_id_selected, is_parent_selected, group_size)
      - parent_version_index_full.parquet  (ONE row per group, with parent info + members lists)
      - dedupe_full_metrics.json
    """
    os.makedirs(out_dir, exist_ok=True)
    con = duckdb.connect(database=":memory:")
    con.execute("PRAGMA threads=8;")          # tune if needed
    con.execute("PRAGMA memory_limit='16GB';")# tune if needed

    # Register dataframe
    con.register("df_in", df)

    # -------------
    # 0) Build a stable "full" group id (clusters + singletons)
    # -------------
    # Note: we compute parent per group using window functions.
    # Parent selection: MIN_BY(record_id, sort_key) doesn't exist in DuckDB,
    # but we can do FIRST_VALUE over an ordered window.
    con.execute(f"""
        CREATE OR REPLACE TEMP VIEW base AS
        SELECT
            *,
            COALESCE(CAST({group_id_col} AS VARCHAR), CAST({record_id_col} AS VARCHAR)) AS dup_group_id_full,
            TRY_CAST({date_col} AS TIMESTAMP) AS dt,
            TRY_CAST({record_id_col} AS BIGINT) AS rid_num,
            NULLIF(TRIM(CAST({doi_col} AS VARCHAR)), '') AS doi_clean,
            NULLIF(TRIM(CAST({server_col} AS VARCHAR)), '') AS server_clean
        FROM df_in
    """)

    # -------------
    # 1) Create long_full (ALL rows)
    #    parent_record_id_selected = oldest record_id within dup_group_id_full
    # -------------
    con.execute(f"""
        CREATE OR REPLACE TEMP VIEW long_full AS
        SELECT
            -- keep original columns
            b.*,

            -- selected parent per group
            FIRST_VALUE(CAST({record_id_col} AS VARCHAR)) OVER (
                PARTITION BY dup_group_id_full
                ORDER BY dt ASC NULLS LAST, CAST({record_id_col} AS VARCHAR) ASC
            ) AS parent_record_id_selected,

            -- parent metadata (from the chosen parent row)
            FIRST_VALUE(CAST({server_col} AS VARCHAR)) OVER (
                PARTITION BY dup_group_id_full
                ORDER BY dt ASC NULLS LAST, CAST({record_id_col} AS VARCHAR) ASC
            ) AS parent_server_name_selected,

            FIRST_VALUE(CAST({doi_col} AS VARCHAR)) OVER (
                PARTITION BY dup_group_id_full
                ORDER BY dt ASC NULLS LAST, CAST({record_id_col} AS VARCHAR) ASC
            ) AS parent_doi_selected,


            -- add ------------
            FIRST_VALUE(CAST({url_col} AS VARCHAR)) OVER (
                PARTITION BY dup_group_id_full
                ORDER BY dt ASC NULLS LAST, CAST({record_id_col} AS VARCHAR) ASC
            ) AS parent_url_selected,
            
            FIRST_VALUE(CAST({title_col} AS VARCHAR)) OVER (
                PARTITION BY dup_group_id_full
                ORDER BY dt ASC NULLS LAST, CAST({record_id_col} AS VARCHAR) ASC
            ) AS parent_title_selected,
            
            FIRST_VALUE(CAST({authors_col} AS VARCHAR)) OVER (
                PARTITION BY dup_group_id_full
                ORDER BY dt ASC NULLS LAST, CAST({record_id_col} AS VARCHAR) ASC
            ) AS parent_authors_selected,

            -- ---------
    

            FIRST_VALUE(dt) OVER (
                PARTITION BY dup_group_id_full
                ORDER BY dt ASC NULLS LAST, CAST({record_id_col} AS VARCHAR) ASC
            ) AS parent_date_selected,

            FIRST_VALUE(CAST({year_col} AS VARCHAR)) OVER (
                PARTITION BY dup_group_id_full
                ORDER BY dt ASC NULLS LAST, CAST({record_id_col} AS VARCHAR) ASC
            ) AS parent_year_selected,

            -- is this row the selected parent?
            CASE
              WHEN CAST({record_id_col} AS VARCHAR) =
                   FIRST_VALUE(CAST({record_id_col} AS VARCHAR)) OVER (
                      PARTITION BY dup_group_id_full
                      ORDER BY dt ASC NULLS LAST, CAST({record_id_col} AS VARCHAR) ASC
                   )
              THEN TRUE ELSE FALSE
            END AS is_parent_selected,

            COUNT(*) OVER (PARTITION BY dup_group_id_full) AS group_size
        FROM base b
    """)

    # Export full long table
    long_path = os.path.join(out_dir, long_full_name)
    con.execute(f"COPY long_full TO '{long_path}' (FORMAT 'parquet');")

    # -------------
    # 2) Build parent_version_index_full (ONE row per group)
    #    Includes lists (record_ids, dois, servers with counts), first/last version dates, etc.
    # -------------
    # a) servers with counts as "ServerA (12); ServerB (3)"
    con.execute(f"""
        CREATE OR REPLACE TEMP VIEW servers_counts AS
        SELECT
            dup_group_id_full,
            CAST({server_col} AS VARCHAR) AS server_name,
            COUNT(*) AS n
        FROM long_full
        GROUP BY 1, 2
    """)

    con.execute("""
        CREATE OR REPLACE TEMP VIEW servers_counts_str AS
        SELECT
            dup_group_id_full,
            STRING_AGG(server_name || ' (' || CAST(n AS VARCHAR) || ')', '; ' ORDER BY n DESC, server_name ASC) AS servers_with_counts
        FROM servers_counts
        GROUP BY 1
    """)

    # b) most recent version server(s): if multiple on same max date → join with ';'
    con.execute("""
        CREATE OR REPLACE TEMP VIEW max_dt AS
        SELECT dup_group_id_full, MAX(dt) AS max_dt
        FROM long_full
        GROUP BY 1
    """)

    con.execute(f"""
        CREATE OR REPLACE TEMP VIEW most_recent_servers AS
        SELECT
            l.dup_group_id_full,
            STRING_AGG(DISTINCT CAST(l.{server_col} AS VARCHAR), '; ' ORDER BY CAST(l.{server_col} AS VARCHAR))
              AS most_recent_server_names
        FROM long_full l
        JOIN max_dt m
          ON l.dup_group_id_full = m.dup_group_id_full
         AND l.dt = m.max_dt
        GROUP BY 1
    """)

    # c) parent index
    parent_path = os.path.join(out_dir, parent_index_name)
    con.execute(f"""
        COPY (
            SELECT
                l.dup_group_id_full,

                l.parent_record_id_selected AS parent_record_id,
                l.parent_server_name_selected AS parent_server_name,
                l.parent_doi_selected       AS parent_doi,
                l.parent_url_selected       AS parent_url,
                l.parent_title_selected     AS parent_title,
                l.parent_authors_selected   AS parent_authors,
                l.parent_date_selected      AS parent_date_first_seen,
                l.parent_year_selected      AS parent_year_first_seen,

                STRING_AGG(DISTINCT CAST(l.{record_id_col} AS VARCHAR), '; '
                           ORDER BY CAST(l.{record_id_col} AS VARCHAR)) AS version_record_ids,

                -- cleaned DOI list (sorted, skips null/empty)
                STRING_AGG(l.doi_clean, '; ' ORDER BY l.doi_clean)
                    FILTER (WHERE l.doi_clean IS NOT NULL) AS version_dois,

                s.servers_with_counts,

                MAX(l.group_size) AS total_versions,
                MIN(l.dt) AS first_version_date,
                MAX(l.dt) AS last_version_date,

                mr.most_recent_server_names AS most_recent_version_servers

            FROM long_full l
            LEFT JOIN servers_counts_str s USING(dup_group_id_full)
            LEFT JOIN most_recent_servers mr USING(dup_group_id_full)
            GROUP BY
                l.dup_group_id_full,
                l.parent_record_id_selected,
                l.parent_server_name_selected,
                l.parent_doi_selected,
                l.parent_url_selected,
                l.parent_title_selected,
                l.parent_authors_selected,
                l.parent_date_selected,
                l.parent_year_selected,
                s.servers_with_counts,
                mr.most_recent_server_names
        )
        TO '{parent_path}' (FORMAT 'parquet');
    """)


    # -------------
    # 3) Metrics
    # -------------
    total_rows = con.execute("SELECT COUNT(*) FROM base").fetchone()[0]
    clustered_rows = con.execute(f"SELECT COUNT(*) FROM base WHERE {group_id_col} IS NOT NULL").fetchone()[0]
    singleton_rows = total_rows - clustered_rows

    clusters = con.execute(f"SELECT COUNT(DISTINCT CAST({group_id_col} AS VARCHAR)) FROM base WHERE {group_id_col} IS NOT NULL").fetchone()[0]
    groups_full = con.execute("SELECT COUNT(DISTINCT dup_group_id_full) FROM base").fetchone()[0]

    # sanity checks
    long_rows = con.execute("SELECT COUNT(*) FROM long_full").fetchone()[0]
    parent_rows = con.execute("SELECT COUNT(DISTINCT dup_group_id_full) FROM long_full").fetchone()[0]

    metrics = {
        "total_rows": int(total_rows),
        "clustered_rows_has_dup_group_id": int(clustered_rows),
        "singleton_rows_no_dup_group_id": int(singleton_rows),
        "clusters_distinct_dup_group_id": int(clusters),
        "groups_full_clusters_plus_singletons": int(groups_full),
        "long_full_rows_written": int(long_rows),
        "parent_index_rows_written": int(parent_rows),
    }

    # write metrics json
    metrics_path = os.path.join(out_dir, metrics_name)
    with open(metrics_path, "w", encoding="utf-8") as f:
        json.dump(metrics, f, indent=2)

    return {
        "long_full_path": long_path,
        "parent_index_path": parent_path,
        "metrics_path": metrics_path,
        "metrics": metrics,
    }

# %%
result = build_parent_index_and_long_full_duckdb(
    df=data,          # or data_out after unify steps
    out_dir="outputs_new/parent",
    group_id_col="dup_group_id",  # or "dup_group_id_merged" if you renamed it
    date_col="date_first_seen",
)

result["metrics"]
# Out:
# {'total_rows': 7905699,
#  'clustered_rows_has_dup_group_id': 1036237,
#  'singleton_rows_no_dup_group_id': 6869462,
#  'clusters_distinct_dup_group_id': 463030,
#  'groups_full_clusters_plus_singletons': 7332492,
#  'long_full_rows_written': 7905699,
#  'parent_index_rows_written': 7332492}

# %%
result
# Out:
# {'long_full_path': 'outputs_new/parent/dedupe_clusters_long_full.parquet',
#  'parent_index_path': 'outputs_new/parent/parent_version_index_full.parquet',
#  'metrics_path': 'outputs_new/parent/dedupe_full_metrics.json',
#  'metrics': {'total_rows': 7905699,
#   'clustered_rows_has_dup_group_id': 1036237,
#   'singleton_rows_no_dup_group_id': 6869462,
#   'clusters_distinct_dup_group_id': 463030,
#   'groups_full_clusters_plus_singletons': 7332492,
#   'long_full_rows_written': 7905699,
#   'parent_index_rows_written': 7332492}}

# %%
import duckdb

con = duckdb.connect()

long_path = "outputs_new/parent/dedupe_clusters_long_full.parquet"
parent_path = "outputs_new/parent/parent_version_index_full.parquet"

# %%
long_path
# Out:
# 'outputs_new/parent/dedupe_clusters_long_full.parquet'

# %%
parent_path
# Out:
# 'outputs_new/parent/parent_version_index_full.parquet'

# %%
juan = con.sql(f"""
SELECT *
FROM '{parent_path}'
WHERE total_versions > 1
ORDER BY RANDOM()
LIMIT 10
""").df()

juan#.shape[0]
# Out:
#                       dup_group_id_full                      parent_record_id  \
# 0   crossref::10.1101/2022.01.10.475285   crossref::10.1101/2022.01.10.475285
# 1       crossref::10.31235/osf.io/9gpz6       crossref::10.31235/osf.io/9gpz6
# 2   crossref::10.1101/2025.04.25.650650   crossref::10.1101/2025.04.25.650650
# 3   datacite::10.48550/arxiv.1907.10176   datacite::10.48550/arxiv.1907.10176
# 4        crossref::10.2139/ssrn.4081778        crossref::10.2139/ssrn.4081778
# 5     datacite::10.5281/zenodo.17635976     datacite::10.5281/zenodo.17635976
# 6  crossref::10.36227/techrxiv.13365209  crossref::10.36227/techrxiv.13365209
# 7   datacite::10.48550/arxiv.2102.12454   datacite::10.48550/arxiv.2102.12454
# 8        crossref::10.2139/ssrn.5027116        crossref::10.2139/ssrn.5027116
# 9  crossref::10.21203/rs.3.rs-639332/v1  crossref::10.21203/rs.3.rs-639332/v1
#
#   parent_server_name                  parent_doi  \
# 0            bioRxiv   10.1101/2022.01.10.475285
# 1           SocArXiv       10.31235/osf.io/9gpz6
# 2            bioRxiv   10.1101/2025.04.25.650650
# 3              arXiv   10.48550/arxiv.1907.10176
# 4               SSRN        10.2139/ssrn.4081778
# 5             Zenodo     10.5281/zenodo.17635976
# 6           TechRxiv  10.36227/techrxiv.13365209
# 7              arXiv   10.48550/arxiv.2102.12454
# 8               SSRN        10.2139/ssrn.5027116
# 9    Research Square  10.21203/rs.3.rs-639332/v1
#
#                                           parent_url  \
# 0  http://biorxiv.org/lookup/doi/10.1101/2022.01....
# 1                            https://osf.io/9gpz6_v1
# 2  http://biorxiv.org/lookup/doi/10.1101/2025.04....
# 3                   https://arxiv.org/abs/1907.10176
# 4              https://www.ssrn.com/abstract=4081778
# 5     https://zenodo.org/doi/10.5281/zenodo.17635976
# 6  https://www.techrxiv.org/articles/preprint/On_...
# 7                   https://arxiv.org/abs/2102.12454
# 8              https://www.ssrn.com/abstract=5027116
# 9  https://www.researchsquare.com/article/rs-6393...
#
#                                         parent_title  \
# 0  MEK inhibition enhances presentation of target...
# 1  Challenges and Strategies Taken by English Lan...
# 2                   Engineering NIR-Sighted Bacteria
# 3  Graph inference with clustering and false disc...
# 4  Implantable Qr Code Subcutaneous Microchip Usi...
# 5  Conservative Motion Theory – D X: Euler Totien...
# 6  On Actual Maximum Exposure From 5G Multi-Colum...
# 7  Regional and Sectoral Structures and Their Dyn...
# 8  An Improved Point-to-Surface Contact Algorithm...
# 9  Physiological, Hematological and Biochemical r...
#
#                                       parent_authors parent_date_first_seen  \
# 0  Stopfer, Lauren E.; Rettko, Nicholas J.; Leddy...             2022-01-12
# 1  Mohamad, Maslawati; Wahab, Siti Mahirah Ab; Ku...             2023-04-26
# 2  Meier, Stefanie S. M.; Hörzing, Michael; Böhm,...             2025-04-27
# 3   Rebafka, Tabea; Roquain, Etienne; Villers, Fanny             2019-07-23
# 4  Wan, Nan; Zhang, Pengcheng; Liu, Zuheng; Niu, ...             2022-04-12
# 5                                   Kawasaki, Hideyo             2025-11-18
# 6  Xu, Bo; Colombi, Davide; Törnevik, Christer; G...             2020-12-14
# 7  Wang, Tao; Xiao, Shiying; Yan, Jun; Zhang, Panpan             2021-02-24
# 8  Zhang, Haoran; Liu, Lisheng; Lai, Xin; Li, Jun...             2024-01-01
# 9       Tulu, Diriba; Urge, Mengistu; Yusuf, Yisehak             2022-06-27
#
#   parent_year_first_seen                                 version_record_ids  \
# 0                   2022  crossref::10.1101/2022.01.10.475285; crossref:...
# 1                   2023  crossref::10.2139/ssrn.4431207; crossref::10.3...
# 2                   2025  crossref::10.1101/2025.04.25.650650; crossref:...
# 3                   2019  datacite::10.48550/arxiv.1907.10176; openalex:...
# 4                   2022  crossref::10.2139/ssrn.4081778; crossref::10.2...
# 5                   2025  datacite::10.5281/zenodo.17635976; datacite::1...
# 6                   2020  crossref::10.36227/techrxiv.13365209; crossref...
# 7                   2021  datacite::10.48550/arxiv.2102.12454; openalex:...
# 8                   2024  crossref::10.2139/ssrn.5027116; crossref::10.2...
# 9                   2022  crossref::10.21203/rs.3.rs-639332/v1; crossref...
#
#                                         version_dois  \
# 0    10.1101/2022.01.10.475285; 10.2139/ssrn.4018615
# 1        10.2139/ssrn.4431207; 10.31235/osf.io/9gpz6
# 2  10.1101/2025.04.25.650650; 10.7554/elife.10706...
# 3                          10.48550/arxiv.1907.10176
# 4         10.2139/ssrn.4081778; 10.2139/ssrn.4367659
# 5   10.5281/zenodo.17635976; 10.5281/zenodo.17635977
# 6  10.36227/techrxiv.13365209; 10.36227/techrxiv....
# 7  10.48550/arxiv.2102.12454; 10.48550/arxiv.2102...
# 8  10.2139/ssrn.5027116; 10.2139/ssrn.5036487; 10...
# 9   10.21203/rs.3.rs-639332/v1; 10.2139/ssrn.4147065
#
#                                  servers_with_counts  total_versions  \
# 0                              SSRN (1); bioRxiv (1)               2
# 1                             SSRN (1); SocArXiv (1)               2
# 2                             eLife (4); bioRxiv (1)               5
# 3                                 HAL (1); arXiv (1)               2
# 4                                           SSRN (2)               2
# 5                                         Zenodo (2)               2
# 6                                       TechRxiv (3)               3
# 7  RePEc: Research Papers in Economics (1); arXiv...               2
# 8                                SSRN (3); arXiv (1)               4
# 9                      Research Square (1); SSRN (1)               2
#
#   first_version_date last_version_date  \
# 0         2022-01-12        2022-01-26
# 1         2023-04-26        2023-05-01
# 2         2025-04-27        2025-11-03
# 3         2019-07-23        2022-12-07
# 4         2022-04-12        2023-03-03
# 5         2025-11-18        2025-11-18
# 6         2020-12-14        2021-06-15
# 7         2021-02-24        2021-02-24
# 8         2024-01-01        2025-01-01
# 9         2022-06-27        2022-06-27
#
#                   most_recent_version_servers
# 0                                        SSRN
# 1                                        SSRN
# 2                                       eLife
# 3                                         HAL
# 4                                        SSRN
# 5                                      Zenodo
# 6                                    TechRxiv
# 7  RePEc: Research Papers in Economics; arXiv
# 8                                        SSRN
# 9                       Research Square; SSRN

# %% [markdown]
# # exploration

# %%
len(long_path)
# Out:
# 52

# %%
len(parent_path)
# Out:
# 52

# %%
juan = con.sql(f"""
SELECT *
FROM '{parent_path}'
WHERE total_versions > 1
ORDER BY RANDOM()
LIMIT 10
""").df()

juan#.shape[0]
# Out:
#                        dup_group_id_full  \
# 0      datacite::10.5281/zenodo.15072675
# 1    crossref::10.1101/2020.06.22.166017
# 2      datacite::10.5281/zenodo.17795335
# 3         datacite::10.17613/rxht2-7r628
# 4                  openalex::W3191225828
# 5     datacite::10.48550/arxiv.0806.0621
# 6  datacite::10.13140/rg.2.2.34761.86885
# 7       datacite::10.22004/ag.econ.14549
# 8         datacite::10.17613/p2688-5ed18
# 9         crossref::10.2139/ssrn.4965928
#
#                         parent_record_id                   parent_server_name  \
# 0      datacite::10.5281/zenodo.15072675                               Zenodo
# 1    crossref::10.1101/2020.06.22.166017                              bioRxiv
# 2      datacite::10.5281/zenodo.17795335                               Zenodo
# 3         datacite::10.17613/rxht2-7r628              Humanities Commons CORE
# 4                  openalex::W3191225828  RePEc: Research Papers in Economics
# 5     datacite::10.48550/arxiv.0806.0621                                arXiv
# 6  datacite::10.13140/rg.2.2.12951.48808                         ResearchGate
# 7       datacite::10.22004/ag.econ.14549                        AgEcon Search
# 8         datacite::10.17613/p2688-5ed18              Humanities Commons CORE
# 9         crossref::10.2139/ssrn.4965928                                 SSRN
#
#                     parent_doi  \
# 0      10.5281/zenodo.15072675
# 1    10.1101/2020.06.22.166017
# 2      10.5281/zenodo.17795335
# 3         10.17613/rxht2-7r628
# 4                         None
# 5     10.48550/arxiv.0806.0621
# 6  10.13140/rg.2.2.12951.48808
# 7       10.22004/ag.econ.14549
# 8         10.17613/p2688-5ed18
# 9         10.2139/ssrn.4965928
#
#                                           parent_url  \
# 0     https://zenodo.org/doi/10.5281/zenodo.15072675
# 1  http://biorxiv.org/lookup/doi/10.1101/2020.06....
# 2     https://zenodo.org/doi/10.5281/zenodo.17795335
# 3  https://works.hcommons.org/doi/10.17613/rxht2-...
# 4  https://ideas.repec.org/p/arx/papers/2107.1373...
# 5                    https://arxiv.org/abs/0806.0621
# 6  https://www.researchgate.net/doi/10.13140/RG.2...
# 7          https://ageconsearch.umn.edu/record/14549
# 8  https://works.hcommons.org/doi/10.17613/p2688-...
# 9              https://www.ssrn.com/abstract=4965928
#
#                                         parent_title  \
# 0  Anthropological and Historical Review of Tibet...
# 1  Rapid and Efficient BAC Recombineering: Gain &...
# 2  PRH | Essay | 7.21 • Fractal Dimension as a Me...
# 3  Riding the White Elephant, Blossoming the Gold...
# 4  Double-Robust Two-Way-Fixed-Effects Regression...
# 5  The early-type dwarf galaxy population of the ...
# 6  Cardiomate|> an American empirical game theore...
# 7  LIVESTOCK PRODUCTS TRADE: PROSPECTS FOR LIBERA...
# 8            DIY Methods 2023 Conference Proceedings
# 9  Prevalence of Chikungunya, Dengue, and West Ni...
#
#                                       parent_authors parent_date_first_seen  \
# 0                              Fuertes Oliva, Martín             2025-03-23
# 1        Kuk, Myeong Uk; Oh, Sekyung; Park, Joon Tae             2020-06-23
# 2                                Perisic, Aleksandar             2025-12-02
# 3                                     McCarty, Steve             2019-01-01
# 4  Dmitry Arkhangelsky; Guido W. Imbens; Lihua Le...             2021-01-01
# 5                Misgeld, I.; Mieske, S.; Hilker, M.             2008-06-03
# 6                                      Cartik Sharma             2025-07-04
# 7                                      Andrews, Neil             2001-01-01
# 8  Almendarez, Loren; Andrikanich, Lauren; Armstr...             2023-01-01
# 9  Abbasi, Ebrahim; Moemenbellah-Fard, Mohammad  ...             2024-01-01
#
#   parent_year_first_seen                                 version_record_ids  \
# 0                   2025  datacite::10.5281/zenodo.15072675; datacite::1...
# 1                   2020  crossref::10.1101/2020.06.22.166017; crossref:...
# 2                   2025  datacite::10.5281/zenodo.17795335; datacite::1...
# 3                   2019  datacite::10.17613/98zq-yy30; datacite::10.176...
# 4                   2021  datacite::10.48550/arxiv.2107.13737; openalex:...
# 5                   2008  datacite::10.48550/arxiv.0806.0621; datacite::...
# 6                   2025  datacite::10.13140/rg.2.2.12951.48808; datacit...
# 7                   2001  datacite::10.22004/ag.econ.14549; openalex::W3...
# 8                   2023  datacite::10.17613/6hj0-5w42; datacite::10.176...
# 9                   2024  crossref::10.1101/2024.09.12.24313525; crossre...
#
#                                         version_dois  \
# 0   10.5281/zenodo.15072675; 10.5281/zenodo.15072676
# 1  10.1101/2020.06.22.166017; 10.21203/rs.3.rs-44...
# 2  10.5281/zenodo.17795335; 10.5281/zenodo.177953...
# 3           10.17613/98zq-yy30; 10.17613/rxht2-7r628
# 4                          10.48550/arxiv.2107.13737
# 5  10.48550/arxiv.0806.0621; 10.48550/arxiv.0901....
# 6  10.13140/rg.2.2.12951.48808; 10.13140/rg.2.2.3...
# 7                             10.22004/ag.econ.14549
# 8           10.17613/6hj0-5w42; 10.17613/p2688-5ed18
# 9  10.1101/2024.09.12.24313525; 10.2139/ssrn.4965928
#
#                                  servers_with_counts  total_versions  \
# 0                                         Zenodo (2)               2
# 1                   Research Square (1); bioRxiv (1)               2
# 2                                         Zenodo (3)               3
# 3                        Humanities Commons CORE (2)               2
# 4  RePEc: Research Papers in Economics (1); arXiv...               2
# 5                                          arXiv (2)               2
# 6                                   ResearchGate (2)               2
# 7  AgEcon Search (1); RePEc: Research Papers in E...               2
# 8                        Humanities Commons CORE (2)               2
# 9                              SSRN (1); medRxiv (1)               2
#
#   first_version_date last_version_date  \
# 0         2025-03-23        2025-03-23
# 1         2020-06-23        2020-08-03
# 2         2025-12-02        2025-12-27
# 3         2019-01-01        2019-06-13
# 4         2021-01-01        2021-07-29
# 5         2008-06-03        2009-01-28
# 6         2025-07-04        2025-07-04
# 7         2001-01-01        2001-01-01
# 8         2023-01-01        2023-10-17
# 9         2024-01-01        2024-09-12
#
#                          most_recent_version_servers
# 0                                             Zenodo
# 1                                    Research Square
# 2                                             Zenodo
# 3                            Humanities Commons CORE
# 4                                              arXiv
# 5                                              arXiv
# 6                                       ResearchGate
# 7  AgEcon Search; RePEc: Research Papers in Econo...
# 8                            Humanities Commons CORE
# 9                                            medRxiv

# %%
juan = con.sql(f"""
SELECT *
FROM '{parent_path}'
WHERE total_versions > 1
ORDER BY RANDOM()
LIMIT 10
""").df()

juan#.shape[0]
# Out:
#                          dup_group_id_full  \
# 0                 crossref::10.1101/026757
# 1      datacite::10.48550/arxiv.2109.11376
# 2      crossref::10.21203/rs.3.rs-42242/v1
# 3  datacite::10.13140/rg.2.2.14521.06241/2
# 4       crossref::10.31234/osf.io/2qv5y_v1
# 5           crossref::10.2139/ssrn.1647647
# 6                    openalex::W4302309204
# 7           datacite::10.17181/dkyc0-vzd48
# 8           crossref::10.2139/ssrn.3644621
# 9                    openalex::W4416179070
#
#                           parent_record_id  \
# 0                 crossref::10.1101/026757
# 1      datacite::10.48550/arxiv.2109.11376
# 2      crossref::10.21203/rs.3.rs-42242/v1
# 3  datacite::10.13140/rg.2.2.14521.06241/2
# 4       crossref::10.31234/osf.io/2qv5y_v1
# 5           crossref::10.2139/ssrn.1647647
# 6                    openalex::W4302309204
# 7           datacite::10.17181/dkyc0-vzd48
# 8           crossref::10.2139/ssrn.3644621
# 9                    openalex::W4416179070
#
#                     parent_server_name                     parent_doi  \
# 0                              bioRxiv                 10.1101/026757
# 1                                arXiv      10.48550/arxiv.2109.11376
# 2                      Research Square      10.21203/rs.3.rs-42242/v1
# 3                         ResearchGate  10.13140/rg.2.2.14521.06241/2
# 4                             PsyArXiv       10.31234/osf.io/2qv5y_v1
# 5                                 SSRN           10.2139/ssrn.1647647
# 6  RePEc: Research Papers in Economics                           None
# 7                 CERN document server           10.17181/dkyc0-vzd48
# 8                                 SSRN           10.2139/ssrn.3644621
# 9                                  HAL                           None
#
#                                           parent_url  \
# 0       http://biorxiv.org/lookup/doi/10.1101/026757
# 1                   https://arxiv.org/abs/2109.11376
# 2  https://www.researchsquare.com/article/rs-4224...
# 3  https://www.researchgate.net/doi/10.13140/RG.2...
# 4                            https://osf.io/2qv5y_v1
# 5               http://www.ssrn.com/abstract=1647647
# 6                                               None
# 7   https://repository.cern/doi/10.17181/dkyc0-vzd48
# 8              https://www.ssrn.com/abstract=3644621
# 9                   https://hal.science/hal-05328121
#
#                                         parent_title  \
# 0  Inference of multiple-wave population admixtur...
# 1  The stochastic gravitational wave background f...
# 2  An optimized segmentation and quantification a...
# 3  The singularities as ontological limits of the...
# 4  Daily life fluctuations in affect predict with...
# 5  Debt Collection Agencies and the Supply of Con...
# 6  Duration of Low Wage Employment: A Study Based...
# 7  Feasibility study for the measurement of the a...
# 8  American Military Justice: Retaining the Comma...
# 9  Analytical Aspects of the Compressible Magneto...
#
#                                       parent_authors parent_date_first_seen  \
# 0  Zhou, Ying; Yuan, Kai; Yu, Yaoliang; Ni, Xumin...             2015-09-14
# 1  García-Bellido, Juan; Jaraba, Santiago; Kuroya...             2021-09-23
# 2  Wu, Sheng; Wu, Shaowei; Feng, Hui; Hu, Zizhong...             2020-07-20
# 3                                    Sfetcu, Nicolae             2018-01-01
# 4  Fittipaldi, Sol; Teckentrup, Vanessa; Kelley, ...             2025-04-15
# 5                                  Fedaseyeu, Viktar             2011-01-01
# 6  António M. S. Pimenta; Francisco J. Silva; Jos...             2011-01-01
# 7                                 Toffolin, Leonardo             2022-10-24
# 8                                Schlueter, David A.             2020-08-03
# 9                                   Edoardo Niccolai             2025-10-23
#
#   parent_year_first_seen                                 version_record_ids  \
# 0                   2015  crossref::10.1101/026757; crossref::10.1101/08...
# 1                   2021  crossref::10.2139/ssrn.4010368; datacite::10.4...
# 2                   2020  crossref::10.21203/rs.3.rs-42242/v1; crossref:...
# 3                   2018  crossref::10.2139/ssrn.4351193; crossref::10.3...
# 4                   2025  crossref::10.31234/osf.io/2qv5y_v1; crossref::...
# 5                   2011  crossref::10.2139/ssrn.1647647; crossref::10.2...
# 6                   2011  crossref::10.2139/ssrn.1933329; openalex::W430...
# 7                   2022  datacite::10.17181/dkyc0-vzd48; datacite::10.1...
# 8                   2020  crossref::10.2139/ssrn.3644621; crossref::10.2...
# 9                   2025       openalex::W4416179070; openalex::W7105508260
#
#                                         version_dois  \
# 0                     10.1101/026757; 10.1101/082644
# 1    10.2139/ssrn.4010368; 10.48550/arxiv.2109.11376
# 2  10.21203/rs.3.rs-42242/v1; 10.21203/rs.3.rs-51...
# 3  10.13140/rg.2.2.14521.06241/2; 10.2139/ssrn.43...
# 4  10.31234/osf.io/2qv5y_v1; 10.7554/elife.108521...
# 5  10.2139/ssrn.1647647; 10.2139/ssrn.2330451; 10...
# 6                               10.2139/ssrn.1933329
# 7         10.17181/dkyc0-vzd48; 10.17181/hsz8k-mx212
# 8         10.2139/ssrn.3644621; 10.2139/ssrn.3666595
# 9                                               None
#
#                                  servers_with_counts  total_versions  \
# 0                                        bioRxiv (2)               2
# 1                                SSRN (1); arXiv (1)               2
# 2                                Research Square (4)               4
# 3           ResearchGate (1); SSRN (1); SocArXiv (1)               3
# 4                            eLife (2); PsyArXiv (1)               3
# 5                                           SSRN (4)               4
# 6  RePEc: Research Papers in Economics (1); SSRN (1)               2
# 7                           CERN document server (2)               2
# 8                                           SSRN (2)               2
# 9                                            HAL (2)               2
#
#   first_version_date last_version_date most_recent_version_servers
# 0         2015-09-14        2016-10-22                     bioRxiv
# 1         2021-09-23        2022-02-16                        SSRN
# 2         2020-07-20        2021-01-13             Research Square
# 3         2018-01-01        2023-06-10                    SocArXiv
# 4         2025-04-15        2025-12-23                       eLife
# 5         2011-01-01        2015-01-01                        SSRN
# 6         2011-01-01        2011-09-25                        SSRN
# 7         2022-10-24        2022-10-24        CERN document server
# 8         2020-08-03        2020-09-16                        SSRN
# 9         2025-10-23        2025-10-23                         HAL

# %%
juan.iloc[8]
# Out:
# dup_group_id_full                                 crossref::10.2139/ssrn.3644621
# parent_record_id                                  crossref::10.2139/ssrn.3644621
# parent_server_name                                                          SSRN
# parent_doi                                                  10.2139/ssrn.3644621
# parent_url                                 https://www.ssrn.com/abstract=3644621
# parent_title                   American Military Justice: Retaining the Comma...
# parent_authors                                               Schlueter, David A.
# parent_date_first_seen                                       2020-08-03 00:00:00
# parent_year_first_seen                                                      2020
# version_record_ids             crossref::10.2139/ssrn.3644621; crossref::10.2...
# version_dois                          10.2139/ssrn.3644621; 10.2139/ssrn.3666595
# servers_with_counts                                                     SSRN (2)
# total_versions                                                                 2
# first_version_date                                           2020-08-03 00:00:00
# last_version_date                                            2020-09-16 00:00:00
# most_recent_version_servers                                                 SSRN
# Name: 8, dtype: object

# %%
juan.servers_with_counts[8]
# Out:
# 'SSRN (2)'

# %% [markdown]
# ## to look at
#
# - same preprint posted to two servers same day (like RS, posted automatically)
# - same preprint at datacite and crossref (moved over from one agency to the other?)

# %%
juan.iloc[0].version_record_ids
# Out:
# 'crossref::10.1101/026757; crossref::10.1101/082644'

# %%
long_path_df = con.sql(f"""
SELECT *
FROM '{long_path}'
ORDER BY RANDOM()
LIMIT 100000
""").df()

# %%
long_path_df
# Out:
#                                    record_id  \
# 0        datacite::10.48550/arxiv.1902.06323
# 1                      openalex::W2994991216
# 2            crossref::10.31219/osf.io/8qhj4
# 3        datacite::10.48550/arxiv.1710.09153
# 4         datacite::10.48550/arxiv.1107.1481
# ...                                      ...
# 99995  crossref::10.1101/2020.07.30.20165050
# 99996   crossref::10.33774/coe-2022-06r8l-v2
# 99997                  openalex::W1577779290
# 99998     datacite::10.48550/arxiv.1306.2507
# 99999        crossref::10.31219/osf.io/5phj9
#
#                                server_name   backend  \
# 0                                    arXiv  datacite
# 1            Munich Personal RePEc Archive  openalex
# 2                   Open Science Framework  crossref
# 3                                    arXiv  datacite
# 4                                    arXiv  datacite
# ...                                    ...       ...
# 99995                              medRxiv  crossref
# 99996                Cambridge Open Engage  crossref
# 99997  RePEc: Research Papers in Economics  openalex
# 99998                                arXiv  datacite
# 99999               Open Science Framework  crossref
#
#                                doi  \
# 0        10.48550/arxiv.1902.06323
# 1                             None
# 2            10.31219/osf.io/8qhj4
# 3        10.48550/arxiv.1710.09153
# 4         10.48550/arxiv.1107.1481
# ...                            ...
# 99995  10.1101/2020.07.30.20165050
# 99996   10.33774/coe-2022-06r8l-v2
# 99997                         None
# 99998     10.48550/arxiv.1306.2507
# 99999        10.31219/osf.io/5phj9
#
#                                            doi_url  \
# 0        https://doi.org/10.48550/arxiv.1902.06323
# 1                                             None
# 2            https://doi.org/10.31219/osf.io/8qhj4
# 3        https://doi.org/10.48550/arxiv.1710.09153
# 4         https://doi.org/10.48550/arxiv.1107.1481
# ...                                            ...
# 99995  https://doi.org/10.1101/2020.07.30.20165050
# 99996   https://doi.org/10.33774/coe-2022-06r8l-v2
# 99997                                         None
# 99998     https://doi.org/10.48550/arxiv.1306.2507
# 99999        https://doi.org/10.31219/osf.io/5phj9
#
#                                         landing_page_url type_backend_raw  \
# 0                       https://arxiv.org/abs/1902.06323             Text
# 1             http://www.theses.fr/2019LYSEI038/document         preprint
# 2                                https://osf.io/8qhj4_v1   posted-content
# 3                       https://arxiv.org/abs/1710.09153         Preprint
# 4                        https://arxiv.org/abs/1107.1481             Text
# ...                                                  ...              ...
# 99995  http://medrxiv.org/lookup/doi/10.1101/2020.07....   posted-content
# 99996  https://www.cambridge.org/engage/coe/article-d...   posted-content
# 99997  https://econpapers.repec.org/paper/isugenres/1...         preprint
# 99998                    https://arxiv.org/abs/1306.2507             Text
# 99999                            https://osf.io/5phj9_v1   posted-content
#
#       subtype_backend_raw                                              title  \
# 0                 Article  Automated Detection of Regions of Interest for...
# 1                    None  Building a secure infrastructure for IoT syste...
# 2                preprint  Resume Iklan, Gaya Hidup, Perilaku Konsumen da...
# 3                 Article                        On the Brannan's conjecture
# 4                 Article  Neutron experiments to search for new spin-dep...
# ...                   ...                                                ...
# 99995            preprint  Quantification of the association between pred...
# 99996            preprint  Feasibility Study of Biogas Production and App...
# 99997                None  Grain Traffic on the Missouri River Declines o...
# 99998             Article             Eigenvalue Spectra of Modular Networks
# 99999            preprint        Tugas metodologi penelitian analisis jurnal
#
#                                             authors_flat  \
# 0                                  Alkhimova, Svitlana M
# 1                                           Xiaoyang Zhu
# 2                                           J, Nurfaitma
# 3                                          Szász, Róbert
# 4                                   Pokotilovski, Yu. N.
# ...                                                  ...
# 99995  Fernandez Villalobos, Nathalie Verónica; Ott, ...
# 99996  Ansari, Ammar Arif; Elshamy, Yousef; Dheen, Ma...
# 99997              C. Phillip Baumel; Jerry Van Der Kamp
# 99998                                  Peixoto, Tiago P.
# 99999                            puspitasari, Dina indra
#
#                                        institutions_flat countries_flat  \
# 0                                                   None           None
# 1      Laboratoire d'Informatique en Images et Systèm...             FR
# 2                                                   None           None
# 3                                                   None           None
# 4                                    JINR, Dubna, Russia           None
# ...                                                  ...            ...
# 99995                                               None           None
# 99996                                               None           None
# 99997                                               None           None
# 99998                                               None           None
# 99999                                               None           None
#
#                                           relations_json version_label  \
# 0      [{"relatedIdentifier": "10.20535/1810-0546.201...             1
# 1                                                   None          None
# 2                                                   None          None
# 3                                                     []             1
# 4      [{"relatedIdentifier": "10.1134/s0021364011180...             2
# ...                                                  ...           ...
# 99995  {"is-preprint-of": [{"asserted-by": "subject",...          None
# 99996  {"is-version-of": [{"asserted-by": "subject", ...          None
# 99997                                               None          None
# 99998  [{"relatedIdentifier": "10.1103/physrevlett.11...             2
# 99999                                               None          None
#
#                           is_version_of                    is_preprint_of  \
# 0      10.20535/1810-0546.2018.5.146185  10.20535/1810-0546.2018.5.146185
# 1                                  None                              None
# 2                                  None
# 3                                  None
# 4             10.1134/s0021364011180111         10.1134/s0021364011180111
# ...                                 ...                               ...
# 99995                              None        10.1186/s13643-021-01732-3
# 99996           10.33774/coe-2022-06r8l
# 99997                              None                              None
# 99998    10.1103/physrevlett.111.098701    10.1103/physrevlett.111.098701
# 99999                              None
#
#       has_preprint has_review has_published_version  \
# 0                                              true
# 1             None       None                  None
# 2                                             false
# 3                                             false
# 4                                              true
# ...            ...        ...                   ...
# 99995                                          true
# 99996                                         false
# 99997         None       None                  None
# 99998                                          true
# 99999                                         false
#
#        published_version_ids_json  version_of_ids_json update_to_json  \
# 0                            <NA>                 <NA>           None
# 1                            <NA>                 <NA>           None
# 2                            <NA>                 <NA>           None
# 3                            <NA>                 <NA>           None
# 4                            <NA>                 <NA>           None
# ...                           ...                  ...            ...
# 99995                        <NA>                 <NA>           None
# 99996                        <NA>                 <NA>           None
# 99997                        <NA>                 <NA>           None
# 99998                        <NA>                 <NA>           None
# 99999                        <NA>                 <NA>           None
#
#                                   raw_relationships_json  \
# 0      {"client": {"data": {"id": "arxiv.content", "t...
# 1                                                   None
# 2                                                   None
# 3      {"client": {"data": {"id": "arxiv.content", "t...
# 4      {"client": {"data": {"id": "arxiv.content", "t...
# ...                                                  ...
# 99995                                               None
# 99996                                               None
# 99997                                               None
# 99998  {"client": {"data": {"id": "arxiv.content", "t...
# 99999                                               None
#
#                                 records_hierarchy date_first_seen  \
# 0                                          parent      2019-02-17
# 1                                          parent      2019-06-24
# 2                                          parent      2022-06-30
# 3                                          parent      2017-10-25
# 4                                          parent      2011-07-07
# ...                                           ...             ...
# 99995                                      parent      2020-08-01
# 99996  parent - duplicate (Cambridge Open Engage)      2022-02-28
# 99997                                      parent      2003-01-01
# 99998                                      parent      2013-06-11
# 99999                                      parent      2022-05-09
#
#        publication_year  publication_year_first_seen  \
# 0                2019.0                         2019
# 1                2019.0                         2019
# 2                2022.0                         2022
# 3                2017.0                         2017
# 4                2011.0                         2011
# ...                 ...                          ...
# 99995            2020.0                         2020
# 99996            2022.0                         2022
# 99997            2003.0                         2003
# 99998            2013.0                         2013
# 99999            2022.0                         2022
#
#                                                raw_dates  \
# 0      [{"date": "2019-02-17T20:47:22Z", "dateInforma...
# 1                                                   None
# 2                                                   None
# 3      [{"date": "2017-10-25T10:26:19Z", "dateInforma...
# 4      [{"date": "2011-07-07T18:43:31Z", "dateInforma...
# ...                                                  ...
# 99995                                               None
# 99996                                               None
# 99997                                               None
# 99998  [{"date": "2013-06-11T12:42:05Z", "dateInforma...
# 99999                                               None
#
#       records_hierarchy_backup                   parent_record_id  \
# 0                       parent                               None
# 1                       parent                               None
# 2                       parent                               None
# 3                       parent                               None
# 4                       parent                               None
# ...                        ...                                ...
# 99995                   parent                               None
# 99996                  version  crossref::10.33774/coe-2022-06r8l
# 99997                   parent                               None
# 99998                   parent                               None
# 99999                   parent                               None
#
#                             dup_group_id  \
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
# ...                                  ...
# 99995                               None
# 99996  crossref::10.33774/coe-2022-06r8l
# 99997                               None
# 99998                               None
# 99999                               None
#
#                                      authors_fp_tokenbag  \
# 0                                                   None
# 1                                                   None
# 2                                            j_nurfaitma
# 3                                                   None
# 4                                      n_pokotilovski_yu
# ...                                                  ...
# 99995                                               None
# 99996  ahmed_khalid;ammar_ansari_arif;cavin_correia_h...
# 99997                baumel_c_phillip;der_jerry_kamp_van
# 99998                                    p_peixoto_tiago
# 99999                             dina_indra_puspitasari
#
#                                           title_clean_v2  \
# 0      automated detection of regions of interest for...
# 1      building a secure infrastructure for iot syste...
# 2      resume iklan gaya hidup perilaku konsumen dan ...
# 3                                                   None
# 4      neutron experiments to search for new spin dep...
# ...                                                  ...
# 99995                                               None
# 99996  feasibility study of biogas production and app...
# 99997  grain traffic on the missouri river declines o...
# 99998             eigenvalue spectra of modular networks
# 99999        tugas metodologi penelitian analisis jurnal
#
#       authors_fp_last_initial authors_fp_last  \
# 0                 alkhimova|s            None
# 1                       zhu|x            None
# 2                         j|n               j
# 3                        None            None
# 4              pokotilovski|y            None
# ...                       ...             ...
# 99995                    None            None
# 99996                    None            None
# 99997         baumel|c;kamp|j            None
# 99998               peixoto|t            None
# 99999           puspitasari|d     puspitasari
#
#                   records_hierarchy_dedupe_backup  \
# 0                                          parent
# 1                                          parent
# 2                                          parent
# 3                                          parent
# 4                                          parent
# ...                                           ...
# 99995                                      parent
# 99996  parent - duplicate (Cambridge Open Engage)
# 99997                                      parent
# 99998                                      parent
# 99999                                      parent
#
#           parent_record_id_dedupe_backup dup_group_id_dedupe_backup  \
# 0                                   None                       None
# 1                                   None                       None
# 2                                   None                       None
# 3                                   None                       None
# 4                                   None                       None
# ...                                  ...                        ...
# 99995                               None                       None
# 99996  crossref::10.33774/coe-2022-06r8l       12361182027440777727
# 99997                               None                       None
# 99998                               None                       None
# 99999                               None                       None
#
#                        has_version_dois  \
# 0      10.20535/1810-0546.2018.5.146185
# 1                                  None
# 2                                  None
# 3                                  None
# 4             10.1134/s0021364011180111
# ...                                 ...
# 99995                              None
# 99996                              None
# 99997                              None
# 99998    10.1103/physrevlett.111.098701
# 99999                              None
#
#       records_hierarchy_unify_version_backup  \
# 0                                     parent
# 1                                     parent
# 2                                     parent
# 3                                     parent
# 4                                     parent
# ...                                      ...
# 99995                                 parent
# 99996      parent - duplicate (version-link)
# 99997                                 parent
# 99998                                 parent
# 99999                                 parent
#
#       parent_record_id_unify_version_backup  \
# 0                                      None
# 1                                      None
# 2                                      None
# 3                                      None
# 4                                      None
# ...                                     ...
# 99995                                  None
# 99996     crossref::10.33774/coe-2022-06r8l
# 99997                                  None
# 99998                                  None
# 99999                                  None
#
#        dup_group_id_unify_version_backup  \
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
# ...                                  ...
# 99995                               None
# 99996  crossref::10.33774/coe-2022-06r8l
# 99997                               None
# 99998                               None
# 99999                               None
#
#                            dup_group_id_full         dt  rid_num  \
# 0        datacite::10.48550/arxiv.1902.06323 2019-02-17     <NA>
# 1                      openalex::W2994991216 2019-06-24     <NA>
# 2            crossref::10.31219/osf.io/8qhj4 2022-06-30     <NA>
# 3        datacite::10.48550/arxiv.1710.09153 2017-10-25     <NA>
# 4         datacite::10.48550/arxiv.1107.1481 2011-07-07     <NA>
# ...                                      ...        ...      ...
# 99995  crossref::10.1101/2020.07.30.20165050 2020-08-01     <NA>
# 99996      crossref::10.33774/coe-2022-06r8l 2022-02-28     <NA>
# 99997                  openalex::W1577779290 2003-01-01     <NA>
# 99998     datacite::10.48550/arxiv.1306.2507 2013-06-11     <NA>
# 99999        crossref::10.31219/osf.io/5phj9 2022-05-09     <NA>
#
#                          doi_clean                         server_clean  \
# 0        10.48550/arxiv.1902.06323                                arXiv
# 1                             None        Munich Personal RePEc Archive
# 2            10.31219/osf.io/8qhj4               Open Science Framework
# 3        10.48550/arxiv.1710.09153                                arXiv
# 4         10.48550/arxiv.1107.1481                                arXiv
# ...                            ...                                  ...
# 99995  10.1101/2020.07.30.20165050                              medRxiv
# 99996   10.33774/coe-2022-06r8l-v2                Cambridge Open Engage
# 99997                         None  RePEc: Research Papers in Economics
# 99998     10.48550/arxiv.1306.2507                                arXiv
# 99999        10.31219/osf.io/5phj9               Open Science Framework
#
#                    parent_record_id_selected  \
# 0        datacite::10.48550/arxiv.1902.06323
# 1                      openalex::W2994991216
# 2            crossref::10.31219/osf.io/8qhj4
# 3        datacite::10.48550/arxiv.1710.09153
# 4         datacite::10.48550/arxiv.1107.1481
# ...                                      ...
# 99995  crossref::10.1101/2020.07.30.20165050
# 99996      crossref::10.33774/coe-2022-06r8l
# 99997                  openalex::W1577779290
# 99998     datacite::10.48550/arxiv.1306.2507
# 99999        crossref::10.31219/osf.io/5phj9
#
#                parent_server_name_selected          parent_doi_selected  \
# 0                                    arXiv    10.48550/arxiv.1902.06323
# 1            Munich Personal RePEc Archive                         None
# 2                   Open Science Framework        10.31219/osf.io/8qhj4
# 3                                    arXiv    10.48550/arxiv.1710.09153
# 4                                    arXiv     10.48550/arxiv.1107.1481
# ...                                    ...                          ...
# 99995                              medRxiv  10.1101/2020.07.30.20165050
# 99996                Cambridge Open Engage      10.33774/coe-2022-06r8l
# 99997  RePEc: Research Papers in Economics                         None
# 99998                                arXiv     10.48550/arxiv.1306.2507
# 99999               Open Science Framework        10.31219/osf.io/5phj9
#
#                                      parent_url_selected  \
# 0                       https://arxiv.org/abs/1902.06323
# 1             http://www.theses.fr/2019LYSEI038/document
# 2                                https://osf.io/8qhj4_v1
# 3                       https://arxiv.org/abs/1710.09153
# 4                        https://arxiv.org/abs/1107.1481
# ...                                                  ...
# 99995  http://medrxiv.org/lookup/doi/10.1101/2020.07....
# 99996  https://www.cambridge.org/engage/coe/article-d...
# 99997  https://econpapers.repec.org/paper/isugenres/1...
# 99998                    https://arxiv.org/abs/1306.2507
# 99999                            https://osf.io/5phj9_v1
#
#                                    parent_title_selected  \
# 0      Automated Detection of Regions of Interest for...
# 1      Building a secure infrastructure for IoT syste...
# 2      Resume Iklan, Gaya Hidup, Perilaku Konsumen da...
# 3                            On the Brannan's conjecture
# 4      Neutron experiments to search for new spin-dep...
# ...                                                  ...
# 99995  Quantification of the association between pred...
# 99996  Feasibility Study of Biogas Production and App...
# 99997  Grain Traffic on the Missouri River Declines o...
# 99998             Eigenvalue Spectra of Modular Networks
# 99999        Tugas metodologi penelitian analisis jurnal
#
#                                  parent_authors_selected parent_date_selected  \
# 0                                  Alkhimova, Svitlana M           2019-02-17
# 1                                           Xiaoyang Zhu           2019-06-24
# 2                                           J, Nurfaitma           2022-06-30
# 3                                          Szász, Róbert           2017-10-25
# 4                                   Pokotilovski, Yu. N.           2011-07-07
# ...                                                  ...                  ...
# 99995  Fernandez Villalobos, Nathalie Verónica; Ott, ...           2020-08-01
# 99996  Ansari, Ammar Arif; Khalid, Ahmed; Correia, Ca...           2022-02-21
# 99997              C. Phillip Baumel; Jerry Van Der Kamp           2003-01-01
# 99998                                  Peixoto, Tiago P.           2013-06-11
# 99999                            puspitasari, Dina indra           2022-05-09
#
#       parent_year_selected  is_parent_selected  group_size
# 0                     2019                True           1
# 1                     2019                True           1
# 2                     2022                True           1
# 3                     2017                True           1
# 4                     2011                True           1
# ...                    ...                 ...         ...
# 99995                 2020                True           1
# 99996                 2022               False           2
# 99997                 2003                True           1
# 99998                 2013                True           1
# 99999                 2022                True           1
#
# [100000 rows x 57 columns]

# %%
long_path_df.update_to_json[31]

# %%
long_path_df.published_version_ids_json.value_counts()
# Out:
# Series([], Name: count, dtype: Int64)

# %%
juan = con.sql(f"""
SELECT dup_group_id_full, server_name, COUNT(*) AS n
FROM '{long_path}'
GROUP BY 1, 2
ORDER BY n DESC
LIMIT 1000
""").df()

juan.groupby('server_name').size().nlargest(100)
# Out:
# server_name
# Zenodo                                  654
# Preprints.org                            57
# ResearchGate                             46
# arXiv                                    36
# Open Science Framework                   22
# Cambridge Open Engage                    21
# SSRN                                     19
# PsyArXiv                                 17
# ChemRxiv                                 15
# Qeios                                    14
# Research Square                          13
# AgEcon Search                            13
# searchRxiv                               11
# Authorea Inc.                             8
# TechRxiv                                  7
# INA-Rxiv                                  7
# Thesis Commons                            7
# HAL                                       5
# Covid-19 Preprints                        5
# RePEc: Research Papers in Economics       3
# APSA Preprints                            2
# Earth and Space Science Open Archive      2
# SocArXiv                                  2
# PeerJ Preprints                           2
# ResearchHub                               2
# Humanities Commons CORE                   2
# Nature Precedings                         1
# Law Archive                               1
# F1000Research                             1
# EconStor Preprints                        1
# CrossAsia-Repository                      1
# CERN document server                      1
# EcoEvoRxiv                                1
# PropylaeumDok                             1
# dtype: int64

# %%
con.sql(f"""
SELECT *
FROM '{long_path}'
WHERE dup_group_id_full IN (
    SELECT DISTINCT dup_group_id_full
    FROM '{long_path}'
    ORDER BY RANDOM()
    LIMIT 5
)
""").df()
# Out:
#                              record_id                          server_name  \
# 0  datacite::10.48550/arxiv.1804.06795                                arXiv
# 1                openalex::W1487526705  RePEc: Research Papers in Economics
# 2  datacite::10.48550/arxiv.1712.10300                                arXiv
# 3  datacite::10.48550/arxiv.2406.06813                                arXiv
# 4    datacite::10.22004/ag.econ.301720                        AgEcon Search
#
#     backend                        doi  \
# 0  datacite  10.48550/arxiv.1804.06795
# 1  openalex                       None
# 2  datacite  10.48550/arxiv.1712.10300
# 3  datacite  10.48550/arxiv.2406.06813
# 4  datacite    10.22004/ag.econ.301720
#
#                                      doi_url  \
# 0  https://doi.org/10.48550/arxiv.1804.06795
# 1                                       None
# 2  https://doi.org/10.48550/arxiv.1712.10300
# 3  https://doi.org/10.48550/arxiv.2406.06813
# 4    https://doi.org/10.22004/ag.econ.301720
#
#                                  landing_page_url type_backend_raw  \
# 0                https://arxiv.org/abs/1804.06795             Text
# 1  https://discovery.ucl.ac.uk/id/eprint/1413809/         preprint
# 2                https://arxiv.org/abs/1712.10300         Preprint
# 3                https://arxiv.org/abs/2406.06813             Text
# 4      https://ageconsearch.umn.edu/record/301720             Text
#
#   subtype_backend_raw                                              title  \
# 0             Article  The Fornax3D project: overall goals, galaxy sa...
# 1                None  Beyond LATE with a discrete instrument: Hetero...
# 2             Article  3d field theory, plane partitions and triple M...
# 3             Article  Stable Neighbor Denoising for Source-free Doma...
# 4                Text  Wilhelm Brandes, Guido Recke, Thomas Berger - ...
#
#                                         authors_flat institutions_flat  \
# 0  Sarzi, M.; Iodice, E.; Coccato, L.; Corsini, E...              None
# 1          Magne Mogstad; CN Brinch; Matthew Wiswall              None
# 2                                   Zenkevich, Yegor              None
# 3  Zhao, Dong; Wang, Shuang; Zang, Qi; Jiao, Lich...              None
# 4                                Witzke, Heinz Peter              None
#
#   countries_flat                                     relations_json  \
# 0           None  [{"relatedIdentifier": "10.1051/0004-6361/2018...
# 1           None                                               None
# 2           None                                                 []
# 3           None                                                 []
# 4           None                                                 []
#
#   version_label                is_version_of               is_preprint_of  \
# 0             1  10.1051/0004-6361/201833137  10.1051/0004-6361/201833137
# 1          None                         None                         None
# 2             2                         None
# 3             1                         None
# 4          None                         None
#
#   has_preprint has_review has_published_version  published_version_ids_json  \
# 0                                          true                        <NA>
# 1         None       None                  None                        <NA>
# 2                                         false                        <NA>
# 3                                         false                        <NA>
# 4                                         false                        <NA>
#
#    version_of_ids_json update_to_json  \
# 0                 <NA>           None
# 1                 <NA>           None
# 2                 <NA>           None
# 3                 <NA>           None
# 4                 <NA>           None
#
#                               raw_relationships_json records_hierarchy  \
# 0  {"client": {"data": {"id": "arxiv.content", "t...            parent
# 1                                               None            parent
# 2  {"client": {"data": {"id": "arxiv.content", "t...            parent
# 3  {"client": {"data": {"id": "arxiv.content", "t...            parent
# 4  {"client": {"data": {"id": "tind.agecon", "typ...            parent
#
#   date_first_seen  publication_year  publication_year_first_seen  \
# 0      2018-04-18            2018.0                         2018
# 1      2013-01-01            2013.0                         2013
# 2      2017-12-29            2017.0                         2017
# 3      2024-06-10            2024.0                         2024
# 4      1998-01-01            1998.0                         1998
#
#                                            raw_dates records_hierarchy_backup  \
# 0  [{"date": "2018-04-18T15:53:42Z", "dateInforma...                   parent
# 1                                               None                   parent
# 2  [{"date": "2017-12-29T18:24:11Z", "dateInforma...                   parent
# 3  [{"date": "2024-06-10T21:44:52Z", "dateInforma...                   parent
# 4           [{"date": "1998", "dateType": "Issued"}]                   parent
#
#   parent_record_id dup_group_id authors_fp_tokenbag  \
# 0             None         None                None
# 1             None         None                None
# 2             None         None     yegor_zenkevich
# 3             None         None                None
# 4             None         None  heinz_peter_witzke
#
#                                       title_clean_v2 authors_fp_last_initial  \
# 0                                               None                    None
# 1                                               None                    None
# 2  3d field theory plane partitions and triple ma...             zenkevich|y
# 3                                               None                    None
# 4  wilhelm brandes guido recke thomas berger prod...                witzke|h
#
#   authors_fp_last records_hierarchy_dedupe_backup  \
# 0            None                          parent
# 1            None                          parent
# 2            None                          parent
# 3            None                          parent
# 4            None                          parent
#
#   parent_record_id_dedupe_backup dup_group_id_dedupe_backup  \
# 0                           None                       None
# 1                           None                       None
# 2                           None                       None
# 3                           None                       None
# 4                           None                       None
#
#               has_version_dois records_hierarchy_unify_version_backup  \
# 0  10.1051/0004-6361/201833137                                 parent
# 1                         None                                 parent
# 2                         None                                 parent
# 3                         None                                 parent
# 4                         None                                 parent
#
#   parent_record_id_unify_version_backup dup_group_id_unify_version_backup  \
# 0                                  None                              None
# 1                                  None                              None
# 2                                  None                              None
# 3                                  None                              None
# 4                                  None                              None
#
#                      dup_group_id_full         dt  rid_num  \
# 0  datacite::10.48550/arxiv.1804.06795 2018-04-18     <NA>
# 1                openalex::W1487526705 2013-01-01     <NA>
# 2  datacite::10.48550/arxiv.1712.10300 2017-12-29     <NA>
# 3  datacite::10.48550/arxiv.2406.06813 2024-06-10     <NA>
# 4    datacite::10.22004/ag.econ.301720 1998-01-01     <NA>
#
#                    doi_clean                         server_clean  \
# 0  10.48550/arxiv.1804.06795                                arXiv
# 1                       None  RePEc: Research Papers in Economics
# 2  10.48550/arxiv.1712.10300                                arXiv
# 3  10.48550/arxiv.2406.06813                                arXiv
# 4    10.22004/ag.econ.301720                        AgEcon Search
#
#              parent_record_id_selected          parent_server_name_selected  \
# 0  datacite::10.48550/arxiv.1804.06795                                arXiv
# 1                openalex::W1487526705  RePEc: Research Papers in Economics
# 2  datacite::10.48550/arxiv.1712.10300                                arXiv
# 3  datacite::10.48550/arxiv.2406.06813                                arXiv
# 4    datacite::10.22004/ag.econ.301720                        AgEcon Search
#
#          parent_doi_selected                             parent_url_selected  \
# 0  10.48550/arxiv.1804.06795                https://arxiv.org/abs/1804.06795
# 1                       None  https://discovery.ucl.ac.uk/id/eprint/1413809/
# 2  10.48550/arxiv.1712.10300                https://arxiv.org/abs/1712.10300
# 3  10.48550/arxiv.2406.06813                https://arxiv.org/abs/2406.06813
# 4    10.22004/ag.econ.301720      https://ageconsearch.umn.edu/record/301720
#
#                                parent_title_selected  \
# 0  The Fornax3D project: overall goals, galaxy sa...
# 1  Beyond LATE with a discrete instrument: Hetero...
# 2  3d field theory, plane partitions and triple M...
# 3  Stable Neighbor Denoising for Source-free Doma...
# 4  Wilhelm Brandes, Guido Recke, Thomas Berger - ...
#
#                              parent_authors_selected parent_date_selected  \
# 0  Sarzi, M.; Iodice, E.; Coccato, L.; Corsini, E...           2018-04-18
# 1          Magne Mogstad; CN Brinch; Matthew Wiswall           2013-01-01
# 2                                   Zenkevich, Yegor           2017-12-29
# 3  Zhao, Dong; Wang, Shuang; Zang, Qi; Jiao, Lich...           2024-06-10
# 4                                Witzke, Heinz Peter           1998-01-01
#
#   parent_year_selected  is_parent_selected  group_size
# 0                 2018                True           1
# 1                 2013                True           1
# 2                 2017                True           1
# 3                 2024                True           1
# 4                 1998                True           1
