# %%
import pandas as pd
# Set option to display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# # import data

# %%
data = pd.read_pickle("outputs_new/dedupe_data_group_merge.pkl")
data
# Out:
#                                record_id     server_name   backend  \
# 0        crossref::10.21467/preprints.48  AIJR Preprints  crossref
# 1        crossref::10.21467/preprints.43  AIJR Preprints  crossref
# 2        crossref::10.21467/preprints.39  AIJR Preprints  crossref
# 3        crossref::10.21467/preprints.38  AIJR Preprints  crossref
# 4        crossref::10.21467/preprints.36  AIJR Preprints  crossref
# ...                                  ...             ...       ...
# 8084855             openalex::W999325625           viXra  openalex
# 8084856             openalex::W999460032           viXra  openalex
# 8084857              openalex::W99967155           viXra  openalex
# 8084858             openalex::W999790414           viXra  openalex
# 8084859             openalex::W999805801           viXra  openalex
#
#                            doi                                doi_url  \
# 0        10.21467/preprints.48  https://doi.org/10.21467/preprints.48
# 1        10.21467/preprints.43  https://doi.org/10.21467/preprints.43
# 2        10.21467/preprints.39  https://doi.org/10.21467/preprints.39
# 3        10.21467/preprints.38  https://doi.org/10.21467/preprints.38
# 4        10.21467/preprints.36  https://doi.org/10.21467/preprints.36
# ...                        ...                                    ...
# 8084855                   None                                   None
# 8084856                   None                                   None
# 8084857                   None                                   None
# 8084858                   None                                   None
# 8084859                   None                                   None
#
#                                           landing_page_url  \
# 0        https://preprints.aijr.org/index.php/ap/prepri...
# 1        https://preprints.aijr.org/index.php/ap/prepri...
# 2        https://preprints.aijr.org/index.php/ap/prepri...
# 3        https://preprints.aijr.org/index.php/ap/prepri...
# 4        https://preprints.aijr.org/index.php/ap/prepri...
# ...                                                    ...
# 8084855              https://vixra.org/pdf/1409.0090v1.pdf
# 8084856                    https://vixra.org/abs/1112.0094
# 8084857              https://vixra.org/pdf/1406.0019v1.pdf
# 8084858              https://vixra.org/pdf/1306.0105v3.pdf
# 8084859              https://vixra.org/pdf/1412.0197v3.pdf
#
#                                                      title  \
# 0        Bird’s Eye View on the Diagnosis, Treatment, &...
# 1        Doxycycline and Minocycline Drugs as a Treatme...
# 2        A Genetic Perspective of 2019-nCoV in Relation...
# 3        Marine Algae as a Natural Source for Antiviral...
# 4        Possible Prevention of COVID 19 by Using Linol...
# ...                                                    ...
# 8084855                 Three Objections to Modern Physics
# 8084856                               Particle Mass Ratios
# 8084857  Quantum FFF Theory Proposals for Some Unsolved...
# 8084858  Investigation of the Formalism of Particle Dyn...
# 8084859  Electromagnetic Energy and Electromagnetic For...
#
#                                               authors_flat institutions_flat  \
# 0                              Panchalingala, Sai Bhargavi              None
# 1                                         Mostafa, Mohamed              None
# 2                                        Dasgupta, Rimjhim              None
# 3        Musale, Amar S; G., Raja Krishna Kumar; Sapre,...              None
# 4        Subhash, Venkata; G, Raja Krishna Kumar; Sapre...              None
# ...                                                    ...               ...
# 8084855                                      Lubomir Vlcek              None
# 8084856                                         DT Froedge              None
# 8084857                                           Leo Vuyk              None
# 8084858                                        Chi-Yi Chen              None
# 8084859                                    Yu.A. Spirichev              None
#
#         countries_flat relations_json version_label is_version_of  \
# 0                 None           None          None
# 1                 None           None          None
# 2                 None           None          None
# 3                 None           None          None
# 4                 None           None          None
# ...                ...            ...           ...           ...
# 8084855           None           None          None          None
# 8084856           None           None          None          None
# 8084857           None           None          None          None
# 8084858           None           None          None          None
# 8084859           None           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 0                                                              false
# 1                                                              false
# 2                                                              false
# 3                                                              false
# 4                                                              false
# ...                ...          ...        ...                   ...
# 8084855           None         None       None                  None
# 8084856           None         None       None                  None
# 8084857           None         None       None                  None
# 8084858           None         None       None                  None
# 8084859           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 0                             None                None           None
# 1                             None                None           None
# 2                             None                None           None
# 3                             None                None           None
# 4                             None                None           None
# ...                            ...                 ...            ...
# 8084855                       None                None           None
# 8084856                       None                None           None
# 8084857                       None                None           None
# 8084858                       None                None           None
# 8084859                       None                None           None
#
#         raw_relationships_json records_hierarchy date_first_seen  \
# 0                         None            parent      2020-05-03
# 1                         None            parent      2020-04-25
# 2                         None            parent      2020-04-16
# 3                         None            parent      2020-04-15
# 4                         None            parent      2020-04-15
# ...                        ...               ...             ...
# 8084855                   None            parent      2014-09-01
# 8084856                   None            parent      2011-12-01
# 8084857                   None            parent      2014-06-01
# 8084858                   None            parent      2013-06-01
# 8084859                   None            parent      2014-12-01
#
#          publication_year_first_seen records_hierarchy_backup  \
# 0                               2020                   parent
# 1                               2020                   parent
# 2                               2020                   parent
# 3                               2020                   parent
# 4                               2020                   parent
# ...                              ...                      ...
# 8084855                         2014                   parent
# 8084856                         2011                   parent
# 8084857                         2014                   parent
# 8084858                         2013                   parent
# 8084859                         2014                   parent
#
#         parent_record_id dup_group_id authors_fp_tokenbag  \
# 0                   None         None                None
# 1                   None         None     mohamed_mostafa
# 2                   None         None    dasgupta_rimjhim
# 3                   None         None                None
# 4                   None         None                None
# ...                  ...          ...                 ...
# 8084855             None         None       lubomir_vlcek
# 8084856             None         None          dt_froedge
# 8084857             None         None            leo_vuyk
# 8084858             None         None         chen_chi_yi
# 8084859             None         None      a_spirichev_yu
#
#                                             title_clean_v2  \
# 0                                                     None
# 1        doxycycline and minocycline drugs as a treatme...
# 2        a genetic perspective of 2019 ncov in relation...
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 8084855                 three objections to modern physics
# 8084856                               particle mass ratios
# 8084857  quantum fff theory proposals for some unsolved...
# 8084858  investigation of the formalism of particle dyn...
# 8084859  electromagnetic energy and electromagnetic for...
#
#         authors_fp_last_initial authors_fp_last  \
# 0                          None            None
# 1                     mostafa|m            None
# 2                    dasgupta|r            None
# 3                          None            None
# 4                          None            None
# ...                         ...             ...
# 8084855                 vlcek|l            None
# 8084856               froedge|d            None
# 8084857                  vuyk|l            None
# 8084858                  chen|c            None
# 8084859             spirichev|y            None
#
#         records_hierarchy_dedupe_backup parent_record_id_dedupe_backup  \
# 0                                parent                           None
# 1                                parent                           None
# 2                                parent                           None
# 3                                parent                           None
# 4                                parent                           None
# ...                                 ...                            ...
# 8084855                          parent                           None
# 8084856                          parent                           None
# 8084857                          parent                           None
# 8084858                          parent                           None
# 8084859                          parent                           None
#
#         dup_group_id_dedupe_backup records_hierarchy_unify_version_backup  \
# 0                             None                                 parent
# 1                             None                                 parent
# 2                             None                                 parent
# 3                             None                                 parent
# 4                             None                                 parent
# ...                            ...                                    ...
# 8084855                       None                                 parent
# 8084856                       None                                 parent
# 8084857                       None                                 parent
# 8084858                       None                                 parent
# 8084859                       None                                 parent
#
#         parent_record_id_unify_version_backup  \
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# ...                                       ...
# 8084855                                  None
# 8084856                                  None
# 8084857                                  None
# 8084858                                  None
# 8084859                                  None
#
#         dup_group_id_unify_version_backup
# 0                                    None
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# ...                                   ...
# 8084855                              None
# 8084856                              None
# 8084857                              None
# 8084858                              None
# 8084859                              None
#
# [8084860 rows x 37 columns]

# %%
data['records_hierarchy'].value_counts()
# Out:
# records_hierarchy
# parent                                            7467120
# parent - duplicate (SSRN)                          135606
# parent - duplicate (Zenodo)                         98767
# parent - duplicate (arXiv)                          85008
# parent - duplicate (Research Square)                59931
#                                                    ...
# parent - duplicate (SAE Mobilus®)                       1
# parent - duplicate (Therapoid)                          1
# parent - duplicate (WikiJournal of Humanities)          1
# parent - duplicate (WikiJournal of Science)             1
# parent - duplicate (searchRxiv)                         1
# Name: count, Length: 109, dtype: int64

# %%
data[data['dup_group_id'].isna()]
# Out:
#                                record_id     server_name   backend  \
# 0        crossref::10.21467/preprints.48  AIJR Preprints  crossref
# 1        crossref::10.21467/preprints.43  AIJR Preprints  crossref
# 2        crossref::10.21467/preprints.39  AIJR Preprints  crossref
# 3        crossref::10.21467/preprints.38  AIJR Preprints  crossref
# 4        crossref::10.21467/preprints.36  AIJR Preprints  crossref
# ...                                  ...             ...       ...
# 8084855             openalex::W999325625           viXra  openalex
# 8084856             openalex::W999460032           viXra  openalex
# 8084857              openalex::W99967155           viXra  openalex
# 8084858             openalex::W999790414           viXra  openalex
# 8084859             openalex::W999805801           viXra  openalex
#
#                            doi                                doi_url  \
# 0        10.21467/preprints.48  https://doi.org/10.21467/preprints.48
# 1        10.21467/preprints.43  https://doi.org/10.21467/preprints.43
# 2        10.21467/preprints.39  https://doi.org/10.21467/preprints.39
# 3        10.21467/preprints.38  https://doi.org/10.21467/preprints.38
# 4        10.21467/preprints.36  https://doi.org/10.21467/preprints.36
# ...                        ...                                    ...
# 8084855                   None                                   None
# 8084856                   None                                   None
# 8084857                   None                                   None
# 8084858                   None                                   None
# 8084859                   None                                   None
#
#                                           landing_page_url  \
# 0        https://preprints.aijr.org/index.php/ap/prepri...
# 1        https://preprints.aijr.org/index.php/ap/prepri...
# 2        https://preprints.aijr.org/index.php/ap/prepri...
# 3        https://preprints.aijr.org/index.php/ap/prepri...
# 4        https://preprints.aijr.org/index.php/ap/prepri...
# ...                                                    ...
# 8084855              https://vixra.org/pdf/1409.0090v1.pdf
# 8084856                    https://vixra.org/abs/1112.0094
# 8084857              https://vixra.org/pdf/1406.0019v1.pdf
# 8084858              https://vixra.org/pdf/1306.0105v3.pdf
# 8084859              https://vixra.org/pdf/1412.0197v3.pdf
#
#                                                      title  \
# 0        Bird’s Eye View on the Diagnosis, Treatment, &...
# 1        Doxycycline and Minocycline Drugs as a Treatme...
# 2        A Genetic Perspective of 2019-nCoV in Relation...
# 3        Marine Algae as a Natural Source for Antiviral...
# 4        Possible Prevention of COVID 19 by Using Linol...
# ...                                                    ...
# 8084855                 Three Objections to Modern Physics
# 8084856                               Particle Mass Ratios
# 8084857  Quantum FFF Theory Proposals for Some Unsolved...
# 8084858  Investigation of the Formalism of Particle Dyn...
# 8084859  Electromagnetic Energy and Electromagnetic For...
#
#                                               authors_flat institutions_flat  \
# 0                              Panchalingala, Sai Bhargavi              None
# 1                                         Mostafa, Mohamed              None
# 2                                        Dasgupta, Rimjhim              None
# 3        Musale, Amar S; G., Raja Krishna Kumar; Sapre,...              None
# 4        Subhash, Venkata; G, Raja Krishna Kumar; Sapre...              None
# ...                                                    ...               ...
# 8084855                                      Lubomir Vlcek              None
# 8084856                                         DT Froedge              None
# 8084857                                           Leo Vuyk              None
# 8084858                                        Chi-Yi Chen              None
# 8084859                                    Yu.A. Spirichev              None
#
#         countries_flat relations_json version_label is_version_of  \
# 0                 None           None          None
# 1                 None           None          None
# 2                 None           None          None
# 3                 None           None          None
# 4                 None           None          None
# ...                ...            ...           ...           ...
# 8084855           None           None          None          None
# 8084856           None           None          None          None
# 8084857           None           None          None          None
# 8084858           None           None          None          None
# 8084859           None           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 0                                                              false
# 1                                                              false
# 2                                                              false
# 3                                                              false
# 4                                                              false
# ...                ...          ...        ...                   ...
# 8084855           None         None       None                  None
# 8084856           None         None       None                  None
# 8084857           None         None       None                  None
# 8084858           None         None       None                  None
# 8084859           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 0                             None                None           None
# 1                             None                None           None
# 2                             None                None           None
# 3                             None                None           None
# 4                             None                None           None
# ...                            ...                 ...            ...
# 8084855                       None                None           None
# 8084856                       None                None           None
# 8084857                       None                None           None
# 8084858                       None                None           None
# 8084859                       None                None           None
#
#         raw_relationships_json records_hierarchy date_first_seen  \
# 0                         None            parent      2020-05-03
# 1                         None            parent      2020-04-25
# 2                         None            parent      2020-04-16
# 3                         None            parent      2020-04-15
# 4                         None            parent      2020-04-15
# ...                        ...               ...             ...
# 8084855                   None            parent      2014-09-01
# 8084856                   None            parent      2011-12-01
# 8084857                   None            parent      2014-06-01
# 8084858                   None            parent      2013-06-01
# 8084859                   None            parent      2014-12-01
#
#          publication_year_first_seen records_hierarchy_backup  \
# 0                               2020                   parent
# 1                               2020                   parent
# 2                               2020                   parent
# 3                               2020                   parent
# 4                               2020                   parent
# ...                              ...                      ...
# 8084855                         2014                   parent
# 8084856                         2011                   parent
# 8084857                         2014                   parent
# 8084858                         2013                   parent
# 8084859                         2014                   parent
#
#         parent_record_id dup_group_id authors_fp_tokenbag  \
# 0                   None         None                None
# 1                   None         None     mohamed_mostafa
# 2                   None         None    dasgupta_rimjhim
# 3                   None         None                None
# 4                   None         None                None
# ...                  ...          ...                 ...
# 8084855             None         None       lubomir_vlcek
# 8084856             None         None          dt_froedge
# 8084857             None         None            leo_vuyk
# 8084858             None         None         chen_chi_yi
# 8084859             None         None      a_spirichev_yu
#
#                                             title_clean_v2  \
# 0                                                     None
# 1        doxycycline and minocycline drugs as a treatme...
# 2        a genetic perspective of 2019 ncov in relation...
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 8084855                 three objections to modern physics
# 8084856                               particle mass ratios
# 8084857  quantum fff theory proposals for some unsolved...
# 8084858  investigation of the formalism of particle dyn...
# 8084859  electromagnetic energy and electromagnetic for...
#
#         authors_fp_last_initial authors_fp_last  \
# 0                          None            None
# 1                     mostafa|m            None
# 2                    dasgupta|r            None
# 3                          None            None
# 4                          None            None
# ...                         ...             ...
# 8084855                 vlcek|l            None
# 8084856               froedge|d            None
# 8084857                  vuyk|l            None
# 8084858                  chen|c            None
# 8084859             spirichev|y            None
#
#         records_hierarchy_dedupe_backup parent_record_id_dedupe_backup  \
# 0                                parent                           None
# 1                                parent                           None
# 2                                parent                           None
# 3                                parent                           None
# 4                                parent                           None
# ...                                 ...                            ...
# 8084855                          parent                           None
# 8084856                          parent                           None
# 8084857                          parent                           None
# 8084858                          parent                           None
# 8084859                          parent                           None
#
#         dup_group_id_dedupe_backup records_hierarchy_unify_version_backup  \
# 0                             None                                 parent
# 1                             None                                 parent
# 2                             None                                 parent
# 3                             None                                 parent
# 4                             None                                 parent
# ...                            ...                                    ...
# 8084855                       None                                 parent
# 8084856                       None                                 parent
# 8084857                       None                                 parent
# 8084858                       None                                 parent
# 8084859                       None                                 parent
#
#         parent_record_id_unify_version_backup  \
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# ...                                       ...
# 8084855                                  None
# 8084856                                  None
# 8084857                                  None
# 8084858                                  None
# 8084859                                  None
#
#         dup_group_id_unify_version_backup
# 0                                    None
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# ...                                   ...
# 8084855                              None
# 8084856                              None
# 8084857                              None
# 8084858                              None
# 8084859                              None
#
# [6971456 rows x 37 columns]

# %%
data["dup_group_id"] = (
    data["dup_group_id"]
    .astype("string")
    .str.strip()
    .replace("", pd.NA)
    .fillna(data["record_id"])
)

# %%
data[data['dup_group_id'].isna()]
# Out:
# Empty DataFrame
# Columns: [record_id, server_name, backend, doi, doi_url, landing_page_url, title, authors_flat, institutions_flat, countries_flat, relations_json, version_label, is_version_of, is_preprint_of, has_preprint, has_review, has_published_version, published_version_ids_json, version_of_ids_json, update_to_json, raw_relationships_json, records_hierarchy, date_first_seen, publication_year_first_seen, records_hierarchy_backup, parent_record_id, dup_group_id, authors_fp_tokenbag, title_clean_v2, authors_fp_last_initial, authors_fp_last, records_hierarchy_dedupe_backup, parent_record_id_dedupe_backup, dup_group_id_dedupe_backup, records_hierarchy_unify_version_backup, parent_record_id_unify_version_backup, dup_group_id_unify_version_backup]
# Index: []

# %%
data['has_published_version'].value_counts()
# Out:
# has_published_version
# false    4537462
# true     1846125
# Name: count, dtype: int64

# %%
data['published_version_ids_json'].value_counts()

# %%
data['is_preprint_of'].value_counts()
# Out:
# is_preprint_of
#                                   4537462
# 10.5281/zenodo.17226274               410
# 10.5281/zenodo.15583046               384
# 10.31237/osf.io/yr86k                 373
# 10.5281/zenodo.15832876               293
#                                    ...
# 10.1038/s41535-018-0136-x               1
# 10.1088/1751-8121/aae65c                1
# 10.1007/s00220-019-03356-0              1
# 10.1007/s00010-018-0633-9               1
# 10.1103/physrevlett.121.221101          1
# Name: count, Length: 1766090, dtype: int64

# %%
data['is_version_of'].value_counts()
# Out:
# is_version_of
#                                     6295224
# 10.2139/ssrn.2721313                    152
# 10.5281/zenodo.16899882                  73
# 10.5281/zenodo.15408957                  50
# 10.5281/zenodo.16944712                  29
#                                      ...
# 10.20944/preprints202407.1296.v1          1
# 10.20944/preprints202407.1220.v1          1
# 10.20944/preprints202407.1200.v1          1
# 10.20944/preprints202407.0147.v1          1
# 10.20944/preprints202409.0055.v1          1
# Name: count, Length: 81607, dtype: int64

# %% [markdown]
# # Build the 3 core files for preprint tracker

# %%
from __future__ import annotations

from pathlib import Path
from typing import Optional, Tuple, Dict
import pandas as pd
import numpy as np


def generate_tracker_files_from_dedupe(
    df: pd.DataFrame,
    out_dir: str | Path = "outputs/tracker_data",
    *,
    # core cols
    server_col: str = "server_name",
    record_id_col: str = "record_id",
    group_id_col: str = "dup_group_id",
    hierarchy_col: str = "records_hierarchy",
    date_col: str = "date_first_seen",
    year_col: str = "publication_year_first_seen",
    has_published_col: str = "has_published_version",
    source_col: Optional[str] = None,  # if you have it; else will be omitted

    # outputs
    write_csv: bool = True,
    write_xlsx: bool = False,
    return_frames: bool = True,
) -> Tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame, Dict]:
    """
    Build the 3 core files your Streamlit tracker can consume, from a deduped long table:
      1) summary.csv   (one row per server_name)
      2) yearly.csv    (wide or long? -> we export wide by default, plus long)
      3) clusters_summary.csv (one row per dup_group_id)

    Important modeling choices:
      - n_records: record-level count (raw harvested rows)
      - n_unique:  cluster-level count (nunique dup_group_id)
      - versions:  cluster-level count where cluster_size > 1
      - published: cluster-level count where any record in cluster has has_published_version=True
      - yearly:    computed using *parent* rows only (avoid double counting versions)

    Returns:
      summary_df, yearly_wide_df, clusters_summary_df, metrics
    """
    out_dir = Path(out_dir)
    out_dir.mkdir(parents=True, exist_ok=True)

    required = [server_col, record_id_col, group_id_col]
    missing = [c for c in required if c not in df.columns]
    if missing:
        raise ValueError(f"Missing required columns: {missing}")

    work = df.copy()

    # ---- clean basics
    work[server_col] = work[server_col].astype("string").fillna("").str.strip()
    work[group_id_col] = work[group_id_col].astype("string").fillna("").str.strip()
    work[record_id_col] = work[record_id_col].astype("string").fillna("").str.strip()

    # drop rows with empty server or group id (cannot aggregate reliably)
    work = work[(work[server_col] != "") & (work[group_id_col] != "")].copy()

    # ---- normalize has_published to bool (if exists)
    if has_published_col in work.columns:
        hp = work[has_published_col]
        # accept True/False, 1/0, "true"/"false"
        work[has_published_col] = (
            hp.astype("string")
              .str.lower()
              .map({"true": True, "false": False, "1": True, "0": False})
              .where(~hp.isna(), other=np.nan)
        )
        # if original was already boolean/numeric, above may produce NaN; fallback:
        work[has_published_col] = pd.to_numeric(hp, errors="ignore") if work[has_published_col].isna().all() else work[has_published_col]
        # final coercion
        work[has_published_col] = work[has_published_col].fillna(False).astype(bool)
    else:
        work[has_published_col] = False

    # ---- parse date/year
    if date_col in work.columns:
        work[date_col] = pd.to_datetime(work[date_col], errors="coerce")
    else:
        work[date_col] = pd.NaT

    if year_col in work.columns:
        y = pd.to_numeric(work[year_col], errors="coerce")
        work[year_col] = y.where((y >= 1000) & (y <= 3000)).round().astype("Int64")
    else:
        work[year_col] = pd.NA

    # =========================================================
    # 1) clusters_summary (one row per dup_group_id)
    # =========================================================
    # cluster_size
    cluster_size = work.groupby(group_id_col, as_index=True).size().rename("cluster_size")

    # number of servers per cluster
    n_servers = work.groupby(group_id_col)[server_col].nunique().rename("n_servers")

    # cluster has published (any record in cluster)
    cluster_has_published = work.groupby(group_id_col)[has_published_col].any().rename("cluster_has_published")

    # Determine a "cluster parent" row:
    # Prefer rows labeled 'parent' in records_hierarchy; if missing, fallback to earliest date then record_id.
    if hierarchy_col in work.columns:
        h = work[hierarchy_col].astype("string").fillna("").str.lower().str.strip()
        is_parent = h.eq("parent")
    else:
        is_parent = pd.Series(False, index=work.index)

    parents = work[is_parent].copy()
    if parents.empty:
        # fallback: earliest row per cluster
        tmp = work.sort_values([group_id_col, date_col, record_id_col], ascending=[True, True, True], na_position="last")
        parents = tmp.groupby(group_id_col, sort=False).head(1).copy()
    else:
        # if a cluster has multiple 'parent' rows (shouldn't, but can happen), pick earliest
        parents = parents.sort_values([group_id_col, date_col, record_id_col], ascending=[True, True, True], na_position="last")
        parents = parents.groupby(group_id_col, sort=False).head(1).copy()

    # Build clusters summary frame
    clusters_summary = (
        parents[[group_id_col, record_id_col, server_col, date_col, year_col]]
        .rename(columns={
            record_id_col: "parent_record_id",
            server_col: "parent_server_name",
            date_col: "parent_date_first_seen",
            year_col: "parent_year_first_seen",
        })
        .set_index(group_id_col)
        .join(cluster_size)
        .join(n_servers)
        .join(cluster_has_published)
        .reset_index()
    )

    clusters_summary["has_versions"] = clusters_summary["cluster_size"] > 1
    clusters_summary["is_cross_server"] = clusters_summary["n_servers"] > 1

    # =========================================================
    # 2) summary (one row per server)
    # =========================================================
    # record-level counts
    n_records = work.groupby(server_col)[record_id_col].count().rename("n_records")

    # cluster-level unique count by server (a cluster may touch many servers; this is "server participation")
    n_unique = work.groupby(server_col)[group_id_col].nunique().rename("n_unique")

    # cluster-level versions by server (clusters with cluster_size>1 that have at least one record in server)
    version_clusters = set(clusters_summary.loc[clusters_summary["has_versions"], group_id_col].astype(str))
    published_clusters = set(clusters_summary.loc[clusters_summary["cluster_has_published"], group_id_col].astype(str))

    n_is_version_of = (
        work[work[group_id_col].isin(version_clusters)]
        .groupby(server_col)[group_id_col].nunique()
        .rename("n_is_version_of")
    )

    n_published = (
        work[work[group_id_col].isin(published_clusters)]
        .groupby(server_col)[group_id_col].nunique()
        .rename("n_published")
    )

    summary = (
        pd.concat([n_records, n_unique, n_is_version_of, n_published], axis=1)
          .fillna(0)
          .reset_index()
          .rename(columns={server_col: "server_name"})
    )

    summary["pct_published"] = np.where(
        summary["n_unique"] > 0,
        (summary["n_published"] / summary["n_unique"]) * 100.0,
        np.nan,
    )

    # optional: add source column if provided
    if source_col and source_col in df.columns:
        # take the most frequent source per server
        tmp = df[[server_col, source_col]].copy()
        tmp[server_col] = tmp[server_col].astype("string").fillna("").str.strip()
        tmp[source_col] = tmp[source_col].astype("string").fillna("").str.strip()
        mode_source = (
            tmp.groupby(server_col)[source_col]
               .agg(lambda x: x.value_counts().index[0] if len(x.dropna()) else "")
               .rename("source")
               .reset_index()
               .rename(columns={server_col: "server_name"})
        )
        summary = summary.merge(mode_source, on="server_name", how="left")

    summary["collection_date"] = pd.Timestamp.utcnow().date().isoformat()

    # =========================================================
    # 3) yearly (use *parents* only to avoid double counting)
    # =========================================================
    # Use parent server as the server for yearly counts (recommended).
    parents_for_yearly = clusters_summary.copy()
    parents_for_yearly = parents_for_yearly.dropna(subset=["parent_year_first_seen"])
    parents_for_yearly["parent_year_first_seen"] = parents_for_yearly["parent_year_first_seen"].astype("Int64")

    yearly_long = (
        parents_for_yearly.groupby(["parent_server_name", "parent_year_first_seen"], as_index=False)[group_id_col]
        .nunique()
        .rename(columns={
            "parent_server_name": "server_name",
            "parent_year_first_seen": "year",
            group_id_col: "count",
        })
        .sort_values(["server_name", "year"])
    )

    # Wide format (one row per server, year columns) — matches your app’s cleaner
    yearly_wide = (
        yearly_long.pivot_table(index="server_name", columns="year", values="count", aggfunc="sum", fill_value=0)
        .reset_index()
    )
    yearly_wide.columns = [str(c) for c in yearly_wide.columns]

    # Also add count_2024 / count_2025 to summary if present
    if "2024" in yearly_wide.columns:
        summary = summary.merge(yearly_wide[["server_name", "2024"]].rename(columns={"2024": "count_2024"}), on="server_name", how="left")
    else:
        summary["count_2024"] = 0
    if "2025" in yearly_wide.columns:
        summary = summary.merge(yearly_wide[["server_name", "2025"]].rename(columns={"2025": "count_2025"}), on="server_name", how="left")
    else:
        summary["count_2025"] = 0

    # =========================================================
    # Metrics (quick QA)
    # =========================================================
    metrics = {
        "rows_in_input": int(len(df)),
        "rows_used": int(len(work)),
        "n_servers": int(work[server_col].nunique()),
        "n_clusters": int(clusters_summary[group_id_col].nunique()),
        "clusters_with_versions": int(clusters_summary["has_versions"].sum()),
        "clusters_with_published": int(clusters_summary["cluster_has_published"].sum()),
        "cross_server_clusters": int(clusters_summary["is_cross_server"].sum()),
        "year_min": int(yearly_long["year"].min()) if len(yearly_long) else None,
        "year_max": int(yearly_long["year"].max()) if len(yearly_long) else None,
        "out_dir": str(out_dir),
    }

    # =========================================================
    # Write files
    # =========================================================
    if write_csv:
        summary.to_csv(out_dir / "summary.csv", index=False)
        yearly_wide.to_csv(out_dir / "yearly.csv", index=False)       # app expects wide-ish
        yearly_long.to_csv(out_dir / "yearly_long.csv", index=False) # useful for QA
        clusters_summary.to_csv(out_dir / "clusters_summary.csv", index=False)

        pd.DataFrame([metrics]).to_json(out_dir / "build_metrics.json", orient="records", indent=2)

    if write_xlsx:
        with pd.ExcelWriter(out_dir / "tracker_outputs.xlsx", engine="openpyxl") as xw:
            summary.to_excel(xw, sheet_name="summary", index=False)
            yearly_wide.to_excel(xw, sheet_name="yearly_wide", index=False)
            yearly_long.to_excel(xw, sheet_name="yearly_long", index=False)
            clusters_summary.to_excel(xw, sheet_name="clusters_summary", index=False)
            pd.DataFrame([metrics]).to_excel(xw, sheet_name="metrics", index=False)

    if return_frames:
        return summary, yearly_wide, clusters_summary, metrics

    return summary, yearly_wide, clusters_summary, metrics  # keep signature stable


# -------------------------
# Example usage
# -------------------------
# summary_df, yearly_df, clusters_df, build_metrics = generate_tracker_files_from_dedupe(
#     dedupe_clusters_long,
#     out_dir="outputs/tracker_data",
#     write_csv=True,
#     write_xlsx=False,
# )
# print(build_metrics)

# %%
summary_df, yearly_df, clusters_df, build_metrics = generate_tracker_files_from_dedupe(
    data,
    hierarchy_col = "records_hierarchy",
    out_dir="outputs_new/tracker_data",
    write_csv=True,
    write_xlsx=False,
)
print(build_metrics)
# Out:
# /tmp/ipykernel_12609/760881034.py:75: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   work[has_published_col] = work[has_published_col].fillna(False).astype(bool)
# {'rows_in_input': 8084860, 'rows_used': 8084860, 'n_servers': 112, 'n_clusters': 7467120, 'clusters_with_versions': 485490, 'clusters_with_published': 1758718, 'cross_server_clusters': 194959, 'year_min': 1961, 'year_max': 2025, 'out_dir': 'outputs_new/tracker_data'}

# %% [markdown]
# # exploration

# %%
data_version = data[data['records_hierarchy']=='version']
data_version
# Out:
# Empty DataFrame
# Columns: [record_id, server_name, backend, doi, doi_url, landing_page_url, title, authors_flat, institutions_flat, countries_flat, relations_json, version_label, is_version_of, is_preprint_of, has_preprint, has_review, has_published_version, published_version_ids_json, version_of_ids_json, update_to_json, raw_relationships_json, records_hierarchy, date_first_seen, publication_year_first_seen, records_hierarchy_backup, parent_record_id, dup_group_id, authors_fp_tokenbag, title_clean_v2, authors_fp_last_initial, authors_fp_last, records_hierarchy_dedupe_backup, parent_record_id_dedupe_backup, dup_group_id_dedupe_backup, records_hierarchy_unify_version_backup, parent_record_id_unify_version_backup, dup_group_id_unify_version_backup]
# Index: []

# %%
data_version[data_version['records_hierarchy']=='parent']
# Out:
# Empty DataFrame
# Columns: [record_id, server_name, backend, doi, doi_url, landing_page_url, title, authors_flat, institutions_flat, countries_flat, relations_json, version_label, is_version_of, is_preprint_of, has_preprint, has_review, has_published_version, published_version_ids_json, version_of_ids_json, update_to_json, raw_relationships_json, records_hierarchy, date_first_seen, publication_year_first_seen, records_hierarchy_backup, parent_record_id, dup_group_id, authors_fp_tokenbag, title_clean_v2, authors_fp_last_initial, authors_fp_last, records_hierarchy_dedupe_backup, parent_record_id_dedupe_backup, dup_group_id_dedupe_backup, records_hierarchy_unify_version_backup, parent_record_id_unify_version_backup, dup_group_id_unify_version_backup]
# Index: []

# %%
pattern = "Evaluation of ML methods for online use in th"


mask = data['title'].str.contains(pattern, regex=False, na=False)
result = data[mask]
print(len(result))
result
# Out:
# 1
#                      record_id server_name   backend  \
# 8080999  openalex::W3119327510       viXra  openalex
#
#                                      doi  \
# 8080999  10.6084/m9.figshare.13553642.v3
#
#                                                  doi_url  \
# 8080999  https://doi.org/10.6084/m9.figshare.13553642.v3
#
#                               landing_page_url  \
# 8080999  https://vixra.org/pdf/2101.0032v1.pdf
#
#                                                      title authors_flat  \
# 8080999  Evaluation of ML methods for online use in the...      Liu Hao
#
#         institutions_flat countries_flat relations_json version_label  \
# 8080999              None           None           None          None
#
#         is_version_of is_preprint_of has_preprint has_review  \
# 8080999          None           None         None       None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 8080999                  None                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 8080999           None                   None            parent
#
#         date_first_seen  publication_year_first_seen records_hierarchy_backup  \
# 8080999      2021-01-01                         2021                  version
#
#         parent_record_id dup_group_id authors_fp_tokenbag  \
# 8080999             None         None             hao_liu
#
#                                             title_clean_v2  \
# 8080999  evaluation of ml methods for online use in the...
#
#         authors_fp_last_initial authors_fp_last  \
# 8080999                   hao|l            None
#
#         records_hierarchy_dedupe_backup parent_record_id_dedupe_backup  \
# 8080999                          parent                           None
#
#         dup_group_id_dedupe_backup records_hierarchy_unify_version_backup  \
# 8080999                       None                                 parent
#
#         parent_record_id_unify_version_backup  \
# 8080999                                  None
#
#         dup_group_id_unify_version_backup
# 8080999                              None

# %%
pattern = "Exploring the Relationship of Enrollmen"


mask = data['title'].str.contains(pattern, regex=False, na=False)
result = data[mask]
print(len(result))
result
# Out:
# 3
#                                      record_id     server_name   backend  \
# 190         crossref::10.33774/apsa-2019-nd8n2  APSA Preprints  crossref
# 215      crossref::10.33774/apsa-2019-nd8n2-v2  APSA Preprints  crossref
# 3710568         crossref::10.2139/ssrn.3757559            SSRN  crossref
#
#                                  doi  \
# 190         10.33774/apsa-2019-nd8n2
# 215      10.33774/apsa-2019-nd8n2-v2
# 3710568         10.2139/ssrn.3757559
#
#                                              doi_url  \
# 190         https://doi.org/10.33774/apsa-2019-nd8n2
# 215      https://doi.org/10.33774/apsa-2019-nd8n2-v2
# 3710568         https://doi.org/10.2139/ssrn.3757559
#
#                                           landing_page_url  \
# 190      https://preprints.apsanet.org/engage/apsa/arti...
# 215      https://preprints.apsanet.org/engage/apsa/arti...
# 3710568              https://www.ssrn.com/abstract=3757559
#
#                                                      title  \
# 190      Exploring the Relationship of Enrollment in In...
# 215      Exploring the Relationship of Enrollment in In...
# 3710568  Exploring the Relationship of Enrollment in ID...
#
#                                               authors_flat  \
# 190      Collier, Daniel A.; Fitzpatrick, Dan; Marsican...
# 215      Collier, Daniel A.; Fitzpatrick, Dan; Marsican...
# 3710568  Collier, Daniel; Fitzpatrick, Dan; Marsicano, ...
#
#                                          institutions_flat countries_flat  \
# 190      W.E. Upjohn Institute for Employment Research;...           None
# 215      W.E. Upjohn Institute for Employment Research;...           None
# 3710568                                               None           None
#
#                                             relations_json version_label  \
# 190      {"is-version-of": [{"asserted-by": "subject", ...          None
# 215      {"is-version-of": [{"asserted-by": "subject", ...          None
# 3710568                                               None          None
#
#                        is_version_of is_preprint_of has_preprint has_review  \
# 190      10.33774/apsa-2019-nd8n2-v2
# 215         10.33774/apsa-2019-nd8n2
# 3710568
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 190                     false                       None                None
# 215                     false                       None                None
# 3710568                 false                       None                None
#
#         update_to_json raw_relationships_json  \
# 190               None                   None
# 215               None                   None
# 3710568           None                   None
#
#                            records_hierarchy date_first_seen  \
# 190                                   parent      2019-10-04
# 215      parent - duplicate (APSA Preprints)      2020-04-06
# 3710568            parent - duplicate (SSRN)      2021-01-08
#
#          publication_year_first_seen records_hierarchy_backup  \
# 190                             2019                  version
# 215                             2020                  version
# 3710568                         2021                   parent
#
#                            parent_record_id  \
# 190                                    <NA>
# 215      crossref::10.33774/apsa-2019-nd8n2
# 3710568  crossref::10.33774/apsa-2019-nd8n2
#
#                                dup_group_id  \
# 190      crossref::10.33774/apsa-2019-nd8n2
# 215      crossref::10.33774/apsa-2019-nd8n2
# 3710568  crossref::10.33774/apsa-2019-nd8n2
#
#                                        authors_fp_tokenbag  \
# 190      a_collier_daniel;christopher_marsicano_r;dan_f...
# 215      a_collier_daniel;christopher_marsicano_r;dan_f...
# 3710568  christopher_marsicano;collier_daniel;dan_fitzp...
#
#                                             title_clean_v2  \
# 190      exploring the relationship of enrollment in in...
# 215      exploring the relationship of enrollment in in...
# 3710568  exploring the relationship of enrollment in id...
#
#                      authors_fp_last_initial authors_fp_last  \
# 190      collier|d;fitzpatrick|d;marsicano|c            None
# 215                                     None            None
# 3710568  collier|d;fitzpatrick|d;marsicano|c            None
#
#              records_hierarchy_dedupe_backup  \
# 190                                   parent
# 215      parent - duplicate (APSA Preprints)
# 3710568  parent - duplicate (APSA Preprints)
#
#              parent_record_id_dedupe_backup  \
# 190                                    None
# 215      crossref::10.33774/apsa-2019-nd8n2
# 3710568  crossref::10.33774/apsa-2019-nd8n2
#
#                                 dup_group_id_dedupe_backup  \
# 190                                   10655472821248023217
# 215                                   10655472821248023217
# 3710568  fuzzy::last_initial::collier|d;fitzpatrick|d;m...
#
#         records_hierarchy_unify_version_backup  \
# 190                                     parent
# 215          parent - duplicate (version-link)
# 3710568    parent - duplicate (APSA Preprints)
#
#         parent_record_id_unify_version_backup  \
# 190                                      None
# 215        crossref::10.33774/apsa-2019-nd8n2
# 3710568    crossref::10.33774/apsa-2019-nd8n2
#
#                          dup_group_id_unify_version_backup
# 190                     crossref::10.33774/apsa-2019-nd8n2
# 215                     crossref::10.33774/apsa-2019-nd8n2
# 3710568  fuzzy::last_initial::collier|d;fitzpatrick|d;m...

# %%
result[['record_id','server_name','records_hierarchy','parent_record_id','dup_group_id','date_first_seen',]]
# Out:
#                                      record_id     server_name  \
# 190         crossref::10.33774/apsa-2019-nd8n2  APSA Preprints
# 215      crossref::10.33774/apsa-2019-nd8n2-v2  APSA Preprints
# 3710568         crossref::10.2139/ssrn.3757559            SSRN
#
#                            records_hierarchy  \
# 190                                   parent
# 215      parent - duplicate (APSA Preprints)
# 3710568            parent - duplicate (SSRN)
#
#                            parent_record_id  \
# 190                                    <NA>
# 215      crossref::10.33774/apsa-2019-nd8n2
# 3710568  crossref::10.33774/apsa-2019-nd8n2
#
#                                dup_group_id date_first_seen
# 190      crossref::10.33774/apsa-2019-nd8n2      2019-10-04
# 215      crossref::10.33774/apsa-2019-nd8n2      2020-04-06
# 3710568  crossref::10.33774/apsa-2019-nd8n2      2021-01-08

# %%
pattern = "Ethnic Autonomy"


mask = data['title'].str.contains(pattern, regex=False, na=False)
result = data[mask]
print(len(result))
result
# Out:
# 5
#                                      record_id     server_name   backend  \
# 185         crossref::10.33774/apsa-2019-25rz9  APSA Preprints  crossref
# 202      crossref::10.33774/apsa-2019-25rz9-v2  APSA Preprints  crossref
# 262      crossref::10.33774/apsa-2019-25rz9-v3  APSA Preprints  crossref
# 3624706         crossref::10.2139/ssrn.1634570            SSRN  crossref
# 4197312         crossref::10.2139/ssrn.5071920            SSRN  crossref
#
#                                  doi  \
# 185         10.33774/apsa-2019-25rz9
# 202      10.33774/apsa-2019-25rz9-v2
# 262      10.33774/apsa-2019-25rz9-v3
# 3624706         10.2139/ssrn.1634570
# 4197312         10.2139/ssrn.5071920
#
#                                              doi_url  \
# 185         https://doi.org/10.33774/apsa-2019-25rz9
# 202      https://doi.org/10.33774/apsa-2019-25rz9-v2
# 262      https://doi.org/10.33774/apsa-2019-25rz9-v3
# 3624706         https://doi.org/10.2139/ssrn.1634570
# 4197312         https://doi.org/10.2139/ssrn.5071920
#
#                                           landing_page_url  \
# 185      https://preprints.apsanet.org/engage/apsa/arti...
# 202      https://preprints.apsanet.org/engage/apsa/arti...
# 262      https://preprints.apsanet.org/engage/apsa/arti...
# 3624706               http://www.ssrn.com/abstract=1634570
# 4197312              https://www.ssrn.com/abstract=5071920
#
#                                                      title  \
# 185                                        Ethnic Autonomy
# 202                                        Ethnic Autonomy
# 262                                        Ethnic Autonomy
# 3624706  Culture, Development, and Regional Ethnic Auto...
# 4197312  Federalism vs. Centralization: Ethnic Autonomy...
#
#                          authors_flat    institutions_flat countries_flat  \
# 185                        Sasaki, Yu    Waseda University           None
# 202                        Sasaki, Yu    Waseda University           None
# 262                        Sasaki, Yu  Kanazawa University           None
# 3624706              Zheng, George G.                 None           None
# 4197312  AYAZ, MUHAMMAD; Fahad, Ujala                 None           None
#
#                                             relations_json version_label  \
# 185      {"is-version-of": [{"asserted-by": "subject", ...          None
# 202      {"is-version-of": [{"asserted-by": "subject", ...          None
# 262      {"is-version-of": [{"asserted-by": "subject", ...          None
# 3624706                                               None          None
# 4197312                                               None          None
#
#                                              is_version_of is_preprint_of  \
# 185      10.33774/apsa-2019-25rz9-v2;10.33774/apsa-2019...
# 202      10.33774/apsa-2019-25rz9;10.33774/apsa-2019-25...
# 262      10.33774/apsa-2019-25rz9;10.33774/apsa-2019-25...
# 3624706
# 4197312
#
#         has_preprint has_review has_published_version  \
# 185                                             false
# 202                                             false
# 262                                             false
# 3624706                                         false
# 4197312                                         false
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 185                           None                None           None
# 202                           None                None           None
# 262                           None                None           None
# 3624706                       None                None           None
# 4197312                       None                None           None
#
#         raw_relationships_json                    records_hierarchy  \
# 185                       None                               parent
# 202                       None  parent - duplicate (APSA Preprints)
# 262                       None  parent - duplicate (APSA Preprints)
# 3624706                   None                               parent
# 4197312                   None                               parent
#
#         date_first_seen  publication_year_first_seen records_hierarchy_backup  \
# 185          2019-09-19                         2019                  version
# 202          2020-01-31                         2020                  version
# 262          2020-12-03                         2020                  version
# 3624706      2010-07-05                         2010                   parent
# 4197312      2025-01-01                         2025                   parent
#
#                            parent_record_id  \
# 185                                    <NA>
# 202      crossref::10.33774/apsa-2019-25rz9
# 262      crossref::10.33774/apsa-2019-25rz9
# 3624706                                None
# 4197312                                None
#
#                                dup_group_id authors_fp_tokenbag  \
# 185      crossref::10.33774/apsa-2019-25rz9           sasaki_yu
# 202      crossref::10.33774/apsa-2019-25rz9           sasaki_yu
# 262      crossref::10.33774/apsa-2019-25rz9           sasaki_yu
# 3624706                                None                None
# 4197312                                None                None
#
#                                             title_clean_v2  \
# 185                                        ethnic autonomy
# 202                                        ethnic autonomy
# 262                                        ethnic autonomy
# 3624706  culture development and regional ethnic autono...
# 4197312                                               None
#
#         authors_fp_last_initial authors_fp_last  \
# 185                    sasaki|y            None
# 202                        None            None
# 262                        None            None
# 3624706                 zheng|g            None
# 4197312                    None            None
#
#              records_hierarchy_dedupe_backup  \
# 185                                   parent
# 202      parent - duplicate (APSA Preprints)
# 262      parent - duplicate (APSA Preprints)
# 3624706                               parent
# 4197312                               parent
#
#              parent_record_id_dedupe_backup dup_group_id_dedupe_backup  \
# 185                                    None       14449129667358129714
# 202      crossref::10.33774/apsa-2019-25rz9       14449129667358129714
# 262      crossref::10.33774/apsa-2019-25rz9       14449129667358129714
# 3624706                                None                       None
# 4197312                                None                       None
#
#         records_hierarchy_unify_version_backup  \
# 185                                     parent
# 202          parent - duplicate (version-link)
# 262          parent - duplicate (version-link)
# 3624706                                 parent
# 4197312                                 parent
#
#         parent_record_id_unify_version_backup  \
# 185                                      None
# 202        crossref::10.33774/apsa-2019-25rz9
# 262        crossref::10.33774/apsa-2019-25rz9
# 3624706                                  None
# 4197312                                  None
#
#           dup_group_id_unify_version_backup
# 185      crossref::10.33774/apsa-2019-25rz9
# 202      crossref::10.33774/apsa-2019-25rz9
# 262      crossref::10.33774/apsa-2019-25rz9
# 3624706                                None
# 4197312                                None

# %%
pattern = "datacite::10.48550/arxiv.1009.5069"


mask = data['dup_group_id'].str.contains(pattern, regex=False, na=False)
result = data[mask]
print(len(result))
result
# Out:
# 0
# Empty DataFrame
# Columns: [record_id, server_name, backend, doi, doi_url, landing_page_url, title, authors_flat, institutions_flat, countries_flat, relations_json, version_label, is_version_of, is_preprint_of, has_preprint, has_review, has_published_version, published_version_ids_json, version_of_ids_json, update_to_json, raw_relationships_json, records_hierarchy, date_first_seen, publication_year_first_seen, records_hierarchy_backup, parent_record_id, dup_group_id, authors_fp_tokenbag, title_clean_v2, authors_fp_last_initial, authors_fp_last, records_hierarchy_dedupe_backup, parent_record_id_dedupe_backup, dup_group_id_dedupe_backup, records_hierarchy_unify_version_backup, parent_record_id_unify_version_backup, dup_group_id_unify_version_backup]
# Index: []

# %%
pattern = "datacite::10.48550/arxiv.1010.0203"


mask = data['dup_group_id'].str.contains(pattern, regex=False, na=False)
result = data[mask]
print(len(result))
result
# Out:
# 0
# Empty DataFrame
# Columns: [record_id, server_name, backend, doi, doi_url, landing_page_url, title, authors_flat, institutions_flat, countries_flat, relations_json, version_label, is_version_of, is_preprint_of, has_preprint, has_review, has_published_version, published_version_ids_json, version_of_ids_json, update_to_json, raw_relationships_json, records_hierarchy, date_first_seen, publication_year_first_seen, records_hierarchy_backup, parent_record_id, dup_group_id, authors_fp_tokenbag, title_clean_v2, authors_fp_last_initial, authors_fp_last, records_hierarchy_dedupe_backup, parent_record_id_dedupe_backup, dup_group_id_dedupe_backup, records_hierarchy_unify_version_backup, parent_record_id_unify_version_backup, dup_group_id_unify_version_backup]
# Index: []

# %%
pattern = "Search for a heavy resonance decaying into"


mask = data['title'].str.contains(pattern, regex=False, na=False)
result = data[mask]
print(len(result))
result
# Out:
# 6
#                                        record_id server_name   backend  \
# 335713                     openalex::W2921909056  DSpace@MIT  openalex
# 4739525      datacite::10.48550/arxiv.2111.10216       arXiv  datacite
# 5975676      datacite::10.48550/arxiv.1803.03838       arXiv  datacite
# 5977724      datacite::10.48550/arxiv.1803.10093       arXiv  datacite
# 6550333  datacite::10.48550/arxiv.hep-ex/0606018       arXiv  datacite
# 7628808      datacite::10.48550/arxiv.2411.00202       arXiv  datacite
#
#                                    doi  \
# 335713                            None
# 4739525      10.48550/arxiv.2111.10216
# 5975676      10.48550/arxiv.1803.03838
# 5977724      10.48550/arxiv.1803.10093
# 6550333  10.48550/arxiv.hep-ex/0606018
# 7628808      10.48550/arxiv.2411.00202
#
#                                                doi_url  \
# 335713                                            None
# 4739525      https://doi.org/10.48550/arxiv.2111.10216
# 5975676      https://doi.org/10.48550/arxiv.1803.03838
# 5977724      https://doi.org/10.48550/arxiv.1803.10093
# 6550333  https://doi.org/10.48550/arxiv.hep-ex/0606018
# 7628808      https://doi.org/10.48550/arxiv.2411.00202
#
#                              landing_page_url  \
# 335713    http://hdl.handle.net/1721.1/117537
# 4739525      https://arxiv.org/abs/2111.10216
# 5975676      https://arxiv.org/abs/1803.03838
# 5977724      https://arxiv.org/abs/1803.10093
# 6550333  https://arxiv.org/abs/hep-ex/0606018
# 7628808      https://arxiv.org/abs/2411.00202
#
#                                                      title  \
# 335713   Search for a heavy resonance decaying into a Z...
# 4739525  Search for a heavy resonance decaying into a t...
# 5975676  Search for a heavy resonance decaying into a Z...
# 5977724  Search for a heavy resonance decaying into a Z...
# 6550333  Search for a heavy resonance decaying into a Z...
# 7628808  Search for a heavy resonance decaying into a Z...
#
#                                               authors_flat institutions_flat  \
# 335713   Daniel Robert Abercrombie; Brandon Leigh Allen...              None
# 4739525                                  CMS Collaboration              None
# 5975676                                  CMS Collaboration              None
# 5977724                                  CMS Collaboration              None
# 6550333                    D0 Collaboration; Abazov, V. M.              None
# 7628808                                  CMS Collaboration              None
#
#         countries_flat                                     relations_json  \
# 335713            None                                               None
# 4739525           None  [{"relatedIdentifier": "10.1007/jhep04(2022)04...
# 5975676           None  [{"relatedIdentifier": "10.1007/jhep07(2018)07...
# 5977724           None  [{"relatedIdentifier": "10.1007/jhep09(2018)10...
# 6550333           None  [{"relatedIdentifier": "10.1103/physrevd.74.01...
# 7628808           None  [{"relatedIdentifier": "10.1007/jhep02(2025)08...
#
#         version_label is_version_of              is_preprint_of has_preprint  \
# 335713           None          None                        None         None
# 4739525             2                   10.1007/jhep04(2022)048
# 5975676             2                   10.1007/jhep07(2018)075
# 5977724             2                   10.1007/jhep09(2018)101
# 6550333             1                10.1103/physrevd.74.011104
# 7628808             2                   10.1007/jhep02(2025)089
#
#         has_review has_published_version published_version_ids_json  \
# 335713        None                  None                       None
# 4739525                             true                       None
# 5975676                             true                       None
# 5977724                             true                       None
# 6550333                             true                       None
# 7628808                             true                       None
#
#         version_of_ids_json update_to_json  \
# 335713                 None           None
# 4739525                None           None
# 5975676                None           None
# 5977724                None           None
# 6550333                None           None
# 7628808                None           None
#
#                                     raw_relationships_json records_hierarchy  \
# 335713                                                None            parent
# 4739525  {"client": {"data": {"id": "arxiv.content", "t...            parent
# 5975676  {"client": {"data": {"id": "arxiv.content", "t...            parent
# 5977724  {"client": {"data": {"id": "arxiv.content", "t...            parent
# 6550333  {"client": {"data": {"id": "arxiv.content", "t...            parent
# 7628808  {"client": {"data": {"id": "arxiv.content", "t...            parent
#
#         date_first_seen  publication_year_first_seen records_hierarchy_backup  \
# 335713       2018-07-01                         2018                   parent
# 4739525      2022-02-20                         2022                   parent
# 5975676      2022-03-03                         2022                   parent
# 5977724      2022-03-03                         2022                   parent
# 6550333      2022-03-17                         2022                   parent
# 7628808      2024-11-04                         2024                   parent
#
#         parent_record_id dup_group_id          authors_fp_tokenbag  \
# 335713              None         None                         None
# 4739525             None         None            cms_collaboration
# 5975676             None         None            cms_collaboration
# 5977724             None         None            cms_collaboration
# 6550333             None         None  abazov_m_v;collaboration_d0
# 7628808             None         None            cms_collaboration
#
#                                             title_clean_v2  \
# 335713                                                None
# 4739525  search for a heavy resonance decaying into a t...
# 5975676  search for a heavy resonance decaying into a z...
# 5977724  search for a heavy resonance decaying into a z...
# 6550333  search for a heavy resonance decaying into a z...
# 7628808  search for a heavy resonance decaying into a z...
#
#           authors_fp_last_initial authors_fp_last  \
# 335713                       None            None
# 4739525           collaboration|c            None
# 5975676           collaboration|c            None
# 5977724           collaboration|c            None
# 6550333  abazov|v;collaboration|d            None
# 7628808           collaboration|c            None
#
#         records_hierarchy_dedupe_backup parent_record_id_dedupe_backup  \
# 335713                           parent                           None
# 4739525                          parent                           None
# 5975676                          parent                           None
# 5977724                          parent                           None
# 6550333                          parent                           None
# 7628808                          parent                           None
#
#         dup_group_id_dedupe_backup records_hierarchy_unify_version_backup  \
# 335713                        None                                 parent
# 4739525                       None                                 parent
# 5975676                       None                                 parent
# 5977724                       None                                 parent
# 6550333                       None                                 parent
# 7628808                       None                                 parent
#
#         parent_record_id_unify_version_backup  \
# 335713                                   None
# 4739525                                  None
# 5975676                                  None
# 5977724                                  None
# 6550333                                  None
# 7628808                                  None
#
#         dup_group_id_unify_version_backup
# 335713                               None
# 4739525                              None
# 5975676                              None
# 5977724                              None
# 6550333                              None
# 7628808                              None

# %%
pattern = "Search for a heavy resonance decaying into"


mask = data['title'].str.contains(pattern, regex=False, na=False)
result = data[mask]
print(len(result))
result
# Out:
# 6
#                                        record_id server_name   backend  \
# 335713                     openalex::W2921909056  DSpace@MIT  openalex
# 4739525      datacite::10.48550/arxiv.2111.10216       arXiv  datacite
# 5975676      datacite::10.48550/arxiv.1803.03838       arXiv  datacite
# 5977724      datacite::10.48550/arxiv.1803.10093       arXiv  datacite
# 6550333  datacite::10.48550/arxiv.hep-ex/0606018       arXiv  datacite
# 7628808      datacite::10.48550/arxiv.2411.00202       arXiv  datacite
#
#                                    doi  \
# 335713                            None
# 4739525      10.48550/arxiv.2111.10216
# 5975676      10.48550/arxiv.1803.03838
# 5977724      10.48550/arxiv.1803.10093
# 6550333  10.48550/arxiv.hep-ex/0606018
# 7628808      10.48550/arxiv.2411.00202
#
#                                                doi_url  \
# 335713                                            None
# 4739525      https://doi.org/10.48550/arxiv.2111.10216
# 5975676      https://doi.org/10.48550/arxiv.1803.03838
# 5977724      https://doi.org/10.48550/arxiv.1803.10093
# 6550333  https://doi.org/10.48550/arxiv.hep-ex/0606018
# 7628808      https://doi.org/10.48550/arxiv.2411.00202
#
#                              landing_page_url  \
# 335713    http://hdl.handle.net/1721.1/117537
# 4739525      https://arxiv.org/abs/2111.10216
# 5975676      https://arxiv.org/abs/1803.03838
# 5977724      https://arxiv.org/abs/1803.10093
# 6550333  https://arxiv.org/abs/hep-ex/0606018
# 7628808      https://arxiv.org/abs/2411.00202
#
#                                                      title  \
# 335713   Search for a heavy resonance decaying into a Z...
# 4739525  Search for a heavy resonance decaying into a t...
# 5975676  Search for a heavy resonance decaying into a Z...
# 5977724  Search for a heavy resonance decaying into a Z...
# 6550333  Search for a heavy resonance decaying into a Z...
# 7628808  Search for a heavy resonance decaying into a Z...
#
#                                               authors_flat institutions_flat  \
# 335713   Daniel Robert Abercrombie; Brandon Leigh Allen...              None
# 4739525                                  CMS Collaboration              None
# 5975676                                  CMS Collaboration              None
# 5977724                                  CMS Collaboration              None
# 6550333                    D0 Collaboration; Abazov, V. M.              None
# 7628808                                  CMS Collaboration              None
#
#         countries_flat                                     relations_json  \
# 335713            None                                               None
# 4739525           None  [{"relatedIdentifier": "10.1007/jhep04(2022)04...
# 5975676           None  [{"relatedIdentifier": "10.1007/jhep07(2018)07...
# 5977724           None  [{"relatedIdentifier": "10.1007/jhep09(2018)10...
# 6550333           None  [{"relatedIdentifier": "10.1103/physrevd.74.01...
# 7628808           None  [{"relatedIdentifier": "10.1007/jhep02(2025)08...
#
#         version_label is_version_of              is_preprint_of has_preprint  \
# 335713           None          None                        None         None
# 4739525             2                   10.1007/jhep04(2022)048
# 5975676             2                   10.1007/jhep07(2018)075
# 5977724             2                   10.1007/jhep09(2018)101
# 6550333             1                10.1103/physrevd.74.011104
# 7628808             2                   10.1007/jhep02(2025)089
#
#         has_review has_published_version published_version_ids_json  \
# 335713        None                  None                       None
# 4739525                             true                       None
# 5975676                             true                       None
# 5977724                             true                       None
# 6550333                             true                       None
# 7628808                             true                       None
#
#         version_of_ids_json update_to_json  \
# 335713                 None           None
# 4739525                None           None
# 5975676                None           None
# 5977724                None           None
# 6550333                None           None
# 7628808                None           None
#
#                                     raw_relationships_json records_hierarchy  \
# 335713                                                None            parent
# 4739525  {"client": {"data": {"id": "arxiv.content", "t...            parent
# 5975676  {"client": {"data": {"id": "arxiv.content", "t...            parent
# 5977724  {"client": {"data": {"id": "arxiv.content", "t...            parent
# 6550333  {"client": {"data": {"id": "arxiv.content", "t...            parent
# 7628808  {"client": {"data": {"id": "arxiv.content", "t...            parent
#
#         date_first_seen  publication_year_first_seen records_hierarchy_backup  \
# 335713       2018-07-01                         2018                   parent
# 4739525      2022-02-20                         2022                   parent
# 5975676      2022-03-03                         2022                   parent
# 5977724      2022-03-03                         2022                   parent
# 6550333      2022-03-17                         2022                   parent
# 7628808      2024-11-04                         2024                   parent
#
#         parent_record_id dup_group_id          authors_fp_tokenbag  \
# 335713              None         None                         None
# 4739525             None         None            cms_collaboration
# 5975676             None         None            cms_collaboration
# 5977724             None         None            cms_collaboration
# 6550333             None         None  abazov_m_v;collaboration_d0
# 7628808             None         None            cms_collaboration
#
#                                             title_clean_v2  \
# 335713                                                None
# 4739525  search for a heavy resonance decaying into a t...
# 5975676  search for a heavy resonance decaying into a z...
# 5977724  search for a heavy resonance decaying into a z...
# 6550333  search for a heavy resonance decaying into a z...
# 7628808  search for a heavy resonance decaying into a z...
#
#           authors_fp_last_initial authors_fp_last  \
# 335713                       None            None
# 4739525           collaboration|c            None
# 5975676           collaboration|c            None
# 5977724           collaboration|c            None
# 6550333  abazov|v;collaboration|d            None
# 7628808           collaboration|c            None
#
#         records_hierarchy_dedupe_backup parent_record_id_dedupe_backup  \
# 335713                           parent                           None
# 4739525                          parent                           None
# 5975676                          parent                           None
# 5977724                          parent                           None
# 6550333                          parent                           None
# 7628808                          parent                           None
#
#         dup_group_id_dedupe_backup records_hierarchy_unify_version_backup  \
# 335713                        None                                 parent
# 4739525                       None                                 parent
# 5975676                       None                                 parent
# 5977724                       None                                 parent
# 6550333                       None                                 parent
# 7628808                       None                                 parent
#
#         parent_record_id_unify_version_backup  \
# 335713                                   None
# 4739525                                  None
# 5975676                                  None
# 5977724                                  None
# 6550333                                  None
# 7628808                                  None
#
#         dup_group_id_unify_version_backup
# 335713                               None
# 4739525                              None
# 5975676                              None
# 5977724                              None
# 6550333                              None
# 7628808                              None

# %%
result['title'].value_counts()
# Out:
# title
# Search for a heavy resonance decaying into a Z boson and a vector boson in the vv qq final state                                                                                                                    1
# Search for a heavy resonance decaying into a top quark and a W boson in the lepton+jets final state at $\sqrt{s} = $13 TeV                                                                                          1
# Search for a heavy resonance decaying into a Z boson and a vector boson in the $ν\overlineν\mathrm{q}\overline{\mathrm{q}}$ final state                                                                             1
# Search for a heavy resonance decaying into a Z boson and a Z or W boson in 2$\ell$2q final states at $\sqrt{s}=$ 13 TeV                                                                                             1
# Search for a heavy resonance decaying into a Z+jet final state in p-pbar collisions at sqrt(s) = 1.96 TeV using the D0 detector                                                                                     1
# Search for a heavy resonance decaying into a Z and a Higgs boson in events with an energetic jet and two electrons, two muons, or missing transverse momentum in proton-proton collisions at $\sqrt{s}$ = 13 TeV    1
# Name: count, dtype: int64
