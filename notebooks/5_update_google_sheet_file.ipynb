# %%
import pandas as pd
# Set option to display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# # function to update google sheet file

# %%
from __future__ import annotations

# =========================
# 0) Imports
# =========================
import numpy as np
import pandas as pd
import duckdb
from typing import Iterable, Dict, Any, Optional, List, Tuple

import gspread
from google.oauth2.service_account import Credentials


# =========================
# 1) DuckDB metrics builder
# =========================
def build_sheet_metrics_duckdb(
    df: pd.DataFrame,
    *,
    server_col: str = "server_name",
    backend_col: str = "backend",
    group_id_col: str = "dup_group_id",
    date_col: str = "date_first_seen",
    year_col: str = "publication_year_first_seen",
    has_published_col: str = "has_published_version",
    hierarchy_col: str = "records_hierarchy",
    record_id_col: str = "record_id",
    choose_parent: str = "oldest",   # "oldest" | "newest"
) -> tuple[pd.DataFrame, pd.DataFrame]:
    """
    Returns:
      overall_df:  one row per server_name (ALL backends combined)
      backend_df:  one row per (server_name, backend)

    Output columns (overall_df & backend_df):
      server_name, [backend], n_records, n_unique, n_published, pct_published,
      n_is_version_of, pct_has_versions, count_2024, count_2025
    """
    if choose_parent not in ("oldest", "newest"):
        raise ValueError("choose_parent must be 'oldest' or 'newest'")

    order_dir = "ASC" if choose_parent == "oldest" else "DESC"

    con = duckdb.connect(database=":memory:")
    con.register("df", df)

    overall_sql = f"""
    WITH base AS (
      SELECT
        CAST({server_col} AS VARCHAR) AS server_name,
        CAST({backend_col} AS VARCHAR) AS backend,
        CAST({group_id_col} AS VARCHAR) AS dup_group_id,
        CAST({record_id_col} AS VARCHAR) AS record_id,
        TRY_CAST({date_col} AS TIMESTAMP) AS date_first_seen,
        TRY_CAST({year_col} AS INTEGER) AS year_first_seen,
        CASE
          WHEN {has_published_col} IS NULL THEN FALSE
          WHEN CAST({has_published_col} AS VARCHAR) IN ('true','True','1') THEN TRUE
          WHEN CAST({has_published_col} AS VARCHAR) IN ('false','False','0') THEN FALSE
          ELSE COALESCE(TRY_CAST({has_published_col} AS BOOLEAN), FALSE)
        END AS has_published_version,
        LOWER(TRIM(COALESCE(CAST({hierarchy_col} AS VARCHAR), ''))) AS records_hierarchy
      FROM df
      WHERE {server_col} IS NOT NULL
        AND {group_id_col} IS NOT NULL
        AND TRIM(CAST({server_col} AS VARCHAR)) <> ''
        AND TRIM(CAST({group_id_col} AS VARCHAR)) <> ''
    ),
    clusters AS (
      SELECT
        dup_group_id,
        COUNT(*) AS cluster_size,
        BOOL_OR(has_published_version) AS cluster_has_published
      FROM base
      GROUP BY dup_group_id
    ),
    parents AS (
      SELECT
        b.dup_group_id,
        b.server_name AS parent_server_name,
        b.backend AS parent_backend,
        b.record_id AS parent_record_id,
        b.date_first_seen AS parent_date_first_seen,
        b.year_first_seen AS parent_year_first_seen
      FROM base b
      QUALIFY ROW_NUMBER() OVER (
        PARTITION BY b.dup_group_id
        ORDER BY
          CASE WHEN b.records_hierarchy = 'parent' THEN 0 ELSE 1 END,
          b.date_first_seen {order_dir} NULLS LAST,
          b.record_id {order_dir}
      ) = 1
    ),
    joined AS (
      SELECT
        b.server_name,
        b.backend,
        b.dup_group_id,
        c.cluster_size,
        c.cluster_has_published,
        p.parent_year_first_seen
      FROM base b
      JOIN clusters c USING (dup_group_id)
      JOIN parents  p USING (dup_group_id)
    ),
    overall AS (
      SELECT
        server_name,
        COUNT(*) AS n_records,
        COUNT(DISTINCT dup_group_id) AS n_unique,
        COUNT(DISTINCT CASE WHEN cluster_has_published THEN dup_group_id END) AS n_published,
        COUNT(DISTINCT CASE WHEN cluster_size > 1 THEN dup_group_id END) AS n_is_version_of
      FROM joined
      GROUP BY server_name
    ),
    yearly AS (
      SELECT
        server_name,
        SUM(CASE WHEN parent_year_first_seen = 2024 THEN 1 ELSE 0 END) AS count_2024,
        SUM(CASE WHEN parent_year_first_seen = 2025 THEN 1 ELSE 0 END) AS count_2025
      FROM (
        SELECT DISTINCT server_name, dup_group_id, parent_year_first_seen
        FROM joined
      )
      GROUP BY server_name
    )
    SELECT
      o.server_name,
      o.n_records,
      o.n_unique,
      o.n_published,
      CASE WHEN o.n_unique > 0 THEN (o.n_published::DOUBLE / o.n_unique) * 100 ELSE NULL END AS pct_published,
      o.n_is_version_of,
      CASE WHEN o.n_unique > 0 THEN (o.n_is_version_of::DOUBLE / o.n_unique) * 100 ELSE NULL END AS pct_has_versions,
      COALESCE(y.count_2024, 0) AS count_2024,
      COALESCE(y.count_2025, 0) AS count_2025
    FROM overall o
    LEFT JOIN yearly y USING (server_name)
    ORDER BY o.server_name;
    """
    overall_df = con.sql(overall_sql).df()

    backend_sql = f"""
    WITH base AS (
      SELECT
        CAST({server_col} AS VARCHAR) AS server_name,
        CAST({backend_col} AS VARCHAR) AS backend,
        CAST({group_id_col} AS VARCHAR) AS dup_group_id,
        CAST({record_id_col} AS VARCHAR) AS record_id,
        TRY_CAST({date_col} AS TIMESTAMP) AS date_first_seen,
        TRY_CAST({year_col} AS INTEGER) AS year_first_seen,
        CASE
          WHEN {has_published_col} IS NULL THEN FALSE
          WHEN CAST({has_published_col} AS VARCHAR) IN ('true','True','1') THEN TRUE
          WHEN CAST({has_published_col} AS VARCHAR) IN ('false','False','0') THEN FALSE
          ELSE COALESCE(TRY_CAST({has_published_col} AS BOOLEAN), FALSE)
        END AS has_published_version,
        LOWER(TRIM(COALESCE(CAST({hierarchy_col} AS VARCHAR), ''))) AS records_hierarchy
      FROM df
      WHERE {server_col} IS NOT NULL
        AND {group_id_col} IS NOT NULL
        AND TRIM(CAST({server_col} AS VARCHAR)) <> ''
        AND TRIM(CAST({group_id_col} AS VARCHAR)) <> ''
        AND {backend_col} IS NOT NULL
        AND TRIM(CAST({backend_col} AS VARCHAR)) <> ''
    ),
    clusters AS (
      SELECT
        dup_group_id,
        COUNT(*) AS cluster_size,
        BOOL_OR(has_published_version) AS cluster_has_published
      FROM base
      GROUP BY dup_group_id
    ),
    parents AS (
      SELECT
        b.dup_group_id,
        b.server_name AS parent_server_name,
        b.backend AS parent_backend,
        b.record_id AS parent_record_id,
        b.date_first_seen AS parent_date_first_seen,
        b.year_first_seen AS parent_year_first_seen
      FROM base b
      QUALIFY ROW_NUMBER() OVER (
        PARTITION BY b.dup_group_id
        ORDER BY
          CASE WHEN b.records_hierarchy = 'parent' THEN 0 ELSE 1 END,
          b.date_first_seen {order_dir} NULLS LAST,
          b.record_id {order_dir}
      ) = 1
    ),
    joined AS (
      SELECT
        b.server_name,
        b.backend,
        b.dup_group_id,
        c.cluster_size,
        c.cluster_has_published,
        p.parent_year_first_seen
      FROM base b
      JOIN clusters c USING (dup_group_id)
      JOIN parents  p USING (dup_group_id)
    ),
    agg AS (
      SELECT
        server_name,
        backend,
        COUNT(*) AS n_records,
        COUNT(DISTINCT dup_group_id) AS n_unique,
        COUNT(DISTINCT CASE WHEN cluster_has_published THEN dup_group_id END) AS n_published,
        COUNT(DISTINCT CASE WHEN cluster_size > 1 THEN dup_group_id END) AS n_is_version_of
      FROM joined
      GROUP BY server_name, backend
    ),
    yearly AS (
      SELECT
        server_name,
        backend,
        SUM(CASE WHEN parent_year_first_seen = 2024 THEN 1 ELSE 0 END) AS count_2024,
        SUM(CASE WHEN parent_year_first_seen = 2025 THEN 1 ELSE 0 END) AS count_2025
      FROM (
        SELECT DISTINCT server_name, backend, dup_group_id, parent_year_first_seen
        FROM joined
      )
      GROUP BY server_name, backend
    )
    SELECT
      a.server_name,
      a.backend,
      a.n_records,
      a.n_unique,
      a.n_published,
      CASE WHEN a.n_unique > 0 THEN (a.n_published::DOUBLE / a.n_unique) * 100 ELSE NULL END AS pct_published,
      a.n_is_version_of,
      CASE WHEN a.n_unique > 0 THEN (a.n_is_version_of::DOUBLE / a.n_unique) * 100 ELSE NULL END AS pct_has_versions,
      COALESCE(y.count_2024, 0) AS count_2024,
      COALESCE(y.count_2025, 0) AS count_2025
    FROM agg a
    LEFT JOIN yearly y
      ON a.server_name = y.server_name AND a.backend = y.backend
    ORDER BY a.server_name, a.backend;
    """
    backend_df = con.sql(backend_sql).df()

    con.close()
    return overall_df, backend_df


# ============================================
# 2) Read sheet -> DataFrame (gspread)
# ============================================
def read_sheet_as_df(
    *,
    sheet_id: str,
    worksheet_gid: int,
    service_account_json_path: str,
) -> pd.DataFrame:
    scopes = ["https://www.googleapis.com/auth/spreadsheets"]
    creds = Credentials.from_service_account_file(service_account_json_path, scopes=scopes)
    gc = gspread.authorize(creds)
    sh = gc.open_by_key(sheet_id)

    ws = None
    for w in sh.worksheets():
        if w.id == worksheet_gid:
            ws = w
            break
    if ws is None:
        raise ValueError(f"Worksheet gid={worksheet_gid} not found.")

    values = ws.get_all_values()
    if not values:
        return pd.DataFrame()

    header = values[0]
    rows = values[1:]
    df = pd.DataFrame(rows, columns=header)
    return df


# ============================================
# 3) Build payload_df (only columns to update)
# ============================================
def build_update_payload(
    sheet_df: pd.DataFrame,
    overall_df: pd.DataFrame,
    backend_df: pd.DataFrame,
    target_cols: List[str],
    *,
    key_col: str = "source_id",
    default_collection_date: str = "2025/12/31",
    per_server_date: Optional[Dict[str, str]] = None,
) -> pd.DataFrame:
    """
    Returns a dataframe containing:
      - key_col
      - all target_cols (exact names from the sheet, including trailing spaces)
    Values come from overall_df & backend_df.
    Missing columns are created as blanks so the writer won't crash.
    """
    if key_col not in sheet_df.columns:
        raise ValueError(f"Sheet dataframe must contain '{key_col}'.")

    out = pd.DataFrame()
    out[key_col] = sheet_df[key_col].astype(str)

    # Ensure all target cols exist in out (so writer won't KeyError)
    for c in target_cols:
        out[c] = ""

    # ---- Global map (overall)
    g = overall_df.set_index("server_name")
    sid = out[key_col].astype(str)

    def set_if_present(colname: str, values):
        if colname in out.columns:
            out[colname] = values

    # Global (red columns)
    set_if_present("Collection Date used for Red Columns", default_collection_date)
    set_if_present("number of unique preprints", sid.map(g["n_unique"]))
    set_if_present("number of unique preprints that are published", sid.map(g["n_published"]))

    # NOTE: your sheet has trailing spaces in some headers:
    set_if_present("% of unique that are published ", sid.map(g["pct_published"]))
    set_if_present("Number of unique preprints with more than 1 version", sid.map(g["n_is_version_of"]))
    set_if_present("% of unique that have more than one version ", sid.map(g["pct_has_versions"]))

    # ---- Backend blocks
    b = backend_df.copy()
    b["backend"] = b["backend"].astype(str).str.lower().str.strip()
    b["server_name"] = b["server_name"].astype(str)

    def backend_map(backend_key: str) -> pd.DataFrame:
        return b[b["backend"] == backend_key].set_index("server_name")

    # Crossref
    cr = backend_map("crossref")
    set_if_present("Is the Server in Crossref", sid.isin(cr.index))
    set_if_present("Crossref collection_date", default_collection_date)
    set_if_present("Number of works in Crossref", sid.map(cr["n_records"]))
    set_if_present("Number of unique preprints in Crossref", sid.map(cr["n_unique"]))
    set_if_present("Number of unique preprints that are published in Crossref", sid.map(cr["n_published"]))
    set_if_present("%_of unique that are published in Crossref", sid.map(cr["pct_published"]))
    set_if_present("Number of unique preprints with more than 1 version in Crossref", sid.map(cr["n_is_version_of"]))
    set_if_present("% of unique that have more than one version  in Crossref", sid.map(cr["pct_has_versions"]))
    set_if_present("Works_in_2024 in Crossref", sid.map(cr["count_2024"]))
    set_if_present("Works_in_2025 in Crossref", sid.map(cr["count_2025"]))

    # DataCite
    dc = backend_map("datacite")
    set_if_present("Is the server in DataCite", sid.isin(dc.index))
    set_if_present("DataCite Collection Date", default_collection_date)
    set_if_present("Number of works in DataCite", sid.map(dc["n_records"]))
    # sheet uses this exact column name:
    set_if_present("number_of_preprint_unique in DataCite", sid.map(dc["n_unique"]))
    set_if_present("number of unique preprints that are published in Datacite", sid.map(dc["n_published"]))
    set_if_present("%_of unique that are published in DataCite", sid.map(dc["pct_published"]))
    set_if_present("Number of unique preprints with more than 1 version in DataCite", sid.map(dc["n_is_version_of"]))
    set_if_present("% of unique that have more than one version  in DataCite", sid.map(dc["pct_has_versions"]))
    set_if_present("Works_in_2024 in DataCite", sid.map(dc["count_2024"]))
    set_if_present("Works_in_2025 in DataCite", sid.map(dc["count_2025"]))

    # OpenAlex
    oa = backend_map("openalex")
    set_if_present("Is the server in OpenAlex", sid.isin(oa.index))
    set_if_present("OpenAlex Data Collection Date", default_collection_date)
    set_if_present("Number of works in OpenAlex", sid.map(oa["n_records"]))
    set_if_present("number_of_preprint_unique in OpenAlex", sid.map(oa["n_unique"]))
    set_if_present("number of unique preprints that are published in OpenAlex", sid.map(oa["n_published"]))
    set_if_present("%_of unique that are published in OpenAlex", sid.map(oa["pct_published"]))
    set_if_present("Number of unique preprints with more than 1 version in OpenAlex", sid.map(oa["n_is_version_of"]))
    set_if_present("% of unique preprints with more than 1 version in OpenAlex", sid.map(oa["pct_has_versions"]))
    set_if_present("Works_in_2024 in OpenAlex", sid.map(oa["count_2024"]))
    set_if_present("Works_in_2025 in OpenAlex", sid.map(oa["count_2025"]))

    # ---- Optional per-server collection date overrides
    if per_server_date:
        # Only touches the *collection date* columns if present in target_cols
        for date_col in [
            "Collection Date used for Red Columns",
            "Crossref collection_date",
            "DataCite Collection Date",
            "OpenAlex Data Collection Date",
        ]:
            if date_col in out.columns:
                out[date_col] = [
                    per_server_date.get(s, default_collection_date) for s in sid.tolist()
                ]

    # Clean types for writing
    for c in target_cols:
        if c in out.columns:
            out[c] = out[c].replace({np.nan: ""})
    return out[[key_col] + list(target_cols)]


# ============================================
# 4) Update ONLY selected columns in the sheet
# ============================================
def update_google_sheet_only_columns(
    *,
    sheet_id: str,
    worksheet_gid: int,
    service_account_json_path: str,
    payload_df: pd.DataFrame,
    key_col: str,
    columns_to_update: Iterable[str],
    chunk_size: int = 500,
    overwrite: bool = True,
    verbose: bool = True,
) -> Dict[str, Any]:
    cols = list(columns_to_update)
    if key_col not in payload_df.columns:
        raise ValueError(f"payload_df must contain '{key_col}'.")

    scopes = ["https://www.googleapis.com/auth/spreadsheets"]
    creds = Credentials.from_service_account_file(service_account_json_path, scopes=scopes)
    gc = gspread.authorize(creds)
    sh = gc.open_by_key(sheet_id)

    ws = None
    for w in sh.worksheets():
        if w.id == worksheet_gid:
            ws = w
            break
    if ws is None:
        raise ValueError(f"Worksheet gid={worksheet_gid} not found.")

    header = ws.row_values(1)
    header_map = {h: (i + 1) for i, h in enumerate(header)}  # 1-based

    missing_cols = [c for c in cols if c not in header_map]
    if missing_cols:
        raise ValueError(f"These columns are not in the sheet header: {missing_cols}")

    if key_col not in header_map:
        raise ValueError(f"Sheet must contain '{key_col}' in header row.")

    key_col_idx = header_map[key_col]
    all_keys = ws.col_values(key_col_idx)
    key_to_row = {str(k): r for r, k in enumerate(all_keys[1:], start=2) if str(k).strip() != ""}

    p = payload_df.copy()
    p[key_col] = p[key_col].astype(str)

    keys_in_sheet = set(key_to_row.keys())
    p_in = p[p[key_col].isin(keys_in_sheet)].copy()
    missing_keys = p.loc[~p[key_col].isin(keys_in_sheet), key_col].unique().tolist()

    # Read existing values if overwrite=False
    existing = None
    if not overwrite:
        existing = {}
        for c in cols:
            cidx = header_map[c]
            vals = ws.col_values(cidx)
            for r, val in enumerate(vals[1:], start=2):
                existing[(r, cidx)] = val

    def norm(v):
        if v is None:
            return ""
        if isinstance(v, float) and np.isnan(v):
            return ""
        # keep numbers readable
        if isinstance(v, (np.integer,)):
            return str(int(v))
        if isinstance(v, (np.floating,)):
            return str(float(v))
        return str(v)

    cells_written = 0
    chunks = 0

    for i in range(0, len(p_in), chunk_size):
        chunk = p_in.iloc[i:i+chunk_size]
        cell_list = []

        for _, row in chunk.iterrows():
            rid = str(row[key_col])
            sheet_row = key_to_row.get(rid)
            if sheet_row is None:
                continue

            for c in cols:
                cidx = header_map[c]
                new_val = norm(row.get(c, ""))

                if not overwrite:
                    old_val = existing.get((sheet_row, cidx), "")
                    if str(old_val).strip() != "":
                        continue

                cell_list.append(gspread.Cell(sheet_row, cidx, new_val))

        if cell_list:
            ws.update_cells(cell_list, value_input_option="USER_ENTERED")
            cells_written += len(cell_list)

        chunks += 1
        if verbose:
            print(f"Chunk {chunks}: scanned {len(chunk)} rows, wrote {len(cell_list)} cells")

    return {
        "sheet_id": sheet_id,
        "worksheet_gid": worksheet_gid,
        "rows_payload": int(len(payload_df)),
        "rows_matched": int(len(p_in)),
        "missing_keys": missing_keys[:20],
        "n_missing_keys": int(len(missing_keys)),
        "columns_updated": cols,
        "overwrite": overwrite,
        "cells_written": int(cells_written),
        "chunks": int(chunks),
    }


# ============================================
# 5) RUN PIPELINE (edit these 4 things)
# ============================================

# SHEET_ID = "10_7FdcpZjntqFsEHIii7bAM72uF__of_iUohSD5w8w4"
# WORKSHEET_GID = 881157301

# # 1) put your service account json path here
# SERVICE_ACCOUNT_JSON = "/path/to/service_account.json"

# # 2) your target columns exactly as in the sheet (including trailing spaces)
# TARGET_COLS = [
#     'Collection Date used for Red Columns',
#     'number of unique preprints',
#     'number of unique preprints that are published',
#     '% of unique that are published ',
#     'Number of unique preprints with more than 1 version',
#     '% of unique that have more than one version ',
#     'Is the Server in Crossref',
#     'Crossref collection_date',
#     'Number of works in Crossref',
#     'Number of unique preprints in Crossref',
#     'Number of unique preprints that are published in Crossref',
#     '%_of unique that are published in Crossref',
#     'Number of unique preprints with more than 1 version in Crossref',
#     '% of unique that have more than one version  in Crossref',
#     'Works_in_2024 in Crossref',
#     'Works_in_2025 in Crossref',
#     'Is the server in DataCite',
#     'DataCite Collection Date',
#     'Number of works in DataCite',
#     'number_of_preprint_unique in DataCite',
#     'number of unique preprints that are published in Datacite',
#     '%_of unique that are published in DataCite',
#     'Number of unique preprints with more than 1 version in DataCite',
#     '% of unique that have more than one version  in DataCite',
#     'Works_in_2024 in DataCite',
#     'Works_in_2025 in DataCite',
#     'Is the server in OpenAlex',
#     'OpenAlex Data Collection Date',
#     'Number of works in OpenAlex',
#     'number_of_preprint_unique in OpenAlex',
#     'number of unique preprints that are published in OpenAlex',
#     '%_of unique that are published in OpenAlex',
#     'Number of unique preprints with more than 1 version in OpenAlex',
#     '% of unique preprints with more than 1 version in OpenAlex',
#     'Works_in_2024 in OpenAlex',
#     'Works_in_2025 in OpenAlex',
# ]

# # 3) choose the collection date you want for all servers
# DEFAULT_COLLECTION_DATE = "2025/12/31"

# # 4) optional later: per server overrides (keep None for now)
# PER_SERVER_DATE = None
# # Example:
# # PER_SERVER_DATE = {"bioRxiv": "2026/01/15", "medRxiv": "2026/01/15"}


# # =========================
# # Step A: compute metrics
# # =========================
# # IMPORTANT: 'data' must be your dedupe long dataframe in memory
# overall_df, backend_df = build_sheet_metrics_duckdb(data, choose_parent="oldest")

# # =========================
# # Step B: read the sheet
# # =========================
# sheet_df = read_sheet_as_df(
#     sheet_id=SHEET_ID,
#     worksheet_gid=WORKSHEET_GID,
#     service_account_json_path=SERVICE_ACCOUNT_JSON,
# )

# # =========================
# # Step C: build payload (only key + target cols)
# # =========================
# payload_df = build_update_payload(
#     sheet_df=sheet_df,
#     overall_df=overall_df,
#     backend_df=backend_df,
#     target_cols=TARGET_COLS,
#     key_col="source_id",
#     default_collection_date=DEFAULT_COLLECTION_DATE,
#     per_server_date=PER_SERVER_DATE,
# )

# print(payload_df.head())

# # =========================
# # Step D: update only those columns
# # =========================
# report = update_google_sheet_only_columns(
#     sheet_id=SHEET_ID,
#     worksheet_gid=WORKSHEET_GID,
#     service_account_json_path=SERVICE_ACCOUNT_JSON,
#     payload_df=payload_df,
#     key_col="source_id",
#     columns_to_update=TARGET_COLS,
#     chunk_size=500,
#     overwrite=True,   # set False to fill blanks only
#     verbose=True,
# )

# report

# %% [markdown]
# # import data

# %%
# lon_path = "outputs_new/parent/dedupe_clusters_long_full.parquet"
# data = pd.read_parquet(lon_path)

data = pd.read_pickle("outputs_new/dedupe_data_group_merge.pkl")
data["dup_group_id"] = (
    data["dup_group_id"]
    .astype("string")
    .str.strip()
    .replace("", pd.NA)
    .fillna(data["record_id"])
)
data
# Out:
#                                    record_id  \
# 0        crossref::10.1002/essoar.10500000.1
# 1        crossref::10.1002/essoar.10500002.1
# 2        crossref::10.1002/essoar.10500004.1
# 3        crossref::10.1002/essoar.10500007.1
# 4        crossref::10.1002/essoar.10500009.1
# ...                                      ...
# 7905694                 openalex::W999921877
# 7905695                 openalex::W999947037
# 7905696                 openalex::W999974616
# 7905697                 openalex::W999989114
# 7905698                 openalex::W999989584
#
#                                   server_name   backend  \
# 0        Earth and Space Science Open Archive  crossref
# 1        Earth and Space Science Open Archive  crossref
# 2        Earth and Space Science Open Archive  crossref
# 3        Earth and Space Science Open Archive  crossref
# 4        Earth and Space Science Open Archive  crossref
# ...                                       ...       ...
# 7905694   RePEc: Research Papers in Economics  openalex
# 7905695                                   HAL  openalex
# 7905696   RePEc: Research Papers in Economics  openalex
# 7905697                                   HAL  openalex
# 7905698   RePEc: Research Papers in Economics  openalex
#
#                                doi                                    doi_url  \
# 0        10.1002/essoar.10500000.1  https://doi.org/10.1002/essoar.10500000.1
# 1        10.1002/essoar.10500002.1  https://doi.org/10.1002/essoar.10500002.1
# 2        10.1002/essoar.10500004.1  https://doi.org/10.1002/essoar.10500004.1
# 3        10.1002/essoar.10500007.1  https://doi.org/10.1002/essoar.10500007.1
# 4        10.1002/essoar.10500009.1  https://doi.org/10.1002/essoar.10500009.1
# ...                            ...                                        ...
# 7905694                       None                                       None
# 7905695                       None                                       None
# 7905696                       None                                       None
# 7905697                       None                                       None
# 7905698                       None                                       None
#
#                                           landing_page_url type_backend_raw  \
# 0        https://essopenarchive.org/doi/full/10.1002/es...   posted-content
# 1        https://essopenarchive.org/doi/full/10.1002/es...   posted-content
# 2        https://essopenarchive.org/doi/full/10.1002/es...   posted-content
# 3        https://essopenarchive.org/doi/full/10.1002/es...   posted-content
# 4        https://essopenarchive.org/doi/full/10.1002/es...   posted-content
# ...                                                    ...              ...
# 7905694  https://steconomice.uoradea.ro/anale/volume/20...         preprint
# 7905695                   https://hal.science/hal-01922484         preprint
# 7905696   https://EconPapers.repec.org/RePEc:cde:cdewps:19         preprint
# 7905697                   https://hal.science/hal-01268467         preprint
# 7905698  http://thred.devecon.org/papers/2014/2014-018_...         preprint
#
#         subtype_backend_raw  \
# 0                  preprint
# 1                  preprint
# 2                  preprint
# 3                  preprint
# 4                  preprint
# ...                     ...
# 7905694                None
# 7905695                None
# 7905696                None
# 7905697                None
# 7905698                None
#
#                                                      title  \
# 0        Long-term monitoring of land surface phenologi...
# 1        Impact of spatial scale for phenological indic...
# 2        Observations of Low Latitude Red Aurora in Mex...
# 3        Pipeline oil fire detection with MODIS active ...
# 4        Land Product Validation of MODIS Derived FPAR ...
# ...                                                    ...
# 7905694  IDE sous l'influence du degré de l'intégration...
# 7905695  Building realistic potential patients queries ...
# 7905696  Debt Financing with Limited Liability and Quan...
# 7905697  Sustainable orchards' redesign: at the crossro...
# 7905698  When warm glow burns: Motivational (mis)alloca...
#
#                                               authors_flat  \
# 0                                     Tsutsumida, Narumasa
# 1                        Tsutsumida, Narumasa; Kaduk, Jörg
# 2        Gonzalez-Esparza, J. Americo; Cuevas-Cardona, ...
# 3        Ogungbuyi, Michael Gbenga; Martinez, Peter; Ec...
# 4        Sharp, Iain; Sanchez-Azofeifa, Arturo; Musilek...
# ...                                                    ...
# 7905694                        Simona-Gabriela Serbu Masca
# 7905695  Lorraine Goeuriot; Wendy W. Chapman; Gareth Jf...
# 7905696                          Krishnendu Ghosh Dastidar
# 7905697  Servane Penvern; Sylvaine Simon; Stéphane Bell...
# 7905698  Gani Aldashev; Esteban Jaimovich; Thierry Verdier
#
#                                          institutions_flat  countries_flat  \
# 0                                                     None            None
# 1                                                     None            None
# 2               Universidad Autónoma del Estado de Hidalgo            None
# 3                                                     None            None
# 4                                                     None            None
# ...                                                    ...             ...
# 7905694                            Babeș-Bolyai University              RO
# 7905695  Laboratoire d'Informatique de Grenoble; Dublin...          FR; IE
# 7905696                                               None            None
# 7905697  Institut National de Recherche pour l'Agricult...              FR
# 7905698  University of Namur; University of Surrey; Éco...  BE; GB; BI; FR
#
#                                             relations_json version_label  \
# 0                                                     None          None
# 1                                                     None          None
# 2        {"is-preprint-of": [{"asserted-by": "subject",...          None
# 3                                                     None          None
# 4                                                     None          None
# ...                                                    ...           ...
# 7905694                                               None          None
# 7905695                                               None          None
# 7905696                                               None          None
# 7905697                                               None          None
# 7905698                                               None          None
#
#         is_version_of        is_preprint_of has_preprint has_review  \
# 0                None
# 1                None
# 2                None  10.1029/2018sw001995
# 3                None
# 4                None
# ...               ...                   ...          ...        ...
# 7905694          None                  None         None       None
# 7905695          None                  None         None       None
# 7905696          None                  None         None       None
# 7905697          None                  None         None       None
# 7905698          None                  None         None       None
#
#         has_published_version published_version_ids_json version_of_ids_json  \
# 0                       false                       None                None
# 1                       false                       None                None
# 2                        true                       None                None
# 3                       false                       None                None
# 4                       false                       None                None
# ...                       ...                        ...                 ...
# 7905694                  None                       None                None
# 7905695                  None                       None                None
# 7905696                  None                       None                None
# 7905697                  None                       None                None
# 7905698                  None                       None                None
#
#         update_to_json raw_relationships_json records_hierarchy  \
# 0                 None                   None            parent
# 1                 None                   None            parent
# 2                 None                   None            parent
# 3                 None                   None            parent
# 4                 None                   None            parent
# ...                ...                    ...               ...
# 7905694           None                   None            parent
# 7905695           None                   None            parent
# 7905696           None                   None            parent
# 7905697           None                   None            parent
# 7905698           None                   None            parent
#
#         date_first_seen  publication_year  publication_year_first_seen  \
# 0            2018-05-24            2018.0                         2018
# 1            2018-05-27            2018.0                         2018
# 2            2018-05-28            2018.0                         2018
# 3            2018-05-30            2018.0                         2018
# 4            2018-06-05            2018.0                         2018
# ...                 ...               ...                          ...
# 7905694      2008-01-01            2008.0                         2008
# 7905695      2014-01-01            2014.0                         2014
# 7905696      1994-08-01            1994.0                         1994
# 7905697      2012-07-01            2012.0                         2012
# 7905698      2015-02-01            2015.0                         2015
#
#         raw_dates records_hierarchy_backup parent_record_id  \
# 0            None                   parent             None
# 1            None                   parent             None
# 2            None                   parent             None
# 3            None                   parent             None
# 4            None                   parent             None
# ...           ...                      ...              ...
# 7905694      None                   parent             None
# 7905695      None                   parent             None
# 7905696      None                   parent             None
# 7905697      None                   parent             None
# 7905698      None                   parent             None
#
#                                 dup_group_id  \
# 0        crossref::10.1002/essoar.10500000.1
# 1        crossref::10.1002/essoar.10500002.1
# 2        crossref::10.1002/essoar.10500004.1
# 3        crossref::10.1002/essoar.10500007.1
# 4        crossref::10.1002/essoar.10500009.1
# ...                                      ...
# 7905694                 openalex::W999921877
# 7905695                 openalex::W999947037
# 7905696                 openalex::W999974616
# 7905697                 openalex::W999989114
# 7905698                 openalex::W999989584
#
#                                      authors_fp_tokenbag  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 7905694                      gabriela_masca_serbu_simona
# 7905695                                             None
# 7905696                        dastidar_ghosh_krishnendu
# 7905697                                             None
# 7905698  aldashev_gani;esteban_jaimovich;thierry_verdier
#
#                                             title_clean_v2  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 7905694  ide sous l influence du degre de l integration...
# 7905695                                               None
# 7905696  debt financing with limited liability and quan...
# 7905697                                               None
# 7905698  when warm glow burns motivational mis allocati...
#
#                   authors_fp_last_initial authors_fp_last  \
# 0                                    None            None
# 1                                    None            None
# 2                                    None            None
# 3                                    None            None
# 4                                    None            None
# ...                                   ...             ...
# 7905694                           masca|s            None
# 7905695                              None            None
# 7905696                        dastidar|k            None
# 7905697                              None            None
# 7905698  aldashev|g;jaimovich|e;verdier|t            None
#
#         records_hierarchy_dedupe_backup parent_record_id_dedupe_backup  \
# 0                                parent                           None
# 1                                parent                           None
# 2                                parent                           None
# 3                                parent                           None
# 4                                parent                           None
# ...                                 ...                            ...
# 7905694                          parent                           None
# 7905695                          parent                           None
# 7905696                          parent                           None
# 7905697                          parent                           None
# 7905698                          parent                           None
#
#         dup_group_id_dedupe_backup has_version_dois  \
# 0                             None             None
# 1                             None             None
# 2                             None             None
# 3                             None             None
# 4                             None             None
# ...                            ...              ...
# 7905694                       None             None
# 7905695                       None             None
# 7905696                       None             None
# 7905697                       None             None
# 7905698                       None             None
#
#         records_hierarchy_unify_version_backup  \
# 0                                       parent
# 1                                       parent
# 2                                       parent
# 3                                       parent
# 4                                       parent
# ...                                        ...
# 7905694                                 parent
# 7905695                                 parent
# 7905696                                 parent
# 7905697                                 parent
# 7905698                                 parent
#
#         parent_record_id_unify_version_backup  \
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# ...                                       ...
# 7905694                                  None
# 7905695                                  None
# 7905696                                  None
# 7905697                                  None
# 7905698                                  None
#
#         dup_group_id_unify_version_backup
# 0                                    None
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# ...                                   ...
# 7905694                              None
# 7905695                              None
# 7905696                              None
# 7905697                              None
# 7905698                              None
#
# [7905699 rows x 42 columns]

# %%
data[data['dup_group_id'].isna()]
# Out:
# Empty DataFrame
# Columns: [record_id, server_name, backend, doi, doi_url, landing_page_url, type_backend_raw, subtype_backend_raw, title, authors_flat, institutions_flat, countries_flat, relations_json, version_label, is_version_of, is_preprint_of, has_preprint, has_review, has_published_version, published_version_ids_json, version_of_ids_json, update_to_json, raw_relationships_json, records_hierarchy, date_first_seen, publication_year, publication_year_first_seen, raw_dates, records_hierarchy_backup, parent_record_id, dup_group_id, authors_fp_tokenbag, title_clean_v2, authors_fp_last_initial, authors_fp_last, records_hierarchy_dedupe_backup, parent_record_id_dedupe_backup, dup_group_id_dedupe_backup, has_version_dois, records_hierarchy_unify_version_backup, parent_record_id_unify_version_backup, dup_group_id_unify_version_backup]
# Index: []

# %% [markdown]
# # execution

# %%
SHEET_ID = "10_7FdcpZjntqFsEHIii7bAM72uF__of_iUohSD5w8w4"
GID = "582500270"   # your tab gid

sheet_url = f"https://docs.google.com/spreadsheets/d/{SHEET_ID}/export?format=csv&gid={GID}"

sheet_df = pd.read_csv(sheet_url)

sheet_df.head()
# Out:
#        source_id open_alex_source_id  InternalOrder      SourceOrig  \
# 0        Advance                 NaN              1  1Original list
# 1     AfricArXiv                 NaN              2  1Original list
# 2  AgEcon Search                 NaN              3  1Original list
# 3       AgriRxiv                 NaN              4  1Original list
# 4            NaN                 NaN              5  1Original list
#
#                            Server Name  \
# 0  Advance: a SAGE Preprints Community
# 1                           AfricArxiv
# 2                        AgEcon Search
# 3          AgriRxiv (formerly AgriXiv)
# 4                         ai.vixra.org
#
#                           Server Name Rule File  \
# 0                                       Advance
# 1                                    AfricArXiv
# 2  AgEcon Search (University of Minnesota, USA)
# 3                                      AgriRxiv
# 4                                  ai.vixra.org
#
#                                                Notes Registration Agencies  \
# 0                                                NaN              Crossref
# 1                                                NaN     Crossref/DataCite
# 2  no preprint group on main website or on dataci...              DataCite
# 3  Preprints for Agriculture and Allied Sciences ...              Crossref
# 4                                                NaN                no doi
#
#   Where to get metadata ?                                   Example URLs/DOI  \
# 0                Crossref  ['https://doi.org/10.31124/advance.172059085.5...
# 1                Crossref  ['https://doi.org/10.31730/osf.io/7n258', 'htt...
# 2                DataCite  https://openalex.org/works?page=1&filter=prima...
# 3                Crossref  ['https://doi.org/10.31220/osf.io/87k3q', 'htt...
# 4             API website                          https://ai.vixra.org/hep/
#
#     synonym Electronic\nISSN / ISBN  Source to obtain Red Columns  \
# 0   Advance                     NaN                      Crossref
# 1       NaN                     NaN             Crossref/Datacite
# 2       NaN               2332-3140                      DataCite
# 3  AgriRxiv               2791-1969                      Crossref
# 4       NaN                     NaN                       Website
#
#                                           Column 134 Column 135 download rule  \
# 0  https://api.crossref.org/works?filter=type:pos...         ok            ok
# 1  https://api.datacite.org/dois?client-id=eqhh.h...         ok            ok
# 2  https://api.datacite.org/dois?client-id=tind.a...         ok            ok
# 3  https://api.crossref.org/works?filter=type:pos...         ok            ok
# 4                                                NaN         ok             /
#
#   Collection Date used for Red Columns number of unique preprints  \
# 0                           31/12/2025                       2440
# 1                           31/12/2025                        483
# 2                           31/12/2025                     172831
# 3                           31/12/2025                        804
# 4                           10/12/2025                        966
#
#    number of unique preprints that are published  \
# 0                                          162.0
# 1                                           56.0
# 2                                           53.0
# 3                                           24.0
# 4                                            NaN
#
#    % of unique that are published   \
# 0                         6.639344
# 1                        11.594203
# 2                         0.030666
# 3                         2.985075
# 4                              NaN
#
#    Number of unique preprints with more than 1 version  \
# 0                                             1788.0
# 1                                               68.0
# 2                                            27568.0
# 3                                              132.0
# 4                                                NaN
#
#    % of unique that have more than one version  Is the Server in Crossref  \
# 0                                     73.278689                      True
# 1                                     14.078675                      True
# 2                                     15.950842                     False
# 3                                     16.417910                      True
# 4                                           NaN                        No
#
#                              Example DOI in Crossref  \
# 0  ['https://doi.org/10.31124/advance.172059085.5...
# 1  ['https://doi.org/10.31730/osf.io/7n258', 'htt...
# 2                                                NaN
# 3  ['https://doi.org/10.31220/osf.io/87k3q', 'htt...
# 4                                                NaN
#
#                                API Query in Crossref Crossref collection_date  \
# 0  https://api.crossref.org/works/10.31124/advanc...               31/12/2025
# 1  https://api.crossref.org/works/10.31730/osf.io...               31/12/2025
# 2                                                NaN               2025/12/31
# 3  https://api.crossref.org/works/10.31220/osf.io...               31/12/2025
# 4                                                NaN                      NaN
#
#    Number of works in Crossref Number of unique preprints in Crossref  \
# 0                       4400.0                                  2,440
# 1                        501.0                                    483
# 2                          NaN                                    NaN
# 3                        818.0                                    804
# 4                          NaN                                    NaN
#
#   Remarks in Crossref  \
# 0                  ok
# 1                  ok
# 2                 NaN
# 3                  ok
# 4                 NaN
#
#    Number of unique preprints that are published in Crossref  \
# 0                                              162.0
# 1                                               56.0
# 2                                                NaN
# 3                                               24.0
# 4                                                NaN
#
#    %_of unique that are published in Crossref  \
# 0                                    6.639344
# 1                                   11.594203
# 2                                         NaN
# 3                                    2.985075
# 4                                         NaN
#
#    Number of unique preprints with more than 1 version in Crossref  \
# 0                                             1788.0
# 1                                               68.0
# 2                                                NaN
# 3                                              132.0
# 4                                                NaN
#
#    % of unique that have more than one version  in Crossref  \
# 0                                          73.278689
# 1                                          14.078675
# 2                                                NaN
# 3                                          16.417910
# 4                                                NaN
#
#    Works_in_2024 in Crossref  Works_in_2025 in Crossref  Notes for Crossref  \
# 0                      414.0                      346.0                 NaN
# 1                       16.0                        0.0                 NaN
# 2                        NaN                        NaN                 NaN
# 3                       69.0                       93.0                 NaN
# 4                        NaN                        NaN                 NaN
#
#   Is the server in DataCite     ExampleDOI in DataCite  \
# 0                     False                        NaN
# 1                     False  10.60763/africarxiv/10352
# 2                      True    10.22004/ag.econ.151297
# 3                     False                        NaN
# 4                        No                        NaN
#
#                               API Query for DataCite DataCite Collection Date  \
# 0                                                NaN               2025/12/31
# 1  https://api.datacite.org/dois?client-id=eqhh.h...               31/12/2025
# 2  https://api.datacite.org/dois?client-id=tind.a...               31/12/2025
# 3                                                NaN               2025/12/31
# 4                                                NaN                      NaN
#
#   Number of works in DataCite number_of_preprint_unique in DataCite  \
# 0                         NaN                                   NaN
# 1                         NaN                                   NaN
# 2                     188,173                               172,831
# 3                         NaN                                   NaN
# 4                         NaN                                   NaN
#
#    Remarks DataCite  \
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
#    number of unique preprints that are published in Datacite  \
# 0                                                NaN
# 1                                                NaN
# 2                                               53.0
# 3                                                NaN
# 4                                                NaN
#
#    %_of unique that are published in DataCite  \
# 0                                         NaN
# 1                                         NaN
# 2                                    0.030666
# 3                                         NaN
# 4                                         NaN
#
#    Number of unique preprints with more than 1 version in DataCite  \
# 0                                                NaN
# 1                                                NaN
# 2                                            27568.0
# 3                                                NaN
# 4                                                NaN
#
#    % of unique that have more than one version  in DataCite  \
# 0                                                NaN
# 1                                                NaN
# 2                                          15.950842
# 3                                                NaN
# 4                                                NaN
#
#    Works_in_2024 in DataCite  Works_in_2025 in DataCite  Notes for DataCite  \
# 0                        NaN                        NaN                 NaN
# 1                        NaN                        NaN                 NaN
# 2                     8072.0                     9054.0                 NaN
# 3                        NaN                        NaN                 NaN
# 4                        NaN                        NaN                 NaN
#
#   Is the server in OpenAlex                       Example DOI in OpenAlex  \
# 0                     False  https://doi.org/10.31124/advance.13491510.v1
# 1                     False                       10.60763/africarxiv/357
# 2                     False       https://doi.org/10.22004/ag.econ.273723
# 3                     False  https://doi.org/10.31220/agrirxiv.2024.00228
# 4                        no                                        no doi
#
#                               API Querry in OpenAlex  \
# 0               https://api.openalex.org/w4212857168
# 1  https://api.openalex.org/works?page=1&filter=p...
# 2  https://api.openalex.org/works?page=1&filter=p...
# 3  https://openalex.org/works?page=1&filter=prima...
# 4                                                  /
#
#   OpenAlex Data Collection Date Number of works in OpenAlex  \
# 0                    31/12/2025                         NaN
# 1                    31/12/2025                         NaN
# 2                    31/12/2025                         NaN
# 3                    31/12/2025                         NaN
# 4                    12/12/2025                           /
#
#   number_of_preprint_unique in OpenAlex  Remarks  OpenAlex  \
# 0                                   NaN                NaN
# 1                                   NaN                NaN
# 2                                   NaN                NaN
# 3                                   NaN                NaN
# 4                                     /                NaN
#
#    number of unique preprints that are published in OpenAlex  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    %_of unique that are published in OpenAlex  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Number of unique preprints with more than 1 version in OpenAlex  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    % of unique preprints with more than 1 version in OpenAlex  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Works_in_2024 in OpenAlex  Works_in_2025 in OpenAlex OpenAlex notes  \
# 0                        NaN                        NaN            NaN
# 1                        NaN                        NaN            NaN
# 2                        NaN                        NaN            NaN
# 3                        NaN                        NaN            NaN
# 4                        NaN                        NaN            NaN
#
#                            ExampleDOI on server page  \
# 0  https://doi.org/10.31124/advance.176303470.009...
# 1          https://doi.org/10.60763/africarxiv/10286
# 2            https://doi.org/10.22004/ag.econ.382416
# 3       https://doi.org/10.31220/agriRxiv.2020.00005
# 4                                             no doi
#
#                            API Querry on Server Page  \
# 0                                                NaN
# 1  https://api.osf.io/v2/providers/preprints/afri...
# 2                 https://ageconsearch.umn.edu/oai2d
# 3  https://api.osf.io/v2/providers/preprints/arab...
# 4                                                NaN
#
#   ServerPage Data Collection Date Number of Works on Server Page  \
# 0                      15/12/2025                          2,384
# 1                      15/12/2025                          7,944
# 2                      15/12/2025                        211,648
# 3                      15/12/2025                            464
# 4                      15/12/2025                            988
#
#   number_of_preprint_unique on Server Page Remarks  Server Page  \
# 0                          no types filter                  NaN
# 1                          no types filter                  NaN
# 2                          no types filter                  NaN
# 3                                      462                  NaN
# 4                          no types filter                  NaN
#
#    number of unique preprints that are published on Server Page  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    %_of unique that are published on Server Page  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Number of unique preprints with more than 1 version on Server Page  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    %of unique preprints with more than 1 version on Server Page  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Works_in_2024 on Server Page  Works_in_2025 on Server Page  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#   Active (in 2025)                                          API Query  \
# 0              yes                                                NaN
# 1              yes  https://api.osf.io/v2/providers/preprints/afri...
# 2               no                 https://ageconsearch.umn.edu/oai2d
# 3              yes  https://api.osf.io/v2/providers/preprints/arab...
# 4              yes                                                NaN
#
#                                             API LINK  \
# 0                                                  -
# 1  https://api.osf.io/v2/providers/preprints/afri...
# 2  https://ageconsearch.umn.edu/oai2d?verb=ListRe...
# 3                                                  -
# 4                                       ai.vixra.org
#
#   total count from sever API link Dimensions  \
# 0                               /        Yes
# 1                             480        Yes
# 2                          209243         no
# 3                             397        Yes
# 4                             567         no
#
#                                     Dimensions Query  \
# 0  https://app.dimensions.ai/discover/publication...
# 1  https://app.dimensions.ai/discover/publication...
# 2                                                NaN
# 3  https://app.dimensions.ai/discover/publication...
# 4                                                NaN
#
#                                Dimensions Query note DOI registration Agency  \
# 0                                                NaN                Crossref
# 1                                                NaN                DataCite
# 2                                                NaN                DataCite
# 3  https://app.dimensions.ai/discover/publication...                Crossref
# 4                                                NaN                  no doi
#
#   OAI-PMH URL                              Server Main Page Link  \
# 0         NaN                       https://advance.sagepub.com/
# 1         NaN              https://africarxiv.ubuntunet.net/home
# 2         NaN                https://ageconsearch.umn.edu/?ln=en
# 3         NaN  https://www.cabidigitallibrary.org/journal/agr...
# 4         NaN                              https://ai.vixra.org/
#
#   Active (in 2026) MarioDateCheck                        Who can submit text  \
# 0               No       01/15/26                                 Not Active
# 1              Yes       01/15/26                      Researcher (specific)
# 2               No       01/15/26  Organizations, not individual researchers
# 3              Yes       01/15/26                                 Researcher
# 4              Yes       01/15/26                                 Researcher
#
#   Researcher can submit Accepts Preprints ONLY  \
# 0            Not Active                    Yes
# 1                   Yes                     No
# 2                    No                     No
# 3                   Yes                    Yes
# 4                   Yes                    Yes
#
#                           Type of documents accepted  \
# 0                                     Preprints only
# 1  working papers, preprints, accepted manuscript...
# 2  articles, conference papers, working or discus...
# 3                                     Preprints only
# 4                                     Preprints only
#
#   Publish - Review - Curate models Date of Check  \
# 0                               No      08/30/25
# 1                               No      08/30/25
# 2                               No      08/30/25
# 3                               No      08/30/25
# 4                               No      08/30/25
#
#   Definition of server/platform on the main page (Y/N)  \
# 0                                                  Y
# 1                                                  Y
# 2                                                  N
# 3                                                  Y
# 4                                                  Y
#
#   Text of the Definition of the server/platform on the main page   \
# 0  Advance: a Sage preprints community allows res...
# 1  AfricArxiv is a community-led digital archive ...
# 2                                                NaN
# 3  agriRxiv (pronounced ‘agri-archive’) is a free...
# 4  ai.viXra.org is an e-print archive of AI assis...
#
#           SelfDefinitiononMainPage Definition on non-main page  \
# 0              preprints community                         NaN
# 1    community-led digital archive                         NaN
# 2                              NaN              web repository
# 3  source of unpublished preprints                         NaN
# 4                  e-print archive                         NaN
#
#                            Non-main source and notes  \
# 0                                                NaN
# 1  Very inconsistent termonology across their var...
# 2  From their FAQ:  ".. is free-to-user Web site ...
# 3                                                NaN
# 4                                                NaN
#
#   Definition of preprint on main page (Y/N)  \
# 0                                         Y
# 1                                         N
# 2                                         N
# 3                                         N
# 4                                         N
#
#                          Text of Preprint definition  \
# 0  A preprint is a version of a scholarly piece o...
# 1  A preprint is a version of a scholarly or scie...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Classified as 1- preprint, 2-eprint, 3-working, 4--   \
# 0                                                1.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Any Warning message on main page  \
# 0                                Y
# 1                                N
# 2                                N
# 3                                N
# 4                                Y
#
#                                      Text of message  \
# 0  Papers posted to Advance or transportRxiv shou...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  ai.viXra.org has no association with arXiv.org...
#
#                             Link of preprint checked  \
# 0  https://advance.sagepub.com/doi/full/10.31124/...
# 1  https://africarxiv.ubuntunet.net/items/e85a94c...
# 2   https://ageconsearch.umn.edu/record/358968?v=pdf
# 3  https://www.cabidigitallibrary.org/doi/10.3122...
# 4                 https://ai.vixra.org/abs/2508.0021
#
#   Any Warning on a single preprint page  \
# 0                                     Y
# 1                                     N
# 2                                     N
# 3                                     N
# 4                                     Y
#
#                          Text of single page warning  \
# 0  Preprints are early versions of research artic...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  ai.Vixra.org is a AI assisted e-print reposito...
#
#    Any warning on the text of COVID 19 page  Text of COVID page warning  \
# 0                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
#
#                 Do they have a general warning label  \
# 0  Preprints are early versions of research artic...
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                               yes
#
#                               Notes on warning label  \
# 0  Papers posted to Advance or transportRxiv shou...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  ai.Vixra.org is a AI assisted e-print reposito...
#
#   Is there a separate warning label for medical preprints  \
# 0                                                NaN
# 1                                                 No
# 2                                                NaN
# 3                                                NaN
# 4                                                 no
#
#                                    Types can identify peer reviewed version  \
# 0  Primary submission preprint platforms                                NaN
# 1                                    NaN                                NaN
# 2                             repository                                NaN
# 3  Primary submission preprint platforms                                NaN
# 4  Primary submission preprint platforms                                NaN
#
#   Review Type Publications can be submitted elsewhere   \
# 0         NaN                                      NaN
# 1         NaN                                      NaN
# 2         NaN                                      NaN
# 3         NaN                                      NaN
# 4         NaN                                      NaN
#
#                                           File types Who has access contact  \
# 0                                                NaN            NaN     NaN
# 1  Text documents (preprints, postprints, VoR):\n...            NaN     NaN
# 2      Conference papers and posters\n    Working...            NaN     NaN
# 3  The following types of article may be posted:\...            NaN     NaN
# 4                                                NaN            NaN     NaN
#
#    Does a server allow posting of protocols, or other resaeerch parts?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Is there a separete metadata for protocols?  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   Preprint Tag for Search or metadata  \
# 0                                 yes
# 1                                 yes
# 2                                 yes
# 3                                 yes
# 4                                 NaN
#
#                                           Versioning Publication Status  \
# 0                                                NaN                NaN
# 1  We also provide options to link data and code,...                NaN
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4                                                NaN                NaN
#
#                                 Charges for Services  \
# 0                                                NaN
# 1                                                NaN
# 2  There are no costs for posting papers for grou...
# 3     There is no fee to submit articles to agriRxiv
# 4                                                NaN
#
#   is statistics available ? metrics to track their preprints Mario List  \
# 0                       NaN                              NaN        yes
# 1                       NaN                              NaN        yes
# 2                       NaN                              NaN        NaN
# 3                       yes                              NaN        yes
# 4                       NaN                              NaN        NaN
#
#   Wikipedia List Dimensions List ASAP BIO List  \
# 0            NaN             yes           yes
# 1            yes             yes           yes
# 2            NaN             NaN           NaN
# 3            yes             yes           yes
# 4            NaN             NaN           NaN
#
#   Directory of Open Access Preprint Repositories  List  \
# 0                                                yes
# 1                                                yes
# 2                                                yes
# 3                                                yes
# 4                                                NaN
#
#   State University of Campinas   \
# 0                           NaN
# 1                           yes
# 2                           NaN
# 3                           yes
# 4                           NaN
#
#                                   Disciplinary scope  \
# 0                     Humanities and Social Sciences
# 1                              All scientific fields
# 2       Relating to agricultural & applied economics
# 3  Relating to agriculture and allied sciences, i...
# 4                                                NaN
#
#              Ownership type  \
# 0                 Publisher
# 1  Academic community group
# 2      Academic institution
# 3  Academic community group
# 4                       NaN
#
#                                  Screening processes  \
# 0  Content within scope, scholarly nature, manusc...
# 1                                                NaN
# 2                                                NaN
# 3  Content within scope, no inappropriate materia...
# 4                                                NaN
#
#                Additional notes on screening process  \
# 0  Preprints must include a research question or ...
# 1  No information on screening on the new website...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                            External content indexing  \
# 0                           Google Scholar, CrossRef
# 1  Google Scholar, SHARE, Microsoft Academic, Unp...
# 2                                                NaN
# 3  Google Scholar, Crossref, Researcher-app; Prep...
# 4                                                NaN
#
#                                Permanence of content         Commenting
# 0  Permanent with some removal options in excepti...         Commenting
# 1  Permanent with some removal options in excepti...  no (on UbuntuNet)
# 2  Permanent with some removal options in special...                 no
# 3  Permanent with withdrawal marking; articles ca...                no
# 4                                                NaN                NaN

# %%
# ============================================
# 5) RUN PIPELINE (edit these 4 things)
# ============================================

SHEET_ID = "10_7FdcpZjntqFsEHIii7bAM72uF__of_iUohSD5w8w4"
WORKSHEET_GID = 881157301 # test copy database sheet 582500270

# 1) put your service account json path here
SERVICE_ACCOUNT_JSON = "sheet_writer_key/preprint-tracker-credential.json"
# SERVICE_ACCOUNT_JSON =  '/mnt/c/SCHOLCOMMLAB/APPs/preprint-harvester/notebooks/notebooks/sheet_writer_key/preprint-tracker-credential.json'
# 2) your target columns exactly as in the sheet (including trailing spaces)
TARGET_COLS = [
    'Collection Date used for Red Columns',
    'number of unique preprints',
    'number of unique preprints that are published',
    '% of unique that are published ',
    'Number of unique preprints with more than 1 version',
    '% of unique that have more than one version ',
    'Is the Server in Crossref',
    'Crossref collection_date',
    'Number of works in Crossref',
    'Number of unique preprints in Crossref',
    'Number of unique preprints that are published in Crossref',
    '%_of unique that are published in Crossref',
    'Number of unique preprints with more than 1 version in Crossref',
    '% of unique that have more than one version  in Crossref',
    'Works_in_2024 in Crossref',
    'Works_in_2025 in Crossref',
    'Is the server in DataCite',
    'DataCite Collection Date',
    'Number of works in DataCite',
    'number_of_preprint_unique in DataCite',
    'number of unique preprints that are published in Datacite',
    '%_of unique that are published in DataCite',
    'Number of unique preprints with more than 1 version in DataCite',
    '% of unique that have more than one version  in DataCite',
    'Works_in_2024 in DataCite',
    'Works_in_2025 in DataCite',
    'Is the server in OpenAlex',
    'OpenAlex Data Collection Date',
    'Number of works in OpenAlex',
    'number_of_preprint_unique in OpenAlex',
    'number of unique preprints that are published in OpenAlex',
    '%_of unique that are published in OpenAlex',
    'Number of unique preprints with more than 1 version in OpenAlex',
    '% of unique preprints with more than 1 version in OpenAlex',
    'Works_in_2024 in OpenAlex',
    'Works_in_2025 in OpenAlex',
]

# 3) choose the collection date you want for all servers
DEFAULT_COLLECTION_DATE = "2025/12/31"

# 4) optional later: per server overrides (keep None for now)
PER_SERVER_DATE = None
# Example:
# PER_SERVER_DATE = {"bioRxiv": "2026/01/15", "medRxiv": "2026/01/15"}


# =========================
# Step A: compute metrics
# =========================
# IMPORTANT: 'data' must be your dedupe long dataframe in memory
overall_df, backend_df = build_sheet_metrics_duckdb(data, choose_parent="oldest")

# =========================
# Step B: read the sheet
# =========================
sheet_df = read_sheet_as_df(
    sheet_id=SHEET_ID,
    worksheet_gid=WORKSHEET_GID,
    service_account_json_path=SERVICE_ACCOUNT_JSON,
)

# =========================
# Step C: build payload (only key + target cols)
# =========================
payload_df = build_update_payload(
    sheet_df=sheet_df,
    overall_df=overall_df,
    backend_df=backend_df,
    target_cols=TARGET_COLS,
    key_col="source_id",
    default_collection_date=DEFAULT_COLLECTION_DATE,
    per_server_date=PER_SERVER_DATE,
)

payload_df.head()

# =========================
# Step D: update only those columns
# =========================
report = update_google_sheet_only_columns(
    sheet_id=SHEET_ID,
    worksheet_gid=WORKSHEET_GID,
    service_account_json_path=SERVICE_ACCOUNT_JSON,
    payload_df=payload_df,
    key_col="source_id",
    columns_to_update=TARGET_COLS,
    chunk_size=500,
    overwrite=True,   # set False to fill blanks only
    verbose=True,
)

report
# Out:
# Chunk 1: scanned 382 rows, wrote 13752 cells
# {'sheet_id': '10_7FdcpZjntqFsEHIii7bAM72uF__of_iUohSD5w8w4',
#  'worksheet_gid': 881157301,
#  'rows_payload': 751,
#  'rows_matched': 382,
#  'missing_keys': [''],
#  'n_missing_keys': 1,
#  'columns_updated': ['Collection Date used for Red Columns',
#   'number of unique preprints',
#   'number of unique preprints that are published',
#   '% of unique that are published ',
#   'Number of unique preprints with more than 1 version',
#   '% of unique that have more than one version ',
#   'Is the Server in Crossref',
#   'Crossref collection_date',
#   'Number of works in Crossref',
#   'Number of unique preprints in Crossref',
#   'Number of unique preprints that are published in Crossref',
#   '%_of unique that are published in Crossref',
#   'Number of unique preprints with more than 1 version in Crossref',
#   '% of unique that have more than one version  in Crossref',
#   'Works_in_2024 in Crossref',
#   'Works_in_2025 in Crossref',
#   'Is the server in DataCite',
#   'DataCite Collection Date',
#   'Number of works in DataCite',
#   'number_of_preprint_unique in DataCite',
#   'number of unique preprints that are published in Datacite',
#   '%_of unique that are published in DataCite',
#   'Number of unique preprints with more than 1 version in DataCite',
#   '% of unique that have more than one version  in DataCite',
#   'Works_in_2024 in DataCite',
#   'Works_in_2025 in DataCite',
#   'Is the server in OpenAlex',
#   'OpenAlex Data Collection Date',
#   'Number of works in OpenAlex',
#   'number_of_preprint_unique in OpenAlex',
#   'number of unique preprints that are published in OpenAlex',
#   '%_of unique that are published in OpenAlex',
#   'Number of unique preprints with more than 1 version in OpenAlex',
#   '% of unique preprints with more than 1 version in OpenAlex',
#   'Works_in_2024 in OpenAlex',
#   'Works_in_2025 in OpenAlex'],
#  'overwrite': True,
#  'cells_written': 13752,
#  'chunks': 1}

# %% [markdown]
# # exploration

# %%
payload_df
# Out:
#           source_id Collection Date used for Red Columns  \
# 0           Advance                           2025/12/31
# 1        AfricArXiv                           2025/12/31
# 2     AgEcon Search                           2025/12/31
# 3          AgriRxiv                           2025/12/31
# 4    AIJR Preprints                           2025/12/31
# ..              ...                                  ...
# 746        cngb.cga                           2025/12/31
# 747         cos.osf                           2025/12/31
# 748                                           2025/12/31
# 749                                           2025/12/31
# 750                                           2025/12/31
#
#     number of unique preprints number of unique preprints that are published  \
# 0                       2484.0                                         159.0
# 1                       1684.0                                          56.0
# 2                     132736.0                                          51.0
# 3                        811.0                                          23.0
# 4                        143.0                                           0.0
# ..                         ...                                           ...
# 746
# 747
# 748
# 749
# 750
#
#     % of unique that are published   \
# 0                          6.400966
# 1                          3.325416
# 2                          0.038422
# 3                          2.836005
# 4                               0.0
# ..                              ...
# 746
# 747
# 748
# 749
# 750
#
#     Number of unique preprints with more than 1 version  \
# 0                                               1787.0
# 1                                                517.0
# 2                                              25090.0
# 3                                                128.0
# 4                                                  8.0
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     % of unique that have more than one version   Is the Server in Crossref  \
# 0                                      71.940419                       True
# 1                                      30.700713                       True
# 2                                      18.902182                      False
# 3                                      15.782984                       True
# 4                                       5.594406                       True
# ..                                           ...                        ...
# 746                                                                   False
# 747                                                                   False
# 748                                                                   False
# 749                                                                   False
# 750                                                                   False
#
#     Crossref collection_date Number of works in Crossref  \
# 0                 2025/12/31                      4400.0
# 1                 2025/12/31                       501.0
# 2                 2025/12/31
# 3                 2025/12/31                       818.0
# 4                 2025/12/31                       143.0
# ..                       ...                         ...
# 746               2025/12/31
# 747               2025/12/31
# 748               2025/12/31
# 749               2025/12/31
# 750               2025/12/31
#
#     Number of unique preprints in Crossref  \
# 0                                   2484.0
# 1                                    487.0
# 2
# 3                                    809.0
# 4                                    143.0
# ..                                     ...
# 746
# 747
# 748
# 749
# 750
#
#     Number of unique preprints that are published in Crossref  \
# 0                                                159.0
# 1                                                 49.0
# 2
# 3                                                 23.0
# 4                                                  0.0
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     %_of unique that are published in Crossref  \
# 0                                     6.400966
# 1                                    10.061602
# 2
# 3                                     2.843016
# 4                                          0.0
# ..                                         ...
# 746
# 747
# 748
# 749
# 750
#
#     Number of unique preprints with more than 1 version in Crossref  \
# 0                                               1787.0
# 1                                                436.0
# 2
# 3                                                127.0
# 4                                                  8.0
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     % of unique that have more than one version  in Crossref  \
# 0                                            71.940419
# 1                                            89.527721
# 2
# 3                                            15.698393
# 4                                             5.594406
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     Works_in_2024 in Crossref Works_in_2025 in Crossref  \
# 0                       416.0                     346.0
# 1                        16.0                       0.0
# 2
# 3                        70.0                      93.0
# 4                         6.0                       5.0
# ..                        ...                       ...
# 746
# 747
# 748
# 749
# 750
#
#      Is the server in DataCite DataCite Collection Date  \
# 0                        False               2025/12/31
# 1                         True               2025/12/31
# 2                         True               2025/12/31
# 3                         True               2025/12/31
# 4                        False               2025/12/31
# ..                         ...                      ...
# 746                      False               2025/12/31
# 747                      False               2025/12/31
# 748                      False               2025/12/31
# 749                      False               2025/12/31
# 750                      False               2025/12/31
#
#     Number of works in DataCite number_of_preprint_unique in DataCite  \
# 0
# 1                        1683.0                                1630.0
# 2                      140392.0                              132736.0
# 3                          40.0                                  38.0
# 4
# ..                          ...                                   ...
# 746
# 747
# 748
# 749
# 750
#
#     number of unique preprints that are published in Datacite  \
# 0
# 1                                                 53.0
# 2                                                 51.0
# 3                                                  0.0
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     %_of unique that are published in DataCite  \
# 0
# 1                                     3.251534
# 2                                     0.038422
# 3                                          0.0
# 4
# ..                                         ...
# 746
# 747
# 748
# 749
# 750
#
#     Number of unique preprints with more than 1 version in DataCite  \
# 0
# 1                                                514.0
# 2                                              25090.0
# 3                                                 37.0
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     % of unique that have more than one version  in DataCite  \
# 0
# 1                                            31.533742
# 2                                            18.902182
# 3                                            97.368421
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     Works_in_2024 in DataCite Works_in_2025 in DataCite  \
# 0
# 1                       166.0                     215.0
# 2                      2782.0                    4949.0
# 3                         0.0                       0.0
# 4
# ..                        ...                       ...
# 746
# 747
# 748
# 749
# 750
#
#      Is the server in OpenAlex OpenAlex Data Collection Date  \
# 0                        False                    2025/12/31
# 1                        False                    2025/12/31
# 2                        False                    2025/12/31
# 3                        False                    2025/12/31
# 4                        False                    2025/12/31
# ..                         ...                           ...
# 746                      False                    2025/12/31
# 747                      False                    2025/12/31
# 748                      False                    2025/12/31
# 749                      False                    2025/12/31
# 750                      False                    2025/12/31
#
#     Number of works in OpenAlex number_of_preprint_unique in OpenAlex  \
# 0
# 1
# 2
# 3
# 4
# ..                          ...                                   ...
# 746
# 747
# 748
# 749
# 750
#
#     number of unique preprints that are published in OpenAlex  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     %_of unique that are published in OpenAlex  \
# 0
# 1
# 2
# 3
# 4
# ..                                         ...
# 746
# 747
# 748
# 749
# 750
#
#     Number of unique preprints with more than 1 version in OpenAlex  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     % of unique preprints with more than 1 version in OpenAlex  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     Works_in_2024 in OpenAlex Works_in_2025 in OpenAlex
# 0
# 1
# 2
# 3
# 4
# ..                        ...                       ...
# 746
# 747
# 748
# 749
# 750
#
# [751 rows x 37 columns]

# %%
overall_df.head(60)
# Out:
#                                           server_name  n_records  n_unique  \
# 0                                      AIJR Preprints        143       143
# 1                                  AMRC Open Research        101        71
# 2                                      APSA Preprints       1470      1171
# 3                                     ARPHA Preprints        890       870
# 4                                             ART-Dok       9648      9567
# 5                                             Advance       4400      2484
# 6                                          AfricArXiv       2184      1684
# 7                                       AgEcon Search     140392    132736
# 8                                            AgriRxiv        858       811
# 9                                            Arabixiv        584       506
# 10                                      Authorea Inc.      61903     58978
# 11                                 Beilstein Archives        697       697
# 12                                        BioHackrXiv        139       136
# 13                                          BodoArXiv        165       157
# 14                               CERN document server       2623      2100
# 15                              Cambridge Open Engage       3090      2138
# 16                                           ChemRxiv      46475     36452
# 17                                                CoP         30        29
# 18                                          CogPrints       1498      1497
# 19                                 Covid-19 Preprints        647       453
# 20                                           CrimRxiv       2832      2722
# 21                               CrossAsia-Repository        479       459
# 22                                         DSpace@MIT      11324     11249
# 23  Digital Access to Scholarship at Harvard (DASH...       9549      9537
# 24                                   E-LIS Repository       8864      8819
# 25                                           ECSarXiv        326       302
# 26                                          EGUsphere      10458     10384
# 27                      ELPUB (Universitat Wuppertal)         41        41
# 28               Earth and Space Science Open Archive      22747     19622
# 29                                         EarthArXiv       6799      6495
# 30                                 EasyChair preprint        620       618
# 31                                         EcoEvoRxiv       2886      2845
# 32                                 EconStor Preprints      64676     64309
# 33                                            EdArXiv       2547      2329
# 34                 Electron Colloquium Comput Complex        141       140
# 35                                              EmeRI          8         8
# 36                                       Encyclopedia        166       161
# 37                                          EnerarXiv        204       203
# 38                                      F1000Research      16866     11086
# 39                                      FocUS Archive         83        80
# 40                                            Frenxiv        179       171
# 41                                Gates Open Research        862       543
# 42                                                HAL    1056415   1041309
# 43                         HANS Publication PrePrints         75        75
# 44                                  HRB Open Research       1012       655
# 45                            Humanities Commons CORE      29465     17108
# 46                     IACR Cryptology ePrint Archive      10569     10473
# 47                                           INA-Rxiv      17837     15785
# 48                                          IndiaRxiv        142       140
# 49                                     JMIR Preprints      37631     36686
# 50                                               Jxiv        779       770
# 51                        Keldysh Institute Preprints       1256      1205
# 52                            LIS Scholarship Archive        397       356
# 53         LSE Research Online Documents on Economics        119       119
# 54                                           LatArXiv        125       123
# 55                                        Law Archive       1808      1623
# 56                                  MNI Open Research         19        13
# 57                                             MarXiv        666       519
# 58                                          MediArXiv        309       299
# 59                                          MetaArXiv        880       773
#
#     n_published  pct_published  n_is_version_of  pct_has_versions  count_2024  \
# 0             0       0.000000                8          5.594406         6.0
# 1             0       0.000000               28         39.436620        16.0
# 2           160      13.663535              261         22.288642       140.0
# 3           315      36.206897               38          4.367816       184.0
# 4             3       0.031358               81          0.846660       564.0
# 5           159       6.400966             1787         71.940419       416.0
# 6            56       3.325416              517         30.700713       169.0
# 7            51       0.038422            25090         18.902182      2782.0
# 8            23       2.836005              128         15.782984        70.0
# 9           216      42.687747              102         20.158103         0.0
# 10          693       1.175014             6033         10.229238     13633.0
# 11          461      66.140603               10          1.434720        73.0
# 12            0       0.000000                4          2.941176        35.0
# 13           46      29.299363               16         10.191083        10.0
# 14         1355      64.523810             1675         79.761905        68.0
# 15          163       7.623948              697         32.600561       443.0
# 16        17022      46.697026             8305         22.783386      6932.0
# 17            5      17.241379                1          3.448276         9.0
# 18            2       0.133601               24          1.603206         0.0
# 19            0       0.000000               30          6.622517        90.0
# 20           28       1.028655              266          9.772226       370.0
# 21            0       0.000000                3          0.653595        64.0
# 22          561       4.987110              993          8.827451         0.0
# 23           30       0.314564              288          3.019818      1233.0
# 24            3       0.034017               64          0.725706        81.0
# 25           24       7.947020               37         12.251656        20.0
# 26         8261      79.555085              293          2.821649      2897.0
# 27            1       2.439024                0          0.000000        34.0
# 28         8492      43.277953             3080         15.696667      2556.0
# 29         1435      22.093918              740         11.393380       884.0
# 30           14       2.265372               79         12.783172         0.0
# 31           56       1.968366              110          3.866432       592.0
# 32            8       0.012440             6682         10.390459       138.0
# 33          285      12.237012              395         16.960069       286.0
# 34            5       3.571429               30         21.428571         0.0
# 35            0       0.000000                0          0.000000         0.0
# 36            0       0.000000                6          3.726708         0.0
# 37            3       1.477833               16          7.881773         0.0
# 38          157       1.416201             4617         41.647122      1233.0
# 39            3       3.750000               37         46.250000        10.0
# 40           64      37.426901               83         48.538012         0.0
# 41            6       1.104972              305         56.169429        48.0
# 42         2338       0.224525            24709          2.372879      4878.0
# 43            0       0.000000                0          0.000000         0.0
# 44            4       0.610687              311         47.480916        79.0
# 45         8177      47.796353            12038         70.364742      2088.0
# 46           15       0.143225              222          2.119736         0.0
# 47         1436       9.097244             2726         17.269560         0.0
# 48           17      12.142857               42         30.000000         2.0
# 49        24458      66.668484             1911          5.209072      5201.0
# 50            1       0.129870               19          2.467532       209.0
# 51            8       0.663900               61          5.062241        83.0
# 52           69      19.382022               95         26.685393         7.0
# 53            1       0.840336               18         15.126050         0.0
# 54            7       5.691057               11          8.943089        44.0
# 55          108       6.654344              675         41.589649        37.0
# 56            0       0.000000                6         46.153846         0.0
# 57          253      48.747592              158         30.443160         2.0
# 58           90      30.100334               34         11.371237        20.0
# 59          147      19.016818              204         26.390686        78.0
#
#     count_2025
# 0          5.0
# 1          5.0
# 2        214.0
# 3        211.0
# 4        494.0
# 5        346.0
# 6        215.0
# 7       4949.0
# 8         93.0
# 9          0.0
# 10     11401.0
# 11        65.0
# 12        41.0
# 13        28.0
# 14       285.0
# 15       687.0
# 16      7955.0
# 17         7.0
# 18         0.0
# 19        61.0
# 20       497.0
# 21        21.0
# 22        13.0
# 23       667.0
# 24        55.0
# 25        17.0
# 26      4276.0
# 27         7.0
# 28      3284.0
# 29      1153.0
# 30         0.0
# 31       860.0
# 32       671.0
# 33       543.0
# 34         0.0
# 35         0.0
# 36         0.0
# 37         0.0
# 38      1057.0
# 39         8.0
# 40         0.0
# 41        21.0
# 42      3847.0
# 43         0.0
# 44       124.0
# 45      1113.0
# 46         0.0
# 47         0.0
# 48         1.0
# 49      4737.0
# 50       298.0
# 51         1.0
# 52        13.0
# 53         0.0
# 54        79.0
# 55       127.0
# 56         0.0
# 57         2.0
# 58        34.0
# 59       111.0

# %%
overall_df.tail(60)
# Out:
#                                     server_name  n_records  n_unique  \
# 49                               JMIR Preprints      37631     36686
# 50                                         Jxiv        779       770
# 51                  Keldysh Institute Preprints       1256      1205
# 52                      LIS Scholarship Archive        397       356
# 53   LSE Research Online Documents on Economics        119       119
# 54                                     LatArXiv        125       123
# 55                                  Law Archive       1808      1623
# 56                            MNI Open Research         19        13
# 57                                       MarXiv        666       519
# 58                                    MediArXiv        309       299
# 59                                    MetaArXiv        880       773
# 60                                     MindRxiv        381       296
# 61                Munich Personal RePEc Archive      67263     67185
# 62         National Bureau of Economic Research       1828      1804
# 63                            Nature Precedings       5210      3270
# 64                               NewAddictionsX          7         4
# 65                                     NutriXiv         94        86
# 66                         Open Research Africa        287       190
# 67                         Open Research Europe       1877      1193
# 68                       Open Science Framework     112569    101491
# 69                              Organic Eprints      13704     13571
# 70                         Oroboros Instruments         95        69
# 71                                 PREPRINTS.RU       1415      1375
# 72                                    PaleorXiv        317       251
# 73                              PeerJ Preprints       6446      5226
# 74                              PhilSci-Archive       2167      2159
# 75                                     PoolText         79        79
# 76                                Preprints.org     115815    106432
# 77                 Prepublicaciones OpenCiencia          8         7
# 78                                PropylaeumDok       6727      6662
# 79                                     PsyArXiv      58193     49681
# 80                                        Qeios       5650      3868
# 81          RePEc: Research Papers in Economics     389387    384355
# 82                              Research Square     450816    406441
# 83                                 ResearchGate     180860    176895
# 84                                  ResearchHub       1636      1458
# 85                                 SAE Mobilus®        105       105
# 86                                         SSRN    1258578   1185658
# 87                             SciELO Preprints       4141      4112
# 88                        ScienceOpen Preprints       1961      1755
# 89                          Sciencepaper Online         99        99
# 90                                     SocArXiv      21541     19551
# 91        Social Science Open Access Repository      27201     27060
# 92                                    SportRxiv        878       867
# 93                                     TechRxiv      29416     17987
# 94                                    Therapoid          7         6
# 95                               Thesis Commons       4175      3421
# 96                         UCL Open Environment        368       177
# 97                                    UnisaRxiv        126       126
# 98                                      VeriXiv        504       450
# 99                       Wellcome Open Research       4727      3453
# 100                                      Zenodo     166112     67806
# 101                                       arXiv    2920789   2886934
# 102                                     bioRxiv     306948    306682
# 103                                       eLife      29900     19697
# 104                                     engrXiv       5066      4896
# 105                                     medRxiv      75743     75587
# 106                                   prepare@u        227       225
# 107                                  searchRxiv       1234       555
# 108                                       viXra      22924     22749
#
#      n_published  pct_published  n_is_version_of  pct_has_versions  \
# 49         24458      66.668484             1911          5.209072
# 50             1       0.129870               19          2.467532
# 51             8       0.663900               61          5.062241
# 52            69      19.382022               95         26.685393
# 53             1       0.840336               18         15.126050
# 54             7       5.691057               11          8.943089
# 55           108       6.654344              675         41.589649
# 56             0       0.000000                6         46.153846
# 57           253      48.747592              158         30.443160
# 58            90      30.100334               34         11.371237
# 59           147      19.016818              204         26.390686
# 60           108      36.486486               93         31.418919
# 61            22       0.032745             3038          4.521843
# 62             0       0.000000              629         34.866962
# 63            28       0.856269             1758         53.761468
# 64             0       0.000000                2         50.000000
# 65            15      17.441860               18         20.930233
# 66             4       2.105263               90         47.368421
# 67            34       2.849958              621         52.053646
# 68          8490       8.365274            15218         14.994433
# 69             0       0.000000              174          1.282146
# 70             0       0.000000               17         24.637681
# 71             8       0.581818               63          4.581818
# 72           105      41.832669               97         38.645418
# 73            35       0.669728              971         18.580176
# 74            17       0.787402               50          2.315887
# 75            14      17.721519                0          0.000000
# 76         64387      60.495903            10460          9.827871
# 77             0       0.000000                1         14.285714
# 78             0       0.000000               46          0.690483
# 79          8315      16.736781             8827         17.767356
# 80            90       2.326784             1772         45.811789
# 81          3310       0.861183            65507         17.043358
# 82        131196      32.279224            49620         12.208414
# 83          2747       1.552899            18174         10.273891
# 84            18       1.234568              133          9.122085
# 85            18      17.142857                3          2.857143
# 86         10613       0.895115           154297         13.013618
# 87            53       1.288911               64          1.556420
# 88            35       1.994302              381         21.709402
# 89             0       0.000000                2          2.020202
# 90          5285      27.031865             4431         22.663802
# 91            14       0.051737              401          1.481892
# 92            84       9.688581               44          5.074971
# 93          2362      13.131706            10186         56.629788
# 94             0       0.000000                1         16.666667
# 95           743      21.718796              610         17.831044
# 96             3       1.694915               92         51.977401
# 97             0       0.000000                9          7.142857
# 98            42       9.333333               82         18.222222
# 99            69       1.998262             1168         33.825659
# 100        65627      96.786420            65096         96.003304
# 101      1272475      44.077038            85210          2.951574
# 102       112313      36.621973            21031          6.857592
# 103         5660      28.735340            10346         52.525765
# 104          595      12.152778              775         15.829248
# 105        33734      44.629367             4587          6.068504
# 106            0       0.000000                4          1.777778
# 107            5       0.900901              165         29.729730
# 108           16       0.070333              420          1.846235
#
#      count_2024  count_2025
# 49       5201.0      4737.0
# 50        209.0       298.0
# 51         83.0         1.0
# 52          7.0        13.0
# 53          0.0         0.0
# 54         44.0        79.0
# 55         37.0       127.0
# 56          0.0         0.0
# 57          2.0         2.0
# 58         20.0        34.0
# 59         78.0       111.0
# 60          1.0         0.0
# 61         30.0         1.0
# 62          0.0         0.0
# 63          0.0         0.0
# 64          2.0         2.0
# 65          1.0         0.0
# 66          9.0        21.0
# 67        280.0       370.0
# 68       6778.0      6234.0
# 69         13.0         0.0
# 70          9.0        21.0
# 71        235.0       558.0
# 72         12.0        13.0
# 73          0.0         0.0
# 74          0.0        21.0
# 75          0.0         0.0
# 76      26565.0     28831.0
# 77          0.0         0.0
# 78        602.0       357.0
# 79       7213.0      8751.0
# 80       1295.0       653.0
# 81        319.0       200.0
# 82      71233.0     57930.0
# 83      27421.0     36313.0
# 84        163.0      1084.0
# 85         13.0         0.0
# 86     195880.0    238333.0
# 87        774.0      1004.0
# 88        314.0       404.0
# 89         19.0        79.0
# 90       2195.0      2997.0
# 91         49.0       198.0
# 92        111.0       137.0
# 93       3486.0      5527.0
# 94          0.0         0.0
# 95        317.0       254.0
# 96         10.0        54.0
# 97         42.0        27.0
# 98         36.0       413.0
# 99        705.0       627.0
# 100      4514.0     54372.0
# 101    242014.0    279694.0
# 102     43404.0     44285.0
# 103      1740.0       745.0
# 104       616.0      1141.0
# 105     12800.0     13597.0
# 106        27.0         1.0
# 107       150.0       178.0
# 108         0.0         0.0

# %%
backend_df.head(60)
# Out:
#                                           server_name   backend  n_records  \
# 0                                      AIJR Preprints  crossref        143
# 1                                  AMRC Open Research  crossref        101
# 2                                      APSA Preprints  crossref       1470
# 3                                     ARPHA Preprints  crossref        890
# 4                                             ART-Dok  datacite       9648
# 5                                             Advance  crossref       4400
# 6                                          AfricArXiv  crossref        501
# 7                                          AfricArXiv  datacite       1683
# 8                                       AgEcon Search  datacite     140392
# 9                                            AgriRxiv  crossref        818
# 10                                           AgriRxiv  datacite         40
# 11                                           Arabixiv  crossref        502
# 12                                           Arabixiv  datacite         82
# 13                                      Authorea Inc.  crossref      61903
# 14                                 Beilstein Archives  crossref        697
# 15                                        BioHackrXiv  crossref        139
# 16                                          BodoArXiv  crossref        165
# 17                               CERN document server  datacite        948
# 18                               CERN document server  openalex       1675
# 19                              Cambridge Open Engage  crossref       3090
# 20                                           ChemRxiv  crossref      46475
# 21                                                CoP  crossref         30
# 22                                          CogPrints  openalex       1498
# 23                                 Covid-19 Preprints  crossref        647
# 24                                           CrimRxiv  crossref       2832
# 25                               CrossAsia-Repository  datacite        479
# 26                                         DSpace@MIT  openalex      11324
# 27  Digital Access to Scholarship at Harvard (DASH...  openalex       9549
# 28                                   E-LIS Repository  openalex       8864
# 29                                           ECSarXiv  crossref        314
# 30                                           ECSarXiv  datacite         12
# 31                                          EGUsphere  crossref      10458
# 32                      ELPUB (Universitat Wuppertal)  datacite         41
# 33               Earth and Space Science Open Archive  crossref      22747
# 34                                         EarthArXiv  crossref       6537
# 35                                         EarthArXiv  datacite        262
# 36                                 EasyChair preprint  crossref        620
# 37                                         EcoEvoRxiv  crossref       2886
# 38                                 EconStor Preprints  openalex      64676
# 39                                            EdArXiv  crossref       2547
# 40                 Electron Colloquium Comput Complex  openalex        141
# 41                                              EmeRI  crossref          8
# 42                                       Encyclopedia  crossref        166
# 43                                          EnerarXiv  crossref        204
# 44                                      F1000Research  crossref      16866
# 45                                      FocUS Archive  crossref         83
# 46                                            Frenxiv  crossref        179
# 47                                Gates Open Research  crossref        862
# 48                                                HAL  openalex    1056415
# 49                         HANS Publication PrePrints  crossref         75
# 50                                  HRB Open Research  crossref       1012
# 51                            Humanities Commons CORE  datacite      29465
# 52                     IACR Cryptology ePrint Archive  openalex      10569
# 53                                           INA-Rxiv  crossref      17837
# 54                                          IndiaRxiv  crossref        142
# 55                                     JMIR Preprints  crossref      37631
# 56                                               Jxiv      jxiv        779
# 57                        Keldysh Institute Preprints  crossref       1256
# 58                            LIS Scholarship Archive  crossref        397
# 59         LSE Research Online Documents on Economics  openalex        119
#
#     n_unique  n_published  pct_published  n_is_version_of  pct_has_versions  \
# 0        143            0       0.000000                8          5.594406
# 1         71            0       0.000000               28         39.436620
# 2       1171          160      13.663535              261         22.288642
# 3        870          315      36.206897               38          4.367816
# 4       9567            3       0.031358               81          0.846660
# 5       2484          159       6.400966             1787         71.940419
# 6        487           49      10.061602              436         89.527721
# 7       1630           53       3.251534              514         31.533742
# 8     132736           51       0.038422            25090         18.902182
# 9        809           23       2.843016              127         15.698393
# 10        38            0       0.000000               37         97.368421
# 11       491          216      43.991853              102         20.773931
# 12        82           25      30.487805               67         81.707317
# 13     58978          693       1.175014             6033         10.229238
# 14       697          461      66.140603               10          1.434720
# 15       136            0       0.000000                4          2.941176
# 16       157           46      29.299363               16         10.191083
# 17       432          385      89.120370              384         88.888889
# 18      1668          970      58.153477             1291         77.398082
# 19      2138          163       7.623948              697         32.600561
# 20     36452        17022      46.697026             8305         22.783386
# 21        29            5      17.241379                1          3.448276
# 22      1497            2       0.133601               24          1.603206
# 23       453            0       0.000000               30          6.622517
# 24      2722           28       1.028655              266          9.772226
# 25       459            0       0.000000                3          0.653595
# 26     11249          561       4.987110              993          8.827451
# 27      9537           30       0.314564              288          3.019818
# 28      8819            3       0.034017               64          0.725706
# 29       301           24       7.973422               37         12.292359
# 30        12            0       0.000000               11         91.666667
# 31     10384         8261      79.555085              293          2.821649
# 32        41            1       2.439024                0          0.000000
# 33     19622         8492      43.277953             3080         15.696667
# 34      6476         1435      22.158740              740         11.426807
# 35       260          133      51.153846              241         92.692308
# 36       618           14       2.265372               79         12.783172
# 37      2845           56       1.968366              110          3.866432
# 38     64309            8       0.012440             6682         10.390459
# 39      2329          285      12.237012              395         16.960069
# 40       140            5       3.571429               30         21.428571
# 41         8            0       0.000000                0          0.000000
# 42       161            0       0.000000                6          3.726708
# 43       203            3       1.477833               16          7.881773
# 44     11086          157       1.416201             4617         41.647122
# 45        80            3       3.750000               37         46.250000
# 46       171           64      37.426901               83         48.538012
# 47       543            6       1.104972              305         56.169429
# 48   1041309         2338       0.224525            24709          2.372879
# 49        75            0       0.000000                0          0.000000
# 50       655            4       0.610687              311         47.480916
# 51     17108         8177      47.796353            12038         70.364742
# 52     10473           15       0.143225              222          2.119736
# 53     15785         1436       9.097244             2726         17.269560
# 54       140           17      12.142857               42         30.000000
# 55     36686        24458      66.668484             1911          5.209072
# 56       770            1       0.129870               19          2.467532
# 57      1205            8       0.663900               61          5.062241
# 58       356           69      19.382022               95         26.685393
# 59       119            1       0.840336               18         15.126050
#
#     count_2024  count_2025
# 0          6.0         5.0
# 1         16.0         5.0
# 2        140.0       214.0
# 3        184.0       211.0
# 4        564.0       494.0
# 5        416.0       346.0
# 6         16.0         0.0
# 7        166.0       215.0
# 8       2782.0      4949.0
# 9         70.0        93.0
# 10         0.0         0.0
# 11         0.0         0.0
# 12         0.0         0.0
# 13     13633.0     11401.0
# 14        73.0        65.0
# 15        35.0        41.0
# 16        10.0        28.0
# 17        68.0       277.0
# 18         0.0         8.0
# 19       443.0       687.0
# 20      6932.0      7955.0
# 21         9.0         7.0
# 22         0.0         0.0
# 23        90.0        61.0
# 24       370.0       497.0
# 25        64.0        21.0
# 26         0.0        13.0
# 27      1233.0       667.0
# 28        81.0        55.0
# 29        20.0        17.0
# 30         0.0         0.0
# 31      2897.0      4276.0
# 32        34.0         7.0
# 33      2556.0      3284.0
# 34       884.0      1153.0
# 35         0.0         0.0
# 36         0.0         0.0
# 37       592.0       860.0
# 38       138.0       671.0
# 39       286.0       543.0
# 40         0.0         0.0
# 41         0.0         0.0
# 42         0.0         0.0
# 43         0.0         0.0
# 44      1233.0      1057.0
# 45        10.0         8.0
# 46         0.0         0.0
# 47        48.0        21.0
# 48      4878.0      3847.0
# 49         0.0         0.0
# 50        79.0       124.0
# 51      2088.0      1113.0
# 52         0.0         0.0
# 53         0.0         0.0
# 54         2.0         1.0
# 55      5201.0      4737.0
# 56       209.0       298.0
# 57        83.0         1.0
# 58         7.0        13.0
# 59         0.0         0.0

# %%
backend_df.tail(60)
# Out:
#                                server_name   backend  n_records  n_unique  \
# 62                       MNI Open Research  crossref         19        13
# 63                                  MarXiv  crossref        508       489
# 64                                  MarXiv  datacite        158       156
# 65                               MediArXiv  crossref        309       299
# 66                               MetaArXiv  crossref        880       773
# 67                                MindRxiv  crossref        335       293
# 68                                MindRxiv  datacite         46        46
# 69           Munich Personal RePEc Archive  openalex      67263     67185
# 70    National Bureau of Economic Research  openalex       1828      1804
# 71                       Nature Precedings  crossref       5210      3270
# 72                          NewAddictionsX  crossref          7         4
# 73                                NutriXiv  crossref         94        86
# 74                    Open Research Africa  crossref        287       190
# 75                    Open Research Europe  crossref       1877      1193
# 76                  Open Science Framework  crossref     103652     95411
# 77                  Open Science Framework  datacite       8917      8442
# 78                         Organic Eprints  openalex      13704     13571
# 79                    Oroboros Instruments  datacite         95        69
# 80                            PREPRINTS.RU  crossref       1415      1375
# 81                               PaleorXiv  crossref        287       251
# 82                               PaleorXiv  datacite         30        30
# 83                         PeerJ Preprints  crossref       6446      5226
# 84                         PhilSci-Archive  openalex       2167      2159
# 85                                PoolText  crossref         79        79
# 86                           Preprints.org  crossref     115815    106432
# 87            Prepublicaciones OpenCiencia  crossref          8         7
# 88                           PropylaeumDok  datacite       6727      6662
# 89                                PsyArXiv  crossref      56866     49537
# 90                                PsyArXiv  datacite       1327      1320
# 91                                   Qeios  crossref       5650      3868
# 92     RePEc: Research Papers in Economics  openalex     389387    384355
# 93                         Research Square  crossref     450816    406441
# 94                            ResearchGate  datacite     180860    176895
# 95                             ResearchHub  crossref       1636      1458
# 96                            SAE Mobilus®  crossref        105       105
# 97                                    SSRN  crossref    1258578   1185658
# 98                        SciELO Preprints  crossref       4141      4112
# 99                   ScienceOpen Preprints  crossref       1961      1755
# 100                    Sciencepaper Online  crossref         99        99
# 101                               SocArXiv  crossref      21541     19551
# 102  Social Science Open Access Repository  openalex      27201     27060
# 103                              SportRxiv  crossref        878       867
# 104                               TechRxiv  crossref      29416     17987
# 105                              Therapoid  crossref          7         6
# 106                         Thesis Commons  crossref       3959      3410
# 107                         Thesis Commons  datacite        216       215
# 108                   UCL Open Environment  crossref        368       177
# 109                              UnisaRxiv  crossref        126       126
# 110                                VeriXiv  crossref        504       450
# 111                 Wellcome Open Research  crossref       4727      3453
# 112                                 Zenodo  datacite     166112     67806
# 113                                  arXiv  datacite    2920789   2886934
# 114                                bioRxiv  crossref     306948    306682
# 115                                  eLife  crossref      29900     19697
# 116                                engrXiv  crossref       4929      4892
# 117                                engrXiv  datacite        137       136
# 118                                medRxiv  crossref      75743     75587
# 119                              prepare@u  crossref        227       225
# 120                             searchRxiv  crossref       1234       555
# 121                                  viXra  openalex      22924     22749
#
#      n_published  pct_published  n_is_version_of  pct_has_versions  \
# 62             0       0.000000                6         46.153846
# 63           253      51.738241              158         32.310838
# 64            81      51.923077              126         80.769231
# 65            90      30.100334               34         11.371237
# 66           147      19.016818              204         26.390686
# 67           108      36.860068               92         31.399317
# 68            10      21.739130               44         95.652174
# 69            22       0.032745             3038          4.521843
# 70             0       0.000000              629         34.866962
# 71            28       0.856269             1758         53.761468
# 72             0       0.000000                2         50.000000
# 73            15      17.441860               18         20.930233
# 74             4       2.105263               90         47.368421
# 75            34       2.849958              621         52.053646
# 76          7733       8.104935            11845         12.414711
# 77          1289      15.268894             5735         67.934139
# 78             0       0.000000              174          1.282146
# 79             0       0.000000               17         24.637681
# 80             8       0.581818               63          4.581818
# 81           105      41.832669               97         38.645418
# 82            24      80.000000               30        100.000000
# 83            35       0.669728              971         18.580176
# 84            17       0.787402               50          2.315887
# 85            14      17.721519                0          0.000000
# 86         64387      60.495903            10460          9.827871
# 87             0       0.000000                1         14.285714
# 88             0       0.000000               46          0.690483
# 89          8313      16.781396             8823         17.810929
# 90           342      25.909091             1180         89.393939
# 91            90       2.326784             1772         45.811789
# 92          3310       0.861183            65507         17.043358
# 93        131196      32.279224            49620         12.208414
# 94          2747       1.552899            18174         10.273891
# 95            18       1.234568              133          9.122085
# 96            18      17.142857                3          2.857143
# 97         10613       0.895115           154297         13.013618
# 98            53       1.288911               64          1.556420
# 99            35       1.994302              381         21.709402
# 100            0       0.000000                2          2.020202
# 101         5285      27.031865             4431         22.663802
# 102           14       0.051737              401          1.481892
# 103           84       9.688581               44          5.074971
# 104         2362      13.131706            10186         56.629788
# 105            0       0.000000                1         16.666667
# 106          743      21.788856              610         17.888563
# 107            8       3.720930              204         94.883721
# 108            3       1.694915               92         51.977401
# 109            0       0.000000                9          7.142857
# 110           42       9.333333               82         18.222222
# 111           69       1.998262             1168         33.825659
# 112        65627      96.786420            65096         96.003304
# 113      1272475      44.077038            85210          2.951574
# 114       112313      36.621973            21031          6.857592
# 115         5660      28.735340            10346         52.525765
# 116          595      12.162715              775         15.842191
# 117           46      33.823529              132         97.058824
# 118        33734      44.629367             4587          6.068504
# 119            0       0.000000                4          1.777778
# 120            5       0.900901              165         29.729730
# 121           16       0.070333              420          1.846235
#
#      count_2024  count_2025
# 62          0.0         0.0
# 63          2.0         2.0
# 64          0.0         0.0
# 65         20.0        34.0
# 66         78.0       111.0
# 67          1.0         0.0
# 68          0.0         0.0
# 69         30.0         1.0
# 70          0.0         0.0
# 71          0.0         0.0
# 72          2.0         2.0
# 73          1.0         0.0
# 74          9.0        21.0
# 75        280.0       370.0
# 76       6185.0      4771.0
# 77        606.0      1483.0
# 78         13.0         0.0
# 79          9.0        21.0
# 80        235.0       558.0
# 81         12.0        13.0
# 82          0.0         0.0
# 83          0.0         0.0
# 84          0.0        21.0
# 85          0.0         0.0
# 86      26565.0     28831.0
# 87          0.0         0.0
# 88        602.0       357.0
# 89       7213.0      8751.0
# 90          0.0         0.0
# 91       1295.0       653.0
# 92        319.0       200.0
# 93      71233.0     57930.0
# 94      27421.0     36313.0
# 95        163.0      1084.0
# 96         13.0         0.0
# 97     195880.0    238333.0
# 98        774.0      1004.0
# 99        314.0       404.0
# 100        19.0        79.0
# 101      2195.0      2997.0
# 102        49.0       198.0
# 103       111.0       137.0
# 104      3486.0      5527.0
# 105         0.0         0.0
# 106       317.0       254.0
# 107         0.0         0.0
# 108        10.0        54.0
# 109        42.0        27.0
# 110        36.0       413.0
# 111       705.0       627.0
# 112      4514.0     54372.0
# 113    242014.0    279694.0
# 114     43404.0     44285.0
# 115      1740.0       745.0
# 116       616.0      1141.0
# 117         0.0         0.0
# 118     12800.0     13597.0
# 119        27.0         1.0
# 120       150.0       178.0
# 121         0.0         0.0
