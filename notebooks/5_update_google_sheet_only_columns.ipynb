# %%
import pandas as pd
# Set option to display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# # function to update google sheet file

# %%
from __future__ import annotations

# =========================
# 0) Imports
# =========================
import numpy as np
import pandas as pd
import duckdb
from typing import Iterable, Dict, Any, Optional, List, Tuple

import gspread
from google.oauth2.service_account import Credentials


# =========================
# 1) DuckDB metrics builder
# =========================
def build_sheet_metrics_duckdb(
    df: pd.DataFrame,
    *,
    server_col: str = "server_name",
    backend_col: str = "backend",
    group_id_col: str = "dup_group_id",
    date_col: str = "date_first_seen",
    year_col: str = "publication_year_first_seen",
    has_published_col: str = "has_published_version",
    hierarchy_col: str = "records_hierarchy",
    record_id_col: str = "record_id",
    choose_parent: str = "oldest",   # "oldest" | "newest"
) -> tuple[pd.DataFrame, pd.DataFrame]:
    """
    Returns:
      overall_df:  one row per server_name (ALL backends combined)
      backend_df:  one row per (server_name, backend)

    Output columns (overall_df & backend_df):
      server_name, [backend], n_records, n_unique, n_published, pct_published,
      n_is_version_of, pct_has_versions, count_2024, count_2025
    """
    if choose_parent not in ("oldest", "newest"):
        raise ValueError("choose_parent must be 'oldest' or 'newest'")

    order_dir = "ASC" if choose_parent == "oldest" else "DESC"

    con = duckdb.connect(database=":memory:")
    con.register("df", df)

    overall_sql = f"""
    WITH base AS (
      SELECT
        CAST({server_col} AS VARCHAR) AS server_name,
        CAST({backend_col} AS VARCHAR) AS backend,
        CAST({group_id_col} AS VARCHAR) AS dup_group_id,
        CAST({record_id_col} AS VARCHAR) AS record_id,
        TRY_CAST({date_col} AS TIMESTAMP) AS date_first_seen,
        TRY_CAST({year_col} AS INTEGER) AS year_first_seen,
        CASE
          WHEN {has_published_col} IS NULL THEN FALSE
          WHEN CAST({has_published_col} AS VARCHAR) IN ('true','True','1') THEN TRUE
          WHEN CAST({has_published_col} AS VARCHAR) IN ('false','False','0') THEN FALSE
          ELSE COALESCE(TRY_CAST({has_published_col} AS BOOLEAN), FALSE)
        END AS has_published_version,
        LOWER(TRIM(COALESCE(CAST({hierarchy_col} AS VARCHAR), ''))) AS records_hierarchy
      FROM df
      WHERE {server_col} IS NOT NULL
        AND {group_id_col} IS NOT NULL
        AND TRIM(CAST({server_col} AS VARCHAR)) <> ''
        AND TRIM(CAST({group_id_col} AS VARCHAR)) <> ''
    ),
    clusters AS (
      SELECT
        dup_group_id,
        COUNT(*) AS cluster_size,
        BOOL_OR(has_published_version) AS cluster_has_published
      FROM base
      GROUP BY dup_group_id
    ),
    parents AS (
      SELECT
        b.dup_group_id,
        b.server_name AS parent_server_name,
        b.backend AS parent_backend,
        b.record_id AS parent_record_id,
        b.date_first_seen AS parent_date_first_seen,
        b.year_first_seen AS parent_year_first_seen
      FROM base b
      QUALIFY ROW_NUMBER() OVER (
        PARTITION BY b.dup_group_id
        ORDER BY
          CASE WHEN b.records_hierarchy = 'parent' THEN 0 ELSE 1 END,
          b.date_first_seen {order_dir} NULLS LAST,
          b.record_id {order_dir}
      ) = 1
    ),
    joined AS (
      SELECT
        b.server_name,
        b.backend,
        b.dup_group_id,
        c.cluster_size,
        c.cluster_has_published,
        p.parent_year_first_seen
      FROM base b
      JOIN clusters c USING (dup_group_id)
      JOIN parents  p USING (dup_group_id)
    ),
    overall AS (
      SELECT
        server_name,
        COUNT(*) AS n_records,
        COUNT(DISTINCT dup_group_id) AS n_unique,
        COUNT(DISTINCT CASE WHEN cluster_has_published THEN dup_group_id END) AS n_published,
        COUNT(DISTINCT CASE WHEN cluster_size > 1 THEN dup_group_id END) AS n_is_version_of
      FROM joined
      GROUP BY server_name
    ),
    yearly AS (
      SELECT
        server_name,
        SUM(CASE WHEN parent_year_first_seen = 2024 THEN 1 ELSE 0 END) AS count_2024,
        SUM(CASE WHEN parent_year_first_seen = 2025 THEN 1 ELSE 0 END) AS count_2025
      FROM (
        SELECT DISTINCT server_name, dup_group_id, parent_year_first_seen
        FROM joined
      )
      GROUP BY server_name
    )
    SELECT
      o.server_name,
      o.n_records,
      o.n_unique,
      o.n_published,
      CASE WHEN o.n_unique > 0 THEN (o.n_published::DOUBLE / o.n_unique) * 100 ELSE NULL END AS pct_published,
      o.n_is_version_of,
      CASE WHEN o.n_unique > 0 THEN (o.n_is_version_of::DOUBLE / o.n_unique) * 100 ELSE NULL END AS pct_has_versions,
      COALESCE(y.count_2024, 0) AS count_2024,
      COALESCE(y.count_2025, 0) AS count_2025
    FROM overall o
    LEFT JOIN yearly y USING (server_name)
    ORDER BY o.server_name;
    """
    overall_df = con.sql(overall_sql).df()

    backend_sql = f"""
    WITH base AS (
      SELECT
        CAST({server_col} AS VARCHAR) AS server_name,
        CAST({backend_col} AS VARCHAR) AS backend,
        CAST({group_id_col} AS VARCHAR) AS dup_group_id,
        CAST({record_id_col} AS VARCHAR) AS record_id,
        TRY_CAST({date_col} AS TIMESTAMP) AS date_first_seen,
        TRY_CAST({year_col} AS INTEGER) AS year_first_seen,
        CASE
          WHEN {has_published_col} IS NULL THEN FALSE
          WHEN CAST({has_published_col} AS VARCHAR) IN ('true','True','1') THEN TRUE
          WHEN CAST({has_published_col} AS VARCHAR) IN ('false','False','0') THEN FALSE
          ELSE COALESCE(TRY_CAST({has_published_col} AS BOOLEAN), FALSE)
        END AS has_published_version,
        LOWER(TRIM(COALESCE(CAST({hierarchy_col} AS VARCHAR), ''))) AS records_hierarchy
      FROM df
      WHERE {server_col} IS NOT NULL
        AND {group_id_col} IS NOT NULL
        AND TRIM(CAST({server_col} AS VARCHAR)) <> ''
        AND TRIM(CAST({group_id_col} AS VARCHAR)) <> ''
        AND {backend_col} IS NOT NULL
        AND TRIM(CAST({backend_col} AS VARCHAR)) <> ''
    ),
    clusters AS (
      SELECT
        dup_group_id,
        COUNT(*) AS cluster_size,
        BOOL_OR(has_published_version) AS cluster_has_published
      FROM base
      GROUP BY dup_group_id
    ),
    parents AS (
      SELECT
        b.dup_group_id,
        b.server_name AS parent_server_name,
        b.backend AS parent_backend,
        b.record_id AS parent_record_id,
        b.date_first_seen AS parent_date_first_seen,
        b.year_first_seen AS parent_year_first_seen
      FROM base b
      QUALIFY ROW_NUMBER() OVER (
        PARTITION BY b.dup_group_id
        ORDER BY
          CASE WHEN b.records_hierarchy = 'parent' THEN 0 ELSE 1 END,
          b.date_first_seen {order_dir} NULLS LAST,
          b.record_id {order_dir}
      ) = 1
    ),
    joined AS (
      SELECT
        b.server_name,
        b.backend,
        b.dup_group_id,
        c.cluster_size,
        c.cluster_has_published,
        p.parent_year_first_seen
      FROM base b
      JOIN clusters c USING (dup_group_id)
      JOIN parents  p USING (dup_group_id)
    ),
    agg AS (
      SELECT
        server_name,
        backend,
        COUNT(*) AS n_records,
        COUNT(DISTINCT dup_group_id) AS n_unique,
        COUNT(DISTINCT CASE WHEN cluster_has_published THEN dup_group_id END) AS n_published,
        COUNT(DISTINCT CASE WHEN cluster_size > 1 THEN dup_group_id END) AS n_is_version_of
      FROM joined
      GROUP BY server_name, backend
    ),
    yearly AS (
      SELECT
        server_name,
        backend,
        SUM(CASE WHEN parent_year_first_seen = 2024 THEN 1 ELSE 0 END) AS count_2024,
        SUM(CASE WHEN parent_year_first_seen = 2025 THEN 1 ELSE 0 END) AS count_2025
      FROM (
        SELECT DISTINCT server_name, backend, dup_group_id, parent_year_first_seen
        FROM joined
      )
      GROUP BY server_name, backend
    )
    SELECT
      a.server_name,
      a.backend,
      a.n_records,
      a.n_unique,
      a.n_published,
      CASE WHEN a.n_unique > 0 THEN (a.n_published::DOUBLE / a.n_unique) * 100 ELSE NULL END AS pct_published,
      a.n_is_version_of,
      CASE WHEN a.n_unique > 0 THEN (a.n_is_version_of::DOUBLE / a.n_unique) * 100 ELSE NULL END AS pct_has_versions,
      COALESCE(y.count_2024, 0) AS count_2024,
      COALESCE(y.count_2025, 0) AS count_2025
    FROM agg a
    LEFT JOIN yearly y
      ON a.server_name = y.server_name AND a.backend = y.backend
    ORDER BY a.server_name, a.backend;
    """
    backend_df = con.sql(backend_sql).df()

    con.close()
    return overall_df, backend_df


# ============================================
# 2) Read sheet -> DataFrame (gspread)
# ============================================
def read_sheet_as_df(
    *,
    sheet_id: str,
    worksheet_gid: int,
    service_account_json_path: str,
) -> pd.DataFrame:
    scopes = ["https://www.googleapis.com/auth/spreadsheets"]
    creds = Credentials.from_service_account_file(service_account_json_path, scopes=scopes)
    gc = gspread.authorize(creds)
    sh = gc.open_by_key(sheet_id)

    ws = None
    for w in sh.worksheets():
        if w.id == worksheet_gid:
            ws = w
            break
    if ws is None:
        raise ValueError(f"Worksheet gid={worksheet_gid} not found.")

    values = ws.get_all_values()
    if not values:
        return pd.DataFrame()

    header = values[0]
    rows = values[1:]
    df = pd.DataFrame(rows, columns=header)
    return df


# ============================================
# 3) Build payload_df (only columns to update)
# ============================================
def build_update_payload(
    sheet_df: pd.DataFrame,
    overall_df: pd.DataFrame,
    backend_df: pd.DataFrame,
    target_cols: List[str],
    *,
    key_col: str = "source_id",
    default_collection_date: str = "2025/12/31",
    per_server_date: Optional[Dict[str, str]] = None,
) -> pd.DataFrame:
    """
    Returns a dataframe containing:
      - key_col
      - all target_cols (exact names from the sheet, including trailing spaces)
    Values come from overall_df & backend_df.
    Missing columns are created as blanks so the writer won't crash.
    """
    if key_col not in sheet_df.columns:
        raise ValueError(f"Sheet dataframe must contain '{key_col}'.")

    out = pd.DataFrame()
    out[key_col] = sheet_df[key_col].astype(str)

    # Ensure all target cols exist in out (so writer won't KeyError)
    for c in target_cols:
        out[c] = ""

    # ---- Global map (overall)
    g = overall_df.set_index("server_name")
    sid = out[key_col].astype(str)

    def set_if_present(colname: str, values):
        if colname in out.columns:
            out[colname] = values

    # Global (red columns)
    set_if_present("Collection Date used for Red Columns", default_collection_date)
    set_if_present("number of unique preprints", sid.map(g["n_unique"]))
    set_if_present("number of unique preprints that are published", sid.map(g["n_published"]))

    # NOTE: your sheet has trailing spaces in some headers:
    set_if_present("% of unique that are published ", sid.map(g["pct_published"]))
    set_if_present("Number of unique preprints with more than 1 version", sid.map(g["n_is_version_of"]))
    set_if_present("% of unique that have more than one version ", sid.map(g["pct_has_versions"]))

    # ---- Backend blocks
    b = backend_df.copy()
    b["backend"] = b["backend"].astype(str).str.lower().str.strip()
    b["server_name"] = b["server_name"].astype(str)

    def backend_map(backend_key: str) -> pd.DataFrame:
        return b[b["backend"] == backend_key].set_index("server_name")

    # Crossref
    cr = backend_map("crossref")
    set_if_present("Is the Server in Crossref", sid.isin(cr.index))
    set_if_present("Crossref collection_date", default_collection_date)
    set_if_present("Number of works in Crossref", sid.map(cr["n_records"]))
    set_if_present("Number of unique preprints in Crossref", sid.map(cr["n_unique"]))
    set_if_present("Number of unique preprints that are published in Crossref", sid.map(cr["n_published"]))
    set_if_present("%_of unique that are published in Crossref", sid.map(cr["pct_published"]))
    set_if_present("Number of unique preprints with more than 1 version in Crossref", sid.map(cr["n_is_version_of"]))
    set_if_present("% of unique that have more than one version  in Crossref", sid.map(cr["pct_has_versions"]))
    set_if_present("Works_in_2024 in Crossref", sid.map(cr["count_2024"]))
    set_if_present("Works_in_2025 in Crossref", sid.map(cr["count_2025"]))

    # DataCite
    dc = backend_map("datacite")
    set_if_present("Is the server in DataCite", sid.isin(dc.index))
    set_if_present("DataCite Collection Date", default_collection_date)
    set_if_present("Number of works in DataCite", sid.map(dc["n_records"]))
    # sheet uses this exact column name:
    set_if_present("number_of_preprint_unique in DataCite", sid.map(dc["n_unique"]))
    set_if_present("number of unique preprints that are published in Datacite", sid.map(dc["n_published"]))
    set_if_present("%_of unique that are published in DataCite", sid.map(dc["pct_published"]))
    set_if_present("Number of unique preprints with more than 1 version in DataCite", sid.map(dc["n_is_version_of"]))
    set_if_present("% of unique that have more than one version  in DataCite", sid.map(dc["pct_has_versions"]))
    set_if_present("Works_in_2024 in DataCite", sid.map(dc["count_2024"]))
    set_if_present("Works_in_2025 in DataCite", sid.map(dc["count_2025"]))

    # OpenAlex
    oa = backend_map("openalex")
    set_if_present("Is the server in OpenAlex", sid.isin(oa.index))
    set_if_present("OpenAlex Data Collection Date", default_collection_date)
    set_if_present("Number of works in OpenAlex", sid.map(oa["n_records"]))
    set_if_present("number_of_preprint_unique in OpenAlex", sid.map(oa["n_unique"]))
    set_if_present("number of unique preprints that are published in OpenAlex", sid.map(oa["n_published"]))
    set_if_present("%_of unique that are published in OpenAlex", sid.map(oa["pct_published"]))
    set_if_present("Number of unique preprints with more than 1 version in OpenAlex", sid.map(oa["n_is_version_of"]))
    set_if_present("% of unique preprints with more than 1 version in OpenAlex", sid.map(oa["pct_has_versions"]))
    set_if_present("Works_in_2024 in OpenAlex", sid.map(oa["count_2024"]))
    set_if_present("Works_in_2025 in OpenAlex", sid.map(oa["count_2025"]))

    # ---- Optional per-server collection date overrides
    if per_server_date:
        # Only touches the *collection date* columns if present in target_cols
        for date_col in [
            "Collection Date used for Red Columns",
            "Crossref collection_date",
            "DataCite Collection Date",
            "OpenAlex Data Collection Date",
        ]:
            if date_col in out.columns:
                out[date_col] = [
                    per_server_date.get(s, default_collection_date) for s in sid.tolist()
                ]

    # Clean types for writing
    for c in target_cols:
        if c in out.columns:
            out[c] = out[c].replace({np.nan: ""})
    return out[[key_col] + list(target_cols)]


# ============================================
# 4) Update ONLY selected columns in the sheet
# ============================================
def update_google_sheet_only_columns(
    *,
    sheet_id: str,
    worksheet_gid: int,
    service_account_json_path: str,
    payload_df: pd.DataFrame,
    key_col: str,
    columns_to_update: Iterable[str],
    chunk_size: int = 500,
    overwrite: bool = True,
    verbose: bool = True,
) -> Dict[str, Any]:
    cols = list(columns_to_update)
    if key_col not in payload_df.columns:
        raise ValueError(f"payload_df must contain '{key_col}'.")

    scopes = ["https://www.googleapis.com/auth/spreadsheets"]
    creds = Credentials.from_service_account_file(service_account_json_path, scopes=scopes)
    gc = gspread.authorize(creds)
    sh = gc.open_by_key(sheet_id)

    ws = None
    for w in sh.worksheets():
        if w.id == worksheet_gid:
            ws = w
            break
    if ws is None:
        raise ValueError(f"Worksheet gid={worksheet_gid} not found.")

    header = ws.row_values(1)
    header_map = {h: (i + 1) for i, h in enumerate(header)}  # 1-based

    missing_cols = [c for c in cols if c not in header_map]
    if missing_cols:
        raise ValueError(f"These columns are not in the sheet header: {missing_cols}")

    if key_col not in header_map:
        raise ValueError(f"Sheet must contain '{key_col}' in header row.")

    key_col_idx = header_map[key_col]
    all_keys = ws.col_values(key_col_idx)
    key_to_row = {str(k): r for r, k in enumerate(all_keys[1:], start=2) if str(k).strip() != ""}

    p = payload_df.copy()
    p[key_col] = p[key_col].astype(str)

    keys_in_sheet = set(key_to_row.keys())
    p_in = p[p[key_col].isin(keys_in_sheet)].copy()
    missing_keys = p.loc[~p[key_col].isin(keys_in_sheet), key_col].unique().tolist()

    # Read existing values if overwrite=False
    existing = None
    if not overwrite:
        existing = {}
        for c in cols:
            cidx = header_map[c]
            vals = ws.col_values(cidx)
            for r, val in enumerate(vals[1:], start=2):
                existing[(r, cidx)] = val

    def norm(v):
        if v is None:
            return ""
        if isinstance(v, float) and np.isnan(v):
            return ""
        # keep numbers readable
        if isinstance(v, (np.integer,)):
            return str(int(v))
        if isinstance(v, (np.floating,)):
            return str(float(v))
        return str(v)

    cells_written = 0
    chunks = 0

    for i in range(0, len(p_in), chunk_size):
        chunk = p_in.iloc[i:i+chunk_size]
        cell_list = []

        for _, row in chunk.iterrows():
            rid = str(row[key_col])
            sheet_row = key_to_row.get(rid)
            if sheet_row is None:
                continue

            for c in cols:
                cidx = header_map[c]
                new_val = norm(row.get(c, ""))

                if not overwrite:
                    old_val = existing.get((sheet_row, cidx), "")
                    if str(old_val).strip() != "":
                        continue

                cell_list.append(gspread.Cell(sheet_row, cidx, new_val))

        if cell_list:
            ws.update_cells(cell_list, value_input_option="USER_ENTERED")
            cells_written += len(cell_list)

        chunks += 1
        if verbose:
            print(f"Chunk {chunks}: scanned {len(chunk)} rows, wrote {len(cell_list)} cells")

    return {
        "sheet_id": sheet_id,
        "worksheet_gid": worksheet_gid,
        "rows_payload": int(len(payload_df)),
        "rows_matched": int(len(p_in)),
        "missing_keys": missing_keys[:20],
        "n_missing_keys": int(len(missing_keys)),
        "columns_updated": cols,
        "overwrite": overwrite,
        "cells_written": int(cells_written),
        "chunks": int(chunks),
    }


# ============================================
# 5) RUN PIPELINE (edit these 4 things)
# ============================================

# SHEET_ID = "10_7FdcpZjntqFsEHIii7bAM72uF__of_iUohSD5w8w4"
# WORKSHEET_GID = 881157301

# # 1) put your service account json path here
# SERVICE_ACCOUNT_JSON = "/path/to/service_account.json"

# # 2) your target columns exactly as in the sheet (including trailing spaces)
# TARGET_COLS = [
#     'Collection Date used for Red Columns',
#     'number of unique preprints',
#     'number of unique preprints that are published',
#     '% of unique that are published ',
#     'Number of unique preprints with more than 1 version',
#     '% of unique that have more than one version ',
#     'Is the Server in Crossref',
#     'Crossref collection_date',
#     'Number of works in Crossref',
#     'Number of unique preprints in Crossref',
#     'Number of unique preprints that are published in Crossref',
#     '%_of unique that are published in Crossref',
#     'Number of unique preprints with more than 1 version in Crossref',
#     '% of unique that have more than one version  in Crossref',
#     'Works_in_2024 in Crossref',
#     'Works_in_2025 in Crossref',
#     'Is the server in DataCite',
#     'DataCite Collection Date',
#     'Number of works in DataCite',
#     'number_of_preprint_unique in DataCite',
#     'number of unique preprints that are published in Datacite',
#     '%_of unique that are published in DataCite',
#     'Number of unique preprints with more than 1 version in DataCite',
#     '% of unique that have more than one version  in DataCite',
#     'Works_in_2024 in DataCite',
#     'Works_in_2025 in DataCite',
#     'Is the server in OpenAlex',
#     'OpenAlex Data Collection Date',
#     'Number of works in OpenAlex',
#     'number_of_preprint_unique in OpenAlex',
#     'number of unique preprints that are published in OpenAlex',
#     '%_of unique that are published in OpenAlex',
#     'Number of unique preprints with more than 1 version in OpenAlex',
#     '% of unique preprints with more than 1 version in OpenAlex',
#     'Works_in_2024 in OpenAlex',
#     'Works_in_2025 in OpenAlex',
# ]

# # 3) choose the collection date you want for all servers
# DEFAULT_COLLECTION_DATE = "2025/12/31"

# # 4) optional later: per server overrides (keep None for now)
# PER_SERVER_DATE = None
# # Example:
# # PER_SERVER_DATE = {"bioRxiv": "2026/01/15", "medRxiv": "2026/01/15"}


# # =========================
# # Step A: compute metrics
# # =========================
# # IMPORTANT: 'data' must be your dedupe long dataframe in memory
# overall_df, backend_df = build_sheet_metrics_duckdb(data, choose_parent="oldest")

# # =========================
# # Step B: read the sheet
# # =========================
# sheet_df = read_sheet_as_df(
#     sheet_id=SHEET_ID,
#     worksheet_gid=WORKSHEET_GID,
#     service_account_json_path=SERVICE_ACCOUNT_JSON,
# )

# # =========================
# # Step C: build payload (only key + target cols)
# # =========================
# payload_df = build_update_payload(
#     sheet_df=sheet_df,
#     overall_df=overall_df,
#     backend_df=backend_df,
#     target_cols=TARGET_COLS,
#     key_col="source_id",
#     default_collection_date=DEFAULT_COLLECTION_DATE,
#     per_server_date=PER_SERVER_DATE,
# )

# print(payload_df.head())

# # =========================
# # Step D: update only those columns
# # =========================
# report = update_google_sheet_only_columns(
#     sheet_id=SHEET_ID,
#     worksheet_gid=WORKSHEET_GID,
#     service_account_json_path=SERVICE_ACCOUNT_JSON,
#     payload_df=payload_df,
#     key_col="source_id",
#     columns_to_update=TARGET_COLS,
#     chunk_size=500,
#     overwrite=True,   # set False to fill blanks only
#     verbose=True,
# )

# report

# %% [markdown]
# # import data

# %%
# lon_path = "outputs_new/parent/dedupe_clusters_long_full.parquet"
# data = pd.read_parquet(lon_path)

data = pd.read_pickle("outputs_new/dedupe_data_group_merge.pkl")
data["dup_group_id"] = (
    data["dup_group_id"]
    .astype("string")
    .str.strip()
    .replace("", pd.NA)
    .fillna(data["record_id"])
)
data
# Out:
#                                record_id     server_name   backend  \
# 0        crossref::10.21467/preprints.48  AIJR Preprints  crossref
# 1        crossref::10.21467/preprints.43  AIJR Preprints  crossref
# 2        crossref::10.21467/preprints.39  AIJR Preprints  crossref
# 3        crossref::10.21467/preprints.38  AIJR Preprints  crossref
# 4        crossref::10.21467/preprints.36  AIJR Preprints  crossref
# ...                                  ...             ...       ...
# 8084855             openalex::W999325625           viXra  openalex
# 8084856             openalex::W999460032           viXra  openalex
# 8084857              openalex::W99967155           viXra  openalex
# 8084858             openalex::W999790414           viXra  openalex
# 8084859             openalex::W999805801           viXra  openalex
#
#                            doi                                doi_url  \
# 0        10.21467/preprints.48  https://doi.org/10.21467/preprints.48
# 1        10.21467/preprints.43  https://doi.org/10.21467/preprints.43
# 2        10.21467/preprints.39  https://doi.org/10.21467/preprints.39
# 3        10.21467/preprints.38  https://doi.org/10.21467/preprints.38
# 4        10.21467/preprints.36  https://doi.org/10.21467/preprints.36
# ...                        ...                                    ...
# 8084855                   None                                   None
# 8084856                   None                                   None
# 8084857                   None                                   None
# 8084858                   None                                   None
# 8084859                   None                                   None
#
#                                           landing_page_url  \
# 0        https://preprints.aijr.org/index.php/ap/prepri...
# 1        https://preprints.aijr.org/index.php/ap/prepri...
# 2        https://preprints.aijr.org/index.php/ap/prepri...
# 3        https://preprints.aijr.org/index.php/ap/prepri...
# 4        https://preprints.aijr.org/index.php/ap/prepri...
# ...                                                    ...
# 8084855              https://vixra.org/pdf/1409.0090v1.pdf
# 8084856                    https://vixra.org/abs/1112.0094
# 8084857              https://vixra.org/pdf/1406.0019v1.pdf
# 8084858              https://vixra.org/pdf/1306.0105v3.pdf
# 8084859              https://vixra.org/pdf/1412.0197v3.pdf
#
#                                                      title  \
# 0        Bird’s Eye View on the Diagnosis, Treatment, &...
# 1        Doxycycline and Minocycline Drugs as a Treatme...
# 2        A Genetic Perspective of 2019-nCoV in Relation...
# 3        Marine Algae as a Natural Source for Antiviral...
# 4        Possible Prevention of COVID 19 by Using Linol...
# ...                                                    ...
# 8084855                 Three Objections to Modern Physics
# 8084856                               Particle Mass Ratios
# 8084857  Quantum FFF Theory Proposals for Some Unsolved...
# 8084858  Investigation of the Formalism of Particle Dyn...
# 8084859  Electromagnetic Energy and Electromagnetic For...
#
#                                               authors_flat institutions_flat  \
# 0                              Panchalingala, Sai Bhargavi              None
# 1                                         Mostafa, Mohamed              None
# 2                                        Dasgupta, Rimjhim              None
# 3        Musale, Amar S; G., Raja Krishna Kumar; Sapre,...              None
# 4        Subhash, Venkata; G, Raja Krishna Kumar; Sapre...              None
# ...                                                    ...               ...
# 8084855                                      Lubomir Vlcek              None
# 8084856                                         DT Froedge              None
# 8084857                                           Leo Vuyk              None
# 8084858                                        Chi-Yi Chen              None
# 8084859                                    Yu.A. Spirichev              None
#
#         countries_flat relations_json version_label is_version_of  \
# 0                 None           None          None
# 1                 None           None          None
# 2                 None           None          None
# 3                 None           None          None
# 4                 None           None          None
# ...                ...            ...           ...           ...
# 8084855           None           None          None          None
# 8084856           None           None          None          None
# 8084857           None           None          None          None
# 8084858           None           None          None          None
# 8084859           None           None          None          None
#
#         is_preprint_of has_preprint has_review has_published_version  \
# 0                                                              false
# 1                                                              false
# 2                                                              false
# 3                                                              false
# 4                                                              false
# ...                ...          ...        ...                   ...
# 8084855           None         None       None                  None
# 8084856           None         None       None                  None
# 8084857           None         None       None                  None
# 8084858           None         None       None                  None
# 8084859           None         None       None                  None
#
#         published_version_ids_json version_of_ids_json update_to_json  \
# 0                             None                None           None
# 1                             None                None           None
# 2                             None                None           None
# 3                             None                None           None
# 4                             None                None           None
# ...                            ...                 ...            ...
# 8084855                       None                None           None
# 8084856                       None                None           None
# 8084857                       None                None           None
# 8084858                       None                None           None
# 8084859                       None                None           None
#
#         raw_relationships_json records_hierarchy date_first_seen  \
# 0                         None            parent      2020-05-03
# 1                         None            parent      2020-04-25
# 2                         None            parent      2020-04-16
# 3                         None            parent      2020-04-15
# 4                         None            parent      2020-04-15
# ...                        ...               ...             ...
# 8084855                   None            parent      2014-09-01
# 8084856                   None            parent      2011-12-01
# 8084857                   None            parent      2014-06-01
# 8084858                   None            parent      2013-06-01
# 8084859                   None            parent      2014-12-01
#
#          publication_year_first_seen records_hierarchy_backup  \
# 0                               2020                   parent
# 1                               2020                   parent
# 2                               2020                   parent
# 3                               2020                   parent
# 4                               2020                   parent
# ...                              ...                      ...
# 8084855                         2014                   parent
# 8084856                         2011                   parent
# 8084857                         2014                   parent
# 8084858                         2013                   parent
# 8084859                         2014                   parent
#
#         parent_record_id                     dup_group_id authors_fp_tokenbag  \
# 0                   None  crossref::10.21467/preprints.48                None
# 1                   None  crossref::10.21467/preprints.43     mohamed_mostafa
# 2                   None  crossref::10.21467/preprints.39    dasgupta_rimjhim
# 3                   None  crossref::10.21467/preprints.38                None
# 4                   None  crossref::10.21467/preprints.36                None
# ...                  ...                              ...                 ...
# 8084855             None             openalex::W999325625       lubomir_vlcek
# 8084856             None             openalex::W999460032          dt_froedge
# 8084857             None              openalex::W99967155            leo_vuyk
# 8084858             None             openalex::W999790414         chen_chi_yi
# 8084859             None             openalex::W999805801      a_spirichev_yu
#
#                                             title_clean_v2  \
# 0                                                     None
# 1        doxycycline and minocycline drugs as a treatme...
# 2        a genetic perspective of 2019 ncov in relation...
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 8084855                 three objections to modern physics
# 8084856                               particle mass ratios
# 8084857  quantum fff theory proposals for some unsolved...
# 8084858  investigation of the formalism of particle dyn...
# 8084859  electromagnetic energy and electromagnetic for...
#
#         authors_fp_last_initial authors_fp_last  \
# 0                          None            None
# 1                     mostafa|m            None
# 2                    dasgupta|r            None
# 3                          None            None
# 4                          None            None
# ...                         ...             ...
# 8084855                 vlcek|l            None
# 8084856               froedge|d            None
# 8084857                  vuyk|l            None
# 8084858                  chen|c            None
# 8084859             spirichev|y            None
#
#         records_hierarchy_dedupe_backup parent_record_id_dedupe_backup  \
# 0                                parent                           None
# 1                                parent                           None
# 2                                parent                           None
# 3                                parent                           None
# 4                                parent                           None
# ...                                 ...                            ...
# 8084855                          parent                           None
# 8084856                          parent                           None
# 8084857                          parent                           None
# 8084858                          parent                           None
# 8084859                          parent                           None
#
#         dup_group_id_dedupe_backup records_hierarchy_unify_version_backup  \
# 0                             None                                 parent
# 1                             None                                 parent
# 2                             None                                 parent
# 3                             None                                 parent
# 4                             None                                 parent
# ...                            ...                                    ...
# 8084855                       None                                 parent
# 8084856                       None                                 parent
# 8084857                       None                                 parent
# 8084858                       None                                 parent
# 8084859                       None                                 parent
#
#         parent_record_id_unify_version_backup  \
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# ...                                       ...
# 8084855                                  None
# 8084856                                  None
# 8084857                                  None
# 8084858                                  None
# 8084859                                  None
#
#         dup_group_id_unify_version_backup
# 0                                    None
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# ...                                   ...
# 8084855                              None
# 8084856                              None
# 8084857                              None
# 8084858                              None
# 8084859                              None
#
# [8084860 rows x 37 columns]

# %%
data[data['dup_group_id'].isna()]
# Out:
# Empty DataFrame
# Columns: [record_id, server_name, backend, doi, doi_url, landing_page_url, title, authors_flat, institutions_flat, countries_flat, relations_json, version_label, is_version_of, is_preprint_of, has_preprint, has_review, has_published_version, published_version_ids_json, version_of_ids_json, update_to_json, raw_relationships_json, records_hierarchy, date_first_seen, publication_year_first_seen, records_hierarchy_backup, parent_record_id, dup_group_id, authors_fp_tokenbag, title_clean_v2, authors_fp_last_initial, authors_fp_last, records_hierarchy_dedupe_backup, parent_record_id_dedupe_backup, dup_group_id_dedupe_backup, records_hierarchy_unify_version_backup, parent_record_id_unify_version_backup, dup_group_id_unify_version_backup]
# Index: []

# %% [markdown]
# # execution

# %%
SHEET_ID = "10_7FdcpZjntqFsEHIii7bAM72uF__of_iUohSD5w8w4"
GID = "582500270"   # your tab gid

sheet_url = f"https://docs.google.com/spreadsheets/d/{SHEET_ID}/export?format=csv&gid={GID}"

sheet_df = pd.read_csv(sheet_url)

sheet_df.head()
# Out:
#        source_id open_alex_source_id  InternalOrder      SourceOrig  \
# 0        Advance                 NaN              1  1Original list
# 1     AfricArXiv                 NaN              2  1Original list
# 2  AgEcon Search                 NaN              3  1Original list
# 3       AgriRxiv                 NaN              4  1Original list
# 4            NaN                 NaN              5  1Original list
#
#                            Server Name  \
# 0  Advance: a SAGE Preprints Community
# 1                           AfricArxiv
# 2                        AgEcon Search
# 3          AgriRxiv (formerly AgriXiv)
# 4                         ai.vixra.org
#
#                           Server Name Rule File  \
# 0                                       Advance
# 1                                    AfricArXiv
# 2  AgEcon Search (University of Minnesota, USA)
# 3                                      AgriRxiv
# 4                                  ai.vixra.org
#
#                                                Notes Registration Agencies  \
# 0                                                NaN              Crossref
# 1                                                NaN     Crossref/DataCite
# 2  no preprint group on main website or on dataci...              DataCite
# 3  Preprints for Agriculture and Allied Sciences ...              Crossref
# 4                                                NaN                no doi
#
#   Where to get metadata ?                                   Example URLs/DOI  \
# 0                Crossref  ['https://doi.org/10.31124/advance.172059085.5...
# 1                Crossref  ['https://doi.org/10.31730/osf.io/7n258', 'htt...
# 2                DataCite  https://openalex.org/works?page=1&filter=prima...
# 3                Crossref  ['https://doi.org/10.31220/osf.io/87k3q', 'htt...
# 4             API website                          https://ai.vixra.org/hep/
#
#     synonym Electronic\nISSN / ISBN  Source to obtain Red Columns  \
# 0   Advance                     NaN                      Crossref
# 1       NaN                     NaN             Crossref/Datacite
# 2       NaN               2332-3140                      DataCite
# 3  AgriRxiv               2791-1969                      Crossref
# 4       NaN                     NaN                       Website
#
#                                           Column 134 Column 135 download rule  \
# 0  https://api.crossref.org/works?filter=type:pos...         ok            ok
# 1  https://api.datacite.org/dois?client-id=eqhh.h...         ok            ok
# 2  https://api.datacite.org/dois?client-id=tind.a...         ok            ok
# 3  https://api.crossref.org/works?filter=type:pos...         ok            ok
# 4                                                NaN         ok             /
#
#   Collection Date used for Red Columns number of unique preprints  \
# 0                           31/12/2025                       2440
# 1                           31/12/2025                        483
# 2                           31/12/2025                     172831
# 3                           31/12/2025                        804
# 4                           10/12/2025                        966
#
#    number of unique preprints that are published  \
# 0                                          162.0
# 1                                           56.0
# 2                                           53.0
# 3                                           24.0
# 4                                            NaN
#
#    % of unique that are published   \
# 0                         6.639344
# 1                        11.594203
# 2                         0.030666
# 3                         2.985075
# 4                              NaN
#
#    Number of unique preprints with more than 1 version  \
# 0                                             1788.0
# 1                                               68.0
# 2                                            27568.0
# 3                                              132.0
# 4                                                NaN
#
#    % of unique that have more than one version  Is the Server in Crossref  \
# 0                                     73.278689                      True
# 1                                     14.078675                      True
# 2                                     15.950842                     False
# 3                                     16.417910                      True
# 4                                           NaN                        No
#
#                              Example DOI in Crossref  \
# 0  ['https://doi.org/10.31124/advance.172059085.5...
# 1  ['https://doi.org/10.31730/osf.io/7n258', 'htt...
# 2                                                NaN
# 3  ['https://doi.org/10.31220/osf.io/87k3q', 'htt...
# 4                                                NaN
#
#                                API Query in Crossref Crossref collection_date  \
# 0  https://api.crossref.org/works/10.31124/advanc...               31/12/2025
# 1  https://api.crossref.org/works/10.31730/osf.io...               31/12/2025
# 2                                                NaN               2025/12/31
# 3  https://api.crossref.org/works/10.31220/osf.io...               31/12/2025
# 4                                                NaN                      NaN
#
#    Number of works in Crossref Number of unique preprints in Crossref  \
# 0                       4400.0                                  2,440
# 1                        501.0                                    483
# 2                          NaN                                    NaN
# 3                        818.0                                    804
# 4                          NaN                                    NaN
#
#   Remarks in Crossref  \
# 0                  ok
# 1                  ok
# 2                 NaN
# 3                  ok
# 4                 NaN
#
#    Number of unique preprints that are published in Crossref  \
# 0                                              162.0
# 1                                               56.0
# 2                                                NaN
# 3                                               24.0
# 4                                                NaN
#
#    %_of unique that are published in Crossref  \
# 0                                    6.639344
# 1                                   11.594203
# 2                                         NaN
# 3                                    2.985075
# 4                                         NaN
#
#    Number of unique preprints with more than 1 version in Crossref  \
# 0                                             1788.0
# 1                                               68.0
# 2                                                NaN
# 3                                              132.0
# 4                                                NaN
#
#    % of unique that have more than one version  in Crossref  \
# 0                                          73.278689
# 1                                          14.078675
# 2                                                NaN
# 3                                          16.417910
# 4                                                NaN
#
#    Works_in_2024 in Crossref  Works_in_2025 in Crossref  Notes for Crossref  \
# 0                      414.0                      346.0                 NaN
# 1                       16.0                        0.0                 NaN
# 2                        NaN                        NaN                 NaN
# 3                       69.0                       93.0                 NaN
# 4                        NaN                        NaN                 NaN
#
#   Is the server in DataCite     ExampleDOI in DataCite  \
# 0                     False                        NaN
# 1                     False  10.60763/africarxiv/10352
# 2                      True    10.22004/ag.econ.151297
# 3                     False                        NaN
# 4                        No                        NaN
#
#                               API Query for DataCite DataCite Collection Date  \
# 0                                                NaN               2025/12/31
# 1  https://api.datacite.org/dois?client-id=eqhh.h...               31/12/2025
# 2  https://api.datacite.org/dois?client-id=tind.a...               31/12/2025
# 3                                                NaN               2025/12/31
# 4                                                NaN                      NaN
#
#   Number of works in DataCite number_of_preprint_unique in DataCite  \
# 0                         NaN                                   NaN
# 1                         NaN                                   NaN
# 2                     188,173                               172,831
# 3                         NaN                                   NaN
# 4                         NaN                                   NaN
#
#    Remarks DataCite  \
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
#    number of unique preprints that are published in Datacite  \
# 0                                                NaN
# 1                                                NaN
# 2                                               53.0
# 3                                                NaN
# 4                                                NaN
#
#    %_of unique that are published in DataCite  \
# 0                                         NaN
# 1                                         NaN
# 2                                    0.030666
# 3                                         NaN
# 4                                         NaN
#
#    Number of unique preprints with more than 1 version in DataCite  \
# 0                                                NaN
# 1                                                NaN
# 2                                            27568.0
# 3                                                NaN
# 4                                                NaN
#
#    % of unique that have more than one version  in DataCite  \
# 0                                                NaN
# 1                                                NaN
# 2                                          15.950842
# 3                                                NaN
# 4                                                NaN
#
#    Works_in_2024 in DataCite  Works_in_2025 in DataCite  Notes for DataCite  \
# 0                        NaN                        NaN                 NaN
# 1                        NaN                        NaN                 NaN
# 2                     8072.0                     9054.0                 NaN
# 3                        NaN                        NaN                 NaN
# 4                        NaN                        NaN                 NaN
#
#   Is the server in OpenAlex                       Example DOI in OpenAlex  \
# 0                     False  https://doi.org/10.31124/advance.13491510.v1
# 1                     False                       10.60763/africarxiv/357
# 2                     False       https://doi.org/10.22004/ag.econ.273723
# 3                     False  https://doi.org/10.31220/agrirxiv.2024.00228
# 4                        no                                        no doi
#
#                               API Querry in OpenAlex  \
# 0               https://api.openalex.org/w4212857168
# 1  https://api.openalex.org/works?page=1&filter=p...
# 2  https://api.openalex.org/works?page=1&filter=p...
# 3  https://openalex.org/works?page=1&filter=prima...
# 4                                                  /
#
#   OpenAlex Data Collection Date Number of works in OpenAlex  \
# 0                    31/12/2025                         NaN
# 1                    31/12/2025                         NaN
# 2                    31/12/2025                         NaN
# 3                    31/12/2025                         NaN
# 4                    12/12/2025                           /
#
#   number_of_preprint_unique in OpenAlex  Remarks  OpenAlex  \
# 0                                   NaN                NaN
# 1                                   NaN                NaN
# 2                                   NaN                NaN
# 3                                   NaN                NaN
# 4                                     /                NaN
#
#    number of unique preprints that are published in OpenAlex  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    %_of unique that are published in OpenAlex  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Number of unique preprints with more than 1 version in OpenAlex  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    % of unique preprints with more than 1 version in OpenAlex  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Works_in_2024 in OpenAlex  Works_in_2025 in OpenAlex OpenAlex notes  \
# 0                        NaN                        NaN            NaN
# 1                        NaN                        NaN            NaN
# 2                        NaN                        NaN            NaN
# 3                        NaN                        NaN            NaN
# 4                        NaN                        NaN            NaN
#
#                            ExampleDOI on server page  \
# 0  https://doi.org/10.31124/advance.176303470.009...
# 1          https://doi.org/10.60763/africarxiv/10286
# 2            https://doi.org/10.22004/ag.econ.382416
# 3       https://doi.org/10.31220/agriRxiv.2020.00005
# 4                                             no doi
#
#                            API Querry on Server Page  \
# 0                                                NaN
# 1  https://api.osf.io/v2/providers/preprints/afri...
# 2                 https://ageconsearch.umn.edu/oai2d
# 3  https://api.osf.io/v2/providers/preprints/arab...
# 4                                                NaN
#
#   ServerPage Data Collection Date Number of Works on Server Page  \
# 0                      15/12/2025                          2,384
# 1                      15/12/2025                          7,944
# 2                      15/12/2025                        211,648
# 3                      15/12/2025                            464
# 4                      15/12/2025                            988
#
#   number_of_preprint_unique on Server Page Remarks  Server Page  \
# 0                          no types filter                  NaN
# 1                          no types filter                  NaN
# 2                          no types filter                  NaN
# 3                                      462                  NaN
# 4                          no types filter                  NaN
#
#    number of unique preprints that are published on Server Page  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    %_of unique that are published on Server Page  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Number of unique preprints with more than 1 version on Server Page  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    %of unique preprints with more than 1 version on Server Page  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Works_in_2024 on Server Page  Works_in_2025 on Server Page  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#   Active (in 2025)                                          API Query  \
# 0              yes                                                NaN
# 1              yes  https://api.osf.io/v2/providers/preprints/afri...
# 2               no                 https://ageconsearch.umn.edu/oai2d
# 3              yes  https://api.osf.io/v2/providers/preprints/arab...
# 4              yes                                                NaN
#
#                                             API LINK  \
# 0                                                  -
# 1  https://api.osf.io/v2/providers/preprints/afri...
# 2  https://ageconsearch.umn.edu/oai2d?verb=ListRe...
# 3                                                  -
# 4                                       ai.vixra.org
#
#   total count from sever API link Dimensions  \
# 0                               /        Yes
# 1                             480        Yes
# 2                          209243         no
# 3                             397        Yes
# 4                             567         no
#
#                                     Dimensions Query  \
# 0  https://app.dimensions.ai/discover/publication...
# 1  https://app.dimensions.ai/discover/publication...
# 2                                                NaN
# 3  https://app.dimensions.ai/discover/publication...
# 4                                                NaN
#
#                                Dimensions Query note DOI registration Agency  \
# 0                                                NaN                Crossref
# 1                                                NaN                DataCite
# 2                                                NaN                DataCite
# 3  https://app.dimensions.ai/discover/publication...                Crossref
# 4                                                NaN                  no doi
#
#   OAI-PMH URL                              Server Main Page Link  \
# 0         NaN                       https://advance.sagepub.com/
# 1         NaN              https://africarxiv.ubuntunet.net/home
# 2         NaN                https://ageconsearch.umn.edu/?ln=en
# 3         NaN  https://www.cabidigitallibrary.org/journal/agr...
# 4         NaN                              https://ai.vixra.org/
#
#   Active (in 2026) MarioDateCheck                        Who can submit text  \
# 0               No       01/15/26                                 Not Active
# 1              Yes       01/15/26                      Researcher (specific)
# 2               No       01/15/26  Organizations, not individual researchers
# 3              Yes       01/15/26                                 Researcher
# 4              Yes       01/15/26                                 Researcher
#
#   Researcher can submit Accepts Preprints ONLY  \
# 0            Not Active                    Yes
# 1                   Yes                     No
# 2                    No                     No
# 3                   Yes                    Yes
# 4                   Yes                    Yes
#
#                           Type of documents accepted  \
# 0                                     Preprints only
# 1  working papers, preprints, accepted manuscript...
# 2  articles, conference papers, working or discus...
# 3                                     Preprints only
# 4                                     Preprints only
#
#   Publish - Review - Curate models Date of Check  \
# 0                               No      08/30/25
# 1                               No      08/30/25
# 2                               No      08/30/25
# 3                               No      08/30/25
# 4                               No      08/30/25
#
#   Definition of server/platform on the main page (Y/N)  \
# 0                                                  Y
# 1                                                  Y
# 2                                                  N
# 3                                                  Y
# 4                                                  Y
#
#   Text of the Definition of the server/platform on the main page   \
# 0  Advance: a Sage preprints community allows res...
# 1  AfricArxiv is a community-led digital archive ...
# 2                                                NaN
# 3  agriRxiv (pronounced ‘agri-archive’) is a free...
# 4  ai.viXra.org is an e-print archive of AI assis...
#
#           SelfDefinitiononMainPage Definition on non-main page  \
# 0              preprints community                         NaN
# 1    community-led digital archive                         NaN
# 2                              NaN              web repository
# 3  source of unpublished preprints                         NaN
# 4                  e-print archive                         NaN
#
#                            Non-main source and notes  \
# 0                                                NaN
# 1  Very inconsistent termonology across their var...
# 2  From their FAQ:  ".. is free-to-user Web site ...
# 3                                                NaN
# 4                                                NaN
#
#   Definition of preprint on main page (Y/N)  \
# 0                                         Y
# 1                                         N
# 2                                         N
# 3                                         N
# 4                                         N
#
#                          Text of Preprint definition  \
# 0  A preprint is a version of a scholarly piece o...
# 1  A preprint is a version of a scholarly or scie...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Classified as 1- preprint, 2-eprint, 3-working, 4--   \
# 0                                                1.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Any Warning message on main page  \
# 0                                Y
# 1                                N
# 2                                N
# 3                                N
# 4                                Y
#
#                                      Text of message  \
# 0  Papers posted to Advance or transportRxiv shou...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  ai.viXra.org has no association with arXiv.org...
#
#                             Link of preprint checked  \
# 0  https://advance.sagepub.com/doi/full/10.31124/...
# 1  https://africarxiv.ubuntunet.net/items/e85a94c...
# 2   https://ageconsearch.umn.edu/record/358968?v=pdf
# 3  https://www.cabidigitallibrary.org/doi/10.3122...
# 4                 https://ai.vixra.org/abs/2508.0021
#
#   Any Warning on a single preprint page  \
# 0                                     Y
# 1                                     N
# 2                                     N
# 3                                     N
# 4                                     Y
#
#                          Text of single page warning  \
# 0  Preprints are early versions of research artic...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  ai.Vixra.org is a AI assisted e-print reposito...
#
#    Any warning on the text of COVID 19 page  Text of COVID page warning  \
# 0                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
#
#                 Do they have a general warning label  \
# 0  Preprints are early versions of research artic...
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                               yes
#
#                               Notes on warning label  \
# 0  Papers posted to Advance or transportRxiv shou...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  ai.Vixra.org is a AI assisted e-print reposito...
#
#   Is there a separate warning label for medical preprints  \
# 0                                                NaN
# 1                                                 No
# 2                                                NaN
# 3                                                NaN
# 4                                                 no
#
#                                    Types can identify peer reviewed version  \
# 0  Primary submission preprint platforms                                NaN
# 1                                    NaN                                NaN
# 2                             repository                                NaN
# 3  Primary submission preprint platforms                                NaN
# 4  Primary submission preprint platforms                                NaN
#
#   Review Type Publications can be submitted elsewhere   \
# 0         NaN                                      NaN
# 1         NaN                                      NaN
# 2         NaN                                      NaN
# 3         NaN                                      NaN
# 4         NaN                                      NaN
#
#                                           File types Who has access contact  \
# 0                                                NaN            NaN     NaN
# 1  Text documents (preprints, postprints, VoR):\n...            NaN     NaN
# 2      Conference papers and posters\n    Working...            NaN     NaN
# 3  The following types of article may be posted:\...            NaN     NaN
# 4                                                NaN            NaN     NaN
#
#    Does a server allow posting of protocols, or other resaeerch parts?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Is there a separete metadata for protocols?  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   Preprint Tag for Search or metadata  \
# 0                                 yes
# 1                                 yes
# 2                                 yes
# 3                                 yes
# 4                                 NaN
#
#                                           Versioning Publication Status  \
# 0                                                NaN                NaN
# 1  We also provide options to link data and code,...                NaN
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4                                                NaN                NaN
#
#                                 Charges for Services  \
# 0                                                NaN
# 1                                                NaN
# 2  There are no costs for posting papers for grou...
# 3     There is no fee to submit articles to agriRxiv
# 4                                                NaN
#
#   is statistics available ? metrics to track their preprints Mario List  \
# 0                       NaN                              NaN        yes
# 1                       NaN                              NaN        yes
# 2                       NaN                              NaN        NaN
# 3                       yes                              NaN        yes
# 4                       NaN                              NaN        NaN
#
#   Wikipedia List Dimensions List ASAP BIO List  \
# 0            NaN             yes           yes
# 1            yes             yes           yes
# 2            NaN             NaN           NaN
# 3            yes             yes           yes
# 4            NaN             NaN           NaN
#
#   Directory of Open Access Preprint Repositories  List  \
# 0                                                yes
# 1                                                yes
# 2                                                yes
# 3                                                yes
# 4                                                NaN
#
#   State University of Campinas   \
# 0                           NaN
# 1                           yes
# 2                           NaN
# 3                           yes
# 4                           NaN
#
#                                   Disciplinary scope  \
# 0                     Humanities and Social Sciences
# 1                              All scientific fields
# 2       Relating to agricultural & applied economics
# 3  Relating to agriculture and allied sciences, i...
# 4                                                NaN
#
#              Ownership type  \
# 0                 Publisher
# 1  Academic community group
# 2      Academic institution
# 3  Academic community group
# 4                       NaN
#
#                                  Screening processes  \
# 0  Content within scope, scholarly nature, manusc...
# 1                                                NaN
# 2                                                NaN
# 3  Content within scope, no inappropriate materia...
# 4                                                NaN
#
#                Additional notes on screening process  \
# 0  Preprints must include a research question or ...
# 1  No information on screening on the new website...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                            External content indexing  \
# 0                           Google Scholar, CrossRef
# 1  Google Scholar, SHARE, Microsoft Academic, Unp...
# 2                                                NaN
# 3  Google Scholar, Crossref, Researcher-app; Prep...
# 4                                                NaN
#
#                                Permanence of content         Commenting
# 0  Permanent with some removal options in excepti...         Commenting
# 1  Permanent with some removal options in excepti...  no (on UbuntuNet)
# 2  Permanent with some removal options in special...                 no
# 3  Permanent with withdrawal marking; articles ca...                no
# 4                                                NaN                NaN

# %%
# ============================================
# 5) RUN PIPELINE (edit these 4 things)
# ============================================

SHEET_ID = "10_7FdcpZjntqFsEHIii7bAM72uF__of_iUohSD5w8w4"
WORKSHEET_GID = 881157301 # test copy database sheet 582500270

# 1) put your service account json path here
SERVICE_ACCOUNT_JSON = "sheet_writer_key/preprint-tracker-credential.json"
# SERVICE_ACCOUNT_JSON =  '/mnt/c/SCHOLCOMMLAB/APPs/preprint-harvester/notebooks/notebooks/sheet_writer_key/preprint-tracker-credential.json'
# 2) your target columns exactly as in the sheet (including trailing spaces)
TARGET_COLS = [
    'Collection Date used for Red Columns',
    'number of unique preprints',
    'number of unique preprints that are published',
    '% of unique that are published ',
    'Number of unique preprints with more than 1 version',
    '% of unique that have more than one version ',
    'Is the Server in Crossref',
    'Crossref collection_date',
    'Number of works in Crossref',
    'Number of unique preprints in Crossref',
    'Number of unique preprints that are published in Crossref',
    '%_of unique that are published in Crossref',
    'Number of unique preprints with more than 1 version in Crossref',
    '% of unique that have more than one version  in Crossref',
    'Works_in_2024 in Crossref',
    'Works_in_2025 in Crossref',
    'Is the server in DataCite',
    'DataCite Collection Date',
    'Number of works in DataCite',
    'number_of_preprint_unique in DataCite',
    'number of unique preprints that are published in Datacite',
    '%_of unique that are published in DataCite',
    'Number of unique preprints with more than 1 version in DataCite',
    '% of unique that have more than one version  in DataCite',
    'Works_in_2024 in DataCite',
    'Works_in_2025 in DataCite',
    'Is the server in OpenAlex',
    'OpenAlex Data Collection Date',
    'Number of works in OpenAlex',
    'number_of_preprint_unique in OpenAlex',
    'number of unique preprints that are published in OpenAlex',
    '%_of unique that are published in OpenAlex',
    'Number of unique preprints with more than 1 version in OpenAlex',
    '% of unique preprints with more than 1 version in OpenAlex',
    'Works_in_2024 in OpenAlex',
    'Works_in_2025 in OpenAlex',
]

# 3) choose the collection date you want for all servers
DEFAULT_COLLECTION_DATE = "2025/12/31"

# 4) optional later: per server overrides (keep None for now)
PER_SERVER_DATE = None
# Example:
# PER_SERVER_DATE = {"bioRxiv": "2026/01/15", "medRxiv": "2026/01/15"}


# =========================
# Step A: compute metrics
# =========================
# IMPORTANT: 'data' must be your dedupe long dataframe in memory
overall_df, backend_df = build_sheet_metrics_duckdb(data, choose_parent="oldest")

# =========================
# Step B: read the sheet
# =========================
sheet_df = read_sheet_as_df(
    sheet_id=SHEET_ID,
    worksheet_gid=WORKSHEET_GID,
    service_account_json_path=SERVICE_ACCOUNT_JSON,
)

# =========================
# Step C: build payload (only key + target cols)
# =========================
payload_df = build_update_payload(
    sheet_df=sheet_df,
    overall_df=overall_df,
    backend_df=backend_df,
    target_cols=TARGET_COLS,
    key_col="source_id",
    default_collection_date=DEFAULT_COLLECTION_DATE,
    per_server_date=PER_SERVER_DATE,
)

payload_df.head()

# =========================
# Step D: update only those columns
# =========================
report = update_google_sheet_only_columns(
    sheet_id=SHEET_ID,
    worksheet_gid=WORKSHEET_GID,
    service_account_json_path=SERVICE_ACCOUNT_JSON,
    payload_df=payload_df,
    key_col="source_id",
    columns_to_update=TARGET_COLS,
    chunk_size=500,
    overwrite=True,   # set False to fill blanks only
    verbose=True,
)

report
# Out:
# Chunk 1: scanned 388 rows, wrote 13968 cells
# {'sheet_id': '10_7FdcpZjntqFsEHIii7bAM72uF__of_iUohSD5w8w4',
#  'worksheet_gid': 881157301,
#  'rows_payload': 751,
#  'rows_matched': 388,
#  'missing_keys': [''],
#  'n_missing_keys': 1,
#  'columns_updated': ['Collection Date used for Red Columns',
#   'number of unique preprints',
#   'number of unique preprints that are published',
#   '% of unique that are published ',
#   'Number of unique preprints with more than 1 version',
#   '% of unique that have more than one version ',
#   'Is the Server in Crossref',
#   'Crossref collection_date',
#   'Number of works in Crossref',
#   'Number of unique preprints in Crossref',
#   'Number of unique preprints that are published in Crossref',
#   '%_of unique that are published in Crossref',
#   'Number of unique preprints with more than 1 version in Crossref',
#   '% of unique that have more than one version  in Crossref',
#   'Works_in_2024 in Crossref',
#   'Works_in_2025 in Crossref',
#   'Is the server in DataCite',
#   'DataCite Collection Date',
#   'Number of works in DataCite',
#   'number_of_preprint_unique in DataCite',
#   'number of unique preprints that are published in Datacite',
#   '%_of unique that are published in DataCite',
#   'Number of unique preprints with more than 1 version in DataCite',
#   '% of unique that have more than one version  in DataCite',
#   'Works_in_2024 in DataCite',
#   'Works_in_2025 in DataCite',
#   'Is the server in OpenAlex',
#   'OpenAlex Data Collection Date',
#   'Number of works in OpenAlex',
#   'number_of_preprint_unique in OpenAlex',
#   'number of unique preprints that are published in OpenAlex',
#   '%_of unique that are published in OpenAlex',
#   'Number of unique preprints with more than 1 version in OpenAlex',
#   '% of unique preprints with more than 1 version in OpenAlex',
#   'Works_in_2024 in OpenAlex',
#   'Works_in_2025 in OpenAlex'],
#  'overwrite': True,
#  'cells_written': 13968,
#  'chunks': 1}

# %% [markdown]
# # exploration

# %%
payload_df
# Out:
#          source_id Collection Date used for Red Columns  \
# 0          Advance                           2025/12/31
# 1       AfricArXiv                           2025/12/31
# 2    AgEcon Search                           2025/12/31
# 3         AgriRxiv                           2025/12/31
# 4                                            2025/12/31
# ..             ...                                  ...
# 746       cngb.cga                           2025/12/31
# 747        cos.osf                           2025/12/31
# 748                                          2025/12/31
# 749                                          2025/12/31
# 750                                          2025/12/31
#
#     number of unique preprints number of unique preprints that are published  \
# 0                       2440.0                                         162.0
# 1                        483.0                                          56.0
# 2                     172831.0                                          53.0
# 3                        804.0                                          24.0
# 4
# ..                         ...                                           ...
# 746
# 747
# 748
# 749
# 750
#
#     % of unique that are published   \
# 0                          6.639344
# 1                         11.594203
# 2                          0.030666
# 3                          2.985075
# 4
# ..                              ...
# 746
# 747
# 748
# 749
# 750
#
#     Number of unique preprints with more than 1 version  \
# 0                                               1788.0
# 1                                                 68.0
# 2                                              27568.0
# 3                                                132.0
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     % of unique that have more than one version   Is the Server in Crossref  \
# 0                                      73.278689                       True
# 1                                      14.078675                       True
# 2                                      15.950842                      False
# 3                                       16.41791                       True
# 4                                                                     False
# ..                                           ...                        ...
# 746                                                                   False
# 747                                                                   False
# 748                                                                   False
# 749                                                                   False
# 750                                                                   False
#
#     Crossref collection_date Number of works in Crossref  \
# 0                 2025/12/31                      4400.0
# 1                 2025/12/31                       501.0
# 2                 2025/12/31
# 3                 2025/12/31                       818.0
# 4                 2025/12/31
# ..                       ...                         ...
# 746               2025/12/31
# 747               2025/12/31
# 748               2025/12/31
# 749               2025/12/31
# 750               2025/12/31
#
#     Number of unique preprints in Crossref  \
# 0                                   2440.0
# 1                                    483.0
# 2
# 3                                    804.0
# 4
# ..                                     ...
# 746
# 747
# 748
# 749
# 750
#
#     Number of unique preprints that are published in Crossref  \
# 0                                                162.0
# 1                                                 56.0
# 2
# 3                                                 24.0
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     %_of unique that are published in Crossref  \
# 0                                     6.639344
# 1                                    11.594203
# 2
# 3                                     2.985075
# 4
# ..                                         ...
# 746
# 747
# 748
# 749
# 750
#
#     Number of unique preprints with more than 1 version in Crossref  \
# 0                                               1788.0
# 1                                                 68.0
# 2
# 3                                                132.0
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     % of unique that have more than one version  in Crossref  \
# 0                                            73.278689
# 1                                            14.078675
# 2
# 3                                             16.41791
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     Works_in_2024 in Crossref Works_in_2025 in Crossref  \
# 0                       414.0                     346.0
# 1                        16.0                       0.0
# 2
# 3                        69.0                      93.0
# 4
# ..                        ...                       ...
# 746
# 747
# 748
# 749
# 750
#
#      Is the server in DataCite DataCite Collection Date  \
# 0                        False               2025/12/31
# 1                        False               2025/12/31
# 2                         True               2025/12/31
# 3                        False               2025/12/31
# 4                        False               2025/12/31
# ..                         ...                      ...
# 746                      False               2025/12/31
# 747                      False               2025/12/31
# 748                      False               2025/12/31
# 749                      False               2025/12/31
# 750                      False               2025/12/31
#
#     Number of works in DataCite number_of_preprint_unique in DataCite  \
# 0
# 1
# 2                      188173.0                              172831.0
# 3
# 4
# ..                          ...                                   ...
# 746
# 747
# 748
# 749
# 750
#
#     number of unique preprints that are published in Datacite  \
# 0
# 1
# 2                                                 53.0
# 3
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     %_of unique that are published in DataCite  \
# 0
# 1
# 2                                     0.030666
# 3
# 4
# ..                                         ...
# 746
# 747
# 748
# 749
# 750
#
#     Number of unique preprints with more than 1 version in DataCite  \
# 0
# 1
# 2                                              27568.0
# 3
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     % of unique that have more than one version  in DataCite  \
# 0
# 1
# 2                                            15.950842
# 3
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     Works_in_2024 in DataCite Works_in_2025 in DataCite  \
# 0
# 1
# 2                      8072.0                    9054.0
# 3
# 4
# ..                        ...                       ...
# 746
# 747
# 748
# 749
# 750
#
#      Is the server in OpenAlex OpenAlex Data Collection Date  \
# 0                        False                    2025/12/31
# 1                        False                    2025/12/31
# 2                        False                    2025/12/31
# 3                        False                    2025/12/31
# 4                        False                    2025/12/31
# ..                         ...                           ...
# 746                      False                    2025/12/31
# 747                      False                    2025/12/31
# 748                      False                    2025/12/31
# 749                      False                    2025/12/31
# 750                      False                    2025/12/31
#
#     Number of works in OpenAlex number_of_preprint_unique in OpenAlex  \
# 0
# 1
# 2
# 3
# 4
# ..                          ...                                   ...
# 746
# 747
# 748
# 749
# 750
#
#     number of unique preprints that are published in OpenAlex  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     %_of unique that are published in OpenAlex  \
# 0
# 1
# 2
# 3
# 4
# ..                                         ...
# 746
# 747
# 748
# 749
# 750
#
#     Number of unique preprints with more than 1 version in OpenAlex  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     % of unique preprints with more than 1 version in OpenAlex  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 746
# 747
# 748
# 749
# 750
#
#     Works_in_2024 in OpenAlex Works_in_2025 in OpenAlex
# 0
# 1
# 2
# 3
# 4
# ..                        ...                       ...
# 746
# 747
# 748
# 749
# 750
#
# [751 rows x 37 columns]

# %%
overall_df.head(60)
# Out:
#                                           server_name  n_records  n_unique  \
# 0                                      AIJR Preprints        143       143
# 1                                  AMRC Open Research         38        27
# 2                                      APSA Preprints       1470      1171
# 3                                     ARPHA Preprints        890       869
# 4                                             ART-Dok       9653      9532
# 5                                             Advance       4400      2440
# 6                                          AfricArXiv        501       483
# 7                                       AgEcon Search     188173    172831
# 8                                            AgriRxiv        818       804
# 9                                            Arabixiv        502       491
# 10                                      Authorea Inc.      61903     58895
# 11                                 Beilstein Archives        697       697
# 12                           Bepress Legal Repository          6         5
# 13                                        BioHackrXiv        139       136
# 14                                          BodoArXiv        165       157
# 15                               CERN document server        972       447
# 16                              Cambridge Open Engage       3090      2135
# 17                                           ChemRxiv      46475     36435
# 18                                                CoP         30        29
# 19                                          CogPrints       1537      1535
# 20                                 Covid-19 Preprints        647       294
# 21                                           CrimRxiv       2832      2718
# 22                               CrossAsia-Repository        479       460
# 23                                         DSpace@MIT      12632     12535
# 24  Digital Access to Scholarship at Harvard (DASH...       9703      9687
# 25                                   E-LIS Repository       9128      9061
# 26                                           ECSarXiv        314       300
# 27                                          EGUsphere      10255     10178
# 28                      ELPUB (Universitat Wuppertal)         41        41
# 29               Earth and Space Science Open Archive      22928     19443
# 30                                         EarthArXiv       6537      6464
# 31                                 EasyChair preprint        620       618
# 32                                         EcoEvoRxiv       2886      2842
# 33                                 EconStor Preprints      71761     70966
# 34                                            EdArXiv       2547      2320
# 35                 Electron Colloquium Comput Complex        141       140
# 36                                              EmeRI          8         8
# 37                                       Encyclopedia        166       161
# 38                                          EnerarXiv        204       203
# 39                                      F1000Research      16866     11053
# 40                                      FocUS Archive         83        80
# 41                                            Frenxiv        179       171
# 42                                Gates Open Research        862       541
# 43                                                HAL    1056424   1037931
# 44                         HANS Publication PrePrints         75        75
# 45                                  HRB Open Research       1012       654
# 46                            Humanities Commons CORE      29570     16959
# 47                     IACR Cryptology ePrint Archive      10771     10646
# 48                                           INA-Rxiv      17837     15346
# 49                                          IndiaRxiv        142       139
# 50                                     JMIR Preprints      37631     36607
# 51                        Keldysh Institute Preprints       1258      1201
# 52                            LIS Scholarship Archive        397       353
# 53         LSE Research Online Documents on Economics        119       119
# 54                                           LatArXiv        125       123
# 55                                        Law Archive       1808      1600
# 56                                  MNI Open Research         19        13
# 57                                             MarXiv        508       489
# 58                                          MediArXiv        309       298
# 59                                          MetaArXiv        880       770
#
#     n_published  pct_published  n_is_version_of  pct_has_versions  count_2024  \
# 0             1       0.699301                9          6.293706         7.0
# 1             0       0.000000               11         40.740741         0.0
# 2           164      14.005124              263         22.459436       140.0
# 3           315      36.248562               39          4.487917       184.0
# 4             3       0.031473              106          1.112044       562.0
# 5           162       6.639344             1788         73.278689       414.0
# 6            56      11.594203               68         14.078675        16.0
# 7            53       0.030666            27568         15.950842      8072.0
# 8            24       2.985075              132         16.417910        69.0
# 9           217      44.195519              113         23.014257         0.0
# 10          789       1.339672             6221         10.562866     13605.0
# 11          461      66.140603               10          1.434720        73.0
# 12            0       0.000000                2         40.000000         0.0
# 13            0       0.000000                4          2.941176        35.0
# 14           47      29.936306               18         11.464968        11.0
# 15          400      89.485459              394         88.143177        59.0
# 16          186       8.711944              705         33.021077       446.0
# 17        17031      46.743516             8341         22.892823      6930.0
# 18            5      17.241379                1          3.448276         9.0
# 19            5       0.325733               42          2.736156         0.0
# 20            0       0.000000               32         10.884354        32.0
# 21           28       1.030169              275         10.117734       367.0
# 22            0       0.000000                3          0.652174       332.0
# 23         1724      13.753490             2236         17.838053         1.0
# 24           97       1.001342              389          4.015691      1237.0
# 25           12       0.132436              124          1.368502        95.0
# 26           24       8.000000               38         12.666667        20.0
# 27         7073      69.493024              304          2.986834      2884.0
# 28            1       2.439024                0          0.000000        34.0
# 29         2700      13.886746             3404         17.507586      2518.0
# 30         1426      22.060644              762         11.788366       884.0
# 31           14       2.265372               80         12.944984         0.0
# 32           59       2.076003              120          4.222379       591.0
# 33           68       0.095821             8582         12.093115       359.0
# 34          292      12.586207              411         17.715517       286.0
# 35            5       3.571429               32         22.857143         0.0
# 36            0       0.000000                0          0.000000         0.0
# 37            0       0.000000                6          3.726708         0.0
# 38            3       1.477833               16          7.881773         0.0
# 39          155       1.402334             4644         42.015742      1230.0
# 40            3       3.750000               37         46.250000        10.0
# 41           68      39.766082               83         48.538012         0.0
# 42            6       1.109057              305         56.377079        48.0
# 43         2536       0.244332            28296          2.726193      4870.0
# 44            0       0.000000                0          0.000000         0.0
# 45            4       0.611621              312         47.706422        79.0
# 46         8050      47.467421            11686         68.907365      2933.0
# 47           84       0.789029              352          3.306406         7.0
# 48         1341       8.738433             4314         28.111560         0.0
# 49           18      12.949640               43         30.935252         2.0
# 50        24431      66.738602             2106          5.752998      5194.0
# 51            6       0.499584               64          5.328893        82.0
# 52           69      19.546742              152         43.059490         7.0
# 53            1       0.840336               33         27.731092         0.0
# 54            7       5.691057               11          8.943089        44.0
# 55          109       6.812500              965         60.312500        35.0
# 56            0       0.000000                6         46.153846         0.0
# 57          253      51.738241              159         32.515337         2.0
# 58           90      30.201342               38         12.751678        20.0
# 59          153      19.870130              224         29.090909        78.0
#
#     count_2025
# 0          4.0
# 1          0.0
# 2        214.0
# 3        211.0
# 4        485.0
# 5        346.0
# 6          0.0
# 7       9054.0
# 8         93.0
# 9          0.0
# 10     11382.0
# 11        65.0
# 12         0.0
# 13        41.0
# 14        28.0
# 15       339.0
# 16       686.0
# 17      7951.0
# 18         7.0
# 19         0.0
# 20        27.0
# 21       496.0
# 22        90.0
# 23        13.0
# 24       667.0
# 25        55.0
# 26        17.0
# 27      4075.0
# 28         7.0
# 29      3251.0
# 30      1150.0
# 31         0.0
# 32       859.0
# 33       830.0
# 34       543.0
# 35         0.0
# 36         0.0
# 37         0.0
# 38         0.0
# 39      1058.0
# 40         8.0
# 41         0.0
# 42        21.0
# 43      3835.0
# 44         0.0
# 45       124.0
# 46      1811.0
# 47         0.0
# 48         0.0
# 49         1.0
# 50      4727.0
# 51         1.0
# 52        13.0
# 53         0.0
# 54        79.0
# 55       128.0
# 56         0.0
# 57         2.0
# 58        34.0
# 59       111.0

# %%
overall_df.tail(60)
# Out:
#                                     server_name  n_records  n_unique  \
# 52                      LIS Scholarship Archive        397       353
# 53   LSE Research Online Documents on Economics        119       119
# 54                                     LatArXiv        125       123
# 55                                  Law Archive       1808      1600
# 56                            MNI Open Research         19        13
# 57                                       MarXiv        508       489
# 58                                    MediArXiv        309       298
# 59                                    MetaArXiv        880       770
# 60                                     MindRxiv        335       292
# 61                Munich Personal RePEc Archive      68692     68585
# 62         National Bureau of Economic Research       1856      1831
# 63                            Nature Precedings       5210      3201
# 64                               NewAddictionsX          7         4
# 65                                     NutriXiv         94        86
# 66                         Open Research Africa        287       189
# 67                         Open Research Europe       1877      1190
# 68                       Open Science Framework     119481    106211
# 69                              Organic Eprints      13983     13773
# 70                         Oroboros Instruments         95        69
# 71                                 PREPRINTS.RU       1415      1371
# 72                                    PaleorXiv        287       251
# 73                              PeerJ Preprints       6446      5203
# 74                              PhilSci-Archive       2362      2347
# 75                                     PoolText         79        79
# 76                                Preprints.org     115815    106335
# 77                 Prepublicaciones OpenCiencia          8         7
# 78                                PropylaeumDok       6750      6666
# 79                                     PsyArXiv      56866     49446
# 80                                        Qeios     116478    111465
# 81          RePEc: Research Papers in Economics     389387    383338
# 82                              Research Square     450816    405719
# 83                                 ResearchGate     181231    176695
# 84                                  ResearchHub       1636      1421
# 85                                 SAE Mobilus®        105       104
# 86                                         SSRN    1258958   1182514
# 87                             SciELO Preprints       4141      4109
# 88                        ScienceOpen Preprints       4295      3917
# 89                          Sciencepaper Online         99        99
# 90                                     SocArXiv      21541     19506
# 91        Social Science Open Access Repository      27201     27031
# 92                                    SportRxiv        878       866
# 93                                     TechRxiv      29416     17881
# 94                                    Therapoid          7         6
# 95                               Thesis Commons       3959      3374
# 96                         UCL Open Environment       3467      3173
# 97                                    UnisaRxiv        126       125
# 98                                      VeriXiv        504       450
# 99                       Wellcome Open Research       4727      3439
# 100                   WikiJournal of Humanities         10         9
# 101                     WikiJournal of Medicine         63        57
# 102                      WikiJournal of Science         44        43
# 103                                      Zenodo     166786     70904
# 104                                       arXiv    2920797   2880017
# 105                                     bioRxiv     306948    306602
# 106                                       eLife      30518     19859
# 107                                     engrXiv       4929      4880
# 108                                     medRxiv      75743     75516
# 109                                   prepare@u        227       225
# 110                                  searchRxiv          2         1
# 111                                       viXra      25570     25311
#
#      n_published  pct_published  n_is_version_of  pct_has_versions  \
# 52            69      19.546742              152         43.059490
# 53             1       0.840336               33         27.731092
# 54             7       5.691057               11          8.943089
# 55           109       6.812500              965         60.312500
# 56             0       0.000000                6         46.153846
# 57           253      51.738241              159         32.515337
# 58            90      30.201342               38         12.751678
# 59           153      19.870130              224         29.090909
# 60           108      36.986301               94         32.191781
# 61            99       0.144346             3783          5.515783
# 62             0       0.000000              679         37.083561
# 63            29       0.905967             1808         56.482349
# 64             0       0.000000                2         50.000000
# 65            15      17.441860               23         26.744186
# 66             4       2.116402               90         47.619048
# 67            34       2.857143              627         52.689076
# 68         10389       9.781473            22812         21.478001
# 69             0       0.000000              247          1.793364
# 70             0       0.000000               17         24.637681
# 71            18       1.312910               73          5.324581
# 72           105      41.832669              101         40.239044
# 73            36       0.691909              992         19.065924
# 74            45       1.917341              238         10.140605
# 75            14      17.721519                0          0.000000
# 76         64464      60.623501            10711         10.072883
# 77             0       0.000000                1         14.285714
# 78             0       0.000000               58          0.870087
# 79          8335      16.856773             9028         18.258302
# 80            98       0.087920             3869          3.471045
# 81          3340       0.871294            67771         17.679176
# 82        131050      32.300681            50668         12.488446
# 83          3462       1.959308            20170         11.415150
# 84            35       2.463054              162         11.400422
# 85            18      17.307692                4          3.846154
# 86         12027       1.017070           160813         13.599247
# 87            57       1.387199               71          1.727914
# 88            57       1.455195              569         14.526423
# 89             0       0.000000                2          2.020202
# 90          5310      27.222393             5924         30.370143
# 91            14       0.051792              440          1.627761
# 92            85       9.815242               64          7.390300
# 93          2393      13.382920            10220         57.155640
# 94             0       0.000000                1         16.666667
# 95           734      21.754594              649         19.235329
# 96             8       0.252127              154          4.853451
# 97             0       0.000000                8          6.400000
# 98            42       9.333333               82         18.222222
# 99            70       2.035475             1175         34.166909
# 100            1      11.111111                2         22.222222
# 101            1       1.754386                7         12.280702
# 102            0       0.000000                2          4.651163
# 103        68640      96.806950            63974         90.226221
# 104      1272002      44.166475            94341          3.275710
# 105       112144      36.576409            21029          6.858729
# 106         5151      25.937862            10006         50.385216
# 107          602      12.336066              805         16.495902
# 108        33735      44.672652             4773          6.320515
# 109            0       0.000000                4          1.777778
# 110            0       0.000000                1        100.000000
# 111          229       0.904745             1408          5.562799
#
#      count_2024  count_2025
# 52          7.0        13.0
# 53          0.0         0.0
# 54         44.0        79.0
# 55         35.0       128.0
# 56          0.0         0.0
# 57          2.0         2.0
# 58         20.0        34.0
# 59         78.0       111.0
# 60          1.0         0.0
# 61         42.0         3.0
# 62          0.0         0.0
# 63          0.0         0.0
# 64          2.0         2.0
# 65          1.0         0.0
# 66          9.0        21.0
# 67        279.0       369.0
# 68       6742.0      6349.0
# 69         17.0         4.0
# 70          9.0        21.0
# 71        236.0       556.0
# 72         12.0        13.0
# 73          0.0         0.0
# 74          1.0        21.0
# 75          0.0         0.0
# 76      26546.0     28785.0
# 77          0.0         0.0
# 78        599.0       356.0
# 79       7200.0      8742.0
# 80       3415.0      1069.0
# 81        315.0       200.0
# 82      71160.0     57849.0
# 83      29361.0     39982.0
# 84        162.0      1049.0
# 85         13.0         0.0
# 86     195320.0    237712.0
# 87        774.0      1003.0
# 88        523.0       511.0
# 89         19.0        79.0
# 90       2196.0      2995.0
# 91         49.0       198.0
# 92        110.0       138.0
# 93       3485.0      5523.0
# 94          0.0         0.0
# 95        315.0       255.0
# 96        175.0       238.0
# 97         41.0        27.0
# 98         36.0       413.0
# 99        701.0       627.0
# 100         0.0         0.0
# 101         2.0         0.0
# 102         7.0         1.0
# 103      4554.0     58029.0
# 104    242236.0    280066.0
# 105     43397.0     44269.0
# 106      1747.0       754.0
# 107       615.0      1138.0
# 108     12791.0     13589.0
# 109        27.0         1.0
# 110         0.0         0.0
# 111        16.0         9.0

# %%
backend_df.head(60)
# Out:
#                                           server_name   backend  n_records  \
# 0                                      AIJR Preprints  crossref        143
# 1                                  AMRC Open Research  crossref         38
# 2                                      APSA Preprints  crossref       1470
# 3                                     ARPHA Preprints  crossref        890
# 4                                             ART-Dok  datacite       9653
# 5                                             Advance  crossref       4400
# 6                                          AfricArXiv  crossref        501
# 7                                       AgEcon Search  datacite     188173
# 8                                            AgriRxiv  crossref        818
# 9                                            Arabixiv  crossref        502
# 10                                      Authorea Inc.  crossref      61903
# 11                                 Beilstein Archives  crossref        697
# 12                           Bepress Legal Repository  openalex          6
# 13                                        BioHackrXiv  crossref        139
# 14                                          BodoArXiv  crossref        165
# 15                               CERN document server  datacite        972
# 16                              Cambridge Open Engage  crossref       3090
# 17                                           ChemRxiv  crossref      46475
# 18                                                CoP  crossref         30
# 19                                          CogPrints  openalex       1537
# 20                                 Covid-19 Preprints  crossref        647
# 21                                           CrimRxiv  crossref       2832
# 22                               CrossAsia-Repository  datacite        479
# 23                                         DSpace@MIT  openalex      12632
# 24  Digital Access to Scholarship at Harvard (DASH...  openalex       9703
# 25                                   E-LIS Repository  openalex       9128
# 26                                           ECSarXiv  crossref        314
# 27                                          EGUsphere  crossref      10255
# 28                      ELPUB (Universitat Wuppertal)  datacite         41
# 29               Earth and Space Science Open Archive  crossref      22928
# 30                                         EarthArXiv  crossref       6537
# 31                                 EasyChair preprint  crossref        620
# 32                                         EcoEvoRxiv  crossref       2886
# 33                                 EconStor Preprints  openalex      71761
# 34                                            EdArXiv  crossref       2547
# 35                 Electron Colloquium Comput Complex  openalex        141
# 36                                              EmeRI  crossref          8
# 37                                       Encyclopedia  crossref        166
# 38                                          EnerarXiv  crossref        204
# 39                                      F1000Research  crossref      16866
# 40                                      FocUS Archive  crossref         83
# 41                                            Frenxiv  crossref        179
# 42                                Gates Open Research  crossref        862
# 43                                                HAL  openalex    1056424
# 44                         HANS Publication PrePrints  crossref         75
# 45                                  HRB Open Research  crossref       1012
# 46                            Humanities Commons CORE  datacite      29570
# 47                     IACR Cryptology ePrint Archive  openalex      10771
# 48                                           INA-Rxiv  crossref      17837
# 49                                          IndiaRxiv  crossref        142
# 50                                     JMIR Preprints  crossref      37631
# 51                        Keldysh Institute Preprints  crossref       1258
# 52                            LIS Scholarship Archive  crossref        397
# 53         LSE Research Online Documents on Economics  openalex        119
# 54                                           LatArXiv  crossref        125
# 55                                        Law Archive  crossref       1808
# 56                                  MNI Open Research  crossref         19
# 57                                             MarXiv  crossref        508
# 58                                          MediArXiv  crossref        309
# 59                                          MetaArXiv  crossref        880
#
#     n_unique  n_published  pct_published  n_is_version_of  pct_has_versions  \
# 0        143            1       0.699301                9          6.293706
# 1         27            0       0.000000               11         40.740741
# 2       1171          164      14.005124              263         22.459436
# 3        869          315      36.248562               39          4.487917
# 4       9532            3       0.031473              106          1.112044
# 5       2440          162       6.639344             1788         73.278689
# 6        483           56      11.594203               68         14.078675
# 7     172831           53       0.030666            27568         15.950842
# 8        804           24       2.985075              132         16.417910
# 9        491          217      44.195519              113         23.014257
# 10     58895          789       1.339672             6221         10.562866
# 11       697          461      66.140603               10          1.434720
# 12         5            0       0.000000                2         40.000000
# 13       136            0       0.000000                4          2.941176
# 14       157           47      29.936306               18         11.464968
# 15       447          400      89.485459              394         88.143177
# 16      2135          186       8.711944              705         33.021077
# 17     36435        17031      46.743516             8341         22.892823
# 18        29            5      17.241379                1          3.448276
# 19      1535            5       0.325733               42          2.736156
# 20       294            0       0.000000               32         10.884354
# 21      2718           28       1.030169              275         10.117734
# 22       460            0       0.000000                3          0.652174
# 23     12535         1724      13.753490             2236         17.838053
# 24      9687           97       1.001342              389          4.015691
# 25      9061           12       0.132436              124          1.368502
# 26       300           24       8.000000               38         12.666667
# 27     10178         7073      69.493024              304          2.986834
# 28        41            1       2.439024                0          0.000000
# 29     19443         2700      13.886746             3404         17.507586
# 30      6464         1426      22.060644              762         11.788366
# 31       618           14       2.265372               80         12.944984
# 32      2842           59       2.076003              120          4.222379
# 33     70966           68       0.095821             8582         12.093115
# 34      2320          292      12.586207              411         17.715517
# 35       140            5       3.571429               32         22.857143
# 36         8            0       0.000000                0          0.000000
# 37       161            0       0.000000                6          3.726708
# 38       203            3       1.477833               16          7.881773
# 39     11053          155       1.402334             4644         42.015742
# 40        80            3       3.750000               37         46.250000
# 41       171           68      39.766082               83         48.538012
# 42       541            6       1.109057              305         56.377079
# 43   1037931         2536       0.244332            28296          2.726193
# 44        75            0       0.000000                0          0.000000
# 45       654            4       0.611621              312         47.706422
# 46     16959         8050      47.467421            11686         68.907365
# 47     10646           84       0.789029              352          3.306406
# 48     15346         1341       8.738433             4314         28.111560
# 49       139           18      12.949640               43         30.935252
# 50     36607        24431      66.738602             2106          5.752998
# 51      1201            6       0.499584               64          5.328893
# 52       353           69      19.546742              152         43.059490
# 53       119            1       0.840336               33         27.731092
# 54       123            7       5.691057               11          8.943089
# 55      1600          109       6.812500              965         60.312500
# 56        13            0       0.000000                6         46.153846
# 57       489          253      51.738241              159         32.515337
# 58       298           90      30.201342               38         12.751678
# 59       770          153      19.870130              224         29.090909
#
#     count_2024  count_2025
# 0          7.0         4.0
# 1          0.0         0.0
# 2        140.0       214.0
# 3        184.0       211.0
# 4        562.0       485.0
# 5        414.0       346.0
# 6         16.0         0.0
# 7       8072.0      9054.0
# 8         69.0        93.0
# 9          0.0         0.0
# 10     13605.0     11382.0
# 11        73.0        65.0
# 12         0.0         0.0
# 13        35.0        41.0
# 14        11.0        28.0
# 15        59.0       339.0
# 16       446.0       686.0
# 17      6930.0      7951.0
# 18         9.0         7.0
# 19         0.0         0.0
# 20        32.0        27.0
# 21       367.0       496.0
# 22       332.0        90.0
# 23         1.0        13.0
# 24      1237.0       667.0
# 25        95.0        55.0
# 26        20.0        17.0
# 27      2884.0      4075.0
# 28        34.0         7.0
# 29      2518.0      3251.0
# 30       884.0      1150.0
# 31         0.0         0.0
# 32       591.0       859.0
# 33       359.0       830.0
# 34       286.0       543.0
# 35         0.0         0.0
# 36         0.0         0.0
# 37         0.0         0.0
# 38         0.0         0.0
# 39      1230.0      1058.0
# 40        10.0         8.0
# 41         0.0         0.0
# 42        48.0        21.0
# 43      4870.0      3835.0
# 44         0.0         0.0
# 45        79.0       124.0
# 46      2933.0      1811.0
# 47         7.0         0.0
# 48         0.0         0.0
# 49         2.0         1.0
# 50      5194.0      4727.0
# 51        82.0         1.0
# 52         7.0        13.0
# 53         0.0         0.0
# 54        44.0        79.0
# 55        35.0       128.0
# 56         0.0         0.0
# 57         2.0         2.0
# 58        20.0        34.0
# 59        78.0       111.0

# %%
backend_df.tail(60)
# Out:
#                                     server_name   backend  n_records  \
# 53   LSE Research Online Documents on Economics  openalex        119
# 54                                     LatArXiv  crossref        125
# 55                                  Law Archive  crossref       1808
# 56                            MNI Open Research  crossref         19
# 57                                       MarXiv  crossref        508
# 58                                    MediArXiv  crossref        309
# 59                                    MetaArXiv  crossref        880
# 60                                     MindRxiv  crossref        335
# 61                Munich Personal RePEc Archive  openalex      68692
# 62         National Bureau of Economic Research  openalex       1856
# 63                            Nature Precedings  crossref       5210
# 64                               NewAddictionsX  crossref          7
# 65                                     NutriXiv  crossref         94
# 66                         Open Research Africa  crossref        287
# 67                         Open Research Europe  crossref       1877
# 68                       Open Science Framework  crossref     103652
# 69                       Open Science Framework  datacite      15829
# 70                              Organic Eprints  openalex      13983
# 71                         Oroboros Instruments  datacite         95
# 72                                 PREPRINTS.RU  crossref       1415
# 73                                    PaleorXiv  crossref        287
# 74                              PeerJ Preprints  crossref       6446
# 75                              PhilSci-Archive  openalex       2362
# 76                                     PoolText  crossref         79
# 77                                Preprints.org  crossref     115815
# 78                 Prepublicaciones OpenCiencia  crossref          8
# 79                                PropylaeumDok  datacite       6750
# 80                                     PsyArXiv  crossref      56866
# 81                                        Qeios  crossref     116478
# 82          RePEc: Research Papers in Economics  openalex     389387
# 83                              Research Square  crossref     450816
# 84                                 ResearchGate  datacite     181231
# 85                                  ResearchHub  crossref       1636
# 86                                 SAE Mobilus®  crossref        105
# 87                                         SSRN  crossref    1258958
# 88                             SciELO Preprints  crossref       4141
# 89                        ScienceOpen Preprints  crossref       4295
# 90                          Sciencepaper Online  crossref         99
# 91                                     SocArXiv  crossref      21541
# 92        Social Science Open Access Repository  openalex      27201
# 93                                    SportRxiv  crossref        878
# 94                                     TechRxiv  crossref      29416
# 95                                    Therapoid  crossref          7
# 96                               Thesis Commons  crossref       3959
# 97                         UCL Open Environment  crossref       3467
# 98                                    UnisaRxiv  crossref        126
# 99                                      VeriXiv  crossref        504
# 100                      Wellcome Open Research  crossref       4727
# 101                   WikiJournal of Humanities  crossref         10
# 102                     WikiJournal of Medicine  crossref         63
# 103                      WikiJournal of Science  crossref         44
# 104                                      Zenodo  datacite     166786
# 105                                       arXiv  datacite    2920797
# 106                                     bioRxiv  crossref     306948
# 107                                       eLife  crossref      30518
# 108                                     engrXiv  crossref       4929
# 109                                     medRxiv  crossref      75743
# 110                                   prepare@u  crossref        227
# 111                                  searchRxiv  crossref          2
# 112                                       viXra  openalex      25570
#
#      n_unique  n_published  pct_published  n_is_version_of  pct_has_versions  \
# 53        119            1       0.840336               33         27.731092
# 54        123            7       5.691057               11          8.943089
# 55       1600          109       6.812500              965         60.312500
# 56         13            0       0.000000                6         46.153846
# 57        489          253      51.738241              159         32.515337
# 58        298           90      30.201342               38         12.751678
# 59        770          153      19.870130              224         29.090909
# 60        292          108      36.986301               94         32.191781
# 61      68585           99       0.144346             3783          5.515783
# 62       1831            0       0.000000              679         37.083561
# 63       3201           29       0.905967             1808         56.482349
# 64          4            0       0.000000                2         50.000000
# 65         86           15      17.441860               23         26.744186
# 66        189            4       2.116402               90         47.619048
# 67       1190           34       2.857143              627         52.689076
# 68      93561         8007       8.558053            12970         13.862614
# 69      15158         2939      19.389101            12350         81.475129
# 70      13773            0       0.000000              247          1.793364
# 71         69            0       0.000000               17         24.637681
# 72       1371           18       1.312910               73          5.324581
# 73        251          105      41.832669              101         40.239044
# 74       5203           36       0.691909              992         19.065924
# 75       2347           45       1.917341              238         10.140605
# 76         79           14      17.721519                0          0.000000
# 77     106335        64464      60.623501            10711         10.072883
# 78          7            0       0.000000                1         14.285714
# 79       6666            0       0.000000               58          0.870087
# 80      49446         8335      16.856773             9028         18.258302
# 81     111465           98       0.087920             3869          3.471045
# 82     383338         3340       0.871294            67771         17.679176
# 83     405719       131050      32.300681            50668         12.488446
# 84     176695         3462       1.959308            20170         11.415150
# 85       1421           35       2.463054              162         11.400422
# 86        104           18      17.307692                4          3.846154
# 87    1182514        12027       1.017070           160813         13.599247
# 88       4109           57       1.387199               71          1.727914
# 89       3917           57       1.455195              569         14.526423
# 90         99            0       0.000000                2          2.020202
# 91      19506         5310      27.222393             5924         30.370143
# 92      27031           14       0.051792              440          1.627761
# 93        866           85       9.815242               64          7.390300
# 94      17881         2393      13.382920            10220         57.155640
# 95          6            0       0.000000                1         16.666667
# 96       3374          734      21.754594              649         19.235329
# 97       3173            8       0.252127              154          4.853451
# 98        125            0       0.000000                8          6.400000
# 99        450           42       9.333333               82         18.222222
# 100      3439           70       2.035475             1175         34.166909
# 101         9            1      11.111111                2         22.222222
# 102        57            1       1.754386                7         12.280702
# 103        43            0       0.000000                2          4.651163
# 104     70904        68640      96.806950            63974         90.226221
# 105   2880017      1272002      44.166475            94341          3.275710
# 106    306602       112144      36.576409            21029          6.858729
# 107     19859         5151      25.937862            10006         50.385216
# 108      4880          602      12.336066              805         16.495902
# 109     75516        33735      44.672652             4773          6.320515
# 110       225            0       0.000000                4          1.777778
# 111         1            0       0.000000                1        100.000000
# 112     25311          229       0.904745             1408          5.562799
#
#      count_2024  count_2025
# 53          0.0         0.0
# 54         44.0        79.0
# 55         35.0       128.0
# 56          0.0         0.0
# 57          2.0         2.0
# 58         20.0        34.0
# 59         78.0       111.0
# 60          1.0         0.0
# 61         42.0         3.0
# 62          0.0         0.0
# 63          0.0         0.0
# 64          2.0         2.0
# 65          1.0         0.0
# 66          9.0        21.0
# 67        279.0       369.0
# 68       6165.0      4775.0
# 69        594.0      1595.0
# 70         17.0         4.0
# 71          9.0        21.0
# 72        236.0       556.0
# 73         12.0        13.0
# 74          0.0         0.0
# 75          1.0        21.0
# 76          0.0         0.0
# 77      26546.0     28785.0
# 78          0.0         0.0
# 79        599.0       356.0
# 80       7200.0      8742.0
# 81       3415.0      1069.0
# 82        315.0       200.0
# 83      71160.0     57849.0
# 84      29361.0     39982.0
# 85        162.0      1049.0
# 86         13.0         0.0
# 87     195320.0    237712.0
# 88        774.0      1003.0
# 89        523.0       511.0
# 90         19.0        79.0
# 91       2196.0      2995.0
# 92         49.0       198.0
# 93        110.0       138.0
# 94       3485.0      5523.0
# 95          0.0         0.0
# 96        315.0       255.0
# 97        175.0       238.0
# 98         41.0        27.0
# 99         36.0       413.0
# 100       701.0       627.0
# 101         0.0         0.0
# 102         2.0         0.0
# 103         7.0         1.0
# 104      4554.0     58029.0
# 105    242236.0    280066.0
# 106     43397.0     44269.0
# 107      1747.0       754.0
# 108       615.0      1138.0
# 109     12791.0     13589.0
# 110        27.0         1.0
# 111         0.0         0.0
# 112        16.0         9.0
